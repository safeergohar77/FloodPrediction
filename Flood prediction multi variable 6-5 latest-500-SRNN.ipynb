# %%
import pandas as pd
from pandas import concat
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from sklearn import preprocessing
from tensorflow.keras import backend as K
#from sklearn.preprocessing import MinMaxScaler
#from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input, Dense, LSTM,GRU,SimpleRNN, Activation
from matplotlib import pyplot
#from sklearn.model_selection import train_test_split

# %%
"# convert series to supervised learning\n" 
#windowing of data
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1),
    for i in range(n_in, 0, -1): #startes from n_in and decreses to 0 by decreasing each time -1
     cols.append(df.shift(i))
     names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
     cols.append(df.shift(-i))
     if i == 0:
       names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
     else:
       names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together\n",
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values\n",
    if dropnan:
      agg.dropna(inplace=True)
    return agg

# %%
#def root_mean_squared_error(y_true, y_pred):
 #       return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
dataset1=pd.read_excel('F:\MS thesis data/Brooklyn.xlsx')
dataset1=dataset1.drop(['Date/Time','Flowd'],axis=1)
dataset1.dropna(inplace=True)

# %%
shape=np.shape(dataset1)
print(shape)
pyplot.plot(dataset1)
# Out:
# (26302, 3)
# [<matplotlib.lines.Line2D at 0x182a4622408>,
#  <matplotlib.lines.Line2D at 0x182a4615208>,
#  <matplotlib.lines.Line2D at 0x182a4613748>]

# %%
dataset1
# Out:
#        Cumulative rainfall    Flow  Level
# 0                       0.0  0.172   0.352
# 1                       0.0  0.180   0.356
# 2                       0.0  0.180   0.356
# 3                       0.0  0.189   0.360
# 4                       0.0  0.189   0.360
# ...                     ...    ...     ...
# 26297                   0.0  0.025   0.232
# 26298                   0.0  0.023   0.228
# 26299                   0.0  0.023   0.228
# 26300                   0.0  0.023   0.228
# 26301                   0.0  0.023   0.228
#
# [26302 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset1)))
# Out:
# The std of original data is Cumulative rainfall     2.872616
# Flow                    1.306642
# Level                   0.147238
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset=dataset1.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset[:,0]== maxi[0])
    ind2=np.argwhere(dataset[:,1]== maxi[1])
    ind3=np.argwhere(dataset[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset[:,0]== mini[0])
    ind2=np.argwhere(dataset[:,1]== mini[1])
    ind3=np.argwhere(dataset[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset = min_max_scaler.fit_transform(dataset)
# Out:
# The std of cleaned data is 1.626639593959813

# %%
pyplot.plot(dataset)
# Out:
# [<matplotlib.lines.Line2D at 0x182a3eb9648>,
#  <matplotlib.lines.Line2D at 0x182a3bf25c8>,
#  <matplotlib.lines.Line2D at 0x182a3bf2788>]

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=5
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values
train_size  = int(len(dataset) * 0.50)
val_size=int(len(dataset) * 0.75)
train_X, train_y = values[0:train_size, :-out_hour], values[0:train_size,-out_hour: ]
val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-out_hour: ]
test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-out_hour:]
#for last hour
#train_X, train_y = values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]  #for only last hour
#val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]
#test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-1]
print(train_X, train_y)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6341, 33)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var2(t-2)  var3(t-2)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.524545   0.776699
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.524545   0.776699
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.549980   0.791262
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.603309   0.820388
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.650485   0.844660
#
#     var1(t-1)  var2(t-1)  var3(t-1)   var3(t)  var3(t+1)  var3(t+2)  \
# 6    0.215385   0.524545   0.776699  0.791262   0.820388   0.844660
# 7    0.123077   0.549980   0.791262  0.820388   0.844660   0.873786
# 8    0.092308   0.603309   0.820388  0.844660   0.873786   0.898058
# 9    0.092308   0.650485   0.844660  0.873786   0.898058   0.932039
# 10   0.092308   0.709285   0.873786  0.898058   0.932039   0.966019
#
#     var3(t+3)  var3(t+4)
# 6    0.873786   0.898058
# 7    0.898058   0.932039
# 8    0.932039   0.966019
# 9    0.966019   1.000000
# 10   1.000000   0.941748
#
# [5 rows x 23 columns]
# [[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]
#  [0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]
#  [0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]
#  ...
#  [0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]
#  [0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]
#  [0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]] [[0.79126215 0.8203884  0.8446602  0.8737864  0.89805824]
#  [0.8203884  0.8446602  0.8737864  0.89805824 0.93203884]
#  [0.8446602  0.8737864  0.89805824 0.93203884 0.9660194 ]
#  ...
#  [0.23786408 0.24271844 0.24757281 0.24757281 0.24757281]
#  [0.24271844 0.24757281 0.24757281 0.24757281 0.2184466 ]
#  [0.24757281 0.24757281 0.24757281 0.2184466  0.23300971]]

# %%
print(train_X, train_y)
# Out:
# [[[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]]
#
#  [[0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]]
#
#  [[0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]]
#
#  ...
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]]] [[0.79126215 0.8203884  0.8446602  0.8737864  0.89805824]
#  [0.8203884  0.8446602  0.8737864  0.89805824 0.93203884]
#  [0.8446602  0.8737864  0.89805824 0.93203884 0.9660194 ]
#  ...
#  [0.23786408 0.24271844 0.24757281 0.24757281 0.24757281]
#  [0.24271844 0.24757281 0.24757281 0.24757281 0.2184466 ]
#  [0.24757281 0.24757281 0.24757281 0.2184466  0.23300971]]

# %%
print(train_X.shape, train_y.shape, val_X.shape, val_y.shape)
# Out:
# (3175, 1, 18) (3175, 5) (1588, 1, 18) (1588, 5)

# %%
randomState = 46
np.random.seed(randomState)
#tensorflow.random.set_random_seed(randomState)
tensorflow.random.set_seed(randomState)
model = Sequential()
model.add(SimpleRNN(15,input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dense(22))
#model.add(Activation('relu'))    
model.add(Dense(out_hour,activation = "sigmoid"))
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.001)
#    opt=tensorflow.keras.optimizers.Adam(learning_rate=0.00075)
model.compile(loss='mae', optimizer=opt,metrics=['mse','mae',tensorflow.keras.metrics.RootMeanSquaredError()])
history = model.fit(train_X, train_y,validation_data=(val_X, val_y), epochs=500, batch_size=100,verbose=1,shuffle=False)
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)
# Out:
# Train on 3175 samples, validate on 1588 samples
# Epoch 1/500
# 3175/3175 [==============================] - 1s 343us/sample - loss: 0.2430 - mse: 0.0720 - mae: 0.2430 - root_mean_squared_error: 0.2684 - val_loss: 0.2501 - val_mse: 0.0791 - val_mae: 0.2501 - val_root_mean_squared_error: 0.2813
# Epoch 2/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.2143 - mse: 0.0585 - mae: 0.2143 - root_mean_squared_error: 0.2419 - val_loss: 0.2266 - val_mse: 0.0668 - val_mae: 0.2266 - val_root_mean_squared_error: 0.2584
# Epoch 3/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.1936 - mse: 0.0509 - mae: 0.1936 - root_mean_squared_error: 0.2256 - val_loss: 0.2079 - val_mse: 0.0582 - val_mae: 0.2079 - val_root_mean_squared_error: 0.2412
# Epoch 4/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1782 - mse: 0.0463 - mae: 0.1782 - root_mean_squared_error: 0.2151 - val_loss: 0.1935 - val_mse: 0.0520 - val_mae: 0.1935 - val_root_mean_squared_error: 0.2281
# Epoch 5/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1666 - mse: 0.0430 - mae: 0.1666 - root_mean_squared_error: 0.2074 - val_loss: 0.1819 - val_mse: 0.0472 - val_mae: 0.1819 - val_root_mean_squared_error: 0.2172
# Epoch 6/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1566 - mse: 0.0397 - mae: 0.1566 - root_mean_squared_error: 0.1992 - val_loss: 0.1709 - val_mse: 0.0425 - val_mae: 0.1709 - val_root_mean_squared_error: 0.2060
# Epoch 7/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1464 - mse: 0.0355 - mae: 0.1464 - root_mean_squared_error: 0.1883 - val_loss: 0.1595 - val_mse: 0.0373 - val_mae: 0.1595 - val_root_mean_squared_error: 0.1932
# Epoch 8/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.1352 - mse: 0.0304 - mae: 0.1352 - root_mean_squared_error: 0.1743 - val_loss: 0.1471 - val_mse: 0.0320 - val_mae: 0.1471 - val_root_mean_squared_error: 0.1788
# Epoch 9/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.1233 - mse: 0.0252 - mae: 0.1233 - root_mean_squared_error: 0.1586 - val_loss: 0.1341 - val_mse: 0.0269 - val_mae: 0.1341 - val_root_mean_squared_error: 0.1640
# Epoch 10/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.1118 - mse: 0.0207 - mae: 0.1118 - root_mean_squared_error: 0.1438 - val_loss: 0.1217 - val_mse: 0.0228 - val_mae: 0.1217 - val_root_mean_squared_error: 0.1508
# Epoch 11/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.1016 - mse: 0.0174 - mae: 0.1016 - root_mean_squared_error: 0.1320 - val_loss: 0.1114 - val_mse: 0.0197 - val_mae: 0.1114 - val_root_mean_squared_error: 0.1403
# Epoch 12/500
# 3175/3175 [==============================] - 0s 41us/sample - loss: 0.0930 - mse: 0.0153 - mae: 0.0930 - root_mean_squared_error: 0.1238 - val_loss: 0.1035 - val_mse: 0.0176 - val_mae: 0.1035 - val_root_mean_squared_error: 0.1325
# Epoch 13/500
# 3175/3175 [==============================] - 0s 42us/sample - loss: 0.0861 - mse: 0.0141 - mae: 0.0861 - root_mean_squared_error: 0.1187 - val_loss: 0.0971 - val_mse: 0.0161 - val_mae: 0.0971 - val_root_mean_squared_error: 0.1270
# Epoch 14/500
# 3175/3175 [==============================] - 0s 43us/sample - loss: 0.0807 - mse: 0.0134 - mae: 0.0807 - root_mean_squared_error: 0.1157 - val_loss: 0.0920 - val_mse: 0.0152 - val_mae: 0.0920 - val_root_mean_squared_error: 0.1232
# Epoch 15/500
# 3175/3175 [==============================] - 0s 41us/sample - loss: 0.0764 - mse: 0.0130 - mae: 0.0764 - root_mean_squared_error: 0.1139 - val_loss: 0.0880 - val_mse: 0.0146 - val_mae: 0.0880 - val_root_mean_squared_error: 0.1207
# Epoch 16/500
# 3175/3175 [==============================] - 0s 41us/sample - loss: 0.0733 - mse: 0.0128 - mae: 0.0733 - root_mean_squared_error: 0.1130 - val_loss: 0.0849 - val_mse: 0.0142 - val_mae: 0.0849 - val_root_mean_squared_error: 0.1191
# Epoch 17/500
# 3175/3175 [==============================] - 0s 41us/sample - loss: 0.0711 - mse: 0.0126 - mae: 0.0711 - root_mean_squared_error: 0.1124 - val_loss: 0.0823 - val_mse: 0.0139 - val_mae: 0.0823 - val_root_mean_squared_error: 0.1177
# Epoch 18/500
# 3175/3175 [==============================] - 0s 41us/sample - loss: 0.0694 - mse: 0.0125 - mae: 0.0694 - root_mean_squared_error: 0.1118 - val_loss: 0.0803 - val_mse: 0.0136 - val_mae: 0.0803 - val_root_mean_squared_error: 0.1166
# Epoch 19/500
# 3175/3175 [==============================] - 0s 42us/sample - loss: 0.0681 - mse: 0.0124 - mae: 0.0681 - root_mean_squared_error: 0.1112 - val_loss: 0.0787 - val_mse: 0.0134 - val_mae: 0.0787 - val_root_mean_squared_error: 0.1157
# Epoch 20/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0670 - mse: 0.0122 - mae: 0.0670 - root_mean_squared_error: 0.1106 - val_loss: 0.0772 - val_mse: 0.0132 - val_mae: 0.0772 - val_root_mean_squared_error: 0.1149
# Epoch 21/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0660 - mse: 0.0121 - mae: 0.0660 - root_mean_squared_error: 0.1099 - val_loss: 0.0760 - val_mse: 0.0130 - val_mae: 0.0760 - val_root_mean_squared_error: 0.1140
# Epoch 22/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0650 - mse: 0.0119 - mae: 0.0650 - root_mean_squared_error: 0.1091 - val_loss: 0.0748 - val_mse: 0.0128 - val_mae: 0.0748 - val_root_mean_squared_error: 0.1131
# Epoch 23/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0641 - mse: 0.0117 - mae: 0.0641 - root_mean_squared_error: 0.1082 - val_loss: 0.0737 - val_mse: 0.0126 - val_mae: 0.0737 - val_root_mean_squared_error: 0.1122
# Epoch 24/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0632 - mse: 0.0115 - mae: 0.0632 - root_mean_squared_error: 0.1072 - val_loss: 0.0727 - val_mse: 0.0124 - val_mae: 0.0727 - val_root_mean_squared_error: 0.1113
# Epoch 25/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0624 - mse: 0.0113 - mae: 0.0624 - root_mean_squared_error: 0.1063 - val_loss: 0.0717 - val_mse: 0.0122 - val_mae: 0.0717 - val_root_mean_squared_error: 0.1104
# Epoch 26/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0616 - mse: 0.0111 - mae: 0.0616 - root_mean_squared_error: 0.1052 - val_loss: 0.0707 - val_mse: 0.0120 - val_mae: 0.0707 - val_root_mean_squared_error: 0.1094
# Epoch 27/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0608 - mse: 0.0108 - mae: 0.0608 - root_mean_squared_error: 0.1041 - val_loss: 0.0698 - val_mse: 0.0118 - val_mae: 0.0698 - val_root_mean_squared_error: 0.1085
# Epoch 28/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0600 - mse: 0.0106 - mae: 0.0600 - root_mean_squared_error: 0.1030 - val_loss: 0.0689 - val_mse: 0.0116 - val_mae: 0.0689 - val_root_mean_squared_error: 0.1076
# Epoch 29/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0592 - mse: 0.0104 - mae: 0.0592 - root_mean_squared_error: 0.1018 - val_loss: 0.0680 - val_mse: 0.0114 - val_mae: 0.0680 - val_root_mean_squared_error: 0.1067
# Epoch 30/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0584 - mse: 0.0101 - mae: 0.0584 - root_mean_squared_error: 0.1007 - val_loss: 0.0670 - val_mse: 0.0112 - val_mae: 0.0670 - val_root_mean_squared_error: 0.1056
# Epoch 31/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0577 - mse: 0.0099 - mae: 0.0577 - root_mean_squared_error: 0.0996 - val_loss: 0.0662 - val_mse: 0.0110 - val_mae: 0.0662 - val_root_mean_squared_error: 0.1047
# Epoch 32/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0570 - mse: 0.0097 - mae: 0.0570 - root_mean_squared_error: 0.0984 - val_loss: 0.0654 - val_mse: 0.0108 - val_mae: 0.0654 - val_root_mean_squared_error: 0.1039
# Epoch 33/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0562 - mse: 0.0095 - mae: 0.0562 - root_mean_squared_error: 0.0974 - val_loss: 0.0646 - val_mse: 0.0106 - val_mae: 0.0646 - val_root_mean_squared_error: 0.1031
# Epoch 34/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0556 - mse: 0.0093 - mae: 0.0556 - root_mean_squared_error: 0.0963 - val_loss: 0.0638 - val_mse: 0.0105 - val_mae: 0.0638 - val_root_mean_squared_error: 0.1024
# Epoch 35/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0549 - mse: 0.0091 - mae: 0.0549 - root_mean_squared_error: 0.0954 - val_loss: 0.0632 - val_mse: 0.0103 - val_mae: 0.0632 - val_root_mean_squared_error: 0.1016
# Epoch 36/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0543 - mse: 0.0089 - mae: 0.0543 - root_mean_squared_error: 0.0944 - val_loss: 0.0625 - val_mse: 0.0102 - val_mae: 0.0625 - val_root_mean_squared_error: 0.1009
# Epoch 37/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0537 - mse: 0.0087 - mae: 0.0537 - root_mean_squared_error: 0.0935 - val_loss: 0.0619 - val_mse: 0.0101 - val_mae: 0.0619 - val_root_mean_squared_error: 0.1003
# Epoch 38/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0532 - mse: 0.0086 - mae: 0.0532 - root_mean_squared_error: 0.0927 - val_loss: 0.0614 - val_mse: 0.0099 - val_mae: 0.0614 - val_root_mean_squared_error: 0.0997
# Epoch 39/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0527 - mse: 0.0085 - mae: 0.0527 - root_mean_squared_error: 0.0920 - val_loss: 0.0609 - val_mse: 0.0098 - val_mae: 0.0609 - val_root_mean_squared_error: 0.0992
# Epoch 40/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0523 - mse: 0.0083 - mae: 0.0523 - root_mean_squared_error: 0.0913 - val_loss: 0.0604 - val_mse: 0.0097 - val_mae: 0.0604 - val_root_mean_squared_error: 0.0987
# Epoch 41/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0518 - mse: 0.0082 - mae: 0.0518 - root_mean_squared_error: 0.0906 - val_loss: 0.0600 - val_mse: 0.0096 - val_mae: 0.0600 - val_root_mean_squared_error: 0.0982
# Epoch 42/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0514 - mse: 0.0081 - mae: 0.0514 - root_mean_squared_error: 0.0900 - val_loss: 0.0596 - val_mse: 0.0096 - val_mae: 0.0596 - val_root_mean_squared_error: 0.0978
# Epoch 43/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0511 - mse: 0.0080 - mae: 0.0511 - root_mean_squared_error: 0.0895 - val_loss: 0.0592 - val_mse: 0.0095 - val_mae: 0.0592 - val_root_mean_squared_error: 0.0974
# Epoch 44/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0508 - mse: 0.0079 - mae: 0.0508 - root_mean_squared_error: 0.0891 - val_loss: 0.0589 - val_mse: 0.0094 - val_mae: 0.0589 - val_root_mean_squared_error: 0.0972
# Epoch 45/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0505 - mse: 0.0079 - mae: 0.0505 - root_mean_squared_error: 0.0887 - val_loss: 0.0585 - val_mse: 0.0094 - val_mae: 0.0585 - val_root_mean_squared_error: 0.0968
# Epoch 46/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0502 - mse: 0.0078 - mae: 0.0502 - root_mean_squared_error: 0.0883 - val_loss: 0.0583 - val_mse: 0.0093 - val_mae: 0.0583 - val_root_mean_squared_error: 0.0966
# Epoch 47/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0500 - mse: 0.0077 - mae: 0.0500 - root_mean_squared_error: 0.0880 - val_loss: 0.0580 - val_mse: 0.0093 - val_mae: 0.0580 - val_root_mean_squared_error: 0.0963
# Epoch 48/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0498 - mse: 0.0077 - mae: 0.0498 - root_mean_squared_error: 0.0877 - val_loss: 0.0578 - val_mse: 0.0092 - val_mae: 0.0578 - val_root_mean_squared_error: 0.0961
# Epoch 49/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0496 - mse: 0.0076 - mae: 0.0496 - root_mean_squared_error: 0.0874 - val_loss: 0.0575 - val_mse: 0.0092 - val_mae: 0.0575 - val_root_mean_squared_error: 0.0960
# Epoch 50/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0494 - mse: 0.0076 - mae: 0.0494 - root_mean_squared_error: 0.0872 - val_loss: 0.0573 - val_mse: 0.0092 - val_mae: 0.0573 - val_root_mean_squared_error: 0.0958
# Epoch 51/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0492 - mse: 0.0076 - mae: 0.0492 - root_mean_squared_error: 0.0870 - val_loss: 0.0571 - val_mse: 0.0091 - val_mae: 0.0571 - val_root_mean_squared_error: 0.0956
# Epoch 52/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0491 - mse: 0.0075 - mae: 0.0491 - root_mean_squared_error: 0.0868 - val_loss: 0.0570 - val_mse: 0.0091 - val_mae: 0.0570 - val_root_mean_squared_error: 0.0955
# Epoch 53/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0490 - mse: 0.0075 - mae: 0.0490 - root_mean_squared_error: 0.0866 - val_loss: 0.0568 - val_mse: 0.0091 - val_mae: 0.0568 - val_root_mean_squared_error: 0.0954
# Epoch 54/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0488 - mse: 0.0075 - mae: 0.0488 - root_mean_squared_error: 0.0865 - val_loss: 0.0567 - val_mse: 0.0091 - val_mae: 0.0567 - val_root_mean_squared_error: 0.0953
# Epoch 55/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0487 - mse: 0.0075 - mae: 0.0487 - root_mean_squared_error: 0.0863 - val_loss: 0.0565 - val_mse: 0.0090 - val_mae: 0.0565 - val_root_mean_squared_error: 0.0951
# Epoch 56/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0486 - mse: 0.0074 - mae: 0.0486 - root_mean_squared_error: 0.0862 - val_loss: 0.0563 - val_mse: 0.0090 - val_mae: 0.0563 - val_root_mean_squared_error: 0.0950
# Epoch 57/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0485 - mse: 0.0074 - mae: 0.0485 - root_mean_squared_error: 0.0861 - val_loss: 0.0562 - val_mse: 0.0090 - val_mae: 0.0562 - val_root_mean_squared_error: 0.0948
# Epoch 58/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0484 - mse: 0.0074 - mae: 0.0484 - root_mean_squared_error: 0.0859 - val_loss: 0.0560 - val_mse: 0.0090 - val_mae: 0.0560 - val_root_mean_squared_error: 0.0947
# Epoch 59/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0483 - mse: 0.0074 - mae: 0.0483 - root_mean_squared_error: 0.0858 - val_loss: 0.0559 - val_mse: 0.0090 - val_mae: 0.0559 - val_root_mean_squared_error: 0.0946
# Epoch 60/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0481 - mse: 0.0073 - mae: 0.0481 - root_mean_squared_error: 0.0857 - val_loss: 0.0557 - val_mse: 0.0089 - val_mae: 0.0557 - val_root_mean_squared_error: 0.0945
# Epoch 61/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0480 - mse: 0.0073 - mae: 0.0480 - root_mean_squared_error: 0.0856 - val_loss: 0.0556 - val_mse: 0.0089 - val_mae: 0.0556 - val_root_mean_squared_error: 0.0944
# Epoch 62/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0479 - mse: 0.0073 - mae: 0.0479 - root_mean_squared_error: 0.0855 - val_loss: 0.0555 - val_mse: 0.0089 - val_mae: 0.0555 - val_root_mean_squared_error: 0.0943
# Epoch 63/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0478 - mse: 0.0073 - mae: 0.0478 - root_mean_squared_error: 0.0854 - val_loss: 0.0553 - val_mse: 0.0089 - val_mae: 0.0553 - val_root_mean_squared_error: 0.0941
# Epoch 64/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0970 - mse: 0.0202 - mae: 0.0970 - root_mean_squared_error: 0.142 - 0s 21us/sample - loss: 0.0477 - mse: 0.0073 - mae: 0.0477 - root_mean_squared_error: 0.0853 - val_loss: 0.0552 - val_mse: 0.0088 - val_mae: 0.0552 - val_root_mean_squared_error: 0.0941
# Epoch 65/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0476 - mse: 0.0073 - mae: 0.0476 - root_mean_squared_error: 0.0852 - val_loss: 0.0551 - val_mse: 0.0088 - val_mae: 0.0551 - val_root_mean_squared_error: 0.0939
# Epoch 66/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0966 - mse: 0.0201 - mae: 0.0966 - root_mean_squared_error: 0.141 - 0s 20us/sample - loss: 0.0475 - mse: 0.0072 - mae: 0.0475 - root_mean_squared_error: 0.0851 - val_loss: 0.0549 - val_mse: 0.0088 - val_mae: 0.0549 - val_root_mean_squared_error: 0.0938
# Epoch 67/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0474 - mse: 0.0072 - mae: 0.0474 - root_mean_squared_error: 0.0851 - val_loss: 0.0548 - val_mse: 0.0088 - val_mae: 0.0548 - val_root_mean_squared_error: 0.0938
# Epoch 68/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0473 - mse: 0.0072 - mae: 0.0473 - root_mean_squared_error: 0.0850 - val_loss: 0.0547 - val_mse: 0.0088 - val_mae: 0.0547 - val_root_mean_squared_error: 0.0937
# Epoch 69/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0472 - mse: 0.0072 - mae: 0.0472 - root_mean_squared_error: 0.0849 - val_loss: 0.0546 - val_mse: 0.0088 - val_mae: 0.0546 - val_root_mean_squared_error: 0.0936
# Epoch 70/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0471 - mse: 0.0072 - mae: 0.0471 - root_mean_squared_error: 0.0849 - val_loss: 0.0545 - val_mse: 0.0087 - val_mae: 0.0545 - val_root_mean_squared_error: 0.0935
# Epoch 71/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0470 - mse: 0.0072 - mae: 0.0470 - root_mean_squared_error: 0.0848 - val_loss: 0.0544 - val_mse: 0.0087 - val_mae: 0.0544 - val_root_mean_squared_error: 0.0935
# Epoch 72/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0470 - mse: 0.0072 - mae: 0.0470 - root_mean_squared_error: 0.0848 - val_loss: 0.0543 - val_mse: 0.0087 - val_mae: 0.0543 - val_root_mean_squared_error: 0.0934
# Epoch 73/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0469 - mse: 0.0072 - mae: 0.0469 - root_mean_squared_error: 0.0847 - val_loss: 0.0542 - val_mse: 0.0087 - val_mae: 0.0542 - val_root_mean_squared_error: 0.0933
# Epoch 74/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0468 - mse: 0.0072 - mae: 0.0468 - root_mean_squared_error: 0.0847 - val_loss: 0.0541 - val_mse: 0.0087 - val_mae: 0.0541 - val_root_mean_squared_error: 0.0933
# Epoch 75/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0468 - mse: 0.0072 - mae: 0.0468 - root_mean_squared_error: 0.0846 - val_loss: 0.0540 - val_mse: 0.0087 - val_mae: 0.0540 - val_root_mean_squared_error: 0.0932
# Epoch 76/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0467 - mse: 0.0071 - mae: 0.0467 - root_mean_squared_error: 0.0846 - val_loss: 0.0539 - val_mse: 0.0087 - val_mae: 0.0539 - val_root_mean_squared_error: 0.0931
# Epoch 77/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0466 - mse: 0.0071 - mae: 0.0466 - root_mean_squared_error: 0.0845 - val_loss: 0.0538 - val_mse: 0.0086 - val_mae: 0.0538 - val_root_mean_squared_error: 0.0930
# Epoch 78/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0465 - mse: 0.0071 - mae: 0.0465 - root_mean_squared_error: 0.0844 - val_loss: 0.0537 - val_mse: 0.0086 - val_mae: 0.0537 - val_root_mean_squared_error: 0.0929
# Epoch 79/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0464 - mse: 0.0071 - mae: 0.0464 - root_mean_squared_error: 0.0844 - val_loss: 0.0536 - val_mse: 0.0086 - val_mae: 0.0536 - val_root_mean_squared_error: 0.0928
# Epoch 80/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0464 - mse: 0.0071 - mae: 0.0464 - root_mean_squared_error: 0.0844 - val_loss: 0.0535 - val_mse: 0.0086 - val_mae: 0.0535 - val_root_mean_squared_error: 0.0928
# Epoch 81/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0463 - mse: 0.0071 - mae: 0.0463 - root_mean_squared_error: 0.0843 - val_loss: 0.0534 - val_mse: 0.0086 - val_mae: 0.0534 - val_root_mean_squared_error: 0.0927
# Epoch 82/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0462 - mse: 0.0071 - mae: 0.0462 - root_mean_squared_error: 0.0843 - val_loss: 0.0533 - val_mse: 0.0086 - val_mae: 0.0533 - val_root_mean_squared_error: 0.0927
# Epoch 83/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0462 - mse: 0.0071 - mae: 0.0462 - root_mean_squared_error: 0.0843 - val_loss: 0.0532 - val_mse: 0.0086 - val_mae: 0.0532 - val_root_mean_squared_error: 0.0926
# Epoch 84/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0461 - mse: 0.0071 - mae: 0.0461 - root_mean_squared_error: 0.0842 - val_loss: 0.0531 - val_mse: 0.0086 - val_mae: 0.0531 - val_root_mean_squared_error: 0.0925
# Epoch 85/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0460 - mse: 0.0071 - mae: 0.0460 - root_mean_squared_error: 0.0842 - val_loss: 0.0530 - val_mse: 0.0086 - val_mae: 0.0530 - val_root_mean_squared_error: 0.0925
# Epoch 86/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0460 - mse: 0.0071 - mae: 0.0460 - root_mean_squared_error: 0.0842 - val_loss: 0.0529 - val_mse: 0.0085 - val_mae: 0.0529 - val_root_mean_squared_error: 0.0924
# Epoch 87/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0459 - mse: 0.0071 - mae: 0.0459 - root_mean_squared_error: 0.0841 - val_loss: 0.0528 - val_mse: 0.0085 - val_mae: 0.0528 - val_root_mean_squared_error: 0.0924
# Epoch 88/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0459 - mse: 0.0071 - mae: 0.0459 - root_mean_squared_error: 0.0841 - val_loss: 0.0528 - val_mse: 0.0085 - val_mae: 0.0528 - val_root_mean_squared_error: 0.0923
# Epoch 89/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0458 - mse: 0.0071 - mae: 0.0458 - root_mean_squared_error: 0.0841 - val_loss: 0.0527 - val_mse: 0.0085 - val_mae: 0.0527 - val_root_mean_squared_error: 0.0923
# Epoch 90/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0457 - mse: 0.0071 - mae: 0.0457 - root_mean_squared_error: 0.0840 - val_loss: 0.0526 - val_mse: 0.0085 - val_mae: 0.0526 - val_root_mean_squared_error: 0.0922
# Epoch 91/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0457 - mse: 0.0071 - mae: 0.0457 - root_mean_squared_error: 0.0840 - val_loss: 0.0526 - val_mse: 0.0085 - val_mae: 0.0526 - val_root_mean_squared_error: 0.0922
# Epoch 92/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0456 - mse: 0.0071 - mae: 0.0456 - root_mean_squared_error: 0.0840 - val_loss: 0.0525 - val_mse: 0.0085 - val_mae: 0.0525 - val_root_mean_squared_error: 0.0922
# Epoch 93/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0456 - mse: 0.0071 - mae: 0.0456 - root_mean_squared_error: 0.0840 - val_loss: 0.0524 - val_mse: 0.0085 - val_mae: 0.0524 - val_root_mean_squared_error: 0.0921
# Epoch 94/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0455 - mse: 0.0071 - mae: 0.0455 - root_mean_squared_error: 0.0840 - val_loss: 0.0524 - val_mse: 0.0085 - val_mae: 0.0524 - val_root_mean_squared_error: 0.0921
# Epoch 95/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0455 - mse: 0.0071 - mae: 0.0455 - root_mean_squared_error: 0.0840 - val_loss: 0.0523 - val_mse: 0.0085 - val_mae: 0.0523 - val_root_mean_squared_error: 0.0921
# Epoch 96/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0454 - mse: 0.0071 - mae: 0.0454 - root_mean_squared_error: 0.0840 - val_loss: 0.0522 - val_mse: 0.0085 - val_mae: 0.0522 - val_root_mean_squared_error: 0.0920
# Epoch 97/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0454 - mse: 0.0070 - mae: 0.0454 - root_mean_squared_error: 0.0839 - val_loss: 0.0521 - val_mse: 0.0085 - val_mae: 0.0521 - val_root_mean_squared_error: 0.0919
# Epoch 98/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0453 - mse: 0.0070 - mae: 0.0453 - root_mean_squared_error: 0.0839 - val_loss: 0.0521 - val_mse: 0.0084 - val_mae: 0.0521 - val_root_mean_squared_error: 0.0919
# Epoch 99/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0453 - mse: 0.0070 - mae: 0.0453 - root_mean_squared_error: 0.0839 - val_loss: 0.0520 - val_mse: 0.0084 - val_mae: 0.0520 - val_root_mean_squared_error: 0.0918
# Epoch 100/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0452 - mse: 0.0070 - mae: 0.0452 - root_mean_squared_error: 0.0839 - val_loss: 0.0519 - val_mse: 0.0084 - val_mae: 0.0519 - val_root_mean_squared_error: 0.0918
# Epoch 101/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0452 - mse: 0.0070 - mae: 0.0452 - root_mean_squared_error: 0.0839 - val_loss: 0.0518 - val_mse: 0.0084 - val_mae: 0.0518 - val_root_mean_squared_error: 0.0918
# Epoch 102/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0451 - mse: 0.0070 - mae: 0.0451 - root_mean_squared_error: 0.0839 - val_loss: 0.0518 - val_mse: 0.0084 - val_mae: 0.0518 - val_root_mean_squared_error: 0.0917
# Epoch 103/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0451 - mse: 0.0070 - mae: 0.0451 - root_mean_squared_error: 0.0839 - val_loss: 0.0517 - val_mse: 0.0084 - val_mae: 0.0517 - val_root_mean_squared_error: 0.0917
# Epoch 104/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0451 - mse: 0.0070 - mae: 0.0451 - root_mean_squared_error: 0.0839 - val_loss: 0.0517 - val_mse: 0.0084 - val_mae: 0.0517 - val_root_mean_squared_error: 0.0917
# Epoch 105/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0450 - mse: 0.0070 - mae: 0.0450 - root_mean_squared_error: 0.0839 - val_loss: 0.0516 - val_mse: 0.0084 - val_mae: 0.0516 - val_root_mean_squared_error: 0.0917
# Epoch 106/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0450 - mse: 0.0070 - mae: 0.0450 - root_mean_squared_error: 0.0839 - val_loss: 0.0515 - val_mse: 0.0084 - val_mae: 0.0515 - val_root_mean_squared_error: 0.0916
# Epoch 107/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0450 - mse: 0.0070 - mae: 0.0450 - root_mean_squared_error: 0.0838 - val_loss: 0.0515 - val_mse: 0.0084 - val_mae: 0.0515 - val_root_mean_squared_error: 0.0916
# Epoch 108/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0449 - mse: 0.0070 - mae: 0.0449 - root_mean_squared_error: 0.0838 - val_loss: 0.0514 - val_mse: 0.0084 - val_mae: 0.0514 - val_root_mean_squared_error: 0.0916
# Epoch 109/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0449 - mse: 0.0070 - mae: 0.0449 - root_mean_squared_error: 0.0838 - val_loss: 0.0514 - val_mse: 0.0084 - val_mae: 0.0514 - val_root_mean_squared_error: 0.0916
# Epoch 110/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0448 - mse: 0.0070 - mae: 0.0448 - root_mean_squared_error: 0.0838 - val_loss: 0.0513 - val_mse: 0.0084 - val_mae: 0.0513 - val_root_mean_squared_error: 0.0915
# Epoch 111/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0448 - mse: 0.0070 - mae: 0.0448 - root_mean_squared_error: 0.0838 - val_loss: 0.0513 - val_mse: 0.0084 - val_mae: 0.0513 - val_root_mean_squared_error: 0.0915
# Epoch 112/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0448 - mse: 0.0070 - mae: 0.0448 - root_mean_squared_error: 0.0838 - val_loss: 0.0512 - val_mse: 0.0084 - val_mae: 0.0512 - val_root_mean_squared_error: 0.0915
# Epoch 113/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0447 - mse: 0.0070 - mae: 0.0447 - root_mean_squared_error: 0.0838 - val_loss: 0.0511 - val_mse: 0.0084 - val_mae: 0.0511 - val_root_mean_squared_error: 0.0914
# Epoch 114/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0447 - mse: 0.0070 - mae: 0.0447 - root_mean_squared_error: 0.0838 - val_loss: 0.0511 - val_mse: 0.0084 - val_mae: 0.0511 - val_root_mean_squared_error: 0.0914
# Epoch 115/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0447 - mse: 0.0070 - mae: 0.0447 - root_mean_squared_error: 0.0838 - val_loss: 0.0510 - val_mse: 0.0084 - val_mae: 0.0510 - val_root_mean_squared_error: 0.0914
# Epoch 116/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0446 - mse: 0.0070 - mae: 0.0446 - root_mean_squared_error: 0.0838 - val_loss: 0.0510 - val_mse: 0.0084 - val_mae: 0.0510 - val_root_mean_squared_error: 0.0914
# Epoch 117/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0446 - mse: 0.0070 - mae: 0.0446 - root_mean_squared_error: 0.0838 - val_loss: 0.0509 - val_mse: 0.0083 - val_mae: 0.0509 - val_root_mean_squared_error: 0.0914
# Epoch 118/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0446 - mse: 0.0070 - mae: 0.0446 - root_mean_squared_error: 0.0838 - val_loss: 0.0509 - val_mse: 0.0083 - val_mae: 0.0509 - val_root_mean_squared_error: 0.0913
# Epoch 119/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0445 - mse: 0.0070 - mae: 0.0445 - root_mean_squared_error: 0.0838 - val_loss: 0.0508 - val_mse: 0.0083 - val_mae: 0.0508 - val_root_mean_squared_error: 0.0913
# Epoch 120/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0445 - mse: 0.0070 - mae: 0.0445 - root_mean_squared_error: 0.0838 - val_loss: 0.0508 - val_mse: 0.0083 - val_mae: 0.0508 - val_root_mean_squared_error: 0.0913
# Epoch 121/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0890 - mse: 0.0191 - mae: 0.0890 - root_mean_squared_error: 0.138 - 0s 21us/sample - loss: 0.0445 - mse: 0.0070 - mae: 0.0445 - root_mean_squared_error: 0.0838 - val_loss: 0.0507 - val_mse: 0.0083 - val_mae: 0.0507 - val_root_mean_squared_error: 0.0912
# Epoch 122/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0445 - mse: 0.0070 - mae: 0.0445 - root_mean_squared_error: 0.0838 - val_loss: 0.0507 - val_mse: 0.0083 - val_mae: 0.0507 - val_root_mean_squared_error: 0.0913
# Epoch 123/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0444 - mse: 0.0070 - mae: 0.0444 - root_mean_squared_error: 0.0838 - val_loss: 0.0507 - val_mse: 0.0083 - val_mae: 0.0507 - val_root_mean_squared_error: 0.0912
# Epoch 124/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0444 - mse: 0.0070 - mae: 0.0444 - root_mean_squared_error: 0.0838 - val_loss: 0.0506 - val_mse: 0.0083 - val_mae: 0.0506 - val_root_mean_squared_error: 0.0912
# Epoch 125/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0444 - mse: 0.0070 - mae: 0.0444 - root_mean_squared_error: 0.0838 - val_loss: 0.0506 - val_mse: 0.0083 - val_mae: 0.0506 - val_root_mean_squared_error: 0.0912
# Epoch 126/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0444 - mse: 0.0070 - mae: 0.0444 - root_mean_squared_error: 0.0838 - val_loss: 0.0505 - val_mse: 0.0083 - val_mae: 0.0505 - val_root_mean_squared_error: 0.0912
# Epoch 127/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0444 - mse: 0.0070 - mae: 0.0444 - root_mean_squared_error: 0.0838 - val_loss: 0.0505 - val_mse: 0.0083 - val_mae: 0.0505 - val_root_mean_squared_error: 0.0911
# Epoch 128/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0443 - mse: 0.0070 - mae: 0.0443 - root_mean_squared_error: 0.0838 - val_loss: 0.0505 - val_mse: 0.0083 - val_mae: 0.0505 - val_root_mean_squared_error: 0.0912
# Epoch 129/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0443 - mse: 0.0070 - mae: 0.0443 - root_mean_squared_error: 0.0838 - val_loss: 0.0504 - val_mse: 0.0083 - val_mae: 0.0504 - val_root_mean_squared_error: 0.0911
# Epoch 130/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0443 - mse: 0.0070 - mae: 0.0443 - root_mean_squared_error: 0.0838 - val_loss: 0.0503 - val_mse: 0.0083 - val_mae: 0.0503 - val_root_mean_squared_error: 0.0911
# Epoch 131/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0443 - mse: 0.0070 - mae: 0.0443 - root_mean_squared_error: 0.0838 - val_loss: 0.0503 - val_mse: 0.0083 - val_mae: 0.0503 - val_root_mean_squared_error: 0.0910
# Epoch 132/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0442 - mse: 0.0070 - mae: 0.0442 - root_mean_squared_error: 0.0838 - val_loss: 0.0503 - val_mse: 0.0083 - val_mae: 0.0503 - val_root_mean_squared_error: 0.0910
# Epoch 133/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0442 - mse: 0.0070 - mae: 0.0442 - root_mean_squared_error: 0.0838 - val_loss: 0.0502 - val_mse: 0.0083 - val_mae: 0.0502 - val_root_mean_squared_error: 0.0911
# Epoch 134/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0442 - mse: 0.0070 - mae: 0.0442 - root_mean_squared_error: 0.0838 - val_loss: 0.0502 - val_mse: 0.0083 - val_mae: 0.0502 - val_root_mean_squared_error: 0.0910
# Epoch 135/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0442 - mse: 0.0070 - mae: 0.0442 - root_mean_squared_error: 0.0838 - val_loss: 0.0502 - val_mse: 0.0083 - val_mae: 0.0502 - val_root_mean_squared_error: 0.0910
# Epoch 136/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0442 - mse: 0.0070 - mae: 0.0442 - root_mean_squared_error: 0.0838 - val_loss: 0.0501 - val_mse: 0.0083 - val_mae: 0.0501 - val_root_mean_squared_error: 0.0909
# Epoch 137/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0441 - mse: 0.0070 - mae: 0.0441 - root_mean_squared_error: 0.0838 - val_loss: 0.0501 - val_mse: 0.0083 - val_mae: 0.0501 - val_root_mean_squared_error: 0.0910
# Epoch 138/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0441 - mse: 0.0070 - mae: 0.0441 - root_mean_squared_error: 0.0838 - val_loss: 0.0500 - val_mse: 0.0083 - val_mae: 0.0500 - val_root_mean_squared_error: 0.0909
# Epoch 139/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0441 - mse: 0.0070 - mae: 0.0441 - root_mean_squared_error: 0.0838 - val_loss: 0.0500 - val_mse: 0.0083 - val_mae: 0.0500 - val_root_mean_squared_error: 0.0909
# Epoch 140/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0441 - mse: 0.0070 - mae: 0.0441 - root_mean_squared_error: 0.0838 - val_loss: 0.0499 - val_mse: 0.0083 - val_mae: 0.0499 - val_root_mean_squared_error: 0.0909
# Epoch 141/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0441 - mse: 0.0070 - mae: 0.0441 - root_mean_squared_error: 0.0838 - val_loss: 0.0499 - val_mse: 0.0083 - val_mae: 0.0499 - val_root_mean_squared_error: 0.0909
# Epoch 142/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0440 - mse: 0.0070 - mae: 0.0440 - root_mean_squared_error: 0.0838 - val_loss: 0.0498 - val_mse: 0.0082 - val_mae: 0.0498 - val_root_mean_squared_error: 0.0908
# Epoch 143/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0440 - mse: 0.0070 - mae: 0.0440 - root_mean_squared_error: 0.0838 - val_loss: 0.0498 - val_mse: 0.0083 - val_mae: 0.0498 - val_root_mean_squared_error: 0.0909
# Epoch 144/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0440 - mse: 0.0070 - mae: 0.0440 - root_mean_squared_error: 0.0838 - val_loss: 0.0498 - val_mse: 0.0083 - val_mae: 0.0498 - val_root_mean_squared_error: 0.0908
# Epoch 145/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0440 - mse: 0.0070 - mae: 0.0440 - root_mean_squared_error: 0.0838 - val_loss: 0.0498 - val_mse: 0.0082 - val_mae: 0.0498 - val_root_mean_squared_error: 0.0908
# Epoch 146/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0440 - mse: 0.0070 - mae: 0.0440 - root_mean_squared_error: 0.0838 - val_loss: 0.0497 - val_mse: 0.0082 - val_mae: 0.0497 - val_root_mean_squared_error: 0.0908
# Epoch 147/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0440 - mse: 0.0070 - mae: 0.0440 - root_mean_squared_error: 0.0838 - val_loss: 0.0497 - val_mse: 0.0082 - val_mae: 0.0497 - val_root_mean_squared_error: 0.0908
# Epoch 148/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0439 - mse: 0.0070 - mae: 0.0439 - root_mean_squared_error: 0.0838 - val_loss: 0.0496 - val_mse: 0.0082 - val_mae: 0.0496 - val_root_mean_squared_error: 0.0907
# Epoch 149/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0439 - mse: 0.0070 - mae: 0.0439 - root_mean_squared_error: 0.0838 - val_loss: 0.0496 - val_mse: 0.0082 - val_mae: 0.0496 - val_root_mean_squared_error: 0.0908
# Epoch 150/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0439 - mse: 0.0070 - mae: 0.0439 - root_mean_squared_error: 0.0839 - val_loss: 0.0496 - val_mse: 0.0082 - val_mae: 0.0496 - val_root_mean_squared_error: 0.0907
# Epoch 151/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0439 - mse: 0.0070 - mae: 0.0439 - root_mean_squared_error: 0.0838 - val_loss: 0.0496 - val_mse: 0.0082 - val_mae: 0.0496 - val_root_mean_squared_error: 0.0907
# Epoch 152/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0439 - mse: 0.0070 - mae: 0.0439 - root_mean_squared_error: 0.0839 - val_loss: 0.0495 - val_mse: 0.0082 - val_mae: 0.0495 - val_root_mean_squared_error: 0.0907
# Epoch 153/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0439 - mse: 0.0070 - mae: 0.0439 - root_mean_squared_error: 0.0838 - val_loss: 0.0495 - val_mse: 0.0082 - val_mae: 0.0495 - val_root_mean_squared_error: 0.0907
# Epoch 154/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0438 - mse: 0.0070 - mae: 0.0438 - root_mean_squared_error: 0.0839 - val_loss: 0.0495 - val_mse: 0.0082 - val_mae: 0.0495 - val_root_mean_squared_error: 0.0907
# Epoch 155/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0438 - mse: 0.0070 - mae: 0.0438 - root_mean_squared_error: 0.0839 - val_loss: 0.0494 - val_mse: 0.0082 - val_mae: 0.0494 - val_root_mean_squared_error: 0.0907
# Epoch 156/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0438 - mse: 0.0070 - mae: 0.0438 - root_mean_squared_error: 0.0839 - val_loss: 0.0494 - val_mse: 0.0082 - val_mae: 0.0494 - val_root_mean_squared_error: 0.0907
# Epoch 157/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0438 - mse: 0.0070 - mae: 0.0438 - root_mean_squared_error: 0.0839 - val_loss: 0.0494 - val_mse: 0.0082 - val_mae: 0.0494 - val_root_mean_squared_error: 0.0907
# Epoch 158/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0438 - mse: 0.0070 - mae: 0.0438 - root_mean_squared_error: 0.0839 - val_loss: 0.0494 - val_mse: 0.0082 - val_mae: 0.0494 - val_root_mean_squared_error: 0.0907
# Epoch 159/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0438 - mse: 0.0070 - mae: 0.0438 - root_mean_squared_error: 0.0839 - val_loss: 0.0493 - val_mse: 0.0082 - val_mae: 0.0493 - val_root_mean_squared_error: 0.0906
# Epoch 160/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0437 - mse: 0.0070 - mae: 0.0437 - root_mean_squared_error: 0.0839 - val_loss: 0.0493 - val_mse: 0.0082 - val_mae: 0.0493 - val_root_mean_squared_error: 0.0906
# Epoch 161/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0437 - mse: 0.0070 - mae: 0.0437 - root_mean_squared_error: 0.0839 - val_loss: 0.0493 - val_mse: 0.0082 - val_mae: 0.0493 - val_root_mean_squared_error: 0.0906
# Epoch 162/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0437 - mse: 0.0070 - mae: 0.0437 - root_mean_squared_error: 0.0839 - val_loss: 0.0492 - val_mse: 0.0082 - val_mae: 0.0492 - val_root_mean_squared_error: 0.0906
# Epoch 163/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0437 - mse: 0.0070 - mae: 0.0437 - root_mean_squared_error: 0.0839 - val_loss: 0.0492 - val_mse: 0.0082 - val_mae: 0.0492 - val_root_mean_squared_error: 0.0906
# Epoch 164/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0437 - mse: 0.0070 - mae: 0.0437 - root_mean_squared_error: 0.0839 - val_loss: 0.0492 - val_mse: 0.0082 - val_mae: 0.0492 - val_root_mean_squared_error: 0.0906
# Epoch 165/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0437 - mse: 0.0070 - mae: 0.0437 - root_mean_squared_error: 0.0839 - val_loss: 0.0492 - val_mse: 0.0082 - val_mae: 0.0492 - val_root_mean_squared_error: 0.0906
# Epoch 166/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0437 - mse: 0.0070 - mae: 0.0437 - root_mean_squared_error: 0.0839 - val_loss: 0.0491 - val_mse: 0.0082 - val_mae: 0.0491 - val_root_mean_squared_error: 0.0906
# Epoch 167/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0437 - mse: 0.0070 - mae: 0.0437 - root_mean_squared_error: 0.0839 - val_loss: 0.0491 - val_mse: 0.0082 - val_mae: 0.0491 - val_root_mean_squared_error: 0.0906
# Epoch 168/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0437 - mse: 0.0070 - mae: 0.0437 - root_mean_squared_error: 0.0839 - val_loss: 0.0491 - val_mse: 0.0082 - val_mae: 0.0491 - val_root_mean_squared_error: 0.0906
# Epoch 169/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0436 - mse: 0.0070 - mae: 0.0436 - root_mean_squared_error: 0.0839 - val_loss: 0.0491 - val_mse: 0.0082 - val_mae: 0.0491 - val_root_mean_squared_error: 0.0906
# Epoch 170/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0436 - mse: 0.0070 - mae: 0.0436 - root_mean_squared_error: 0.0839 - val_loss: 0.0491 - val_mse: 0.0082 - val_mae: 0.0491 - val_root_mean_squared_error: 0.0906
# Epoch 171/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0436 - mse: 0.0070 - mae: 0.0436 - root_mean_squared_error: 0.0839 - val_loss: 0.0490 - val_mse: 0.0082 - val_mae: 0.0490 - val_root_mean_squared_error: 0.0905
# Epoch 172/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0436 - mse: 0.0070 - mae: 0.0436 - root_mean_squared_error: 0.0839 - val_loss: 0.0490 - val_mse: 0.0082 - val_mae: 0.0490 - val_root_mean_squared_error: 0.0905
# Epoch 173/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0436 - mse: 0.0070 - mae: 0.0436 - root_mean_squared_error: 0.0839 - val_loss: 0.0490 - val_mse: 0.0082 - val_mae: 0.0490 - val_root_mean_squared_error: 0.0905
# Epoch 174/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0436 - mse: 0.0070 - mae: 0.0436 - root_mean_squared_error: 0.0839 - val_loss: 0.0490 - val_mse: 0.0082 - val_mae: 0.0490 - val_root_mean_squared_error: 0.0905
# Epoch 175/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0871 - mse: 0.0189 - mae: 0.0871 - root_mean_squared_error: 0.137 - 0s 21us/sample - loss: 0.0436 - mse: 0.0070 - mae: 0.0436 - root_mean_squared_error: 0.0839 - val_loss: 0.0489 - val_mse: 0.0082 - val_mae: 0.0489 - val_root_mean_squared_error: 0.0905
# Epoch 176/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0436 - mse: 0.0070 - mae: 0.0436 - root_mean_squared_error: 0.0839 - val_loss: 0.0489 - val_mse: 0.0082 - val_mae: 0.0489 - val_root_mean_squared_error: 0.0905
# Epoch 177/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0435 - mse: 0.0070 - mae: 0.0435 - root_mean_squared_error: 0.0839 - val_loss: 0.0489 - val_mse: 0.0082 - val_mae: 0.0489 - val_root_mean_squared_error: 0.0905
# Epoch 178/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0435 - mse: 0.0070 - mae: 0.0435 - root_mean_squared_error: 0.0839 - val_loss: 0.0488 - val_mse: 0.0082 - val_mae: 0.0488 - val_root_mean_squared_error: 0.0905
# Epoch 179/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0435 - mse: 0.0070 - mae: 0.0435 - root_mean_squared_error: 0.0839 - val_loss: 0.0488 - val_mse: 0.0082 - val_mae: 0.0488 - val_root_mean_squared_error: 0.0905
# Epoch 180/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0435 - mse: 0.0070 - mae: 0.0435 - root_mean_squared_error: 0.0838 - val_loss: 0.0488 - val_mse: 0.0082 - val_mae: 0.0488 - val_root_mean_squared_error: 0.0905
# Epoch 181/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0435 - mse: 0.0070 - mae: 0.0435 - root_mean_squared_error: 0.0838 - val_loss: 0.0488 - val_mse: 0.0082 - val_mae: 0.0488 - val_root_mean_squared_error: 0.0904
# Epoch 182/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0435 - mse: 0.0070 - mae: 0.0435 - root_mean_squared_error: 0.0838 - val_loss: 0.0487 - val_mse: 0.0082 - val_mae: 0.0487 - val_root_mean_squared_error: 0.0904
# Epoch 183/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0435 - mse: 0.0070 - mae: 0.0435 - root_mean_squared_error: 0.0838 - val_loss: 0.0487 - val_mse: 0.0082 - val_mae: 0.0487 - val_root_mean_squared_error: 0.0904
# Epoch 184/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0435 - mse: 0.0070 - mae: 0.0435 - root_mean_squared_error: 0.0838 - val_loss: 0.0487 - val_mse: 0.0082 - val_mae: 0.0487 - val_root_mean_squared_error: 0.0904
# Epoch 185/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0435 - mse: 0.0070 - mae: 0.0435 - root_mean_squared_error: 0.0838 - val_loss: 0.0487 - val_mse: 0.0082 - val_mae: 0.0487 - val_root_mean_squared_error: 0.0904
# Epoch 186/500
# 3175/3175 [==============================] - 0s 19us/sample - loss: 0.0434 - mse: 0.0070 - mae: 0.0434 - root_mean_squared_error: 0.0838 - val_loss: 0.0486 - val_mse: 0.0082 - val_mae: 0.0486 - val_root_mean_squared_error: 0.0904
# Epoch 187/500
# 3175/3175 [==============================] - 0s 18us/sample - loss: 0.0434 - mse: 0.0070 - mae: 0.0434 - root_mean_squared_error: 0.0838 - val_loss: 0.0486 - val_mse: 0.0082 - val_mae: 0.0486 - val_root_mean_squared_error: 0.0904
# Epoch 188/500
# 3175/3175 [==============================] - 0s 19us/sample - loss: 0.0434 - mse: 0.0070 - mae: 0.0434 - root_mean_squared_error: 0.0838 - val_loss: 0.0486 - val_mse: 0.0082 - val_mae: 0.0486 - val_root_mean_squared_error: 0.0903
# Epoch 189/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0434 - mse: 0.0070 - mae: 0.0434 - root_mean_squared_error: 0.0838 - val_loss: 0.0486 - val_mse: 0.0082 - val_mae: 0.0486 - val_root_mean_squared_error: 0.0903
# Epoch 190/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0434 - mse: 0.0070 - mae: 0.0434 - root_mean_squared_error: 0.0838 - val_loss: 0.0486 - val_mse: 0.0082 - val_mae: 0.0486 - val_root_mean_squared_error: 0.0903
# Epoch 191/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0866 - mse: 0.0188 - mae: 0.0866 - root_mean_squared_error: 0.137 - 0s 21us/sample - loss: 0.0434 - mse: 0.0070 - mae: 0.0434 - root_mean_squared_error: 0.0838 - val_loss: 0.0485 - val_mse: 0.0082 - val_mae: 0.0485 - val_root_mean_squared_error: 0.0903
# Epoch 192/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0434 - mse: 0.0070 - mae: 0.0434 - root_mean_squared_error: 0.0838 - val_loss: 0.0485 - val_mse: 0.0082 - val_mae: 0.0485 - val_root_mean_squared_error: 0.0903
# Epoch 193/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0434 - mse: 0.0070 - mae: 0.0434 - root_mean_squared_error: 0.0838 - val_loss: 0.0485 - val_mse: 0.0082 - val_mae: 0.0485 - val_root_mean_squared_error: 0.0903
# Epoch 194/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0434 - mse: 0.0070 - mae: 0.0434 - root_mean_squared_error: 0.0838 - val_loss: 0.0485 - val_mse: 0.0081 - val_mae: 0.0485 - val_root_mean_squared_error: 0.0903
# Epoch 195/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0434 - mse: 0.0070 - mae: 0.0434 - root_mean_squared_error: 0.0838 - val_loss: 0.0484 - val_mse: 0.0081 - val_mae: 0.0484 - val_root_mean_squared_error: 0.0903
# Epoch 196/500
# ...
# Epoch 436/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0423 - mse: 0.0069 - mae: 0.0423 - root_mean_squared_error: 0.0830 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 437/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0423 - mse: 0.0069 - mae: 0.0423 - root_mean_squared_error: 0.0830 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 438/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0423 - mse: 0.0069 - mae: 0.0423 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 439/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0423 - mse: 0.0069 - mae: 0.0423 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 440/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0423 - mse: 0.0069 - mae: 0.0423 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 441/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0423 - mse: 0.0069 - mae: 0.0423 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 442/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0423 - mse: 0.0069 - mae: 0.0423 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 443/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0423 - mse: 0.0069 - mae: 0.0423 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 444/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0423 - mse: 0.0069 - mae: 0.0423 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 445/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0423 - mse: 0.0069 - mae: 0.0423 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 446/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0423 - mse: 0.0069 - mae: 0.0423 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 447/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0423 - mse: 0.0069 - mae: 0.0423 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 448/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0423 - mse: 0.0069 - mae: 0.0423 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 449/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0423 - mse: 0.0069 - mae: 0.0423 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 450/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 451/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0423 - mse: 0.0069 - mae: 0.0423 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 452/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0423 - mse: 0.0069 - mae: 0.0423 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 453/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 454/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 455/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 456/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0423 - mse: 0.0069 - mae: 0.0423 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 457/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 458/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0463 - val_mse: 0.0080 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0895
# Epoch 459/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 460/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 461/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 462/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 463/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 464/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 465/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 466/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 467/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 468/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 469/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 470/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 471/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 472/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 473/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 474/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 475/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0894
# Epoch 476/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 477/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 478/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 479/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0894
# Epoch 480/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 481/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0828 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 482/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0894
# Epoch 483/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 484/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 485/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0828 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 486/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0828 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 487/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 488/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 489/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 490/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 491/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0828 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 492/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0828 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 493/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0828 - val_loss: 0.0461 - val_mse: 0.0080 - val_mae: 0.0461 - val_root_mean_squared_error: 0.0895
# Epoch 494/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0461 - val_mse: 0.0080 - val_mae: 0.0461 - val_root_mean_squared_error: 0.0895
# Epoch 495/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0828 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 496/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0828 - val_loss: 0.0462 - val_mse: 0.0080 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0895
# Epoch 497/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0421 - mse: 0.0069 - mae: 0.0421 - root_mean_squared_error: 0.0828 - val_loss: 0.0461 - val_mse: 0.0080 - val_mae: 0.0461 - val_root_mean_squared_error: 0.0895
# Epoch 498/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0829 - val_loss: 0.0461 - val_mse: 0.0080 - val_mae: 0.0461 - val_root_mean_squared_error: 0.0895
# Epoch 499/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0828 - val_loss: 0.0461 - val_mse: 0.0080 - val_mae: 0.0461 - val_root_mean_squared_error: 0.0895
# Epoch 500/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0422 - mse: 0.0069 - mae: 0.0422 - root_mean_squared_error: 0.0828 - val_loss: 0.0461 - val_mse: 0.0080 - val_mae: 0.0461 - val_root_mean_squared_error: 0.0895

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mae'],label='train mae')
pyplot.plot(history.history['val_mae'],label='val mae')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mse'],label='train mse')
pyplot.plot(history.history['val_mse'],label='val mse')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['root_mean_squared_error'],label='train rmse')
pyplot.plot(history.history['val_root_mean_squared_error'],label='val rmse')
pyplot.legend()
pyplot.show()
# Out:
# The testing MAE loss is: 0.043919377
# The testing MSE loss is: 0.007342929
# The testing RMSE loss is: 0.0856909

# %%
pyplot.plot(test_y[:,4],color='red', label='True Values')
pyplot.plot(out[:,4],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()

# %%
dataset_test=pd.read_excel('F:\MS thesis data/Hopper Crossing.xlsx')
dataset_test=dataset_test.drop(['Date/Time','Flowd'],axis=1)
dataset_test.dropna(inplace=True)

# %%
shape=np.shape(dataset_test)
print(shape)
pyplot.plot(dataset_test)
# Out:
# (26285, 3)
# [<matplotlib.lines.Line2D at 0x182a946f048>,
#  <matplotlib.lines.Line2D at 0x182a94729c8>,
#  <matplotlib.lines.Line2D at 0x182a9472788>]

# %%
dataset_test
# Out:
#        Cumulative rainfall   Flow  Level
# 0                      0.0  0.093    1.50
# 1                      0.0  0.093    1.50
# 2                      0.0  0.093    1.50
# 3                      0.0  0.093    1.50
# 4                      0.0  0.093    1.50
# ...                    ...    ...     ...
# 26280                  0.2  0.080    1.49
# 26281                  0.2  0.080    1.49
# 26282                  0.2  0.080    1.49
# 26283                  0.2  0.080    1.49
# 26284                  0.2  0.080    1.49
#
# [26285 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset_test)))
# Out:
# The std of original data is Cumulative rainfall    2.451640
# Flow                   0.520832
# Level                  0.083204
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset_test=dataset_test.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset_test.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset_test[:,0]== maxi[0])
    ind2=np.argwhere(dataset_test[:,1]== maxi[1])
    ind3=np.argwhere(dataset_test[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset_test.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset_test[:,0]== mini[0])
    ind2=np.argwhere(dataset_test[:,1]== mini[1])
    ind3=np.argwhere(dataset_test[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset_test)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset_test = min_max_scaler.fit_transform(dataset_test)
# Out:
# The std of cleaned data is 1.5154548293543502

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=5
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values

#one hour
#test_X, test_y = values[:, :-out_hour], values[:,-1]


test_X, test_y = values[:, :-out_hour], values[:, -out_hour: ]


test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6341, 33)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var2(t-2)  var3(t-2)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.524545   0.776699
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.524545   0.776699
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.549980   0.791262
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.603309   0.820388
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.650485   0.844660
#
#     var1(t-1)  var2(t-1)  var3(t-1)   var3(t)  var3(t+1)  var3(t+2)  \
# 6    0.215385   0.524545   0.776699  0.791262   0.820388   0.844660
# 7    0.123077   0.549980   0.791262  0.820388   0.844660   0.873786
# 8    0.092308   0.603309   0.820388  0.844660   0.873786   0.898058
# 9    0.092308   0.650485   0.844660  0.873786   0.898058   0.932039
# 10   0.092308   0.709285   0.873786  0.898058   0.932039   0.966019
#
#     var3(t+3)  var3(t+4)
# 6    0.873786   0.898058
# 7    0.898058   0.932039
# 8    0.932039   0.966019
# 9    0.966019   1.000000
# 10   1.000000   0.941748
#
# [5 rows x 23 columns]

# %%
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
# Out:
# The testing MAE loss is: 0.043516055
# The testing MSE loss is: 0.007274035
# The testing RMSE loss is: 0.08528797

# %%
pyplot.plot(test_y[:,4],color='red', label='True Values')
pyplot.plot(out[:,4],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()
