# %%
import pandas as pd
from pandas import concat
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from sklearn import preprocessing
from tensorflow.keras import backend as K
#from sklearn.preprocessing import MinMaxScaler
#from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input, Dense, LSTM,GRU,SimpleRNN, Activation
from matplotlib import pyplot
#from sklearn.model_selection import train_test_split

# %%
"# convert series to supervised learning\n" 
#windowing of data
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1),
    for i in range(n_in, 0, -1): #startes from n_in and decreses to 0 by decreasing each time -1
     cols.append(df.shift(i))
     names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
     cols.append(df.shift(-i))
     if i == 0:
       names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
     else:
       names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together\n",
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values\n",
    if dropnan:
      agg.dropna(inplace=True)
    return agg

# %%
#def root_mean_squared_error(y_true, y_pred):
 #       return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
dataset1=pd.read_excel('F:\MS thesis data/Brooklyn.xlsx')
dataset1=dataset1.drop(['Date/Time','Flowd'],axis=1)
dataset1.dropna(inplace=True)

# %%
shape=np.shape(dataset1)
print(shape)
pyplot.plot(dataset1)
# Out:
# (26302, 3)
# [<matplotlib.lines.Line2D at 0x1f40233c388>,
#  <matplotlib.lines.Line2D at 0x1f4018a0bc8>,
#  <matplotlib.lines.Line2D at 0x1f4023343c8>]

# %%
dataset1
# Out:
#        Cumulative rainfall    Flow  Level
# 0                       0.0  0.172   0.352
# 1                       0.0  0.180   0.356
# 2                       0.0  0.180   0.356
# 3                       0.0  0.189   0.360
# 4                       0.0  0.189   0.360
# ...                     ...    ...     ...
# 26297                   0.0  0.025   0.232
# 26298                   0.0  0.023   0.228
# 26299                   0.0  0.023   0.228
# 26300                   0.0  0.023   0.228
# 26301                   0.0  0.023   0.228
#
# [26302 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset1)))
# Out:
# The std of original data is Cumulative rainfall     2.872616
# Flow                    1.306642
# Level                   0.147238
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset=dataset1.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset[:,0]== maxi[0])
    ind2=np.argwhere(dataset[:,1]== maxi[1])
    ind3=np.argwhere(dataset[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset[:,0]== mini[0])
    ind2=np.argwhere(dataset[:,1]== mini[1])
    ind3=np.argwhere(dataset[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset = min_max_scaler.fit_transform(dataset)
# Out:
# The std of cleaned data is 1.626639593959813

# %%
pyplot.plot(dataset)
# Out:
# [<matplotlib.lines.Line2D at 0x1f401bba588>,
#  <matplotlib.lines.Line2D at 0x1f401b6d588>,
#  <matplotlib.lines.Line2D at 0x1f401b6d748>]

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=1
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values
train_size  = int(len(dataset) * 0.50)
val_size=int(len(dataset) * 0.75)
train_X, train_y = values[0:train_size, :-out_hour], values[0:train_size,-out_hour: ]
val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-out_hour: ]
test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-out_hour:]
#for last hour
#train_X, train_y = values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]  #for only last hour
#val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]
#test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-1]
print(train_X, train_y)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6345, 21)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  var2(t-3)  var3(t-3)  \
# 6    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 7    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 8    0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
# 9    0.215385   0.524545   0.776699   0.123077   0.549980   0.791262
# 10   0.123077   0.549980   0.791262   0.092308   0.603309   0.820388
#
#     var1(t-2)  var2(t-2)  var3(t-2)  var1(t-1)  var2(t-1)  var3(t-1)   var3(t)
# 6    0.230769   0.524545   0.776699   0.215385   0.524545   0.776699  0.791262
# 7    0.215385   0.524545   0.776699   0.123077   0.549980   0.791262  0.820388
# 8    0.123077   0.549980   0.791262   0.092308   0.603309   0.820388  0.844660
# 9    0.092308   0.603309   0.820388   0.092308   0.650485   0.844660  0.873786
# 10   0.092308   0.650485   0.844660   0.092308   0.709285   0.873786  0.898058
# [[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]
#  [0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]
#  [0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]
#  ...
#  [0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]
#  [0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]
#  [0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]] [[0.79126215]
#  [0.8203884 ]
#  [0.8446602 ]
#  ...
#  [0.23786408]
#  [0.24271844]
#  [0.24757281]]

# %%
print(train_X, train_y)
# Out:
# [[[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]]
#
#  [[0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]]
#
#  [[0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]]
#
#  ...
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]]] [[0.79126215]
#  [0.8203884 ]
#  [0.8446602 ]
#  ...
#  [0.23786408]
#  [0.24271844]
#  [0.24757281]]

# %%
print(train_X.shape, train_y.shape, val_X.shape, val_y.shape)
# Out:
# (3175, 1, 18) (3175, 1) (1588, 1, 18) (1588, 1)

# %%
randomState = 46
np.random.seed(randomState)
#tensorflow.random.set_random_seed(randomState)
tensorflow.random.set_seed(randomState)
model = Sequential()
model.add(GRU(15,input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dense(22))
#model.add(Activation('relu'))    
model.add(Dense(out_hour,activation = "sigmoid"))
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.001)
#    opt=tensorflow.keras.optimizers.Adam(learning_rate=0.00075)
model.compile(loss='mae', optimizer=opt,metrics=['mse','mae',tensorflow.keras.metrics.RootMeanSquaredError()])
history = model.fit(train_X, train_y,validation_data=(val_X, val_y), epochs=500, batch_size=100,verbose=1,shuffle=False)
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)
# Out:
# Train on 3175 samples, validate on 1588 samples
# Epoch 1/500
# 3175/3175 [==============================] - 2s 581us/sample - loss: 0.2414 - mse: 0.0712 - mae: 0.2414 - root_mean_squared_error: 0.2668 - val_loss: 0.2465 - val_mse: 0.0761 - val_mae: 0.2465 - val_root_mean_squared_error: 0.2758
# Epoch 2/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.2110 - mse: 0.0571 - mae: 0.2110 - root_mean_squared_error: 0.2390 - val_loss: 0.2189 - val_mse: 0.0621 - val_mae: 0.2189 - val_root_mean_squared_error: 0.2492
# Epoch 3/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.1874 - mse: 0.0484 - mae: 0.1874 - root_mean_squared_error: 0.2200 - val_loss: 0.1961 - val_mse: 0.0521 - val_mae: 0.1961 - val_root_mean_squared_error: 0.2282
# Epoch 4/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1690 - mse: 0.0423 - mae: 0.1690 - root_mean_squared_error: 0.2057 - val_loss: 0.1777 - val_mse: 0.0444 - val_mae: 0.1777 - val_root_mean_squared_error: 0.2106
# Epoch 5/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.1537 - mse: 0.0368 - mae: 0.1537 - root_mean_squared_error: 0.1919 - val_loss: 0.1616 - val_mse: 0.0375 - val_mae: 0.1616 - val_root_mean_squared_error: 0.1935
# Epoch 6/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1384 - mse: 0.0306 - mae: 0.1384 - root_mean_squared_error: 0.1750 - val_loss: 0.1448 - val_mse: 0.0304 - val_mae: 0.1448 - val_root_mean_squared_error: 0.1743
# Epoch 7/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.1215 - mse: 0.0236 - mae: 0.1215 - root_mean_squared_error: 0.1537 - val_loss: 0.1266 - val_mse: 0.0235 - val_mae: 0.1266 - val_root_mean_squared_error: 0.1532
# Epoch 8/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.1037 - mse: 0.0170 - mae: 0.1037 - root_mean_squared_error: 0.1304 - val_loss: 0.1082 - val_mse: 0.0178 - val_mae: 0.1082 - val_root_mean_squared_error: 0.1334
# Epoch 9/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0880 - mse: 0.0125 - mae: 0.0880 - root_mean_squared_error: 0.1118 - val_loss: 0.0947 - val_mse: 0.0140 - val_mae: 0.0947 - val_root_mean_squared_error: 0.1181
# Epoch 10/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0761 - mse: 0.0099 - mae: 0.0761 - root_mean_squared_error: 0.0997 - val_loss: 0.0851 - val_mse: 0.0117 - val_mae: 0.0851 - val_root_mean_squared_error: 0.1082
# Epoch 11/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0678 - mse: 0.0087 - mae: 0.0678 - root_mean_squared_error: 0.0932 - val_loss: 0.0781 - val_mse: 0.0104 - val_mae: 0.0781 - val_root_mean_squared_error: 0.1020
# Epoch 12/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0616 - mse: 0.0081 - mae: 0.0616 - root_mean_squared_error: 0.0898 - val_loss: 0.0726 - val_mse: 0.0095 - val_mae: 0.0726 - val_root_mean_squared_error: 0.0977
# Epoch 13/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0572 - mse: 0.0076 - mae: 0.0572 - root_mean_squared_error: 0.0873 - val_loss: 0.0683 - val_mse: 0.0088 - val_mae: 0.0683 - val_root_mean_squared_error: 0.0939
# Epoch 14/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0544 - mse: 0.0072 - mae: 0.0544 - root_mean_squared_error: 0.0848 - val_loss: 0.0652 - val_mse: 0.0083 - val_mae: 0.0652 - val_root_mean_squared_error: 0.0914
# Epoch 15/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0522 - mse: 0.0068 - mae: 0.0522 - root_mean_squared_error: 0.0825 - val_loss: 0.0627 - val_mse: 0.0079 - val_mae: 0.0627 - val_root_mean_squared_error: 0.0890
# Epoch 16/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0503 - mse: 0.0064 - mae: 0.0503 - root_mean_squared_error: 0.0803 - val_loss: 0.0605 - val_mse: 0.0075 - val_mae: 0.0605 - val_root_mean_squared_error: 0.0867
# Epoch 17/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0486 - mse: 0.0061 - mae: 0.0486 - root_mean_squared_error: 0.0780 - val_loss: 0.0584 - val_mse: 0.0072 - val_mae: 0.0584 - val_root_mean_squared_error: 0.0847
# Epoch 18/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0470 - mse: 0.0057 - mae: 0.0470 - root_mean_squared_error: 0.0758 - val_loss: 0.0565 - val_mse: 0.0068 - val_mae: 0.0565 - val_root_mean_squared_error: 0.0827
# Epoch 19/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0454 - mse: 0.0054 - mae: 0.0454 - root_mean_squared_error: 0.0736 - val_loss: 0.0546 - val_mse: 0.0065 - val_mae: 0.0546 - val_root_mean_squared_error: 0.0809
# Epoch 20/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0439 - mse: 0.0051 - mae: 0.0439 - root_mean_squared_error: 0.0715 - val_loss: 0.0529 - val_mse: 0.0062 - val_mae: 0.0529 - val_root_mean_squared_error: 0.0790
# Epoch 21/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0762 - mse: 0.0121 - mae: 0.0762 - root_mean_squared_error: 0.109 - 0s 26us/sample - loss: 0.0425 - mse: 0.0048 - mae: 0.0425 - root_mean_squared_error: 0.0694 - val_loss: 0.0513 - val_mse: 0.0060 - val_mae: 0.0513 - val_root_mean_squared_error: 0.0774
# Epoch 22/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0412 - mse: 0.0045 - mae: 0.0412 - root_mean_squared_error: 0.0674 - val_loss: 0.0501 - val_mse: 0.0058 - val_mae: 0.0501 - val_root_mean_squared_error: 0.0764
# Epoch 23/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0399 - mse: 0.0043 - mae: 0.0399 - root_mean_squared_error: 0.0658 - val_loss: 0.0489 - val_mse: 0.0057 - val_mae: 0.0489 - val_root_mean_squared_error: 0.0752
# Epoch 24/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0388 - mse: 0.0041 - mae: 0.0388 - root_mean_squared_error: 0.0642 - val_loss: 0.0478 - val_mse: 0.0055 - val_mae: 0.0478 - val_root_mean_squared_error: 0.0741
# Epoch 25/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0379 - mse: 0.0039 - mae: 0.0379 - root_mean_squared_error: 0.0628 - val_loss: 0.0471 - val_mse: 0.0054 - val_mae: 0.0471 - val_root_mean_squared_error: 0.0735
# Epoch 26/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0371 - mse: 0.0038 - mae: 0.0371 - root_mean_squared_error: 0.0617 - val_loss: 0.0463 - val_mse: 0.0053 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0727
# Epoch 27/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0365 - mse: 0.0037 - mae: 0.0365 - root_mean_squared_error: 0.0605 - val_loss: 0.0456 - val_mse: 0.0052 - val_mae: 0.0456 - val_root_mean_squared_error: 0.0721
# Epoch 28/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0359 - mse: 0.0036 - mae: 0.0359 - root_mean_squared_error: 0.0597 - val_loss: 0.0452 - val_mse: 0.0051 - val_mae: 0.0452 - val_root_mean_squared_error: 0.0716
# Epoch 29/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0354 - mse: 0.0035 - mae: 0.0354 - root_mean_squared_error: 0.0590 - val_loss: 0.0446 - val_mse: 0.0050 - val_mae: 0.0446 - val_root_mean_squared_error: 0.0711
# Epoch 30/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0349 - mse: 0.0034 - mae: 0.0349 - root_mean_squared_error: 0.0583 - val_loss: 0.0440 - val_mse: 0.0050 - val_mae: 0.0440 - val_root_mean_squared_error: 0.0704
# Epoch 31/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0345 - mse: 0.0033 - mae: 0.0345 - root_mean_squared_error: 0.0577 - val_loss: 0.0435 - val_mse: 0.0049 - val_mae: 0.0435 - val_root_mean_squared_error: 0.0698
# Epoch 32/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0340 - mse: 0.0033 - mae: 0.0340 - root_mean_squared_error: 0.0571 - val_loss: 0.0430 - val_mse: 0.0048 - val_mae: 0.0430 - val_root_mean_squared_error: 0.0692
# Epoch 33/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0337 - mse: 0.0032 - mae: 0.0337 - root_mean_squared_error: 0.0566 - val_loss: 0.0426 - val_mse: 0.0047 - val_mae: 0.0426 - val_root_mean_squared_error: 0.0688
# Epoch 34/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0334 - mse: 0.0032 - mae: 0.0334 - root_mean_squared_error: 0.0562 - val_loss: 0.0422 - val_mse: 0.0047 - val_mae: 0.0422 - val_root_mean_squared_error: 0.0685
# Epoch 35/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0331 - mse: 0.0031 - mae: 0.0331 - root_mean_squared_error: 0.0557 - val_loss: 0.0419 - val_mse: 0.0046 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0681
# Epoch 36/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0328 - mse: 0.0031 - mae: 0.0328 - root_mean_squared_error: 0.0554 - val_loss: 0.0416 - val_mse: 0.0046 - val_mae: 0.0416 - val_root_mean_squared_error: 0.0678
# Epoch 37/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0325 - mse: 0.0030 - mae: 0.0325 - root_mean_squared_error: 0.0550 - val_loss: 0.0413 - val_mse: 0.0046 - val_mae: 0.0413 - val_root_mean_squared_error: 0.0676
# Epoch 38/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0323 - mse: 0.0030 - mae: 0.0323 - root_mean_squared_error: 0.0547 - val_loss: 0.0410 - val_mse: 0.0045 - val_mae: 0.0410 - val_root_mean_squared_error: 0.0673
# Epoch 39/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0319 - mse: 0.0030 - mae: 0.0319 - root_mean_squared_error: 0.0544 - val_loss: 0.0406 - val_mse: 0.0045 - val_mae: 0.0406 - val_root_mean_squared_error: 0.0668
# Epoch 40/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0317 - mse: 0.0029 - mae: 0.0317 - root_mean_squared_error: 0.0541 - val_loss: 0.0404 - val_mse: 0.0044 - val_mae: 0.0404 - val_root_mean_squared_error: 0.0666
# Epoch 41/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0314 - mse: 0.0029 - mae: 0.0314 - root_mean_squared_error: 0.0538 - val_loss: 0.0399 - val_mse: 0.0044 - val_mae: 0.0399 - val_root_mean_squared_error: 0.0661
# Epoch 42/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0311 - mse: 0.0029 - mae: 0.0311 - root_mean_squared_error: 0.0535 - val_loss: 0.0395 - val_mse: 0.0043 - val_mae: 0.0395 - val_root_mean_squared_error: 0.0657
# Epoch 43/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0308 - mse: 0.0028 - mae: 0.0308 - root_mean_squared_error: 0.0533 - val_loss: 0.0392 - val_mse: 0.0043 - val_mae: 0.0392 - val_root_mean_squared_error: 0.0653
# Epoch 44/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0305 - mse: 0.0028 - mae: 0.0305 - root_mean_squared_error: 0.0529 - val_loss: 0.0388 - val_mse: 0.0042 - val_mae: 0.0388 - val_root_mean_squared_error: 0.0649
# Epoch 45/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0301 - mse: 0.0028 - mae: 0.0301 - root_mean_squared_error: 0.0526 - val_loss: 0.0385 - val_mse: 0.0042 - val_mae: 0.0385 - val_root_mean_squared_error: 0.0647
# Epoch 46/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0299 - mse: 0.0027 - mae: 0.0299 - root_mean_squared_error: 0.0524 - val_loss: 0.0382 - val_mse: 0.0041 - val_mae: 0.0382 - val_root_mean_squared_error: 0.0643
# Epoch 47/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0296 - mse: 0.0027 - mae: 0.0296 - root_mean_squared_error: 0.0522 - val_loss: 0.0380 - val_mse: 0.0041 - val_mae: 0.0380 - val_root_mean_squared_error: 0.0641
# Epoch 48/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0293 - mse: 0.0027 - mae: 0.0293 - root_mean_squared_error: 0.0520 - val_loss: 0.0377 - val_mse: 0.0041 - val_mae: 0.0377 - val_root_mean_squared_error: 0.0638
# Epoch 49/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0291 - mse: 0.0027 - mae: 0.0291 - root_mean_squared_error: 0.0518 - val_loss: 0.0375 - val_mse: 0.0040 - val_mae: 0.0375 - val_root_mean_squared_error: 0.0636
# Epoch 50/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0289 - mse: 0.0027 - mae: 0.0289 - root_mean_squared_error: 0.0516 - val_loss: 0.0372 - val_mse: 0.0040 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0633
# Epoch 51/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0286 - mse: 0.0026 - mae: 0.0286 - root_mean_squared_error: 0.0514 - val_loss: 0.0369 - val_mse: 0.0040 - val_mae: 0.0369 - val_root_mean_squared_error: 0.0630
# Epoch 52/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0284 - mse: 0.0026 - mae: 0.0284 - root_mean_squared_error: 0.0512 - val_loss: 0.0366 - val_mse: 0.0039 - val_mae: 0.0366 - val_root_mean_squared_error: 0.0628
# Epoch 53/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0281 - mse: 0.0026 - mae: 0.0281 - root_mean_squared_error: 0.0510 - val_loss: 0.0364 - val_mse: 0.0039 - val_mae: 0.0364 - val_root_mean_squared_error: 0.0625
# Epoch 54/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0279 - mse: 0.0026 - mae: 0.0279 - root_mean_squared_error: 0.0508 - val_loss: 0.0361 - val_mse: 0.0039 - val_mae: 0.0361 - val_root_mean_squared_error: 0.0622
# Epoch 55/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0276 - mse: 0.0026 - mae: 0.0276 - root_mean_squared_error: 0.0506 - val_loss: 0.0358 - val_mse: 0.0039 - val_mae: 0.0358 - val_root_mean_squared_error: 0.0621
# Epoch 56/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0275 - mse: 0.0025 - mae: 0.0275 - root_mean_squared_error: 0.0505 - val_loss: 0.0356 - val_mse: 0.0038 - val_mae: 0.0356 - val_root_mean_squared_error: 0.0619
# Epoch 57/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0273 - mse: 0.0025 - mae: 0.0273 - root_mean_squared_error: 0.0503 - val_loss: 0.0353 - val_mse: 0.0038 - val_mae: 0.0353 - val_root_mean_squared_error: 0.0617
# Epoch 58/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0271 - mse: 0.0025 - mae: 0.0271 - root_mean_squared_error: 0.0502 - val_loss: 0.0351 - val_mse: 0.0038 - val_mae: 0.0351 - val_root_mean_squared_error: 0.0615
# Epoch 59/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0269 - mse: 0.0025 - mae: 0.0269 - root_mean_squared_error: 0.0500 - val_loss: 0.0348 - val_mse: 0.0038 - val_mae: 0.0348 - val_root_mean_squared_error: 0.0613
# Epoch 60/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0267 - mse: 0.0025 - mae: 0.0267 - root_mean_squared_error: 0.0499 - val_loss: 0.0346 - val_mse: 0.0038 - val_mae: 0.0346 - val_root_mean_squared_error: 0.0613
# Epoch 61/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0265 - mse: 0.0025 - mae: 0.0265 - root_mean_squared_error: 0.0498 - val_loss: 0.0343 - val_mse: 0.0037 - val_mae: 0.0343 - val_root_mean_squared_error: 0.0611
# Epoch 62/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0263 - mse: 0.0025 - mae: 0.0263 - root_mean_squared_error: 0.0497 - val_loss: 0.0341 - val_mse: 0.0037 - val_mae: 0.0341 - val_root_mean_squared_error: 0.0609
# Epoch 63/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0262 - mse: 0.0025 - mae: 0.0262 - root_mean_squared_error: 0.0495 - val_loss: 0.0339 - val_mse: 0.0037 - val_mae: 0.0339 - val_root_mean_squared_error: 0.0608
# Epoch 64/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0260 - mse: 0.0024 - mae: 0.0260 - root_mean_squared_error: 0.0494 - val_loss: 0.0336 - val_mse: 0.0037 - val_mae: 0.0336 - val_root_mean_squared_error: 0.0606
# Epoch 65/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0258 - mse: 0.0024 - mae: 0.0258 - root_mean_squared_error: 0.0493 - val_loss: 0.0334 - val_mse: 0.0037 - val_mae: 0.0334 - val_root_mean_squared_error: 0.0605
# Epoch 66/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0257 - mse: 0.0024 - mae: 0.0257 - root_mean_squared_error: 0.0492 - val_loss: 0.0332 - val_mse: 0.0037 - val_mae: 0.0332 - val_root_mean_squared_error: 0.0604
# Epoch 67/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0255 - mse: 0.0024 - mae: 0.0255 - root_mean_squared_error: 0.0491 - val_loss: 0.0330 - val_mse: 0.0036 - val_mae: 0.0330 - val_root_mean_squared_error: 0.0603
# Epoch 68/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0254 - mse: 0.0024 - mae: 0.0254 - root_mean_squared_error: 0.0490 - val_loss: 0.0328 - val_mse: 0.0036 - val_mae: 0.0328 - val_root_mean_squared_error: 0.0602
# Epoch 69/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0252 - mse: 0.0024 - mae: 0.0252 - root_mean_squared_error: 0.0489 - val_loss: 0.0326 - val_mse: 0.0036 - val_mae: 0.0326 - val_root_mean_squared_error: 0.0602
# Epoch 70/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0251 - mse: 0.0024 - mae: 0.0251 - root_mean_squared_error: 0.0489 - val_loss: 0.0324 - val_mse: 0.0036 - val_mae: 0.0324 - val_root_mean_squared_error: 0.0601
# Epoch 71/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0249 - mse: 0.0024 - mae: 0.0249 - root_mean_squared_error: 0.0488 - val_loss: 0.0322 - val_mse: 0.0036 - val_mae: 0.0322 - val_root_mean_squared_error: 0.0600
# Epoch 72/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0248 - mse: 0.0024 - mae: 0.0248 - root_mean_squared_error: 0.0488 - val_loss: 0.0321 - val_mse: 0.0036 - val_mae: 0.0321 - val_root_mean_squared_error: 0.0600
# Epoch 73/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0247 - mse: 0.0024 - mae: 0.0247 - root_mean_squared_error: 0.0487 - val_loss: 0.0319 - val_mse: 0.0036 - val_mae: 0.0319 - val_root_mean_squared_error: 0.0599
# Epoch 74/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0246 - mse: 0.0024 - mae: 0.0246 - root_mean_squared_error: 0.0487 - val_loss: 0.0317 - val_mse: 0.0036 - val_mae: 0.0317 - val_root_mean_squared_error: 0.0598
# Epoch 75/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0244 - mse: 0.0024 - mae: 0.0244 - root_mean_squared_error: 0.0486 - val_loss: 0.0315 - val_mse: 0.0036 - val_mae: 0.0315 - val_root_mean_squared_error: 0.0597
# Epoch 76/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0243 - mse: 0.0024 - mae: 0.0243 - root_mean_squared_error: 0.0486 - val_loss: 0.0313 - val_mse: 0.0035 - val_mae: 0.0313 - val_root_mean_squared_error: 0.0596
# Epoch 77/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0242 - mse: 0.0024 - mae: 0.0242 - root_mean_squared_error: 0.0485 - val_loss: 0.0312 - val_mse: 0.0036 - val_mae: 0.0312 - val_root_mean_squared_error: 0.0597
# Epoch 78/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0241 - mse: 0.0024 - mae: 0.0241 - root_mean_squared_error: 0.0485 - val_loss: 0.0310 - val_mse: 0.0036 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0598
# Epoch 79/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0240 - mse: 0.0024 - mae: 0.0240 - root_mean_squared_error: 0.0485 - val_loss: 0.0309 - val_mse: 0.0036 - val_mae: 0.0309 - val_root_mean_squared_error: 0.0597
# Epoch 80/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0239 - mse: 0.0024 - mae: 0.0239 - root_mean_squared_error: 0.0485 - val_loss: 0.0308 - val_mse: 0.0036 - val_mae: 0.0308 - val_root_mean_squared_error: 0.0598
# Epoch 81/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0239 - mse: 0.0023 - mae: 0.0239 - root_mean_squared_error: 0.0485 - val_loss: 0.0306 - val_mse: 0.0036 - val_mae: 0.0306 - val_root_mean_squared_error: 0.0597
# Epoch 82/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0238 - mse: 0.0023 - mae: 0.0238 - root_mean_squared_error: 0.0485 - val_loss: 0.0305 - val_mse: 0.0036 - val_mae: 0.0305 - val_root_mean_squared_error: 0.0597
# Epoch 83/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0237 - mse: 0.0023 - mae: 0.0237 - root_mean_squared_error: 0.0485 - val_loss: 0.0304 - val_mse: 0.0036 - val_mae: 0.0304 - val_root_mean_squared_error: 0.0597
# Epoch 84/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0237 - mse: 0.0024 - mae: 0.0237 - root_mean_squared_error: 0.0485 - val_loss: 0.0303 - val_mse: 0.0036 - val_mae: 0.0303 - val_root_mean_squared_error: 0.0598
# Epoch 85/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0236 - mse: 0.0024 - mae: 0.0236 - root_mean_squared_error: 0.0485 - val_loss: 0.0302 - val_mse: 0.0036 - val_mae: 0.0302 - val_root_mean_squared_error: 0.0598
# Epoch 86/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0235 - mse: 0.0024 - mae: 0.0235 - root_mean_squared_error: 0.0485 - val_loss: 0.0301 - val_mse: 0.0036 - val_mae: 0.0301 - val_root_mean_squared_error: 0.0598
# Epoch 87/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0235 - mse: 0.0024 - mae: 0.0235 - root_mean_squared_error: 0.0485 - val_loss: 0.0299 - val_mse: 0.0035 - val_mae: 0.0299 - val_root_mean_squared_error: 0.0595
# Epoch 88/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0233 - mse: 0.0023 - mae: 0.0233 - root_mean_squared_error: 0.0485 - val_loss: 0.0298 - val_mse: 0.0036 - val_mae: 0.0298 - val_root_mean_squared_error: 0.0596
# Epoch 89/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0234 - mse: 0.0024 - mae: 0.0234 - root_mean_squared_error: 0.0485 - val_loss: 0.0298 - val_mse: 0.0036 - val_mae: 0.0298 - val_root_mean_squared_error: 0.0597
# Epoch 90/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0232 - mse: 0.0024 - mae: 0.0232 - root_mean_squared_error: 0.0485 - val_loss: 0.0295 - val_mse: 0.0035 - val_mae: 0.0295 - val_root_mean_squared_error: 0.0594
# Epoch 91/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0232 - mse: 0.0023 - mae: 0.0232 - root_mean_squared_error: 0.0485 - val_loss: 0.0295 - val_mse: 0.0035 - val_mae: 0.0295 - val_root_mean_squared_error: 0.0595
# Epoch 92/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0232 - mse: 0.0023 - mae: 0.0232 - root_mean_squared_error: 0.0485 - val_loss: 0.0294 - val_mse: 0.0035 - val_mae: 0.0294 - val_root_mean_squared_error: 0.0595
# Epoch 93/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0230 - mse: 0.0024 - mae: 0.0230 - root_mean_squared_error: 0.0485 - val_loss: 0.0292 - val_mse: 0.0035 - val_mae: 0.0292 - val_root_mean_squared_error: 0.0593
# Epoch 94/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0230 - mse: 0.0023 - mae: 0.0230 - root_mean_squared_error: 0.0485 - val_loss: 0.0292 - val_mse: 0.0035 - val_mae: 0.0292 - val_root_mean_squared_error: 0.0593
# Epoch 95/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0229 - mse: 0.0024 - mae: 0.0229 - root_mean_squared_error: 0.0485 - val_loss: 0.0291 - val_mse: 0.0035 - val_mae: 0.0291 - val_root_mean_squared_error: 0.0593
# Epoch 96/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0228 - mse: 0.0023 - mae: 0.0228 - root_mean_squared_error: 0.0485 - val_loss: 0.0289 - val_mse: 0.0035 - val_mae: 0.0289 - val_root_mean_squared_error: 0.0592
# Epoch 97/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0228 - mse: 0.0023 - mae: 0.0228 - root_mean_squared_error: 0.0485 - val_loss: 0.0289 - val_mse: 0.0035 - val_mae: 0.0289 - val_root_mean_squared_error: 0.0592
# Epoch 98/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0227 - mse: 0.0023 - mae: 0.0227 - root_mean_squared_error: 0.0484 - val_loss: 0.0287 - val_mse: 0.0035 - val_mae: 0.0287 - val_root_mean_squared_error: 0.0591
# Epoch 99/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0226 - mse: 0.0023 - mae: 0.0226 - root_mean_squared_error: 0.0484 - val_loss: 0.0286 - val_mse: 0.0035 - val_mae: 0.0286 - val_root_mean_squared_error: 0.0589
# Epoch 100/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0225 - mse: 0.0023 - mae: 0.0225 - root_mean_squared_error: 0.0484 - val_loss: 0.0285 - val_mse: 0.0035 - val_mae: 0.0285 - val_root_mean_squared_error: 0.0589
# Epoch 101/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0225 - mse: 0.0023 - mae: 0.0225 - root_mean_squared_error: 0.0484 - val_loss: 0.0284 - val_mse: 0.0035 - val_mae: 0.0284 - val_root_mean_squared_error: 0.0589
# Epoch 102/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0224 - mse: 0.0023 - mae: 0.0224 - root_mean_squared_error: 0.0484 - val_loss: 0.0284 - val_mse: 0.0035 - val_mae: 0.0284 - val_root_mean_squared_error: 0.0590
# Epoch 103/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0224 - mse: 0.0023 - mae: 0.0224 - root_mean_squared_error: 0.0484 - val_loss: 0.0283 - val_mse: 0.0035 - val_mae: 0.0283 - val_root_mean_squared_error: 0.0589
# Epoch 104/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0223 - mse: 0.0023 - mae: 0.0223 - root_mean_squared_error: 0.0484 - val_loss: 0.0282 - val_mse: 0.0034 - val_mae: 0.0282 - val_root_mean_squared_error: 0.0587
# Epoch 105/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0223 - mse: 0.0023 - mae: 0.0223 - root_mean_squared_error: 0.0483 - val_loss: 0.0280 - val_mse: 0.0034 - val_mae: 0.0280 - val_root_mean_squared_error: 0.0586
# Epoch 106/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0222 - mse: 0.0023 - mae: 0.0222 - root_mean_squared_error: 0.0483 - val_loss: 0.0279 - val_mse: 0.0034 - val_mae: 0.0279 - val_root_mean_squared_error: 0.0585
# Epoch 107/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0222 - mse: 0.0023 - mae: 0.0222 - root_mean_squared_error: 0.0483 - val_loss: 0.0278 - val_mse: 0.0034 - val_mae: 0.0278 - val_root_mean_squared_error: 0.0583
# Epoch 108/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0221 - mse: 0.0023 - mae: 0.0221 - root_mean_squared_error: 0.0483 - val_loss: 0.0277 - val_mse: 0.0034 - val_mae: 0.0277 - val_root_mean_squared_error: 0.0583
# Epoch 109/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0221 - mse: 0.0023 - mae: 0.0221 - root_mean_squared_error: 0.0483 - val_loss: 0.0277 - val_mse: 0.0034 - val_mae: 0.0277 - val_root_mean_squared_error: 0.0583
# Epoch 110/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0221 - mse: 0.0023 - mae: 0.0221 - root_mean_squared_error: 0.0483 - val_loss: 0.0276 - val_mse: 0.0034 - val_mae: 0.0276 - val_root_mean_squared_error: 0.0582
# Epoch 111/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0220 - mse: 0.0023 - mae: 0.0220 - root_mean_squared_error: 0.0482 - val_loss: 0.0276 - val_mse: 0.0034 - val_mae: 0.0276 - val_root_mean_squared_error: 0.0582
# Epoch 112/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0220 - mse: 0.0023 - mae: 0.0220 - root_mean_squared_error: 0.0482 - val_loss: 0.0275 - val_mse: 0.0034 - val_mae: 0.0275 - val_root_mean_squared_error: 0.0580
# Epoch 113/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0220 - mse: 0.0023 - mae: 0.0220 - root_mean_squared_error: 0.0482 - val_loss: 0.0274 - val_mse: 0.0034 - val_mae: 0.0274 - val_root_mean_squared_error: 0.0580
# Epoch 114/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0219 - mse: 0.0023 - mae: 0.0219 - root_mean_squared_error: 0.0482 - val_loss: 0.0274 - val_mse: 0.0034 - val_mae: 0.0274 - val_root_mean_squared_error: 0.0580
# Epoch 115/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0219 - mse: 0.0023 - mae: 0.0219 - root_mean_squared_error: 0.0482 - val_loss: 0.0273 - val_mse: 0.0034 - val_mae: 0.0273 - val_root_mean_squared_error: 0.0580
# Epoch 116/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0219 - mse: 0.0023 - mae: 0.0219 - root_mean_squared_error: 0.0482 - val_loss: 0.0272 - val_mse: 0.0034 - val_mae: 0.0272 - val_root_mean_squared_error: 0.0580
# Epoch 117/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0218 - mse: 0.0023 - mae: 0.0218 - root_mean_squared_error: 0.0482 - val_loss: 0.0272 - val_mse: 0.0034 - val_mae: 0.0272 - val_root_mean_squared_error: 0.0580
# Epoch 118/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0218 - mse: 0.0023 - mae: 0.0218 - root_mean_squared_error: 0.0482 - val_loss: 0.0271 - val_mse: 0.0034 - val_mae: 0.0271 - val_root_mean_squared_error: 0.0580
# Epoch 119/500
# 3175/3175 [==============================] - 0s 40us/sample - loss: 0.0218 - mse: 0.0023 - mae: 0.0218 - root_mean_squared_error: 0.0482 - val_loss: 0.0271 - val_mse: 0.0033 - val_mae: 0.0271 - val_root_mean_squared_error: 0.0579
# Epoch 120/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0217 - mse: 0.0023 - mae: 0.0217 - root_mean_squared_error: 0.0481 - val_loss: 0.0270 - val_mse: 0.0034 - val_mae: 0.0270 - val_root_mean_squared_error: 0.0579
# Epoch 121/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0217 - mse: 0.0023 - mae: 0.0217 - root_mean_squared_error: 0.0481 - val_loss: 0.0270 - val_mse: 0.0034 - val_mae: 0.0270 - val_root_mean_squared_error: 0.0579
# Epoch 122/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0217 - mse: 0.0023 - mae: 0.0217 - root_mean_squared_error: 0.0482 - val_loss: 0.0269 - val_mse: 0.0033 - val_mae: 0.0269 - val_root_mean_squared_error: 0.0578
# Epoch 123/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0217 - mse: 0.0023 - mae: 0.0217 - root_mean_squared_error: 0.0481 - val_loss: 0.0269 - val_mse: 0.0033 - val_mae: 0.0269 - val_root_mean_squared_error: 0.0578
# Epoch 124/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0216 - mse: 0.0023 - mae: 0.0216 - root_mean_squared_error: 0.0481 - val_loss: 0.0268 - val_mse: 0.0033 - val_mae: 0.0268 - val_root_mean_squared_error: 0.0577
# Epoch 125/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0216 - mse: 0.0023 - mae: 0.0216 - root_mean_squared_error: 0.0481 - val_loss: 0.0267 - val_mse: 0.0033 - val_mae: 0.0267 - val_root_mean_squared_error: 0.0578
# Epoch 126/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0216 - mse: 0.0023 - mae: 0.0216 - root_mean_squared_error: 0.0481 - val_loss: 0.0267 - val_mse: 0.0033 - val_mae: 0.0267 - val_root_mean_squared_error: 0.0578
# Epoch 127/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0215 - mse: 0.0023 - mae: 0.0215 - root_mean_squared_error: 0.0481 - val_loss: 0.0267 - val_mse: 0.0033 - val_mae: 0.0267 - val_root_mean_squared_error: 0.0576
# Epoch 128/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0215 - mse: 0.0023 - mae: 0.0215 - root_mean_squared_error: 0.0480 - val_loss: 0.0266 - val_mse: 0.0033 - val_mae: 0.0266 - val_root_mean_squared_error: 0.0577
# Epoch 129/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0215 - mse: 0.0023 - mae: 0.0215 - root_mean_squared_error: 0.0480 - val_loss: 0.0265 - val_mse: 0.0033 - val_mae: 0.0265 - val_root_mean_squared_error: 0.0577
# Epoch 130/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0215 - mse: 0.0023 - mae: 0.0215 - root_mean_squared_error: 0.0480 - val_loss: 0.0265 - val_mse: 0.0033 - val_mae: 0.0265 - val_root_mean_squared_error: 0.0577
# Epoch 131/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0215 - mse: 0.0023 - mae: 0.0215 - root_mean_squared_error: 0.0480 - val_loss: 0.0265 - val_mse: 0.0033 - val_mae: 0.0265 - val_root_mean_squared_error: 0.0577
# Epoch 132/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0214 - mse: 0.0023 - mae: 0.0214 - root_mean_squared_error: 0.0480 - val_loss: 0.0264 - val_mse: 0.0033 - val_mae: 0.0264 - val_root_mean_squared_error: 0.0578
# Epoch 133/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0214 - mse: 0.0023 - mae: 0.0214 - root_mean_squared_error: 0.0480 - val_loss: 0.0264 - val_mse: 0.0033 - val_mae: 0.0264 - val_root_mean_squared_error: 0.0576
# Epoch 134/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0214 - mse: 0.0023 - mae: 0.0214 - root_mean_squared_error: 0.0480 - val_loss: 0.0263 - val_mse: 0.0033 - val_mae: 0.0263 - val_root_mean_squared_error: 0.0576
# Epoch 135/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0214 - mse: 0.0023 - mae: 0.0214 - root_mean_squared_error: 0.0480 - val_loss: 0.0263 - val_mse: 0.0033 - val_mae: 0.0263 - val_root_mean_squared_error: 0.0576
# Epoch 136/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0214 - mse: 0.0023 - mae: 0.0214 - root_mean_squared_error: 0.0479 - val_loss: 0.0262 - val_mse: 0.0033 - val_mae: 0.0262 - val_root_mean_squared_error: 0.0576
# Epoch 137/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0213 - mse: 0.0023 - mae: 0.0213 - root_mean_squared_error: 0.0480 - val_loss: 0.0262 - val_mse: 0.0033 - val_mae: 0.0262 - val_root_mean_squared_error: 0.0576
# Epoch 138/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0213 - mse: 0.0023 - mae: 0.0213 - root_mean_squared_error: 0.0480 - val_loss: 0.0262 - val_mse: 0.0033 - val_mae: 0.0262 - val_root_mean_squared_error: 0.0575
# Epoch 139/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0213 - mse: 0.0023 - mae: 0.0213 - root_mean_squared_error: 0.0479 - val_loss: 0.0261 - val_mse: 0.0033 - val_mae: 0.0261 - val_root_mean_squared_error: 0.0575
# Epoch 140/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0213 - mse: 0.0023 - mae: 0.0213 - root_mean_squared_error: 0.0479 - val_loss: 0.0261 - val_mse: 0.0033 - val_mae: 0.0261 - val_root_mean_squared_error: 0.0575
# Epoch 141/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0212 - mse: 0.0023 - mae: 0.0212 - root_mean_squared_error: 0.0479 - val_loss: 0.0260 - val_mse: 0.0033 - val_mae: 0.0260 - val_root_mean_squared_error: 0.0575
# Epoch 142/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0212 - mse: 0.0023 - mae: 0.0212 - root_mean_squared_error: 0.0479 - val_loss: 0.0260 - val_mse: 0.0033 - val_mae: 0.0260 - val_root_mean_squared_error: 0.0575
# Epoch 143/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0212 - mse: 0.0023 - mae: 0.0212 - root_mean_squared_error: 0.0479 - val_loss: 0.0260 - val_mse: 0.0033 - val_mae: 0.0260 - val_root_mean_squared_error: 0.0575
# Epoch 144/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0212 - mse: 0.0023 - mae: 0.0212 - root_mean_squared_error: 0.0479 - val_loss: 0.0259 - val_mse: 0.0033 - val_mae: 0.0259 - val_root_mean_squared_error: 0.0574
# Epoch 145/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0212 - mse: 0.0023 - mae: 0.0212 - root_mean_squared_error: 0.0478 - val_loss: 0.0259 - val_mse: 0.0033 - val_mae: 0.0259 - val_root_mean_squared_error: 0.0574
# Epoch 146/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0212 - mse: 0.0023 - mae: 0.0212 - root_mean_squared_error: 0.0478 - val_loss: 0.0258 - val_mse: 0.0033 - val_mae: 0.0258 - val_root_mean_squared_error: 0.0574
# Epoch 147/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0211 - mse: 0.0023 - mae: 0.0211 - root_mean_squared_error: 0.0478 - val_loss: 0.0258 - val_mse: 0.0033 - val_mae: 0.0258 - val_root_mean_squared_error: 0.0574
# Epoch 148/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0211 - mse: 0.0023 - mae: 0.0211 - root_mean_squared_error: 0.0478 - val_loss: 0.0258 - val_mse: 0.0033 - val_mae: 0.0258 - val_root_mean_squared_error: 0.0573
# Epoch 149/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0211 - mse: 0.0023 - mae: 0.0211 - root_mean_squared_error: 0.0478 - val_loss: 0.0257 - val_mse: 0.0033 - val_mae: 0.0257 - val_root_mean_squared_error: 0.0573
# Epoch 150/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0211 - mse: 0.0023 - mae: 0.0211 - root_mean_squared_error: 0.0478 - val_loss: 0.0257 - val_mse: 0.0033 - val_mae: 0.0257 - val_root_mean_squared_error: 0.0573
# Epoch 151/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0210 - mse: 0.0023 - mae: 0.0210 - root_mean_squared_error: 0.0477 - val_loss: 0.0256 - val_mse: 0.0033 - val_mae: 0.0256 - val_root_mean_squared_error: 0.0574
# Epoch 152/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0210 - mse: 0.0023 - mae: 0.0210 - root_mean_squared_error: 0.0478 - val_loss: 0.0256 - val_mse: 0.0033 - val_mae: 0.0256 - val_root_mean_squared_error: 0.0574
# Epoch 153/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0210 - mse: 0.0023 - mae: 0.0210 - root_mean_squared_error: 0.0477 - val_loss: 0.0256 - val_mse: 0.0033 - val_mae: 0.0256 - val_root_mean_squared_error: 0.0573
# Epoch 154/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0210 - mse: 0.0023 - mae: 0.0210 - root_mean_squared_error: 0.0477 - val_loss: 0.0256 - val_mse: 0.0033 - val_mae: 0.0256 - val_root_mean_squared_error: 0.0573
# Epoch 155/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0210 - mse: 0.0023 - mae: 0.0210 - root_mean_squared_error: 0.0477 - val_loss: 0.0256 - val_mse: 0.0033 - val_mae: 0.0256 - val_root_mean_squared_error: 0.0572
# Epoch 156/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0209 - mse: 0.0023 - mae: 0.0209 - root_mean_squared_error: 0.0477 - val_loss: 0.0255 - val_mse: 0.0033 - val_mae: 0.0255 - val_root_mean_squared_error: 0.0572
# Epoch 157/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0209 - mse: 0.0023 - mae: 0.0209 - root_mean_squared_error: 0.0477 - val_loss: 0.0255 - val_mse: 0.0033 - val_mae: 0.0255 - val_root_mean_squared_error: 0.0572
# Epoch 158/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0209 - mse: 0.0023 - mae: 0.0209 - root_mean_squared_error: 0.0477 - val_loss: 0.0255 - val_mse: 0.0033 - val_mae: 0.0255 - val_root_mean_squared_error: 0.0572
# Epoch 159/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0209 - mse: 0.0023 - mae: 0.0209 - root_mean_squared_error: 0.0477 - val_loss: 0.0255 - val_mse: 0.0033 - val_mae: 0.0255 - val_root_mean_squared_error: 0.0572
# Epoch 160/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0209 - mse: 0.0023 - mae: 0.0209 - root_mean_squared_error: 0.0476 - val_loss: 0.0254 - val_mse: 0.0033 - val_mae: 0.0254 - val_root_mean_squared_error: 0.0571
# Epoch 161/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0221 - mse: 0.0025 - mae: 0.0221 - root_mean_squared_error: 0.050 - 0s 28us/sample - loss: 0.0209 - mse: 0.0023 - mae: 0.0209 - root_mean_squared_error: 0.0476 - val_loss: 0.0254 - val_mse: 0.0033 - val_mae: 0.0254 - val_root_mean_squared_error: 0.0572
# Epoch 162/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0209 - mse: 0.0023 - mae: 0.0209 - root_mean_squared_error: 0.0476 - val_loss: 0.0254 - val_mse: 0.0033 - val_mae: 0.0254 - val_root_mean_squared_error: 0.0571
# Epoch 163/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0208 - mse: 0.0023 - mae: 0.0208 - root_mean_squared_error: 0.0476 - val_loss: 0.0254 - val_mse: 0.0033 - val_mae: 0.0254 - val_root_mean_squared_error: 0.0571
# Epoch 164/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0208 - mse: 0.0023 - mae: 0.0208 - root_mean_squared_error: 0.0476 - val_loss: 0.0253 - val_mse: 0.0033 - val_mae: 0.0253 - val_root_mean_squared_error: 0.0571
# Epoch 165/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0208 - mse: 0.0023 - mae: 0.0208 - root_mean_squared_error: 0.0476 - val_loss: 0.0253 - val_mse: 0.0033 - val_mae: 0.0253 - val_root_mean_squared_error: 0.0571
# Epoch 166/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0208 - mse: 0.0023 - mae: 0.0208 - root_mean_squared_error: 0.0476 - val_loss: 0.0253 - val_mse: 0.0033 - val_mae: 0.0253 - val_root_mean_squared_error: 0.0572
# Epoch 167/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0208 - mse: 0.0023 - mae: 0.0208 - root_mean_squared_error: 0.0476 - val_loss: 0.0253 - val_mse: 0.0033 - val_mae: 0.0253 - val_root_mean_squared_error: 0.0571
# Epoch 168/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0212 - mse: 0.0024 - mae: 0.0212 - root_mean_squared_error: 0.048 - 0s 28us/sample - loss: 0.0207 - mse: 0.0023 - mae: 0.0207 - root_mean_squared_error: 0.0476 - val_loss: 0.0252 - val_mse: 0.0032 - val_mae: 0.0252 - val_root_mean_squared_error: 0.0570
# Epoch 169/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0208 - mse: 0.0023 - mae: 0.0208 - root_mean_squared_error: 0.0476 - val_loss: 0.0252 - val_mse: 0.0032 - val_mae: 0.0252 - val_root_mean_squared_error: 0.0570
# Epoch 170/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0207 - mse: 0.0023 - mae: 0.0207 - root_mean_squared_error: 0.0476 - val_loss: 0.0252 - val_mse: 0.0032 - val_mae: 0.0252 - val_root_mean_squared_error: 0.0570
# Epoch 171/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0207 - mse: 0.0023 - mae: 0.0207 - root_mean_squared_error: 0.0476 - val_loss: 0.0252 - val_mse: 0.0032 - val_mae: 0.0252 - val_root_mean_squared_error: 0.0569
# Epoch 172/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0207 - mse: 0.0023 - mae: 0.0207 - root_mean_squared_error: 0.0475 - val_loss: 0.0251 - val_mse: 0.0032 - val_mae: 0.0251 - val_root_mean_squared_error: 0.0569
# Epoch 173/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0207 - mse: 0.0023 - mae: 0.0207 - root_mean_squared_error: 0.0475 - val_loss: 0.0251 - val_mse: 0.0032 - val_mae: 0.0251 - val_root_mean_squared_error: 0.0569
# Epoch 174/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0207 - mse: 0.0023 - mae: 0.0207 - root_mean_squared_error: 0.0475 - val_loss: 0.0251 - val_mse: 0.0032 - val_mae: 0.0251 - val_root_mean_squared_error: 0.0569
# Epoch 175/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0207 - mse: 0.0023 - mae: 0.0207 - root_mean_squared_error: 0.0475 - val_loss: 0.0251 - val_mse: 0.0032 - val_mae: 0.0251 - val_root_mean_squared_error: 0.0569
# Epoch 176/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0207 - mse: 0.0023 - mae: 0.0207 - root_mean_squared_error: 0.0475 - val_loss: 0.0251 - val_mse: 0.0032 - val_mae: 0.0251 - val_root_mean_squared_error: 0.0569
# Epoch 177/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0207 - mse: 0.0023 - mae: 0.0207 - root_mean_squared_error: 0.0475 - val_loss: 0.0251 - val_mse: 0.0032 - val_mae: 0.0251 - val_root_mean_squared_error: 0.0569
# Epoch 178/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0206 - mse: 0.0023 - mae: 0.0206 - root_mean_squared_error: 0.0475 - val_loss: 0.0251 - val_mse: 0.0032 - val_mae: 0.0251 - val_root_mean_squared_error: 0.0568
# Epoch 179/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0206 - mse: 0.0023 - mae: 0.0206 - root_mean_squared_error: 0.0475 - val_loss: 0.0251 - val_mse: 0.0032 - val_mae: 0.0251 - val_root_mean_squared_error: 0.0567
# Epoch 180/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0206 - mse: 0.0023 - mae: 0.0206 - root_mean_squared_error: 0.0475 - val_loss: 0.0251 - val_mse: 0.0032 - val_mae: 0.0251 - val_root_mean_squared_error: 0.0568
# Epoch 181/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0206 - mse: 0.0023 - mae: 0.0206 - root_mean_squared_error: 0.0475 - val_loss: 0.0250 - val_mse: 0.0032 - val_mae: 0.0250 - val_root_mean_squared_error: 0.0569
# Epoch 182/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0206 - mse: 0.0023 - mae: 0.0206 - root_mean_squared_error: 0.0475 - val_loss: 0.0250 - val_mse: 0.0032 - val_mae: 0.0250 - val_root_mean_squared_error: 0.0568
# Epoch 183/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0206 - mse: 0.0023 - mae: 0.0206 - root_mean_squared_error: 0.0475 - val_loss: 0.0250 - val_mse: 0.0032 - val_mae: 0.0250 - val_root_mean_squared_error: 0.0568
# Epoch 184/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0205 - mse: 0.0023 - mae: 0.0205 - root_mean_squared_error: 0.0474 - val_loss: 0.0250 - val_mse: 0.0032 - val_mae: 0.0250 - val_root_mean_squared_error: 0.0567
# Epoch 185/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0206 - mse: 0.0023 - mae: 0.0206 - root_mean_squared_error: 0.0475 - val_loss: 0.0250 - val_mse: 0.0032 - val_mae: 0.0250 - val_root_mean_squared_error: 0.0567
# Epoch 186/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0207 - mse: 0.0023 - mae: 0.0207 - root_mean_squared_error: 0.0475 - val_loss: 0.0250 - val_mse: 0.0032 - val_mae: 0.0250 - val_root_mean_squared_error: 0.0567
# Epoch 187/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0205 - mse: 0.0023 - mae: 0.0205 - root_mean_squared_error: 0.0475 - val_loss: 0.0250 - val_mse: 0.0032 - val_mae: 0.0250 - val_root_mean_squared_error: 0.0566
# Epoch 188/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0206 - mse: 0.0022 - mae: 0.0206 - root_mean_squared_error: 0.0474 - val_loss: 0.0250 - val_mse: 0.0032 - val_mae: 0.0250 - val_root_mean_squared_error: 0.0567
# Epoch 189/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0205 - mse: 0.0022 - mae: 0.0205 - root_mean_squared_error: 0.0474 - val_loss: 0.0250 - val_mse: 0.0032 - val_mae: 0.0250 - val_root_mean_squared_error: 0.0566
# Epoch 190/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0213 - mse: 0.0024 - mae: 0.0213 - root_mean_squared_error: 0.049 - 0s 27us/sample - loss: 0.0205 - mse: 0.0022 - mae: 0.0205 - root_mean_squared_error: 0.0474 - val_loss: 0.0250 - val_mse: 0.0032 - val_mae: 0.0250 - val_root_mean_squared_error: 0.0566
# Epoch 191/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0206 - mse: 0.0022 - mae: 0.0206 - root_mean_squared_error: 0.0474 - val_loss: 0.0249 - val_mse: 0.0032 - val_mae: 0.0249 - val_root_mean_squared_error: 0.0567
# Epoch 192/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0205 - mse: 0.0023 - mae: 0.0205 - root_mean_squared_error: 0.0474 - val_loss: 0.0249 - val_mse: 0.0032 - val_mae: 0.0249 - val_root_mean_squared_error: 0.0566
# Epoch 193/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0205 - mse: 0.0022 - mae: 0.0205 - root_mean_squared_error: 0.0474 - val_loss: 0.0250 - val_mse: 0.0032 - val_mae: 0.0250 - val_root_mean_squared_error: 0.0565
# Epoch 194/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0205 - mse: 0.0022 - mae: 0.0205 - root_mean_squared_error: 0.0474 - val_loss: 0.0249 - val_mse: 0.0032 - val_mae: 0.0249 - val_root_mean_squared_error: 0.0567
# Epoch 195/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0205 - mse: 0.0022 - mae: 0.0205 - root_mean_squared_error: 0.0474 - val_loss: 0.0249 - val_mse: 0.0032 - val_mae: 0.0249 - val_root_mean_squared_error: 0.0566
# Epoch 196/500
# ...
# Epoch 436/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0471 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0563
# Epoch 437/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0564
# Epoch 438/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0471 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0563
# Epoch 439/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0565
# Epoch 440/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0471 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0564
# Epoch 441/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0565
# Epoch 442/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0471 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0564
# Epoch 443/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0564
# Epoch 444/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0563
# Epoch 445/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0471 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0565
# Epoch 446/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0471 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0564
# Epoch 447/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0564
# Epoch 448/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0565
# Epoch 449/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 450/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0564
# Epoch 451/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0564
# Epoch 452/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0471 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0563
# Epoch 453/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0565
# Epoch 454/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0471 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0564
# Epoch 455/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0565
# Epoch 456/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0471 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0563
# Epoch 457/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 458/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0564
# Epoch 459/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0564
# Epoch 460/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0564
# Epoch 461/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0564
# Epoch 462/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 463/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0564
# Epoch 464/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0564
# Epoch 465/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 466/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 467/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 468/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0234 - val_mse: 0.0032 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0564
# Epoch 469/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0565
# Epoch 470/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 471/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 472/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 473/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0565
# Epoch 474/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 475/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 476/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 477/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0565
# Epoch 478/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 479/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 480/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0565
# Epoch 481/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0565
# Epoch 482/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 483/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 484/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0565
# Epoch 485/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 486/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 487/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 488/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0566
# Epoch 489/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0471 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 490/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0565
# Epoch 491/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 492/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0565
# Epoch 493/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 494/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0565
# Epoch 495/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0564
# Epoch 496/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0565
# Epoch 497/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0565
# Epoch 498/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0193 - mse: 0.0022 - mae: 0.0193 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0565
# Epoch 499/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0565
# Epoch 500/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0192 - mse: 0.0022 - mae: 0.0192 - root_mean_squared_error: 0.0470 - val_loss: 0.0233 - val_mse: 0.0032 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0565

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mae'],label='train mae')
pyplot.plot(history.history['val_mae'],label='val mae')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mse'],label='train mse')
pyplot.plot(history.history['val_mse'],label='val mse')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['root_mean_squared_error'],label='train rmse')
pyplot.plot(history.history['val_root_mean_squared_error'],label='val rmse')
pyplot.legend()
pyplot.show()
# Out:
# The testing MAE loss is: 0.021559365
# The testing MSE loss is: 0.0028056614
# The testing RMSE loss is: 0.052968495

# %%
pyplot.plot(test_y,color='red', label='True Values')
pyplot.plot(out,color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()

# %%
dataset_test=pd.read_excel('F:\MS thesis data/Hopper Crossing.xlsx')
dataset_test=dataset_test.drop(['Date/Time','Flowd'],axis=1)
dataset_test.dropna(inplace=True)

# %%
shape=np.shape(dataset_test)
print(shape)
pyplot.plot(dataset_test)
# Out:
# (26285, 3)
# [<matplotlib.lines.Line2D at 0x1f40a461948>,
#  <matplotlib.lines.Line2D at 0x1f40a461708>,
#  <matplotlib.lines.Line2D at 0x1f40a461e48>]

# %%
dataset_test
# Out:
#        Cumulative rainfall   Flow  Level
# 0                      0.0  0.093    1.50
# 1                      0.0  0.093    1.50
# 2                      0.0  0.093    1.50
# 3                      0.0  0.093    1.50
# 4                      0.0  0.093    1.50
# ...                    ...    ...     ...
# 26280                  0.2  0.080    1.49
# 26281                  0.2  0.080    1.49
# 26282                  0.2  0.080    1.49
# 26283                  0.2  0.080    1.49
# 26284                  0.2  0.080    1.49
#
# [26285 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset_test)))
# Out:
# The std of original data is Cumulative rainfall    2.451640
# Flow                   0.520832
# Level                  0.083204
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset_test=dataset_test.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset_test.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset_test[:,0]== maxi[0])
    ind2=np.argwhere(dataset_test[:,1]== maxi[1])
    ind3=np.argwhere(dataset_test[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset_test.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset_test[:,0]== mini[0])
    ind2=np.argwhere(dataset_test[:,1]== mini[1])
    ind3=np.argwhere(dataset_test[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset_test)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset_test = min_max_scaler.fit_transform(dataset_test)
# Out:
# The std of cleaned data is 1.5154548293543502

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=1
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values

#one hour
#test_X, test_y = values[:, :-out_hour], values[:,-1]


test_X, test_y = values[:, :-out_hour], values[:, -out_hour: ]


test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6345, 21)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  var2(t-3)  var3(t-3)  \
# 6    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 7    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 8    0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
# 9    0.215385   0.524545   0.776699   0.123077   0.549980   0.791262
# 10   0.123077   0.549980   0.791262   0.092308   0.603309   0.820388
#
#     var1(t-2)  var2(t-2)  var3(t-2)  var1(t-1)  var2(t-1)  var3(t-1)   var3(t)
# 6    0.230769   0.524545   0.776699   0.215385   0.524545   0.776699  0.791262
# 7    0.215385   0.524545   0.776699   0.123077   0.549980   0.791262  0.820388
# 8    0.123077   0.549980   0.791262   0.092308   0.603309   0.820388  0.844660
# 9    0.092308   0.603309   0.820388   0.092308   0.650485   0.844660  0.873786
# 10   0.092308   0.650485   0.844660   0.092308   0.709285   0.873786  0.898058

# %%
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
# Out:
# The testing MAE loss is: 0.020771427
# The testing MSE loss is: 0.0026111705
# The testing RMSE loss is: 0.051099613

# %%
pyplot.plot(test_y,color='red', label='True Values')
pyplot.plot(out,color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()
