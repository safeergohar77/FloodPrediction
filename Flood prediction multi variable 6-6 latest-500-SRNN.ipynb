# %%
import pandas as pd
from pandas import concat
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from sklearn import preprocessing
from tensorflow.keras import backend as K
#from sklearn.preprocessing import MinMaxScaler
#from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input, Dense, LSTM,GRU,SimpleRNN, Activation
from matplotlib import pyplot
#from sklearn.model_selection import train_test_split

# %%
"# convert series to supervised learning\n" 
#windowing of data
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1),
    for i in range(n_in, 0, -1): #startes from n_in and decreses to 0 by decreasing each time -1
     cols.append(df.shift(i))
     names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
     cols.append(df.shift(-i))
     if i == 0:
       names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
     else:
       names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together\n",
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values\n",
    if dropnan:
      agg.dropna(inplace=True)
    return agg

# %%
#def root_mean_squared_error(y_true, y_pred):
 #       return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
dataset1=pd.read_excel('F:\MS thesis data/Brooklyn.xlsx')
dataset1=dataset1.drop(['Date/Time','Flowd'],axis=1)
dataset1.dropna(inplace=True)

# %%
shape=np.shape(dataset1)
print(shape)
pyplot.plot(dataset1)
# Out:
# (26302, 3)
# [<matplotlib.lines.Line2D at 0x20b9c6362c8>,
#  <matplotlib.lines.Line2D at 0x20b9c62de88>,
#  <matplotlib.lines.Line2D at 0x20b9c5cf5c8>]

# %%
dataset1
# Out:
#        Cumulative rainfall    Flow  Level
# 0                       0.0  0.172   0.352
# 1                       0.0  0.180   0.356
# 2                       0.0  0.180   0.356
# 3                       0.0  0.189   0.360
# 4                       0.0  0.189   0.360
# ...                     ...    ...     ...
# 26297                   0.0  0.025   0.232
# 26298                   0.0  0.023   0.228
# 26299                   0.0  0.023   0.228
# 26300                   0.0  0.023   0.228
# 26301                   0.0  0.023   0.228
#
# [26302 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset1)))
# Out:
# The std of original data is Cumulative rainfall     2.872616
# Flow                    1.306642
# Level                   0.147238
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset=dataset1.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset[:,0]== maxi[0])
    ind2=np.argwhere(dataset[:,1]== maxi[1])
    ind3=np.argwhere(dataset[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset[:,0]== mini[0])
    ind2=np.argwhere(dataset[:,1]== mini[1])
    ind3=np.argwhere(dataset[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset = min_max_scaler.fit_transform(dataset)
# Out:
# The std of cleaned data is 1.626639593959813

# %%
pyplot.plot(dataset)
# Out:
# [<matplotlib.lines.Line2D at 0x20b9c952408>,
#  <matplotlib.lines.Line2D at 0x20b9c91c348>,
#  <matplotlib.lines.Line2D at 0x20b9c91c508>]

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=6
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values
train_size  = int(len(dataset) * 0.50)
val_size=int(len(dataset) * 0.75)
train_X, train_y = values[0:train_size, :-out_hour], values[0:train_size,-out_hour: ]
val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-out_hour: ]
test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-out_hour:]
#for last hour
#train_X, train_y = values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]  #for only last hour
#val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]
#test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-1]
print(train_X, train_y)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6340, 36)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var3(t-2)  var1(t-1)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.776699   0.215385
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.776699   0.123077
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.791262   0.092308
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.820388   0.092308
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.844660   0.092308
#
#     var2(t-1)  var3(t-1)   var3(t)  var3(t+1)  var3(t+2)  var3(t+3)  \
# 6    0.524545   0.776699  0.791262   0.820388   0.844660   0.873786
# 7    0.549980   0.791262  0.820388   0.844660   0.873786   0.898058
# 8    0.603309   0.820388  0.844660   0.873786   0.898058   0.932039
# 9    0.650485   0.844660  0.873786   0.898058   0.932039   0.966019
# 10   0.709285   0.873786  0.898058   0.932039   0.966019   1.000000
#
#     var3(t+4)  var3(t+5)
# 6    0.898058   0.932039
# 7    0.932039   0.966019
# 8    0.966019   1.000000
# 9    1.000000   0.941748
# 10   0.941748   0.912621
#
# [5 rows x 24 columns]
# [[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]
#  [0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]
#  [0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]
#  ...
#  [0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]
#  [0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]
#  [0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]] [[0.79126215 0.8203884  0.8446602  0.8737864  0.89805824 0.93203884]
#  [0.8203884  0.8446602  0.8737864  0.89805824 0.93203884 0.9660194 ]
#  [0.8446602  0.8737864  0.89805824 0.93203884 0.9660194  1.        ]
#  ...
#  [0.23786408 0.24271844 0.24757281 0.24757281 0.24757281 0.2184466 ]
#  [0.24271844 0.24757281 0.24757281 0.24757281 0.2184466  0.23300971]
#  [0.24757281 0.24757281 0.24757281 0.2184466  0.23300971 0.24271844]]

# %%
print(train_X, train_y)
# Out:
# [[[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]]
#
#  [[0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]]
#
#  [[0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]]
#
#  ...
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]]] [[0.79126215 0.8203884  0.8446602  0.8737864  0.89805824 0.93203884]
#  [0.8203884  0.8446602  0.8737864  0.89805824 0.93203884 0.9660194 ]
#  [0.8446602  0.8737864  0.89805824 0.93203884 0.9660194  1.        ]
#  ...
#  [0.23786408 0.24271844 0.24757281 0.24757281 0.24757281 0.2184466 ]
#  [0.24271844 0.24757281 0.24757281 0.24757281 0.2184466  0.23300971]
#  [0.24757281 0.24757281 0.24757281 0.2184466  0.23300971 0.24271844]]

# %%
print(train_X.shape, train_y.shape, val_X.shape, val_y.shape)
# Out:
# (3175, 1, 18) (3175, 6) (1588, 1, 18) (1588, 6)

# %%
randomState = 46
np.random.seed(randomState)
#tensorflow.random.set_random_seed(randomState)
tensorflow.random.set_seed(randomState)
model = Sequential()
model.add(SimpleRNN(15,input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dense(22))
#model.add(Activation('relu'))    
model.add(Dense(out_hour,activation = "sigmoid"))
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.001)
#    opt=tensorflow.keras.optimizers.Adam(learning_rate=0.00075)
model.compile(loss='mae', optimizer=opt,metrics=['mse','mae',tensorflow.keras.metrics.RootMeanSquaredError()])
history = model.fit(train_X, train_y,validation_data=(val_X, val_y), epochs=100, batch_size=100,verbose=1,shuffle=False)
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)
# Out:
# Train on 3175 samples, validate on 1588 samples
# Epoch 1/100
# 3175/3175 [==============================] - 1s 337us/sample - loss: 0.2643 - mse: 0.0836 - mae: 0.2643 - root_mean_squared_error: 0.2891 - val_loss: 0.2687 - val_mse: 0.0892 - val_mae: 0.2687 - val_root_mean_squared_error: 0.2986
# Epoch 2/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.2324 - mse: 0.0661 - mae: 0.2324 - root_mean_squared_error: 0.2572 - val_loss: 0.2404 - val_mse: 0.0729 - val_mae: 0.2404 - val_root_mean_squared_error: 0.2699
# Epoch 3/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.2060 - mse: 0.0544 - mae: 0.2060 - root_mean_squared_error: 0.2333 - val_loss: 0.2160 - val_mse: 0.0608 - val_mae: 0.2160 - val_root_mean_squared_error: 0.2465
# Epoch 4/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.1851 - mse: 0.0471 - mae: 0.1851 - root_mean_squared_error: 0.2171 - val_loss: 0.1971 - val_mse: 0.0526 - val_mae: 0.1971 - val_root_mean_squared_error: 0.2294
# Epoch 5/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1702 - mse: 0.0431 - mae: 0.1702 - root_mean_squared_error: 0.2076 - val_loss: 0.1833 - val_mse: 0.0472 - val_mae: 0.1833 - val_root_mean_squared_error: 0.2173
# Epoch 6/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.1594 - mse: 0.0403 - mae: 0.1594 - root_mean_squared_error: 0.2007 - val_loss: 0.1723 - val_mse: 0.0429 - val_mae: 0.1723 - val_root_mean_squared_error: 0.2072
# Epoch 7/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1501 - mse: 0.0371 - mae: 0.1501 - root_mean_squared_error: 0.1926 - val_loss: 0.1620 - val_mse: 0.0386 - val_mae: 0.1620 - val_root_mean_squared_error: 0.1965
# Epoch 8/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1403 - mse: 0.0331 - mae: 0.1403 - root_mean_squared_error: 0.1818 - val_loss: 0.1510 - val_mse: 0.0340 - val_mae: 0.1510 - val_root_mean_squared_error: 0.1843
# Epoch 9/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1297 - mse: 0.0285 - mae: 0.1297 - root_mean_squared_error: 0.1689 - val_loss: 0.1393 - val_mse: 0.0293 - val_mae: 0.1393 - val_root_mean_squared_error: 0.1712
# Epoch 10/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1190 - mse: 0.0243 - mae: 0.1190 - root_mean_squared_error: 0.1558 - val_loss: 0.1276 - val_mse: 0.0252 - val_mae: 0.1276 - val_root_mean_squared_error: 0.1588
# Epoch 11/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1090 - mse: 0.0208 - mae: 0.1090 - root_mean_squared_error: 0.1443 - val_loss: 0.1172 - val_mse: 0.0218 - val_mae: 0.1172 - val_root_mean_squared_error: 0.1478
# Epoch 12/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.1002 - mse: 0.0183 - mae: 0.1002 - root_mean_squared_error: 0.1352 - val_loss: 0.1084 - val_mse: 0.0193 - val_mae: 0.1084 - val_root_mean_squared_error: 0.1391
# Epoch 13/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0930 - mse: 0.0166 - mae: 0.0930 - root_mean_squared_error: 0.1287 - val_loss: 0.1012 - val_mse: 0.0176 - val_mae: 0.1012 - val_root_mean_squared_error: 0.1325
# Epoch 14/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0871 - mse: 0.0154 - mae: 0.0871 - root_mean_squared_error: 0.1242 - val_loss: 0.0956 - val_mse: 0.0164 - val_mae: 0.0956 - val_root_mean_squared_error: 0.1279
# Epoch 15/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0827 - mse: 0.0148 - mae: 0.0827 - root_mean_squared_error: 0.1216 - val_loss: 0.0912 - val_mse: 0.0156 - val_mae: 0.0912 - val_root_mean_squared_error: 0.1248
# Epoch 16/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0795 - mse: 0.0144 - mae: 0.0795 - root_mean_squared_error: 0.1199 - val_loss: 0.0879 - val_mse: 0.0150 - val_mae: 0.0879 - val_root_mean_squared_error: 0.1227
# Epoch 17/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0770 - mse: 0.0141 - mae: 0.0770 - root_mean_squared_error: 0.1189 - val_loss: 0.0852 - val_mse: 0.0147 - val_mae: 0.0852 - val_root_mean_squared_error: 0.1213
# Epoch 18/100
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0750 - mse: 0.0140 - mae: 0.0750 - root_mean_squared_error: 0.1183 - val_loss: 0.0830 - val_mse: 0.0144 - val_mae: 0.0830 - val_root_mean_squared_error: 0.1202
# Epoch 19/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0734 - mse: 0.0139 - mae: 0.0734 - root_mean_squared_error: 0.1178 - val_loss: 0.0812 - val_mse: 0.0143 - val_mae: 0.0812 - val_root_mean_squared_error: 0.1194
# Epoch 20/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0719 - mse: 0.0138 - mae: 0.0719 - root_mean_squared_error: 0.1174 - val_loss: 0.0796 - val_mse: 0.0141 - val_mae: 0.0796 - val_root_mean_squared_error: 0.1187
# Epoch 21/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0707 - mse: 0.0137 - mae: 0.0707 - root_mean_squared_error: 0.1169 - val_loss: 0.0782 - val_mse: 0.0139 - val_mae: 0.0782 - val_root_mean_squared_error: 0.1179
# Epoch 22/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0697 - mse: 0.0135 - mae: 0.0697 - root_mean_squared_error: 0.1163 - val_loss: 0.0770 - val_mse: 0.0137 - val_mae: 0.0770 - val_root_mean_squared_error: 0.1172
# Epoch 23/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0686 - mse: 0.0134 - mae: 0.0686 - root_mean_squared_error: 0.1157 - val_loss: 0.0759 - val_mse: 0.0135 - val_mae: 0.0759 - val_root_mean_squared_error: 0.1163
# Epoch 24/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0677 - mse: 0.0132 - mae: 0.0677 - root_mean_squared_error: 0.1148 - val_loss: 0.0749 - val_mse: 0.0134 - val_mae: 0.0749 - val_root_mean_squared_error: 0.1156
# Epoch 25/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0668 - mse: 0.0130 - mae: 0.0668 - root_mean_squared_error: 0.1139 - val_loss: 0.0739 - val_mse: 0.0132 - val_mae: 0.0739 - val_root_mean_squared_error: 0.1147
# Epoch 26/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0659 - mse: 0.0127 - mae: 0.0659 - root_mean_squared_error: 0.1129 - val_loss: 0.0728 - val_mse: 0.0129 - val_mae: 0.0728 - val_root_mean_squared_error: 0.1138
# Epoch 27/100
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0651 - mse: 0.0125 - mae: 0.0651 - root_mean_squared_error: 0.1118 - val_loss: 0.0719 - val_mse: 0.0127 - val_mae: 0.0719 - val_root_mean_squared_error: 0.1128
# Epoch 28/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0642 - mse: 0.0122 - mae: 0.0642 - root_mean_squared_error: 0.1106 - val_loss: 0.0709 - val_mse: 0.0125 - val_mae: 0.0709 - val_root_mean_squared_error: 0.1118
# Epoch 29/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0634 - mse: 0.0120 - mae: 0.0634 - root_mean_squared_error: 0.1095 - val_loss: 0.0699 - val_mse: 0.0123 - val_mae: 0.0699 - val_root_mean_squared_error: 0.1108
# Epoch 30/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0625 - mse: 0.0117 - mae: 0.0625 - root_mean_squared_error: 0.1083 - val_loss: 0.0690 - val_mse: 0.0121 - val_mae: 0.0690 - val_root_mean_squared_error: 0.1098
# Epoch 31/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0617 - mse: 0.0115 - mae: 0.0617 - root_mean_squared_error: 0.1071 - val_loss: 0.0682 - val_mse: 0.0119 - val_mae: 0.0682 - val_root_mean_squared_error: 0.1089
# Epoch 32/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0609 - mse: 0.0112 - mae: 0.0609 - root_mean_squared_error: 0.1060 - val_loss: 0.0674 - val_mse: 0.0117 - val_mae: 0.0674 - val_root_mean_squared_error: 0.1080
# Epoch 33/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0602 - mse: 0.0110 - mae: 0.0602 - root_mean_squared_error: 0.1049 - val_loss: 0.0666 - val_mse: 0.0115 - val_mae: 0.0666 - val_root_mean_squared_error: 0.1072
# Epoch 34/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0595 - mse: 0.0108 - mae: 0.0595 - root_mean_squared_error: 0.1039 - val_loss: 0.0659 - val_mse: 0.0113 - val_mae: 0.0659 - val_root_mean_squared_error: 0.1065
# Epoch 35/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0588 - mse: 0.0106 - mae: 0.0588 - root_mean_squared_error: 0.1029 - val_loss: 0.0652 - val_mse: 0.0112 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1058
# Epoch 36/100
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0582 - mse: 0.0104 - mae: 0.0582 - root_mean_squared_error: 0.1019 - val_loss: 0.0647 - val_mse: 0.0110 - val_mae: 0.0647 - val_root_mean_squared_error: 0.1051
# Epoch 37/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0576 - mse: 0.0102 - mae: 0.0576 - root_mean_squared_error: 0.1009 - val_loss: 0.0642 - val_mse: 0.0109 - val_mae: 0.0642 - val_root_mean_squared_error: 0.1046
# Epoch 38/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0571 - mse: 0.0100 - mae: 0.0571 - root_mean_squared_error: 0.1001 - val_loss: 0.0637 - val_mse: 0.0108 - val_mae: 0.0637 - val_root_mean_squared_error: 0.1041
# Epoch 39/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0566 - mse: 0.0099 - mae: 0.0566 - root_mean_squared_error: 0.0993 - val_loss: 0.0632 - val_mse: 0.0107 - val_mae: 0.0632 - val_root_mean_squared_error: 0.1035
# Epoch 40/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0562 - mse: 0.0097 - mae: 0.0562 - root_mean_squared_error: 0.0986 - val_loss: 0.0628 - val_mse: 0.0106 - val_mae: 0.0628 - val_root_mean_squared_error: 0.1031
# Epoch 41/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0558 - mse: 0.0096 - mae: 0.0558 - root_mean_squared_error: 0.0979 - val_loss: 0.0625 - val_mse: 0.0106 - val_mae: 0.0625 - val_root_mean_squared_error: 0.1028
# Epoch 42/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0555 - mse: 0.0095 - mae: 0.0555 - root_mean_squared_error: 0.0974 - val_loss: 0.0621 - val_mse: 0.0105 - val_mae: 0.0621 - val_root_mean_squared_error: 0.1025
# Epoch 43/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0551 - mse: 0.0094 - mae: 0.0551 - root_mean_squared_error: 0.0969 - val_loss: 0.0618 - val_mse: 0.0104 - val_mae: 0.0618 - val_root_mean_squared_error: 0.1022
# Epoch 44/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0548 - mse: 0.0093 - mae: 0.0548 - root_mean_squared_error: 0.0964 - val_loss: 0.0615 - val_mse: 0.0104 - val_mae: 0.0615 - val_root_mean_squared_error: 0.1019
# Epoch 45/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0545 - mse: 0.0092 - mae: 0.0545 - root_mean_squared_error: 0.0960 - val_loss: 0.0612 - val_mse: 0.0103 - val_mae: 0.0612 - val_root_mean_squared_error: 0.1016
# Epoch 46/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0543 - mse: 0.0091 - mae: 0.0543 - root_mean_squared_error: 0.0956 - val_loss: 0.0610 - val_mse: 0.0103 - val_mae: 0.0610 - val_root_mean_squared_error: 0.1014
# Epoch 47/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0541 - mse: 0.0091 - mae: 0.0541 - root_mean_squared_error: 0.0952 - val_loss: 0.0608 - val_mse: 0.0103 - val_mae: 0.0608 - val_root_mean_squared_error: 0.1013
# Epoch 48/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0539 - mse: 0.0090 - mae: 0.0539 - root_mean_squared_error: 0.0949 - val_loss: 0.0606 - val_mse: 0.0102 - val_mae: 0.0606 - val_root_mean_squared_error: 0.1011
# Epoch 49/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0537 - mse: 0.0090 - mae: 0.0537 - root_mean_squared_error: 0.0946 - val_loss: 0.0604 - val_mse: 0.0102 - val_mae: 0.0604 - val_root_mean_squared_error: 0.1009
# Epoch 50/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0535 - mse: 0.0089 - mae: 0.0535 - root_mean_squared_error: 0.0944 - val_loss: 0.0602 - val_mse: 0.0101 - val_mae: 0.0602 - val_root_mean_squared_error: 0.1007
# Epoch 51/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0534 - mse: 0.0089 - mae: 0.0534 - root_mean_squared_error: 0.0941 - val_loss: 0.0600 - val_mse: 0.0101 - val_mae: 0.0600 - val_root_mean_squared_error: 0.1006
# Epoch 52/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0532 - mse: 0.0088 - mae: 0.0532 - root_mean_squared_error: 0.0939 - val_loss: 0.0599 - val_mse: 0.0101 - val_mae: 0.0599 - val_root_mean_squared_error: 0.1004
# Epoch 53/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0531 - mse: 0.0088 - mae: 0.0531 - root_mean_squared_error: 0.0937 - val_loss: 0.0597 - val_mse: 0.0101 - val_mae: 0.0597 - val_root_mean_squared_error: 0.1003
# Epoch 54/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0530 - mse: 0.0087 - mae: 0.0530 - root_mean_squared_error: 0.0935 - val_loss: 0.0596 - val_mse: 0.0100 - val_mae: 0.0596 - val_root_mean_squared_error: 0.1002
# Epoch 55/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0528 - mse: 0.0087 - mae: 0.0528 - root_mean_squared_error: 0.0933 - val_loss: 0.0594 - val_mse: 0.0100 - val_mae: 0.0594 - val_root_mean_squared_error: 0.1001
# Epoch 56/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0527 - mse: 0.0087 - mae: 0.0527 - root_mean_squared_error: 0.0931 - val_loss: 0.0593 - val_mse: 0.0100 - val_mae: 0.0593 - val_root_mean_squared_error: 0.0999
# Epoch 57/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0526 - mse: 0.0086 - mae: 0.0526 - root_mean_squared_error: 0.0929 - val_loss: 0.0592 - val_mse: 0.0100 - val_mae: 0.0592 - val_root_mean_squared_error: 0.0998
# Epoch 58/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0525 - mse: 0.0086 - mae: 0.0525 - root_mean_squared_error: 0.0928 - val_loss: 0.0591 - val_mse: 0.0099 - val_mae: 0.0591 - val_root_mean_squared_error: 0.0997
# Epoch 59/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0524 - mse: 0.0086 - mae: 0.0524 - root_mean_squared_error: 0.0926 - val_loss: 0.0589 - val_mse: 0.0099 - val_mae: 0.0589 - val_root_mean_squared_error: 0.0996
# Epoch 60/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0523 - mse: 0.0086 - mae: 0.0523 - root_mean_squared_error: 0.0925 - val_loss: 0.0588 - val_mse: 0.0099 - val_mae: 0.0588 - val_root_mean_squared_error: 0.0995
# Epoch 61/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0522 - mse: 0.0085 - mae: 0.0522 - root_mean_squared_error: 0.0923 - val_loss: 0.0587 - val_mse: 0.0099 - val_mae: 0.0587 - val_root_mean_squared_error: 0.0994
# Epoch 62/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0521 - mse: 0.0085 - mae: 0.0521 - root_mean_squared_error: 0.0922 - val_loss: 0.0586 - val_mse: 0.0099 - val_mae: 0.0586 - val_root_mean_squared_error: 0.0993
# Epoch 63/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0521 - mse: 0.0085 - mae: 0.0521 - root_mean_squared_error: 0.0921 - val_loss: 0.0585 - val_mse: 0.0098 - val_mae: 0.0585 - val_root_mean_squared_error: 0.0992
# Epoch 64/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0520 - mse: 0.0085 - mae: 0.0520 - root_mean_squared_error: 0.0920 - val_loss: 0.0584 - val_mse: 0.0098 - val_mae: 0.0584 - val_root_mean_squared_error: 0.0991
# Epoch 65/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0519 - mse: 0.0084 - mae: 0.0519 - root_mean_squared_error: 0.0919 - val_loss: 0.0583 - val_mse: 0.0098 - val_mae: 0.0583 - val_root_mean_squared_error: 0.0990
# Epoch 66/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0518 - mse: 0.0084 - mae: 0.0518 - root_mean_squared_error: 0.0918 - val_loss: 0.0582 - val_mse: 0.0098 - val_mae: 0.0582 - val_root_mean_squared_error: 0.0989
# Epoch 67/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0517 - mse: 0.0084 - mae: 0.0517 - root_mean_squared_error: 0.0917 - val_loss: 0.0580 - val_mse: 0.0098 - val_mae: 0.0580 - val_root_mean_squared_error: 0.0988
# Epoch 68/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0516 - mse: 0.0084 - mae: 0.0516 - root_mean_squared_error: 0.0916 - val_loss: 0.0579 - val_mse: 0.0097 - val_mae: 0.0579 - val_root_mean_squared_error: 0.0987
# Epoch 69/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0515 - mse: 0.0084 - mae: 0.0515 - root_mean_squared_error: 0.0915 - val_loss: 0.0578 - val_mse: 0.0097 - val_mae: 0.0578 - val_root_mean_squared_error: 0.0986
# Epoch 70/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0515 - mse: 0.0084 - mae: 0.0515 - root_mean_squared_error: 0.0914 - val_loss: 0.0578 - val_mse: 0.0097 - val_mae: 0.0578 - val_root_mean_squared_error: 0.0986
# Epoch 71/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0514 - mse: 0.0083 - mae: 0.0514 - root_mean_squared_error: 0.0914 - val_loss: 0.0577 - val_mse: 0.0097 - val_mae: 0.0577 - val_root_mean_squared_error: 0.0985
# Epoch 72/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0513 - mse: 0.0083 - mae: 0.0513 - root_mean_squared_error: 0.0913 - val_loss: 0.0576 - val_mse: 0.0097 - val_mae: 0.0576 - val_root_mean_squared_error: 0.0984
# Epoch 73/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0513 - mse: 0.0083 - mae: 0.0513 - root_mean_squared_error: 0.0912 - val_loss: 0.0575 - val_mse: 0.0097 - val_mae: 0.0575 - val_root_mean_squared_error: 0.0984
# Epoch 74/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0512 - mse: 0.0083 - mae: 0.0512 - root_mean_squared_error: 0.0911 - val_loss: 0.0574 - val_mse: 0.0097 - val_mae: 0.0574 - val_root_mean_squared_error: 0.0983
# Epoch 75/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0511 - mse: 0.0083 - mae: 0.0511 - root_mean_squared_error: 0.0911 - val_loss: 0.0573 - val_mse: 0.0096 - val_mae: 0.0573 - val_root_mean_squared_error: 0.0982
# Epoch 76/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0511 - mse: 0.0083 - mae: 0.0511 - root_mean_squared_error: 0.0910 - val_loss: 0.0572 - val_mse: 0.0096 - val_mae: 0.0572 - val_root_mean_squared_error: 0.0981
# Epoch 77/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0510 - mse: 0.0083 - mae: 0.0510 - root_mean_squared_error: 0.0910 - val_loss: 0.0572 - val_mse: 0.0096 - val_mae: 0.0572 - val_root_mean_squared_error: 0.0981
# Epoch 78/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0509 - mse: 0.0083 - mae: 0.0509 - root_mean_squared_error: 0.0909 - val_loss: 0.0571 - val_mse: 0.0096 - val_mae: 0.0571 - val_root_mean_squared_error: 0.0981
# Epoch 79/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0509 - mse: 0.0083 - mae: 0.0509 - root_mean_squared_error: 0.0908 - val_loss: 0.0570 - val_mse: 0.0096 - val_mae: 0.0570 - val_root_mean_squared_error: 0.0980
# Epoch 80/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0508 - mse: 0.0082 - mae: 0.0508 - root_mean_squared_error: 0.0908 - val_loss: 0.0569 - val_mse: 0.0096 - val_mae: 0.0569 - val_root_mean_squared_error: 0.0979
# Epoch 81/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0508 - mse: 0.0082 - mae: 0.0508 - root_mean_squared_error: 0.0907 - val_loss: 0.0569 - val_mse: 0.0096 - val_mae: 0.0569 - val_root_mean_squared_error: 0.0979
# Epoch 82/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0507 - mse: 0.0082 - mae: 0.0507 - root_mean_squared_error: 0.0907 - val_loss: 0.0568 - val_mse: 0.0096 - val_mae: 0.0568 - val_root_mean_squared_error: 0.0978
# Epoch 83/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0507 - mse: 0.0082 - mae: 0.0507 - root_mean_squared_error: 0.0906 - val_loss: 0.0567 - val_mse: 0.0096 - val_mae: 0.0567 - val_root_mean_squared_error: 0.0978
# Epoch 84/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0506 - mse: 0.0082 - mae: 0.0506 - root_mean_squared_error: 0.0906 - val_loss: 0.0566 - val_mse: 0.0095 - val_mae: 0.0566 - val_root_mean_squared_error: 0.0977
# Epoch 85/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0505 - mse: 0.0082 - mae: 0.0505 - root_mean_squared_error: 0.0905 - val_loss: 0.0566 - val_mse: 0.0095 - val_mae: 0.0566 - val_root_mean_squared_error: 0.0977
# Epoch 86/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0505 - mse: 0.0082 - mae: 0.0505 - root_mean_squared_error: 0.0905 - val_loss: 0.0565 - val_mse: 0.0095 - val_mae: 0.0565 - val_root_mean_squared_error: 0.0976
# Epoch 87/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0504 - mse: 0.0082 - mae: 0.0504 - root_mean_squared_error: 0.0904 - val_loss: 0.0564 - val_mse: 0.0095 - val_mae: 0.0564 - val_root_mean_squared_error: 0.0975
# Epoch 88/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0504 - mse: 0.0082 - mae: 0.0504 - root_mean_squared_error: 0.0904 - val_loss: 0.0563 - val_mse: 0.0095 - val_mae: 0.0563 - val_root_mean_squared_error: 0.0974
# Epoch 89/100
# 3175/3175 [==============================] - ETA: 0s - loss: 0.1024 - mse: 0.0228 - mae: 0.1024 - root_mean_squared_error: 0.151 - 0s 21us/sample - loss: 0.0503 - mse: 0.0082 - mae: 0.0503 - root_mean_squared_error: 0.0903 - val_loss: 0.0562 - val_mse: 0.0095 - val_mae: 0.0562 - val_root_mean_squared_error: 0.0974
# Epoch 90/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0503 - mse: 0.0082 - mae: 0.0503 - root_mean_squared_error: 0.0903 - val_loss: 0.0562 - val_mse: 0.0095 - val_mae: 0.0562 - val_root_mean_squared_error: 0.0974
# Epoch 91/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0502 - mse: 0.0081 - mae: 0.0502 - root_mean_squared_error: 0.0903 - val_loss: 0.0561 - val_mse: 0.0095 - val_mae: 0.0561 - val_root_mean_squared_error: 0.0973
# Epoch 92/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0502 - mse: 0.0081 - mae: 0.0502 - root_mean_squared_error: 0.0902 - val_loss: 0.0560 - val_mse: 0.0095 - val_mae: 0.0560 - val_root_mean_squared_error: 0.0973
# Epoch 93/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0501 - mse: 0.0081 - mae: 0.0501 - root_mean_squared_error: 0.0902 - val_loss: 0.0560 - val_mse: 0.0095 - val_mae: 0.0560 - val_root_mean_squared_error: 0.0972
# Epoch 94/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0501 - mse: 0.0081 - mae: 0.0501 - root_mean_squared_error: 0.0901 - val_loss: 0.0559 - val_mse: 0.0094 - val_mae: 0.0559 - val_root_mean_squared_error: 0.0972
# Epoch 95/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0500 - mse: 0.0081 - mae: 0.0500 - root_mean_squared_error: 0.0901 - val_loss: 0.0558 - val_mse: 0.0094 - val_mae: 0.0558 - val_root_mean_squared_error: 0.0971
# Epoch 96/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0500 - mse: 0.0081 - mae: 0.0500 - root_mean_squared_error: 0.0901 - val_loss: 0.0558 - val_mse: 0.0094 - val_mae: 0.0558 - val_root_mean_squared_error: 0.0971
# Epoch 97/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0499 - mse: 0.0081 - mae: 0.0499 - root_mean_squared_error: 0.0900 - val_loss: 0.0557 - val_mse: 0.0094 - val_mae: 0.0557 - val_root_mean_squared_error: 0.0970
# Epoch 98/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0499 - mse: 0.0081 - mae: 0.0499 - root_mean_squared_error: 0.0900 - val_loss: 0.0556 - val_mse: 0.0094 - val_mae: 0.0556 - val_root_mean_squared_error: 0.0970
# Epoch 99/100
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0499 - mse: 0.0081 - mae: 0.0499 - root_mean_squared_error: 0.0900 - val_loss: 0.0556 - val_mse: 0.0094 - val_mae: 0.0556 - val_root_mean_squared_error: 0.0969
# Epoch 100/100
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0498 - mse: 0.0081 - mae: 0.0498 - root_mean_squared_error: 0.0899 - val_loss: 0.0555 - val_mse: 0.0094 - val_mae: 0.0555 - val_root_mean_squared_error: 0.0969

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mae'],label='train mae')
pyplot.plot(history.history['val_mae'],label='val mae')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mse'],label='train mse')
pyplot.plot(history.history['val_mse'],label='val mse')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['root_mean_squared_error'],label='train rmse')
pyplot.plot(history.history['val_root_mean_squared_error'],label='val rmse')
pyplot.legend()
pyplot.show()
# Out:
# The testing MAE loss is: 0.05340825
# The testing MSE loss is: 0.008441612
# The testing RMSE loss is: 0.09187824

# %%
pyplot.plot(test_y[:,5],color='red', label='True Values')
pyplot.plot(out[:,5],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()

# %%
dataset_test=pd.read_excel('F:\MS thesis data/Hopper Crossing.xlsx')
dataset_test=dataset_test.drop(['Date/Time','Flowd'],axis=1)
dataset_test.dropna(inplace=True)

# %%
shape=np.shape(dataset_test)
print(shape)
pyplot.plot(dataset_test)
# Out:
# (26285, 3)
# [<matplotlib.lines.Line2D at 0x20ba1eec948>,
#  <matplotlib.lines.Line2D at 0x20ba1eeca48>,
#  <matplotlib.lines.Line2D at 0x20ba1eec3c8>]

# %%
dataset_test
# Out:
#        Cumulative rainfall   Flow  Level
# 0                      0.0  0.093    1.50
# 1                      0.0  0.093    1.50
# 2                      0.0  0.093    1.50
# 3                      0.0  0.093    1.50
# 4                      0.0  0.093    1.50
# ...                    ...    ...     ...
# 26280                  0.2  0.080    1.49
# 26281                  0.2  0.080    1.49
# 26282                  0.2  0.080    1.49
# 26283                  0.2  0.080    1.49
# 26284                  0.2  0.080    1.49
#
# [26285 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset_test)))
# Out:
# The std of original data is Cumulative rainfall    2.451640
# Flow                   0.520832
# Level                  0.083204
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset_test=dataset_test.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset_test.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset_test[:,0]== maxi[0])
    ind2=np.argwhere(dataset_test[:,1]== maxi[1])
    ind3=np.argwhere(dataset_test[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset_test.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset_test[:,0]== mini[0])
    ind2=np.argwhere(dataset_test[:,1]== mini[1])
    ind3=np.argwhere(dataset_test[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset_test)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset_test = min_max_scaler.fit_transform(dataset_test)
# Out:
# The std of cleaned data is 1.5154548293543502

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=6
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values

#one hour
#test_X, test_y = values[:, :-out_hour], values[:,-1]


test_X, test_y = values[:, :-out_hour], values[:, -out_hour: ]


test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6340, 36)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var3(t-2)  var1(t-1)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.776699   0.215385
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.776699   0.123077
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.791262   0.092308
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.820388   0.092308
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.844660   0.092308
#
#     var2(t-1)  var3(t-1)   var3(t)  var3(t+1)  var3(t+2)  var3(t+3)  \
# 6    0.524545   0.776699  0.791262   0.820388   0.844660   0.873786
# 7    0.549980   0.791262  0.820388   0.844660   0.873786   0.898058
# 8    0.603309   0.820388  0.844660   0.873786   0.898058   0.932039
# 9    0.650485   0.844660  0.873786   0.898058   0.932039   0.966019
# 10   0.709285   0.873786  0.898058   0.932039   0.966019   1.000000
#
#     var3(t+4)  var3(t+5)
# 6    0.898058   0.932039
# 7    0.932039   0.966019
# 8    0.966019   1.000000
# 9    1.000000   0.941748
# 10   0.941748   0.912621
#
# [5 rows x 24 columns]

# %%
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
# Out:
# The testing MAE loss is: 0.052201334
# The testing MSE loss is: 0.008526804
# The testing RMSE loss is: 0.09234069

# %%
pyplot.plot(test_y[:,5],color='red', label='True Values')
pyplot.plot(out[:,5],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()
