# %%
import pandas as pd
from pandas import concat
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from sklearn import preprocessing
from tensorflow.keras import backend as K
#from sklearn.preprocessing import MinMaxScaler
#from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input, Dense, LSTM,GRU,SimpleRNN, Activation
from matplotlib import pyplot
#from sklearn.model_selection import train_test_split

# %%
"# convert series to supervised learning\n" 
#windowing of data
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1),
    for i in range(n_in, 0, -1): #startes from n_in and decreses to 0 by decreasing each time -1
     cols.append(df.shift(i))
     names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
     cols.append(df.shift(-i))
     if i == 0:
       names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
     else:
       names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together\n",
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values\n",
    if dropnan:
      agg.dropna(inplace=True)
    return agg

# %%
#def root_mean_squared_error(y_true, y_pred):
 #       return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
dataset1=pd.read_excel('F:\MS thesis data/Brooklyn.xlsx')
dataset1=dataset1.drop(['Date/Time','Flowd'],axis=1)
dataset1.dropna(inplace=True)

# %%
shape=np.shape(dataset1)
print(shape)
pyplot.plot(dataset1)
# Out:
# (26302, 3)
# [<matplotlib.lines.Line2D at 0x1cb0ad19148>,
#  <matplotlib.lines.Line2D at 0x1cb0b8f0c88>,
#  <matplotlib.lines.Line2D at 0x1cb0b8eb148>]

# %%
dataset1
# Out:
#        Cumulative rainfall    Flow  Level
# 0                       0.0  0.172   0.352
# 1                       0.0  0.180   0.356
# 2                       0.0  0.180   0.356
# 3                       0.0  0.189   0.360
# 4                       0.0  0.189   0.360
# ...                     ...    ...     ...
# 26297                   0.0  0.025   0.232
# 26298                   0.0  0.023   0.228
# 26299                   0.0  0.023   0.228
# 26300                   0.0  0.023   0.228
# 26301                   0.0  0.023   0.228
#
# [26302 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset1)))
# Out:
# The std of original data is Cumulative rainfall     2.872616
# Flow                    1.306642
# Level                   0.147238
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset=dataset1.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset[:,0]== maxi[0])
    ind2=np.argwhere(dataset[:,1]== maxi[1])
    ind3=np.argwhere(dataset[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset[:,0]== mini[0])
    ind2=np.argwhere(dataset[:,1]== mini[1])
    ind3=np.argwhere(dataset[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset = min_max_scaler.fit_transform(dataset)
# Out:
# The std of cleaned data is 1.626639593959813

# %%
pyplot.plot(dataset)
# Out:
# [<matplotlib.lines.Line2D at 0x1cb0af5a688>,
#  <matplotlib.lines.Line2D at 0x1cb0aee68c8>,
#  <matplotlib.lines.Line2D at 0x1cb0aee6a88>]

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=12
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values
train_size  = int(len(dataset) * 0.50)
val_size=int(len(dataset) * 0.75)
train_X, train_y = values[0:train_size, :-out_hour], values[0:train_size,-out_hour: ]
val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-out_hour: ]
test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-out_hour:]
#for last hour
#train_X, train_y = values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]  #for only last hour
#val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]
#test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-1]
print(train_X, train_y)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6334, 54)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var3(t+2)  var3(t+3)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.844660   0.873786
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.873786   0.898058
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.898058   0.932039
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.932039   0.966019
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.966019   1.000000
#
#     var3(t+4)  var3(t+5)  var3(t+6)  var3(t+7)  var3(t+8)  var3(t+9)  \
# 6    0.898058   0.932039   0.966019   1.000000   0.941748   0.912621
# 7    0.932039   0.966019   1.000000   0.941748   0.912621   0.800971
# 8    0.966019   1.000000   0.941748   0.912621   0.800971   0.723301
# 9    1.000000   0.941748   0.912621   0.800971   0.723301   0.665049
# 10   0.941748   0.912621   0.800971   0.723301   0.665049   0.616505
#
#     var3(t+10)  var3(t+11)
# 6     0.800971    0.723301
# 7     0.723301    0.665049
# 8     0.665049    0.616505
# 9     0.616505    0.572816
# 10    0.572816    0.548544
#
# [5 rows x 30 columns]
# [[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]
#  [0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]
#  [0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]
#  ...
#  [0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]
#  [0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]
#  [0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]] [[0.79126215 0.8203884  0.8446602  ... 0.9126214  0.80097085 0.723301  ]
#  [0.8203884  0.8446602  0.8737864  ... 0.80097085 0.723301   0.66504854]
#  [0.8446602  0.8737864  0.89805824 ... 0.723301   0.66504854 0.61650485]
#  ...
#  [0.23786408 0.24271844 0.24757281 ... 0.27184466 0.27184466 0.2961165 ]
#  [0.24271844 0.24757281 0.24757281 ... 0.27184466 0.2961165  0.32524273]
#  [0.24757281 0.24757281 0.24757281 ... 0.2961165  0.32524273 0.35436893]]

# %%
print(train_X, train_y)
# Out:
# [[[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]]
#
#  [[0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]]
#
#  [[0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]]
#
#  ...
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]]] [[0.79126215 0.8203884  0.8446602  ... 0.9126214  0.80097085 0.723301  ]
#  [0.8203884  0.8446602  0.8737864  ... 0.80097085 0.723301   0.66504854]
#  [0.8446602  0.8737864  0.89805824 ... 0.723301   0.66504854 0.61650485]
#  ...
#  [0.23786408 0.24271844 0.24757281 ... 0.27184466 0.27184466 0.2961165 ]
#  [0.24271844 0.24757281 0.24757281 ... 0.27184466 0.2961165  0.32524273]
#  [0.24757281 0.24757281 0.24757281 ... 0.2961165  0.32524273 0.35436893]]

# %%
print(train_X.shape, train_y.shape, val_X.shape, val_y.shape)
# Out:
# (3175, 1, 18) (3175, 12) (1588, 1, 18) (1588, 12)

# %%
randomState = 46
np.random.seed(randomState)
#tensorflow.random.set_random_seed(randomState)
tensorflow.random.set_seed(randomState)
model = Sequential()
model.add(LSTM(15,input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dense(22))
#model.add(Activation('relu'))    
model.add(Dense(out_hour,activation = "sigmoid"))
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.001)
#    opt=tensorflow.keras.optimizers.Adam(learning_rate=0.00075)
model.compile(loss='mae', optimizer=opt,metrics=['mse','mae',tensorflow.keras.metrics.RootMeanSquaredError()])
history = model.fit(train_X, train_y,validation_data=(val_X, val_y), epochs=500, batch_size=100,verbose=1,shuffle=False)
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)
# Out:
# Train on 3175 samples, validate on 1588 samples
# Epoch 1/500
# 3175/3175 [==============================] - 2s 600us/sample - loss: 0.2586 - mse: 0.0797 - mae: 0.2586 - root_mean_squared_error: 0.2822 - val_loss: 0.2737 - val_mse: 0.0919 - val_mae: 0.2737 - val_root_mean_squared_error: 0.3032
# Epoch 2/500
# 3175/3175 [==============================] - 0s 56us/sample - loss: 0.2456 - mse: 0.0727 - mae: 0.2456 - root_mean_squared_error: 0.2697 - val_loss: 0.2601 - val_mse: 0.0836 - val_mae: 0.2601 - val_root_mean_squared_error: 0.2892
# Epoch 3/500
# 3175/3175 [==============================] - 0s 57us/sample - loss: 0.2308 - mse: 0.0654 - mae: 0.2308 - root_mean_squared_error: 0.2557 - val_loss: 0.2441 - val_mse: 0.0746 - val_mae: 0.2441 - val_root_mean_squared_error: 0.2732
# Epoch 4/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.2141 - mse: 0.0580 - mae: 0.2141 - root_mean_squared_error: 0.2409 - val_loss: 0.2268 - val_mse: 0.0658 - val_mae: 0.2268 - val_root_mean_squared_error: 0.2566
# Epoch 5/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.1977 - mse: 0.0518 - mae: 0.1977 - root_mean_squared_error: 0.2276 - val_loss: 0.2107 - val_mse: 0.0584 - val_mae: 0.2107 - val_root_mean_squared_error: 0.2417
# Epoch 6/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.1835 - mse: 0.0472 - mae: 0.1835 - root_mean_squared_error: 0.2173 - val_loss: 0.1971 - val_mse: 0.0528 - val_mae: 0.1971 - val_root_mean_squared_error: 0.2298
# Epoch 7/500
# 3175/3175 [==============================] - 0s 53us/sample - loss: 0.1722 - mse: 0.0440 - mae: 0.1722 - root_mean_squared_error: 0.2098 - val_loss: 0.1862 - val_mse: 0.0486 - val_mae: 0.1862 - val_root_mean_squared_error: 0.2204
# Epoch 8/500
# 3175/3175 [==============================] - 0s 53us/sample - loss: 0.1632 - mse: 0.0415 - mae: 0.1632 - root_mean_squared_error: 0.2038 - val_loss: 0.1772 - val_mse: 0.0451 - val_mae: 0.1772 - val_root_mean_squared_error: 0.2124
# Epoch 9/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.1556 - mse: 0.0393 - mae: 0.1556 - root_mean_squared_error: 0.1983 - val_loss: 0.1694 - val_mse: 0.0421 - val_mae: 0.1694 - val_root_mean_squared_error: 0.2052
# Epoch 10/500
# 3175/3175 [==============================] - 0s 53us/sample - loss: 0.1489 - mse: 0.0372 - mae: 0.1489 - root_mean_squared_error: 0.1929 - val_loss: 0.1624 - val_mse: 0.0394 - val_mae: 0.1624 - val_root_mean_squared_error: 0.1986
# Epoch 11/500
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.1428 - mse: 0.0351 - mae: 0.1428 - root_mean_squared_error: 0.1874 - val_loss: 0.1560 - val_mse: 0.0369 - val_mae: 0.1560 - val_root_mean_squared_error: 0.1922
# Epoch 12/500
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.1372 - mse: 0.0331 - mae: 0.1372 - root_mean_squared_error: 0.1819 - val_loss: 0.1501 - val_mse: 0.0346 - val_mae: 0.1501 - val_root_mean_squared_error: 0.1861
# Epoch 13/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.1320 - mse: 0.0312 - mae: 0.1320 - root_mean_squared_error: 0.1766 - val_loss: 0.1446 - val_mse: 0.0325 - val_mae: 0.1446 - val_root_mean_squared_error: 0.1804
# Epoch 14/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.1272 - mse: 0.0295 - mae: 0.1272 - root_mean_squared_error: 0.1716 - val_loss: 0.1395 - val_mse: 0.0306 - val_mae: 0.1395 - val_root_mean_squared_error: 0.1751
# Epoch 15/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1229 - mse: 0.0278 - mae: 0.1229 - root_mean_squared_error: 0.1669 - val_loss: 0.1348 - val_mse: 0.0289 - val_mae: 0.1348 - val_root_mean_squared_error: 0.1701
# Epoch 16/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1189 - mse: 0.0264 - mae: 0.1189 - root_mean_squared_error: 0.1624 - val_loss: 0.1304 - val_mse: 0.0274 - val_mae: 0.1304 - val_root_mean_squared_error: 0.1655
# Epoch 17/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.1154 - mse: 0.0251 - mae: 0.1154 - root_mean_squared_error: 0.1583 - val_loss: 0.1264 - val_mse: 0.0260 - val_mae: 0.1264 - val_root_mean_squared_error: 0.1613
# Epoch 18/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1121 - mse: 0.0239 - mae: 0.1121 - root_mean_squared_error: 0.1545 - val_loss: 0.1226 - val_mse: 0.0248 - val_mae: 0.1226 - val_root_mean_squared_error: 0.1574
# Epoch 19/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1090 - mse: 0.0228 - mae: 0.1090 - root_mean_squared_error: 0.1509 - val_loss: 0.1191 - val_mse: 0.0237 - val_mae: 0.1191 - val_root_mean_squared_error: 0.1539
# Epoch 20/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1061 - mse: 0.0218 - mae: 0.1061 - root_mean_squared_error: 0.1476 - val_loss: 0.1157 - val_mse: 0.0227 - val_mae: 0.1157 - val_root_mean_squared_error: 0.1505
# Epoch 21/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1034 - mse: 0.0209 - mae: 0.1034 - root_mean_squared_error: 0.1445 - val_loss: 0.1125 - val_mse: 0.0217 - val_mae: 0.1125 - val_root_mean_squared_error: 0.1475
# Epoch 22/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1008 - mse: 0.0201 - mae: 0.1008 - root_mean_squared_error: 0.1416 - val_loss: 0.1094 - val_mse: 0.0209 - val_mae: 0.1094 - val_root_mean_squared_error: 0.1447
# Epoch 23/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0984 - mse: 0.0193 - mae: 0.0984 - root_mean_squared_error: 0.1391 - val_loss: 0.1066 - val_mse: 0.0202 - val_mae: 0.1066 - val_root_mean_squared_error: 0.1422
# Epoch 24/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0962 - mse: 0.0187 - mae: 0.0962 - root_mean_squared_error: 0.1368 - val_loss: 0.1039 - val_mse: 0.0196 - val_mae: 0.1039 - val_root_mean_squared_error: 0.1400
# Epoch 25/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0942 - mse: 0.0182 - mae: 0.0942 - root_mean_squared_error: 0.1348 - val_loss: 0.1014 - val_mse: 0.0191 - val_mae: 0.1014 - val_root_mean_squared_error: 0.1381
# Epoch 26/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0923 - mse: 0.0177 - mae: 0.0923 - root_mean_squared_error: 0.1331 - val_loss: 0.0991 - val_mse: 0.0186 - val_mae: 0.0991 - val_root_mean_squared_error: 0.1363
# Epoch 27/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0906 - mse: 0.0173 - mae: 0.0906 - root_mean_squared_error: 0.1316 - val_loss: 0.0970 - val_mse: 0.0182 - val_mae: 0.0970 - val_root_mean_squared_error: 0.1348
# Epoch 28/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0890 - mse: 0.0170 - mae: 0.0890 - root_mean_squared_error: 0.1302 - val_loss: 0.0951 - val_mse: 0.0178 - val_mae: 0.0951 - val_root_mean_squared_error: 0.1334
# Epoch 29/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0876 - mse: 0.0166 - mae: 0.0876 - root_mean_squared_error: 0.1290 - val_loss: 0.0934 - val_mse: 0.0175 - val_mae: 0.0934 - val_root_mean_squared_error: 0.1322
# Epoch 30/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0863 - mse: 0.0164 - mae: 0.0863 - root_mean_squared_error: 0.1280 - val_loss: 0.0919 - val_mse: 0.0172 - val_mae: 0.0919 - val_root_mean_squared_error: 0.1311
# Epoch 31/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0852 - mse: 0.0161 - mae: 0.0852 - root_mean_squared_error: 0.1271 - val_loss: 0.0905 - val_mse: 0.0169 - val_mae: 0.0905 - val_root_mean_squared_error: 0.1301
# Epoch 32/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0842 - mse: 0.0159 - mae: 0.0842 - root_mean_squared_error: 0.1262 - val_loss: 0.0892 - val_mse: 0.0167 - val_mae: 0.0892 - val_root_mean_squared_error: 0.1291
# Epoch 33/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0832 - mse: 0.0157 - mae: 0.0832 - root_mean_squared_error: 0.1254 - val_loss: 0.0880 - val_mse: 0.0164 - val_mae: 0.0880 - val_root_mean_squared_error: 0.1283
# Epoch 34/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0824 - mse: 0.0156 - mae: 0.0824 - root_mean_squared_error: 0.1247 - val_loss: 0.0870 - val_mse: 0.0162 - val_mae: 0.0870 - val_root_mean_squared_error: 0.1274
# Epoch 35/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0816 - mse: 0.0154 - mae: 0.0816 - root_mean_squared_error: 0.1241 - val_loss: 0.0860 - val_mse: 0.0161 - val_mae: 0.0860 - val_root_mean_squared_error: 0.1267
# Epoch 36/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0809 - mse: 0.0152 - mae: 0.0809 - root_mean_squared_error: 0.1234 - val_loss: 0.0851 - val_mse: 0.0159 - val_mae: 0.0851 - val_root_mean_squared_error: 0.1260
# Epoch 37/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0802 - mse: 0.0151 - mae: 0.0802 - root_mean_squared_error: 0.1229 - val_loss: 0.0843 - val_mse: 0.0157 - val_mae: 0.0843 - val_root_mean_squared_error: 0.1253
# Epoch 38/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0796 - mse: 0.0150 - mae: 0.0796 - root_mean_squared_error: 0.1223 - val_loss: 0.0835 - val_mse: 0.0156 - val_mae: 0.0835 - val_root_mean_squared_error: 0.1247
# Epoch 39/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0816 - mse: 0.0157 - mae: 0.0816 - root_mean_squared_error: 0.125 - 0s 27us/sample - loss: 0.0791 - mse: 0.0148 - mae: 0.0791 - root_mean_squared_error: 0.1218 - val_loss: 0.0828 - val_mse: 0.0154 - val_mae: 0.0828 - val_root_mean_squared_error: 0.1241
# Epoch 40/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0786 - mse: 0.0147 - mae: 0.0786 - root_mean_squared_error: 0.1214 - val_loss: 0.0821 - val_mse: 0.0153 - val_mae: 0.0821 - val_root_mean_squared_error: 0.1236
# Epoch 41/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0781 - mse: 0.0146 - mae: 0.0781 - root_mean_squared_error: 0.1209 - val_loss: 0.0815 - val_mse: 0.0152 - val_mae: 0.0815 - val_root_mean_squared_error: 0.1231
# Epoch 42/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0777 - mse: 0.0145 - mae: 0.0777 - root_mean_squared_error: 0.1205 - val_loss: 0.0810 - val_mse: 0.0150 - val_mae: 0.0810 - val_root_mean_squared_error: 0.1226
# Epoch 43/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0773 - mse: 0.0144 - mae: 0.0773 - root_mean_squared_error: 0.1202 - val_loss: 0.0805 - val_mse: 0.0149 - val_mae: 0.0805 - val_root_mean_squared_error: 0.1222
# Epoch 44/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0769 - mse: 0.0144 - mae: 0.0769 - root_mean_squared_error: 0.1198 - val_loss: 0.0800 - val_mse: 0.0148 - val_mae: 0.0800 - val_root_mean_squared_error: 0.1218
# Epoch 45/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0766 - mse: 0.0143 - mae: 0.0766 - root_mean_squared_error: 0.1195 - val_loss: 0.0796 - val_mse: 0.0148 - val_mae: 0.0796 - val_root_mean_squared_error: 0.1215
# Epoch 46/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0763 - mse: 0.0142 - mae: 0.0763 - root_mean_squared_error: 0.1193 - val_loss: 0.0792 - val_mse: 0.0147 - val_mae: 0.0792 - val_root_mean_squared_error: 0.1212
# Epoch 47/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0760 - mse: 0.0142 - mae: 0.0760 - root_mean_squared_error: 0.1190 - val_loss: 0.0788 - val_mse: 0.0146 - val_mae: 0.0788 - val_root_mean_squared_error: 0.1209
# Epoch 48/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0757 - mse: 0.0141 - mae: 0.0757 - root_mean_squared_error: 0.1188 - val_loss: 0.0785 - val_mse: 0.0145 - val_mae: 0.0785 - val_root_mean_squared_error: 0.1206
# Epoch 49/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0755 - mse: 0.0141 - mae: 0.0755 - root_mean_squared_error: 0.1186 - val_loss: 0.0781 - val_mse: 0.0145 - val_mae: 0.0781 - val_root_mean_squared_error: 0.1203
# Epoch 50/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0753 - mse: 0.0140 - mae: 0.0753 - root_mean_squared_error: 0.1184 - val_loss: 0.0778 - val_mse: 0.0144 - val_mae: 0.0778 - val_root_mean_squared_error: 0.1201
# Epoch 51/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0751 - mse: 0.0140 - mae: 0.0751 - root_mean_squared_error: 0.1182 - val_loss: 0.0775 - val_mse: 0.0144 - val_mae: 0.0775 - val_root_mean_squared_error: 0.1199
# Epoch 52/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0748 - mse: 0.0139 - mae: 0.0748 - root_mean_squared_error: 0.1180 - val_loss: 0.0773 - val_mse: 0.0143 - val_mae: 0.0773 - val_root_mean_squared_error: 0.1197
# Epoch 53/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0747 - mse: 0.0139 - mae: 0.0747 - root_mean_squared_error: 0.1179 - val_loss: 0.0770 - val_mse: 0.0143 - val_mae: 0.0770 - val_root_mean_squared_error: 0.1195
# Epoch 54/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0745 - mse: 0.0139 - mae: 0.0745 - root_mean_squared_error: 0.1177 - val_loss: 0.0768 - val_mse: 0.0142 - val_mae: 0.0768 - val_root_mean_squared_error: 0.1193
# Epoch 55/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0743 - mse: 0.0138 - mae: 0.0743 - root_mean_squared_error: 0.1176 - val_loss: 0.0766 - val_mse: 0.0142 - val_mae: 0.0766 - val_root_mean_squared_error: 0.1192
# Epoch 56/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0742 - mse: 0.0138 - mae: 0.0742 - root_mean_squared_error: 0.1174 - val_loss: 0.0763 - val_mse: 0.0142 - val_mae: 0.0763 - val_root_mean_squared_error: 0.1190
# Epoch 57/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0740 - mse: 0.0138 - mae: 0.0740 - root_mean_squared_error: 0.1173 - val_loss: 0.0761 - val_mse: 0.0141 - val_mae: 0.0761 - val_root_mean_squared_error: 0.1189
# Epoch 58/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0739 - mse: 0.0137 - mae: 0.0739 - root_mean_squared_error: 0.1172 - val_loss: 0.0760 - val_mse: 0.0141 - val_mae: 0.0760 - val_root_mean_squared_error: 0.1188
# Epoch 59/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0737 - mse: 0.0137 - mae: 0.0737 - root_mean_squared_error: 0.1171 - val_loss: 0.0758 - val_mse: 0.0141 - val_mae: 0.0758 - val_root_mean_squared_error: 0.1186
# Epoch 60/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0736 - mse: 0.0137 - mae: 0.0736 - root_mean_squared_error: 0.1170 - val_loss: 0.0756 - val_mse: 0.0140 - val_mae: 0.0756 - val_root_mean_squared_error: 0.1185
# Epoch 61/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0735 - mse: 0.0137 - mae: 0.0735 - root_mean_squared_error: 0.1169 - val_loss: 0.0754 - val_mse: 0.0140 - val_mae: 0.0754 - val_root_mean_squared_error: 0.1184
# Epoch 62/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0734 - mse: 0.0137 - mae: 0.0734 - root_mean_squared_error: 0.1168 - val_loss: 0.0753 - val_mse: 0.0140 - val_mae: 0.0753 - val_root_mean_squared_error: 0.1183
# Epoch 63/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0733 - mse: 0.0136 - mae: 0.0733 - root_mean_squared_error: 0.1167 - val_loss: 0.0751 - val_mse: 0.0140 - val_mae: 0.0751 - val_root_mean_squared_error: 0.1182
# Epoch 64/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0731 - mse: 0.0136 - mae: 0.0731 - root_mean_squared_error: 0.1167 - val_loss: 0.0750 - val_mse: 0.0139 - val_mae: 0.0750 - val_root_mean_squared_error: 0.1181
# Epoch 65/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0730 - mse: 0.0136 - mae: 0.0730 - root_mean_squared_error: 0.1166 - val_loss: 0.0748 - val_mse: 0.0139 - val_mae: 0.0748 - val_root_mean_squared_error: 0.1180
# Epoch 66/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0729 - mse: 0.0136 - mae: 0.0729 - root_mean_squared_error: 0.1165 - val_loss: 0.0747 - val_mse: 0.0139 - val_mae: 0.0747 - val_root_mean_squared_error: 0.1179
# Epoch 67/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0728 - mse: 0.0136 - mae: 0.0728 - root_mean_squared_error: 0.1164 - val_loss: 0.0745 - val_mse: 0.0139 - val_mae: 0.0745 - val_root_mean_squared_error: 0.1178
# Epoch 68/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0727 - mse: 0.0135 - mae: 0.0727 - root_mean_squared_error: 0.1163 - val_loss: 0.0744 - val_mse: 0.0139 - val_mae: 0.0744 - val_root_mean_squared_error: 0.1177
# Epoch 69/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0726 - mse: 0.0135 - mae: 0.0726 - root_mean_squared_error: 0.1163 - val_loss: 0.0743 - val_mse: 0.0138 - val_mae: 0.0743 - val_root_mean_squared_error: 0.1176
# Epoch 70/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0725 - mse: 0.0135 - mae: 0.0725 - root_mean_squared_error: 0.1162 - val_loss: 0.0742 - val_mse: 0.0138 - val_mae: 0.0742 - val_root_mean_squared_error: 0.1176
# Epoch 71/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0724 - mse: 0.0135 - mae: 0.0724 - root_mean_squared_error: 0.1161 - val_loss: 0.0740 - val_mse: 0.0138 - val_mae: 0.0740 - val_root_mean_squared_error: 0.1175
# Epoch 72/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0723 - mse: 0.0135 - mae: 0.0723 - root_mean_squared_error: 0.1160 - val_loss: 0.0739 - val_mse: 0.0138 - val_mae: 0.0739 - val_root_mean_squared_error: 0.1174
# Epoch 73/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0722 - mse: 0.0135 - mae: 0.0722 - root_mean_squared_error: 0.1160 - val_loss: 0.0738 - val_mse: 0.0138 - val_mae: 0.0738 - val_root_mean_squared_error: 0.1173
# Epoch 74/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0721 - mse: 0.0134 - mae: 0.0721 - root_mean_squared_error: 0.1159 - val_loss: 0.0737 - val_mse: 0.0137 - val_mae: 0.0737 - val_root_mean_squared_error: 0.1172
# Epoch 75/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0720 - mse: 0.0134 - mae: 0.0720 - root_mean_squared_error: 0.1158 - val_loss: 0.0736 - val_mse: 0.0137 - val_mae: 0.0736 - val_root_mean_squared_error: 0.1172
# Epoch 76/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0719 - mse: 0.0134 - mae: 0.0719 - root_mean_squared_error: 0.1158 - val_loss: 0.0735 - val_mse: 0.0137 - val_mae: 0.0735 - val_root_mean_squared_error: 0.1171
# Epoch 77/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0719 - mse: 0.0134 - mae: 0.0719 - root_mean_squared_error: 0.1157 - val_loss: 0.0734 - val_mse: 0.0137 - val_mae: 0.0734 - val_root_mean_squared_error: 0.1170
# Epoch 78/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0718 - mse: 0.0134 - mae: 0.0718 - root_mean_squared_error: 0.1156 - val_loss: 0.0733 - val_mse: 0.0137 - val_mae: 0.0733 - val_root_mean_squared_error: 0.1169
# Epoch 79/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0717 - mse: 0.0134 - mae: 0.0717 - root_mean_squared_error: 0.1156 - val_loss: 0.0731 - val_mse: 0.0137 - val_mae: 0.0731 - val_root_mean_squared_error: 0.1169
# Epoch 80/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0716 - mse: 0.0133 - mae: 0.0716 - root_mean_squared_error: 0.1155 - val_loss: 0.0730 - val_mse: 0.0136 - val_mae: 0.0730 - val_root_mean_squared_error: 0.1168
# Epoch 81/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0715 - mse: 0.0133 - mae: 0.0715 - root_mean_squared_error: 0.1155 - val_loss: 0.0729 - val_mse: 0.0136 - val_mae: 0.0729 - val_root_mean_squared_error: 0.1167
# Epoch 82/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0714 - mse: 0.0133 - mae: 0.0714 - root_mean_squared_error: 0.1154 - val_loss: 0.0728 - val_mse: 0.0136 - val_mae: 0.0728 - val_root_mean_squared_error: 0.1167
# Epoch 83/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0754 - mse: 0.0148 - mae: 0.0754 - root_mean_squared_error: 0.121 - 0s 28us/sample - loss: 0.0713 - mse: 0.0133 - mae: 0.0713 - root_mean_squared_error: 0.1153 - val_loss: 0.0727 - val_mse: 0.0136 - val_mae: 0.0727 - val_root_mean_squared_error: 0.1166
# Epoch 84/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0712 - mse: 0.0133 - mae: 0.0712 - root_mean_squared_error: 0.1153 - val_loss: 0.0726 - val_mse: 0.0136 - val_mae: 0.0726 - val_root_mean_squared_error: 0.1166
# Epoch 85/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0712 - mse: 0.0133 - mae: 0.0712 - root_mean_squared_error: 0.1152 - val_loss: 0.0725 - val_mse: 0.0136 - val_mae: 0.0725 - val_root_mean_squared_error: 0.1165
# Epoch 86/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0711 - mse: 0.0133 - mae: 0.0711 - root_mean_squared_error: 0.1152 - val_loss: 0.0724 - val_mse: 0.0136 - val_mae: 0.0724 - val_root_mean_squared_error: 0.1164
# Epoch 87/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0710 - mse: 0.0133 - mae: 0.0710 - root_mean_squared_error: 0.1151 - val_loss: 0.0723 - val_mse: 0.0135 - val_mae: 0.0723 - val_root_mean_squared_error: 0.1164
# Epoch 88/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0709 - mse: 0.0132 - mae: 0.0709 - root_mean_squared_error: 0.1151 - val_loss: 0.0722 - val_mse: 0.0135 - val_mae: 0.0722 - val_root_mean_squared_error: 0.1163
# Epoch 89/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0708 - mse: 0.0132 - mae: 0.0708 - root_mean_squared_error: 0.1150 - val_loss: 0.0721 - val_mse: 0.0135 - val_mae: 0.0721 - val_root_mean_squared_error: 0.1162
# Epoch 90/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0707 - mse: 0.0132 - mae: 0.0707 - root_mean_squared_error: 0.1149 - val_loss: 0.0720 - val_mse: 0.0135 - val_mae: 0.0720 - val_root_mean_squared_error: 0.1162
# Epoch 91/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0707 - mse: 0.0132 - mae: 0.0707 - root_mean_squared_error: 0.1149 - val_loss: 0.0719 - val_mse: 0.0135 - val_mae: 0.0719 - val_root_mean_squared_error: 0.1161
# Epoch 92/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0730 - mse: 0.0142 - mae: 0.0730 - root_mean_squared_error: 0.119 - 0s 28us/sample - loss: 0.0706 - mse: 0.0132 - mae: 0.0706 - root_mean_squared_error: 0.1148 - val_loss: 0.0718 - val_mse: 0.0135 - val_mae: 0.0718 - val_root_mean_squared_error: 0.1160
# Epoch 93/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0705 - mse: 0.0132 - mae: 0.0705 - root_mean_squared_error: 0.1147 - val_loss: 0.0717 - val_mse: 0.0135 - val_mae: 0.0717 - val_root_mean_squared_error: 0.1160
# Epoch 94/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0704 - mse: 0.0132 - mae: 0.0704 - root_mean_squared_error: 0.1147 - val_loss: 0.0716 - val_mse: 0.0134 - val_mae: 0.0716 - val_root_mean_squared_error: 0.1159
# Epoch 95/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0703 - mse: 0.0131 - mae: 0.0703 - root_mean_squared_error: 0.1146 - val_loss: 0.0716 - val_mse: 0.0134 - val_mae: 0.0716 - val_root_mean_squared_error: 0.1159
# Epoch 96/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0703 - mse: 0.0131 - mae: 0.0703 - root_mean_squared_error: 0.1146 - val_loss: 0.0715 - val_mse: 0.0134 - val_mae: 0.0715 - val_root_mean_squared_error: 0.1158
# Epoch 97/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0702 - mse: 0.0131 - mae: 0.0702 - root_mean_squared_error: 0.1145 - val_loss: 0.0714 - val_mse: 0.0134 - val_mae: 0.0714 - val_root_mean_squared_error: 0.1158
# Epoch 98/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0701 - mse: 0.0131 - mae: 0.0701 - root_mean_squared_error: 0.1145 - val_loss: 0.0713 - val_mse: 0.0134 - val_mae: 0.0713 - val_root_mean_squared_error: 0.1157
# Epoch 99/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0700 - mse: 0.0131 - mae: 0.0700 - root_mean_squared_error: 0.1144 - val_loss: 0.0712 - val_mse: 0.0134 - val_mae: 0.0712 - val_root_mean_squared_error: 0.1157
# Epoch 100/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0699 - mse: 0.0131 - mae: 0.0699 - root_mean_squared_error: 0.1144 - val_loss: 0.0711 - val_mse: 0.0134 - val_mae: 0.0711 - val_root_mean_squared_error: 0.1156
# Epoch 101/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0699 - mse: 0.0131 - mae: 0.0699 - root_mean_squared_error: 0.1143 - val_loss: 0.0710 - val_mse: 0.0134 - val_mae: 0.0710 - val_root_mean_squared_error: 0.1156
# Epoch 102/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0698 - mse: 0.0131 - mae: 0.0698 - root_mean_squared_error: 0.1143 - val_loss: 0.0709 - val_mse: 0.0133 - val_mae: 0.0709 - val_root_mean_squared_error: 0.1155
# Epoch 103/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0697 - mse: 0.0130 - mae: 0.0697 - root_mean_squared_error: 0.1142 - val_loss: 0.0708 - val_mse: 0.0133 - val_mae: 0.0708 - val_root_mean_squared_error: 0.1155
# Epoch 104/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0696 - mse: 0.0130 - mae: 0.0696 - root_mean_squared_error: 0.1142 - val_loss: 0.0707 - val_mse: 0.0133 - val_mae: 0.0707 - val_root_mean_squared_error: 0.1154
# Epoch 105/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0696 - mse: 0.0130 - mae: 0.0696 - root_mean_squared_error: 0.1141 - val_loss: 0.0706 - val_mse: 0.0133 - val_mae: 0.0706 - val_root_mean_squared_error: 0.1154
# Epoch 106/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0695 - mse: 0.0130 - mae: 0.0695 - root_mean_squared_error: 0.1141 - val_loss: 0.0705 - val_mse: 0.0133 - val_mae: 0.0705 - val_root_mean_squared_error: 0.1153
# Epoch 107/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0694 - mse: 0.0130 - mae: 0.0694 - root_mean_squared_error: 0.1140 - val_loss: 0.0705 - val_mse: 0.0133 - val_mae: 0.0705 - val_root_mean_squared_error: 0.1153
# Epoch 108/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0694 - mse: 0.0130 - mae: 0.0694 - root_mean_squared_error: 0.1140 - val_loss: 0.0704 - val_mse: 0.0133 - val_mae: 0.0704 - val_root_mean_squared_error: 0.1152
# Epoch 109/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0711 - mse: 0.0137 - mae: 0.0711 - root_mean_squared_error: 0.117 - 0s 26us/sample - loss: 0.0693 - mse: 0.0130 - mae: 0.0693 - root_mean_squared_error: 0.1139 - val_loss: 0.0703 - val_mse: 0.0133 - val_mae: 0.0703 - val_root_mean_squared_error: 0.1152
# Epoch 110/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0692 - mse: 0.0130 - mae: 0.0692 - root_mean_squared_error: 0.1139 - val_loss: 0.0702 - val_mse: 0.0133 - val_mae: 0.0702 - val_root_mean_squared_error: 0.1151
# Epoch 111/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0692 - mse: 0.0130 - mae: 0.0692 - root_mean_squared_error: 0.1139 - val_loss: 0.0701 - val_mse: 0.0132 - val_mae: 0.0701 - val_root_mean_squared_error: 0.1151
# Epoch 112/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0691 - mse: 0.0130 - mae: 0.0691 - root_mean_squared_error: 0.1138 - val_loss: 0.0701 - val_mse: 0.0132 - val_mae: 0.0701 - val_root_mean_squared_error: 0.1151
# Epoch 113/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0691 - mse: 0.0129 - mae: 0.0691 - root_mean_squared_error: 0.1138 - val_loss: 0.0700 - val_mse: 0.0132 - val_mae: 0.0700 - val_root_mean_squared_error: 0.1150
# Epoch 114/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0690 - mse: 0.0129 - mae: 0.0690 - root_mean_squared_error: 0.1137 - val_loss: 0.0699 - val_mse: 0.0132 - val_mae: 0.0699 - val_root_mean_squared_error: 0.1150
# Epoch 115/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0689 - mse: 0.0129 - mae: 0.0689 - root_mean_squared_error: 0.1137 - val_loss: 0.0699 - val_mse: 0.0132 - val_mae: 0.0699 - val_root_mean_squared_error: 0.1149
# Epoch 116/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0689 - mse: 0.0129 - mae: 0.0689 - root_mean_squared_error: 0.1136 - val_loss: 0.0698 - val_mse: 0.0132 - val_mae: 0.0698 - val_root_mean_squared_error: 0.1149
# Epoch 117/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0688 - mse: 0.0129 - mae: 0.0688 - root_mean_squared_error: 0.1136 - val_loss: 0.0697 - val_mse: 0.0132 - val_mae: 0.0697 - val_root_mean_squared_error: 0.1149
# Epoch 118/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0688 - mse: 0.0129 - mae: 0.0688 - root_mean_squared_error: 0.1136 - val_loss: 0.0696 - val_mse: 0.0132 - val_mae: 0.0696 - val_root_mean_squared_error: 0.1148
# Epoch 119/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0687 - mse: 0.0129 - mae: 0.0687 - root_mean_squared_error: 0.1135 - val_loss: 0.0696 - val_mse: 0.0132 - val_mae: 0.0696 - val_root_mean_squared_error: 0.1148
# Epoch 120/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0687 - mse: 0.0129 - mae: 0.0687 - root_mean_squared_error: 0.1135 - val_loss: 0.0695 - val_mse: 0.0132 - val_mae: 0.0695 - val_root_mean_squared_error: 0.1148
# Epoch 121/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0686 - mse: 0.0129 - mae: 0.0686 - root_mean_squared_error: 0.1134 - val_loss: 0.0695 - val_mse: 0.0132 - val_mae: 0.0695 - val_root_mean_squared_error: 0.1147
# Epoch 122/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0686 - mse: 0.0129 - mae: 0.0686 - root_mean_squared_error: 0.1134 - val_loss: 0.0694 - val_mse: 0.0132 - val_mae: 0.0694 - val_root_mean_squared_error: 0.1147
# Epoch 123/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0685 - mse: 0.0129 - mae: 0.0685 - root_mean_squared_error: 0.1134 - val_loss: 0.0693 - val_mse: 0.0132 - val_mae: 0.0693 - val_root_mean_squared_error: 0.1147
# Epoch 124/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0685 - mse: 0.0128 - mae: 0.0685 - root_mean_squared_error: 0.1133 - val_loss: 0.0693 - val_mse: 0.0131 - val_mae: 0.0693 - val_root_mean_squared_error: 0.1147
# Epoch 125/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0684 - mse: 0.0128 - mae: 0.0684 - root_mean_squared_error: 0.1133 - val_loss: 0.0692 - val_mse: 0.0131 - val_mae: 0.0692 - val_root_mean_squared_error: 0.1146
# Epoch 126/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0684 - mse: 0.0128 - mae: 0.0684 - root_mean_squared_error: 0.1133 - val_loss: 0.0692 - val_mse: 0.0131 - val_mae: 0.0692 - val_root_mean_squared_error: 0.1146
# Epoch 127/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0683 - mse: 0.0128 - mae: 0.0683 - root_mean_squared_error: 0.1132 - val_loss: 0.0691 - val_mse: 0.0131 - val_mae: 0.0691 - val_root_mean_squared_error: 0.1146
# Epoch 128/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0683 - mse: 0.0128 - mae: 0.0683 - root_mean_squared_error: 0.1132 - val_loss: 0.0691 - val_mse: 0.0131 - val_mae: 0.0691 - val_root_mean_squared_error: 0.1146
# Epoch 129/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0682 - mse: 0.0128 - mae: 0.0682 - root_mean_squared_error: 0.1132 - val_loss: 0.0690 - val_mse: 0.0131 - val_mae: 0.0690 - val_root_mean_squared_error: 0.1145
# Epoch 130/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0682 - mse: 0.0128 - mae: 0.0682 - root_mean_squared_error: 0.1131 - val_loss: 0.0690 - val_mse: 0.0131 - val_mae: 0.0690 - val_root_mean_squared_error: 0.1145
# Epoch 131/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0681 - mse: 0.0128 - mae: 0.0681 - root_mean_squared_error: 0.1131 - val_loss: 0.0689 - val_mse: 0.0131 - val_mae: 0.0689 - val_root_mean_squared_error: 0.1145
# Epoch 132/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0681 - mse: 0.0128 - mae: 0.0681 - root_mean_squared_error: 0.1131 - val_loss: 0.0689 - val_mse: 0.0131 - val_mae: 0.0689 - val_root_mean_squared_error: 0.1145
# Epoch 133/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0680 - mse: 0.0128 - mae: 0.0680 - root_mean_squared_error: 0.1130 - val_loss: 0.0688 - val_mse: 0.0131 - val_mae: 0.0688 - val_root_mean_squared_error: 0.1144
# Epoch 134/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0680 - mse: 0.0128 - mae: 0.0680 - root_mean_squared_error: 0.1130 - val_loss: 0.0688 - val_mse: 0.0131 - val_mae: 0.0688 - val_root_mean_squared_error: 0.1144
# Epoch 135/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0680 - mse: 0.0128 - mae: 0.0680 - root_mean_squared_error: 0.1130 - val_loss: 0.0687 - val_mse: 0.0131 - val_mae: 0.0687 - val_root_mean_squared_error: 0.1144
# Epoch 136/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0679 - mse: 0.0128 - mae: 0.0679 - root_mean_squared_error: 0.1129 - val_loss: 0.0687 - val_mse: 0.0131 - val_mae: 0.0687 - val_root_mean_squared_error: 0.1143
# Epoch 137/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0679 - mse: 0.0127 - mae: 0.0679 - root_mean_squared_error: 0.1129 - val_loss: 0.0686 - val_mse: 0.0131 - val_mae: 0.0686 - val_root_mean_squared_error: 0.1143
# Epoch 138/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0678 - mse: 0.0127 - mae: 0.0678 - root_mean_squared_error: 0.1129 - val_loss: 0.0686 - val_mse: 0.0131 - val_mae: 0.0686 - val_root_mean_squared_error: 0.1143
# Epoch 139/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0678 - mse: 0.0127 - mae: 0.0678 - root_mean_squared_error: 0.1128 - val_loss: 0.0685 - val_mse: 0.0131 - val_mae: 0.0685 - val_root_mean_squared_error: 0.1143
# Epoch 140/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0678 - mse: 0.0127 - mae: 0.0678 - root_mean_squared_error: 0.1128 - val_loss: 0.0685 - val_mse: 0.0131 - val_mae: 0.0685 - val_root_mean_squared_error: 0.1143
# Epoch 141/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0677 - mse: 0.0127 - mae: 0.0677 - root_mean_squared_error: 0.1128 - val_loss: 0.0685 - val_mse: 0.0130 - val_mae: 0.0685 - val_root_mean_squared_error: 0.1142
# Epoch 142/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0677 - mse: 0.0127 - mae: 0.0677 - root_mean_squared_error: 0.1127 - val_loss: 0.0684 - val_mse: 0.0130 - val_mae: 0.0684 - val_root_mean_squared_error: 0.1142
# Epoch 143/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0677 - mse: 0.0127 - mae: 0.0677 - root_mean_squared_error: 0.1127 - val_loss: 0.0684 - val_mse: 0.0130 - val_mae: 0.0684 - val_root_mean_squared_error: 0.1142
# Epoch 144/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0676 - mse: 0.0127 - mae: 0.0676 - root_mean_squared_error: 0.1127 - val_loss: 0.0684 - val_mse: 0.0130 - val_mae: 0.0684 - val_root_mean_squared_error: 0.1142
# Epoch 145/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0676 - mse: 0.0127 - mae: 0.0676 - root_mean_squared_error: 0.1126 - val_loss: 0.0683 - val_mse: 0.0130 - val_mae: 0.0683 - val_root_mean_squared_error: 0.1141
# Epoch 146/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0675 - mse: 0.0127 - mae: 0.0675 - root_mean_squared_error: 0.1126 - val_loss: 0.0683 - val_mse: 0.0130 - val_mae: 0.0683 - val_root_mean_squared_error: 0.1141
# Epoch 147/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0711 - mse: 0.0141 - mae: 0.0711 - root_mean_squared_error: 0.118 - 0s 28us/sample - loss: 0.0675 - mse: 0.0127 - mae: 0.0675 - root_mean_squared_error: 0.1126 - val_loss: 0.0682 - val_mse: 0.0130 - val_mae: 0.0682 - val_root_mean_squared_error: 0.1141
# Epoch 148/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0675 - mse: 0.0127 - mae: 0.0675 - root_mean_squared_error: 0.1126 - val_loss: 0.0682 - val_mse: 0.0130 - val_mae: 0.0682 - val_root_mean_squared_error: 0.1141
# Epoch 149/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0674 - mse: 0.0127 - mae: 0.0674 - root_mean_squared_error: 0.1125 - val_loss: 0.0682 - val_mse: 0.0130 - val_mae: 0.0682 - val_root_mean_squared_error: 0.1141
# Epoch 150/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0674 - mse: 0.0127 - mae: 0.0674 - root_mean_squared_error: 0.1125 - val_loss: 0.0681 - val_mse: 0.0130 - val_mae: 0.0681 - val_root_mean_squared_error: 0.1141
# Epoch 151/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0674 - mse: 0.0126 - mae: 0.0674 - root_mean_squared_error: 0.1125 - val_loss: 0.0681 - val_mse: 0.0130 - val_mae: 0.0681 - val_root_mean_squared_error: 0.1140
# Epoch 152/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0709 - mse: 0.0140 - mae: 0.0709 - root_mean_squared_error: 0.118 - 0s 28us/sample - loss: 0.0674 - mse: 0.0126 - mae: 0.0674 - root_mean_squared_error: 0.1124 - val_loss: 0.0681 - val_mse: 0.0130 - val_mae: 0.0681 - val_root_mean_squared_error: 0.1140
# Epoch 153/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0673 - mse: 0.0126 - mae: 0.0673 - root_mean_squared_error: 0.1124 - val_loss: 0.0681 - val_mse: 0.0130 - val_mae: 0.0681 - val_root_mean_squared_error: 0.1140
# Epoch 154/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0673 - mse: 0.0126 - mae: 0.0673 - root_mean_squared_error: 0.1124 - val_loss: 0.0680 - val_mse: 0.0130 - val_mae: 0.0680 - val_root_mean_squared_error: 0.1140
# Epoch 155/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0673 - mse: 0.0126 - mae: 0.0673 - root_mean_squared_error: 0.1124 - val_loss: 0.0680 - val_mse: 0.0130 - val_mae: 0.0680 - val_root_mean_squared_error: 0.1140
# Epoch 156/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0672 - mse: 0.0126 - mae: 0.0672 - root_mean_squared_error: 0.1123 - val_loss: 0.0680 - val_mse: 0.0130 - val_mae: 0.0680 - val_root_mean_squared_error: 0.1140
# Epoch 157/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0672 - mse: 0.0126 - mae: 0.0672 - root_mean_squared_error: 0.1123 - val_loss: 0.0679 - val_mse: 0.0130 - val_mae: 0.0679 - val_root_mean_squared_error: 0.1140
# Epoch 158/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0672 - mse: 0.0126 - mae: 0.0672 - root_mean_squared_error: 0.1123 - val_loss: 0.0679 - val_mse: 0.0130 - val_mae: 0.0679 - val_root_mean_squared_error: 0.1139
# Epoch 159/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0671 - mse: 0.0126 - mae: 0.0671 - root_mean_squared_error: 0.1123 - val_loss: 0.0679 - val_mse: 0.0130 - val_mae: 0.0679 - val_root_mean_squared_error: 0.1139
# Epoch 160/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0671 - mse: 0.0126 - mae: 0.0671 - root_mean_squared_error: 0.1122 - val_loss: 0.0678 - val_mse: 0.0130 - val_mae: 0.0678 - val_root_mean_squared_error: 0.1139
# Epoch 161/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0671 - mse: 0.0126 - mae: 0.0671 - root_mean_squared_error: 0.1122 - val_loss: 0.0678 - val_mse: 0.0130 - val_mae: 0.0678 - val_root_mean_squared_error: 0.1139
# Epoch 162/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0671 - mse: 0.0126 - mae: 0.0671 - root_mean_squared_error: 0.1122 - val_loss: 0.0678 - val_mse: 0.0130 - val_mae: 0.0678 - val_root_mean_squared_error: 0.1139
# Epoch 163/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0670 - mse: 0.0126 - mae: 0.0670 - root_mean_squared_error: 0.1122 - val_loss: 0.0678 - val_mse: 0.0130 - val_mae: 0.0678 - val_root_mean_squared_error: 0.1139
# Epoch 164/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0670 - mse: 0.0126 - mae: 0.0670 - root_mean_squared_error: 0.1122 - val_loss: 0.0677 - val_mse: 0.0130 - val_mae: 0.0677 - val_root_mean_squared_error: 0.1139
# Epoch 165/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0670 - mse: 0.0126 - mae: 0.0670 - root_mean_squared_error: 0.1121 - val_loss: 0.0677 - val_mse: 0.0130 - val_mae: 0.0677 - val_root_mean_squared_error: 0.1139
# Epoch 166/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0669 - mse: 0.0126 - mae: 0.0669 - root_mean_squared_error: 0.1121 - val_loss: 0.0677 - val_mse: 0.0130 - val_mae: 0.0677 - val_root_mean_squared_error: 0.1138
# Epoch 167/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0669 - mse: 0.0126 - mae: 0.0669 - root_mean_squared_error: 0.1121 - val_loss: 0.0677 - val_mse: 0.0130 - val_mae: 0.0677 - val_root_mean_squared_error: 0.1138
# Epoch 168/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0669 - mse: 0.0126 - mae: 0.0669 - root_mean_squared_error: 0.1121 - val_loss: 0.0676 - val_mse: 0.0130 - val_mae: 0.0676 - val_root_mean_squared_error: 0.1138
# Epoch 169/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0669 - mse: 0.0126 - mae: 0.0669 - root_mean_squared_error: 0.1121 - val_loss: 0.0676 - val_mse: 0.0130 - val_mae: 0.0676 - val_root_mean_squared_error: 0.1138
# Epoch 170/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0668 - mse: 0.0126 - mae: 0.0668 - root_mean_squared_error: 0.1120 - val_loss: 0.0676 - val_mse: 0.0129 - val_mae: 0.0676 - val_root_mean_squared_error: 0.1138
# Epoch 171/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0668 - mse: 0.0125 - mae: 0.0668 - root_mean_squared_error: 0.1120 - val_loss: 0.0676 - val_mse: 0.0129 - val_mae: 0.0676 - val_root_mean_squared_error: 0.1138
# Epoch 172/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0668 - mse: 0.0125 - mae: 0.0668 - root_mean_squared_error: 0.1120 - val_loss: 0.0675 - val_mse: 0.0129 - val_mae: 0.0675 - val_root_mean_squared_error: 0.1138
# Epoch 173/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0668 - mse: 0.0125 - mae: 0.0668 - root_mean_squared_error: 0.1120 - val_loss: 0.0675 - val_mse: 0.0129 - val_mae: 0.0675 - val_root_mean_squared_error: 0.1138
# Epoch 174/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0667 - mse: 0.0125 - mae: 0.0667 - root_mean_squared_error: 0.1119 - val_loss: 0.0675 - val_mse: 0.0129 - val_mae: 0.0675 - val_root_mean_squared_error: 0.1137
# Epoch 175/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0667 - mse: 0.0125 - mae: 0.0667 - root_mean_squared_error: 0.1119 - val_loss: 0.0675 - val_mse: 0.0129 - val_mae: 0.0675 - val_root_mean_squared_error: 0.1137
# Epoch 176/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0667 - mse: 0.0125 - mae: 0.0667 - root_mean_squared_error: 0.1119 - val_loss: 0.0675 - val_mse: 0.0129 - val_mae: 0.0675 - val_root_mean_squared_error: 0.1137
# Epoch 177/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0667 - mse: 0.0125 - mae: 0.0667 - root_mean_squared_error: 0.1119 - val_loss: 0.0674 - val_mse: 0.0129 - val_mae: 0.0674 - val_root_mean_squared_error: 0.1137
# Epoch 178/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0667 - mse: 0.0125 - mae: 0.0667 - root_mean_squared_error: 0.1118 - val_loss: 0.0674 - val_mse: 0.0129 - val_mae: 0.0674 - val_root_mean_squared_error: 0.1137
# Epoch 179/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0666 - mse: 0.0125 - mae: 0.0666 - root_mean_squared_error: 0.1118 - val_loss: 0.0674 - val_mse: 0.0129 - val_mae: 0.0674 - val_root_mean_squared_error: 0.1137
# Epoch 180/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0666 - mse: 0.0125 - mae: 0.0666 - root_mean_squared_error: 0.1118 - val_loss: 0.0674 - val_mse: 0.0129 - val_mae: 0.0674 - val_root_mean_squared_error: 0.1136
# Epoch 181/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0666 - mse: 0.0125 - mae: 0.0666 - root_mean_squared_error: 0.1118 - val_loss: 0.0673 - val_mse: 0.0129 - val_mae: 0.0673 - val_root_mean_squared_error: 0.1136
# Epoch 182/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0666 - mse: 0.0125 - mae: 0.0666 - root_mean_squared_error: 0.1117 - val_loss: 0.0673 - val_mse: 0.0129 - val_mae: 0.0673 - val_root_mean_squared_error: 0.1136
# Epoch 183/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0666 - mse: 0.0125 - mae: 0.0666 - root_mean_squared_error: 0.1117 - val_loss: 0.0673 - val_mse: 0.0129 - val_mae: 0.0673 - val_root_mean_squared_error: 0.1136
# Epoch 184/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0665 - mse: 0.0125 - mae: 0.0665 - root_mean_squared_error: 0.1117 - val_loss: 0.0673 - val_mse: 0.0129 - val_mae: 0.0673 - val_root_mean_squared_error: 0.1136
# Epoch 185/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0665 - mse: 0.0125 - mae: 0.0665 - root_mean_squared_error: 0.1117 - val_loss: 0.0673 - val_mse: 0.0129 - val_mae: 0.0673 - val_root_mean_squared_error: 0.1136
# Epoch 186/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0665 - mse: 0.0125 - mae: 0.0665 - root_mean_squared_error: 0.1116 - val_loss: 0.0672 - val_mse: 0.0129 - val_mae: 0.0672 - val_root_mean_squared_error: 0.1136
# Epoch 187/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0665 - mse: 0.0125 - mae: 0.0665 - root_mean_squared_error: 0.1116 - val_loss: 0.0672 - val_mse: 0.0129 - val_mae: 0.0672 - val_root_mean_squared_error: 0.1135
# Epoch 188/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0664 - mse: 0.0124 - mae: 0.0664 - root_mean_squared_error: 0.1116 - val_loss: 0.0672 - val_mse: 0.0129 - val_mae: 0.0672 - val_root_mean_squared_error: 0.1135
# Epoch 189/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0664 - mse: 0.0124 - mae: 0.0664 - root_mean_squared_error: 0.1116 - val_loss: 0.0672 - val_mse: 0.0129 - val_mae: 0.0672 - val_root_mean_squared_error: 0.1135
# Epoch 190/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0664 - mse: 0.0124 - mae: 0.0664 - root_mean_squared_error: 0.1115 - val_loss: 0.0672 - val_mse: 0.0129 - val_mae: 0.0672 - val_root_mean_squared_error: 0.1135
# Epoch 191/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0664 - mse: 0.0124 - mae: 0.0664 - root_mean_squared_error: 0.1115 - val_loss: 0.0671 - val_mse: 0.0129 - val_mae: 0.0671 - val_root_mean_squared_error: 0.1135
# Epoch 192/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0664 - mse: 0.0124 - mae: 0.0664 - root_mean_squared_error: 0.1115 - val_loss: 0.0671 - val_mse: 0.0129 - val_mae: 0.0671 - val_root_mean_squared_error: 0.1135
# Epoch 193/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0663 - mse: 0.0124 - mae: 0.0663 - root_mean_squared_error: 0.1115 - val_loss: 0.0671 - val_mse: 0.0129 - val_mae: 0.0671 - val_root_mean_squared_error: 0.1135
# Epoch 194/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0663 - mse: 0.0124 - mae: 0.0663 - root_mean_squared_error: 0.1114 - val_loss: 0.0671 - val_mse: 0.0129 - val_mae: 0.0671 - val_root_mean_squared_error: 0.1135
# Epoch 195/500
# ...
# Epoch 437/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0643 - mse: 0.0120 - mae: 0.0643 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 438/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0643 - mse: 0.0120 - mae: 0.0643 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 439/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0643 - mse: 0.0120 - mae: 0.0643 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 440/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0643 - mse: 0.0120 - mae: 0.0643 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 441/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0643 - mse: 0.0120 - mae: 0.0643 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 442/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0643 - mse: 0.0120 - mae: 0.0643 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 443/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0643 - mse: 0.0120 - mae: 0.0643 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 444/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 445/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 446/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 447/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 448/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 449/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 450/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 451/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 452/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 453/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 454/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 455/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 456/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 457/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1096 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 458/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1095 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 459/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1095 - val_loss: 0.0652 - val_mse: 0.0128 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1131
# Epoch 460/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 461/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 462/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0679 - mse: 0.0136 - mae: 0.0679 - root_mean_squared_error: 0.116 - 0s 31us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 463/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 464/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 465/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 466/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 467/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 468/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 469/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 470/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 471/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 472/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0642 - mse: 0.0120 - mae: 0.0642 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 473/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 474/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 475/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 476/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 477/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 478/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 479/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 480/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 481/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 482/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 483/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 484/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 485/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 486/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 487/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 488/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 489/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 490/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 491/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 492/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0686 - mse: 0.0137 - mae: 0.0686 - root_mean_squared_error: 0.117 - 0s 31us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 493/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1095 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 494/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1094 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 495/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1094 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 496/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1094 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 497/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1094 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 498/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1094 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 499/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1094 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131
# Epoch 500/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0641 - mse: 0.0120 - mae: 0.0641 - root_mean_squared_error: 0.1094 - val_loss: 0.0651 - val_mse: 0.0128 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1131

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mae'],label='train mae')
pyplot.plot(history.history['val_mae'],label='val mae')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mse'],label='train mse')
pyplot.plot(history.history['val_mse'],label='val mse')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['root_mean_squared_error'],label='train rmse')
pyplot.plot(history.history['val_root_mean_squared_error'],label='val rmse')
pyplot.legend()
pyplot.show()
# Out:
# The testing MAE loss is: 0.0648258
# The testing MSE loss is: 0.012514333
# The testing RMSE loss is: 0.11186749

# %%
pyplot.plot(test_y[:,11],color='red', label='True Values')
pyplot.plot(out[:,11],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()

# %%
dataset_test=pd.read_excel('F:\MS thesis data/Hopper Crossing.xlsx')
dataset_test=dataset_test.drop(['Date/Time','Flowd'],axis=1)
dataset_test.dropna(inplace=True)

# %%
shape=np.shape(dataset_test)
print(shape)
pyplot.plot(dataset_test)
# Out:
# (26285, 3)
# [<matplotlib.lines.Line2D at 0x1cb12c0d308>,
#  <matplotlib.lines.Line2D at 0x1cb12c0d688>,
#  <matplotlib.lines.Line2D at 0x1cb12c0d988>]

# %%
dataset_test
# Out:
#        Cumulative rainfall   Flow  Level
# 0                      0.0  0.093    1.50
# 1                      0.0  0.093    1.50
# 2                      0.0  0.093    1.50
# 3                      0.0  0.093    1.50
# 4                      0.0  0.093    1.50
# ...                    ...    ...     ...
# 26280                  0.2  0.080    1.49
# 26281                  0.2  0.080    1.49
# 26282                  0.2  0.080    1.49
# 26283                  0.2  0.080    1.49
# 26284                  0.2  0.080    1.49
#
# [26285 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset_test)))
# Out:
# The std of original data is Cumulative rainfall    2.451640
# Flow                   0.520832
# Level                  0.083204
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset_test=dataset_test.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset_test.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset_test[:,0]== maxi[0])
    ind2=np.argwhere(dataset_test[:,1]== maxi[1])
    ind3=np.argwhere(dataset_test[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset_test.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset_test[:,0]== mini[0])
    ind2=np.argwhere(dataset_test[:,1]== mini[1])
    ind3=np.argwhere(dataset_test[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset_test)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset_test = min_max_scaler.fit_transform(dataset_test)
# Out:
# The std of cleaned data is 1.5154548293543502

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=12
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values

#one hour
#test_X, test_y = values[:, :-out_hour], values[:,-1]


test_X, test_y = values[:, :-out_hour], values[:, -out_hour: ]


test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6334, 54)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var3(t+2)  var3(t+3)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.844660   0.873786
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.873786   0.898058
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.898058   0.932039
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.932039   0.966019
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.966019   1.000000
#
#     var3(t+4)  var3(t+5)  var3(t+6)  var3(t+7)  var3(t+8)  var3(t+9)  \
# 6    0.898058   0.932039   0.966019   1.000000   0.941748   0.912621
# 7    0.932039   0.966019   1.000000   0.941748   0.912621   0.800971
# 8    0.966019   1.000000   0.941748   0.912621   0.800971   0.723301
# 9    1.000000   0.941748   0.912621   0.800971   0.723301   0.665049
# 10   0.941748   0.912621   0.800971   0.723301   0.665049   0.616505
#
#     var3(t+10)  var3(t+11)
# 6     0.800971    0.723301
# 7     0.723301    0.665049
# 8     0.665049    0.616505
# 9     0.616505    0.572816
# 10    0.572816    0.548544
#
# [5 rows x 30 columns]

# %%
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
# Out:
# The testing MAE loss is: 0.064442754
# The testing MSE loss is: 0.012291098
# The testing RMSE loss is: 0.110865206

# %%
pyplot.plot(test_y[:,11],color='red', label='True Values')
pyplot.plot(out[:,11],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()
