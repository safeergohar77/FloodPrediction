# %%
import pandas as pd
from pandas import concat
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from sklearn import preprocessing
from tensorflow.keras import backend as K
#from sklearn.preprocessing import MinMaxScaler
#from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input, Dense, LSTM,GRU,SimpleRNN, Activation
from matplotlib import pyplot
#from sklearn.model_selection import train_test_split

# %%
"# convert series to supervised learning\n" 
#windowing of data
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1),
    for i in range(n_in, 0, -1): #startes from n_in and decreses to 0 by decreasing each time -1
     cols.append(df.shift(i))
     names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
     cols.append(df.shift(-i))
     if i == 0:
       names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
     else:
       names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together\n",
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values\n",
    if dropnan:
      agg.dropna(inplace=True)
    return agg

# %%
#def root_mean_squared_error(y_true, y_pred):
 #       return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
dataset1=pd.read_excel('F:\MS thesis data/Brooklyn.xlsx')
dataset1=dataset1.drop(['Date/Time','Flowd'],axis=1)
dataset1.dropna(inplace=True)

# %%
shape=np.shape(dataset1)
print(shape)
pyplot.plot(dataset1)
# Out:
# (26302, 3)
# [<matplotlib.lines.Line2D at 0x223500ebcc8>,
#  <matplotlib.lines.Line2D at 0x223500e3308>,
#  <matplotlib.lines.Line2D at 0x223500e2a48>]

# %%
dataset1
# Out:
#        Cumulative rainfall    Flow  Level
# 0                       0.0  0.172   0.352
# 1                       0.0  0.180   0.356
# 2                       0.0  0.180   0.356
# 3                       0.0  0.189   0.360
# 4                       0.0  0.189   0.360
# ...                     ...    ...     ...
# 26297                   0.0  0.025   0.232
# 26298                   0.0  0.023   0.228
# 26299                   0.0  0.023   0.228
# 26300                   0.0  0.023   0.228
# 26301                   0.0  0.023   0.228
#
# [26302 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset1)))
# Out:
# The std of original data is Cumulative rainfall     2.872616
# Flow                    1.306642
# Level                   0.147238
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset=dataset1.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset[:,0]== maxi[0])
    ind2=np.argwhere(dataset[:,1]== maxi[1])
    ind3=np.argwhere(dataset[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset[:,0]== mini[0])
    ind2=np.argwhere(dataset[:,1]== mini[1])
    ind3=np.argwhere(dataset[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset = min_max_scaler.fit_transform(dataset)
# Out:
# The std of cleaned data is 1.626639593959813

# %%
pyplot.plot(dataset)
# Out:
# [<matplotlib.lines.Line2D at 0x2234f924708>,
#  <matplotlib.lines.Line2D at 0x2234f72a6c8>,
#  <matplotlib.lines.Line2D at 0x2234f72a888>]

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=5
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values
train_size  = int(len(dataset) * 0.50)
val_size=int(len(dataset) * 0.75)
train_X, train_y = values[0:train_size, :-out_hour], values[0:train_size,-out_hour: ]
val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-out_hour: ]
test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-out_hour:]
#for last hour
#train_X, train_y = values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]  #for only last hour
#val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]
#test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-1]
print(train_X, train_y)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6341, 33)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var2(t-2)  var3(t-2)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.524545   0.776699
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.524545   0.776699
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.549980   0.791262
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.603309   0.820388
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.650485   0.844660
#
#     var1(t-1)  var2(t-1)  var3(t-1)   var3(t)  var3(t+1)  var3(t+2)  \
# 6    0.215385   0.524545   0.776699  0.791262   0.820388   0.844660
# 7    0.123077   0.549980   0.791262  0.820388   0.844660   0.873786
# 8    0.092308   0.603309   0.820388  0.844660   0.873786   0.898058
# 9    0.092308   0.650485   0.844660  0.873786   0.898058   0.932039
# 10   0.092308   0.709285   0.873786  0.898058   0.932039   0.966019
#
#     var3(t+3)  var3(t+4)
# 6    0.873786   0.898058
# 7    0.898058   0.932039
# 8    0.932039   0.966019
# 9    0.966019   1.000000
# 10   1.000000   0.941748
#
# [5 rows x 23 columns]
# [[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]
#  [0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]
#  [0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]
#  ...
#  [0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]
#  [0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]
#  [0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]] [[0.79126215 0.8203884  0.8446602  0.8737864  0.89805824]
#  [0.8203884  0.8446602  0.8737864  0.89805824 0.93203884]
#  [0.8446602  0.8737864  0.89805824 0.93203884 0.9660194 ]
#  ...
#  [0.23786408 0.24271844 0.24757281 0.24757281 0.24757281]
#  [0.24271844 0.24757281 0.24757281 0.24757281 0.2184466 ]
#  [0.24757281 0.24757281 0.24757281 0.2184466  0.23300971]]

# %%
print(train_X, train_y)
# Out:
# [[[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]]
#
#  [[0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]]
#
#  [[0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]]
#
#  ...
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]]] [[0.79126215 0.8203884  0.8446602  0.8737864  0.89805824]
#  [0.8203884  0.8446602  0.8737864  0.89805824 0.93203884]
#  [0.8446602  0.8737864  0.89805824 0.93203884 0.9660194 ]
#  ...
#  [0.23786408 0.24271844 0.24757281 0.24757281 0.24757281]
#  [0.24271844 0.24757281 0.24757281 0.24757281 0.2184466 ]
#  [0.24757281 0.24757281 0.24757281 0.2184466  0.23300971]]

# %%
print(train_X.shape, train_y.shape, val_X.shape, val_y.shape)
# Out:
# (3175, 1, 18) (3175, 5) (1588, 1, 18) (1588, 5)

# %%
randomState = 46
np.random.seed(randomState)
#tensorflow.random.set_random_seed(randomState)
tensorflow.random.set_seed(randomState)
model = Sequential()
model.add(GRU(15,input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dense(22))
#model.add(Activation('relu'))    
model.add(Dense(out_hour,activation = "sigmoid"))
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.001)
#    opt=tensorflow.keras.optimizers.Adam(learning_rate=0.00075)
model.compile(loss='mae', optimizer=opt,metrics=['mse','mae',tensorflow.keras.metrics.RootMeanSquaredError()])
history = model.fit(train_X, train_y,validation_data=(val_X, val_y), epochs=500, batch_size=100,verbose=1,shuffle=False)
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)
# Out:
# Train on 3175 samples, validate on 1588 samples
# Epoch 1/500
# 3175/3175 [==============================] - 2s 571us/sample - loss: 0.2528 - mse: 0.0767 - mae: 0.2528 - root_mean_squared_error: 0.2769 - val_loss: 0.2630 - val_mse: 0.0854 - val_mae: 0.2630 - val_root_mean_squared_error: 0.2923
# Epoch 2/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.2296 - mse: 0.0651 - mae: 0.2296 - root_mean_squared_error: 0.2552 - val_loss: 0.2394 - val_mse: 0.0721 - val_mae: 0.2394 - val_root_mean_squared_error: 0.2685
# Epoch 3/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.2095 - mse: 0.0578 - mae: 0.2095 - root_mean_squared_error: 0.240 - 0s 29us/sample - loss: 0.2064 - mse: 0.0551 - mae: 0.2064 - root_mean_squared_error: 0.2347 - val_loss: 0.2158 - val_mse: 0.0605 - val_mae: 0.2158 - val_root_mean_squared_error: 0.2460
# Epoch 4/500
# 3175/3175 [==============================] - 0s 43us/sample - loss: 0.1852 - mse: 0.0477 - mae: 0.1852 - root_mean_squared_error: 0.2185 - val_loss: 0.1952 - val_mse: 0.0518 - val_mae: 0.1952 - val_root_mean_squared_error: 0.2275
# Epoch 5/500
# 3175/3175 [==============================] - 0s 56us/sample - loss: 0.1688 - mse: 0.0430 - mae: 0.1688 - root_mean_squared_error: 0.2073 - val_loss: 0.1795 - val_mse: 0.0456 - val_mae: 0.1795 - val_root_mean_squared_error: 0.2135
# Epoch 6/500
# 3175/3175 [==============================] - 0s 56us/sample - loss: 0.1565 - mse: 0.0395 - mae: 0.1565 - root_mean_squared_error: 0.1988 - val_loss: 0.1670 - val_mse: 0.0408 - val_mae: 0.1670 - val_root_mean_squared_error: 0.2020
# Epoch 7/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.1462 - mse: 0.0364 - mae: 0.1462 - root_mean_squared_error: 0.1907 - val_loss: 0.1560 - val_mse: 0.0367 - val_mae: 0.1560 - val_root_mean_squared_error: 0.1915
# Epoch 8/500
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.1369 - mse: 0.0332 - mae: 0.1369 - root_mean_squared_error: 0.1822 - val_loss: 0.1461 - val_mse: 0.0328 - val_mae: 0.1461 - val_root_mean_squared_error: 0.1812
# Epoch 9/500
# 3175/3175 [==============================] - 0s 56us/sample - loss: 0.1281 - mse: 0.0299 - mae: 0.1281 - root_mean_squared_error: 0.1729 - val_loss: 0.1369 - val_mse: 0.0293 - val_mae: 0.1369 - val_root_mean_squared_error: 0.1712
# Epoch 10/500
# 3175/3175 [==============================] - 0s 52us/sample - loss: 0.1199 - mse: 0.0267 - mae: 0.1199 - root_mean_squared_error: 0.1633 - val_loss: 0.1284 - val_mse: 0.0261 - val_mae: 0.1284 - val_root_mean_squared_error: 0.1615
# Epoch 11/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.1123 - mse: 0.0236 - mae: 0.1123 - root_mean_squared_error: 0.1536 - val_loss: 0.1205 - val_mse: 0.0232 - val_mae: 0.1205 - val_root_mean_squared_error: 0.1524
# Epoch 12/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.1054 - mse: 0.0209 - mae: 0.1054 - root_mean_squared_error: 0.1446 - val_loss: 0.1130 - val_mse: 0.0208 - val_mae: 0.1130 - val_root_mean_squared_error: 0.1442
# Epoch 13/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0991 - mse: 0.0186 - mae: 0.0991 - root_mean_squared_error: 0.1365 - val_loss: 0.1062 - val_mse: 0.0187 - val_mae: 0.1062 - val_root_mean_squared_error: 0.1367
# Epoch 14/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0932 - mse: 0.0166 - mae: 0.0932 - root_mean_squared_error: 0.1289 - val_loss: 0.0999 - val_mse: 0.0169 - val_mae: 0.0999 - val_root_mean_squared_error: 0.1300
# Epoch 15/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0876 - mse: 0.0149 - mae: 0.0876 - root_mean_squared_error: 0.1220 - val_loss: 0.0940 - val_mse: 0.0154 - val_mae: 0.0940 - val_root_mean_squared_error: 0.1241
# Epoch 16/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0825 - mse: 0.0135 - mae: 0.0825 - root_mean_squared_error: 0.1161 - val_loss: 0.0888 - val_mse: 0.0142 - val_mae: 0.0888 - val_root_mean_squared_error: 0.1192
# Epoch 17/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0781 - mse: 0.0124 - mae: 0.0781 - root_mean_squared_error: 0.1114 - val_loss: 0.0843 - val_mse: 0.0133 - val_mae: 0.0843 - val_root_mean_squared_error: 0.1154
# Epoch 18/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0742 - mse: 0.0116 - mae: 0.0742 - root_mean_squared_error: 0.1078 - val_loss: 0.0804 - val_mse: 0.0126 - val_mae: 0.0804 - val_root_mean_squared_error: 0.1125
# Epoch 19/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0709 - mse: 0.0111 - mae: 0.0709 - root_mean_squared_error: 0.1052 - val_loss: 0.0769 - val_mse: 0.0121 - val_mae: 0.0769 - val_root_mean_squared_error: 0.1102
# Epoch 20/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0680 - mse: 0.0107 - mae: 0.0680 - root_mean_squared_error: 0.1032 - val_loss: 0.0740 - val_mse: 0.0118 - val_mae: 0.0740 - val_root_mean_squared_error: 0.1085
# Epoch 21/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0656 - mse: 0.0104 - mae: 0.0656 - root_mean_squared_error: 0.1018 - val_loss: 0.0716 - val_mse: 0.0115 - val_mae: 0.0716 - val_root_mean_squared_error: 0.1073
# Epoch 22/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0636 - mse: 0.0101 - mae: 0.0636 - root_mean_squared_error: 0.1007 - val_loss: 0.0697 - val_mse: 0.0113 - val_mae: 0.0697 - val_root_mean_squared_error: 0.1062
# Epoch 23/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0619 - mse: 0.0100 - mae: 0.0619 - root_mean_squared_error: 0.0999 - val_loss: 0.0681 - val_mse: 0.0111 - val_mae: 0.0681 - val_root_mean_squared_error: 0.1054
# Epoch 24/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0606 - mse: 0.0098 - mae: 0.0606 - root_mean_squared_error: 0.0991 - val_loss: 0.0667 - val_mse: 0.0109 - val_mae: 0.0667 - val_root_mean_squared_error: 0.1045
# Epoch 25/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0595 - mse: 0.0097 - mae: 0.0595 - root_mean_squared_error: 0.0983 - val_loss: 0.0656 - val_mse: 0.0108 - val_mae: 0.0656 - val_root_mean_squared_error: 0.1037
# Epoch 26/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0586 - mse: 0.0095 - mae: 0.0586 - root_mean_squared_error: 0.0976 - val_loss: 0.0647 - val_mse: 0.0106 - val_mae: 0.0647 - val_root_mean_squared_error: 0.1030
# Epoch 27/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0578 - mse: 0.0094 - mae: 0.0578 - root_mean_squared_error: 0.0969 - val_loss: 0.0639 - val_mse: 0.0105 - val_mae: 0.0639 - val_root_mean_squared_error: 0.1023
# Epoch 28/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0572 - mse: 0.0093 - mae: 0.0572 - root_mean_squared_error: 0.0963 - val_loss: 0.0633 - val_mse: 0.0103 - val_mae: 0.0633 - val_root_mean_squared_error: 0.1017
# Epoch 29/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0566 - mse: 0.0091 - mae: 0.0566 - root_mean_squared_error: 0.0956 - val_loss: 0.0627 - val_mse: 0.0102 - val_mae: 0.0627 - val_root_mean_squared_error: 0.1011
# Epoch 30/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0561 - mse: 0.0090 - mae: 0.0561 - root_mean_squared_error: 0.0950 - val_loss: 0.0621 - val_mse: 0.0101 - val_mae: 0.0621 - val_root_mean_squared_error: 0.1006
# Epoch 31/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0556 - mse: 0.0089 - mae: 0.0556 - root_mean_squared_error: 0.0945 - val_loss: 0.0616 - val_mse: 0.0100 - val_mae: 0.0616 - val_root_mean_squared_error: 0.1001
# Epoch 32/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0552 - mse: 0.0088 - mae: 0.0552 - root_mean_squared_error: 0.0940 - val_loss: 0.0612 - val_mse: 0.0099 - val_mae: 0.0612 - val_root_mean_squared_error: 0.0995
# Epoch 33/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0548 - mse: 0.0087 - mae: 0.0548 - root_mean_squared_error: 0.0935 - val_loss: 0.0608 - val_mse: 0.0098 - val_mae: 0.0608 - val_root_mean_squared_error: 0.0991
# Epoch 34/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0545 - mse: 0.0086 - mae: 0.0545 - root_mean_squared_error: 0.0930 - val_loss: 0.0604 - val_mse: 0.0097 - val_mae: 0.0604 - val_root_mean_squared_error: 0.0987
# Epoch 35/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0541 - mse: 0.0086 - mae: 0.0541 - root_mean_squared_error: 0.0926 - val_loss: 0.0601 - val_mse: 0.0097 - val_mae: 0.0601 - val_root_mean_squared_error: 0.0983
# Epoch 36/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0539 - mse: 0.0085 - mae: 0.0539 - root_mean_squared_error: 0.0922 - val_loss: 0.0598 - val_mse: 0.0096 - val_mae: 0.0598 - val_root_mean_squared_error: 0.0980
# Epoch 37/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0536 - mse: 0.0084 - mae: 0.0536 - root_mean_squared_error: 0.0918 - val_loss: 0.0595 - val_mse: 0.0095 - val_mae: 0.0595 - val_root_mean_squared_error: 0.0976
# Epoch 38/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0533 - mse: 0.0084 - mae: 0.0533 - root_mean_squared_error: 0.0914 - val_loss: 0.0592 - val_mse: 0.0095 - val_mae: 0.0592 - val_root_mean_squared_error: 0.0973
# Epoch 39/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0530 - mse: 0.0083 - mae: 0.0530 - root_mean_squared_error: 0.0911 - val_loss: 0.0590 - val_mse: 0.0094 - val_mae: 0.0590 - val_root_mean_squared_error: 0.0970
# Epoch 40/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0528 - mse: 0.0082 - mae: 0.0528 - root_mean_squared_error: 0.0908 - val_loss: 0.0587 - val_mse: 0.0094 - val_mae: 0.0587 - val_root_mean_squared_error: 0.0968
# Epoch 41/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0525 - mse: 0.0082 - mae: 0.0525 - root_mean_squared_error: 0.0905 - val_loss: 0.0585 - val_mse: 0.0093 - val_mae: 0.0585 - val_root_mean_squared_error: 0.0965
# Epoch 42/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0523 - mse: 0.0081 - mae: 0.0523 - root_mean_squared_error: 0.0902 - val_loss: 0.0582 - val_mse: 0.0093 - val_mae: 0.0582 - val_root_mean_squared_error: 0.0963
# Epoch 43/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0521 - mse: 0.0081 - mae: 0.0521 - root_mean_squared_error: 0.0900 - val_loss: 0.0580 - val_mse: 0.0092 - val_mae: 0.0580 - val_root_mean_squared_error: 0.0961
# Epoch 44/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0518 - mse: 0.0080 - mae: 0.0518 - root_mean_squared_error: 0.0897 - val_loss: 0.0578 - val_mse: 0.0092 - val_mae: 0.0578 - val_root_mean_squared_error: 0.0959
# Epoch 45/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0516 - mse: 0.0080 - mae: 0.0516 - root_mean_squared_error: 0.0895 - val_loss: 0.0576 - val_mse: 0.0092 - val_mae: 0.0576 - val_root_mean_squared_error: 0.0957
# Epoch 46/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0514 - mse: 0.0080 - mae: 0.0514 - root_mean_squared_error: 0.0893 - val_loss: 0.0574 - val_mse: 0.0091 - val_mae: 0.0574 - val_root_mean_squared_error: 0.0955
# Epoch 47/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0512 - mse: 0.0079 - mae: 0.0512 - root_mean_squared_error: 0.0890 - val_loss: 0.0573 - val_mse: 0.0091 - val_mae: 0.0573 - val_root_mean_squared_error: 0.0953
# Epoch 48/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0510 - mse: 0.0079 - mae: 0.0510 - root_mean_squared_error: 0.0888 - val_loss: 0.0571 - val_mse: 0.0090 - val_mae: 0.0571 - val_root_mean_squared_error: 0.0951
# Epoch 49/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0508 - mse: 0.0079 - mae: 0.0508 - root_mean_squared_error: 0.0886 - val_loss: 0.0569 - val_mse: 0.0090 - val_mae: 0.0569 - val_root_mean_squared_error: 0.0950
# Epoch 50/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0507 - mse: 0.0078 - mae: 0.0507 - root_mean_squared_error: 0.0885 - val_loss: 0.0567 - val_mse: 0.0090 - val_mae: 0.0567 - val_root_mean_squared_error: 0.0948
# Epoch 51/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0505 - mse: 0.0078 - mae: 0.0505 - root_mean_squared_error: 0.0883 - val_loss: 0.0566 - val_mse: 0.0090 - val_mae: 0.0566 - val_root_mean_squared_error: 0.0947
# Epoch 52/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0503 - mse: 0.0078 - mae: 0.0503 - root_mean_squared_error: 0.0881 - val_loss: 0.0564 - val_mse: 0.0089 - val_mae: 0.0564 - val_root_mean_squared_error: 0.0945
# Epoch 53/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0502 - mse: 0.0077 - mae: 0.0502 - root_mean_squared_error: 0.0880 - val_loss: 0.0563 - val_mse: 0.0089 - val_mae: 0.0563 - val_root_mean_squared_error: 0.0944
# Epoch 54/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0500 - mse: 0.0077 - mae: 0.0500 - root_mean_squared_error: 0.0878 - val_loss: 0.0562 - val_mse: 0.0089 - val_mae: 0.0562 - val_root_mean_squared_error: 0.0943
# Epoch 55/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0499 - mse: 0.0077 - mae: 0.0499 - root_mean_squared_error: 0.0877 - val_loss: 0.0560 - val_mse: 0.0089 - val_mae: 0.0560 - val_root_mean_squared_error: 0.0942
# Epoch 56/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0497 - mse: 0.0077 - mae: 0.0497 - root_mean_squared_error: 0.0876 - val_loss: 0.0559 - val_mse: 0.0089 - val_mae: 0.0559 - val_root_mean_squared_error: 0.0941
# Epoch 57/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0496 - mse: 0.0077 - mae: 0.0496 - root_mean_squared_error: 0.0875 - val_loss: 0.0558 - val_mse: 0.0088 - val_mae: 0.0558 - val_root_mean_squared_error: 0.0940
# Epoch 58/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0495 - mse: 0.0076 - mae: 0.0495 - root_mean_squared_error: 0.0874 - val_loss: 0.0557 - val_mse: 0.0088 - val_mae: 0.0557 - val_root_mean_squared_error: 0.0939
# Epoch 59/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0493 - mse: 0.0076 - mae: 0.0493 - root_mean_squared_error: 0.0873 - val_loss: 0.0555 - val_mse: 0.0088 - val_mae: 0.0555 - val_root_mean_squared_error: 0.0938
# Epoch 60/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0492 - mse: 0.0076 - mae: 0.0492 - root_mean_squared_error: 0.0872 - val_loss: 0.0554 - val_mse: 0.0088 - val_mae: 0.0554 - val_root_mean_squared_error: 0.0937
# Epoch 61/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0491 - mse: 0.0076 - mae: 0.0491 - root_mean_squared_error: 0.0871 - val_loss: 0.0553 - val_mse: 0.0088 - val_mae: 0.0553 - val_root_mean_squared_error: 0.0936
# Epoch 62/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0489 - mse: 0.0076 - mae: 0.0489 - root_mean_squared_error: 0.0870 - val_loss: 0.0552 - val_mse: 0.0088 - val_mae: 0.0552 - val_root_mean_squared_error: 0.0936
# Epoch 63/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0488 - mse: 0.0075 - mae: 0.0488 - root_mean_squared_error: 0.0869 - val_loss: 0.0551 - val_mse: 0.0087 - val_mae: 0.0551 - val_root_mean_squared_error: 0.0935
# Epoch 64/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0487 - mse: 0.0075 - mae: 0.0487 - root_mean_squared_error: 0.0868 - val_loss: 0.0549 - val_mse: 0.0087 - val_mae: 0.0549 - val_root_mean_squared_error: 0.0934
# Epoch 65/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0486 - mse: 0.0075 - mae: 0.0486 - root_mean_squared_error: 0.0867 - val_loss: 0.0548 - val_mse: 0.0087 - val_mae: 0.0548 - val_root_mean_squared_error: 0.0933
# Epoch 66/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0485 - mse: 0.0075 - mae: 0.0485 - root_mean_squared_error: 0.0866 - val_loss: 0.0547 - val_mse: 0.0087 - val_mae: 0.0547 - val_root_mean_squared_error: 0.0932
# Epoch 67/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0484 - mse: 0.0075 - mae: 0.0484 - root_mean_squared_error: 0.0865 - val_loss: 0.0546 - val_mse: 0.0087 - val_mae: 0.0546 - val_root_mean_squared_error: 0.0931
# Epoch 68/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0482 - mse: 0.0075 - mae: 0.0482 - root_mean_squared_error: 0.0864 - val_loss: 0.0545 - val_mse: 0.0087 - val_mae: 0.0545 - val_root_mean_squared_error: 0.0931
# Epoch 69/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0482 - mse: 0.0075 - mae: 0.0482 - root_mean_squared_error: 0.0863 - val_loss: 0.0544 - val_mse: 0.0087 - val_mae: 0.0544 - val_root_mean_squared_error: 0.0930
# Epoch 70/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0481 - mse: 0.0074 - mae: 0.0481 - root_mean_squared_error: 0.0863 - val_loss: 0.0543 - val_mse: 0.0086 - val_mae: 0.0543 - val_root_mean_squared_error: 0.0929
# Epoch 71/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0480 - mse: 0.0074 - mae: 0.0480 - root_mean_squared_error: 0.0862 - val_loss: 0.0542 - val_mse: 0.0086 - val_mae: 0.0542 - val_root_mean_squared_error: 0.0929
# Epoch 72/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0479 - mse: 0.0074 - mae: 0.0479 - root_mean_squared_error: 0.0861 - val_loss: 0.0541 - val_mse: 0.0086 - val_mae: 0.0541 - val_root_mean_squared_error: 0.0928
# Epoch 73/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0478 - mse: 0.0074 - mae: 0.0478 - root_mean_squared_error: 0.0861 - val_loss: 0.0540 - val_mse: 0.0086 - val_mae: 0.0540 - val_root_mean_squared_error: 0.0927
# Epoch 74/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0477 - mse: 0.0074 - mae: 0.0477 - root_mean_squared_error: 0.0860 - val_loss: 0.0538 - val_mse: 0.0086 - val_mae: 0.0538 - val_root_mean_squared_error: 0.0926
# Epoch 75/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0476 - mse: 0.0074 - mae: 0.0476 - root_mean_squared_error: 0.0859 - val_loss: 0.0537 - val_mse: 0.0086 - val_mae: 0.0537 - val_root_mean_squared_error: 0.0926
# Epoch 76/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0475 - mse: 0.0074 - mae: 0.0475 - root_mean_squared_error: 0.0858 - val_loss: 0.0536 - val_mse: 0.0086 - val_mae: 0.0536 - val_root_mean_squared_error: 0.0925
# Epoch 77/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0474 - mse: 0.0074 - mae: 0.0474 - root_mean_squared_error: 0.0857 - val_loss: 0.0535 - val_mse: 0.0085 - val_mae: 0.0535 - val_root_mean_squared_error: 0.0924
# Epoch 78/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0473 - mse: 0.0073 - mae: 0.0473 - root_mean_squared_error: 0.0857 - val_loss: 0.0534 - val_mse: 0.0085 - val_mae: 0.0534 - val_root_mean_squared_error: 0.0923
# Epoch 79/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0472 - mse: 0.0073 - mae: 0.0472 - root_mean_squared_error: 0.0856 - val_loss: 0.0533 - val_mse: 0.0085 - val_mae: 0.0533 - val_root_mean_squared_error: 0.0923
# Epoch 80/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0471 - mse: 0.0073 - mae: 0.0471 - root_mean_squared_error: 0.0855 - val_loss: 0.0532 - val_mse: 0.0085 - val_mae: 0.0532 - val_root_mean_squared_error: 0.0922
# Epoch 81/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0470 - mse: 0.0073 - mae: 0.0470 - root_mean_squared_error: 0.0855 - val_loss: 0.0531 - val_mse: 0.0085 - val_mae: 0.0531 - val_root_mean_squared_error: 0.0921
# Epoch 82/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0470 - mse: 0.0073 - mae: 0.0470 - root_mean_squared_error: 0.0854 - val_loss: 0.0530 - val_mse: 0.0085 - val_mae: 0.0530 - val_root_mean_squared_error: 0.0921
# Epoch 83/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0491 - mse: 0.0081 - mae: 0.0491 - root_mean_squared_error: 0.089 - 0s 27us/sample - loss: 0.0469 - mse: 0.0073 - mae: 0.0469 - root_mean_squared_error: 0.0853 - val_loss: 0.0529 - val_mse: 0.0085 - val_mae: 0.0529 - val_root_mean_squared_error: 0.0920
# Epoch 84/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0468 - mse: 0.0073 - mae: 0.0468 - root_mean_squared_error: 0.0853 - val_loss: 0.0528 - val_mse: 0.0085 - val_mae: 0.0528 - val_root_mean_squared_error: 0.0920
# Epoch 85/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0467 - mse: 0.0073 - mae: 0.0467 - root_mean_squared_error: 0.0852 - val_loss: 0.0528 - val_mse: 0.0085 - val_mae: 0.0528 - val_root_mean_squared_error: 0.0919
# Epoch 86/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0466 - mse: 0.0073 - mae: 0.0466 - root_mean_squared_error: 0.0851 - val_loss: 0.0527 - val_mse: 0.0084 - val_mae: 0.0527 - val_root_mean_squared_error: 0.0919
# Epoch 87/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0466 - mse: 0.0072 - mae: 0.0466 - root_mean_squared_error: 0.0851 - val_loss: 0.0526 - val_mse: 0.0084 - val_mae: 0.0526 - val_root_mean_squared_error: 0.0918
# Epoch 88/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0465 - mse: 0.0072 - mae: 0.0465 - root_mean_squared_error: 0.0850 - val_loss: 0.0525 - val_mse: 0.0084 - val_mae: 0.0525 - val_root_mean_squared_error: 0.0918
# Epoch 89/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0464 - mse: 0.0072 - mae: 0.0464 - root_mean_squared_error: 0.0849 - val_loss: 0.0524 - val_mse: 0.0084 - val_mae: 0.0524 - val_root_mean_squared_error: 0.0917
# Epoch 90/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0475 - mse: 0.0077 - mae: 0.0475 - root_mean_squared_error: 0.088 - 0s 27us/sample - loss: 0.0463 - mse: 0.0072 - mae: 0.0463 - root_mean_squared_error: 0.0849 - val_loss: 0.0523 - val_mse: 0.0084 - val_mae: 0.0523 - val_root_mean_squared_error: 0.0917
# Epoch 91/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0463 - mse: 0.0072 - mae: 0.0463 - root_mean_squared_error: 0.0848 - val_loss: 0.0522 - val_mse: 0.0084 - val_mae: 0.0522 - val_root_mean_squared_error: 0.0916
# Epoch 92/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0462 - mse: 0.0072 - mae: 0.0462 - root_mean_squared_error: 0.0848 - val_loss: 0.0521 - val_mse: 0.0084 - val_mae: 0.0521 - val_root_mean_squared_error: 0.0916
# Epoch 93/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0461 - mse: 0.0072 - mae: 0.0461 - root_mean_squared_error: 0.0847 - val_loss: 0.0521 - val_mse: 0.0084 - val_mae: 0.0521 - val_root_mean_squared_error: 0.0915
# Epoch 94/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0461 - mse: 0.0072 - mae: 0.0461 - root_mean_squared_error: 0.0847 - val_loss: 0.0520 - val_mse: 0.0084 - val_mae: 0.0520 - val_root_mean_squared_error: 0.0915
# Epoch 95/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0460 - mse: 0.0072 - mae: 0.0460 - root_mean_squared_error: 0.0846 - val_loss: 0.0519 - val_mse: 0.0084 - val_mae: 0.0519 - val_root_mean_squared_error: 0.0914
# Epoch 96/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0459 - mse: 0.0072 - mae: 0.0459 - root_mean_squared_error: 0.0846 - val_loss: 0.0518 - val_mse: 0.0084 - val_mae: 0.0518 - val_root_mean_squared_error: 0.0914
# Epoch 97/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0459 - mse: 0.0071 - mae: 0.0459 - root_mean_squared_error: 0.0845 - val_loss: 0.0517 - val_mse: 0.0083 - val_mae: 0.0517 - val_root_mean_squared_error: 0.0913
# Epoch 98/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0458 - mse: 0.0071 - mae: 0.0458 - root_mean_squared_error: 0.0845 - val_loss: 0.0516 - val_mse: 0.0083 - val_mae: 0.0516 - val_root_mean_squared_error: 0.0913
# Epoch 99/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0457 - mse: 0.0071 - mae: 0.0457 - root_mean_squared_error: 0.0844 - val_loss: 0.0516 - val_mse: 0.0083 - val_mae: 0.0516 - val_root_mean_squared_error: 0.0913
# Epoch 100/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0457 - mse: 0.0071 - mae: 0.0457 - root_mean_squared_error: 0.0844 - val_loss: 0.0515 - val_mse: 0.0083 - val_mae: 0.0515 - val_root_mean_squared_error: 0.0912
# Epoch 101/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0456 - mse: 0.0071 - mae: 0.0456 - root_mean_squared_error: 0.0844 - val_loss: 0.0514 - val_mse: 0.0083 - val_mae: 0.0514 - val_root_mean_squared_error: 0.0912
# Epoch 102/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0455 - mse: 0.0071 - mae: 0.0455 - root_mean_squared_error: 0.0843 - val_loss: 0.0514 - val_mse: 0.0083 - val_mae: 0.0514 - val_root_mean_squared_error: 0.0912
# Epoch 103/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0455 - mse: 0.0071 - mae: 0.0455 - root_mean_squared_error: 0.0843 - val_loss: 0.0513 - val_mse: 0.0083 - val_mae: 0.0513 - val_root_mean_squared_error: 0.0911
# Epoch 104/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0454 - mse: 0.0071 - mae: 0.0454 - root_mean_squared_error: 0.0842 - val_loss: 0.0512 - val_mse: 0.0083 - val_mae: 0.0512 - val_root_mean_squared_error: 0.0911
# Epoch 105/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0454 - mse: 0.0071 - mae: 0.0454 - root_mean_squared_error: 0.0842 - val_loss: 0.0512 - val_mse: 0.0083 - val_mae: 0.0512 - val_root_mean_squared_error: 0.0911
# Epoch 106/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0453 - mse: 0.0071 - mae: 0.0453 - root_mean_squared_error: 0.0842 - val_loss: 0.0511 - val_mse: 0.0083 - val_mae: 0.0511 - val_root_mean_squared_error: 0.0910
# Epoch 107/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0452 - mse: 0.0071 - mae: 0.0452 - root_mean_squared_error: 0.0841 - val_loss: 0.0510 - val_mse: 0.0083 - val_mae: 0.0510 - val_root_mean_squared_error: 0.0910
# Epoch 108/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0452 - mse: 0.0071 - mae: 0.0452 - root_mean_squared_error: 0.0841 - val_loss: 0.0510 - val_mse: 0.0083 - val_mae: 0.0510 - val_root_mean_squared_error: 0.0910
# Epoch 109/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0451 - mse: 0.0071 - mae: 0.0451 - root_mean_squared_error: 0.0841 - val_loss: 0.0509 - val_mse: 0.0083 - val_mae: 0.0509 - val_root_mean_squared_error: 0.0910
# Epoch 110/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0451 - mse: 0.0071 - mae: 0.0451 - root_mean_squared_error: 0.0840 - val_loss: 0.0508 - val_mse: 0.0083 - val_mae: 0.0508 - val_root_mean_squared_error: 0.0909
# Epoch 111/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0450 - mse: 0.0071 - mae: 0.0450 - root_mean_squared_error: 0.0840 - val_loss: 0.0508 - val_mse: 0.0083 - val_mae: 0.0508 - val_root_mean_squared_error: 0.0909
# Epoch 112/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0450 - mse: 0.0071 - mae: 0.0450 - root_mean_squared_error: 0.0840 - val_loss: 0.0507 - val_mse: 0.0083 - val_mae: 0.0507 - val_root_mean_squared_error: 0.0909
# Epoch 113/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0449 - mse: 0.0071 - mae: 0.0449 - root_mean_squared_error: 0.0840 - val_loss: 0.0507 - val_mse: 0.0083 - val_mae: 0.0507 - val_root_mean_squared_error: 0.0909
# Epoch 114/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0449 - mse: 0.0070 - mae: 0.0449 - root_mean_squared_error: 0.0839 - val_loss: 0.0506 - val_mse: 0.0083 - val_mae: 0.0506 - val_root_mean_squared_error: 0.0909
# Epoch 115/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0448 - mse: 0.0070 - mae: 0.0448 - root_mean_squared_error: 0.0839 - val_loss: 0.0506 - val_mse: 0.0083 - val_mae: 0.0506 - val_root_mean_squared_error: 0.0909
# Epoch 116/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0448 - mse: 0.0070 - mae: 0.0448 - root_mean_squared_error: 0.0839 - val_loss: 0.0505 - val_mse: 0.0083 - val_mae: 0.0505 - val_root_mean_squared_error: 0.0908
# Epoch 117/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0447 - mse: 0.0070 - mae: 0.0447 - root_mean_squared_error: 0.0839 - val_loss: 0.0504 - val_mse: 0.0083 - val_mae: 0.0504 - val_root_mean_squared_error: 0.0908
# Epoch 118/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0447 - mse: 0.0070 - mae: 0.0447 - root_mean_squared_error: 0.0838 - val_loss: 0.0504 - val_mse: 0.0082 - val_mae: 0.0504 - val_root_mean_squared_error: 0.0908
# Epoch 119/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0446 - mse: 0.0070 - mae: 0.0446 - root_mean_squared_error: 0.0838 - val_loss: 0.0503 - val_mse: 0.0082 - val_mae: 0.0503 - val_root_mean_squared_error: 0.0908
# Epoch 120/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0446 - mse: 0.0070 - mae: 0.0446 - root_mean_squared_error: 0.0838 - val_loss: 0.0503 - val_mse: 0.0082 - val_mae: 0.0503 - val_root_mean_squared_error: 0.0908
# Epoch 121/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0445 - mse: 0.0070 - mae: 0.0445 - root_mean_squared_error: 0.0838 - val_loss: 0.0502 - val_mse: 0.0082 - val_mae: 0.0502 - val_root_mean_squared_error: 0.0908
# Epoch 122/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0445 - mse: 0.0070 - mae: 0.0445 - root_mean_squared_error: 0.0837 - val_loss: 0.0502 - val_mse: 0.0082 - val_mae: 0.0502 - val_root_mean_squared_error: 0.0907
# Epoch 123/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0445 - mse: 0.0070 - mae: 0.0445 - root_mean_squared_error: 0.0837 - val_loss: 0.0501 - val_mse: 0.0082 - val_mae: 0.0501 - val_root_mean_squared_error: 0.0907
# Epoch 124/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0444 - mse: 0.0070 - mae: 0.0444 - root_mean_squared_error: 0.0837 - val_loss: 0.0501 - val_mse: 0.0082 - val_mae: 0.0501 - val_root_mean_squared_error: 0.0907
# Epoch 125/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0444 - mse: 0.0070 - mae: 0.0444 - root_mean_squared_error: 0.0837 - val_loss: 0.0500 - val_mse: 0.0082 - val_mae: 0.0500 - val_root_mean_squared_error: 0.0907
# Epoch 126/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0443 - mse: 0.0070 - mae: 0.0443 - root_mean_squared_error: 0.0837 - val_loss: 0.0500 - val_mse: 0.0082 - val_mae: 0.0500 - val_root_mean_squared_error: 0.0907
# Epoch 127/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0443 - mse: 0.0070 - mae: 0.0443 - root_mean_squared_error: 0.0836 - val_loss: 0.0500 - val_mse: 0.0082 - val_mae: 0.0500 - val_root_mean_squared_error: 0.0907
# Epoch 128/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0443 - mse: 0.0070 - mae: 0.0443 - root_mean_squared_error: 0.0836 - val_loss: 0.0499 - val_mse: 0.0082 - val_mae: 0.0499 - val_root_mean_squared_error: 0.0907
# Epoch 129/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0442 - mse: 0.0070 - mae: 0.0442 - root_mean_squared_error: 0.0836 - val_loss: 0.0499 - val_mse: 0.0082 - val_mae: 0.0499 - val_root_mean_squared_error: 0.0907
# Epoch 130/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0442 - mse: 0.0070 - mae: 0.0442 - root_mean_squared_error: 0.0836 - val_loss: 0.0498 - val_mse: 0.0082 - val_mae: 0.0498 - val_root_mean_squared_error: 0.0906
# Epoch 131/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0442 - mse: 0.0070 - mae: 0.0442 - root_mean_squared_error: 0.0836 - val_loss: 0.0498 - val_mse: 0.0082 - val_mae: 0.0498 - val_root_mean_squared_error: 0.0906
# Epoch 132/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0441 - mse: 0.0070 - mae: 0.0441 - root_mean_squared_error: 0.0836 - val_loss: 0.0498 - val_mse: 0.0082 - val_mae: 0.0498 - val_root_mean_squared_error: 0.0906
# Epoch 133/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0441 - mse: 0.0070 - mae: 0.0441 - root_mean_squared_error: 0.0835 - val_loss: 0.0497 - val_mse: 0.0082 - val_mae: 0.0497 - val_root_mean_squared_error: 0.0906
# Epoch 134/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0441 - mse: 0.0070 - mae: 0.0441 - root_mean_squared_error: 0.0835 - val_loss: 0.0497 - val_mse: 0.0082 - val_mae: 0.0497 - val_root_mean_squared_error: 0.0906
# Epoch 135/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0440 - mse: 0.0070 - mae: 0.0440 - root_mean_squared_error: 0.0835 - val_loss: 0.0496 - val_mse: 0.0082 - val_mae: 0.0496 - val_root_mean_squared_error: 0.0906
# Epoch 136/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0440 - mse: 0.0070 - mae: 0.0440 - root_mean_squared_error: 0.0835 - val_loss: 0.0496 - val_mse: 0.0082 - val_mae: 0.0496 - val_root_mean_squared_error: 0.0906
# Epoch 137/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0440 - mse: 0.0070 - mae: 0.0440 - root_mean_squared_error: 0.0835 - val_loss: 0.0496 - val_mse: 0.0082 - val_mae: 0.0496 - val_root_mean_squared_error: 0.0905
# Epoch 138/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0439 - mse: 0.0070 - mae: 0.0439 - root_mean_squared_error: 0.0835 - val_loss: 0.0495 - val_mse: 0.0082 - val_mae: 0.0495 - val_root_mean_squared_error: 0.0905
# Epoch 139/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0439 - mse: 0.0070 - mae: 0.0439 - root_mean_squared_error: 0.0835 - val_loss: 0.0495 - val_mse: 0.0082 - val_mae: 0.0495 - val_root_mean_squared_error: 0.0905
# Epoch 140/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0439 - mse: 0.0070 - mae: 0.0439 - root_mean_squared_error: 0.0835 - val_loss: 0.0495 - val_mse: 0.0082 - val_mae: 0.0495 - val_root_mean_squared_error: 0.0905
# Epoch 141/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0439 - mse: 0.0070 - mae: 0.0439 - root_mean_squared_error: 0.0835 - val_loss: 0.0494 - val_mse: 0.0082 - val_mae: 0.0494 - val_root_mean_squared_error: 0.0905
# Epoch 142/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0438 - mse: 0.0070 - mae: 0.0438 - root_mean_squared_error: 0.0834 - val_loss: 0.0494 - val_mse: 0.0082 - val_mae: 0.0494 - val_root_mean_squared_error: 0.0905
# Epoch 143/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0438 - mse: 0.0070 - mae: 0.0438 - root_mean_squared_error: 0.0834 - val_loss: 0.0494 - val_mse: 0.0082 - val_mae: 0.0494 - val_root_mean_squared_error: 0.0905
# Epoch 144/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0438 - mse: 0.0070 - mae: 0.0438 - root_mean_squared_error: 0.0834 - val_loss: 0.0493 - val_mse: 0.0082 - val_mae: 0.0493 - val_root_mean_squared_error: 0.0905
# Epoch 145/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0438 - mse: 0.0070 - mae: 0.0438 - root_mean_squared_error: 0.0834 - val_loss: 0.0493 - val_mse: 0.0082 - val_mae: 0.0493 - val_root_mean_squared_error: 0.0905
# Epoch 146/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0437 - mse: 0.0070 - mae: 0.0437 - root_mean_squared_error: 0.0834 - val_loss: 0.0493 - val_mse: 0.0082 - val_mae: 0.0493 - val_root_mean_squared_error: 0.0905
# Epoch 147/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0437 - mse: 0.0070 - mae: 0.0437 - root_mean_squared_error: 0.0834 - val_loss: 0.0492 - val_mse: 0.0082 - val_mae: 0.0492 - val_root_mean_squared_error: 0.0905
# Epoch 148/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0437 - mse: 0.0070 - mae: 0.0437 - root_mean_squared_error: 0.0834 - val_loss: 0.0492 - val_mse: 0.0082 - val_mae: 0.0492 - val_root_mean_squared_error: 0.0905
# Epoch 149/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0437 - mse: 0.0070 - mae: 0.0437 - root_mean_squared_error: 0.0834 - val_loss: 0.0492 - val_mse: 0.0082 - val_mae: 0.0492 - val_root_mean_squared_error: 0.0905
# Epoch 150/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0436 - mse: 0.0070 - mae: 0.0436 - root_mean_squared_error: 0.0834 - val_loss: 0.0492 - val_mse: 0.0082 - val_mae: 0.0492 - val_root_mean_squared_error: 0.0905
# Epoch 151/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0436 - mse: 0.0070 - mae: 0.0436 - root_mean_squared_error: 0.0834 - val_loss: 0.0491 - val_mse: 0.0082 - val_mae: 0.0491 - val_root_mean_squared_error: 0.0905
# Epoch 152/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0436 - mse: 0.0070 - mae: 0.0436 - root_mean_squared_error: 0.0834 - val_loss: 0.0491 - val_mse: 0.0082 - val_mae: 0.0491 - val_root_mean_squared_error: 0.0905
# Epoch 153/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0436 - mse: 0.0070 - mae: 0.0436 - root_mean_squared_error: 0.0834 - val_loss: 0.0491 - val_mse: 0.0082 - val_mae: 0.0491 - val_root_mean_squared_error: 0.0904
# Epoch 154/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0436 - mse: 0.0070 - mae: 0.0436 - root_mean_squared_error: 0.0834 - val_loss: 0.0491 - val_mse: 0.0082 - val_mae: 0.0491 - val_root_mean_squared_error: 0.0904
# Epoch 155/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0435 - mse: 0.0070 - mae: 0.0435 - root_mean_squared_error: 0.0834 - val_loss: 0.0490 - val_mse: 0.0082 - val_mae: 0.0490 - val_root_mean_squared_error: 0.0904
# Epoch 156/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0435 - mse: 0.0069 - mae: 0.0435 - root_mean_squared_error: 0.0834 - val_loss: 0.0490 - val_mse: 0.0082 - val_mae: 0.0490 - val_root_mean_squared_error: 0.0904
# Epoch 157/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0435 - mse: 0.0069 - mae: 0.0435 - root_mean_squared_error: 0.0833 - val_loss: 0.0490 - val_mse: 0.0082 - val_mae: 0.0490 - val_root_mean_squared_error: 0.0904
# Epoch 158/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0435 - mse: 0.0069 - mae: 0.0435 - root_mean_squared_error: 0.0833 - val_loss: 0.0489 - val_mse: 0.0082 - val_mae: 0.0489 - val_root_mean_squared_error: 0.0904
# Epoch 159/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0435 - mse: 0.0069 - mae: 0.0435 - root_mean_squared_error: 0.0833 - val_loss: 0.0489 - val_mse: 0.0082 - val_mae: 0.0489 - val_root_mean_squared_error: 0.0904
# Epoch 160/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0434 - mse: 0.0069 - mae: 0.0434 - root_mean_squared_error: 0.0833 - val_loss: 0.0489 - val_mse: 0.0082 - val_mae: 0.0489 - val_root_mean_squared_error: 0.0904
# Epoch 161/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0434 - mse: 0.0069 - mae: 0.0434 - root_mean_squared_error: 0.0833 - val_loss: 0.0489 - val_mse: 0.0082 - val_mae: 0.0488 - val_root_mean_squared_error: 0.0904
# Epoch 162/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0434 - mse: 0.0069 - mae: 0.0434 - root_mean_squared_error: 0.0833 - val_loss: 0.0488 - val_mse: 0.0082 - val_mae: 0.0488 - val_root_mean_squared_error: 0.0904
# Epoch 163/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0434 - mse: 0.0069 - mae: 0.0434 - root_mean_squared_error: 0.0833 - val_loss: 0.0488 - val_mse: 0.0082 - val_mae: 0.0488 - val_root_mean_squared_error: 0.0904
# Epoch 164/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0434 - mse: 0.0069 - mae: 0.0434 - root_mean_squared_error: 0.0833 - val_loss: 0.0488 - val_mse: 0.0082 - val_mae: 0.0488 - val_root_mean_squared_error: 0.0904
# Epoch 165/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0433 - mse: 0.0069 - mae: 0.0433 - root_mean_squared_error: 0.0833 - val_loss: 0.0487 - val_mse: 0.0082 - val_mae: 0.0487 - val_root_mean_squared_error: 0.0903
# Epoch 166/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0433 - mse: 0.0069 - mae: 0.0433 - root_mean_squared_error: 0.0833 - val_loss: 0.0487 - val_mse: 0.0082 - val_mae: 0.0487 - val_root_mean_squared_error: 0.0903
# Epoch 167/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0433 - mse: 0.0069 - mae: 0.0433 - root_mean_squared_error: 0.0833 - val_loss: 0.0487 - val_mse: 0.0082 - val_mae: 0.0487 - val_root_mean_squared_error: 0.0903
# Epoch 168/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0433 - mse: 0.0069 - mae: 0.0433 - root_mean_squared_error: 0.0833 - val_loss: 0.0487 - val_mse: 0.0082 - val_mae: 0.0487 - val_root_mean_squared_error: 0.0903
# Epoch 169/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0433 - mse: 0.0069 - mae: 0.0433 - root_mean_squared_error: 0.0833 - val_loss: 0.0486 - val_mse: 0.0082 - val_mae: 0.0486 - val_root_mean_squared_error: 0.0903
# Epoch 170/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0433 - mse: 0.0069 - mae: 0.0433 - root_mean_squared_error: 0.0833 - val_loss: 0.0486 - val_mse: 0.0082 - val_mae: 0.0486 - val_root_mean_squared_error: 0.0903
# Epoch 171/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0433 - mse: 0.0069 - mae: 0.0433 - root_mean_squared_error: 0.0833 - val_loss: 0.0486 - val_mse: 0.0082 - val_mae: 0.0486 - val_root_mean_squared_error: 0.0903
# Epoch 172/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0432 - mse: 0.0069 - mae: 0.0432 - root_mean_squared_error: 0.0833 - val_loss: 0.0486 - val_mse: 0.0082 - val_mae: 0.0486 - val_root_mean_squared_error: 0.0903
# Epoch 173/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0432 - mse: 0.0069 - mae: 0.0432 - root_mean_squared_error: 0.0833 - val_loss: 0.0485 - val_mse: 0.0082 - val_mae: 0.0485 - val_root_mean_squared_error: 0.0903
# Epoch 174/500
# 3175/3175 [==============================] - 0s 53us/sample - loss: 0.0432 - mse: 0.0069 - mae: 0.0432 - root_mean_squared_error: 0.0833 - val_loss: 0.0485 - val_mse: 0.0081 - val_mae: 0.0485 - val_root_mean_squared_error: 0.0903
# Epoch 175/500
# 3175/3175 [==============================] - 0s 59us/sample - loss: 0.0432 - mse: 0.0069 - mae: 0.0432 - root_mean_squared_error: 0.0833 - val_loss: 0.0485 - val_mse: 0.0081 - val_mae: 0.0485 - val_root_mean_squared_error: 0.0903
# Epoch 176/500
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.0432 - mse: 0.0069 - mae: 0.0432 - root_mean_squared_error: 0.0832 - val_loss: 0.0485 - val_mse: 0.0081 - val_mae: 0.0485 - val_root_mean_squared_error: 0.0903
# Epoch 177/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.0432 - mse: 0.0069 - mae: 0.0432 - root_mean_squared_error: 0.0832 - val_loss: 0.0485 - val_mse: 0.0081 - val_mae: 0.0485 - val_root_mean_squared_error: 0.0903
# Epoch 178/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.0432 - mse: 0.0069 - mae: 0.0432 - root_mean_squared_error: 0.0832 - val_loss: 0.0484 - val_mse: 0.0081 - val_mae: 0.0484 - val_root_mean_squared_error: 0.0902
# Epoch 179/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.0431 - mse: 0.0069 - mae: 0.0431 - root_mean_squared_error: 0.0832 - val_loss: 0.0484 - val_mse: 0.0081 - val_mae: 0.0484 - val_root_mean_squared_error: 0.0903
# Epoch 180/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.0431 - mse: 0.0069 - mae: 0.0431 - root_mean_squared_error: 0.0832 - val_loss: 0.0484 - val_mse: 0.0081 - val_mae: 0.0484 - val_root_mean_squared_error: 0.0902
# Epoch 181/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.0431 - mse: 0.0069 - mae: 0.0431 - root_mean_squared_error: 0.0832 - val_loss: 0.0484 - val_mse: 0.0081 - val_mae: 0.0484 - val_root_mean_squared_error: 0.0902
# Epoch 182/500
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.0431 - mse: 0.0069 - mae: 0.0431 - root_mean_squared_error: 0.0832 - val_loss: 0.0484 - val_mse: 0.0081 - val_mae: 0.0484 - val_root_mean_squared_error: 0.0902
# Epoch 183/500
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.0431 - mse: 0.0069 - mae: 0.0431 - root_mean_squared_error: 0.0832 - val_loss: 0.0483 - val_mse: 0.0081 - val_mae: 0.0483 - val_root_mean_squared_error: 0.0902
# Epoch 184/500
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.0431 - mse: 0.0069 - mae: 0.0431 - root_mean_squared_error: 0.0832 - val_loss: 0.0483 - val_mse: 0.0081 - val_mae: 0.0483 - val_root_mean_squared_error: 0.0902
# Epoch 185/500
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.0431 - mse: 0.0069 - mae: 0.0431 - root_mean_squared_error: 0.0832 - val_loss: 0.0483 - val_mse: 0.0081 - val_mae: 0.0483 - val_root_mean_squared_error: 0.0902
# Epoch 186/500
# 3175/3175 [==============================] - 0s 42us/sample - loss: 0.0431 - mse: 0.0069 - mae: 0.0431 - root_mean_squared_error: 0.0832 - val_loss: 0.0483 - val_mse: 0.0081 - val_mae: 0.0483 - val_root_mean_squared_error: 0.0902
# Epoch 187/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0430 - mse: 0.0069 - mae: 0.0430 - root_mean_squared_error: 0.0832 - val_loss: 0.0483 - val_mse: 0.0081 - val_mae: 0.0483 - val_root_mean_squared_error: 0.0902
# Epoch 188/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0430 - mse: 0.0069 - mae: 0.0430 - root_mean_squared_error: 0.0832 - val_loss: 0.0482 - val_mse: 0.0081 - val_mae: 0.0482 - val_root_mean_squared_error: 0.0902
# Epoch 189/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0430 - mse: 0.0069 - mae: 0.0430 - root_mean_squared_error: 0.0832 - val_loss: 0.0482 - val_mse: 0.0081 - val_mae: 0.0482 - val_root_mean_squared_error: 0.0902
# Epoch 190/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0430 - mse: 0.0069 - mae: 0.0430 - root_mean_squared_error: 0.0832 - val_loss: 0.0482 - val_mse: 0.0081 - val_mae: 0.0482 - val_root_mean_squared_error: 0.0902
# Epoch 191/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0430 - mse: 0.0069 - mae: 0.0430 - root_mean_squared_error: 0.0831 - val_loss: 0.0482 - val_mse: 0.0081 - val_mae: 0.0482 - val_root_mean_squared_error: 0.0902
# Epoch 192/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0430 - mse: 0.0069 - mae: 0.0430 - root_mean_squared_error: 0.0831 - val_loss: 0.0482 - val_mse: 0.0081 - val_mae: 0.0482 - val_root_mean_squared_error: 0.0902
# Epoch 193/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0440 - mse: 0.0074 - mae: 0.0440 - root_mean_squared_error: 0.086 - 0s 27us/sample - loss: 0.0430 - mse: 0.0069 - mae: 0.0430 - root_mean_squared_error: 0.0831 - val_loss: 0.0481 - val_mse: 0.0081 - val_mae: 0.0481 - val_root_mean_squared_error: 0.0901
# Epoch 194/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0430 - mse: 0.0069 - mae: 0.0430 - root_mean_squared_error: 0.0831 - val_loss: 0.0481 - val_mse: 0.0081 - val_mae: 0.0481 - val_root_mean_squared_error: 0.0901
# Epoch 195/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0429 - mse: 0.0069 - mae: 0.0429 - root_mean_squared_error: 0.0831 - val_loss: 0.0481 - val_mse: 0.0081 - val_mae: 0.0481 - val_root_mean_squared_error: 0.0901
# Epoch 196/500
# ...
# Epoch 437/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 438/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 439/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 440/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 441/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 442/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 443/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 444/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 445/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 446/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0436 - mse: 0.0077 - mae: 0.0436 - root_mean_squared_error: 0.087 - 0s 31us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 447/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 448/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0444 - mse: 0.0079 - mae: 0.0444 - root_mean_squared_error: 0.088 - 0s 31us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 449/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 450/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 451/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 452/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 453/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 454/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 455/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 456/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 457/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 458/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 459/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 460/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 461/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 462/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 463/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0417 - mse: 0.0068 - mae: 0.0417 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 464/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 465/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0823 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 466/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 467/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 468/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 469/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 470/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 471/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 472/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 473/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 474/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 475/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 476/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0442 - mse: 0.0077 - mae: 0.0442 - root_mean_squared_error: 0.087 - 0s 30us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 477/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 478/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 479/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 480/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 481/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 482/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 483/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0464 - val_mse: 0.0081 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0898
# Epoch 484/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0463 - val_mse: 0.0081 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0898
# Epoch 485/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0463 - val_mse: 0.0081 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0898
# Epoch 486/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0463 - val_mse: 0.0081 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0898
# Epoch 487/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0463 - val_mse: 0.0081 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0898
# Epoch 488/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0463 - val_mse: 0.0081 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0898
# Epoch 489/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0463 - val_mse: 0.0081 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0898
# Epoch 490/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0068 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0463 - val_mse: 0.0081 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0898
# Epoch 491/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0067 - mae: 0.0416 - root_mean_squared_error: 0.0821 - val_loss: 0.0463 - val_mse: 0.0081 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0898
# Epoch 492/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0416 - mse: 0.0067 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0463 - val_mse: 0.0081 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0898
# Epoch 493/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0067 - mae: 0.0416 - root_mean_squared_error: 0.0822 - val_loss: 0.0463 - val_mse: 0.0081 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0898
# Epoch 494/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0416 - mse: 0.0067 - mae: 0.0416 - root_mean_squared_error: 0.0821 - val_loss: 0.0463 - val_mse: 0.0081 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0898
# Epoch 495/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0067 - mae: 0.0416 - root_mean_squared_error: 0.0821 - val_loss: 0.0463 - val_mse: 0.0081 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0898
# Epoch 496/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0416 - mse: 0.0067 - mae: 0.0416 - root_mean_squared_error: 0.0821 - val_loss: 0.0463 - val_mse: 0.0081 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0898
# Epoch 497/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0416 - mse: 0.0067 - mae: 0.0416 - root_mean_squared_error: 0.0821 - val_loss: 0.0463 - val_mse: 0.0081 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0898
# Epoch 498/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0416 - mse: 0.0067 - mae: 0.0416 - root_mean_squared_error: 0.0821 - val_loss: 0.0463 - val_mse: 0.0081 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0898
# Epoch 499/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0416 - mse: 0.0067 - mae: 0.0416 - root_mean_squared_error: 0.0821 - val_loss: 0.0463 - val_mse: 0.0081 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0898
# Epoch 500/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0416 - mse: 0.0067 - mae: 0.0416 - root_mean_squared_error: 0.0821 - val_loss: 0.0463 - val_mse: 0.0081 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0898

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mae'],label='train mae')
pyplot.plot(history.history['val_mae'],label='val mae')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mse'],label='train mse')
pyplot.plot(history.history['val_mse'],label='val mse')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['root_mean_squared_error'],label='train rmse')
pyplot.plot(history.history['val_root_mean_squared_error'],label='val rmse')
pyplot.legend()
pyplot.show()
# Out:
# The testing MAE loss is: 0.043824833
# The testing MSE loss is: 0.007339268
# The testing RMSE loss is: 0.08566953

# %%
pyplot.plot(test_y[:,4],color='red', label='True Values')
pyplot.plot(out[:,4],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()

# %%
dataset_test=pd.read_excel('F:\MS thesis data/Hopper Crossing.xlsx')
dataset_test=dataset_test.drop(['Date/Time','Flowd'],axis=1)
dataset_test.dropna(inplace=True)

# %%
shape=np.shape(dataset_test)
print(shape)
pyplot.plot(dataset_test)
# Out:
# (26285, 3)
# [<matplotlib.lines.Line2D at 0x2234fefd8c8>,
#  <matplotlib.lines.Line2D at 0x22357244748>,
#  <matplotlib.lines.Line2D at 0x223572444c8>]

# %%
dataset_test
# Out:
#        Cumulative rainfall   Flow  Level
# 0                      0.0  0.093    1.50
# 1                      0.0  0.093    1.50
# 2                      0.0  0.093    1.50
# 3                      0.0  0.093    1.50
# 4                      0.0  0.093    1.50
# ...                    ...    ...     ...
# 26280                  0.2  0.080    1.49
# 26281                  0.2  0.080    1.49
# 26282                  0.2  0.080    1.49
# 26283                  0.2  0.080    1.49
# 26284                  0.2  0.080    1.49
#
# [26285 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset_test)))
# Out:
# The std of original data is Cumulative rainfall    2.451640
# Flow                   0.520832
# Level                  0.083204
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset_test=dataset_test.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset_test.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset_test[:,0]== maxi[0])
    ind2=np.argwhere(dataset_test[:,1]== maxi[1])
    ind3=np.argwhere(dataset_test[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset_test.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset_test[:,0]== mini[0])
    ind2=np.argwhere(dataset_test[:,1]== mini[1])
    ind3=np.argwhere(dataset_test[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset_test)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset_test = min_max_scaler.fit_transform(dataset_test)
# Out:
# The std of cleaned data is 1.5154548293543502

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=5
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values

#one hour
#test_X, test_y = values[:, :-out_hour], values[:,-1]


test_X, test_y = values[:, :-out_hour], values[:, -out_hour: ]


test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6341, 33)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var2(t-2)  var3(t-2)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.524545   0.776699
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.524545   0.776699
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.549980   0.791262
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.603309   0.820388
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.650485   0.844660
#
#     var1(t-1)  var2(t-1)  var3(t-1)   var3(t)  var3(t+1)  var3(t+2)  \
# 6    0.215385   0.524545   0.776699  0.791262   0.820388   0.844660
# 7    0.123077   0.549980   0.791262  0.820388   0.844660   0.873786
# 8    0.092308   0.603309   0.820388  0.844660   0.873786   0.898058
# 9    0.092308   0.650485   0.844660  0.873786   0.898058   0.932039
# 10   0.092308   0.709285   0.873786  0.898058   0.932039   0.966019
#
#     var3(t+3)  var3(t+4)
# 6    0.873786   0.898058
# 7    0.898058   0.932039
# 8    0.932039   0.966019
# 9    0.966019   1.000000
# 10   1.000000   0.941748
#
# [5 rows x 23 columns]

# %%
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
# Out:
# The testing MAE loss is: 0.043276906
# The testing MSE loss is: 0.007226995
# The testing RMSE loss is: 0.085011736

# %%
pyplot.plot(test_y[:,4],color='red', label='True Values')
pyplot.plot(out[:,4],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()
