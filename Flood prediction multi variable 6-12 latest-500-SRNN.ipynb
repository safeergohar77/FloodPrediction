# %%
import pandas as pd
from pandas import concat
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from sklearn import preprocessing
from tensorflow.keras import backend as K
#from sklearn.preprocessing import MinMaxScaler
#from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input, Dense, LSTM,GRU,SimpleRNN, Activation
from matplotlib import pyplot
#from sklearn.model_selection import train_test_split

# %%
"# convert series to supervised learning\n" 
#windowing of data
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1),
    for i in range(n_in, 0, -1): #startes from n_in and decreses to 0 by decreasing each time -1
     cols.append(df.shift(i))
     names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
     cols.append(df.shift(-i))
     if i == 0:
       names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
     else:
       names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together\n",
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values\n",
    if dropnan:
      agg.dropna(inplace=True)
    return agg

# %%
#def root_mean_squared_error(y_true, y_pred):
 #       return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
dataset1=pd.read_excel('F:\MS thesis data/Brooklyn.xlsx')
dataset1=dataset1.drop(['Date/Time','Flowd'],axis=1)
dataset1.dropna(inplace=True)

# %%
shape=np.shape(dataset1)
print(shape)
pyplot.plot(dataset1)
# Out:
# (26302, 3)
# [<matplotlib.lines.Line2D at 0x250b10a4ac8>,
#  <matplotlib.lines.Line2D at 0x250b10a3348>,
#  <matplotlib.lines.Line2D at 0x250b10a3a08>]

# %%
dataset1
# Out:
#        Cumulative rainfall    Flow  Level
# 0                       0.0  0.172   0.352
# 1                       0.0  0.180   0.356
# 2                       0.0  0.180   0.356
# 3                       0.0  0.189   0.360
# 4                       0.0  0.189   0.360
# ...                     ...    ...     ...
# 26297                   0.0  0.025   0.232
# 26298                   0.0  0.023   0.228
# 26299                   0.0  0.023   0.228
# 26300                   0.0  0.023   0.228
# 26301                   0.0  0.023   0.228
#
# [26302 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset1)))
# Out:
# The std of original data is Cumulative rainfall     2.872616
# Flow                    1.306642
# Level                   0.147238
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset=dataset1.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset[:,0]== maxi[0])
    ind2=np.argwhere(dataset[:,1]== maxi[1])
    ind3=np.argwhere(dataset[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset[:,0]== mini[0])
    ind2=np.argwhere(dataset[:,1]== mini[1])
    ind3=np.argwhere(dataset[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset = min_max_scaler.fit_transform(dataset)
# Out:
# The std of cleaned data is 1.626639593959813

# %%
pyplot.plot(dataset)
# Out:
# [<matplotlib.lines.Line2D at 0x250b0a875c8>,
#  <matplotlib.lines.Line2D at 0x250b09035c8>,
#  <matplotlib.lines.Line2D at 0x250b0903788>]

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=12
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values
train_size  = int(len(dataset) * 0.50)
val_size=int(len(dataset) * 0.75)
train_X, train_y = values[0:train_size, :-out_hour], values[0:train_size,-out_hour: ]
val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-out_hour: ]
test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-out_hour:]
#for last hour
#train_X, train_y = values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]  #for only last hour
#val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]
#test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-1]
print(train_X, train_y)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6334, 54)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var3(t+2)  var3(t+3)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.844660   0.873786
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.873786   0.898058
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.898058   0.932039
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.932039   0.966019
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.966019   1.000000
#
#     var3(t+4)  var3(t+5)  var3(t+6)  var3(t+7)  var3(t+8)  var3(t+9)  \
# 6    0.898058   0.932039   0.966019   1.000000   0.941748   0.912621
# 7    0.932039   0.966019   1.000000   0.941748   0.912621   0.800971
# 8    0.966019   1.000000   0.941748   0.912621   0.800971   0.723301
# 9    1.000000   0.941748   0.912621   0.800971   0.723301   0.665049
# 10   0.941748   0.912621   0.800971   0.723301   0.665049   0.616505
#
#     var3(t+10)  var3(t+11)
# 6     0.800971    0.723301
# 7     0.723301    0.665049
# 8     0.665049    0.616505
# 9     0.616505    0.572816
# 10    0.572816    0.548544
#
# [5 rows x 30 columns]
# [[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]
#  [0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]
#  [0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]
#  ...
#  [0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]
#  [0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]
#  [0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]] [[0.79126215 0.8203884  0.8446602  ... 0.9126214  0.80097085 0.723301  ]
#  [0.8203884  0.8446602  0.8737864  ... 0.80097085 0.723301   0.66504854]
#  [0.8446602  0.8737864  0.89805824 ... 0.723301   0.66504854 0.61650485]
#  ...
#  [0.23786408 0.24271844 0.24757281 ... 0.27184466 0.27184466 0.2961165 ]
#  [0.24271844 0.24757281 0.24757281 ... 0.27184466 0.2961165  0.32524273]
#  [0.24757281 0.24757281 0.24757281 ... 0.2961165  0.32524273 0.35436893]]

# %%
print(train_X, train_y)
# Out:
# [[[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]]
#
#  [[0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]]
#
#  [[0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]]
#
#  ...
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]]] [[0.79126215 0.8203884  0.8446602  ... 0.9126214  0.80097085 0.723301  ]
#  [0.8203884  0.8446602  0.8737864  ... 0.80097085 0.723301   0.66504854]
#  [0.8446602  0.8737864  0.89805824 ... 0.723301   0.66504854 0.61650485]
#  ...
#  [0.23786408 0.24271844 0.24757281 ... 0.27184466 0.27184466 0.2961165 ]
#  [0.24271844 0.24757281 0.24757281 ... 0.27184466 0.2961165  0.32524273]
#  [0.24757281 0.24757281 0.24757281 ... 0.2961165  0.32524273 0.35436893]]

# %%
print(train_X.shape, train_y.shape, val_X.shape, val_y.shape)
# Out:
# (3175, 1, 18) (3175, 12) (1588, 1, 18) (1588, 12)

# %%
randomState = 46
np.random.seed(randomState)
#tensorflow.random.set_random_seed(randomState)
tensorflow.random.set_seed(randomState)
model = Sequential()
model.add(SimpleRNN(15,input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dense(22))
#model.add(Activation('relu'))    
model.add(Dense(out_hour,activation = "sigmoid"))
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.001)
#    opt=tensorflow.keras.optimizers.Adam(learning_rate=0.00075)
model.compile(loss='mae', optimizer=opt,metrics=['mse','mae',tensorflow.keras.metrics.RootMeanSquaredError()])
history = model.fit(train_X, train_y,validation_data=(val_X, val_y), epochs=500, batch_size=100,verbose=1,shuffle=False)
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)
# Out:
# Train on 3175 samples, validate on 1588 samples
# Epoch 1/500
# 3175/3175 [==============================] - 1s 359us/sample - loss: 0.2473 - mse: 0.0746 - mae: 0.2473 - root_mean_squared_error: 0.2731 - val_loss: 0.2578 - val_mse: 0.0836 - val_mae: 0.2578 - val_root_mean_squared_error: 0.2891
# Epoch 2/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.2231 - mse: 0.0633 - mae: 0.2231 - root_mean_squared_error: 0.2517 - val_loss: 0.2356 - val_mse: 0.0718 - val_mae: 0.2356 - val_root_mean_squared_error: 0.2680
# Epoch 3/500
# 3175/3175 [==============================] - 0s 19us/sample - loss: 0.2027 - mse: 0.0556 - mae: 0.2027 - root_mean_squared_error: 0.2358 - val_loss: 0.2165 - val_mse: 0.0629 - val_mae: 0.2165 - val_root_mean_squared_error: 0.2507
# Epoch 4/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1866 - mse: 0.0507 - mae: 0.1866 - root_mean_squared_error: 0.2252 - val_loss: 0.2017 - val_mse: 0.0566 - val_mae: 0.2017 - val_root_mean_squared_error: 0.2379
# Epoch 5/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.1750 - mse: 0.0480 - mae: 0.1750 - root_mean_squared_error: 0.2190 - val_loss: 0.1908 - val_mse: 0.0524 - val_mae: 0.1908 - val_root_mean_squared_error: 0.2289
# Epoch 6/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1668 - mse: 0.0462 - mae: 0.1668 - root_mean_squared_error: 0.2150 - val_loss: 0.1824 - val_mse: 0.0492 - val_mae: 0.1824 - val_root_mean_squared_error: 0.2218
# Epoch 7/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1601 - mse: 0.0446 - mae: 0.1601 - root_mean_squared_error: 0.2112 - val_loss: 0.1752 - val_mse: 0.0463 - val_mae: 0.1752 - val_root_mean_squared_error: 0.2153
# Epoch 8/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.1541 - mse: 0.0426 - mae: 0.1541 - root_mean_squared_error: 0.2065 - val_loss: 0.1685 - val_mse: 0.0434 - val_mae: 0.1685 - val_root_mean_squared_error: 0.2084
# Epoch 9/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.1481 - mse: 0.0401 - mae: 0.1481 - root_mean_squared_error: 0.2003 - val_loss: 0.1619 - val_mse: 0.0404 - val_mae: 0.1619 - val_root_mean_squared_error: 0.2010
# Epoch 10/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1418 - mse: 0.0373 - mae: 0.1418 - root_mean_squared_error: 0.1930 - val_loss: 0.1552 - val_mse: 0.0373 - val_mae: 0.1552 - val_root_mean_squared_error: 0.1932
# Epoch 11/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.1357 - mse: 0.0342 - mae: 0.1357 - root_mean_squared_error: 0.1850 - val_loss: 0.1484 - val_mse: 0.0344 - val_mae: 0.1484 - val_root_mean_squared_error: 0.1854
# Epoch 12/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1296 - mse: 0.0313 - mae: 0.1296 - root_mean_squared_error: 0.1770 - val_loss: 0.1416 - val_mse: 0.0316 - val_mae: 0.1416 - val_root_mean_squared_error: 0.1777
# Epoch 13/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.1239 - mse: 0.0286 - mae: 0.1239 - root_mean_squared_error: 0.1692 - val_loss: 0.1351 - val_mse: 0.0291 - val_mae: 0.1351 - val_root_mean_squared_error: 0.1705
# Epoch 14/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.1186 - mse: 0.0263 - mae: 0.1186 - root_mean_squared_error: 0.1622 - val_loss: 0.1291 - val_mse: 0.0269 - val_mae: 0.1291 - val_root_mean_squared_error: 0.1640
# Epoch 15/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.1137 - mse: 0.0244 - mae: 0.1137 - root_mean_squared_error: 0.1561 - val_loss: 0.1235 - val_mse: 0.0251 - val_mae: 0.1235 - val_root_mean_squared_error: 0.1583
# Epoch 16/500
# 3175/3175 [==============================] - 0s 41us/sample - loss: 0.1094 - mse: 0.0228 - mae: 0.1094 - root_mean_squared_error: 0.1510 - val_loss: 0.1185 - val_mse: 0.0235 - val_mae: 0.1185 - val_root_mean_squared_error: 0.1534
# Epoch 17/500
# 3175/3175 [==============================] - 0s 42us/sample - loss: 0.1055 - mse: 0.0216 - mae: 0.1055 - root_mean_squared_error: 0.1470 - val_loss: 0.1140 - val_mse: 0.0223 - val_mae: 0.1140 - val_root_mean_squared_error: 0.1492
# Epoch 18/500
# 3175/3175 [==============================] - 0s 46us/sample - loss: 0.1021 - mse: 0.0207 - mae: 0.1021 - root_mean_squared_error: 0.1437 - val_loss: 0.1100 - val_mse: 0.0213 - val_mae: 0.1100 - val_root_mean_squared_error: 0.1458
# Epoch 19/500
# 3175/3175 [==============================] - 0s 43us/sample - loss: 0.0992 - mse: 0.0199 - mae: 0.0992 - root_mean_squared_error: 0.1412 - val_loss: 0.1064 - val_mse: 0.0204 - val_mae: 0.1064 - val_root_mean_squared_error: 0.1429
# Epoch 20/500
# 3175/3175 [==============================] - 0s 41us/sample - loss: 0.0965 - mse: 0.0194 - mae: 0.0965 - root_mean_squared_error: 0.1391 - val_loss: 0.1032 - val_mse: 0.0197 - val_mae: 0.1032 - val_root_mean_squared_error: 0.1405
# Epoch 21/500
# 3175/3175 [==============================] - 0s 42us/sample - loss: 0.0942 - mse: 0.0189 - mae: 0.0942 - root_mean_squared_error: 0.1375 - val_loss: 0.1004 - val_mse: 0.0192 - val_mae: 0.1004 - val_root_mean_squared_error: 0.1385
# Epoch 22/500
# 3175/3175 [==============================] - 0s 42us/sample - loss: 0.0922 - mse: 0.0186 - mae: 0.0922 - root_mean_squared_error: 0.1363 - val_loss: 0.0979 - val_mse: 0.0187 - val_mae: 0.0979 - val_root_mean_squared_error: 0.1368
# Epoch 23/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0904 - mse: 0.0183 - mae: 0.0904 - root_mean_squared_error: 0.1352 - val_loss: 0.0958 - val_mse: 0.0183 - val_mae: 0.0958 - val_root_mean_squared_error: 0.1354
# Epoch 24/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0889 - mse: 0.0180 - mae: 0.0889 - root_mean_squared_error: 0.1343 - val_loss: 0.0939 - val_mse: 0.0180 - val_mae: 0.0939 - val_root_mean_squared_error: 0.1342
# Epoch 25/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0875 - mse: 0.0178 - mae: 0.0875 - root_mean_squared_error: 0.1335 - val_loss: 0.0922 - val_mse: 0.0177 - val_mae: 0.0922 - val_root_mean_squared_error: 0.1331
# Epoch 26/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0864 - mse: 0.0176 - mae: 0.0864 - root_mean_squared_error: 0.1328 - val_loss: 0.0908 - val_mse: 0.0175 - val_mae: 0.0908 - val_root_mean_squared_error: 0.1322
# Epoch 27/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0853 - mse: 0.0174 - mae: 0.0853 - root_mean_squared_error: 0.1321 - val_loss: 0.0895 - val_mse: 0.0173 - val_mae: 0.0895 - val_root_mean_squared_error: 0.1314
# Epoch 28/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0844 - mse: 0.0173 - mae: 0.0844 - root_mean_squared_error: 0.1314 - val_loss: 0.0883 - val_mse: 0.0170 - val_mae: 0.0883 - val_root_mean_squared_error: 0.1305
# Epoch 29/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0835 - mse: 0.0171 - mae: 0.0835 - root_mean_squared_error: 0.1307 - val_loss: 0.0872 - val_mse: 0.0168 - val_mae: 0.0872 - val_root_mean_squared_error: 0.1298
# Epoch 30/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0827 - mse: 0.0169 - mae: 0.0827 - root_mean_squared_error: 0.1301 - val_loss: 0.0862 - val_mse: 0.0167 - val_mae: 0.0862 - val_root_mean_squared_error: 0.1291
# Epoch 31/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0819 - mse: 0.0168 - mae: 0.0819 - root_mean_squared_error: 0.1294 - val_loss: 0.0853 - val_mse: 0.0165 - val_mae: 0.0853 - val_root_mean_squared_error: 0.1284
# Epoch 32/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0812 - mse: 0.0166 - mae: 0.0812 - root_mean_squared_error: 0.1288 - val_loss: 0.0844 - val_mse: 0.0163 - val_mae: 0.0844 - val_root_mean_squared_error: 0.1277
# Epoch 33/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0806 - mse: 0.0164 - mae: 0.0806 - root_mean_squared_error: 0.1281 - val_loss: 0.0837 - val_mse: 0.0162 - val_mae: 0.0837 - val_root_mean_squared_error: 0.1271
# Epoch 34/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0800 - mse: 0.0163 - mae: 0.0800 - root_mean_squared_error: 0.1275 - val_loss: 0.0830 - val_mse: 0.0160 - val_mae: 0.0830 - val_root_mean_squared_error: 0.1265
# Epoch 35/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0794 - mse: 0.0161 - mae: 0.0794 - root_mean_squared_error: 0.1269 - val_loss: 0.0823 - val_mse: 0.0159 - val_mae: 0.0823 - val_root_mean_squared_error: 0.1260
# Epoch 36/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0788 - mse: 0.0159 - mae: 0.0788 - root_mean_squared_error: 0.1263 - val_loss: 0.0817 - val_mse: 0.0157 - val_mae: 0.0817 - val_root_mean_squared_error: 0.1254
# Epoch 37/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0784 - mse: 0.0158 - mae: 0.0784 - root_mean_squared_error: 0.1257 - val_loss: 0.0811 - val_mse: 0.0156 - val_mae: 0.0811 - val_root_mean_squared_error: 0.1249
# Epoch 38/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0779 - mse: 0.0157 - mae: 0.0779 - root_mean_squared_error: 0.1252 - val_loss: 0.0806 - val_mse: 0.0155 - val_mae: 0.0806 - val_root_mean_squared_error: 0.1244
# Epoch 39/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0775 - mse: 0.0155 - mae: 0.0775 - root_mean_squared_error: 0.1246 - val_loss: 0.0801 - val_mse: 0.0154 - val_mae: 0.0801 - val_root_mean_squared_error: 0.1240
# Epoch 40/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0771 - mse: 0.0154 - mae: 0.0771 - root_mean_squared_error: 0.1241 - val_loss: 0.0797 - val_mse: 0.0153 - val_mae: 0.0797 - val_root_mean_squared_error: 0.1236
# Epoch 41/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0767 - mse: 0.0153 - mae: 0.0767 - root_mean_squared_error: 0.1237 - val_loss: 0.0793 - val_mse: 0.0152 - val_mae: 0.0793 - val_root_mean_squared_error: 0.1232
# Epoch 42/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0764 - mse: 0.0152 - mae: 0.0764 - root_mean_squared_error: 0.1233 - val_loss: 0.0789 - val_mse: 0.0151 - val_mae: 0.0789 - val_root_mean_squared_error: 0.1229
# Epoch 43/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0761 - mse: 0.0151 - mae: 0.0761 - root_mean_squared_error: 0.1229 - val_loss: 0.0785 - val_mse: 0.0150 - val_mae: 0.0785 - val_root_mean_squared_error: 0.1225
# Epoch 44/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0758 - mse: 0.0150 - mae: 0.0758 - root_mean_squared_error: 0.1225 - val_loss: 0.0782 - val_mse: 0.0149 - val_mae: 0.0782 - val_root_mean_squared_error: 0.1222
# Epoch 45/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0755 - mse: 0.0149 - mae: 0.0755 - root_mean_squared_error: 0.1221 - val_loss: 0.0779 - val_mse: 0.0149 - val_mae: 0.0779 - val_root_mean_squared_error: 0.1219
# Epoch 46/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0753 - mse: 0.0148 - mae: 0.0753 - root_mean_squared_error: 0.1218 - val_loss: 0.0776 - val_mse: 0.0148 - val_mae: 0.0776 - val_root_mean_squared_error: 0.1217
# Epoch 47/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0751 - mse: 0.0148 - mae: 0.0751 - root_mean_squared_error: 0.1215 - val_loss: 0.0773 - val_mse: 0.0147 - val_mae: 0.0773 - val_root_mean_squared_error: 0.1214
# Epoch 48/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0748 - mse: 0.0147 - mae: 0.0748 - root_mean_squared_error: 0.1212 - val_loss: 0.0771 - val_mse: 0.0147 - val_mae: 0.0771 - val_root_mean_squared_error: 0.1212
# Epoch 49/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0746 - mse: 0.0146 - mae: 0.0746 - root_mean_squared_error: 0.1209 - val_loss: 0.0768 - val_mse: 0.0146 - val_mae: 0.0768 - val_root_mean_squared_error: 0.1210
# Epoch 50/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0744 - mse: 0.0146 - mae: 0.0744 - root_mean_squared_error: 0.1206 - val_loss: 0.0766 - val_mse: 0.0146 - val_mae: 0.0766 - val_root_mean_squared_error: 0.1208
# Epoch 51/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0743 - mse: 0.0145 - mae: 0.0743 - root_mean_squared_error: 0.1204 - val_loss: 0.0764 - val_mse: 0.0145 - val_mae: 0.0764 - val_root_mean_squared_error: 0.1206
# Epoch 52/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0741 - mse: 0.0144 - mae: 0.0741 - root_mean_squared_error: 0.1202 - val_loss: 0.0762 - val_mse: 0.0145 - val_mae: 0.0762 - val_root_mean_squared_error: 0.1204
# Epoch 53/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0739 - mse: 0.0144 - mae: 0.0739 - root_mean_squared_error: 0.1199 - val_loss: 0.0760 - val_mse: 0.0145 - val_mae: 0.0760 - val_root_mean_squared_error: 0.1203
# Epoch 54/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0738 - mse: 0.0143 - mae: 0.0738 - root_mean_squared_error: 0.1197 - val_loss: 0.0758 - val_mse: 0.0144 - val_mae: 0.0758 - val_root_mean_squared_error: 0.1201
# Epoch 55/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0736 - mse: 0.0143 - mae: 0.0736 - root_mean_squared_error: 0.1195 - val_loss: 0.0756 - val_mse: 0.0144 - val_mae: 0.0756 - val_root_mean_squared_error: 0.1200
# Epoch 56/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0735 - mse: 0.0142 - mae: 0.0735 - root_mean_squared_error: 0.1193 - val_loss: 0.0755 - val_mse: 0.0144 - val_mae: 0.0755 - val_root_mean_squared_error: 0.1198
# Epoch 57/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0733 - mse: 0.0142 - mae: 0.0733 - root_mean_squared_error: 0.1191 - val_loss: 0.0753 - val_mse: 0.0143 - val_mae: 0.0753 - val_root_mean_squared_error: 0.1197
# Epoch 58/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0732 - mse: 0.0141 - mae: 0.0732 - root_mean_squared_error: 0.1189 - val_loss: 0.0751 - val_mse: 0.0143 - val_mae: 0.0751 - val_root_mean_squared_error: 0.1195
# Epoch 59/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0731 - mse: 0.0141 - mae: 0.0731 - root_mean_squared_error: 0.1187 - val_loss: 0.0750 - val_mse: 0.0143 - val_mae: 0.0750 - val_root_mean_squared_error: 0.1194
# Epoch 60/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0730 - mse: 0.0141 - mae: 0.0730 - root_mean_squared_error: 0.1186 - val_loss: 0.0748 - val_mse: 0.0142 - val_mae: 0.0748 - val_root_mean_squared_error: 0.1193
# Epoch 61/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0728 - mse: 0.0140 - mae: 0.0728 - root_mean_squared_error: 0.1184 - val_loss: 0.0747 - val_mse: 0.0142 - val_mae: 0.0747 - val_root_mean_squared_error: 0.1192
# Epoch 62/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0727 - mse: 0.0140 - mae: 0.0727 - root_mean_squared_error: 0.1183 - val_loss: 0.0746 - val_mse: 0.0142 - val_mae: 0.0746 - val_root_mean_squared_error: 0.1191
# Epoch 63/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0726 - mse: 0.0140 - mae: 0.0726 - root_mean_squared_error: 0.1181 - val_loss: 0.0744 - val_mse: 0.0142 - val_mae: 0.0744 - val_root_mean_squared_error: 0.1190
# Epoch 64/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0725 - mse: 0.0139 - mae: 0.0725 - root_mean_squared_error: 0.1180 - val_loss: 0.0743 - val_mse: 0.0141 - val_mae: 0.0743 - val_root_mean_squared_error: 0.1188
# Epoch 65/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0724 - mse: 0.0139 - mae: 0.0724 - root_mean_squared_error: 0.1179 - val_loss: 0.0742 - val_mse: 0.0141 - val_mae: 0.0742 - val_root_mean_squared_error: 0.1187
# Epoch 66/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0723 - mse: 0.0139 - mae: 0.0723 - root_mean_squared_error: 0.1177 - val_loss: 0.0741 - val_mse: 0.0141 - val_mae: 0.0741 - val_root_mean_squared_error: 0.1187
# Epoch 67/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0722 - mse: 0.0138 - mae: 0.0722 - root_mean_squared_error: 0.1176 - val_loss: 0.0739 - val_mse: 0.0141 - val_mae: 0.0739 - val_root_mean_squared_error: 0.1186
# Epoch 68/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0721 - mse: 0.0138 - mae: 0.0721 - root_mean_squared_error: 0.1175 - val_loss: 0.0738 - val_mse: 0.0140 - val_mae: 0.0738 - val_root_mean_squared_error: 0.1185
# Epoch 69/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0720 - mse: 0.0138 - mae: 0.0720 - root_mean_squared_error: 0.1174 - val_loss: 0.0737 - val_mse: 0.0140 - val_mae: 0.0737 - val_root_mean_squared_error: 0.1184
# Epoch 70/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0719 - mse: 0.0137 - mae: 0.0719 - root_mean_squared_error: 0.1173 - val_loss: 0.0736 - val_mse: 0.0140 - val_mae: 0.0736 - val_root_mean_squared_error: 0.1183
# Epoch 71/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0718 - mse: 0.0137 - mae: 0.0718 - root_mean_squared_error: 0.1171 - val_loss: 0.0735 - val_mse: 0.0140 - val_mae: 0.0735 - val_root_mean_squared_error: 0.1182
# Epoch 72/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.1398 - mse: 0.0353 - mae: 0.1398 - root_mean_squared_error: 0.187 - 0s 21us/sample - loss: 0.0717 - mse: 0.0137 - mae: 0.0717 - root_mean_squared_error: 0.1170 - val_loss: 0.0734 - val_mse: 0.0139 - val_mae: 0.0734 - val_root_mean_squared_error: 0.1181
# Epoch 73/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0716 - mse: 0.0137 - mae: 0.0716 - root_mean_squared_error: 0.1169 - val_loss: 0.0733 - val_mse: 0.0139 - val_mae: 0.0733 - val_root_mean_squared_error: 0.1180
# Epoch 74/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0715 - mse: 0.0137 - mae: 0.0715 - root_mean_squared_error: 0.1168 - val_loss: 0.0732 - val_mse: 0.0139 - val_mae: 0.0732 - val_root_mean_squared_error: 0.1179
# Epoch 75/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0714 - mse: 0.0136 - mae: 0.0714 - root_mean_squared_error: 0.1167 - val_loss: 0.0731 - val_mse: 0.0139 - val_mae: 0.0731 - val_root_mean_squared_error: 0.1178
# Epoch 76/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0713 - mse: 0.0136 - mae: 0.0713 - root_mean_squared_error: 0.1166 - val_loss: 0.0730 - val_mse: 0.0139 - val_mae: 0.0730 - val_root_mean_squared_error: 0.1177
# Epoch 77/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0712 - mse: 0.0136 - mae: 0.0712 - root_mean_squared_error: 0.1165 - val_loss: 0.0729 - val_mse: 0.0138 - val_mae: 0.0729 - val_root_mean_squared_error: 0.1177
# Epoch 78/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0711 - mse: 0.0136 - mae: 0.0711 - root_mean_squared_error: 0.1164 - val_loss: 0.0728 - val_mse: 0.0138 - val_mae: 0.0728 - val_root_mean_squared_error: 0.1176
# Epoch 79/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0711 - mse: 0.0135 - mae: 0.0711 - root_mean_squared_error: 0.1164 - val_loss: 0.0727 - val_mse: 0.0138 - val_mae: 0.0727 - val_root_mean_squared_error: 0.1175
# Epoch 80/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0710 - mse: 0.0135 - mae: 0.0710 - root_mean_squared_error: 0.1163 - val_loss: 0.0726 - val_mse: 0.0138 - val_mae: 0.0726 - val_root_mean_squared_error: 0.1174
# Epoch 81/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0709 - mse: 0.0135 - mae: 0.0709 - root_mean_squared_error: 0.1162 - val_loss: 0.0725 - val_mse: 0.0138 - val_mae: 0.0725 - val_root_mean_squared_error: 0.1174
# Epoch 82/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0708 - mse: 0.0135 - mae: 0.0708 - root_mean_squared_error: 0.1161 - val_loss: 0.0724 - val_mse: 0.0138 - val_mae: 0.0724 - val_root_mean_squared_error: 0.1173
# Epoch 83/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0708 - mse: 0.0135 - mae: 0.0708 - root_mean_squared_error: 0.1160 - val_loss: 0.0724 - val_mse: 0.0137 - val_mae: 0.0724 - val_root_mean_squared_error: 0.1172
# Epoch 84/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0707 - mse: 0.0134 - mae: 0.0707 - root_mean_squared_error: 0.1159 - val_loss: 0.0723 - val_mse: 0.0137 - val_mae: 0.0723 - val_root_mean_squared_error: 0.1172
# Epoch 85/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0706 - mse: 0.0134 - mae: 0.0706 - root_mean_squared_error: 0.1158 - val_loss: 0.0722 - val_mse: 0.0137 - val_mae: 0.0722 - val_root_mean_squared_error: 0.1171
# Epoch 86/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0705 - mse: 0.0134 - mae: 0.0705 - root_mean_squared_error: 0.1158 - val_loss: 0.0721 - val_mse: 0.0137 - val_mae: 0.0721 - val_root_mean_squared_error: 0.1170
# Epoch 87/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0705 - mse: 0.0134 - mae: 0.0705 - root_mean_squared_error: 0.1157 - val_loss: 0.0720 - val_mse: 0.0137 - val_mae: 0.0720 - val_root_mean_squared_error: 0.1169
# Epoch 88/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0704 - mse: 0.0134 - mae: 0.0704 - root_mean_squared_error: 0.1156 - val_loss: 0.0719 - val_mse: 0.0137 - val_mae: 0.0719 - val_root_mean_squared_error: 0.1169
# Epoch 89/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.1394 - mse: 0.0356 - mae: 0.1394 - root_mean_squared_error: 0.188 - 0s 22us/sample - loss: 0.0703 - mse: 0.0133 - mae: 0.0703 - root_mean_squared_error: 0.1155 - val_loss: 0.0719 - val_mse: 0.0136 - val_mae: 0.0719 - val_root_mean_squared_error: 0.1168
# Epoch 90/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0703 - mse: 0.0133 - mae: 0.0703 - root_mean_squared_error: 0.1155 - val_loss: 0.0718 - val_mse: 0.0136 - val_mae: 0.0718 - val_root_mean_squared_error: 0.1168
# Epoch 91/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0702 - mse: 0.0133 - mae: 0.0702 - root_mean_squared_error: 0.1154 - val_loss: 0.0717 - val_mse: 0.0136 - val_mae: 0.0717 - val_root_mean_squared_error: 0.1167
# Epoch 92/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0701 - mse: 0.0133 - mae: 0.0701 - root_mean_squared_error: 0.1153 - val_loss: 0.0717 - val_mse: 0.0136 - val_mae: 0.0717 - val_root_mean_squared_error: 0.1166
# Epoch 93/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0701 - mse: 0.0133 - mae: 0.0701 - root_mean_squared_error: 0.1153 - val_loss: 0.0716 - val_mse: 0.0136 - val_mae: 0.0716 - val_root_mean_squared_error: 0.1166
# Epoch 94/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0700 - mse: 0.0133 - mae: 0.0700 - root_mean_squared_error: 0.1152 - val_loss: 0.0715 - val_mse: 0.0136 - val_mae: 0.0715 - val_root_mean_squared_error: 0.1165
# Epoch 95/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0700 - mse: 0.0133 - mae: 0.0700 - root_mean_squared_error: 0.1152 - val_loss: 0.0714 - val_mse: 0.0136 - val_mae: 0.0714 - val_root_mean_squared_error: 0.1165
# Epoch 96/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0699 - mse: 0.0132 - mae: 0.0699 - root_mean_squared_error: 0.1151 - val_loss: 0.0714 - val_mse: 0.0136 - val_mae: 0.0714 - val_root_mean_squared_error: 0.1164
# Epoch 97/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0698 - mse: 0.0132 - mae: 0.0698 - root_mean_squared_error: 0.1150 - val_loss: 0.0713 - val_mse: 0.0135 - val_mae: 0.0713 - val_root_mean_squared_error: 0.1164
# Epoch 98/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0698 - mse: 0.0132 - mae: 0.0698 - root_mean_squared_error: 0.1150 - val_loss: 0.0712 - val_mse: 0.0135 - val_mae: 0.0712 - val_root_mean_squared_error: 0.1163
# Epoch 99/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0697 - mse: 0.0132 - mae: 0.0697 - root_mean_squared_error: 0.1149 - val_loss: 0.0712 - val_mse: 0.0135 - val_mae: 0.0712 - val_root_mean_squared_error: 0.1163
# Epoch 100/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0697 - mse: 0.0132 - mae: 0.0697 - root_mean_squared_error: 0.1149 - val_loss: 0.0711 - val_mse: 0.0135 - val_mae: 0.0711 - val_root_mean_squared_error: 0.1162
# Epoch 101/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0696 - mse: 0.0132 - mae: 0.0696 - root_mean_squared_error: 0.1148 - val_loss: 0.0711 - val_mse: 0.0135 - val_mae: 0.0711 - val_root_mean_squared_error: 0.1162
# Epoch 102/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0696 - mse: 0.0132 - mae: 0.0696 - root_mean_squared_error: 0.1148 - val_loss: 0.0710 - val_mse: 0.0135 - val_mae: 0.0710 - val_root_mean_squared_error: 0.1161
# Epoch 103/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0695 - mse: 0.0132 - mae: 0.0695 - root_mean_squared_error: 0.1147 - val_loss: 0.0710 - val_mse: 0.0135 - val_mae: 0.0710 - val_root_mean_squared_error: 0.1161
# Epoch 104/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0695 - mse: 0.0131 - mae: 0.0695 - root_mean_squared_error: 0.1147 - val_loss: 0.0709 - val_mse: 0.0135 - val_mae: 0.0709 - val_root_mean_squared_error: 0.1160
# Epoch 105/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0694 - mse: 0.0131 - mae: 0.0694 - root_mean_squared_error: 0.1146 - val_loss: 0.0708 - val_mse: 0.0134 - val_mae: 0.0708 - val_root_mean_squared_error: 0.1160
# Epoch 106/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0694 - mse: 0.0131 - mae: 0.0694 - root_mean_squared_error: 0.1146 - val_loss: 0.0708 - val_mse: 0.0134 - val_mae: 0.0708 - val_root_mean_squared_error: 0.1159
# Epoch 107/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0694 - mse: 0.0131 - mae: 0.0694 - root_mean_squared_error: 0.1145 - val_loss: 0.0707 - val_mse: 0.0134 - val_mae: 0.0707 - val_root_mean_squared_error: 0.1159
# Epoch 108/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0693 - mse: 0.0131 - mae: 0.0693 - root_mean_squared_error: 0.1145 - val_loss: 0.0707 - val_mse: 0.0134 - val_mae: 0.0707 - val_root_mean_squared_error: 0.1158
# Epoch 109/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0693 - mse: 0.0131 - mae: 0.0693 - root_mean_squared_error: 0.1144 - val_loss: 0.0706 - val_mse: 0.0134 - val_mae: 0.0706 - val_root_mean_squared_error: 0.1158
# Epoch 110/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0692 - mse: 0.0131 - mae: 0.0692 - root_mean_squared_error: 0.1144 - val_loss: 0.0706 - val_mse: 0.0134 - val_mae: 0.0706 - val_root_mean_squared_error: 0.1158
# Epoch 111/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0692 - mse: 0.0131 - mae: 0.0692 - root_mean_squared_error: 0.1143 - val_loss: 0.0706 - val_mse: 0.0134 - val_mae: 0.0706 - val_root_mean_squared_error: 0.1157
# Epoch 112/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0691 - mse: 0.0131 - mae: 0.0691 - root_mean_squared_error: 0.1143 - val_loss: 0.0705 - val_mse: 0.0134 - val_mae: 0.0705 - val_root_mean_squared_error: 0.1157
# Epoch 113/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0691 - mse: 0.0131 - mae: 0.0691 - root_mean_squared_error: 0.1142 - val_loss: 0.0705 - val_mse: 0.0134 - val_mae: 0.0705 - val_root_mean_squared_error: 0.1157
# Epoch 114/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0691 - mse: 0.0130 - mae: 0.0691 - root_mean_squared_error: 0.1142 - val_loss: 0.0704 - val_mse: 0.0134 - val_mae: 0.0704 - val_root_mean_squared_error: 0.1156
# Epoch 115/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0690 - mse: 0.0130 - mae: 0.0690 - root_mean_squared_error: 0.1142 - val_loss: 0.0704 - val_mse: 0.0134 - val_mae: 0.0704 - val_root_mean_squared_error: 0.1156
# Epoch 116/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0690 - mse: 0.0130 - mae: 0.0690 - root_mean_squared_error: 0.1141 - val_loss: 0.0703 - val_mse: 0.0134 - val_mae: 0.0703 - val_root_mean_squared_error: 0.1156
# Epoch 117/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0690 - mse: 0.0130 - mae: 0.0690 - root_mean_squared_error: 0.1141 - val_loss: 0.0703 - val_mse: 0.0133 - val_mae: 0.0703 - val_root_mean_squared_error: 0.1155
# Epoch 118/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0689 - mse: 0.0130 - mae: 0.0689 - root_mean_squared_error: 0.1141 - val_loss: 0.0703 - val_mse: 0.0133 - val_mae: 0.0703 - val_root_mean_squared_error: 0.1155
# Epoch 119/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0689 - mse: 0.0130 - mae: 0.0689 - root_mean_squared_error: 0.1140 - val_loss: 0.0702 - val_mse: 0.0133 - val_mae: 0.0702 - val_root_mean_squared_error: 0.1155
# Epoch 120/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0688 - mse: 0.0130 - mae: 0.0688 - root_mean_squared_error: 0.1140 - val_loss: 0.0702 - val_mse: 0.0133 - val_mae: 0.0702 - val_root_mean_squared_error: 0.1154
# Epoch 121/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0688 - mse: 0.0130 - mae: 0.0688 - root_mean_squared_error: 0.1139 - val_loss: 0.0701 - val_mse: 0.0133 - val_mae: 0.0701 - val_root_mean_squared_error: 0.1154
# Epoch 122/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0688 - mse: 0.0130 - mae: 0.0688 - root_mean_squared_error: 0.1139 - val_loss: 0.0701 - val_mse: 0.0133 - val_mae: 0.0701 - val_root_mean_squared_error: 0.1154
# Epoch 123/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0687 - mse: 0.0130 - mae: 0.0687 - root_mean_squared_error: 0.1139 - val_loss: 0.0701 - val_mse: 0.0133 - val_mae: 0.0701 - val_root_mean_squared_error: 0.1154
# Epoch 124/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0687 - mse: 0.0130 - mae: 0.0687 - root_mean_squared_error: 0.1138 - val_loss: 0.0700 - val_mse: 0.0133 - val_mae: 0.0700 - val_root_mean_squared_error: 0.1153
# Epoch 125/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0687 - mse: 0.0130 - mae: 0.0687 - root_mean_squared_error: 0.1138 - val_loss: 0.0700 - val_mse: 0.0133 - val_mae: 0.0700 - val_root_mean_squared_error: 0.1153
# Epoch 126/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0687 - mse: 0.0129 - mae: 0.0687 - root_mean_squared_error: 0.1138 - val_loss: 0.0700 - val_mse: 0.0133 - val_mae: 0.0700 - val_root_mean_squared_error: 0.1153
# Epoch 127/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0686 - mse: 0.0129 - mae: 0.0686 - root_mean_squared_error: 0.1138 - val_loss: 0.0699 - val_mse: 0.0133 - val_mae: 0.0699 - val_root_mean_squared_error: 0.1153
# Epoch 128/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0686 - mse: 0.0129 - mae: 0.0686 - root_mean_squared_error: 0.1137 - val_loss: 0.0699 - val_mse: 0.0133 - val_mae: 0.0699 - val_root_mean_squared_error: 0.1152
# Epoch 129/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0686 - mse: 0.0129 - mae: 0.0686 - root_mean_squared_error: 0.1137 - val_loss: 0.0699 - val_mse: 0.0133 - val_mae: 0.0699 - val_root_mean_squared_error: 0.1152
# Epoch 130/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0685 - mse: 0.0129 - mae: 0.0685 - root_mean_squared_error: 0.1137 - val_loss: 0.0698 - val_mse: 0.0133 - val_mae: 0.0698 - val_root_mean_squared_error: 0.1152
# Epoch 131/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0685 - mse: 0.0129 - mae: 0.0685 - root_mean_squared_error: 0.1136 - val_loss: 0.0698 - val_mse: 0.0133 - val_mae: 0.0698 - val_root_mean_squared_error: 0.1152
# Epoch 132/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0685 - mse: 0.0129 - mae: 0.0685 - root_mean_squared_error: 0.1136 - val_loss: 0.0698 - val_mse: 0.0133 - val_mae: 0.0698 - val_root_mean_squared_error: 0.1151
# Epoch 133/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0684 - mse: 0.0129 - mae: 0.0684 - root_mean_squared_error: 0.1136 - val_loss: 0.0697 - val_mse: 0.0132 - val_mae: 0.0697 - val_root_mean_squared_error: 0.1151
# Epoch 134/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0684 - mse: 0.0129 - mae: 0.0684 - root_mean_squared_error: 0.1135 - val_loss: 0.0697 - val_mse: 0.0132 - val_mae: 0.0697 - val_root_mean_squared_error: 0.1151
# Epoch 135/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0684 - mse: 0.0129 - mae: 0.0684 - root_mean_squared_error: 0.1135 - val_loss: 0.0697 - val_mse: 0.0132 - val_mae: 0.0697 - val_root_mean_squared_error: 0.1151
# Epoch 136/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0684 - mse: 0.0129 - mae: 0.0684 - root_mean_squared_error: 0.1135 - val_loss: 0.0697 - val_mse: 0.0132 - val_mae: 0.0697 - val_root_mean_squared_error: 0.1150
# Epoch 137/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0683 - mse: 0.0129 - mae: 0.0683 - root_mean_squared_error: 0.1135 - val_loss: 0.0696 - val_mse: 0.0132 - val_mae: 0.0696 - val_root_mean_squared_error: 0.1150
# Epoch 138/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0683 - mse: 0.0129 - mae: 0.0683 - root_mean_squared_error: 0.1134 - val_loss: 0.0696 - val_mse: 0.0132 - val_mae: 0.0696 - val_root_mean_squared_error: 0.1150
# Epoch 139/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0683 - mse: 0.0129 - mae: 0.0683 - root_mean_squared_error: 0.1134 - val_loss: 0.0696 - val_mse: 0.0132 - val_mae: 0.0696 - val_root_mean_squared_error: 0.1150
# Epoch 140/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0683 - mse: 0.0129 - mae: 0.0683 - root_mean_squared_error: 0.1134 - val_loss: 0.0696 - val_mse: 0.0132 - val_mae: 0.0696 - val_root_mean_squared_error: 0.1149
# Epoch 141/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0682 - mse: 0.0129 - mae: 0.0682 - root_mean_squared_error: 0.1134 - val_loss: 0.0695 - val_mse: 0.0132 - val_mae: 0.0695 - val_root_mean_squared_error: 0.1149
# Epoch 142/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0682 - mse: 0.0128 - mae: 0.0682 - root_mean_squared_error: 0.1133 - val_loss: 0.0695 - val_mse: 0.0132 - val_mae: 0.0695 - val_root_mean_squared_error: 0.1149
# Epoch 143/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0682 - mse: 0.0128 - mae: 0.0682 - root_mean_squared_error: 0.1133 - val_loss: 0.0695 - val_mse: 0.0132 - val_mae: 0.0695 - val_root_mean_squared_error: 0.1149
# Epoch 144/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0682 - mse: 0.0128 - mae: 0.0682 - root_mean_squared_error: 0.1133 - val_loss: 0.0694 - val_mse: 0.0132 - val_mae: 0.0694 - val_root_mean_squared_error: 0.1149
# Epoch 145/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0681 - mse: 0.0128 - mae: 0.0681 - root_mean_squared_error: 0.1133 - val_loss: 0.0694 - val_mse: 0.0132 - val_mae: 0.0694 - val_root_mean_squared_error: 0.1148
# Epoch 146/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.1368 - mse: 0.0358 - mae: 0.1368 - root_mean_squared_error: 0.189 - 0s 20us/sample - loss: 0.0681 - mse: 0.0128 - mae: 0.0681 - root_mean_squared_error: 0.1133 - val_loss: 0.0694 - val_mse: 0.0132 - val_mae: 0.0694 - val_root_mean_squared_error: 0.1148
# Epoch 147/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0681 - mse: 0.0128 - mae: 0.0681 - root_mean_squared_error: 0.1132 - val_loss: 0.0694 - val_mse: 0.0132 - val_mae: 0.0694 - val_root_mean_squared_error: 0.1148
# Epoch 148/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0681 - mse: 0.0128 - mae: 0.0681 - root_mean_squared_error: 0.1132 - val_loss: 0.0694 - val_mse: 0.0132 - val_mae: 0.0694 - val_root_mean_squared_error: 0.1148
# Epoch 149/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0680 - mse: 0.0128 - mae: 0.0680 - root_mean_squared_error: 0.1132 - val_loss: 0.0693 - val_mse: 0.0132 - val_mae: 0.0693 - val_root_mean_squared_error: 0.1148
# Epoch 150/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0680 - mse: 0.0128 - mae: 0.0680 - root_mean_squared_error: 0.1132 - val_loss: 0.0693 - val_mse: 0.0132 - val_mae: 0.0693 - val_root_mean_squared_error: 0.1148
# Epoch 151/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0680 - mse: 0.0128 - mae: 0.0680 - root_mean_squared_error: 0.1132 - val_loss: 0.0693 - val_mse: 0.0132 - val_mae: 0.0693 - val_root_mean_squared_error: 0.1148
# Epoch 152/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0680 - mse: 0.0128 - mae: 0.0680 - root_mean_squared_error: 0.1132 - val_loss: 0.0693 - val_mse: 0.0132 - val_mae: 0.0693 - val_root_mean_squared_error: 0.1147
# Epoch 153/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0680 - mse: 0.0128 - mae: 0.0680 - root_mean_squared_error: 0.1131 - val_loss: 0.0693 - val_mse: 0.0132 - val_mae: 0.0693 - val_root_mean_squared_error: 0.1147
# Epoch 154/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0680 - mse: 0.0128 - mae: 0.0680 - root_mean_squared_error: 0.1131 - val_loss: 0.0692 - val_mse: 0.0132 - val_mae: 0.0692 - val_root_mean_squared_error: 0.1147
# Epoch 155/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0679 - mse: 0.0128 - mae: 0.0679 - root_mean_squared_error: 0.1131 - val_loss: 0.0692 - val_mse: 0.0132 - val_mae: 0.0692 - val_root_mean_squared_error: 0.1147
# Epoch 156/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0679 - mse: 0.0128 - mae: 0.0679 - root_mean_squared_error: 0.1131 - val_loss: 0.0692 - val_mse: 0.0132 - val_mae: 0.0692 - val_root_mean_squared_error: 0.1147
# Epoch 157/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0679 - mse: 0.0128 - mae: 0.0679 - root_mean_squared_error: 0.1131 - val_loss: 0.0692 - val_mse: 0.0132 - val_mae: 0.0692 - val_root_mean_squared_error: 0.1147
# Epoch 158/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0679 - mse: 0.0128 - mae: 0.0679 - root_mean_squared_error: 0.1131 - val_loss: 0.0692 - val_mse: 0.0131 - val_mae: 0.0692 - val_root_mean_squared_error: 0.1147
# Epoch 159/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0679 - mse: 0.0128 - mae: 0.0679 - root_mean_squared_error: 0.1130 - val_loss: 0.0691 - val_mse: 0.0131 - val_mae: 0.0691 - val_root_mean_squared_error: 0.1146
# Epoch 160/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0678 - mse: 0.0128 - mae: 0.0678 - root_mean_squared_error: 0.1130 - val_loss: 0.0691 - val_mse: 0.0131 - val_mae: 0.0691 - val_root_mean_squared_error: 0.1146
# Epoch 161/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0678 - mse: 0.0128 - mae: 0.0678 - root_mean_squared_error: 0.1130 - val_loss: 0.0691 - val_mse: 0.0131 - val_mae: 0.0691 - val_root_mean_squared_error: 0.1146
# Epoch 162/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0678 - mse: 0.0128 - mae: 0.0678 - root_mean_squared_error: 0.1130 - val_loss: 0.0691 - val_mse: 0.0131 - val_mae: 0.0691 - val_root_mean_squared_error: 0.1146
# Epoch 163/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0678 - mse: 0.0128 - mae: 0.0678 - root_mean_squared_error: 0.1130 - val_loss: 0.0690 - val_mse: 0.0131 - val_mae: 0.0690 - val_root_mean_squared_error: 0.1146
# Epoch 164/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0678 - mse: 0.0128 - mae: 0.0678 - root_mean_squared_error: 0.1130 - val_loss: 0.0690 - val_mse: 0.0131 - val_mae: 0.0690 - val_root_mean_squared_error: 0.1146
# Epoch 165/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0677 - mse: 0.0128 - mae: 0.0677 - root_mean_squared_error: 0.1129 - val_loss: 0.0690 - val_mse: 0.0131 - val_mae: 0.0690 - val_root_mean_squared_error: 0.1146
# Epoch 166/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0677 - mse: 0.0128 - mae: 0.0677 - root_mean_squared_error: 0.1129 - val_loss: 0.0690 - val_mse: 0.0131 - val_mae: 0.0690 - val_root_mean_squared_error: 0.1145
# Epoch 167/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0677 - mse: 0.0127 - mae: 0.0677 - root_mean_squared_error: 0.1129 - val_loss: 0.0690 - val_mse: 0.0131 - val_mae: 0.0690 - val_root_mean_squared_error: 0.1145
# Epoch 168/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0677 - mse: 0.0127 - mae: 0.0677 - root_mean_squared_error: 0.1129 - val_loss: 0.0689 - val_mse: 0.0131 - val_mae: 0.0689 - val_root_mean_squared_error: 0.1145
# Epoch 169/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0677 - mse: 0.0127 - mae: 0.0677 - root_mean_squared_error: 0.1129 - val_loss: 0.0689 - val_mse: 0.0131 - val_mae: 0.0689 - val_root_mean_squared_error: 0.1145
# Epoch 170/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0677 - mse: 0.0127 - mae: 0.0677 - root_mean_squared_error: 0.1129 - val_loss: 0.0689 - val_mse: 0.0131 - val_mae: 0.0689 - val_root_mean_squared_error: 0.1145
# Epoch 171/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0676 - mse: 0.0127 - mae: 0.0676 - root_mean_squared_error: 0.1128 - val_loss: 0.0689 - val_mse: 0.0131 - val_mae: 0.0689 - val_root_mean_squared_error: 0.1145
# Epoch 172/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0676 - mse: 0.0127 - mae: 0.0676 - root_mean_squared_error: 0.1128 - val_loss: 0.0689 - val_mse: 0.0131 - val_mae: 0.0689 - val_root_mean_squared_error: 0.1145
# Epoch 173/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0676 - mse: 0.0127 - mae: 0.0676 - root_mean_squared_error: 0.1128 - val_loss: 0.0689 - val_mse: 0.0131 - val_mae: 0.0689 - val_root_mean_squared_error: 0.1144
# Epoch 174/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0676 - mse: 0.0127 - mae: 0.0676 - root_mean_squared_error: 0.1128 - val_loss: 0.0688 - val_mse: 0.0131 - val_mae: 0.0688 - val_root_mean_squared_error: 0.1144
# Epoch 175/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0676 - mse: 0.0127 - mae: 0.0676 - root_mean_squared_error: 0.1128 - val_loss: 0.0688 - val_mse: 0.0131 - val_mae: 0.0688 - val_root_mean_squared_error: 0.1144
# Epoch 176/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0676 - mse: 0.0127 - mae: 0.0676 - root_mean_squared_error: 0.1128 - val_loss: 0.0688 - val_mse: 0.0131 - val_mae: 0.0688 - val_root_mean_squared_error: 0.1144
# Epoch 177/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0675 - mse: 0.0127 - mae: 0.0675 - root_mean_squared_error: 0.1128 - val_loss: 0.0688 - val_mse: 0.0131 - val_mae: 0.0688 - val_root_mean_squared_error: 0.1144
# Epoch 178/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0675 - mse: 0.0127 - mae: 0.0675 - root_mean_squared_error: 0.1127 - val_loss: 0.0688 - val_mse: 0.0131 - val_mae: 0.0688 - val_root_mean_squared_error: 0.1144
# Epoch 179/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0675 - mse: 0.0127 - mae: 0.0675 - root_mean_squared_error: 0.1127 - val_loss: 0.0688 - val_mse: 0.0131 - val_mae: 0.0688 - val_root_mean_squared_error: 0.1144
# Epoch 180/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0675 - mse: 0.0127 - mae: 0.0675 - root_mean_squared_error: 0.1127 - val_loss: 0.0687 - val_mse: 0.0131 - val_mae: 0.0687 - val_root_mean_squared_error: 0.1144
# Epoch 181/500
# 3175/3175 [==============================] - 0s 17us/sample - loss: 0.0675 - mse: 0.0127 - mae: 0.0675 - root_mean_squared_error: 0.1127 - val_loss: 0.0687 - val_mse: 0.0131 - val_mae: 0.0687 - val_root_mean_squared_error: 0.1144
# Epoch 182/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0675 - mse: 0.0127 - mae: 0.0675 - root_mean_squared_error: 0.1127 - val_loss: 0.0687 - val_mse: 0.0131 - val_mae: 0.0687 - val_root_mean_squared_error: 0.1143
# Epoch 183/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0675 - mse: 0.0127 - mae: 0.0675 - root_mean_squared_error: 0.1127 - val_loss: 0.0687 - val_mse: 0.0131 - val_mae: 0.0687 - val_root_mean_squared_error: 0.1143
# Epoch 184/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0674 - mse: 0.0127 - mae: 0.0674 - root_mean_squared_error: 0.1127 - val_loss: 0.0687 - val_mse: 0.0131 - val_mae: 0.0687 - val_root_mean_squared_error: 0.1143
# Epoch 185/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0674 - mse: 0.0127 - mae: 0.0674 - root_mean_squared_error: 0.1126 - val_loss: 0.0687 - val_mse: 0.0131 - val_mae: 0.0687 - val_root_mean_squared_error: 0.1143
# Epoch 186/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0674 - mse: 0.0127 - mae: 0.0674 - root_mean_squared_error: 0.1126 - val_loss: 0.0686 - val_mse: 0.0131 - val_mae: 0.0686 - val_root_mean_squared_error: 0.1143
# Epoch 187/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0674 - mse: 0.0127 - mae: 0.0674 - root_mean_squared_error: 0.1126 - val_loss: 0.0686 - val_mse: 0.0131 - val_mae: 0.0686 - val_root_mean_squared_error: 0.1143
# Epoch 188/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0674 - mse: 0.0127 - mae: 0.0674 - root_mean_squared_error: 0.1126 - val_loss: 0.0686 - val_mse: 0.0131 - val_mae: 0.0686 - val_root_mean_squared_error: 0.1143
# Epoch 189/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0674 - mse: 0.0127 - mae: 0.0674 - root_mean_squared_error: 0.1126 - val_loss: 0.0686 - val_mse: 0.0131 - val_mae: 0.0686 - val_root_mean_squared_error: 0.1143
# Epoch 190/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0674 - mse: 0.0127 - mae: 0.0674 - root_mean_squared_error: 0.1126 - val_loss: 0.0686 - val_mse: 0.0131 - val_mae: 0.0686 - val_root_mean_squared_error: 0.1142
# Epoch 191/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0673 - mse: 0.0127 - mae: 0.0673 - root_mean_squared_error: 0.1126 - val_loss: 0.0686 - val_mse: 0.0130 - val_mae: 0.0686 - val_root_mean_squared_error: 0.1142
# Epoch 192/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0673 - mse: 0.0127 - mae: 0.0673 - root_mean_squared_error: 0.1126 - val_loss: 0.0686 - val_mse: 0.0130 - val_mae: 0.0686 - val_root_mean_squared_error: 0.1142
# Epoch 193/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0673 - mse: 0.0127 - mae: 0.0673 - root_mean_squared_error: 0.1125 - val_loss: 0.0685 - val_mse: 0.0130 - val_mae: 0.0685 - val_root_mean_squared_error: 0.1142
# Epoch 194/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0673 - mse: 0.0127 - mae: 0.0673 - root_mean_squared_error: 0.1125 - val_loss: 0.0685 - val_mse: 0.0130 - val_mae: 0.0685 - val_root_mean_squared_error: 0.1142
# Epoch 195/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0673 - mse: 0.0127 - mae: 0.0673 - root_mean_squared_error: 0.1125 - val_loss: 0.0685 - val_mse: 0.0130 - val_mae: 0.0685 - val_root_mean_squared_error: 0.1142
# Epoch 196/500
# ...
# Epoch 436/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1117 - val_loss: 0.0666 - val_mse: 0.0129 - val_mae: 0.0666 - val_root_mean_squared_error: 0.1135
# Epoch 437/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1117 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 438/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1117 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 439/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1117 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 440/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1117 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 441/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1117 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 442/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1117 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 443/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1117 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 444/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1117 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 445/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1117 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 446/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1117 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 447/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1117 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 448/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1117 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 449/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1117 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 450/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1116 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 451/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1116 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 452/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1116 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 453/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1116 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 454/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1116 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 455/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1116 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 456/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1116 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 457/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1116 - val_loss: 0.0665 - val_mse: 0.0129 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1135
# Epoch 458/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1116 - val_loss: 0.0664 - val_mse: 0.0129 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1135
# Epoch 459/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1116 - val_loss: 0.0664 - val_mse: 0.0129 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1134
# Epoch 460/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1116 - val_loss: 0.0664 - val_mse: 0.0129 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1135
# Epoch 461/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1116 - val_loss: 0.0664 - val_mse: 0.0129 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1135
# Epoch 462/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1116 - val_loss: 0.0664 - val_mse: 0.0129 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1134
# Epoch 463/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1116 - val_loss: 0.0664 - val_mse: 0.0129 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1134
# Epoch 464/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0657 - mse: 0.0125 - mae: 0.0657 - root_mean_squared_error: 0.1116 - val_loss: 0.0664 - val_mse: 0.0129 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1134
# Epoch 465/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0664 - val_mse: 0.0129 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1134
# Epoch 466/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0664 - val_mse: 0.0129 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1134
# Epoch 467/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0664 - val_mse: 0.0129 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1134
# Epoch 468/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0664 - val_mse: 0.0129 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1134
# Epoch 469/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0664 - val_mse: 0.0129 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1134
# Epoch 470/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0664 - val_mse: 0.0129 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1134
# Epoch 471/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0664 - val_mse: 0.0129 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1134
# Epoch 472/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0664 - val_mse: 0.0129 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1134
# Epoch 473/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0664 - val_mse: 0.0129 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1134
# Epoch 474/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0664 - val_mse: 0.0129 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1134
# Epoch 475/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0664 - val_mse: 0.0129 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1134
# Epoch 476/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0664 - val_mse: 0.0129 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1134
# Epoch 477/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 478/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 479/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 480/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 481/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 482/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 483/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 484/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 485/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 486/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 487/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.1335 - mse: 0.0352 - mae: 0.1335 - root_mean_squared_error: 0.187 - 0s 23us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 488/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 489/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 490/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 491/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 492/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 493/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 494/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 495/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 496/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 497/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0656 - mse: 0.0125 - mae: 0.0656 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 498/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0655 - mse: 0.0125 - mae: 0.0655 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 499/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0655 - mse: 0.0125 - mae: 0.0655 - root_mean_squared_error: 0.1116 - val_loss: 0.0663 - val_mse: 0.0129 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1134
# Epoch 500/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0655 - mse: 0.0125 - mae: 0.0655 - root_mean_squared_error: 0.1116 - val_loss: 0.0662 - val_mse: 0.0129 - val_mae: 0.0662 - val_root_mean_squared_error: 0.1134

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mae'],label='train mae')
pyplot.plot(history.history['val_mae'],label='val mae')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mse'],label='train mse')
pyplot.plot(history.history['val_mse'],label='val mse')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['root_mean_squared_error'],label='train rmse')
pyplot.plot(history.history['val_root_mean_squared_error'],label='val rmse')
pyplot.legend()
pyplot.show()
# Out:
# The testing MAE loss is: 0.066479534
# The testing MSE loss is: 0.012810633
# The testing RMSE loss is: 0.11318406

# %%
pyplot.plot(test_y[:,11],color='red', label='True Values')
pyplot.plot(out[:,11],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()

# %%
dataset_test=pd.read_excel('F:\MS thesis data/Hopper Crossing.xlsx')
dataset_test=dataset_test.drop(['Date/Time','Flowd'],axis=1)
dataset_test.dropna(inplace=True)

# %%
shape=np.shape(dataset_test)
print(shape)
pyplot.plot(dataset_test)
# Out:
# (26285, 3)
# [<matplotlib.lines.Line2D at 0x250b5ed7708>,
#  <matplotlib.lines.Line2D at 0x250b5eda248>,
#  <matplotlib.lines.Line2D at 0x250b5e876c8>]

# %%
dataset_test
# Out:
#        Cumulative rainfall   Flow  Level
# 0                      0.0  0.093    1.50
# 1                      0.0  0.093    1.50
# 2                      0.0  0.093    1.50
# 3                      0.0  0.093    1.50
# 4                      0.0  0.093    1.50
# ...                    ...    ...     ...
# 26280                  0.2  0.080    1.49
# 26281                  0.2  0.080    1.49
# 26282                  0.2  0.080    1.49
# 26283                  0.2  0.080    1.49
# 26284                  0.2  0.080    1.49
#
# [26285 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset_test)))
# Out:
# The std of original data is Cumulative rainfall    2.451640
# Flow                   0.520832
# Level                  0.083204
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset_test=dataset_test.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset_test.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset_test[:,0]== maxi[0])
    ind2=np.argwhere(dataset_test[:,1]== maxi[1])
    ind3=np.argwhere(dataset_test[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset_test.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset_test[:,0]== mini[0])
    ind2=np.argwhere(dataset_test[:,1]== mini[1])
    ind3=np.argwhere(dataset_test[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset_test)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset_test = min_max_scaler.fit_transform(dataset_test)
# Out:
# The std of cleaned data is 1.5154548293543502

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=12
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values

#one hour
#test_X, test_y = values[:, :-out_hour], values[:,-1]


test_X, test_y = values[:, :-out_hour], values[:, -out_hour: ]


test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6334, 54)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var3(t+2)  var3(t+3)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.844660   0.873786
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.873786   0.898058
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.898058   0.932039
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.932039   0.966019
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.966019   1.000000
#
#     var3(t+4)  var3(t+5)  var3(t+6)  var3(t+7)  var3(t+8)  var3(t+9)  \
# 6    0.898058   0.932039   0.966019   1.000000   0.941748   0.912621
# 7    0.932039   0.966019   1.000000   0.941748   0.912621   0.800971
# 8    0.966019   1.000000   0.941748   0.912621   0.800971   0.723301
# 9    1.000000   0.941748   0.912621   0.800971   0.723301   0.665049
# 10   0.941748   0.912621   0.800971   0.723301   0.665049   0.616505
#
#     var3(t+10)  var3(t+11)
# 6     0.800971    0.723301
# 7     0.723301    0.665049
# 8     0.665049    0.616505
# 9     0.616505    0.572816
# 10    0.572816    0.548544
#
# [5 rows x 30 columns]

# %%
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
# Out:
# The testing MAE loss is: 0.06590502
# The testing MSE loss is: 0.012616903
# The testing RMSE loss is: 0.11232496

# %%
pyplot.plot(test_y[:,9],color='red', label='True Values')
pyplot.plot(out[:,9],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-91768c6bd1b2> in <module>
# ----> 1 pyplot.plot(test_y[:,9],color='red', label='True Values')
#       2 pyplot.plot(out[:,9],color='blue',label='Predicted values')
#       3 pyplot.title("Level Predictions")
#       4 pyplot.legend(loc='upper left')
#       5 pyplot.xlabel("Samples")
#
# NameError: name 'test_y' is not defined
