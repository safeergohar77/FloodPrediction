# %%
import pandas as pd
from pandas import concat
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from sklearn import preprocessing
from tensorflow.keras import backend as K
#from sklearn.preprocessing import MinMaxScaler
#from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input, Dense, LSTM,GRU,SimpleRNN, Activation
from matplotlib import pyplot
#from sklearn.model_selection import train_test_split

# %%
"# convert series to supervised learning\n" 
#windowing of data
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1),
    for i in range(n_in, 0, -1): #startes from n_in and decreses to 0 by decreasing each time -1
     cols.append(df.shift(i))
     names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
     cols.append(df.shift(-i))
     if i == 0:
       names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
     else:
       names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together\n",
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values\n",
    if dropnan:
      agg.dropna(inplace=True)
    return agg

# %%
#def root_mean_squared_error(y_true, y_pred):
 #       return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
dataset1=pd.read_excel('F:\MS thesis data/Brooklyn.xlsx')
dataset1=dataset1.drop(['Date/Time','Flowd'],axis=1)
dataset1.dropna(inplace=True)

# %%
shape=np.shape(dataset1)
print(shape)
pyplot.plot(dataset1)
# Out:
# (26302, 3)
# [<matplotlib.lines.Line2D at 0x203ee2328c8>,
#  <matplotlib.lines.Line2D at 0x203ee2246c8>,
#  <matplotlib.lines.Line2D at 0x203ee2224c8>]

# %%
dataset1
# Out:
#        Cumulative rainfall    Flow  Level
# 0                       0.0  0.172   0.352
# 1                       0.0  0.180   0.356
# 2                       0.0  0.180   0.356
# 3                       0.0  0.189   0.360
# 4                       0.0  0.189   0.360
# ...                     ...    ...     ...
# 26297                   0.0  0.025   0.232
# 26298                   0.0  0.023   0.228
# 26299                   0.0  0.023   0.228
# 26300                   0.0  0.023   0.228
# 26301                   0.0  0.023   0.228
#
# [26302 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset1)))
# Out:
# The std of original data is Cumulative rainfall     2.872616
# Flow                    1.306642
# Level                   0.147238
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset=dataset1.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset[:,0]== maxi[0])
    ind2=np.argwhere(dataset[:,1]== maxi[1])
    ind3=np.argwhere(dataset[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset[:,0]== mini[0])
    ind2=np.argwhere(dataset[:,1]== mini[1])
    ind3=np.argwhere(dataset[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset = min_max_scaler.fit_transform(dataset)
# Out:
# The std of cleaned data is 1.626639593959813

# %%
pyplot.plot(dataset)
# Out:
# [<matplotlib.lines.Line2D at 0x203ed8af848>,
#  <matplotlib.lines.Line2D at 0x203ed825688>,
#  <matplotlib.lines.Line2D at 0x203ed825848>]

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=10
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values
train_size  = int(len(dataset) * 0.50)
val_size=int(len(dataset) * 0.75)
train_X, train_y = values[0:train_size, :-out_hour], values[0:train_size,-out_hour: ]
val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-out_hour: ]
test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-out_hour:]
#for last hour
#train_X, train_y = values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]  #for only last hour
#val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]
#test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-1]
print(train_X, train_y)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6336, 48)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...   var3(t)  var3(t+1)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...  0.791262   0.820388
# 7    0.230769   0.500068   0.762136   0.230769  ...  0.820388   0.844660
# 8    0.230769   0.524545   0.776699   0.215385  ...  0.844660   0.873786
# 9    0.215385   0.524545   0.776699   0.123077  ...  0.873786   0.898058
# 10   0.123077   0.549980   0.791262   0.092308  ...  0.898058   0.932039
#
#     var3(t+2)  var3(t+3)  var3(t+4)  var3(t+5)  var3(t+6)  var3(t+7)  \
# 6    0.844660   0.873786   0.898058   0.932039   0.966019   1.000000
# 7    0.873786   0.898058   0.932039   0.966019   1.000000   0.941748
# 8    0.898058   0.932039   0.966019   1.000000   0.941748   0.912621
# 9    0.932039   0.966019   1.000000   0.941748   0.912621   0.800971
# 10   0.966019   1.000000   0.941748   0.912621   0.800971   0.723301
#
#     var3(t+8)  var3(t+9)
# 6    0.941748   0.912621
# 7    0.912621   0.800971
# 8    0.800971   0.723301
# 9    0.723301   0.665049
# 10   0.665049   0.616505
#
# [5 rows x 28 columns]
# [[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]
#  [0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]
#  [0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]
#  ...
#  [0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]
#  [0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]
#  [0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]] [[0.79126215 0.8203884  0.8446602  ... 1.         0.94174755 0.9126214 ]
#  [0.8203884  0.8446602  0.8737864  ... 0.94174755 0.9126214  0.80097085]
#  [0.8446602  0.8737864  0.89805824 ... 0.9126214  0.80097085 0.723301  ]
#  ...
#  [0.23786408 0.24271844 0.24757281 ... 0.24271844 0.25728154 0.27184466]
#  [0.24271844 0.24757281 0.24757281 ... 0.25728154 0.27184466 0.27184466]
#  [0.24757281 0.24757281 0.24757281 ... 0.27184466 0.27184466 0.2961165 ]]

# %%
print(train_X, train_y)
# Out:
# [[[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]]
#
#  [[0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]]
#
#  [[0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]]
#
#  ...
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]]] [[0.79126215 0.8203884  0.8446602  ... 1.         0.94174755 0.9126214 ]
#  [0.8203884  0.8446602  0.8737864  ... 0.94174755 0.9126214  0.80097085]
#  [0.8446602  0.8737864  0.89805824 ... 0.9126214  0.80097085 0.723301  ]
#  ...
#  [0.23786408 0.24271844 0.24757281 ... 0.24271844 0.25728154 0.27184466]
#  [0.24271844 0.24757281 0.24757281 ... 0.25728154 0.27184466 0.27184466]
#  [0.24757281 0.24757281 0.24757281 ... 0.27184466 0.27184466 0.2961165 ]]

# %%
print(train_X.shape, train_y.shape, val_X.shape, val_y.shape)
# Out:
# (3175, 1, 18) (3175, 10) (1588, 1, 18) (1588, 10)

# %%
randomState = 46
np.random.seed(randomState)
#tensorflow.random.set_random_seed(randomState)
tensorflow.random.set_seed(randomState)
model = Sequential()
model.add(GRU(15,input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dense(22))
#model.add(Activation('relu'))    
model.add(Dense(out_hour,activation = "sigmoid"))
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.001)
#    opt=tensorflow.keras.optimizers.Adam(learning_rate=0.00075)
model.compile(loss='mae', optimizer=opt,metrics=['mse','mae',tensorflow.keras.metrics.RootMeanSquaredError()])
history = model.fit(train_X, train_y,validation_data=(val_X, val_y), epochs=500, batch_size=100,verbose=1,shuffle=False)
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)
# Out:
# Train on 3175 samples, validate on 1588 samples
# Epoch 1/500
# 3175/3175 [==============================] - 2s 636us/sample - loss: 0.2592 - mse: 0.0800 - mae: 0.2592 - root_mean_squared_error: 0.2829 - val_loss: 0.2710 - val_mse: 0.0904 - val_mae: 0.2710 - val_root_mean_squared_error: 0.3006
# Epoch 2/500
# 3175/3175 [==============================] - 0s 58us/sample - loss: 0.2394 - mse: 0.0697 - mae: 0.2394 - root_mean_squared_error: 0.2640 - val_loss: 0.2500 - val_mse: 0.0781 - val_mae: 0.2500 - val_root_mean_squared_error: 0.2794
# Epoch 3/500
# 3175/3175 [==============================] - 0s 59us/sample - loss: 0.2164 - mse: 0.0592 - mae: 0.2164 - root_mean_squared_error: 0.2433 - val_loss: 0.2253 - val_mse: 0.0653 - val_mae: 0.2253 - val_root_mean_squared_error: 0.2555
# Epoch 4/500
# 3175/3175 [==============================] - 0s 61us/sample - loss: 0.1927 - mse: 0.0501 - mae: 0.1927 - root_mean_squared_error: 0.2239 - val_loss: 0.2020 - val_mse: 0.0547 - val_mae: 0.2020 - val_root_mean_squared_error: 0.2338
# Epoch 5/500
# 3175/3175 [==============================] - 0s 58us/sample - loss: 0.1735 - mse: 0.0442 - mae: 0.1735 - root_mean_squared_error: 0.2101 - val_loss: 0.1839 - val_mse: 0.0473 - val_mae: 0.1839 - val_root_mean_squared_error: 0.2176
# Epoch 6/500
# 3175/3175 [==============================] - 0s 53us/sample - loss: 0.1595 - mse: 0.0404 - mae: 0.1595 - root_mean_squared_error: 0.2010 - val_loss: 0.1703 - val_mse: 0.0423 - val_mae: 0.1703 - val_root_mean_squared_error: 0.2056
# Epoch 7/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.1490 - mse: 0.0376 - mae: 0.1490 - root_mean_squared_error: 0.1939 - val_loss: 0.1596 - val_mse: 0.0383 - val_mae: 0.1596 - val_root_mean_squared_error: 0.1958
# Epoch 8/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.1403 - mse: 0.0349 - mae: 0.1403 - root_mean_squared_error: 0.1868 - val_loss: 0.1506 - val_mse: 0.0349 - val_mae: 0.1506 - val_root_mean_squared_error: 0.1868
# Epoch 9/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.1326 - mse: 0.0321 - mae: 0.1326 - root_mean_squared_error: 0.1791 - val_loss: 0.1424 - val_mse: 0.0318 - val_mae: 0.1424 - val_root_mean_squared_error: 0.1782
# Epoch 10/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.1255 - mse: 0.0293 - mae: 0.1255 - root_mean_squared_error: 0.1710 - val_loss: 0.1350 - val_mse: 0.0289 - val_mae: 0.1350 - val_root_mean_squared_error: 0.1700
# Epoch 11/500
# 3175/3175 [==============================] - 0s 51us/sample - loss: 0.1190 - mse: 0.0266 - mae: 0.1190 - root_mean_squared_error: 0.1630 - val_loss: 0.1280 - val_mse: 0.0264 - val_mae: 0.1280 - val_root_mean_squared_error: 0.1624
# Epoch 12/500
# 3175/3175 [==============================] - 0s 42us/sample - loss: 0.1131 - mse: 0.0242 - mae: 0.1131 - root_mean_squared_error: 0.1556 - val_loss: 0.1216 - val_mse: 0.0242 - val_mae: 0.1216 - val_root_mean_squared_error: 0.1557
# Epoch 13/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.1079 - mse: 0.0222 - mae: 0.1079 - root_mean_squared_error: 0.1491 - val_loss: 0.1160 - val_mse: 0.0225 - val_mae: 0.1160 - val_root_mean_squared_error: 0.1500
# Epoch 14/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.1034 - mse: 0.0207 - mae: 0.1034 - root_mean_squared_error: 0.1439 - val_loss: 0.1111 - val_mse: 0.0211 - val_mae: 0.1111 - val_root_mean_squared_error: 0.1453
# Epoch 15/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0995 - mse: 0.0195 - mae: 0.0995 - root_mean_squared_error: 0.1395 - val_loss: 0.1068 - val_mse: 0.0200 - val_mae: 0.1068 - val_root_mean_squared_error: 0.1413
# Epoch 16/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0961 - mse: 0.0185 - mae: 0.0961 - root_mean_squared_error: 0.1359 - val_loss: 0.1030 - val_mse: 0.0190 - val_mae: 0.1030 - val_root_mean_squared_error: 0.1380
# Epoch 17/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0930 - mse: 0.0177 - mae: 0.0930 - root_mean_squared_error: 0.1329 - val_loss: 0.0996 - val_mse: 0.0183 - val_mae: 0.0996 - val_root_mean_squared_error: 0.1352
# Epoch 18/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0903 - mse: 0.0170 - mae: 0.0903 - root_mean_squared_error: 0.1304 - val_loss: 0.0965 - val_mse: 0.0176 - val_mae: 0.0965 - val_root_mean_squared_error: 0.1328
# Epoch 19/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0878 - mse: 0.0165 - mae: 0.0878 - root_mean_squared_error: 0.1283 - val_loss: 0.0937 - val_mse: 0.0171 - val_mae: 0.0937 - val_root_mean_squared_error: 0.1307
# Epoch 20/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0856 - mse: 0.0160 - mae: 0.0856 - root_mean_squared_error: 0.1265 - val_loss: 0.0912 - val_mse: 0.0166 - val_mae: 0.0912 - val_root_mean_squared_error: 0.1289
# Epoch 21/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0837 - mse: 0.0156 - mae: 0.0837 - root_mean_squared_error: 0.1250 - val_loss: 0.0889 - val_mse: 0.0162 - val_mae: 0.0889 - val_root_mean_squared_error: 0.1274
# Epoch 22/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0821 - mse: 0.0153 - mae: 0.0821 - root_mean_squared_error: 0.1237 - val_loss: 0.0869 - val_mse: 0.0159 - val_mae: 0.0869 - val_root_mean_squared_error: 0.1261
# Epoch 23/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0806 - mse: 0.0150 - mae: 0.0806 - root_mean_squared_error: 0.1225 - val_loss: 0.0851 - val_mse: 0.0156 - val_mae: 0.0851 - val_root_mean_squared_error: 0.1248
# Epoch 24/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0792 - mse: 0.0148 - mae: 0.0792 - root_mean_squared_error: 0.1215 - val_loss: 0.0835 - val_mse: 0.0153 - val_mae: 0.0835 - val_root_mean_squared_error: 0.1237
# Epoch 25/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0781 - mse: 0.0145 - mae: 0.0781 - root_mean_squared_error: 0.1205 - val_loss: 0.0821 - val_mse: 0.0151 - val_mae: 0.0821 - val_root_mean_squared_error: 0.1227
# Epoch 26/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0770 - mse: 0.0143 - mae: 0.0770 - root_mean_squared_error: 0.1196 - val_loss: 0.0808 - val_mse: 0.0148 - val_mae: 0.0808 - val_root_mean_squared_error: 0.1218
# Epoch 27/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0760 - mse: 0.0141 - mae: 0.0760 - root_mean_squared_error: 0.1188 - val_loss: 0.0797 - val_mse: 0.0146 - val_mae: 0.0797 - val_root_mean_squared_error: 0.1210
# Epoch 28/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0751 - mse: 0.0139 - mae: 0.0751 - root_mean_squared_error: 0.1180 - val_loss: 0.0786 - val_mse: 0.0145 - val_mae: 0.0786 - val_root_mean_squared_error: 0.1203
# Epoch 29/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0743 - mse: 0.0138 - mae: 0.0743 - root_mean_squared_error: 0.1173 - val_loss: 0.0777 - val_mse: 0.0143 - val_mae: 0.0777 - val_root_mean_squared_error: 0.1196
# Epoch 30/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0736 - mse: 0.0136 - mae: 0.0736 - root_mean_squared_error: 0.1166 - val_loss: 0.0769 - val_mse: 0.0142 - val_mae: 0.0769 - val_root_mean_squared_error: 0.1190
# Epoch 31/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0730 - mse: 0.0135 - mae: 0.0730 - root_mean_squared_error: 0.1160 - val_loss: 0.0762 - val_mse: 0.0140 - val_mae: 0.0762 - val_root_mean_squared_error: 0.1184
# Epoch 32/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0724 - mse: 0.0133 - mae: 0.0724 - root_mean_squared_error: 0.1155 - val_loss: 0.0755 - val_mse: 0.0139 - val_mae: 0.0755 - val_root_mean_squared_error: 0.1179
# Epoch 33/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0719 - mse: 0.0132 - mae: 0.0719 - root_mean_squared_error: 0.1149 - val_loss: 0.0748 - val_mse: 0.0138 - val_mae: 0.0748 - val_root_mean_squared_error: 0.1174
# Epoch 34/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0714 - mse: 0.0131 - mae: 0.0714 - root_mean_squared_error: 0.1144 - val_loss: 0.0743 - val_mse: 0.0137 - val_mae: 0.0743 - val_root_mean_squared_error: 0.1169
# Epoch 35/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0709 - mse: 0.0130 - mae: 0.0709 - root_mean_squared_error: 0.1140 - val_loss: 0.0738 - val_mse: 0.0136 - val_mae: 0.0738 - val_root_mean_squared_error: 0.1165
# Epoch 36/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0705 - mse: 0.0129 - mae: 0.0705 - root_mean_squared_error: 0.1135 - val_loss: 0.0733 - val_mse: 0.0135 - val_mae: 0.0733 - val_root_mean_squared_error: 0.1161
# Epoch 37/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0701 - mse: 0.0128 - mae: 0.0701 - root_mean_squared_error: 0.1131 - val_loss: 0.0729 - val_mse: 0.0134 - val_mae: 0.0729 - val_root_mean_squared_error: 0.1157
# Epoch 38/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0698 - mse: 0.0127 - mae: 0.0698 - root_mean_squared_error: 0.1128 - val_loss: 0.0725 - val_mse: 0.0133 - val_mae: 0.0725 - val_root_mean_squared_error: 0.1154
# Epoch 39/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0695 - mse: 0.0126 - mae: 0.0695 - root_mean_squared_error: 0.1124 - val_loss: 0.0721 - val_mse: 0.0133 - val_mae: 0.0721 - val_root_mean_squared_error: 0.1151
# Epoch 40/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0692 - mse: 0.0126 - mae: 0.0692 - root_mean_squared_error: 0.1121 - val_loss: 0.0718 - val_mse: 0.0132 - val_mae: 0.0718 - val_root_mean_squared_error: 0.1148
# Epoch 41/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0689 - mse: 0.0125 - mae: 0.0689 - root_mean_squared_error: 0.1118 - val_loss: 0.0715 - val_mse: 0.0131 - val_mae: 0.0715 - val_root_mean_squared_error: 0.1146
# Epoch 42/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0687 - mse: 0.0125 - mae: 0.0687 - root_mean_squared_error: 0.1116 - val_loss: 0.0713 - val_mse: 0.0131 - val_mae: 0.0713 - val_root_mean_squared_error: 0.1144
# Epoch 43/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0684 - mse: 0.0124 - mae: 0.0684 - root_mean_squared_error: 0.1114 - val_loss: 0.0710 - val_mse: 0.0130 - val_mae: 0.0710 - val_root_mean_squared_error: 0.1142
# Epoch 44/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0682 - mse: 0.0124 - mae: 0.0682 - root_mean_squared_error: 0.1112 - val_loss: 0.0708 - val_mse: 0.0130 - val_mae: 0.0708 - val_root_mean_squared_error: 0.1140
# Epoch 45/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0680 - mse: 0.0123 - mae: 0.0680 - root_mean_squared_error: 0.1110 - val_loss: 0.0706 - val_mse: 0.0130 - val_mae: 0.0706 - val_root_mean_squared_error: 0.1139
# Epoch 46/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0678 - mse: 0.0123 - mae: 0.0678 - root_mean_squared_error: 0.1108 - val_loss: 0.0704 - val_mse: 0.0129 - val_mae: 0.0704 - val_root_mean_squared_error: 0.1137
# Epoch 47/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0677 - mse: 0.0122 - mae: 0.0677 - root_mean_squared_error: 0.1106 - val_loss: 0.0702 - val_mse: 0.0129 - val_mae: 0.0702 - val_root_mean_squared_error: 0.1136
# Epoch 48/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0675 - mse: 0.0122 - mae: 0.0675 - root_mean_squared_error: 0.1104 - val_loss: 0.0701 - val_mse: 0.0129 - val_mae: 0.0701 - val_root_mean_squared_error: 0.1134
# Epoch 49/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0674 - mse: 0.0122 - mae: 0.0674 - root_mean_squared_error: 0.1103 - val_loss: 0.0699 - val_mse: 0.0128 - val_mae: 0.0699 - val_root_mean_squared_error: 0.1133
# Epoch 50/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0672 - mse: 0.0121 - mae: 0.0672 - root_mean_squared_error: 0.1102 - val_loss: 0.0697 - val_mse: 0.0128 - val_mae: 0.0697 - val_root_mean_squared_error: 0.1132
# Epoch 51/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0671 - mse: 0.0121 - mae: 0.0671 - root_mean_squared_error: 0.1100 - val_loss: 0.0696 - val_mse: 0.0128 - val_mae: 0.0696 - val_root_mean_squared_error: 0.1131
# Epoch 52/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0669 - mse: 0.0121 - mae: 0.0669 - root_mean_squared_error: 0.1099 - val_loss: 0.0695 - val_mse: 0.0128 - val_mae: 0.0695 - val_root_mean_squared_error: 0.1130
# Epoch 53/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0668 - mse: 0.0121 - mae: 0.0668 - root_mean_squared_error: 0.1098 - val_loss: 0.0693 - val_mse: 0.0127 - val_mae: 0.0693 - val_root_mean_squared_error: 0.1129
# Epoch 54/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0667 - mse: 0.0120 - mae: 0.0667 - root_mean_squared_error: 0.1097 - val_loss: 0.0692 - val_mse: 0.0127 - val_mae: 0.0692 - val_root_mean_squared_error: 0.1128
# Epoch 55/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0666 - mse: 0.0120 - mae: 0.0666 - root_mean_squared_error: 0.1096 - val_loss: 0.0691 - val_mse: 0.0127 - val_mae: 0.0691 - val_root_mean_squared_error: 0.1127
# Epoch 56/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0665 - mse: 0.0120 - mae: 0.0665 - root_mean_squared_error: 0.1095 - val_loss: 0.0690 - val_mse: 0.0127 - val_mae: 0.0690 - val_root_mean_squared_error: 0.1126
# Epoch 57/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0664 - mse: 0.0120 - mae: 0.0664 - root_mean_squared_error: 0.1095 - val_loss: 0.0689 - val_mse: 0.0127 - val_mae: 0.0689 - val_root_mean_squared_error: 0.1126
# Epoch 58/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0663 - mse: 0.0120 - mae: 0.0663 - root_mean_squared_error: 0.1094 - val_loss: 0.0688 - val_mse: 0.0127 - val_mae: 0.0688 - val_root_mean_squared_error: 0.1125
# Epoch 59/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0662 - mse: 0.0119 - mae: 0.0662 - root_mean_squared_error: 0.1093 - val_loss: 0.0687 - val_mse: 0.0126 - val_mae: 0.0687 - val_root_mean_squared_error: 0.1124
# Epoch 60/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0661 - mse: 0.0119 - mae: 0.0661 - root_mean_squared_error: 0.1092 - val_loss: 0.0686 - val_mse: 0.0126 - val_mae: 0.0686 - val_root_mean_squared_error: 0.1124
# Epoch 61/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0660 - mse: 0.0119 - mae: 0.0660 - root_mean_squared_error: 0.1092 - val_loss: 0.0685 - val_mse: 0.0126 - val_mae: 0.0685 - val_root_mean_squared_error: 0.1123
# Epoch 62/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0659 - mse: 0.0119 - mae: 0.0659 - root_mean_squared_error: 0.1091 - val_loss: 0.0685 - val_mse: 0.0126 - val_mae: 0.0685 - val_root_mean_squared_error: 0.1122
# Epoch 63/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0658 - mse: 0.0119 - mae: 0.0658 - root_mean_squared_error: 0.1090 - val_loss: 0.0684 - val_mse: 0.0126 - val_mae: 0.0684 - val_root_mean_squared_error: 0.1122
# Epoch 64/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0657 - mse: 0.0119 - mae: 0.0657 - root_mean_squared_error: 0.1089 - val_loss: 0.0683 - val_mse: 0.0126 - val_mae: 0.0683 - val_root_mean_squared_error: 0.1121
# Epoch 65/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0657 - mse: 0.0119 - mae: 0.0657 - root_mean_squared_error: 0.1089 - val_loss: 0.0682 - val_mse: 0.0126 - val_mae: 0.0682 - val_root_mean_squared_error: 0.1121
# Epoch 66/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0656 - mse: 0.0118 - mae: 0.0656 - root_mean_squared_error: 0.1088 - val_loss: 0.0681 - val_mse: 0.0125 - val_mae: 0.0681 - val_root_mean_squared_error: 0.1120
# Epoch 67/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0655 - mse: 0.0118 - mae: 0.0655 - root_mean_squared_error: 0.1088 - val_loss: 0.0681 - val_mse: 0.0125 - val_mae: 0.0681 - val_root_mean_squared_error: 0.1120
# Epoch 68/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0654 - mse: 0.0118 - mae: 0.0654 - root_mean_squared_error: 0.1087 - val_loss: 0.0680 - val_mse: 0.0125 - val_mae: 0.0680 - val_root_mean_squared_error: 0.1119
# Epoch 69/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0654 - mse: 0.0118 - mae: 0.0654 - root_mean_squared_error: 0.1086 - val_loss: 0.0679 - val_mse: 0.0125 - val_mae: 0.0679 - val_root_mean_squared_error: 0.1119
# Epoch 70/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0653 - mse: 0.0118 - mae: 0.0653 - root_mean_squared_error: 0.1086 - val_loss: 0.0679 - val_mse: 0.0125 - val_mae: 0.0679 - val_root_mean_squared_error: 0.1118
# Epoch 71/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0652 - mse: 0.0118 - mae: 0.0652 - root_mean_squared_error: 0.1085 - val_loss: 0.0678 - val_mse: 0.0125 - val_mae: 0.0678 - val_root_mean_squared_error: 0.1117
# Epoch 72/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0652 - mse: 0.0118 - mae: 0.0652 - root_mean_squared_error: 0.1085 - val_loss: 0.0677 - val_mse: 0.0125 - val_mae: 0.0677 - val_root_mean_squared_error: 0.1117
# Epoch 73/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0651 - mse: 0.0118 - mae: 0.0651 - root_mean_squared_error: 0.1084 - val_loss: 0.0677 - val_mse: 0.0125 - val_mae: 0.0677 - val_root_mean_squared_error: 0.1117
# Epoch 74/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0650 - mse: 0.0117 - mae: 0.0650 - root_mean_squared_error: 0.1084 - val_loss: 0.0676 - val_mse: 0.0125 - val_mae: 0.0676 - val_root_mean_squared_error: 0.1116
# Epoch 75/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0650 - mse: 0.0117 - mae: 0.0650 - root_mean_squared_error: 0.1083 - val_loss: 0.0675 - val_mse: 0.0124 - val_mae: 0.0675 - val_root_mean_squared_error: 0.1116
# Epoch 76/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0649 - mse: 0.0117 - mae: 0.0649 - root_mean_squared_error: 0.1083 - val_loss: 0.0675 - val_mse: 0.0124 - val_mae: 0.0675 - val_root_mean_squared_error: 0.1115
# Epoch 77/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0649 - mse: 0.0117 - mae: 0.0649 - root_mean_squared_error: 0.1082 - val_loss: 0.0674 - val_mse: 0.0124 - val_mae: 0.0674 - val_root_mean_squared_error: 0.1115
# Epoch 78/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0648 - mse: 0.0117 - mae: 0.0648 - root_mean_squared_error: 0.1082 - val_loss: 0.0673 - val_mse: 0.0124 - val_mae: 0.0673 - val_root_mean_squared_error: 0.1114
# Epoch 79/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0647 - mse: 0.0117 - mae: 0.0647 - root_mean_squared_error: 0.1081 - val_loss: 0.0673 - val_mse: 0.0124 - val_mae: 0.0673 - val_root_mean_squared_error: 0.1114
# Epoch 80/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0647 - mse: 0.0117 - mae: 0.0647 - root_mean_squared_error: 0.1081 - val_loss: 0.0672 - val_mse: 0.0124 - val_mae: 0.0672 - val_root_mean_squared_error: 0.1114
# Epoch 81/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0646 - mse: 0.0117 - mae: 0.0646 - root_mean_squared_error: 0.1080 - val_loss: 0.0672 - val_mse: 0.0124 - val_mae: 0.0672 - val_root_mean_squared_error: 0.1113
# Epoch 82/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0646 - mse: 0.0117 - mae: 0.0646 - root_mean_squared_error: 0.1080 - val_loss: 0.0671 - val_mse: 0.0124 - val_mae: 0.0671 - val_root_mean_squared_error: 0.1113
# Epoch 83/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0645 - mse: 0.0117 - mae: 0.0645 - root_mean_squared_error: 0.1079 - val_loss: 0.0671 - val_mse: 0.0124 - val_mae: 0.0671 - val_root_mean_squared_error: 0.1112
# Epoch 84/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0645 - mse: 0.0116 - mae: 0.0645 - root_mean_squared_error: 0.1079 - val_loss: 0.0670 - val_mse: 0.0124 - val_mae: 0.0670 - val_root_mean_squared_error: 0.1112
# Epoch 85/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0644 - mse: 0.0116 - mae: 0.0644 - root_mean_squared_error: 0.1079 - val_loss: 0.0670 - val_mse: 0.0124 - val_mae: 0.0670 - val_root_mean_squared_error: 0.1112
# Epoch 86/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0644 - mse: 0.0116 - mae: 0.0644 - root_mean_squared_error: 0.1078 - val_loss: 0.0669 - val_mse: 0.0123 - val_mae: 0.0669 - val_root_mean_squared_error: 0.1111
# Epoch 87/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0643 - mse: 0.0116 - mae: 0.0643 - root_mean_squared_error: 0.1078 - val_loss: 0.0668 - val_mse: 0.0123 - val_mae: 0.0668 - val_root_mean_squared_error: 0.1111
# Epoch 88/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0643 - mse: 0.0116 - mae: 0.0643 - root_mean_squared_error: 0.1077 - val_loss: 0.0668 - val_mse: 0.0123 - val_mae: 0.0668 - val_root_mean_squared_error: 0.1110
# Epoch 89/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0642 - mse: 0.0116 - mae: 0.0642 - root_mean_squared_error: 0.1077 - val_loss: 0.0667 - val_mse: 0.0123 - val_mae: 0.0667 - val_root_mean_squared_error: 0.1110
# Epoch 90/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0642 - mse: 0.0116 - mae: 0.0642 - root_mean_squared_error: 0.1076 - val_loss: 0.0667 - val_mse: 0.0123 - val_mae: 0.0667 - val_root_mean_squared_error: 0.1110
# Epoch 91/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0641 - mse: 0.0116 - mae: 0.0641 - root_mean_squared_error: 0.1076 - val_loss: 0.0666 - val_mse: 0.0123 - val_mae: 0.0666 - val_root_mean_squared_error: 0.1109
# Epoch 92/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0641 - mse: 0.0116 - mae: 0.0641 - root_mean_squared_error: 0.1076 - val_loss: 0.0666 - val_mse: 0.0123 - val_mae: 0.0666 - val_root_mean_squared_error: 0.1109
# Epoch 93/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0640 - mse: 0.0116 - mae: 0.0640 - root_mean_squared_error: 0.1075 - val_loss: 0.0665 - val_mse: 0.0123 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1109
# Epoch 94/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0640 - mse: 0.0115 - mae: 0.0640 - root_mean_squared_error: 0.1075 - val_loss: 0.0665 - val_mse: 0.0123 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1108
# Epoch 95/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0639 - mse: 0.0115 - mae: 0.0639 - root_mean_squared_error: 0.1074 - val_loss: 0.0665 - val_mse: 0.0123 - val_mae: 0.0665 - val_root_mean_squared_error: 0.1108
# Epoch 96/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0639 - mse: 0.0115 - mae: 0.0639 - root_mean_squared_error: 0.1074 - val_loss: 0.0664 - val_mse: 0.0123 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1107
# Epoch 97/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0638 - mse: 0.0115 - mae: 0.0638 - root_mean_squared_error: 0.1073 - val_loss: 0.0664 - val_mse: 0.0123 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1107
# Epoch 98/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0638 - mse: 0.0115 - mae: 0.0638 - root_mean_squared_error: 0.1073 - val_loss: 0.0663 - val_mse: 0.0122 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1107
# Epoch 99/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0638 - mse: 0.0115 - mae: 0.0638 - root_mean_squared_error: 0.1073 - val_loss: 0.0663 - val_mse: 0.0122 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1106
# Epoch 100/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0637 - mse: 0.0115 - mae: 0.0637 - root_mean_squared_error: 0.1072 - val_loss: 0.0662 - val_mse: 0.0122 - val_mae: 0.0662 - val_root_mean_squared_error: 0.1106
# Epoch 101/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0637 - mse: 0.0115 - mae: 0.0637 - root_mean_squared_error: 0.1072 - val_loss: 0.0662 - val_mse: 0.0122 - val_mae: 0.0662 - val_root_mean_squared_error: 0.1105
# Epoch 102/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0636 - mse: 0.0115 - mae: 0.0636 - root_mean_squared_error: 0.1071 - val_loss: 0.0661 - val_mse: 0.0122 - val_mae: 0.0661 - val_root_mean_squared_error: 0.1105
# Epoch 103/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0636 - mse: 0.0115 - mae: 0.0636 - root_mean_squared_error: 0.1071 - val_loss: 0.0661 - val_mse: 0.0122 - val_mae: 0.0661 - val_root_mean_squared_error: 0.1105
# Epoch 104/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0635 - mse: 0.0115 - mae: 0.0635 - root_mean_squared_error: 0.1071 - val_loss: 0.0660 - val_mse: 0.0122 - val_mae: 0.0660 - val_root_mean_squared_error: 0.1104
# Epoch 105/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0635 - mse: 0.0115 - mae: 0.0635 - root_mean_squared_error: 0.1070 - val_loss: 0.0660 - val_mse: 0.0122 - val_mae: 0.0660 - val_root_mean_squared_error: 0.1104
# Epoch 106/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0635 - mse: 0.0114 - mae: 0.0635 - root_mean_squared_error: 0.1070 - val_loss: 0.0659 - val_mse: 0.0122 - val_mae: 0.0659 - val_root_mean_squared_error: 0.1104
# Epoch 107/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0634 - mse: 0.0114 - mae: 0.0634 - root_mean_squared_error: 0.1070 - val_loss: 0.0659 - val_mse: 0.0122 - val_mae: 0.0659 - val_root_mean_squared_error: 0.1103
# Epoch 108/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0634 - mse: 0.0114 - mae: 0.0634 - root_mean_squared_error: 0.1069 - val_loss: 0.0659 - val_mse: 0.0122 - val_mae: 0.0659 - val_root_mean_squared_error: 0.1103
# Epoch 109/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0633 - mse: 0.0114 - mae: 0.0633 - root_mean_squared_error: 0.1069 - val_loss: 0.0658 - val_mse: 0.0122 - val_mae: 0.0658 - val_root_mean_squared_error: 0.1103
# Epoch 110/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0633 - mse: 0.0114 - mae: 0.0633 - root_mean_squared_error: 0.1069 - val_loss: 0.0658 - val_mse: 0.0122 - val_mae: 0.0658 - val_root_mean_squared_error: 0.1102
# Epoch 111/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0633 - mse: 0.0114 - mae: 0.0633 - root_mean_squared_error: 0.1068 - val_loss: 0.0658 - val_mse: 0.0121 - val_mae: 0.0658 - val_root_mean_squared_error: 0.1102
# Epoch 112/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0632 - mse: 0.0114 - mae: 0.0632 - root_mean_squared_error: 0.1068 - val_loss: 0.0657 - val_mse: 0.0121 - val_mae: 0.0657 - val_root_mean_squared_error: 0.1102
# Epoch 113/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0632 - mse: 0.0114 - mae: 0.0632 - root_mean_squared_error: 0.1067 - val_loss: 0.0657 - val_mse: 0.0121 - val_mae: 0.0657 - val_root_mean_squared_error: 0.1101
# Epoch 114/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0631 - mse: 0.0114 - mae: 0.0631 - root_mean_squared_error: 0.1067 - val_loss: 0.0656 - val_mse: 0.0121 - val_mae: 0.0656 - val_root_mean_squared_error: 0.1101
# Epoch 115/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0631 - mse: 0.0114 - mae: 0.0631 - root_mean_squared_error: 0.1067 - val_loss: 0.0656 - val_mse: 0.0121 - val_mae: 0.0656 - val_root_mean_squared_error: 0.1101
# Epoch 116/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0631 - mse: 0.0114 - mae: 0.0631 - root_mean_squared_error: 0.1067 - val_loss: 0.0655 - val_mse: 0.0121 - val_mae: 0.0655 - val_root_mean_squared_error: 0.1101
# Epoch 117/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0630 - mse: 0.0114 - mae: 0.0630 - root_mean_squared_error: 0.1066 - val_loss: 0.0655 - val_mse: 0.0121 - val_mae: 0.0655 - val_root_mean_squared_error: 0.1101
# Epoch 118/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0630 - mse: 0.0114 - mae: 0.0630 - root_mean_squared_error: 0.1066 - val_loss: 0.0655 - val_mse: 0.0121 - val_mae: 0.0655 - val_root_mean_squared_error: 0.1100
# Epoch 119/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0629 - mse: 0.0114 - mae: 0.0629 - root_mean_squared_error: 0.1066 - val_loss: 0.0654 - val_mse: 0.0121 - val_mae: 0.0654 - val_root_mean_squared_error: 0.1100
# Epoch 120/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0629 - mse: 0.0114 - mae: 0.0629 - root_mean_squared_error: 0.1065 - val_loss: 0.0654 - val_mse: 0.0121 - val_mae: 0.0654 - val_root_mean_squared_error: 0.1100
# Epoch 121/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0629 - mse: 0.0113 - mae: 0.0629 - root_mean_squared_error: 0.1065 - val_loss: 0.0653 - val_mse: 0.0121 - val_mae: 0.0653 - val_root_mean_squared_error: 0.1100
# Epoch 122/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0628 - mse: 0.0113 - mae: 0.0628 - root_mean_squared_error: 0.1065 - val_loss: 0.0653 - val_mse: 0.0121 - val_mae: 0.0653 - val_root_mean_squared_error: 0.1099
# Epoch 123/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0628 - mse: 0.0113 - mae: 0.0628 - root_mean_squared_error: 0.1065 - val_loss: 0.0653 - val_mse: 0.0121 - val_mae: 0.0653 - val_root_mean_squared_error: 0.1099
# Epoch 124/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0628 - mse: 0.0113 - mae: 0.0628 - root_mean_squared_error: 0.1064 - val_loss: 0.0652 - val_mse: 0.0121 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1099
# Epoch 125/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0627 - mse: 0.0113 - mae: 0.0627 - root_mean_squared_error: 0.1064 - val_loss: 0.0652 - val_mse: 0.0121 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1098
# Epoch 126/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0627 - mse: 0.0113 - mae: 0.0627 - root_mean_squared_error: 0.1064 - val_loss: 0.0651 - val_mse: 0.0121 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1098
# Epoch 127/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0627 - mse: 0.0113 - mae: 0.0627 - root_mean_squared_error: 0.1063 - val_loss: 0.0651 - val_mse: 0.0120 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1098
# Epoch 128/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0626 - mse: 0.0113 - mae: 0.0626 - root_mean_squared_error: 0.1063 - val_loss: 0.0651 - val_mse: 0.0120 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1097
# Epoch 129/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0626 - mse: 0.0113 - mae: 0.0626 - root_mean_squared_error: 0.1063 - val_loss: 0.0650 - val_mse: 0.0120 - val_mae: 0.0650 - val_root_mean_squared_error: 0.1097
# Epoch 130/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0626 - mse: 0.0113 - mae: 0.0626 - root_mean_squared_error: 0.1062 - val_loss: 0.0650 - val_mse: 0.0120 - val_mae: 0.0650 - val_root_mean_squared_error: 0.1097
# Epoch 131/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0625 - mse: 0.0113 - mae: 0.0625 - root_mean_squared_error: 0.1062 - val_loss: 0.0650 - val_mse: 0.0120 - val_mae: 0.0650 - val_root_mean_squared_error: 0.1097
# Epoch 132/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0625 - mse: 0.0113 - mae: 0.0625 - root_mean_squared_error: 0.1062 - val_loss: 0.0649 - val_mse: 0.0120 - val_mae: 0.0649 - val_root_mean_squared_error: 0.1096
# Epoch 133/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0625 - mse: 0.0113 - mae: 0.0625 - root_mean_squared_error: 0.1061 - val_loss: 0.0649 - val_mse: 0.0120 - val_mae: 0.0649 - val_root_mean_squared_error: 0.1096
# Epoch 134/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0624 - mse: 0.0113 - mae: 0.0624 - root_mean_squared_error: 0.1061 - val_loss: 0.0649 - val_mse: 0.0120 - val_mae: 0.0649 - val_root_mean_squared_error: 0.1096
# Epoch 135/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0624 - mse: 0.0113 - mae: 0.0624 - root_mean_squared_error: 0.1061 - val_loss: 0.0648 - val_mse: 0.0120 - val_mae: 0.0648 - val_root_mean_squared_error: 0.1096
# Epoch 136/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0624 - mse: 0.0113 - mae: 0.0624 - root_mean_squared_error: 0.1061 - val_loss: 0.0648 - val_mse: 0.0120 - val_mae: 0.0648 - val_root_mean_squared_error: 0.1096
# Epoch 137/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0623 - mse: 0.0112 - mae: 0.0623 - root_mean_squared_error: 0.1061 - val_loss: 0.0648 - val_mse: 0.0120 - val_mae: 0.0648 - val_root_mean_squared_error: 0.1096
# Epoch 138/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0623 - mse: 0.0112 - mae: 0.0623 - root_mean_squared_error: 0.1060 - val_loss: 0.0647 - val_mse: 0.0120 - val_mae: 0.0647 - val_root_mean_squared_error: 0.1095
# Epoch 139/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0623 - mse: 0.0112 - mae: 0.0623 - root_mean_squared_error: 0.1060 - val_loss: 0.0647 - val_mse: 0.0120 - val_mae: 0.0647 - val_root_mean_squared_error: 0.1095
# Epoch 140/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0622 - mse: 0.0112 - mae: 0.0622 - root_mean_squared_error: 0.1060 - val_loss: 0.0647 - val_mse: 0.0120 - val_mae: 0.0647 - val_root_mean_squared_error: 0.1095
# Epoch 141/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0622 - mse: 0.0112 - mae: 0.0622 - root_mean_squared_error: 0.1059 - val_loss: 0.0646 - val_mse: 0.0120 - val_mae: 0.0646 - val_root_mean_squared_error: 0.1095
# Epoch 142/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0622 - mse: 0.0112 - mae: 0.0622 - root_mean_squared_error: 0.1059 - val_loss: 0.0646 - val_mse: 0.0120 - val_mae: 0.0646 - val_root_mean_squared_error: 0.1095
# Epoch 143/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0622 - mse: 0.0112 - mae: 0.0622 - root_mean_squared_error: 0.1059 - val_loss: 0.0646 - val_mse: 0.0120 - val_mae: 0.0646 - val_root_mean_squared_error: 0.1095
# Epoch 144/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0621 - mse: 0.0112 - mae: 0.0621 - root_mean_squared_error: 0.1059 - val_loss: 0.0645 - val_mse: 0.0120 - val_mae: 0.0645 - val_root_mean_squared_error: 0.1094
# Epoch 145/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0621 - mse: 0.0112 - mae: 0.0621 - root_mean_squared_error: 0.1059 - val_loss: 0.0645 - val_mse: 0.0120 - val_mae: 0.0645 - val_root_mean_squared_error: 0.1094
# Epoch 146/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0621 - mse: 0.0112 - mae: 0.0621 - root_mean_squared_error: 0.1058 - val_loss: 0.0645 - val_mse: 0.0120 - val_mae: 0.0645 - val_root_mean_squared_error: 0.1094
# Epoch 147/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0620 - mse: 0.0112 - mae: 0.0620 - root_mean_squared_error: 0.1058 - val_loss: 0.0644 - val_mse: 0.0120 - val_mae: 0.0644 - val_root_mean_squared_error: 0.1094
# Epoch 148/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0620 - mse: 0.0112 - mae: 0.0620 - root_mean_squared_error: 0.1058 - val_loss: 0.0644 - val_mse: 0.0120 - val_mae: 0.0644 - val_root_mean_squared_error: 0.1094
# Epoch 149/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0620 - mse: 0.0112 - mae: 0.0620 - root_mean_squared_error: 0.1058 - val_loss: 0.0644 - val_mse: 0.0120 - val_mae: 0.0644 - val_root_mean_squared_error: 0.1094
# Epoch 150/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0620 - mse: 0.0112 - mae: 0.0620 - root_mean_squared_error: 0.1058 - val_loss: 0.0643 - val_mse: 0.0120 - val_mae: 0.0643 - val_root_mean_squared_error: 0.1093
# Epoch 151/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0619 - mse: 0.0112 - mae: 0.0619 - root_mean_squared_error: 0.1057 - val_loss: 0.0643 - val_mse: 0.0120 - val_mae: 0.0643 - val_root_mean_squared_error: 0.1093
# Epoch 152/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0619 - mse: 0.0112 - mae: 0.0619 - root_mean_squared_error: 0.1057 - val_loss: 0.0643 - val_mse: 0.0120 - val_mae: 0.0643 - val_root_mean_squared_error: 0.1093
# Epoch 153/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0619 - mse: 0.0112 - mae: 0.0619 - root_mean_squared_error: 0.1057 - val_loss: 0.0643 - val_mse: 0.0120 - val_mae: 0.0643 - val_root_mean_squared_error: 0.1093
# Epoch 154/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0619 - mse: 0.0112 - mae: 0.0619 - root_mean_squared_error: 0.1057 - val_loss: 0.0642 - val_mse: 0.0119 - val_mae: 0.0642 - val_root_mean_squared_error: 0.1093
# Epoch 155/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0618 - mse: 0.0112 - mae: 0.0618 - root_mean_squared_error: 0.1057 - val_loss: 0.0642 - val_mse: 0.0119 - val_mae: 0.0642 - val_root_mean_squared_error: 0.1093
# Epoch 156/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0618 - mse: 0.0112 - mae: 0.0618 - root_mean_squared_error: 0.1056 - val_loss: 0.0642 - val_mse: 0.0119 - val_mae: 0.0642 - val_root_mean_squared_error: 0.1093
# Epoch 157/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0618 - mse: 0.0112 - mae: 0.0618 - root_mean_squared_error: 0.1056 - val_loss: 0.0641 - val_mse: 0.0119 - val_mae: 0.0641 - val_root_mean_squared_error: 0.1093
# Epoch 158/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0618 - mse: 0.0111 - mae: 0.0618 - root_mean_squared_error: 0.1056 - val_loss: 0.0641 - val_mse: 0.0119 - val_mae: 0.0641 - val_root_mean_squared_error: 0.1093
# Epoch 159/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0617 - mse: 0.0111 - mae: 0.0617 - root_mean_squared_error: 0.1056 - val_loss: 0.0641 - val_mse: 0.0119 - val_mae: 0.0641 - val_root_mean_squared_error: 0.1092
# Epoch 160/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0617 - mse: 0.0111 - mae: 0.0617 - root_mean_squared_error: 0.1055 - val_loss: 0.0641 - val_mse: 0.0119 - val_mae: 0.0641 - val_root_mean_squared_error: 0.1092
# Epoch 161/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0617 - mse: 0.0111 - mae: 0.0617 - root_mean_squared_error: 0.1055 - val_loss: 0.0640 - val_mse: 0.0119 - val_mae: 0.0640 - val_root_mean_squared_error: 0.1092
# Epoch 162/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0617 - mse: 0.0111 - mae: 0.0617 - root_mean_squared_error: 0.1055 - val_loss: 0.0640 - val_mse: 0.0119 - val_mae: 0.0640 - val_root_mean_squared_error: 0.1092
# Epoch 163/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0616 - mse: 0.0111 - mae: 0.0616 - root_mean_squared_error: 0.1055 - val_loss: 0.0640 - val_mse: 0.0119 - val_mae: 0.0640 - val_root_mean_squared_error: 0.1092
# Epoch 164/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0616 - mse: 0.0111 - mae: 0.0616 - root_mean_squared_error: 0.1055 - val_loss: 0.0640 - val_mse: 0.0119 - val_mae: 0.0640 - val_root_mean_squared_error: 0.1092
# Epoch 165/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0616 - mse: 0.0111 - mae: 0.0616 - root_mean_squared_error: 0.1055 - val_loss: 0.0639 - val_mse: 0.0119 - val_mae: 0.0639 - val_root_mean_squared_error: 0.1092
# Epoch 166/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0616 - mse: 0.0111 - mae: 0.0616 - root_mean_squared_error: 0.1054 - val_loss: 0.0639 - val_mse: 0.0119 - val_mae: 0.0639 - val_root_mean_squared_error: 0.1092
# Epoch 167/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0615 - mse: 0.0111 - mae: 0.0615 - root_mean_squared_error: 0.1054 - val_loss: 0.0639 - val_mse: 0.0119 - val_mae: 0.0639 - val_root_mean_squared_error: 0.1092
# Epoch 168/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0615 - mse: 0.0111 - mae: 0.0615 - root_mean_squared_error: 0.1054 - val_loss: 0.0639 - val_mse: 0.0119 - val_mae: 0.0639 - val_root_mean_squared_error: 0.1092
# Epoch 169/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0615 - mse: 0.0111 - mae: 0.0615 - root_mean_squared_error: 0.1054 - val_loss: 0.0638 - val_mse: 0.0119 - val_mae: 0.0638 - val_root_mean_squared_error: 0.1092
# Epoch 170/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0615 - mse: 0.0111 - mae: 0.0615 - root_mean_squared_error: 0.1054 - val_loss: 0.0638 - val_mse: 0.0119 - val_mae: 0.0638 - val_root_mean_squared_error: 0.1092
# Epoch 171/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0615 - mse: 0.0111 - mae: 0.0615 - root_mean_squared_error: 0.1054 - val_loss: 0.0638 - val_mse: 0.0119 - val_mae: 0.0638 - val_root_mean_squared_error: 0.1092
# Epoch 172/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0614 - mse: 0.0111 - mae: 0.0614 - root_mean_squared_error: 0.1054 - val_loss: 0.0638 - val_mse: 0.0119 - val_mae: 0.0638 - val_root_mean_squared_error: 0.1091
# Epoch 173/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0614 - mse: 0.0111 - mae: 0.0614 - root_mean_squared_error: 0.1053 - val_loss: 0.0638 - val_mse: 0.0119 - val_mae: 0.0638 - val_root_mean_squared_error: 0.1091
# Epoch 174/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0614 - mse: 0.0111 - mae: 0.0614 - root_mean_squared_error: 0.1053 - val_loss: 0.0637 - val_mse: 0.0119 - val_mae: 0.0637 - val_root_mean_squared_error: 0.1092
# Epoch 175/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0614 - mse: 0.0111 - mae: 0.0614 - root_mean_squared_error: 0.1053 - val_loss: 0.0637 - val_mse: 0.0119 - val_mae: 0.0637 - val_root_mean_squared_error: 0.1091
# Epoch 176/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0614 - mse: 0.0111 - mae: 0.0614 - root_mean_squared_error: 0.1053 - val_loss: 0.0637 - val_mse: 0.0119 - val_mae: 0.0637 - val_root_mean_squared_error: 0.1092
# Epoch 177/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0613 - mse: 0.0111 - mae: 0.0613 - root_mean_squared_error: 0.1053 - val_loss: 0.0637 - val_mse: 0.0119 - val_mae: 0.0637 - val_root_mean_squared_error: 0.1091
# Epoch 178/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0613 - mse: 0.0111 - mae: 0.0613 - root_mean_squared_error: 0.1053 - val_loss: 0.0637 - val_mse: 0.0119 - val_mae: 0.0637 - val_root_mean_squared_error: 0.1092
# Epoch 179/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0613 - mse: 0.0111 - mae: 0.0613 - root_mean_squared_error: 0.1053 - val_loss: 0.0637 - val_mse: 0.0119 - val_mae: 0.0637 - val_root_mean_squared_error: 0.1092
# Epoch 180/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0613 - mse: 0.0111 - mae: 0.0613 - root_mean_squared_error: 0.1053 - val_loss: 0.0636 - val_mse: 0.0119 - val_mae: 0.0636 - val_root_mean_squared_error: 0.1092
# Epoch 181/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0613 - mse: 0.0111 - mae: 0.0613 - root_mean_squared_error: 0.1053 - val_loss: 0.0636 - val_mse: 0.0119 - val_mae: 0.0636 - val_root_mean_squared_error: 0.1092
# Epoch 182/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0612 - mse: 0.0111 - mae: 0.0612 - root_mean_squared_error: 0.1053 - val_loss: 0.0636 - val_mse: 0.0119 - val_mae: 0.0636 - val_root_mean_squared_error: 0.1091
# Epoch 183/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0629 - mse: 0.0119 - mae: 0.0629 - root_mean_squared_error: 0.109 - 0s 27us/sample - loss: 0.0612 - mse: 0.0111 - mae: 0.0612 - root_mean_squared_error: 0.1052 - val_loss: 0.0636 - val_mse: 0.0119 - val_mae: 0.0636 - val_root_mean_squared_error: 0.1092
# Epoch 184/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0612 - mse: 0.0111 - mae: 0.0612 - root_mean_squared_error: 0.1052 - val_loss: 0.0636 - val_mse: 0.0119 - val_mae: 0.0636 - val_root_mean_squared_error: 0.1092
# Epoch 185/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0612 - mse: 0.0111 - mae: 0.0612 - root_mean_squared_error: 0.1052 - val_loss: 0.0635 - val_mse: 0.0119 - val_mae: 0.0635 - val_root_mean_squared_error: 0.1092
# Epoch 186/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0612 - mse: 0.0111 - mae: 0.0612 - root_mean_squared_error: 0.1052 - val_loss: 0.0635 - val_mse: 0.0119 - val_mae: 0.0635 - val_root_mean_squared_error: 0.1092
# Epoch 187/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0611 - mse: 0.0111 - mae: 0.0611 - root_mean_squared_error: 0.1052 - val_loss: 0.0635 - val_mse: 0.0119 - val_mae: 0.0635 - val_root_mean_squared_error: 0.1092
# Epoch 188/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0611 - mse: 0.0111 - mae: 0.0611 - root_mean_squared_error: 0.1052 - val_loss: 0.0635 - val_mse: 0.0119 - val_mae: 0.0635 - val_root_mean_squared_error: 0.1092
# Epoch 189/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0611 - mse: 0.0111 - mae: 0.0611 - root_mean_squared_error: 0.1052 - val_loss: 0.0635 - val_mse: 0.0119 - val_mae: 0.0635 - val_root_mean_squared_error: 0.1092
# Epoch 190/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0611 - mse: 0.0111 - mae: 0.0611 - root_mean_squared_error: 0.1052 - val_loss: 0.0635 - val_mse: 0.0119 - val_mae: 0.0635 - val_root_mean_squared_error: 0.1092
# Epoch 191/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0611 - mse: 0.0111 - mae: 0.0611 - root_mean_squared_error: 0.1052 - val_loss: 0.0634 - val_mse: 0.0119 - val_mae: 0.0634 - val_root_mean_squared_error: 0.1092
# Epoch 192/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0611 - mse: 0.0111 - mae: 0.0611 - root_mean_squared_error: 0.1052 - val_loss: 0.0634 - val_mse: 0.0119 - val_mae: 0.0634 - val_root_mean_squared_error: 0.1092
# Epoch 193/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0610 - mse: 0.0111 - mae: 0.0610 - root_mean_squared_error: 0.1052 - val_loss: 0.0634 - val_mse: 0.0119 - val_mae: 0.0634 - val_root_mean_squared_error: 0.1092
# Epoch 194/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0610 - mse: 0.0111 - mae: 0.0610 - root_mean_squared_error: 0.1051 - val_loss: 0.0634 - val_mse: 0.0119 - val_mae: 0.0634 - val_root_mean_squared_error: 0.1092
# Epoch 195/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0610 - mse: 0.0111 - mae: 0.0610 - root_mean_squared_error: 0.1051 - val_loss: 0.0634 - val_mse: 0.0119 - val_mae: 0.0634 - val_root_mean_squared_error: 0.1092
# Epoch 196/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0610 - mse: 0.0111 - mae: 0.0610 - root_mean_squared_error: 0.1051 - val_loss: 0.0634 - val_mse: 0.0119 - val_mae: 0.0634 - val_root_mean_squared_error: 0.1092
# Epoch 197/500
# ...
# Epoch 437/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0594 - mse: 0.0108 - mae: 0.0594 - root_mean_squared_error: 0.1041 - val_loss: 0.0615 - val_mse: 0.0119 - val_mae: 0.0615 - val_root_mean_squared_error: 0.1092
# Epoch 438/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0594 - mse: 0.0108 - mae: 0.0594 - root_mean_squared_error: 0.1041 - val_loss: 0.0615 - val_mse: 0.0119 - val_mae: 0.0615 - val_root_mean_squared_error: 0.1092
# Epoch 439/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0594 - mse: 0.0108 - mae: 0.0594 - root_mean_squared_error: 0.1041 - val_loss: 0.0615 - val_mse: 0.0119 - val_mae: 0.0615 - val_root_mean_squared_error: 0.1092
# Epoch 440/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0594 - mse: 0.0108 - mae: 0.0594 - root_mean_squared_error: 0.1041 - val_loss: 0.0615 - val_mse: 0.0119 - val_mae: 0.0615 - val_root_mean_squared_error: 0.1092
# Epoch 441/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0594 - mse: 0.0108 - mae: 0.0594 - root_mean_squared_error: 0.1041 - val_loss: 0.0615 - val_mse: 0.0119 - val_mae: 0.0615 - val_root_mean_squared_error: 0.1092
# Epoch 442/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0594 - mse: 0.0108 - mae: 0.0594 - root_mean_squared_error: 0.1041 - val_loss: 0.0615 - val_mse: 0.0119 - val_mae: 0.0615 - val_root_mean_squared_error: 0.1092
# Epoch 443/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0594 - mse: 0.0108 - mae: 0.0594 - root_mean_squared_error: 0.1041 - val_loss: 0.0615 - val_mse: 0.0119 - val_mae: 0.0615 - val_root_mean_squared_error: 0.1092
# Epoch 444/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0594 - mse: 0.0108 - mae: 0.0594 - root_mean_squared_error: 0.1040 - val_loss: 0.0615 - val_mse: 0.0119 - val_mae: 0.0615 - val_root_mean_squared_error: 0.1092
# Epoch 445/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0615 - val_mse: 0.0119 - val_mae: 0.0615 - val_root_mean_squared_error: 0.1092
# Epoch 446/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0615 - val_mse: 0.0119 - val_mae: 0.0615 - val_root_mean_squared_error: 0.1092
# Epoch 447/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0615 - val_mse: 0.0119 - val_mae: 0.0615 - val_root_mean_squared_error: 0.1092
# Epoch 448/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0615 - val_mse: 0.0119 - val_mae: 0.0615 - val_root_mean_squared_error: 0.1092
# Epoch 449/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0615 - val_mse: 0.0119 - val_mae: 0.0615 - val_root_mean_squared_error: 0.1092
# Epoch 450/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0615 - val_mse: 0.0119 - val_mae: 0.0615 - val_root_mean_squared_error: 0.1092
# Epoch 451/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0615 - val_mse: 0.0119 - val_mae: 0.0615 - val_root_mean_squared_error: 0.1092
# Epoch 452/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 453/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 454/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 455/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 456/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 457/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 458/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 459/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 460/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0626 - mse: 0.0122 - mae: 0.0626 - root_mean_squared_error: 0.110 - 0s 31us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 461/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 462/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 463/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 464/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 465/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 466/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 467/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 468/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 469/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 470/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 471/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 472/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 473/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 474/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 475/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 476/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 477/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 478/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 479/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 480/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 481/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0593 - mse: 0.0108 - mae: 0.0593 - root_mean_squared_error: 0.1040 - val_loss: 0.0614 - val_mse: 0.0119 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1092
# Epoch 482/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0633 - mse: 0.0123 - mae: 0.0633 - root_mean_squared_error: 0.111 - 0s 31us/sample - loss: 0.0592 - mse: 0.0108 - mae: 0.0592 - root_mean_squared_error: 0.1040 - val_loss: 0.0613 - val_mse: 0.0119 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1092
# Epoch 483/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0592 - mse: 0.0108 - mae: 0.0592 - root_mean_squared_error: 0.1040 - val_loss: 0.0613 - val_mse: 0.0119 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1092
# Epoch 484/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0592 - mse: 0.0108 - mae: 0.0592 - root_mean_squared_error: 0.1039 - val_loss: 0.0613 - val_mse: 0.0119 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1092
# Epoch 485/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0592 - mse: 0.0108 - mae: 0.0592 - root_mean_squared_error: 0.1039 - val_loss: 0.0613 - val_mse: 0.0119 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1092
# Epoch 486/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0592 - mse: 0.0108 - mae: 0.0592 - root_mean_squared_error: 0.1039 - val_loss: 0.0613 - val_mse: 0.0119 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1092
# Epoch 487/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0592 - mse: 0.0108 - mae: 0.0592 - root_mean_squared_error: 0.1039 - val_loss: 0.0613 - val_mse: 0.0119 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1092
# Epoch 488/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0592 - mse: 0.0108 - mae: 0.0592 - root_mean_squared_error: 0.1039 - val_loss: 0.0613 - val_mse: 0.0119 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1092
# Epoch 489/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0592 - mse: 0.0108 - mae: 0.0592 - root_mean_squared_error: 0.1039 - val_loss: 0.0613 - val_mse: 0.0119 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1092
# Epoch 490/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0592 - mse: 0.0108 - mae: 0.0592 - root_mean_squared_error: 0.1039 - val_loss: 0.0613 - val_mse: 0.0119 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1092
# Epoch 491/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0592 - mse: 0.0108 - mae: 0.0592 - root_mean_squared_error: 0.1039 - val_loss: 0.0613 - val_mse: 0.0119 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1092
# Epoch 492/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0592 - mse: 0.0108 - mae: 0.0592 - root_mean_squared_error: 0.1039 - val_loss: 0.0613 - val_mse: 0.0119 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1092
# Epoch 493/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0592 - mse: 0.0108 - mae: 0.0592 - root_mean_squared_error: 0.1039 - val_loss: 0.0613 - val_mse: 0.0119 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1092
# Epoch 494/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0592 - mse: 0.0108 - mae: 0.0592 - root_mean_squared_error: 0.1039 - val_loss: 0.0613 - val_mse: 0.0119 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1092
# Epoch 495/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0592 - mse: 0.0108 - mae: 0.0592 - root_mean_squared_error: 0.1039 - val_loss: 0.0613 - val_mse: 0.0119 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1092
# Epoch 496/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0592 - mse: 0.0108 - mae: 0.0592 - root_mean_squared_error: 0.1039 - val_loss: 0.0613 - val_mse: 0.0119 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1092
# Epoch 497/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0592 - mse: 0.0108 - mae: 0.0592 - root_mean_squared_error: 0.1039 - val_loss: 0.0613 - val_mse: 0.0119 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1092
# Epoch 498/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0592 - mse: 0.0108 - mae: 0.0592 - root_mean_squared_error: 0.1039 - val_loss: 0.0613 - val_mse: 0.0119 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1092
# Epoch 499/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0592 - mse: 0.0108 - mae: 0.0592 - root_mean_squared_error: 0.1039 - val_loss: 0.0613 - val_mse: 0.0119 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1092
# Epoch 500/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0592 - mse: 0.0108 - mae: 0.0592 - root_mean_squared_error: 0.1039 - val_loss: 0.0613 - val_mse: 0.0119 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1092

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mae'],label='train mae')
pyplot.plot(history.history['val_mae'],label='val mae')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mse'],label='train mse')
pyplot.plot(history.history['val_mse'],label='val mse')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['root_mean_squared_error'],label='train rmse')
pyplot.plot(history.history['val_root_mean_squared_error'],label='val rmse')
pyplot.legend()
pyplot.show()
# Out:
# The testing MAE loss is: 0.06033646
# The testing MSE loss is: 0.0112978835
# The testing RMSE loss is: 0.106291495

# %%
pyplot.plot(test_y[:,9],color='red', label='True Values')
pyplot.plot(out[:,9],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()

# %%
dataset_test=pd.read_excel('F:\MS thesis data/Hopper Crossing.xlsx')
dataset_test=dataset_test.drop(['Date/Time','Flowd'],axis=1)
dataset_test.dropna(inplace=True)

# %%
shape=np.shape(dataset_test)
print(shape)
pyplot.plot(dataset_test)
# Out:
# (26285, 3)
# [<matplotlib.lines.Line2D at 0x203f539cd08>,
#  <matplotlib.lines.Line2D at 0x203f539cb08>,
#  <matplotlib.lines.Line2D at 0x203f539c888>]

# %%
dataset_test
# Out:
#        Cumulative rainfall   Flow  Level
# 0                      0.0  0.093    1.50
# 1                      0.0  0.093    1.50
# 2                      0.0  0.093    1.50
# 3                      0.0  0.093    1.50
# 4                      0.0  0.093    1.50
# ...                    ...    ...     ...
# 26280                  0.2  0.080    1.49
# 26281                  0.2  0.080    1.49
# 26282                  0.2  0.080    1.49
# 26283                  0.2  0.080    1.49
# 26284                  0.2  0.080    1.49
#
# [26285 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset_test)))
# Out:
# The std of original data is Cumulative rainfall    2.451640
# Flow                   0.520832
# Level                  0.083204
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset_test=dataset_test.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset_test.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset_test[:,0]== maxi[0])
    ind2=np.argwhere(dataset_test[:,1]== maxi[1])
    ind3=np.argwhere(dataset_test[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset_test.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset_test[:,0]== mini[0])
    ind2=np.argwhere(dataset_test[:,1]== mini[1])
    ind3=np.argwhere(dataset_test[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset_test)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset_test = min_max_scaler.fit_transform(dataset_test)
# Out:
# The std of cleaned data is 1.5154548293543502

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=10
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values

#one hour
#test_X, test_y = values[:, :-out_hour], values[:,-1]


test_X, test_y = values[:, :-out_hour], values[:, -out_hour: ]


test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6336, 48)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...   var3(t)  var3(t+1)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...  0.791262   0.820388
# 7    0.230769   0.500068   0.762136   0.230769  ...  0.820388   0.844660
# 8    0.230769   0.524545   0.776699   0.215385  ...  0.844660   0.873786
# 9    0.215385   0.524545   0.776699   0.123077  ...  0.873786   0.898058
# 10   0.123077   0.549980   0.791262   0.092308  ...  0.898058   0.932039
#
#     var3(t+2)  var3(t+3)  var3(t+4)  var3(t+5)  var3(t+6)  var3(t+7)  \
# 6    0.844660   0.873786   0.898058   0.932039   0.966019   1.000000
# 7    0.873786   0.898058   0.932039   0.966019   1.000000   0.941748
# 8    0.898058   0.932039   0.966019   1.000000   0.941748   0.912621
# 9    0.932039   0.966019   1.000000   0.941748   0.912621   0.800971
# 10   0.966019   1.000000   0.941748   0.912621   0.800971   0.723301
#
#     var3(t+8)  var3(t+9)
# 6    0.941748   0.912621
# 7    0.912621   0.800971
# 8    0.800971   0.723301
# 9    0.723301   0.665049
# 10   0.665049   0.616505
#
# [5 rows x 28 columns]

# %%
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
# Out:
# The testing MAE loss is: 0.059927464
# The testing MSE loss is: 0.01118408
# The testing RMSE loss is: 0.105754815

# %%
pyplot.plot(test_y[:,9],color='red', label='True Values')
pyplot.plot(out[:,9],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()
