# %%
import pandas as pd
from pandas import concat
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from sklearn import preprocessing
from tensorflow.keras import backend as K
#from sklearn.preprocessing import MinMaxScaler
#from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input, Dense, LSTM,GRU,SimpleRNN, Activation
from matplotlib import pyplot
#from sklearn.model_selection import train_test_split

# %%
"# convert series to supervised learning\n" 
#windowing of data
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1),
    for i in range(n_in, 0, -1): #startes from n_in and decreses to 0 by decreasing each time -1
     cols.append(df.shift(i))
     names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
     cols.append(df.shift(-i))
     if i == 0:
       names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
     else:
       names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together\n",
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values\n",
    if dropnan:
      agg.dropna(inplace=True)
    return agg

# %%
#def root_mean_squared_error(y_true, y_pred):
 #       return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
dataset1=pd.read_excel('F:\MS thesis data/Brooklyn.xlsx')
dataset1=dataset1.drop(['Date/Time','Flowd'],axis=1)
dataset1.dropna(inplace=True)

# %%
shape=np.shape(dataset1)
print(shape)
pyplot.plot(dataset1)
# Out:
# (26302, 3)
# [<matplotlib.lines.Line2D at 0x140cb6d6708>,
#  <matplotlib.lines.Line2D at 0x140cb6d6108>,
#  <matplotlib.lines.Line2D at 0x140cb93d648>]

# %%
dataset1
# Out:
#        Cumulative rainfall    Flow  Level
# 0                       0.0  0.172   0.352
# 1                       0.0  0.180   0.356
# 2                       0.0  0.180   0.356
# 3                       0.0  0.189   0.360
# 4                       0.0  0.189   0.360
# ...                     ...    ...     ...
# 26297                   0.0  0.025   0.232
# 26298                   0.0  0.023   0.228
# 26299                   0.0  0.023   0.228
# 26300                   0.0  0.023   0.228
# 26301                   0.0  0.023   0.228
#
# [26302 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset1)))
# Out:
# The std of original data is Cumulative rainfall     2.872616
# Flow                    1.306642
# Level                   0.147238
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset=dataset1.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset[:,0]== maxi[0])
    ind2=np.argwhere(dataset[:,1]== maxi[1])
    ind3=np.argwhere(dataset[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset[:,0]== mini[0])
    ind2=np.argwhere(dataset[:,1]== mini[1])
    ind3=np.argwhere(dataset[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset = min_max_scaler.fit_transform(dataset)
# Out:
# The std of cleaned data is 1.626639593959813

# %%
pyplot.plot(dataset)
# Out:
# [<matplotlib.lines.Line2D at 0x140cb9e5388>,
#  <matplotlib.lines.Line2D at 0x140cb84e348>,
#  <matplotlib.lines.Line2D at 0x140cb84e508>]

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=2
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values
train_size  = int(len(dataset) * 0.50)
val_size=int(len(dataset) * 0.75)
train_X, train_y = values[0:train_size, :-out_hour], values[0:train_size,-out_hour: ]
val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-out_hour: ]
test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-out_hour:]
#for last hour
#train_X, train_y = values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]  #for only last hour
#val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]
#test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-1]
print(train_X, train_y)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6344, 24)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  var2(t-3)  var3(t-3)  \
# 6    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 7    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 8    0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
# 9    0.215385   0.524545   0.776699   0.123077   0.549980   0.791262
# 10   0.123077   0.549980   0.791262   0.092308   0.603309   0.820388
#
#     var1(t-2)  var2(t-2)  var3(t-2)  var1(t-1)  var2(t-1)  var3(t-1)  \
# 6    0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
# 7    0.215385   0.524545   0.776699   0.123077   0.549980   0.791262
# 8    0.123077   0.549980   0.791262   0.092308   0.603309   0.820388
# 9    0.092308   0.603309   0.820388   0.092308   0.650485   0.844660
# 10   0.092308   0.650485   0.844660   0.092308   0.709285   0.873786
#
#      var3(t)  var3(t+1)
# 6   0.791262   0.820388
# 7   0.820388   0.844660
# 8   0.844660   0.873786
# 9   0.873786   0.898058
# 10  0.898058   0.932039
# [[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]
#  [0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]
#  [0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]
#  ...
#  [0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]
#  [0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]
#  [0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]] [[0.79126215 0.8203884 ]
#  [0.8203884  0.8446602 ]
#  [0.8446602  0.8737864 ]
#  ...
#  [0.23786408 0.24271844]
#  [0.24271844 0.24757281]
#  [0.24757281 0.24757281]]

# %%
print(train_X, train_y)
# Out:
# [[[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]]
#
#  [[0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]]
#
#  [[0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]]
#
#  ...
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]]] [[0.79126215 0.8203884 ]
#  [0.8203884  0.8446602 ]
#  [0.8446602  0.8737864 ]
#  ...
#  [0.23786408 0.24271844]
#  [0.24271844 0.24757281]
#  [0.24757281 0.24757281]]

# %%
print(train_X.shape, train_y.shape, val_X.shape, val_y.shape)
# Out:
# (3175, 1, 18) (3175, 2) (1588, 1, 18) (1588, 2)

# %%
randomState = 46
np.random.seed(randomState)
#tensorflow.random.set_random_seed(randomState)
tensorflow.random.set_seed(randomState)
model = Sequential()
model.add(GRU(15,input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dense(22))
#model.add(Activation('relu'))    
model.add(Dense(out_hour,activation = "sigmoid"))
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.001)
#    opt=tensorflow.keras.optimizers.Adam(learning_rate=0.00075)
model.compile(loss='mae', optimizer=opt,metrics=['mse','mae',tensorflow.keras.metrics.RootMeanSquaredError()])
history = model.fit(train_X, train_y,validation_data=(val_X, val_y), epochs=500, batch_size=100,verbose=1,shuffle=False)
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)
# Out:
# Train on 3175 samples, validate on 1588 samples
# Epoch 1/500
# 3175/3175 [==============================] - 3s 904us/sample - loss: 0.2501 - mse: 0.0754 - mae: 0.2501 - root_mean_squared_error: 0.2745 - val_loss: 0.2558 - val_mse: 0.0809 - val_mae: 0.2558 - val_root_mean_squared_error: 0.2844
# Epoch 2/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.2210 - mse: 0.0613 - mae: 0.2210 - root_mean_squared_error: 0.2475 - val_loss: 0.2288 - val_mse: 0.0665 - val_mae: 0.2288 - val_root_mean_squared_error: 0.2580
# Epoch 3/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.1968 - mse: 0.0515 - mae: 0.1968 - root_mean_squared_error: 0.2270 - val_loss: 0.2048 - val_mse: 0.0555 - val_mae: 0.2048 - val_root_mean_squared_error: 0.2356
# Epoch 4/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.1766 - mse: 0.0447 - mae: 0.1766 - root_mean_squared_error: 0.2115 - val_loss: 0.1851 - val_mse: 0.0473 - val_mae: 0.1851 - val_root_mean_squared_error: 0.2174
# Epoch 5/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.1604 - mse: 0.0395 - mae: 0.1604 - root_mean_squared_error: 0.1987 - val_loss: 0.1686 - val_mse: 0.0405 - val_mae: 0.1686 - val_root_mean_squared_error: 0.2013
# Epoch 6/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.1460 - mse: 0.0341 - mae: 0.1460 - root_mean_squared_error: 0.1848 - val_loss: 0.1532 - val_mse: 0.0341 - val_mae: 0.1532 - val_root_mean_squared_error: 0.1848
# Epoch 7/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.1311 - mse: 0.0280 - mae: 0.1311 - root_mean_squared_error: 0.1674 - val_loss: 0.1370 - val_mse: 0.0276 - val_mae: 0.1370 - val_root_mean_squared_error: 0.1661
# Epoch 8/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.1148 - mse: 0.0215 - mae: 0.1148 - root_mean_squared_error: 0.1465 - val_loss: 0.1196 - val_mse: 0.0214 - val_mae: 0.1196 - val_root_mean_squared_error: 0.1464
# Epoch 9/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0986 - mse: 0.0158 - mae: 0.0986 - root_mean_squared_error: 0.1258 - val_loss: 0.1040 - val_mse: 0.0168 - val_mae: 0.1040 - val_root_mean_squared_error: 0.1296
# Epoch 10/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0855 - mse: 0.0122 - mae: 0.0855 - root_mean_squared_error: 0.1106 - val_loss: 0.0927 - val_mse: 0.0138 - val_mae: 0.0927 - val_root_mean_squared_error: 0.1176
# Epoch 11/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0758 - mse: 0.0103 - mae: 0.0758 - root_mean_squared_error: 0.1014 - val_loss: 0.0844 - val_mse: 0.0120 - val_mae: 0.0844 - val_root_mean_squared_error: 0.1097
# Epoch 12/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0688 - mse: 0.0092 - mae: 0.0688 - root_mean_squared_error: 0.0960 - val_loss: 0.0783 - val_mse: 0.0110 - val_mae: 0.0783 - val_root_mean_squared_error: 0.1047
# Epoch 13/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0635 - mse: 0.0086 - mae: 0.0635 - root_mean_squared_error: 0.0930 - val_loss: 0.0735 - val_mse: 0.0103 - val_mae: 0.0735 - val_root_mean_squared_error: 0.1014
# Epoch 14/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0594 - mse: 0.0083 - mae: 0.0594 - root_mean_squared_error: 0.0909 - val_loss: 0.0697 - val_mse: 0.0097 - val_mae: 0.0697 - val_root_mean_squared_error: 0.0987
# Epoch 15/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0565 - mse: 0.0080 - mae: 0.0565 - root_mean_squared_error: 0.0892 - val_loss: 0.0666 - val_mse: 0.0093 - val_mae: 0.0666 - val_root_mean_squared_error: 0.0964
# Epoch 16/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0543 - mse: 0.0076 - mae: 0.0543 - root_mean_squared_error: 0.0874 - val_loss: 0.0642 - val_mse: 0.0089 - val_mae: 0.0642 - val_root_mean_squared_error: 0.0942
# Epoch 17/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0527 - mse: 0.0073 - mae: 0.0527 - root_mean_squared_error: 0.0854 - val_loss: 0.0623 - val_mse: 0.0085 - val_mae: 0.0623 - val_root_mean_squared_error: 0.0922
# Epoch 18/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0511 - mse: 0.0070 - mae: 0.0511 - root_mean_squared_error: 0.0835 - val_loss: 0.0605 - val_mse: 0.0082 - val_mae: 0.0605 - val_root_mean_squared_error: 0.0905
# Epoch 19/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0497 - mse: 0.0067 - mae: 0.0497 - root_mean_squared_error: 0.0817 - val_loss: 0.0588 - val_mse: 0.0079 - val_mae: 0.0588 - val_root_mean_squared_error: 0.0888
# Epoch 20/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0484 - mse: 0.0064 - mae: 0.0484 - root_mean_squared_error: 0.0799 - val_loss: 0.0572 - val_mse: 0.0076 - val_mae: 0.0572 - val_root_mean_squared_error: 0.0871
# Epoch 21/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0472 - mse: 0.0061 - mae: 0.0472 - root_mean_squared_error: 0.0781 - val_loss: 0.0558 - val_mse: 0.0074 - val_mae: 0.0558 - val_root_mean_squared_error: 0.0857
# Epoch 22/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0459 - mse: 0.0058 - mae: 0.0459 - root_mean_squared_error: 0.0764 - val_loss: 0.0545 - val_mse: 0.0071 - val_mae: 0.0545 - val_root_mean_squared_error: 0.0843
# Epoch 23/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0448 - mse: 0.0056 - mae: 0.0448 - root_mean_squared_error: 0.0748 - val_loss: 0.0534 - val_mse: 0.0069 - val_mae: 0.0534 - val_root_mean_squared_error: 0.0832
# Epoch 24/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0438 - mse: 0.0054 - mae: 0.0438 - root_mean_squared_error: 0.0734 - val_loss: 0.0524 - val_mse: 0.0067 - val_mae: 0.0524 - val_root_mean_squared_error: 0.0821
# Epoch 25/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0429 - mse: 0.0052 - mae: 0.0429 - root_mean_squared_error: 0.0721 - val_loss: 0.0516 - val_mse: 0.0066 - val_mae: 0.0516 - val_root_mean_squared_error: 0.0814
# Epoch 26/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0421 - mse: 0.0051 - mae: 0.0421 - root_mean_squared_error: 0.0711 - val_loss: 0.0509 - val_mse: 0.0065 - val_mae: 0.0509 - val_root_mean_squared_error: 0.0807
# Epoch 27/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0414 - mse: 0.0049 - mae: 0.0414 - root_mean_squared_error: 0.0702 - val_loss: 0.0502 - val_mse: 0.0064 - val_mae: 0.0502 - val_root_mean_squared_error: 0.0800
# Epoch 28/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0409 - mse: 0.0048 - mae: 0.0409 - root_mean_squared_error: 0.0694 - val_loss: 0.0496 - val_mse: 0.0063 - val_mae: 0.0496 - val_root_mean_squared_error: 0.0795
# Epoch 29/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0404 - mse: 0.0047 - mae: 0.0404 - root_mean_squared_error: 0.0686 - val_loss: 0.0491 - val_mse: 0.0062 - val_mae: 0.0491 - val_root_mean_squared_error: 0.0789
# Epoch 30/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0399 - mse: 0.0046 - mae: 0.0399 - root_mean_squared_error: 0.0680 - val_loss: 0.0487 - val_mse: 0.0062 - val_mae: 0.0487 - val_root_mean_squared_error: 0.0786
# Epoch 31/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0395 - mse: 0.0046 - mae: 0.0395 - root_mean_squared_error: 0.0675 - val_loss: 0.0482 - val_mse: 0.0061 - val_mae: 0.0482 - val_root_mean_squared_error: 0.0782
# Epoch 32/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0392 - mse: 0.0045 - mae: 0.0392 - root_mean_squared_error: 0.0670 - val_loss: 0.0479 - val_mse: 0.0061 - val_mae: 0.0479 - val_root_mean_squared_error: 0.0778
# Epoch 33/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0388 - mse: 0.0044 - mae: 0.0388 - root_mean_squared_error: 0.0666 - val_loss: 0.0475 - val_mse: 0.0060 - val_mae: 0.0475 - val_root_mean_squared_error: 0.0774
# Epoch 34/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0384 - mse: 0.0044 - mae: 0.0384 - root_mean_squared_error: 0.0662 - val_loss: 0.0470 - val_mse: 0.0059 - val_mae: 0.0470 - val_root_mean_squared_error: 0.0770
# Epoch 35/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0381 - mse: 0.0043 - mae: 0.0381 - root_mean_squared_error: 0.0659 - val_loss: 0.0466 - val_mse: 0.0059 - val_mae: 0.0466 - val_root_mean_squared_error: 0.0766
# Epoch 36/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0377 - mse: 0.0043 - mae: 0.0377 - root_mean_squared_error: 0.0656 - val_loss: 0.0463 - val_mse: 0.0058 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0763
# Epoch 37/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0375 - mse: 0.0043 - mae: 0.0375 - root_mean_squared_error: 0.0654 - val_loss: 0.0460 - val_mse: 0.0058 - val_mae: 0.0460 - val_root_mean_squared_error: 0.0760
# Epoch 38/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0373 - mse: 0.0042 - mae: 0.0373 - root_mean_squared_error: 0.0651 - val_loss: 0.0457 - val_mse: 0.0057 - val_mae: 0.0457 - val_root_mean_squared_error: 0.0758
# Epoch 39/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0370 - mse: 0.0042 - mae: 0.0370 - root_mean_squared_error: 0.0649 - val_loss: 0.0454 - val_mse: 0.0057 - val_mae: 0.0454 - val_root_mean_squared_error: 0.0755
# Epoch 40/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0368 - mse: 0.0042 - mae: 0.0368 - root_mean_squared_error: 0.0647 - val_loss: 0.0451 - val_mse: 0.0057 - val_mae: 0.0451 - val_root_mean_squared_error: 0.0753
# Epoch 41/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0365 - mse: 0.0042 - mae: 0.0365 - root_mean_squared_error: 0.0645 - val_loss: 0.0448 - val_mse: 0.0056 - val_mae: 0.0448 - val_root_mean_squared_error: 0.0750
# Epoch 42/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0363 - mse: 0.0041 - mae: 0.0363 - root_mean_squared_error: 0.0643 - val_loss: 0.0445 - val_mse: 0.0056 - val_mae: 0.0445 - val_root_mean_squared_error: 0.0747
# Epoch 43/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0361 - mse: 0.0041 - mae: 0.0361 - root_mean_squared_error: 0.0641 - val_loss: 0.0442 - val_mse: 0.0055 - val_mae: 0.0442 - val_root_mean_squared_error: 0.0745
# Epoch 44/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0359 - mse: 0.0041 - mae: 0.0359 - root_mean_squared_error: 0.0640 - val_loss: 0.0439 - val_mse: 0.0055 - val_mae: 0.0439 - val_root_mean_squared_error: 0.0743
# Epoch 45/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0356 - mse: 0.0041 - mae: 0.0356 - root_mean_squared_error: 0.0638 - val_loss: 0.0436 - val_mse: 0.0055 - val_mae: 0.0436 - val_root_mean_squared_error: 0.0740
# Epoch 46/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0354 - mse: 0.0040 - mae: 0.0354 - root_mean_squared_error: 0.0636 - val_loss: 0.0434 - val_mse: 0.0054 - val_mae: 0.0434 - val_root_mean_squared_error: 0.0738
# Epoch 47/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0352 - mse: 0.0040 - mae: 0.0352 - root_mean_squared_error: 0.0634 - val_loss: 0.0431 - val_mse: 0.0054 - val_mae: 0.0431 - val_root_mean_squared_error: 0.0736
# Epoch 48/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0350 - mse: 0.0040 - mae: 0.0350 - root_mean_squared_error: 0.0633 - val_loss: 0.0429 - val_mse: 0.0054 - val_mae: 0.0429 - val_root_mean_squared_error: 0.0734
# Epoch 49/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0348 - mse: 0.0040 - mae: 0.0348 - root_mean_squared_error: 0.0632 - val_loss: 0.0426 - val_mse: 0.0054 - val_mae: 0.0426 - val_root_mean_squared_error: 0.0732
# Epoch 50/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0346 - mse: 0.0040 - mae: 0.0346 - root_mean_squared_error: 0.0630 - val_loss: 0.0424 - val_mse: 0.0053 - val_mae: 0.0424 - val_root_mean_squared_error: 0.0731
# Epoch 51/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0344 - mse: 0.0040 - mae: 0.0344 - root_mean_squared_error: 0.0629 - val_loss: 0.0422 - val_mse: 0.0053 - val_mae: 0.0422 - val_root_mean_squared_error: 0.0728
# Epoch 52/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0342 - mse: 0.0039 - mae: 0.0342 - root_mean_squared_error: 0.0627 - val_loss: 0.0419 - val_mse: 0.0053 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0727
# Epoch 53/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0340 - mse: 0.0039 - mae: 0.0340 - root_mean_squared_error: 0.0626 - val_loss: 0.0417 - val_mse: 0.0053 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0725
# Epoch 54/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0338 - mse: 0.0039 - mae: 0.0338 - root_mean_squared_error: 0.0625 - val_loss: 0.0415 - val_mse: 0.0052 - val_mae: 0.0415 - val_root_mean_squared_error: 0.0723
# Epoch 55/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0336 - mse: 0.0039 - mae: 0.0336 - root_mean_squared_error: 0.0623 - val_loss: 0.0413 - val_mse: 0.0052 - val_mae: 0.0413 - val_root_mean_squared_error: 0.0722
# Epoch 56/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0335 - mse: 0.0039 - mae: 0.0335 - root_mean_squared_error: 0.0622 - val_loss: 0.0411 - val_mse: 0.0052 - val_mae: 0.0411 - val_root_mean_squared_error: 0.0721
# Epoch 57/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0333 - mse: 0.0039 - mae: 0.0333 - root_mean_squared_error: 0.0621 - val_loss: 0.0409 - val_mse: 0.0052 - val_mae: 0.0409 - val_root_mean_squared_error: 0.0720
# Epoch 58/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0331 - mse: 0.0038 - mae: 0.0331 - root_mean_squared_error: 0.0620 - val_loss: 0.0407 - val_mse: 0.0052 - val_mae: 0.0407 - val_root_mean_squared_error: 0.0718
# Epoch 59/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0330 - mse: 0.0038 - mae: 0.0330 - root_mean_squared_error: 0.0619 - val_loss: 0.0405 - val_mse: 0.0051 - val_mae: 0.0405 - val_root_mean_squared_error: 0.0718
# Epoch 60/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0328 - mse: 0.0038 - mae: 0.0328 - root_mean_squared_error: 0.0617 - val_loss: 0.0403 - val_mse: 0.0051 - val_mae: 0.0403 - val_root_mean_squared_error: 0.0716
# Epoch 61/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0327 - mse: 0.0038 - mae: 0.0327 - root_mean_squared_error: 0.0616 - val_loss: 0.0402 - val_mse: 0.0051 - val_mae: 0.0402 - val_root_mean_squared_error: 0.0716
# Epoch 62/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0325 - mse: 0.0038 - mae: 0.0325 - root_mean_squared_error: 0.0615 - val_loss: 0.0400 - val_mse: 0.0051 - val_mae: 0.0400 - val_root_mean_squared_error: 0.0714
# Epoch 63/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0324 - mse: 0.0038 - mae: 0.0324 - root_mean_squared_error: 0.0614 - val_loss: 0.0398 - val_mse: 0.0051 - val_mae: 0.0398 - val_root_mean_squared_error: 0.0713
# Epoch 64/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0322 - mse: 0.0038 - mae: 0.0322 - root_mean_squared_error: 0.0613 - val_loss: 0.0396 - val_mse: 0.0051 - val_mae: 0.0396 - val_root_mean_squared_error: 0.0712
# Epoch 65/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0321 - mse: 0.0037 - mae: 0.0321 - root_mean_squared_error: 0.0612 - val_loss: 0.0394 - val_mse: 0.0051 - val_mae: 0.0394 - val_root_mean_squared_error: 0.0711
# Epoch 66/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0320 - mse: 0.0037 - mae: 0.0320 - root_mean_squared_error: 0.0611 - val_loss: 0.0393 - val_mse: 0.0050 - val_mae: 0.0393 - val_root_mean_squared_error: 0.0711
# Epoch 67/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0318 - mse: 0.0037 - mae: 0.0318 - root_mean_squared_error: 0.0610 - val_loss: 0.0391 - val_mse: 0.0050 - val_mae: 0.0391 - val_root_mean_squared_error: 0.0710
# Epoch 68/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0317 - mse: 0.0037 - mae: 0.0317 - root_mean_squared_error: 0.0610 - val_loss: 0.0389 - val_mse: 0.0050 - val_mae: 0.0389 - val_root_mean_squared_error: 0.0709
# Epoch 69/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0316 - mse: 0.0037 - mae: 0.0316 - root_mean_squared_error: 0.0609 - val_loss: 0.0388 - val_mse: 0.0050 - val_mae: 0.0388 - val_root_mean_squared_error: 0.0709
# Epoch 70/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0314 - mse: 0.0037 - mae: 0.0314 - root_mean_squared_error: 0.0608 - val_loss: 0.0386 - val_mse: 0.0050 - val_mae: 0.0386 - val_root_mean_squared_error: 0.0708
# Epoch 71/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0313 - mse: 0.0037 - mae: 0.0313 - root_mean_squared_error: 0.0608 - val_loss: 0.0385 - val_mse: 0.0050 - val_mae: 0.0385 - val_root_mean_squared_error: 0.0708
# Epoch 72/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0312 - mse: 0.0037 - mae: 0.0312 - root_mean_squared_error: 0.0607 - val_loss: 0.0383 - val_mse: 0.0050 - val_mae: 0.0383 - val_root_mean_squared_error: 0.0707
# Epoch 73/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0311 - mse: 0.0037 - mae: 0.0311 - root_mean_squared_error: 0.0606 - val_loss: 0.0382 - val_mse: 0.0050 - val_mae: 0.0382 - val_root_mean_squared_error: 0.0706
# Epoch 74/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0310 - mse: 0.0037 - mae: 0.0310 - root_mean_squared_error: 0.0606 - val_loss: 0.0380 - val_mse: 0.0050 - val_mae: 0.0380 - val_root_mean_squared_error: 0.0706
# Epoch 75/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0309 - mse: 0.0037 - mae: 0.0309 - root_mean_squared_error: 0.0605 - val_loss: 0.0379 - val_mse: 0.0050 - val_mae: 0.0379 - val_root_mean_squared_error: 0.0706
# Epoch 76/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0308 - mse: 0.0037 - mae: 0.0308 - root_mean_squared_error: 0.0605 - val_loss: 0.0377 - val_mse: 0.0050 - val_mae: 0.0377 - val_root_mean_squared_error: 0.0705
# Epoch 77/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0307 - mse: 0.0037 - mae: 0.0307 - root_mean_squared_error: 0.0604 - val_loss: 0.0376 - val_mse: 0.0050 - val_mae: 0.0376 - val_root_mean_squared_error: 0.0705
# Epoch 78/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0306 - mse: 0.0036 - mae: 0.0306 - root_mean_squared_error: 0.0603 - val_loss: 0.0375 - val_mse: 0.0050 - val_mae: 0.0375 - val_root_mean_squared_error: 0.0705
# Epoch 79/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0305 - mse: 0.0036 - mae: 0.0305 - root_mean_squared_error: 0.0603 - val_loss: 0.0373 - val_mse: 0.0050 - val_mae: 0.0373 - val_root_mean_squared_error: 0.0704
# Epoch 80/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0304 - mse: 0.0036 - mae: 0.0304 - root_mean_squared_error: 0.0602 - val_loss: 0.0372 - val_mse: 0.0050 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0704
# Epoch 81/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0303 - mse: 0.0036 - mae: 0.0303 - root_mean_squared_error: 0.0602 - val_loss: 0.0371 - val_mse: 0.0050 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0704
# Epoch 82/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0302 - mse: 0.0036 - mae: 0.0302 - root_mean_squared_error: 0.0601 - val_loss: 0.0370 - val_mse: 0.0050 - val_mae: 0.0370 - val_root_mean_squared_error: 0.0704
# Epoch 83/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0302 - mse: 0.0036 - mae: 0.0302 - root_mean_squared_error: 0.0601 - val_loss: 0.0369 - val_mse: 0.0050 - val_mae: 0.0369 - val_root_mean_squared_error: 0.0704
# Epoch 84/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0301 - mse: 0.0036 - mae: 0.0301 - root_mean_squared_error: 0.0601 - val_loss: 0.0368 - val_mse: 0.0049 - val_mae: 0.0368 - val_root_mean_squared_error: 0.0703
# Epoch 85/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0300 - mse: 0.0036 - mae: 0.0300 - root_mean_squared_error: 0.0600 - val_loss: 0.0367 - val_mse: 0.0049 - val_mae: 0.0367 - val_root_mean_squared_error: 0.0703
# Epoch 86/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0310 - mse: 0.0039 - mae: 0.0310 - root_mean_squared_error: 0.062 - 0s 27us/sample - loss: 0.0299 - mse: 0.0036 - mae: 0.0299 - root_mean_squared_error: 0.0600 - val_loss: 0.0366 - val_mse: 0.0049 - val_mae: 0.0366 - val_root_mean_squared_error: 0.0703
# Epoch 87/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0299 - mse: 0.0036 - mae: 0.0299 - root_mean_squared_error: 0.0599 - val_loss: 0.0365 - val_mse: 0.0049 - val_mae: 0.0365 - val_root_mean_squared_error: 0.0703
# Epoch 88/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0298 - mse: 0.0036 - mae: 0.0298 - root_mean_squared_error: 0.0599 - val_loss: 0.0364 - val_mse: 0.0049 - val_mae: 0.0364 - val_root_mean_squared_error: 0.0703
# Epoch 89/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0297 - mse: 0.0036 - mae: 0.0297 - root_mean_squared_error: 0.0599 - val_loss: 0.0363 - val_mse: 0.0049 - val_mae: 0.0363 - val_root_mean_squared_error: 0.0702
# Epoch 90/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0296 - mse: 0.0036 - mae: 0.0296 - root_mean_squared_error: 0.0599 - val_loss: 0.0362 - val_mse: 0.0049 - val_mae: 0.0362 - val_root_mean_squared_error: 0.0702
# Epoch 91/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0296 - mse: 0.0036 - mae: 0.0296 - root_mean_squared_error: 0.0599 - val_loss: 0.0362 - val_mse: 0.0049 - val_mae: 0.0362 - val_root_mean_squared_error: 0.0702
# Epoch 92/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0295 - mse: 0.0036 - mae: 0.0295 - root_mean_squared_error: 0.0599 - val_loss: 0.0361 - val_mse: 0.0049 - val_mae: 0.0361 - val_root_mean_squared_error: 0.0702
# Epoch 93/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0300 - mse: 0.0038 - mae: 0.0300 - root_mean_squared_error: 0.061 - 0s 27us/sample - loss: 0.0294 - mse: 0.0036 - mae: 0.0294 - root_mean_squared_error: 0.0598 - val_loss: 0.0359 - val_mse: 0.0049 - val_mae: 0.0359 - val_root_mean_squared_error: 0.0701
# Epoch 94/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0294 - mse: 0.0036 - mae: 0.0294 - root_mean_squared_error: 0.0598 - val_loss: 0.0358 - val_mse: 0.0049 - val_mae: 0.0358 - val_root_mean_squared_error: 0.0700
# Epoch 95/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0293 - mse: 0.0036 - mae: 0.0293 - root_mean_squared_error: 0.0598 - val_loss: 0.0357 - val_mse: 0.0049 - val_mae: 0.0357 - val_root_mean_squared_error: 0.0699
# Epoch 96/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0292 - mse: 0.0036 - mae: 0.0292 - root_mean_squared_error: 0.0597 - val_loss: 0.0356 - val_mse: 0.0049 - val_mae: 0.0356 - val_root_mean_squared_error: 0.0699
# Epoch 97/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0292 - mse: 0.0036 - mae: 0.0292 - root_mean_squared_error: 0.0598 - val_loss: 0.0356 - val_mse: 0.0049 - val_mae: 0.0356 - val_root_mean_squared_error: 0.0699
# Epoch 98/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0292 - mse: 0.0036 - mae: 0.0292 - root_mean_squared_error: 0.0597 - val_loss: 0.0355 - val_mse: 0.0049 - val_mae: 0.0355 - val_root_mean_squared_error: 0.0700
# Epoch 99/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0291 - mse: 0.0036 - mae: 0.0291 - root_mean_squared_error: 0.0597 - val_loss: 0.0355 - val_mse: 0.0049 - val_mae: 0.0355 - val_root_mean_squared_error: 0.0699
# Epoch 100/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0291 - mse: 0.0036 - mae: 0.0291 - root_mean_squared_error: 0.0597 - val_loss: 0.0354 - val_mse: 0.0049 - val_mae: 0.0354 - val_root_mean_squared_error: 0.0699
# Epoch 101/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0290 - mse: 0.0036 - mae: 0.0290 - root_mean_squared_error: 0.0597 - val_loss: 0.0353 - val_mse: 0.0049 - val_mae: 0.0353 - val_root_mean_squared_error: 0.0699
# Epoch 102/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0290 - mse: 0.0036 - mae: 0.0290 - root_mean_squared_error: 0.0597 - val_loss: 0.0353 - val_mse: 0.0049 - val_mae: 0.0353 - val_root_mean_squared_error: 0.0699
# Epoch 103/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0289 - mse: 0.0036 - mae: 0.0289 - root_mean_squared_error: 0.0597 - val_loss: 0.0352 - val_mse: 0.0049 - val_mae: 0.0352 - val_root_mean_squared_error: 0.0698
# Epoch 104/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0288 - mse: 0.0036 - mae: 0.0288 - root_mean_squared_error: 0.0597 - val_loss: 0.0350 - val_mse: 0.0049 - val_mae: 0.0350 - val_root_mean_squared_error: 0.0697
# Epoch 105/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0288 - mse: 0.0036 - mae: 0.0288 - root_mean_squared_error: 0.0597 - val_loss: 0.0350 - val_mse: 0.0048 - val_mae: 0.0350 - val_root_mean_squared_error: 0.0696
# Epoch 106/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0292 - mse: 0.0038 - mae: 0.0292 - root_mean_squared_error: 0.061 - 0s 27us/sample - loss: 0.0287 - mse: 0.0036 - mae: 0.0287 - root_mean_squared_error: 0.0597 - val_loss: 0.0349 - val_mse: 0.0048 - val_mae: 0.0349 - val_root_mean_squared_error: 0.0696
# Epoch 107/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0287 - mse: 0.0036 - mae: 0.0287 - root_mean_squared_error: 0.0597 - val_loss: 0.0349 - val_mse: 0.0048 - val_mae: 0.0349 - val_root_mean_squared_error: 0.0695
# Epoch 108/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0287 - mse: 0.0036 - mae: 0.0287 - root_mean_squared_error: 0.0597 - val_loss: 0.0349 - val_mse: 0.0048 - val_mae: 0.0349 - val_root_mean_squared_error: 0.0694
# Epoch 109/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0286 - mse: 0.0036 - mae: 0.0286 - root_mean_squared_error: 0.0597 - val_loss: 0.0348 - val_mse: 0.0048 - val_mae: 0.0348 - val_root_mean_squared_error: 0.0693
# Epoch 110/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0286 - mse: 0.0036 - mae: 0.0286 - root_mean_squared_error: 0.0596 - val_loss: 0.0348 - val_mse: 0.0048 - val_mae: 0.0348 - val_root_mean_squared_error: 0.0693
# Epoch 111/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0286 - mse: 0.0036 - mae: 0.0286 - root_mean_squared_error: 0.0596 - val_loss: 0.0347 - val_mse: 0.0048 - val_mae: 0.0347 - val_root_mean_squared_error: 0.0693
# Epoch 112/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0286 - mse: 0.0036 - mae: 0.0286 - root_mean_squared_error: 0.0596 - val_loss: 0.0347 - val_mse: 0.0048 - val_mae: 0.0347 - val_root_mean_squared_error: 0.0693
# Epoch 113/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0286 - mse: 0.0036 - mae: 0.0286 - root_mean_squared_error: 0.0596 - val_loss: 0.0346 - val_mse: 0.0048 - val_mae: 0.0346 - val_root_mean_squared_error: 0.0693
# Epoch 114/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0285 - mse: 0.0036 - mae: 0.0285 - root_mean_squared_error: 0.0596 - val_loss: 0.0345 - val_mse: 0.0048 - val_mae: 0.0345 - val_root_mean_squared_error: 0.0693
# Epoch 115/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0285 - mse: 0.0036 - mae: 0.0285 - root_mean_squared_error: 0.0596 - val_loss: 0.0345 - val_mse: 0.0048 - val_mae: 0.0345 - val_root_mean_squared_error: 0.0693
# Epoch 116/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0285 - mse: 0.0036 - mae: 0.0285 - root_mean_squared_error: 0.0596 - val_loss: 0.0344 - val_mse: 0.0048 - val_mae: 0.0344 - val_root_mean_squared_error: 0.0692
# Epoch 117/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0284 - mse: 0.0035 - mae: 0.0284 - root_mean_squared_error: 0.0596 - val_loss: 0.0344 - val_mse: 0.0048 - val_mae: 0.0344 - val_root_mean_squared_error: 0.0692
# Epoch 118/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0284 - mse: 0.0035 - mae: 0.0284 - root_mean_squared_error: 0.0596 - val_loss: 0.0344 - val_mse: 0.0048 - val_mae: 0.0344 - val_root_mean_squared_error: 0.0692
# Epoch 119/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0284 - mse: 0.0035 - mae: 0.0284 - root_mean_squared_error: 0.0596 - val_loss: 0.0343 - val_mse: 0.0048 - val_mae: 0.0343 - val_root_mean_squared_error: 0.0692
# Epoch 120/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0284 - mse: 0.0035 - mae: 0.0284 - root_mean_squared_error: 0.0596 - val_loss: 0.0342 - val_mse: 0.0048 - val_mae: 0.0342 - val_root_mean_squared_error: 0.0692
# Epoch 121/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0283 - mse: 0.0035 - mae: 0.0283 - root_mean_squared_error: 0.0595 - val_loss: 0.0342 - val_mse: 0.0048 - val_mae: 0.0342 - val_root_mean_squared_error: 0.0692
# Epoch 122/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0283 - mse: 0.0035 - mae: 0.0283 - root_mean_squared_error: 0.0595 - val_loss: 0.0341 - val_mse: 0.0048 - val_mae: 0.0341 - val_root_mean_squared_error: 0.0691
# Epoch 123/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0283 - mse: 0.0035 - mae: 0.0283 - root_mean_squared_error: 0.0595 - val_loss: 0.0341 - val_mse: 0.0048 - val_mae: 0.0341 - val_root_mean_squared_error: 0.0692
# Epoch 124/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0283 - mse: 0.0035 - mae: 0.0283 - root_mean_squared_error: 0.0595 - val_loss: 0.0340 - val_mse: 0.0048 - val_mae: 0.0340 - val_root_mean_squared_error: 0.0691
# Epoch 125/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0282 - mse: 0.0035 - mae: 0.0282 - root_mean_squared_error: 0.0595 - val_loss: 0.0340 - val_mse: 0.0048 - val_mae: 0.0340 - val_root_mean_squared_error: 0.0691
# Epoch 126/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0282 - mse: 0.0035 - mae: 0.0282 - root_mean_squared_error: 0.0595 - val_loss: 0.0340 - val_mse: 0.0048 - val_mae: 0.0340 - val_root_mean_squared_error: 0.0690
# Epoch 127/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0282 - mse: 0.0035 - mae: 0.0282 - root_mean_squared_error: 0.0595 - val_loss: 0.0340 - val_mse: 0.0048 - val_mae: 0.0340 - val_root_mean_squared_error: 0.0690
# Epoch 128/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0282 - mse: 0.0035 - mae: 0.0282 - root_mean_squared_error: 0.0595 - val_loss: 0.0339 - val_mse: 0.0048 - val_mae: 0.0339 - val_root_mean_squared_error: 0.0691
# Epoch 129/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0282 - mse: 0.0035 - mae: 0.0282 - root_mean_squared_error: 0.0595 - val_loss: 0.0339 - val_mse: 0.0048 - val_mae: 0.0339 - val_root_mean_squared_error: 0.0690
# Epoch 130/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0281 - mse: 0.0035 - mae: 0.0281 - root_mean_squared_error: 0.0594 - val_loss: 0.0338 - val_mse: 0.0048 - val_mae: 0.0338 - val_root_mean_squared_error: 0.0690
# Epoch 131/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0281 - mse: 0.0035 - mae: 0.0281 - root_mean_squared_error: 0.0594 - val_loss: 0.0338 - val_mse: 0.0048 - val_mae: 0.0338 - val_root_mean_squared_error: 0.0690
# Epoch 132/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0281 - mse: 0.0035 - mae: 0.0281 - root_mean_squared_error: 0.0594 - val_loss: 0.0338 - val_mse: 0.0048 - val_mae: 0.0338 - val_root_mean_squared_error: 0.0689
# Epoch 133/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0281 - mse: 0.0035 - mae: 0.0281 - root_mean_squared_error: 0.0594 - val_loss: 0.0338 - val_mse: 0.0047 - val_mae: 0.0338 - val_root_mean_squared_error: 0.0689
# Epoch 134/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0281 - mse: 0.0035 - mae: 0.0281 - root_mean_squared_error: 0.0594 - val_loss: 0.0337 - val_mse: 0.0047 - val_mae: 0.0337 - val_root_mean_squared_error: 0.0689
# Epoch 135/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0281 - mse: 0.0035 - mae: 0.0281 - root_mean_squared_error: 0.0594 - val_loss: 0.0337 - val_mse: 0.0047 - val_mae: 0.0337 - val_root_mean_squared_error: 0.0688
# Epoch 136/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0280 - mse: 0.0035 - mae: 0.0280 - root_mean_squared_error: 0.0594 - val_loss: 0.0337 - val_mse: 0.0047 - val_mae: 0.0337 - val_root_mean_squared_error: 0.0688
# Epoch 137/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0280 - mse: 0.0035 - mae: 0.0280 - root_mean_squared_error: 0.0594 - val_loss: 0.0336 - val_mse: 0.0047 - val_mae: 0.0336 - val_root_mean_squared_error: 0.0688
# Epoch 138/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0280 - mse: 0.0035 - mae: 0.0280 - root_mean_squared_error: 0.0594 - val_loss: 0.0336 - val_mse: 0.0047 - val_mae: 0.0336 - val_root_mean_squared_error: 0.0688
# Epoch 139/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0280 - mse: 0.0035 - mae: 0.0280 - root_mean_squared_error: 0.0594 - val_loss: 0.0335 - val_mse: 0.0047 - val_mae: 0.0335 - val_root_mean_squared_error: 0.0688
# Epoch 140/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0285 - mse: 0.0037 - mae: 0.0285 - root_mean_squared_error: 0.061 - 0s 27us/sample - loss: 0.0280 - mse: 0.0035 - mae: 0.0280 - root_mean_squared_error: 0.0594 - val_loss: 0.0335 - val_mse: 0.0047 - val_mae: 0.0335 - val_root_mean_squared_error: 0.0689
# Epoch 141/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0280 - mse: 0.0035 - mae: 0.0280 - root_mean_squared_error: 0.0593 - val_loss: 0.0334 - val_mse: 0.0047 - val_mae: 0.0334 - val_root_mean_squared_error: 0.0689
# Epoch 142/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0279 - mse: 0.0035 - mae: 0.0279 - root_mean_squared_error: 0.0593 - val_loss: 0.0334 - val_mse: 0.0047 - val_mae: 0.0334 - val_root_mean_squared_error: 0.0689
# Epoch 143/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0279 - mse: 0.0035 - mae: 0.0279 - root_mean_squared_error: 0.0593 - val_loss: 0.0334 - val_mse: 0.0047 - val_mae: 0.0334 - val_root_mean_squared_error: 0.0688
# Epoch 144/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0279 - mse: 0.0035 - mae: 0.0279 - root_mean_squared_error: 0.0593 - val_loss: 0.0334 - val_mse: 0.0047 - val_mae: 0.0334 - val_root_mean_squared_error: 0.0687
# Epoch 145/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0279 - mse: 0.0035 - mae: 0.0279 - root_mean_squared_error: 0.0593 - val_loss: 0.0333 - val_mse: 0.0047 - val_mae: 0.0333 - val_root_mean_squared_error: 0.0688
# Epoch 146/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0279 - mse: 0.0035 - mae: 0.0279 - root_mean_squared_error: 0.0593 - val_loss: 0.0333 - val_mse: 0.0047 - val_mae: 0.0333 - val_root_mean_squared_error: 0.0688
# Epoch 147/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0279 - mse: 0.0035 - mae: 0.0279 - root_mean_squared_error: 0.0593 - val_loss: 0.0333 - val_mse: 0.0047 - val_mae: 0.0333 - val_root_mean_squared_error: 0.0688
# Epoch 148/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0278 - mse: 0.0035 - mae: 0.0278 - root_mean_squared_error: 0.0593 - val_loss: 0.0333 - val_mse: 0.0047 - val_mae: 0.0333 - val_root_mean_squared_error: 0.0687
# Epoch 149/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0278 - mse: 0.0035 - mae: 0.0278 - root_mean_squared_error: 0.0593 - val_loss: 0.0332 - val_mse: 0.0047 - val_mae: 0.0332 - val_root_mean_squared_error: 0.0687
# Epoch 150/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0279 - mse: 0.0035 - mae: 0.0279 - root_mean_squared_error: 0.0593 - val_loss: 0.0332 - val_mse: 0.0047 - val_mae: 0.0332 - val_root_mean_squared_error: 0.0688
# Epoch 151/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0278 - mse: 0.0035 - mae: 0.0278 - root_mean_squared_error: 0.0592 - val_loss: 0.0332 - val_mse: 0.0047 - val_mae: 0.0332 - val_root_mean_squared_error: 0.0687
# Epoch 152/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0278 - mse: 0.0035 - mae: 0.0278 - root_mean_squared_error: 0.0592 - val_loss: 0.0331 - val_mse: 0.0047 - val_mae: 0.0331 - val_root_mean_squared_error: 0.0688
# Epoch 153/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0278 - mse: 0.0035 - mae: 0.0278 - root_mean_squared_error: 0.0592 - val_loss: 0.0331 - val_mse: 0.0047 - val_mae: 0.0331 - val_root_mean_squared_error: 0.0687
# Epoch 154/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0278 - mse: 0.0035 - mae: 0.0278 - root_mean_squared_error: 0.0592 - val_loss: 0.0331 - val_mse: 0.0047 - val_mae: 0.0331 - val_root_mean_squared_error: 0.0687
# Epoch 155/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0278 - mse: 0.0035 - mae: 0.0278 - root_mean_squared_error: 0.0592 - val_loss: 0.0331 - val_mse: 0.0047 - val_mae: 0.0331 - val_root_mean_squared_error: 0.0687
# Epoch 156/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0277 - mse: 0.0035 - mae: 0.0277 - root_mean_squared_error: 0.0592 - val_loss: 0.0331 - val_mse: 0.0047 - val_mae: 0.0331 - val_root_mean_squared_error: 0.0687
# Epoch 157/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0277 - mse: 0.0035 - mae: 0.0277 - root_mean_squared_error: 0.0592 - val_loss: 0.0330 - val_mse: 0.0047 - val_mae: 0.0330 - val_root_mean_squared_error: 0.0687
# Epoch 158/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0277 - mse: 0.0035 - mae: 0.0277 - root_mean_squared_error: 0.0592 - val_loss: 0.0330 - val_mse: 0.0047 - val_mae: 0.0330 - val_root_mean_squared_error: 0.0687
# Epoch 159/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0277 - mse: 0.0035 - mae: 0.0277 - root_mean_squared_error: 0.0592 - val_loss: 0.0330 - val_mse: 0.0047 - val_mae: 0.0330 - val_root_mean_squared_error: 0.0686
# Epoch 160/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0277 - mse: 0.0035 - mae: 0.0277 - root_mean_squared_error: 0.0592 - val_loss: 0.0330 - val_mse: 0.0047 - val_mae: 0.0330 - val_root_mean_squared_error: 0.0686
# Epoch 161/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0277 - mse: 0.0035 - mae: 0.0277 - root_mean_squared_error: 0.0592 - val_loss: 0.0330 - val_mse: 0.0047 - val_mae: 0.0330 - val_root_mean_squared_error: 0.0686
# Epoch 162/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0277 - mse: 0.0035 - mae: 0.0277 - root_mean_squared_error: 0.0592 - val_loss: 0.0329 - val_mse: 0.0047 - val_mae: 0.0329 - val_root_mean_squared_error: 0.0686
# Epoch 163/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0276 - mse: 0.0035 - mae: 0.0276 - root_mean_squared_error: 0.0592 - val_loss: 0.0329 - val_mse: 0.0047 - val_mae: 0.0329 - val_root_mean_squared_error: 0.0686
# Epoch 164/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0276 - mse: 0.0035 - mae: 0.0276 - root_mean_squared_error: 0.0592 - val_loss: 0.0329 - val_mse: 0.0047 - val_mae: 0.0329 - val_root_mean_squared_error: 0.0686
# Epoch 165/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0276 - mse: 0.0035 - mae: 0.0276 - root_mean_squared_error: 0.0592 - val_loss: 0.0329 - val_mse: 0.0047 - val_mae: 0.0329 - val_root_mean_squared_error: 0.0687
# Epoch 166/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0276 - mse: 0.0035 - mae: 0.0276 - root_mean_squared_error: 0.0592 - val_loss: 0.0329 - val_mse: 0.0047 - val_mae: 0.0329 - val_root_mean_squared_error: 0.0687
# Epoch 167/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0276 - mse: 0.0035 - mae: 0.0276 - root_mean_squared_error: 0.0592 - val_loss: 0.0328 - val_mse: 0.0047 - val_mae: 0.0328 - val_root_mean_squared_error: 0.0686
# Epoch 168/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0276 - mse: 0.0035 - mae: 0.0276 - root_mean_squared_error: 0.0592 - val_loss: 0.0328 - val_mse: 0.0047 - val_mae: 0.0328 - val_root_mean_squared_error: 0.0686
# Epoch 169/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0276 - mse: 0.0035 - mae: 0.0276 - root_mean_squared_error: 0.0592 - val_loss: 0.0328 - val_mse: 0.0047 - val_mae: 0.0328 - val_root_mean_squared_error: 0.0686
# Epoch 170/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0276 - mse: 0.0035 - mae: 0.0276 - root_mean_squared_error: 0.0592 - val_loss: 0.0328 - val_mse: 0.0047 - val_mae: 0.0328 - val_root_mean_squared_error: 0.0686
# Epoch 171/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0276 - mse: 0.0035 - mae: 0.0276 - root_mean_squared_error: 0.0592 - val_loss: 0.0328 - val_mse: 0.0047 - val_mae: 0.0328 - val_root_mean_squared_error: 0.0686
# Epoch 172/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0276 - mse: 0.0035 - mae: 0.0276 - root_mean_squared_error: 0.0592 - val_loss: 0.0327 - val_mse: 0.0047 - val_mae: 0.0327 - val_root_mean_squared_error: 0.0686
# Epoch 173/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0275 - mse: 0.0035 - mae: 0.0275 - root_mean_squared_error: 0.0592 - val_loss: 0.0327 - val_mse: 0.0047 - val_mae: 0.0327 - val_root_mean_squared_error: 0.0686
# Epoch 174/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0275 - mse: 0.0035 - mae: 0.0275 - root_mean_squared_error: 0.0592 - val_loss: 0.0327 - val_mse: 0.0047 - val_mae: 0.0327 - val_root_mean_squared_error: 0.0687
# Epoch 175/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0275 - mse: 0.0035 - mae: 0.0275 - root_mean_squared_error: 0.0591 - val_loss: 0.0327 - val_mse: 0.0047 - val_mae: 0.0327 - val_root_mean_squared_error: 0.0686
# Epoch 176/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0275 - mse: 0.0035 - mae: 0.0275 - root_mean_squared_error: 0.0591 - val_loss: 0.0327 - val_mse: 0.0047 - val_mae: 0.0327 - val_root_mean_squared_error: 0.0687
# Epoch 177/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0275 - mse: 0.0035 - mae: 0.0275 - root_mean_squared_error: 0.0591 - val_loss: 0.0327 - val_mse: 0.0047 - val_mae: 0.0327 - val_root_mean_squared_error: 0.0686
# Epoch 178/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0275 - mse: 0.0035 - mae: 0.0275 - root_mean_squared_error: 0.0591 - val_loss: 0.0326 - val_mse: 0.0047 - val_mae: 0.0326 - val_root_mean_squared_error: 0.0686
# Epoch 179/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0275 - mse: 0.0035 - mae: 0.0275 - root_mean_squared_error: 0.0591 - val_loss: 0.0326 - val_mse: 0.0047 - val_mae: 0.0326 - val_root_mean_squared_error: 0.0686
# Epoch 180/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0275 - mse: 0.0035 - mae: 0.0275 - root_mean_squared_error: 0.0591 - val_loss: 0.0326 - val_mse: 0.0047 - val_mae: 0.0326 - val_root_mean_squared_error: 0.0687
# Epoch 181/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0275 - mse: 0.0035 - mae: 0.0275 - root_mean_squared_error: 0.0591 - val_loss: 0.0326 - val_mse: 0.0047 - val_mae: 0.0326 - val_root_mean_squared_error: 0.0686
# Epoch 182/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0275 - mse: 0.0035 - mae: 0.0275 - root_mean_squared_error: 0.0591 - val_loss: 0.0326 - val_mse: 0.0047 - val_mae: 0.0326 - val_root_mean_squared_error: 0.0686
# Epoch 183/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0274 - mse: 0.0035 - mae: 0.0274 - root_mean_squared_error: 0.0591 - val_loss: 0.0326 - val_mse: 0.0047 - val_mae: 0.0326 - val_root_mean_squared_error: 0.0686
# Epoch 184/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0274 - mse: 0.0035 - mae: 0.0274 - root_mean_squared_error: 0.0591 - val_loss: 0.0325 - val_mse: 0.0047 - val_mae: 0.0325 - val_root_mean_squared_error: 0.0686
# Epoch 185/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0274 - mse: 0.0035 - mae: 0.0274 - root_mean_squared_error: 0.0591 - val_loss: 0.0325 - val_mse: 0.0047 - val_mae: 0.0325 - val_root_mean_squared_error: 0.0686
# Epoch 186/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0274 - mse: 0.0035 - mae: 0.0274 - root_mean_squared_error: 0.0591 - val_loss: 0.0325 - val_mse: 0.0047 - val_mae: 0.0325 - val_root_mean_squared_error: 0.0686
# Epoch 187/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0274 - mse: 0.0035 - mae: 0.0274 - root_mean_squared_error: 0.0591 - val_loss: 0.0325 - val_mse: 0.0047 - val_mae: 0.0325 - val_root_mean_squared_error: 0.0686
# Epoch 188/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0274 - mse: 0.0035 - mae: 0.0274 - root_mean_squared_error: 0.0591 - val_loss: 0.0325 - val_mse: 0.0047 - val_mae: 0.0325 - val_root_mean_squared_error: 0.0686
# Epoch 189/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0274 - mse: 0.0035 - mae: 0.0274 - root_mean_squared_error: 0.0591 - val_loss: 0.0325 - val_mse: 0.0047 - val_mae: 0.0325 - val_root_mean_squared_error: 0.0686
# Epoch 190/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0274 - mse: 0.0035 - mae: 0.0274 - root_mean_squared_error: 0.0590 - val_loss: 0.0325 - val_mse: 0.0047 - val_mae: 0.0325 - val_root_mean_squared_error: 0.0686
# Epoch 191/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0274 - mse: 0.0035 - mae: 0.0274 - root_mean_squared_error: 0.0590 - val_loss: 0.0325 - val_mse: 0.0047 - val_mae: 0.0325 - val_root_mean_squared_error: 0.0685
# Epoch 192/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0273 - mse: 0.0035 - mae: 0.0273 - root_mean_squared_error: 0.0590 - val_loss: 0.0325 - val_mse: 0.0047 - val_mae: 0.0325 - val_root_mean_squared_error: 0.0685
# Epoch 193/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0273 - mse: 0.0035 - mae: 0.0273 - root_mean_squared_error: 0.0590 - val_loss: 0.0325 - val_mse: 0.0047 - val_mae: 0.0325 - val_root_mean_squared_error: 0.0684
# Epoch 194/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0273 - mse: 0.0035 - mae: 0.0273 - root_mean_squared_error: 0.0591 - val_loss: 0.0325 - val_mse: 0.0047 - val_mae: 0.0325 - val_root_mean_squared_error: 0.0684
# Epoch 195/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0273 - mse: 0.0035 - mae: 0.0273 - root_mean_squared_error: 0.0590 - val_loss: 0.0325 - val_mse: 0.0047 - val_mae: 0.0325 - val_root_mean_squared_error: 0.0683
# Epoch 196/500
# ...
# Epoch 437/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0263 - mse: 0.0034 - mae: 0.0263 - root_mean_squared_error: 0.0585 - val_loss: 0.0312 - val_mse: 0.0046 - val_mae: 0.0312 - val_root_mean_squared_error: 0.0677
# Epoch 438/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0263 - mse: 0.0034 - mae: 0.0263 - root_mean_squared_error: 0.0585 - val_loss: 0.0312 - val_mse: 0.0046 - val_mae: 0.0312 - val_root_mean_squared_error: 0.0676
# Epoch 439/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0263 - mse: 0.0034 - mae: 0.0263 - root_mean_squared_error: 0.0585 - val_loss: 0.0312 - val_mse: 0.0046 - val_mae: 0.0312 - val_root_mean_squared_error: 0.0677
# Epoch 440/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0263 - mse: 0.0034 - mae: 0.0263 - root_mean_squared_error: 0.0585 - val_loss: 0.0312 - val_mse: 0.0046 - val_mae: 0.0312 - val_root_mean_squared_error: 0.0677
# Epoch 441/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0263 - mse: 0.0034 - mae: 0.0263 - root_mean_squared_error: 0.0586 - val_loss: 0.0312 - val_mse: 0.0046 - val_mae: 0.0312 - val_root_mean_squared_error: 0.0676
# Epoch 442/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0263 - mse: 0.0034 - mae: 0.0263 - root_mean_squared_error: 0.0585 - val_loss: 0.0312 - val_mse: 0.0046 - val_mae: 0.0312 - val_root_mean_squared_error: 0.0676
# Epoch 443/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0263 - mse: 0.0034 - mae: 0.0263 - root_mean_squared_error: 0.0585 - val_loss: 0.0312 - val_mse: 0.0046 - val_mae: 0.0312 - val_root_mean_squared_error: 0.0677
# Epoch 444/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0263 - mse: 0.0034 - mae: 0.0263 - root_mean_squared_error: 0.0585 - val_loss: 0.0312 - val_mse: 0.0046 - val_mae: 0.0312 - val_root_mean_squared_error: 0.0677
# Epoch 445/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0263 - mse: 0.0034 - mae: 0.0263 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 446/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0263 - mse: 0.0034 - mae: 0.0263 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 447/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 448/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0263 - mse: 0.0034 - mae: 0.0263 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 449/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0263 - mse: 0.0034 - mae: 0.0263 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 450/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 451/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0263 - mse: 0.0034 - mae: 0.0263 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 452/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 453/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 454/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 455/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 456/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 457/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0263 - mse: 0.0034 - mae: 0.0263 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 458/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 459/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 460/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 461/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 462/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 463/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 464/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0272 - mse: 0.0037 - mae: 0.0272 - root_mean_squared_error: 0.061 - 0s 27us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 465/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 466/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 467/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 468/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0277 - mse: 0.0039 - mae: 0.0277 - root_mean_squared_error: 0.062 - 0s 29us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 469/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 470/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0677
# Epoch 471/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 472/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 473/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0677
# Epoch 474/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0677
# Epoch 475/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0677
# Epoch 476/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0311 - val_mse: 0.0046 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0677
# Epoch 477/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0677
# Epoch 478/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0677
# Epoch 479/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0277 - mse: 0.0039 - mae: 0.0277 - root_mean_squared_error: 0.062 - 0s 29us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0677
# Epoch 480/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0676
# Epoch 481/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0677
# Epoch 482/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0677
# Epoch 483/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0677
# Epoch 484/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0677
# Epoch 485/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0677
# Epoch 486/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0677
# Epoch 487/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0676
# Epoch 488/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0677
# Epoch 489/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0677
# Epoch 490/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0261 - mse: 0.0034 - mae: 0.0261 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0676
# Epoch 491/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0676
# Epoch 492/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0261 - mse: 0.0034 - mae: 0.0261 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0676
# Epoch 493/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0262 - mse: 0.0034 - mae: 0.0262 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0676
# Epoch 494/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0261 - mse: 0.0034 - mae: 0.0261 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0676
# Epoch 495/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0261 - mse: 0.0034 - mae: 0.0261 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0677
# Epoch 496/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0261 - mse: 0.0034 - mae: 0.0261 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0677
# Epoch 497/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0261 - mse: 0.0034 - mae: 0.0261 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0677
# Epoch 498/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0271 - mse: 0.0037 - mae: 0.0271 - root_mean_squared_error: 0.061 - 0s 26us/sample - loss: 0.0261 - mse: 0.0034 - mae: 0.0261 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0676
# Epoch 499/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0261 - mse: 0.0034 - mae: 0.0261 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0676
# Epoch 500/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0261 - mse: 0.0034 - mae: 0.0261 - root_mean_squared_error: 0.0585 - val_loss: 0.0310 - val_mse: 0.0046 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0677

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mae'],label='train mae')
pyplot.plot(history.history['val_mae'],label='val mae')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mse'],label='train mse')
pyplot.plot(history.history['val_mse'],label='val mse')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['root_mean_squared_error'],label='train rmse')
pyplot.plot(history.history['val_root_mean_squared_error'],label='val rmse')
pyplot.legend()
pyplot.show()
# Out:
# The testing MAE loss is: 0.028648669
# The testing MSE loss is: 0.004108594
# The testing RMSE loss is: 0.06409831

# %%
pyplot.plot(test_y[:,1],color='red', label='True Values')
pyplot.plot(out[:,1],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()

# %%
dataset_test=pd.read_excel('F:\MS thesis data/Hopper Crossing.xlsx')
dataset_test=dataset_test.drop(['Date/Time','Flowd'],axis=1)
dataset_test.dropna(inplace=True)

# %%
shape=np.shape(dataset_test)
print(shape)
pyplot.plot(dataset_test)
# Out:
# (26285, 3)
# [<matplotlib.lines.Line2D at 0x140cb6f13c8>,
#  <matplotlib.lines.Line2D at 0x140d3311488>,
#  <matplotlib.lines.Line2D at 0x140d33117c8>]

# %%
dataset_test
# Out:
#        Cumulative rainfall   Flow  Level
# 0                      0.0  0.093    1.50
# 1                      0.0  0.093    1.50
# 2                      0.0  0.093    1.50
# 3                      0.0  0.093    1.50
# 4                      0.0  0.093    1.50
# ...                    ...    ...     ...
# 26280                  0.2  0.080    1.49
# 26281                  0.2  0.080    1.49
# 26282                  0.2  0.080    1.49
# 26283                  0.2  0.080    1.49
# 26284                  0.2  0.080    1.49
#
# [26285 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset_test)))
# Out:
# The std of original data is Cumulative rainfall    2.451640
# Flow                   0.520832
# Level                  0.083204
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset_test=dataset_test.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset_test.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset_test[:,0]== maxi[0])
    ind2=np.argwhere(dataset_test[:,1]== maxi[1])
    ind3=np.argwhere(dataset_test[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset_test.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset_test[:,0]== mini[0])
    ind2=np.argwhere(dataset_test[:,1]== mini[1])
    ind3=np.argwhere(dataset_test[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset_test)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset_test = min_max_scaler.fit_transform(dataset_test)
# Out:
# The std of cleaned data is 1.5154548293543502

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=2
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values

#one hour
#test_X, test_y = values[:, :-out_hour], values[:,-1]


test_X, test_y = values[:, :-out_hour], values[:, -out_hour: ]


test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6344, 24)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  var2(t-3)  var3(t-3)  \
# 6    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 7    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 8    0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
# 9    0.215385   0.524545   0.776699   0.123077   0.549980   0.791262
# 10   0.123077   0.549980   0.791262   0.092308   0.603309   0.820388
#
#     var1(t-2)  var2(t-2)  var3(t-2)  var1(t-1)  var2(t-1)  var3(t-1)  \
# 6    0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
# 7    0.215385   0.524545   0.776699   0.123077   0.549980   0.791262
# 8    0.123077   0.549980   0.791262   0.092308   0.603309   0.820388
# 9    0.092308   0.603309   0.820388   0.092308   0.650485   0.844660
# 10   0.092308   0.650485   0.844660   0.092308   0.709285   0.873786
#
#      var3(t)  var3(t+1)
# 6   0.791262   0.820388
# 7   0.820388   0.844660
# 8   0.844660   0.873786
# 9   0.873786   0.898058
# 10  0.898058   0.932039

# %%
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
# Out:
# The testing MAE loss is: 0.027898626
# The testing MSE loss is: 0.0038825546
# The testing RMSE loss is: 0.062310148

# %%
pyplot.plot(test_y[:,1],color='red', label='True Values')
pyplot.plot(out[:,1],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()
