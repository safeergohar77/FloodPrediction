# %%
import pandas as pd
from pandas import concat
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from sklearn import preprocessing
from tensorflow.keras import backend as K
#from sklearn.preprocessing import MinMaxScaler
#from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input, Dense, LSTM,GRU,SimpleRNN, Activation
from matplotlib import pyplot
#from sklearn.model_selection import train_test_split

# %%
"# convert series to supervised learning\n" 
#windowing of data
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1),
    for i in range(n_in, 0, -1): #startes from n_in and decreses to 0 by decreasing each time -1
     cols.append(df.shift(i))
     names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
     cols.append(df.shift(-i))
     if i == 0:
       names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
     else:
       names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together\n",
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values\n",
    if dropnan:
      agg.dropna(inplace=True)
    return agg

# %%
#def root_mean_squared_error(y_true, y_pred):
 #       return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
dataset1=pd.read_excel('F:\MS thesis data/Brooklyn.xlsx')
dataset1=dataset1.drop(['Date/Time','Flowd'],axis=1)
dataset1.dropna(inplace=True)

# %%
shape=np.shape(dataset1)
print(shape)
pyplot.plot(dataset1)
# Out:
# (26302, 3)
# [<matplotlib.lines.Line2D at 0x23bf7400c48>,
#  <matplotlib.lines.Line2D at 0x23bf73fc048>,
#  <matplotlib.lines.Line2D at 0x23bf73fc188>]

# %%
dataset1
# Out:
#        Cumulative rainfall    Flow  Level
# 0                       0.0  0.172   0.352
# 1                       0.0  0.180   0.356
# 2                       0.0  0.180   0.356
# 3                       0.0  0.189   0.360
# 4                       0.0  0.189   0.360
# ...                     ...    ...     ...
# 26297                   0.0  0.025   0.232
# 26298                   0.0  0.023   0.228
# 26299                   0.0  0.023   0.228
# 26300                   0.0  0.023   0.228
# 26301                   0.0  0.023   0.228
#
# [26302 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset1)))
# Out:
# The std of original data is Cumulative rainfall     2.872616
# Flow                    1.306642
# Level                   0.147238
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset=dataset1.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset[:,0]== maxi[0])
    ind2=np.argwhere(dataset[:,1]== maxi[1])
    ind3=np.argwhere(dataset[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset[:,0]== mini[0])
    ind2=np.argwhere(dataset[:,1]== mini[1])
    ind3=np.argwhere(dataset[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset = min_max_scaler.fit_transform(dataset)
# Out:
# The std of cleaned data is 1.626639593959813

# %%
pyplot.plot(dataset)
# Out:
# [<matplotlib.lines.Line2D at 0x23bf6c78588>,
#  <matplotlib.lines.Line2D at 0x23bf6c42548>,
#  <matplotlib.lines.Line2D at 0x23bf6c42708>]

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=3
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values
train_size  = int(len(dataset) * 0.50)
val_size=int(len(dataset) * 0.75)
train_X, train_y = values[0:train_size, :-out_hour], values[0:train_size,-out_hour: ]
val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-out_hour: ]
test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-out_hour:]
#for last hour
#train_X, train_y = values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]  #for only last hour
#val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]
#test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-1]
print(train_X, train_y)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6343, 27)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var3(t-3)  var1(t-2)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.762136   0.230769
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.776699   0.215385
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.776699   0.123077
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.791262   0.092308
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.820388   0.092308
#
#     var2(t-2)  var3(t-2)  var1(t-1)  var2(t-1)  var3(t-1)   var3(t)  \
# 6    0.524545   0.776699   0.215385   0.524545   0.776699  0.791262
# 7    0.524545   0.776699   0.123077   0.549980   0.791262  0.820388
# 8    0.549980   0.791262   0.092308   0.603309   0.820388  0.844660
# 9    0.603309   0.820388   0.092308   0.650485   0.844660  0.873786
# 10   0.650485   0.844660   0.092308   0.709285   0.873786  0.898058
#
#     var3(t+1)  var3(t+2)
# 6    0.820388   0.844660
# 7    0.844660   0.873786
# 8    0.873786   0.898058
# 9    0.898058   0.932039
# 10   0.932039   0.966019
#
# [5 rows x 21 columns]
# [[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]
#  [0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]
#  [0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]
#  ...
#  [0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]
#  [0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]
#  [0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]] [[0.79126215 0.8203884  0.8446602 ]
#  [0.8203884  0.8446602  0.8737864 ]
#  [0.8446602  0.8737864  0.89805824]
#  ...
#  [0.23786408 0.24271844 0.24757281]
#  [0.24271844 0.24757281 0.24757281]
#  [0.24757281 0.24757281 0.24757281]]

# %%
print(train_X, train_y)
# Out:
# [[[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]]
#
#  [[0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]]
#
#  [[0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]]
#
#  ...
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]]] [[0.79126215 0.8203884  0.8446602 ]
#  [0.8203884  0.8446602  0.8737864 ]
#  [0.8446602  0.8737864  0.89805824]
#  ...
#  [0.23786408 0.24271844 0.24757281]
#  [0.24271844 0.24757281 0.24757281]
#  [0.24757281 0.24757281 0.24757281]]

# %%
print(train_X.shape, train_y.shape, val_X.shape, val_y.shape)
# Out:
# (3175, 1, 18) (3175, 3) (1588, 1, 18) (1588, 3)

# %%
randomState = 46
np.random.seed(randomState)
#tensorflow.random.set_random_seed(randomState)
tensorflow.random.set_seed(randomState)
model = Sequential()
model.add(GRU(15,input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dense(22))
#model.add(Activation('relu'))    
model.add(Dense(out_hour,activation = "sigmoid"))
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.001)
#    opt=tensorflow.keras.optimizers.Adam(learning_rate=0.00075)
model.compile(loss='mae', optimizer=opt,metrics=['mse','mae',tensorflow.keras.metrics.RootMeanSquaredError()])
history = model.fit(train_X, train_y,validation_data=(val_X, val_y), epochs=500, batch_size=100,verbose=1,shuffle=False)
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)
# Out:
# Train on 3175 samples, validate on 1588 samples
# Epoch 1/500
# 3175/3175 [==============================] - 3s 789us/sample - loss: 0.2432 - mse: 0.0717 - mae: 0.2432 - root_mean_squared_error: 0.2678 - val_loss: 0.2516 - val_mse: 0.0789 - val_mae: 0.2516 - val_root_mean_squared_error: 0.2809
# Epoch 2/500
# 3175/3175 [==============================] - 0s 59us/sample - loss: 0.2161 - mse: 0.0588 - mae: 0.2161 - root_mean_squared_error: 0.2425 - val_loss: 0.2257 - val_mse: 0.0652 - val_mae: 0.2257 - val_root_mean_squared_error: 0.2554
# Epoch 3/500
# 3175/3175 [==============================] - 0s 58us/sample - loss: 0.1928 - mse: 0.0497 - mae: 0.1928 - root_mean_squared_error: 0.2229 - val_loss: 0.2028 - val_mse: 0.0548 - val_mae: 0.2028 - val_root_mean_squared_error: 0.2341
# Epoch 4/500
# 3175/3175 [==============================] - 0s 57us/sample - loss: 0.1741 - mse: 0.0436 - mae: 0.1741 - root_mean_squared_error: 0.2088 - val_loss: 0.1848 - val_mse: 0.0473 - val_mae: 0.1848 - val_root_mean_squared_error: 0.2174
# Epoch 5/500
# 3175/3175 [==============================] - 0s 53us/sample - loss: 0.1596 - mse: 0.0391 - mae: 0.1596 - root_mean_squared_error: 0.1976 - val_loss: 0.1702 - val_mse: 0.0413 - val_mae: 0.1702 - val_root_mean_squared_error: 0.2032
# Epoch 6/500
# 3175/3175 [==============================] - 0s 58us/sample - loss: 0.1472 - mse: 0.0347 - mae: 0.1472 - root_mean_squared_error: 0.1864 - val_loss: 0.1571 - val_mse: 0.0360 - val_mae: 0.1571 - val_root_mean_squared_error: 0.1897
# Epoch 7/500
# 3175/3175 [==============================] - 0s 59us/sample - loss: 0.1354 - mse: 0.0303 - mae: 0.1354 - root_mean_squared_error: 0.1741 - val_loss: 0.1446 - val_mse: 0.0310 - val_mae: 0.1446 - val_root_mean_squared_error: 0.1761
# Epoch 8/500
# 3175/3175 [==============================] - 0s 60us/sample - loss: 0.1239 - mse: 0.0259 - mae: 0.1239 - root_mean_squared_error: 0.1610 - val_loss: 0.1326 - val_mse: 0.0265 - val_mae: 0.1326 - val_root_mean_squared_error: 0.1626
# Epoch 9/500
# 3175/3175 [==============================] - 0s 56us/sample - loss: 0.1129 - mse: 0.0218 - mae: 0.1129 - root_mean_squared_error: 0.1477 - val_loss: 0.1210 - val_mse: 0.0224 - val_mae: 0.1210 - val_root_mean_squared_error: 0.1497
# Epoch 10/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.1025 - mse: 0.0181 - mae: 0.1025 - root_mean_squared_error: 0.1346 - val_loss: 0.1102 - val_mse: 0.0190 - val_mae: 0.1102 - val_root_mean_squared_error: 0.1378
# Epoch 11/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0933 - mse: 0.0152 - mae: 0.0933 - root_mean_squared_error: 0.1232 - val_loss: 0.1009 - val_mse: 0.0164 - val_mae: 0.1009 - val_root_mean_squared_error: 0.1279
# Epoch 12/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0854 - mse: 0.0130 - mae: 0.0854 - root_mean_squared_error: 0.1138 - val_loss: 0.0934 - val_mse: 0.0144 - val_mae: 0.0934 - val_root_mean_squared_error: 0.1200
# Epoch 13/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0789 - mse: 0.0115 - mae: 0.0789 - root_mean_squared_error: 0.1070 - val_loss: 0.0872 - val_mse: 0.0130 - val_mae: 0.0872 - val_root_mean_squared_error: 0.1140
# Epoch 14/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0734 - mse: 0.0104 - mae: 0.0734 - root_mean_squared_error: 0.1021 - val_loss: 0.0821 - val_mse: 0.0120 - val_mae: 0.0821 - val_root_mean_squared_error: 0.1094
# Epoch 15/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0689 - mse: 0.0097 - mae: 0.0689 - root_mean_squared_error: 0.0986 - val_loss: 0.0779 - val_mse: 0.0113 - val_mae: 0.0779 - val_root_mean_squared_error: 0.1062
# Epoch 16/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0651 - mse: 0.0093 - mae: 0.0651 - root_mean_squared_error: 0.0962 - val_loss: 0.0743 - val_mse: 0.0107 - val_mae: 0.0743 - val_root_mean_squared_error: 0.1035
# Epoch 17/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0619 - mse: 0.0089 - mae: 0.0619 - root_mean_squared_error: 0.0943 - val_loss: 0.0712 - val_mse: 0.0103 - val_mae: 0.0712 - val_root_mean_squared_error: 0.1016
# Epoch 18/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0593 - mse: 0.0086 - mae: 0.0593 - root_mean_squared_error: 0.0929 - val_loss: 0.0686 - val_mse: 0.0100 - val_mae: 0.0686 - val_root_mean_squared_error: 0.0998
# Epoch 19/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0573 - mse: 0.0084 - mae: 0.0573 - root_mean_squared_error: 0.0915 - val_loss: 0.0664 - val_mse: 0.0097 - val_mae: 0.0664 - val_root_mean_squared_error: 0.0983
# Epoch 20/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0557 - mse: 0.0081 - mae: 0.0557 - root_mean_squared_error: 0.0901 - val_loss: 0.0646 - val_mse: 0.0094 - val_mae: 0.0646 - val_root_mean_squared_error: 0.0969
# Epoch 21/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0544 - mse: 0.0079 - mae: 0.0544 - root_mean_squared_error: 0.0886 - val_loss: 0.0631 - val_mse: 0.0091 - val_mae: 0.0631 - val_root_mean_squared_error: 0.0956
# Epoch 22/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0531 - mse: 0.0076 - mae: 0.0531 - root_mean_squared_error: 0.0873 - val_loss: 0.0616 - val_mse: 0.0089 - val_mae: 0.0616 - val_root_mean_squared_error: 0.0943
# Epoch 23/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0520 - mse: 0.0074 - mae: 0.0520 - root_mean_squared_error: 0.0859 - val_loss: 0.0604 - val_mse: 0.0087 - val_mae: 0.0604 - val_root_mean_squared_error: 0.0932
# Epoch 24/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0509 - mse: 0.0072 - mae: 0.0509 - root_mean_squared_error: 0.0847 - val_loss: 0.0593 - val_mse: 0.0085 - val_mae: 0.0593 - val_root_mean_squared_error: 0.0922
# Epoch 25/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0500 - mse: 0.0070 - mae: 0.0500 - root_mean_squared_error: 0.0836 - val_loss: 0.0583 - val_mse: 0.0083 - val_mae: 0.0583 - val_root_mean_squared_error: 0.0913
# Epoch 26/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0492 - mse: 0.0068 - mae: 0.0492 - root_mean_squared_error: 0.0825 - val_loss: 0.0574 - val_mse: 0.0082 - val_mae: 0.0574 - val_root_mean_squared_error: 0.0905
# Epoch 27/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0484 - mse: 0.0066 - mae: 0.0484 - root_mean_squared_error: 0.0815 - val_loss: 0.0566 - val_mse: 0.0080 - val_mae: 0.0566 - val_root_mean_squared_error: 0.0897
# Epoch 28/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0478 - mse: 0.0065 - mae: 0.0478 - root_mean_squared_error: 0.0806 - val_loss: 0.0559 - val_mse: 0.0079 - val_mae: 0.0559 - val_root_mean_squared_error: 0.0890
# Epoch 29/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0471 - mse: 0.0064 - mae: 0.0471 - root_mean_squared_error: 0.0798 - val_loss: 0.0553 - val_mse: 0.0078 - val_mae: 0.0553 - val_root_mean_squared_error: 0.0883
# Epoch 30/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0466 - mse: 0.0063 - mae: 0.0466 - root_mean_squared_error: 0.0791 - val_loss: 0.0548 - val_mse: 0.0077 - val_mae: 0.0548 - val_root_mean_squared_error: 0.0878
# Epoch 31/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0460 - mse: 0.0062 - mae: 0.0460 - root_mean_squared_error: 0.0784 - val_loss: 0.0543 - val_mse: 0.0076 - val_mae: 0.0543 - val_root_mean_squared_error: 0.0873
# Epoch 32/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0456 - mse: 0.0061 - mae: 0.0456 - root_mean_squared_error: 0.0778 - val_loss: 0.0538 - val_mse: 0.0075 - val_mae: 0.0538 - val_root_mean_squared_error: 0.0868
# Epoch 33/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0452 - mse: 0.0060 - mae: 0.0452 - root_mean_squared_error: 0.0772 - val_loss: 0.0534 - val_mse: 0.0075 - val_mae: 0.0534 - val_root_mean_squared_error: 0.0863
# Epoch 34/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0447 - mse: 0.0059 - mae: 0.0447 - root_mean_squared_error: 0.0767 - val_loss: 0.0530 - val_mse: 0.0074 - val_mae: 0.0530 - val_root_mean_squared_error: 0.0859
# Epoch 35/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0444 - mse: 0.0058 - mae: 0.0444 - root_mean_squared_error: 0.0761 - val_loss: 0.0527 - val_mse: 0.0073 - val_mae: 0.0527 - val_root_mean_squared_error: 0.0856
# Epoch 36/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0440 - mse: 0.0057 - mae: 0.0440 - root_mean_squared_error: 0.0757 - val_loss: 0.0524 - val_mse: 0.0073 - val_mae: 0.0524 - val_root_mean_squared_error: 0.0853
# Epoch 37/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0437 - mse: 0.0057 - mae: 0.0437 - root_mean_squared_error: 0.0753 - val_loss: 0.0521 - val_mse: 0.0072 - val_mae: 0.0521 - val_root_mean_squared_error: 0.0850
# Epoch 38/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0434 - mse: 0.0056 - mae: 0.0434 - root_mean_squared_error: 0.0749 - val_loss: 0.0519 - val_mse: 0.0072 - val_mae: 0.0519 - val_root_mean_squared_error: 0.0848
# Epoch 39/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0432 - mse: 0.0056 - mae: 0.0432 - root_mean_squared_error: 0.0746 - val_loss: 0.0516 - val_mse: 0.0071 - val_mae: 0.0516 - val_root_mean_squared_error: 0.0845
# Epoch 40/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0429 - mse: 0.0055 - mae: 0.0429 - root_mean_squared_error: 0.0743 - val_loss: 0.0514 - val_mse: 0.0071 - val_mae: 0.0514 - val_root_mean_squared_error: 0.0843
# Epoch 41/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0427 - mse: 0.0055 - mae: 0.0427 - root_mean_squared_error: 0.0740 - val_loss: 0.0512 - val_mse: 0.0071 - val_mae: 0.0512 - val_root_mean_squared_error: 0.0841
# Epoch 42/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0424 - mse: 0.0054 - mae: 0.0424 - root_mean_squared_error: 0.0738 - val_loss: 0.0510 - val_mse: 0.0070 - val_mae: 0.0510 - val_root_mean_squared_error: 0.0839
# Epoch 43/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0422 - mse: 0.0054 - mae: 0.0422 - root_mean_squared_error: 0.0736 - val_loss: 0.0508 - val_mse: 0.0070 - val_mae: 0.0508 - val_root_mean_squared_error: 0.0837
# Epoch 44/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0420 - mse: 0.0054 - mae: 0.0420 - root_mean_squared_error: 0.0734 - val_loss: 0.0506 - val_mse: 0.0070 - val_mae: 0.0506 - val_root_mean_squared_error: 0.0836
# Epoch 45/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0418 - mse: 0.0054 - mae: 0.0418 - root_mean_squared_error: 0.0732 - val_loss: 0.0504 - val_mse: 0.0070 - val_mae: 0.0504 - val_root_mean_squared_error: 0.0834
# Epoch 46/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0417 - mse: 0.0053 - mae: 0.0417 - root_mean_squared_error: 0.0730 - val_loss: 0.0503 - val_mse: 0.0069 - val_mae: 0.0503 - val_root_mean_squared_error: 0.0833
# Epoch 47/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0415 - mse: 0.0053 - mae: 0.0415 - root_mean_squared_error: 0.0728 - val_loss: 0.0501 - val_mse: 0.0069 - val_mae: 0.0501 - val_root_mean_squared_error: 0.0831
# Epoch 48/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0413 - mse: 0.0053 - mae: 0.0413 - root_mean_squared_error: 0.0726 - val_loss: 0.0499 - val_mse: 0.0069 - val_mae: 0.0499 - val_root_mean_squared_error: 0.0830
# Epoch 49/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0431 - mse: 0.0058 - mae: 0.0431 - root_mean_squared_error: 0.076 - 0s 28us/sample - loss: 0.0412 - mse: 0.0053 - mae: 0.0412 - root_mean_squared_error: 0.0725 - val_loss: 0.0498 - val_mse: 0.0069 - val_mae: 0.0498 - val_root_mean_squared_error: 0.0829
# Epoch 50/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0410 - mse: 0.0052 - mae: 0.0410 - root_mean_squared_error: 0.0723 - val_loss: 0.0496 - val_mse: 0.0069 - val_mae: 0.0496 - val_root_mean_squared_error: 0.0828
# Epoch 51/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0409 - mse: 0.0052 - mae: 0.0409 - root_mean_squared_error: 0.0722 - val_loss: 0.0495 - val_mse: 0.0068 - val_mae: 0.0495 - val_root_mean_squared_error: 0.0827
# Epoch 52/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0407 - mse: 0.0052 - mae: 0.0407 - root_mean_squared_error: 0.0721 - val_loss: 0.0493 - val_mse: 0.0068 - val_mae: 0.0493 - val_root_mean_squared_error: 0.0825
# Epoch 53/500
# 3175/3175 [==============================] - 0s 40us/sample - loss: 0.0406 - mse: 0.0052 - mae: 0.0406 - root_mean_squared_error: 0.0719 - val_loss: 0.0491 - val_mse: 0.0068 - val_mae: 0.0491 - val_root_mean_squared_error: 0.0823
# Epoch 54/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0404 - mse: 0.0052 - mae: 0.0404 - root_mean_squared_error: 0.0718 - val_loss: 0.0490 - val_mse: 0.0068 - val_mae: 0.0490 - val_root_mean_squared_error: 0.0822
# Epoch 55/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0403 - mse: 0.0051 - mae: 0.0403 - root_mean_squared_error: 0.0717 - val_loss: 0.0488 - val_mse: 0.0067 - val_mae: 0.0488 - val_root_mean_squared_error: 0.0821
# Epoch 56/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0402 - mse: 0.0051 - mae: 0.0402 - root_mean_squared_error: 0.0716 - val_loss: 0.0486 - val_mse: 0.0067 - val_mae: 0.0486 - val_root_mean_squared_error: 0.0820
# Epoch 57/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0400 - mse: 0.0051 - mae: 0.0400 - root_mean_squared_error: 0.0715 - val_loss: 0.0485 - val_mse: 0.0067 - val_mae: 0.0485 - val_root_mean_squared_error: 0.0819
# Epoch 58/500
# 3175/3175 [==============================] - 0s 40us/sample - loss: 0.0399 - mse: 0.0051 - mae: 0.0399 - root_mean_squared_error: 0.0714 - val_loss: 0.0483 - val_mse: 0.0067 - val_mae: 0.0483 - val_root_mean_squared_error: 0.0818
# Epoch 59/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0397 - mse: 0.0051 - mae: 0.0397 - root_mean_squared_error: 0.0713 - val_loss: 0.0482 - val_mse: 0.0067 - val_mae: 0.0482 - val_root_mean_squared_error: 0.0816
# Epoch 60/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0396 - mse: 0.0051 - mae: 0.0396 - root_mean_squared_error: 0.0712 - val_loss: 0.0480 - val_mse: 0.0066 - val_mae: 0.0480 - val_root_mean_squared_error: 0.0814
# Epoch 61/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0420 - mse: 0.0057 - mae: 0.0420 - root_mean_squared_error: 0.075 - 0s 29us/sample - loss: 0.0395 - mse: 0.0050 - mae: 0.0395 - root_mean_squared_error: 0.0711 - val_loss: 0.0478 - val_mse: 0.0066 - val_mae: 0.0478 - val_root_mean_squared_error: 0.0813
# Epoch 62/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0393 - mse: 0.0050 - mae: 0.0393 - root_mean_squared_error: 0.0709 - val_loss: 0.0477 - val_mse: 0.0066 - val_mae: 0.0477 - val_root_mean_squared_error: 0.0812
# Epoch 63/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0392 - mse: 0.0050 - mae: 0.0392 - root_mean_squared_error: 0.0708 - val_loss: 0.0475 - val_mse: 0.0066 - val_mae: 0.0475 - val_root_mean_squared_error: 0.0811
# Epoch 64/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0391 - mse: 0.0050 - mae: 0.0391 - root_mean_squared_error: 0.0708 - val_loss: 0.0474 - val_mse: 0.0066 - val_mae: 0.0474 - val_root_mean_squared_error: 0.0810
# Epoch 65/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0389 - mse: 0.0050 - mae: 0.0389 - root_mean_squared_error: 0.0707 - val_loss: 0.0472 - val_mse: 0.0065 - val_mae: 0.0472 - val_root_mean_squared_error: 0.0809
# Epoch 66/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0388 - mse: 0.0050 - mae: 0.0388 - root_mean_squared_error: 0.0706 - val_loss: 0.0471 - val_mse: 0.0065 - val_mae: 0.0471 - val_root_mean_squared_error: 0.0808
# Epoch 67/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0414 - mse: 0.0058 - mae: 0.0414 - root_mean_squared_error: 0.076 - 0s 31us/sample - loss: 0.0387 - mse: 0.0050 - mae: 0.0387 - root_mean_squared_error: 0.0706 - val_loss: 0.0469 - val_mse: 0.0065 - val_mae: 0.0469 - val_root_mean_squared_error: 0.0806
# Epoch 68/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0386 - mse: 0.0050 - mae: 0.0386 - root_mean_squared_error: 0.0705 - val_loss: 0.0468 - val_mse: 0.0065 - val_mae: 0.0468 - val_root_mean_squared_error: 0.0805
# Epoch 69/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0384 - mse: 0.0050 - mae: 0.0384 - root_mean_squared_error: 0.0704 - val_loss: 0.0467 - val_mse: 0.0065 - val_mae: 0.0467 - val_root_mean_squared_error: 0.0805
# Epoch 70/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0383 - mse: 0.0049 - mae: 0.0383 - root_mean_squared_error: 0.0703 - val_loss: 0.0465 - val_mse: 0.0065 - val_mae: 0.0465 - val_root_mean_squared_error: 0.0804
# Epoch 71/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0382 - mse: 0.0049 - mae: 0.0382 - root_mean_squared_error: 0.0703 - val_loss: 0.0464 - val_mse: 0.0064 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0802
# Epoch 72/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0396 - mse: 0.0054 - mae: 0.0396 - root_mean_squared_error: 0.073 - 0s 29us/sample - loss: 0.0381 - mse: 0.0049 - mae: 0.0381 - root_mean_squared_error: 0.0702 - val_loss: 0.0462 - val_mse: 0.0064 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0801
# Epoch 73/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0380 - mse: 0.0049 - mae: 0.0380 - root_mean_squared_error: 0.0701 - val_loss: 0.0461 - val_mse: 0.0064 - val_mae: 0.0461 - val_root_mean_squared_error: 0.0800
# Epoch 74/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0378 - mse: 0.0049 - mae: 0.0378 - root_mean_squared_error: 0.0701 - val_loss: 0.0460 - val_mse: 0.0064 - val_mae: 0.0460 - val_root_mean_squared_error: 0.0800
# Epoch 75/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0377 - mse: 0.0049 - mae: 0.0377 - root_mean_squared_error: 0.0700 - val_loss: 0.0459 - val_mse: 0.0064 - val_mae: 0.0459 - val_root_mean_squared_error: 0.0799
# Epoch 76/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0376 - mse: 0.0049 - mae: 0.0376 - root_mean_squared_error: 0.0699 - val_loss: 0.0457 - val_mse: 0.0064 - val_mae: 0.0457 - val_root_mean_squared_error: 0.0798
# Epoch 77/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0375 - mse: 0.0049 - mae: 0.0375 - root_mean_squared_error: 0.0699 - val_loss: 0.0456 - val_mse: 0.0064 - val_mae: 0.0456 - val_root_mean_squared_error: 0.0798
# Epoch 78/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0374 - mse: 0.0049 - mae: 0.0374 - root_mean_squared_error: 0.0698 - val_loss: 0.0455 - val_mse: 0.0064 - val_mae: 0.0455 - val_root_mean_squared_error: 0.0797
# Epoch 79/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0373 - mse: 0.0049 - mae: 0.0373 - root_mean_squared_error: 0.0698 - val_loss: 0.0454 - val_mse: 0.0063 - val_mae: 0.0454 - val_root_mean_squared_error: 0.0796
# Epoch 80/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0372 - mse: 0.0049 - mae: 0.0372 - root_mean_squared_error: 0.0697 - val_loss: 0.0452 - val_mse: 0.0063 - val_mae: 0.0452 - val_root_mean_squared_error: 0.0795
# Epoch 81/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0371 - mse: 0.0048 - mae: 0.0371 - root_mean_squared_error: 0.0696 - val_loss: 0.0451 - val_mse: 0.0063 - val_mae: 0.0451 - val_root_mean_squared_error: 0.0795
# Epoch 82/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0370 - mse: 0.0048 - mae: 0.0370 - root_mean_squared_error: 0.0696 - val_loss: 0.0450 - val_mse: 0.0063 - val_mae: 0.0450 - val_root_mean_squared_error: 0.0794
# Epoch 83/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0369 - mse: 0.0048 - mae: 0.0369 - root_mean_squared_error: 0.0695 - val_loss: 0.0449 - val_mse: 0.0063 - val_mae: 0.0449 - val_root_mean_squared_error: 0.0794
# Epoch 84/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0368 - mse: 0.0048 - mae: 0.0368 - root_mean_squared_error: 0.0695 - val_loss: 0.0448 - val_mse: 0.0063 - val_mae: 0.0448 - val_root_mean_squared_error: 0.0793
# Epoch 85/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0367 - mse: 0.0048 - mae: 0.0367 - root_mean_squared_error: 0.0694 - val_loss: 0.0447 - val_mse: 0.0063 - val_mae: 0.0447 - val_root_mean_squared_error: 0.0792
# Epoch 86/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0367 - mse: 0.0048 - mae: 0.0367 - root_mean_squared_error: 0.0694 - val_loss: 0.0446 - val_mse: 0.0063 - val_mae: 0.0446 - val_root_mean_squared_error: 0.0792
# Epoch 87/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0366 - mse: 0.0048 - mae: 0.0366 - root_mean_squared_error: 0.0694 - val_loss: 0.0445 - val_mse: 0.0063 - val_mae: 0.0445 - val_root_mean_squared_error: 0.0792
# Epoch 88/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0365 - mse: 0.0048 - mae: 0.0365 - root_mean_squared_error: 0.0693 - val_loss: 0.0443 - val_mse: 0.0063 - val_mae: 0.0443 - val_root_mean_squared_error: 0.0791
# Epoch 89/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0364 - mse: 0.0048 - mae: 0.0364 - root_mean_squared_error: 0.0693 - val_loss: 0.0442 - val_mse: 0.0063 - val_mae: 0.0442 - val_root_mean_squared_error: 0.0791
# Epoch 90/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0363 - mse: 0.0048 - mae: 0.0363 - root_mean_squared_error: 0.0693 - val_loss: 0.0441 - val_mse: 0.0062 - val_mae: 0.0441 - val_root_mean_squared_error: 0.0790
# Epoch 91/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0362 - mse: 0.0048 - mae: 0.0362 - root_mean_squared_error: 0.0692 - val_loss: 0.0440 - val_mse: 0.0062 - val_mae: 0.0440 - val_root_mean_squared_error: 0.0790
# Epoch 92/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0361 - mse: 0.0048 - mae: 0.0361 - root_mean_squared_error: 0.0692 - val_loss: 0.0439 - val_mse: 0.0062 - val_mae: 0.0439 - val_root_mean_squared_error: 0.0790
# Epoch 93/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0361 - mse: 0.0048 - mae: 0.0361 - root_mean_squared_error: 0.0692 - val_loss: 0.0438 - val_mse: 0.0062 - val_mae: 0.0438 - val_root_mean_squared_error: 0.0789
# Epoch 94/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0360 - mse: 0.0048 - mae: 0.0360 - root_mean_squared_error: 0.0692 - val_loss: 0.0438 - val_mse: 0.0062 - val_mae: 0.0438 - val_root_mean_squared_error: 0.0789
# Epoch 95/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0359 - mse: 0.0048 - mae: 0.0359 - root_mean_squared_error: 0.0691 - val_loss: 0.0436 - val_mse: 0.0062 - val_mae: 0.0436 - val_root_mean_squared_error: 0.0788
# Epoch 96/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0358 - mse: 0.0048 - mae: 0.0358 - root_mean_squared_error: 0.0691 - val_loss: 0.0436 - val_mse: 0.0062 - val_mae: 0.0436 - val_root_mean_squared_error: 0.0788
# Epoch 97/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0358 - mse: 0.0048 - mae: 0.0358 - root_mean_squared_error: 0.0691 - val_loss: 0.0435 - val_mse: 0.0062 - val_mae: 0.0435 - val_root_mean_squared_error: 0.0788
# Epoch 98/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0357 - mse: 0.0048 - mae: 0.0357 - root_mean_squared_error: 0.0690 - val_loss: 0.0434 - val_mse: 0.0062 - val_mae: 0.0434 - val_root_mean_squared_error: 0.0788
# Epoch 99/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0356 - mse: 0.0048 - mae: 0.0356 - root_mean_squared_error: 0.0690 - val_loss: 0.0433 - val_mse: 0.0062 - val_mae: 0.0433 - val_root_mean_squared_error: 0.0787
# Epoch 100/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0356 - mse: 0.0048 - mae: 0.0356 - root_mean_squared_error: 0.0690 - val_loss: 0.0432 - val_mse: 0.0062 - val_mae: 0.0432 - val_root_mean_squared_error: 0.0787
# Epoch 101/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0355 - mse: 0.0048 - mae: 0.0355 - root_mean_squared_error: 0.0690 - val_loss: 0.0431 - val_mse: 0.0062 - val_mae: 0.0431 - val_root_mean_squared_error: 0.0787
# Epoch 102/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0354 - mse: 0.0048 - mae: 0.0354 - root_mean_squared_error: 0.0690 - val_loss: 0.0430 - val_mse: 0.0062 - val_mae: 0.0430 - val_root_mean_squared_error: 0.0787
# Epoch 103/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0354 - mse: 0.0048 - mae: 0.0354 - root_mean_squared_error: 0.0690 - val_loss: 0.0430 - val_mse: 0.0062 - val_mae: 0.0430 - val_root_mean_squared_error: 0.0787
# Epoch 104/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0353 - mse: 0.0048 - mae: 0.0353 - root_mean_squared_error: 0.0690 - val_loss: 0.0429 - val_mse: 0.0062 - val_mae: 0.0429 - val_root_mean_squared_error: 0.0786
# Epoch 105/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0352 - mse: 0.0048 - mae: 0.0352 - root_mean_squared_error: 0.0690 - val_loss: 0.0428 - val_mse: 0.0062 - val_mae: 0.0428 - val_root_mean_squared_error: 0.0786
# Epoch 106/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0352 - mse: 0.0048 - mae: 0.0352 - root_mean_squared_error: 0.0689 - val_loss: 0.0427 - val_mse: 0.0062 - val_mae: 0.0427 - val_root_mean_squared_error: 0.0786
# Epoch 107/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0351 - mse: 0.0047 - mae: 0.0351 - root_mean_squared_error: 0.0689 - val_loss: 0.0427 - val_mse: 0.0062 - val_mae: 0.0427 - val_root_mean_squared_error: 0.0786
# Epoch 108/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0351 - mse: 0.0047 - mae: 0.0351 - root_mean_squared_error: 0.0689 - val_loss: 0.0426 - val_mse: 0.0062 - val_mae: 0.0426 - val_root_mean_squared_error: 0.0785
# Epoch 109/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0350 - mse: 0.0047 - mae: 0.0350 - root_mean_squared_error: 0.0689 - val_loss: 0.0425 - val_mse: 0.0062 - val_mae: 0.0425 - val_root_mean_squared_error: 0.0785
# Epoch 110/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0350 - mse: 0.0047 - mae: 0.0350 - root_mean_squared_error: 0.0689 - val_loss: 0.0425 - val_mse: 0.0062 - val_mae: 0.0425 - val_root_mean_squared_error: 0.0785
# Epoch 111/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0349 - mse: 0.0047 - mae: 0.0349 - root_mean_squared_error: 0.0689 - val_loss: 0.0424 - val_mse: 0.0062 - val_mae: 0.0424 - val_root_mean_squared_error: 0.0784
# Epoch 112/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0349 - mse: 0.0047 - mae: 0.0349 - root_mean_squared_error: 0.0689 - val_loss: 0.0423 - val_mse: 0.0061 - val_mae: 0.0423 - val_root_mean_squared_error: 0.0784
# Epoch 113/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0348 - mse: 0.0047 - mae: 0.0348 - root_mean_squared_error: 0.0689 - val_loss: 0.0422 - val_mse: 0.0061 - val_mae: 0.0422 - val_root_mean_squared_error: 0.0784
# Epoch 114/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0348 - mse: 0.0047 - mae: 0.0348 - root_mean_squared_error: 0.0689 - val_loss: 0.0422 - val_mse: 0.0061 - val_mae: 0.0422 - val_root_mean_squared_error: 0.0784
# Epoch 115/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0347 - mse: 0.0047 - mae: 0.0347 - root_mean_squared_error: 0.0689 - val_loss: 0.0421 - val_mse: 0.0061 - val_mae: 0.0421 - val_root_mean_squared_error: 0.0783
# Epoch 116/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0347 - mse: 0.0047 - mae: 0.0347 - root_mean_squared_error: 0.0689 - val_loss: 0.0420 - val_mse: 0.0061 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0783
# Epoch 117/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0347 - mse: 0.0047 - mae: 0.0347 - root_mean_squared_error: 0.0689 - val_loss: 0.0420 - val_mse: 0.0061 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0783
# Epoch 118/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0346 - mse: 0.0047 - mae: 0.0346 - root_mean_squared_error: 0.0689 - val_loss: 0.0419 - val_mse: 0.0061 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0783
# Epoch 119/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0346 - mse: 0.0047 - mae: 0.0346 - root_mean_squared_error: 0.0688 - val_loss: 0.0418 - val_mse: 0.0061 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0783
# Epoch 120/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0345 - mse: 0.0047 - mae: 0.0345 - root_mean_squared_error: 0.0688 - val_loss: 0.0418 - val_mse: 0.0061 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0782
# Epoch 121/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0345 - mse: 0.0047 - mae: 0.0345 - root_mean_squared_error: 0.0689 - val_loss: 0.0417 - val_mse: 0.0061 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0782
# Epoch 122/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0345 - mse: 0.0047 - mae: 0.0345 - root_mean_squared_error: 0.0688 - val_loss: 0.0417 - val_mse: 0.0061 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0782
# Epoch 123/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0344 - mse: 0.0047 - mae: 0.0344 - root_mean_squared_error: 0.0689 - val_loss: 0.0416 - val_mse: 0.0061 - val_mae: 0.0416 - val_root_mean_squared_error: 0.0782
# Epoch 124/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0344 - mse: 0.0047 - mae: 0.0344 - root_mean_squared_error: 0.0688 - val_loss: 0.0416 - val_mse: 0.0061 - val_mae: 0.0416 - val_root_mean_squared_error: 0.0782
# Epoch 125/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0344 - mse: 0.0047 - mae: 0.0344 - root_mean_squared_error: 0.0688 - val_loss: 0.0415 - val_mse: 0.0061 - val_mae: 0.0415 - val_root_mean_squared_error: 0.0781
# Epoch 126/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0343 - mse: 0.0047 - mae: 0.0343 - root_mean_squared_error: 0.0688 - val_loss: 0.0414 - val_mse: 0.0061 - val_mae: 0.0414 - val_root_mean_squared_error: 0.0781
# Epoch 127/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0343 - mse: 0.0047 - mae: 0.0343 - root_mean_squared_error: 0.0688 - val_loss: 0.0414 - val_mse: 0.0061 - val_mae: 0.0414 - val_root_mean_squared_error: 0.0781
# Epoch 128/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0343 - mse: 0.0047 - mae: 0.0343 - root_mean_squared_error: 0.0688 - val_loss: 0.0413 - val_mse: 0.0061 - val_mae: 0.0413 - val_root_mean_squared_error: 0.0781
# Epoch 129/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0343 - mse: 0.0047 - mae: 0.0343 - root_mean_squared_error: 0.0688 - val_loss: 0.0413 - val_mse: 0.0061 - val_mae: 0.0413 - val_root_mean_squared_error: 0.0781
# Epoch 130/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0342 - mse: 0.0047 - mae: 0.0342 - root_mean_squared_error: 0.0688 - val_loss: 0.0412 - val_mse: 0.0061 - val_mae: 0.0412 - val_root_mean_squared_error: 0.0781
# Epoch 131/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0342 - mse: 0.0047 - mae: 0.0342 - root_mean_squared_error: 0.0688 - val_loss: 0.0412 - val_mse: 0.0061 - val_mae: 0.0412 - val_root_mean_squared_error: 0.0781
# Epoch 132/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0342 - mse: 0.0047 - mae: 0.0342 - root_mean_squared_error: 0.0688 - val_loss: 0.0411 - val_mse: 0.0061 - val_mae: 0.0411 - val_root_mean_squared_error: 0.0780
# Epoch 133/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0341 - mse: 0.0047 - mae: 0.0341 - root_mean_squared_error: 0.0688 - val_loss: 0.0411 - val_mse: 0.0061 - val_mae: 0.0411 - val_root_mean_squared_error: 0.0780
# Epoch 134/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0341 - mse: 0.0047 - mae: 0.0341 - root_mean_squared_error: 0.0688 - val_loss: 0.0410 - val_mse: 0.0061 - val_mae: 0.0410 - val_root_mean_squared_error: 0.0780
# Epoch 135/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0341 - mse: 0.0047 - mae: 0.0341 - root_mean_squared_error: 0.0688 - val_loss: 0.0410 - val_mse: 0.0061 - val_mae: 0.0410 - val_root_mean_squared_error: 0.0779
# Epoch 136/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0341 - mse: 0.0047 - mae: 0.0341 - root_mean_squared_error: 0.0688 - val_loss: 0.0409 - val_mse: 0.0061 - val_mae: 0.0409 - val_root_mean_squared_error: 0.0780
# Epoch 137/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0341 - mse: 0.0047 - mae: 0.0341 - root_mean_squared_error: 0.0688 - val_loss: 0.0409 - val_mse: 0.0061 - val_mae: 0.0409 - val_root_mean_squared_error: 0.0780
# Epoch 138/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0340 - mse: 0.0047 - mae: 0.0340 - root_mean_squared_error: 0.0688 - val_loss: 0.0409 - val_mse: 0.0061 - val_mae: 0.0409 - val_root_mean_squared_error: 0.0779
# Epoch 139/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0340 - mse: 0.0047 - mae: 0.0340 - root_mean_squared_error: 0.0688 - val_loss: 0.0408 - val_mse: 0.0061 - val_mae: 0.0408 - val_root_mean_squared_error: 0.0779
# Epoch 140/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0340 - mse: 0.0047 - mae: 0.0340 - root_mean_squared_error: 0.0687 - val_loss: 0.0408 - val_mse: 0.0061 - val_mae: 0.0408 - val_root_mean_squared_error: 0.0779
# Epoch 141/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0340 - mse: 0.0047 - mae: 0.0340 - root_mean_squared_error: 0.0688 - val_loss: 0.0407 - val_mse: 0.0061 - val_mae: 0.0407 - val_root_mean_squared_error: 0.0778
# Epoch 142/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0339 - mse: 0.0047 - mae: 0.0339 - root_mean_squared_error: 0.0687 - val_loss: 0.0407 - val_mse: 0.0061 - val_mae: 0.0407 - val_root_mean_squared_error: 0.0778
# Epoch 143/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0339 - mse: 0.0047 - mae: 0.0339 - root_mean_squared_error: 0.0687 - val_loss: 0.0407 - val_mse: 0.0061 - val_mae: 0.0407 - val_root_mean_squared_error: 0.0779
# Epoch 144/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0339 - mse: 0.0047 - mae: 0.0339 - root_mean_squared_error: 0.0687 - val_loss: 0.0406 - val_mse: 0.0061 - val_mae: 0.0406 - val_root_mean_squared_error: 0.0778
# Epoch 145/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0339 - mse: 0.0047 - mae: 0.0339 - root_mean_squared_error: 0.0687 - val_loss: 0.0406 - val_mse: 0.0061 - val_mae: 0.0406 - val_root_mean_squared_error: 0.0778
# Epoch 146/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0339 - mse: 0.0047 - mae: 0.0339 - root_mean_squared_error: 0.0687 - val_loss: 0.0405 - val_mse: 0.0061 - val_mae: 0.0405 - val_root_mean_squared_error: 0.0778
# Epoch 147/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0338 - mse: 0.0047 - mae: 0.0338 - root_mean_squared_error: 0.0687 - val_loss: 0.0405 - val_mse: 0.0060 - val_mae: 0.0405 - val_root_mean_squared_error: 0.0778
# Epoch 148/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0338 - mse: 0.0047 - mae: 0.0338 - root_mean_squared_error: 0.0687 - val_loss: 0.0405 - val_mse: 0.0060 - val_mae: 0.0405 - val_root_mean_squared_error: 0.0777
# Epoch 149/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0338 - mse: 0.0047 - mae: 0.0338 - root_mean_squared_error: 0.0687 - val_loss: 0.0404 - val_mse: 0.0060 - val_mae: 0.0404 - val_root_mean_squared_error: 0.0777
# Epoch 150/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0338 - mse: 0.0047 - mae: 0.0338 - root_mean_squared_error: 0.0687 - val_loss: 0.0404 - val_mse: 0.0060 - val_mae: 0.0404 - val_root_mean_squared_error: 0.0777
# Epoch 151/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0337 - mse: 0.0047 - mae: 0.0337 - root_mean_squared_error: 0.0687 - val_loss: 0.0403 - val_mse: 0.0060 - val_mae: 0.0403 - val_root_mean_squared_error: 0.0777
# Epoch 152/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0337 - mse: 0.0047 - mae: 0.0337 - root_mean_squared_error: 0.0687 - val_loss: 0.0403 - val_mse: 0.0060 - val_mae: 0.0403 - val_root_mean_squared_error: 0.0776
# Epoch 153/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0337 - mse: 0.0047 - mae: 0.0337 - root_mean_squared_error: 0.0687 - val_loss: 0.0402 - val_mse: 0.0060 - val_mae: 0.0402 - val_root_mean_squared_error: 0.0776
# Epoch 154/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0337 - mse: 0.0047 - mae: 0.0337 - root_mean_squared_error: 0.0687 - val_loss: 0.0402 - val_mse: 0.0060 - val_mae: 0.0402 - val_root_mean_squared_error: 0.0776
# Epoch 155/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0337 - mse: 0.0047 - mae: 0.0337 - root_mean_squared_error: 0.0687 - val_loss: 0.0402 - val_mse: 0.0060 - val_mae: 0.0402 - val_root_mean_squared_error: 0.0776
# Epoch 156/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0336 - mse: 0.0047 - mae: 0.0336 - root_mean_squared_error: 0.0686 - val_loss: 0.0401 - val_mse: 0.0060 - val_mae: 0.0401 - val_root_mean_squared_error: 0.0776
# Epoch 157/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0336 - mse: 0.0047 - mae: 0.0336 - root_mean_squared_error: 0.0686 - val_loss: 0.0401 - val_mse: 0.0060 - val_mae: 0.0401 - val_root_mean_squared_error: 0.0775
# Epoch 158/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0336 - mse: 0.0047 - mae: 0.0336 - root_mean_squared_error: 0.0686 - val_loss: 0.0401 - val_mse: 0.0060 - val_mae: 0.0401 - val_root_mean_squared_error: 0.0775
# Epoch 159/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0336 - mse: 0.0047 - mae: 0.0336 - root_mean_squared_error: 0.0686 - val_loss: 0.0400 - val_mse: 0.0060 - val_mae: 0.0400 - val_root_mean_squared_error: 0.0775
# Epoch 160/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0336 - mse: 0.0047 - mae: 0.0336 - root_mean_squared_error: 0.0686 - val_loss: 0.0400 - val_mse: 0.0060 - val_mae: 0.0400 - val_root_mean_squared_error: 0.0775
# Epoch 161/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0336 - mse: 0.0047 - mae: 0.0336 - root_mean_squared_error: 0.0686 - val_loss: 0.0400 - val_mse: 0.0060 - val_mae: 0.0400 - val_root_mean_squared_error: 0.0775
# Epoch 162/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0335 - mse: 0.0047 - mae: 0.0335 - root_mean_squared_error: 0.0686 - val_loss: 0.0399 - val_mse: 0.0060 - val_mae: 0.0399 - val_root_mean_squared_error: 0.0775
# Epoch 163/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0335 - mse: 0.0047 - mae: 0.0335 - root_mean_squared_error: 0.0686 - val_loss: 0.0399 - val_mse: 0.0060 - val_mae: 0.0399 - val_root_mean_squared_error: 0.0775
# Epoch 164/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0335 - mse: 0.0047 - mae: 0.0335 - root_mean_squared_error: 0.0686 - val_loss: 0.0399 - val_mse: 0.0060 - val_mae: 0.0399 - val_root_mean_squared_error: 0.0775
# Epoch 165/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0335 - mse: 0.0047 - mae: 0.0335 - root_mean_squared_error: 0.0686 - val_loss: 0.0398 - val_mse: 0.0060 - val_mae: 0.0398 - val_root_mean_squared_error: 0.0775
# Epoch 166/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0335 - mse: 0.0047 - mae: 0.0335 - root_mean_squared_error: 0.0686 - val_loss: 0.0398 - val_mse: 0.0060 - val_mae: 0.0398 - val_root_mean_squared_error: 0.0774
# Epoch 167/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0335 - mse: 0.0047 - mae: 0.0335 - root_mean_squared_error: 0.0686 - val_loss: 0.0398 - val_mse: 0.0060 - val_mae: 0.0398 - val_root_mean_squared_error: 0.0774
# Epoch 168/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0334 - mse: 0.0047 - mae: 0.0334 - root_mean_squared_error: 0.0686 - val_loss: 0.0398 - val_mse: 0.0060 - val_mae: 0.0398 - val_root_mean_squared_error: 0.0774
# Epoch 169/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0334 - mse: 0.0047 - mae: 0.0334 - root_mean_squared_error: 0.0686 - val_loss: 0.0397 - val_mse: 0.0060 - val_mae: 0.0397 - val_root_mean_squared_error: 0.0774
# Epoch 170/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0334 - mse: 0.0047 - mae: 0.0334 - root_mean_squared_error: 0.0686 - val_loss: 0.0397 - val_mse: 0.0060 - val_mae: 0.0397 - val_root_mean_squared_error: 0.0774
# Epoch 171/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0334 - mse: 0.0047 - mae: 0.0334 - root_mean_squared_error: 0.0686 - val_loss: 0.0397 - val_mse: 0.0060 - val_mae: 0.0397 - val_root_mean_squared_error: 0.0773
# Epoch 172/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0334 - mse: 0.0047 - mae: 0.0334 - root_mean_squared_error: 0.0685 - val_loss: 0.0396 - val_mse: 0.0060 - val_mae: 0.0396 - val_root_mean_squared_error: 0.0773
# Epoch 173/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0334 - mse: 0.0047 - mae: 0.0334 - root_mean_squared_error: 0.0685 - val_loss: 0.0396 - val_mse: 0.0060 - val_mae: 0.0396 - val_root_mean_squared_error: 0.0773
# Epoch 174/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0333 - mse: 0.0047 - mae: 0.0333 - root_mean_squared_error: 0.0685 - val_loss: 0.0396 - val_mse: 0.0060 - val_mae: 0.0396 - val_root_mean_squared_error: 0.0772
# Epoch 175/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0333 - mse: 0.0047 - mae: 0.0333 - root_mean_squared_error: 0.0685 - val_loss: 0.0395 - val_mse: 0.0060 - val_mae: 0.0395 - val_root_mean_squared_error: 0.0772
# Epoch 176/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0333 - mse: 0.0047 - mae: 0.0333 - root_mean_squared_error: 0.0685 - val_loss: 0.0395 - val_mse: 0.0060 - val_mae: 0.0395 - val_root_mean_squared_error: 0.0772
# Epoch 177/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0333 - mse: 0.0047 - mae: 0.0333 - root_mean_squared_error: 0.0685 - val_loss: 0.0395 - val_mse: 0.0060 - val_mae: 0.0395 - val_root_mean_squared_error: 0.0772
# Epoch 178/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0333 - mse: 0.0047 - mae: 0.0333 - root_mean_squared_error: 0.0685 - val_loss: 0.0394 - val_mse: 0.0060 - val_mae: 0.0394 - val_root_mean_squared_error: 0.0772
# Epoch 179/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0333 - mse: 0.0047 - mae: 0.0333 - root_mean_squared_error: 0.0685 - val_loss: 0.0394 - val_mse: 0.0060 - val_mae: 0.0394 - val_root_mean_squared_error: 0.0772
# Epoch 180/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0332 - mse: 0.0047 - mae: 0.0332 - root_mean_squared_error: 0.0685 - val_loss: 0.0394 - val_mse: 0.0060 - val_mae: 0.0394 - val_root_mean_squared_error: 0.0772
# Epoch 181/500
# 3175/3175 [==============================] - 0s 59us/sample - loss: 0.0332 - mse: 0.0047 - mae: 0.0332 - root_mean_squared_error: 0.0685 - val_loss: 0.0394 - val_mse: 0.0060 - val_mae: 0.0394 - val_root_mean_squared_error: 0.0772
# Epoch 182/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0332 - mse: 0.0047 - mae: 0.0332 - root_mean_squared_error: 0.0685 - val_loss: 0.0394 - val_mse: 0.0060 - val_mae: 0.0394 - val_root_mean_squared_error: 0.0772
# Epoch 183/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0332 - mse: 0.0047 - mae: 0.0332 - root_mean_squared_error: 0.0685 - val_loss: 0.0393 - val_mse: 0.0060 - val_mae: 0.0393 - val_root_mean_squared_error: 0.0772
# Epoch 184/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0332 - mse: 0.0047 - mae: 0.0332 - root_mean_squared_error: 0.0685 - val_loss: 0.0393 - val_mse: 0.0060 - val_mae: 0.0393 - val_root_mean_squared_error: 0.0771
# Epoch 185/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0332 - mse: 0.0047 - mae: 0.0332 - root_mean_squared_error: 0.0684 - val_loss: 0.0393 - val_mse: 0.0059 - val_mae: 0.0393 - val_root_mean_squared_error: 0.0771
# Epoch 186/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0332 - mse: 0.0047 - mae: 0.0332 - root_mean_squared_error: 0.0684 - val_loss: 0.0392 - val_mse: 0.0059 - val_mae: 0.0392 - val_root_mean_squared_error: 0.0771
# Epoch 187/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0331 - mse: 0.0047 - mae: 0.0331 - root_mean_squared_error: 0.0684 - val_loss: 0.0392 - val_mse: 0.0059 - val_mae: 0.0392 - val_root_mean_squared_error: 0.0771
# Epoch 188/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0331 - mse: 0.0047 - mae: 0.0331 - root_mean_squared_error: 0.0684 - val_loss: 0.0392 - val_mse: 0.0059 - val_mae: 0.0392 - val_root_mean_squared_error: 0.0770
# Epoch 189/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0331 - mse: 0.0047 - mae: 0.0331 - root_mean_squared_error: 0.0684 - val_loss: 0.0392 - val_mse: 0.0059 - val_mae: 0.0392 - val_root_mean_squared_error: 0.0771
# Epoch 190/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0331 - mse: 0.0047 - mae: 0.0331 - root_mean_squared_error: 0.0684 - val_loss: 0.0391 - val_mse: 0.0059 - val_mae: 0.0391 - val_root_mean_squared_error: 0.0771
# Epoch 191/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0331 - mse: 0.0047 - mae: 0.0331 - root_mean_squared_error: 0.0684 - val_loss: 0.0391 - val_mse: 0.0059 - val_mae: 0.0391 - val_root_mean_squared_error: 0.0771
# Epoch 192/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0331 - mse: 0.0047 - mae: 0.0331 - root_mean_squared_error: 0.0684 - val_loss: 0.0391 - val_mse: 0.0059 - val_mae: 0.0391 - val_root_mean_squared_error: 0.0771
# Epoch 193/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0331 - mse: 0.0047 - mae: 0.0331 - root_mean_squared_error: 0.0684 - val_loss: 0.0391 - val_mse: 0.0059 - val_mae: 0.0391 - val_root_mean_squared_error: 0.0770
# Epoch 194/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0331 - mse: 0.0047 - mae: 0.0331 - root_mean_squared_error: 0.0684 - val_loss: 0.0391 - val_mse: 0.0059 - val_mae: 0.0391 - val_root_mean_squared_error: 0.0771
# Epoch 195/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0331 - mse: 0.0047 - mae: 0.0331 - root_mean_squared_error: 0.0684 - val_loss: 0.0390 - val_mse: 0.0059 - val_mae: 0.0390 - val_root_mean_squared_error: 0.0770
# Epoch 196/500
# ...
# Epoch 436/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0320 - mse: 0.0046 - mae: 0.0320 - root_mean_squared_error: 0.0679 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0765
# Epoch 437/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0320 - mse: 0.0046 - mae: 0.0320 - root_mean_squared_error: 0.0679 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0765
# Epoch 438/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0320 - mse: 0.0046 - mae: 0.0320 - root_mean_squared_error: 0.0679 - val_loss: 0.0372 - val_mse: 0.0059 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0765
# Epoch 439/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0320 - mse: 0.0046 - mae: 0.0320 - root_mean_squared_error: 0.0679 - val_loss: 0.0372 - val_mse: 0.0059 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0765
# Epoch 440/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0320 - mse: 0.0046 - mae: 0.0320 - root_mean_squared_error: 0.0679 - val_loss: 0.0372 - val_mse: 0.0059 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0765
# Epoch 441/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0320 - mse: 0.0046 - mae: 0.0320 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0059 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0766
# Epoch 442/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0320 - mse: 0.0046 - mae: 0.0320 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0059 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0766
# Epoch 443/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0320 - mse: 0.0046 - mae: 0.0320 - root_mean_squared_error: 0.0679 - val_loss: 0.0372 - val_mse: 0.0059 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0766
# Epoch 444/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0320 - mse: 0.0046 - mae: 0.0320 - root_mean_squared_error: 0.0679 - val_loss: 0.0372 - val_mse: 0.0059 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0766
# Epoch 445/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0320 - mse: 0.0046 - mae: 0.0320 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0059 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0766
# Epoch 446/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0320 - mse: 0.0046 - mae: 0.0320 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0059 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0765
# Epoch 447/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0320 - mse: 0.0046 - mae: 0.0320 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0059 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0765
# Epoch 448/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0320 - mse: 0.0046 - mae: 0.0320 - root_mean_squared_error: 0.0679 - val_loss: 0.0372 - val_mse: 0.0059 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0765
# Epoch 449/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0320 - mse: 0.0046 - mae: 0.0320 - root_mean_squared_error: 0.0679 - val_loss: 0.0372 - val_mse: 0.0059 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0765
# Epoch 450/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0679 - val_loss: 0.0372 - val_mse: 0.0059 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0765
# Epoch 451/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0320 - mse: 0.0046 - mae: 0.0320 - root_mean_squared_error: 0.0679 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0765
# Epoch 452/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0320 - mse: 0.0046 - mae: 0.0320 - root_mean_squared_error: 0.0679 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0765
# Epoch 453/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0765
# Epoch 454/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0765
# Epoch 455/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0059 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0765
# Epoch 456/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0059 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0765
# Epoch 457/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0059 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0766
# Epoch 458/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0320 - mse: 0.0046 - mae: 0.0320 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0059 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0766
# Epoch 459/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0679 - val_loss: 0.0371 - val_mse: 0.0059 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0766
# Epoch 460/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0059 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0766
# Epoch 461/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0059 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0766
# Epoch 462/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0059 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0766
# Epoch 463/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0059 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0766
# Epoch 464/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0059 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 465/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0059 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 466/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 467/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 468/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 469/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 470/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 471/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 472/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 473/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 474/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 475/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0059 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 476/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0059 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 477/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0059 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0766
# Epoch 478/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0059 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0766
# Epoch 479/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0059 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0766
# Epoch 480/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0059 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0766
# Epoch 481/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0059 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0766
# Epoch 482/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0059 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0766
# Epoch 483/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0059 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 484/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0059 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 485/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 486/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 487/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 488/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 489/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 490/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 491/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 492/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 493/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 494/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 495/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0370 - val_mse: 0.0059 - val_mae: 0.0370 - val_root_mean_squared_error: 0.0765
# Epoch 496/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0370 - val_mse: 0.0059 - val_mae: 0.0370 - val_root_mean_squared_error: 0.0765
# Epoch 497/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0370 - val_mse: 0.0059 - val_mae: 0.0370 - val_root_mean_squared_error: 0.0765
# Epoch 498/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0370 - val_mse: 0.0059 - val_mae: 0.0370 - val_root_mean_squared_error: 0.0765
# Epoch 499/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0370 - val_mse: 0.0059 - val_mae: 0.0370 - val_root_mean_squared_error: 0.0766
# Epoch 500/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0319 - mse: 0.0046 - mae: 0.0319 - root_mean_squared_error: 0.0678 - val_loss: 0.0370 - val_mse: 0.0059 - val_mae: 0.0370 - val_root_mean_squared_error: 0.0766

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mae'],label='train mae')
pyplot.plot(history.history['val_mae'],label='val mae')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mse'],label='train mse')
pyplot.plot(history.history['val_mse'],label='val mse')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['root_mean_squared_error'],label='train rmse')
pyplot.plot(history.history['val_root_mean_squared_error'],label='val rmse')
pyplot.legend()
pyplot.show()
# Out:
# The testing MAE loss is: 0.034467254
# The testing MSE loss is: 0.005243269
# The testing RMSE loss is: 0.07241042

# %%
pyplot.plot(test_y[:,2],color='red', label='True Values')
pyplot.plot(out[:,2],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()

# %%
dataset_test=pd.read_excel('F:\MS thesis data/Hopper Crossing.xlsx')
dataset_test=dataset_test.drop(['Date/Time','Flowd'],axis=1)
dataset_test.dropna(inplace=True)

# %%
shape=np.shape(dataset_test)
print(shape)
pyplot.plot(dataset_test)
# Out:
# (26285, 3)
# [<matplotlib.lines.Line2D at 0x23bfe5503c8>,
#  <matplotlib.lines.Line2D at 0x23bfe551308>,
#  <matplotlib.lines.Line2D at 0x23bfe551648>]

# %%
dataset_test
# Out:
#        Cumulative rainfall   Flow  Level
# 0                      0.0  0.093    1.50
# 1                      0.0  0.093    1.50
# 2                      0.0  0.093    1.50
# 3                      0.0  0.093    1.50
# 4                      0.0  0.093    1.50
# ...                    ...    ...     ...
# 26280                  0.2  0.080    1.49
# 26281                  0.2  0.080    1.49
# 26282                  0.2  0.080    1.49
# 26283                  0.2  0.080    1.49
# 26284                  0.2  0.080    1.49
#
# [26285 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset_test)))
# Out:
# The std of original data is Cumulative rainfall    2.451640
# Flow                   0.520832
# Level                  0.083204
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset_test=dataset_test.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset_test.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset_test[:,0]== maxi[0])
    ind2=np.argwhere(dataset_test[:,1]== maxi[1])
    ind3=np.argwhere(dataset_test[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset_test.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset_test[:,0]== mini[0])
    ind2=np.argwhere(dataset_test[:,1]== mini[1])
    ind3=np.argwhere(dataset_test[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset_test)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset_test = min_max_scaler.fit_transform(dataset_test)
# Out:
# The std of cleaned data is 1.5154548293543502

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=3
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values

#one hour
#test_X, test_y = values[:, :-out_hour], values[:,-1]


test_X, test_y = values[:, :-out_hour], values[:, -out_hour: ]


test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6343, 27)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var3(t-3)  var1(t-2)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.762136   0.230769
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.776699   0.215385
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.776699   0.123077
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.791262   0.092308
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.820388   0.092308
#
#     var2(t-2)  var3(t-2)  var1(t-1)  var2(t-1)  var3(t-1)   var3(t)  \
# 6    0.524545   0.776699   0.215385   0.524545   0.776699  0.791262
# 7    0.524545   0.776699   0.123077   0.549980   0.791262  0.820388
# 8    0.549980   0.791262   0.092308   0.603309   0.820388  0.844660
# 9    0.603309   0.820388   0.092308   0.650485   0.844660  0.873786
# 10   0.650485   0.844660   0.092308   0.709285   0.873786  0.898058
#
#     var3(t+1)  var3(t+2)
# 6    0.820388   0.844660
# 7    0.844660   0.873786
# 8    0.873786   0.898058
# 9    0.898058   0.932039
# 10   0.932039   0.966019
#
# [5 rows x 21 columns]

# %%
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
# Out:
# The testing MAE loss is: 0.033748128
# The testing MSE loss is: 0.0050815227
# The testing RMSE loss is: 0.071284786

# %%
pyplot.plot(test_y[:,2],color='red', label='True Values')
pyplot.plot(out[:,2],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()
