# %%
import pandas as pd
from pandas import concat
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from sklearn import preprocessing
from tensorflow.keras import backend as K
#from sklearn.preprocessing import MinMaxScaler
#from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input, Dense, LSTM,GRU,SimpleRNN, Activation
from matplotlib import pyplot
#from sklearn.model_selection import train_test_split

# %%
"# convert series to supervised learning\n" 
#windowing of data
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1),
    for i in range(n_in, 0, -1): #startes from n_in and decreses to 0 by decreasing each time -1
     cols.append(df.shift(i))
     names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
     cols.append(df.shift(-i))
     if i == 0:
       names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
     else:
       names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together\n",
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values\n",
    if dropnan:
      agg.dropna(inplace=True)
    return agg

# %%
#def root_mean_squared_error(y_true, y_pred):
 #       return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
dataset1=pd.read_excel('F:\MS thesis data/Brooklyn.xlsx')
dataset1=dataset1.drop(['Date/Time','Flowd'],axis=1)
dataset1.dropna(inplace=True)

# %%
shape=np.shape(dataset1)
print(shape)
pyplot.plot(dataset1)
# Out:
# (26302, 3)
# [<matplotlib.lines.Line2D at 0x241f9995088>,
#  <matplotlib.lines.Line2D at 0x241fa471cc8>,
#  <matplotlib.lines.Line2D at 0x241fa471288>]

# %%
dataset1
# Out:
#        Cumulative rainfall    Flow  Level
# 0                       0.0  0.172   0.352
# 1                       0.0  0.180   0.356
# 2                       0.0  0.180   0.356
# 3                       0.0  0.189   0.360
# 4                       0.0  0.189   0.360
# ...                     ...    ...     ...
# 26297                   0.0  0.025   0.232
# 26298                   0.0  0.023   0.228
# 26299                   0.0  0.023   0.228
# 26300                   0.0  0.023   0.228
# 26301                   0.0  0.023   0.228
#
# [26302 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset1)))
# Out:
# The std of original data is Cumulative rainfall     2.872616
# Flow                    1.306642
# Level                   0.147238
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset=dataset1.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset[:,0]== maxi[0])
    ind2=np.argwhere(dataset[:,1]== maxi[1])
    ind3=np.argwhere(dataset[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset[:,0]== mini[0])
    ind2=np.argwhere(dataset[:,1]== mini[1])
    ind3=np.argwhere(dataset[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset = min_max_scaler.fit_transform(dataset)
# Out:
# The std of cleaned data is 1.626639593959813

# %%
pyplot.plot(dataset)
# Out:
# [<matplotlib.lines.Line2D at 0x241f9ca4408>,
#  <matplotlib.lines.Line2D at 0x241f9af7388>,
#  <matplotlib.lines.Line2D at 0x241f9af7548>]

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=4
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values
train_size  = int(len(dataset) * 0.50)
val_size=int(len(dataset) * 0.75)
train_X, train_y = values[0:train_size, :-out_hour], values[0:train_size,-out_hour: ]
val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-out_hour: ]
test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-out_hour:]
#for last hour
#train_X, train_y = values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]  #for only last hour
#val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]
#test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-1]
print(train_X, train_y)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6342, 30)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var1(t-2)  var2(t-2)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.230769   0.524545
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.215385   0.524545
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.123077   0.549980
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.092308   0.603309
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.092308   0.650485
#
#     var3(t-2)  var1(t-1)  var2(t-1)  var3(t-1)   var3(t)  var3(t+1)  \
# 6    0.776699   0.215385   0.524545   0.776699  0.791262   0.820388
# 7    0.776699   0.123077   0.549980   0.791262  0.820388   0.844660
# 8    0.791262   0.092308   0.603309   0.820388  0.844660   0.873786
# 9    0.820388   0.092308   0.650485   0.844660  0.873786   0.898058
# 10   0.844660   0.092308   0.709285   0.873786  0.898058   0.932039
#
#     var3(t+2)  var3(t+3)
# 6    0.844660   0.873786
# 7    0.873786   0.898058
# 8    0.898058   0.932039
# 9    0.932039   0.966019
# 10   0.966019   1.000000
#
# [5 rows x 22 columns]
# [[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]
#  [0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]
#  [0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]
#  ...
#  [0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]
#  [0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]
#  [0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]] [[0.79126215 0.8203884  0.8446602  0.8737864 ]
#  [0.8203884  0.8446602  0.8737864  0.89805824]
#  [0.8446602  0.8737864  0.89805824 0.93203884]
#  ...
#  [0.23786408 0.24271844 0.24757281 0.24757281]
#  [0.24271844 0.24757281 0.24757281 0.24757281]
#  [0.24757281 0.24757281 0.24757281 0.2184466 ]]

# %%
print(train_X, train_y)
# Out:
# [[[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]]
#
#  [[0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]]
#
#  [[0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]]
#
#  ...
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]]] [[0.79126215 0.8203884  0.8446602  0.8737864 ]
#  [0.8203884  0.8446602  0.8737864  0.89805824]
#  [0.8446602  0.8737864  0.89805824 0.93203884]
#  ...
#  [0.23786408 0.24271844 0.24757281 0.24757281]
#  [0.24271844 0.24757281 0.24757281 0.24757281]
#  [0.24757281 0.24757281 0.24757281 0.2184466 ]]

# %%
print(train_X.shape, train_y.shape, val_X.shape, val_y.shape)
# Out:
# (3175, 1, 18) (3175, 4) (1588, 1, 18) (1588, 4)

# %%
randomState = 46
np.random.seed(randomState)
#tensorflow.random.set_random_seed(randomState)
tensorflow.random.set_seed(randomState)
model = Sequential()
model.add(GRU(15,input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dense(22))
#model.add(Activation('relu'))    
model.add(Dense(out_hour,activation = "sigmoid"))
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.001)
#    opt=tensorflow.keras.optimizers.Adam(learning_rate=0.00075)
model.compile(loss='mae', optimizer=opt,metrics=['mse','mae',tensorflow.keras.metrics.RootMeanSquaredError()])
history = model.fit(train_X, train_y,validation_data=(val_X, val_y), epochs=500, batch_size=100,verbose=1,shuffle=False)
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)
# Out:
# Train on 3175 samples, validate on 1588 samples
# Epoch 1/500
# 3175/3175 [==============================] - 2s 725us/sample - loss: 0.2521 - mse: 0.0763 - mae: 0.2521 - root_mean_squared_error: 0.2762 - val_loss: 0.2617 - val_mse: 0.0848 - val_mae: 0.2617 - val_root_mean_squared_error: 0.2912
# Epoch 2/500
# 3175/3175 [==============================] - 0s 60us/sample - loss: 0.2283 - mse: 0.0644 - mae: 0.2283 - root_mean_squared_error: 0.2538 - val_loss: 0.2381 - val_mse: 0.0714 - val_mae: 0.2381 - val_root_mean_squared_error: 0.2673
# Epoch 3/500
# 3175/3175 [==============================] - 0s 60us/sample - loss: 0.2049 - mse: 0.0545 - mae: 0.2049 - root_mean_squared_error: 0.2334 - val_loss: 0.2142 - val_mse: 0.0598 - val_mae: 0.2142 - val_root_mean_squared_error: 0.2445
# Epoch 4/500
# 3175/3175 [==============================] - 0s 60us/sample - loss: 0.1837 - mse: 0.0472 - mae: 0.1837 - root_mean_squared_error: 0.2172 - val_loss: 0.1935 - val_mse: 0.0510 - val_mae: 0.1935 - val_root_mean_squared_error: 0.2257
# Epoch 5/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.1672 - mse: 0.0424 - mae: 0.1672 - root_mean_squared_error: 0.2059 - val_loss: 0.1774 - val_mse: 0.0446 - val_mae: 0.1774 - val_root_mean_squared_error: 0.2112
# Epoch 6/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.1544 - mse: 0.0387 - mae: 0.1544 - root_mean_squared_error: 0.1967 - val_loss: 0.1641 - val_mse: 0.0395 - val_mae: 0.1641 - val_root_mean_squared_error: 0.1988
# Epoch 7/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.1433 - mse: 0.0351 - mae: 0.1433 - root_mean_squared_error: 0.1872 - val_loss: 0.1524 - val_mse: 0.0349 - val_mae: 0.1524 - val_root_mean_squared_error: 0.1869
# Epoch 8/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.1328 - mse: 0.0311 - mae: 0.1328 - root_mean_squared_error: 0.1764 - val_loss: 0.1412 - val_mse: 0.0306 - val_mae: 0.1412 - val_root_mean_squared_error: 0.1748
# Epoch 9/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.1225 - mse: 0.0271 - mae: 0.1225 - root_mean_squared_error: 0.1645 - val_loss: 0.1305 - val_mse: 0.0264 - val_mae: 0.1305 - val_root_mean_squared_error: 0.1625
# Epoch 10/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.1126 - mse: 0.0231 - mae: 0.1126 - root_mean_squared_error: 0.1518 - val_loss: 0.1200 - val_mse: 0.0227 - val_mae: 0.1200 - val_root_mean_squared_error: 0.1507
# Epoch 11/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.1033 - mse: 0.0195 - mae: 0.1033 - root_mean_squared_error: 0.1396 - val_loss: 0.1106 - val_mse: 0.0196 - val_mae: 0.1106 - val_root_mean_squared_error: 0.1401
# Epoch 12/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0952 - mse: 0.0167 - mae: 0.0952 - root_mean_squared_error: 0.1291 - val_loss: 0.1025 - val_mse: 0.0173 - val_mae: 0.1025 - val_root_mean_squared_error: 0.1316
# Epoch 13/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0884 - mse: 0.0146 - mae: 0.0884 - root_mean_squared_error: 0.1209 - val_loss: 0.0959 - val_mse: 0.0156 - val_mae: 0.0959 - val_root_mean_squared_error: 0.1248
# Epoch 14/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0828 - mse: 0.0132 - mae: 0.0828 - root_mean_squared_error: 0.1148 - val_loss: 0.0905 - val_mse: 0.0143 - val_mae: 0.0905 - val_root_mean_squared_error: 0.1197
# Epoch 15/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0780 - mse: 0.0121 - mae: 0.0780 - root_mean_squared_error: 0.1101 - val_loss: 0.0859 - val_mse: 0.0134 - val_mae: 0.0859 - val_root_mean_squared_error: 0.1157
# Epoch 16/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0739 - mse: 0.0113 - mae: 0.0739 - root_mean_squared_error: 0.1065 - val_loss: 0.0818 - val_mse: 0.0126 - val_mae: 0.0818 - val_root_mean_squared_error: 0.1125
# Epoch 17/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0703 - mse: 0.0107 - mae: 0.0703 - root_mean_squared_error: 0.1037 - val_loss: 0.0782 - val_mse: 0.0120 - val_mae: 0.0782 - val_root_mean_squared_error: 0.1098
# Epoch 18/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0672 - mse: 0.0103 - mae: 0.0672 - root_mean_squared_error: 0.1014 - val_loss: 0.0750 - val_mse: 0.0116 - val_mae: 0.0750 - val_root_mean_squared_error: 0.1075
# Epoch 19/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0646 - mse: 0.0099 - mae: 0.0646 - root_mean_squared_error: 0.0995 - val_loss: 0.0723 - val_mse: 0.0112 - val_mae: 0.0723 - val_root_mean_squared_error: 0.1058
# Epoch 20/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0623 - mse: 0.0096 - mae: 0.0623 - root_mean_squared_error: 0.0980 - val_loss: 0.0699 - val_mse: 0.0109 - val_mae: 0.0699 - val_root_mean_squared_error: 0.1043
# Epoch 21/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0604 - mse: 0.0094 - mae: 0.0604 - root_mean_squared_error: 0.0967 - val_loss: 0.0678 - val_mse: 0.0106 - val_mae: 0.0678 - val_root_mean_squared_error: 0.1029
# Epoch 22/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0588 - mse: 0.0091 - mae: 0.0588 - root_mean_squared_error: 0.0956 - val_loss: 0.0662 - val_mse: 0.0103 - val_mae: 0.0662 - val_root_mean_squared_error: 0.1017
# Epoch 23/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0574 - mse: 0.0089 - mae: 0.0574 - root_mean_squared_error: 0.0945 - val_loss: 0.0647 - val_mse: 0.0101 - val_mae: 0.0647 - val_root_mean_squared_error: 0.1005
# Epoch 24/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0609 - mse: 0.0101 - mae: 0.0609 - root_mean_squared_error: 0.100 - 0s 29us/sample - loss: 0.0562 - mse: 0.0087 - mae: 0.0562 - root_mean_squared_error: 0.0933 - val_loss: 0.0635 - val_mse: 0.0099 - val_mae: 0.0635 - val_root_mean_squared_error: 0.0994
# Epoch 25/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0552 - mse: 0.0085 - mae: 0.0552 - root_mean_squared_error: 0.0922 - val_loss: 0.0625 - val_mse: 0.0097 - val_mae: 0.0625 - val_root_mean_squared_error: 0.0986
# Epoch 26/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0543 - mse: 0.0083 - mae: 0.0543 - root_mean_squared_error: 0.0913 - val_loss: 0.0616 - val_mse: 0.0095 - val_mae: 0.0616 - val_root_mean_squared_error: 0.0977
# Epoch 27/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0535 - mse: 0.0082 - mae: 0.0535 - root_mean_squared_error: 0.0904 - val_loss: 0.0608 - val_mse: 0.0094 - val_mae: 0.0608 - val_root_mean_squared_error: 0.0969
# Epoch 28/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0529 - mse: 0.0080 - mae: 0.0529 - root_mean_squared_error: 0.0896 - val_loss: 0.0602 - val_mse: 0.0093 - val_mae: 0.0602 - val_root_mean_squared_error: 0.0963
# Epoch 29/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0523 - mse: 0.0079 - mae: 0.0523 - root_mean_squared_error: 0.0888 - val_loss: 0.0596 - val_mse: 0.0092 - val_mae: 0.0596 - val_root_mean_squared_error: 0.0958
# Epoch 30/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0518 - mse: 0.0078 - mae: 0.0518 - root_mean_squared_error: 0.0882 - val_loss: 0.0591 - val_mse: 0.0091 - val_mae: 0.0591 - val_root_mean_squared_error: 0.0953
# Epoch 31/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0513 - mse: 0.0077 - mae: 0.0513 - root_mean_squared_error: 0.0875 - val_loss: 0.0587 - val_mse: 0.0090 - val_mae: 0.0587 - val_root_mean_squared_error: 0.0949
# Epoch 32/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0509 - mse: 0.0076 - mae: 0.0509 - root_mean_squared_error: 0.0870 - val_loss: 0.0583 - val_mse: 0.0089 - val_mae: 0.0583 - val_root_mean_squared_error: 0.0945
# Epoch 33/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0506 - mse: 0.0075 - mae: 0.0506 - root_mean_squared_error: 0.0865 - val_loss: 0.0580 - val_mse: 0.0089 - val_mae: 0.0580 - val_root_mean_squared_error: 0.0942
# Epoch 34/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0503 - mse: 0.0074 - mae: 0.0503 - root_mean_squared_error: 0.0860 - val_loss: 0.0577 - val_mse: 0.0088 - val_mae: 0.0577 - val_root_mean_squared_error: 0.0939
# Epoch 35/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0542 - mse: 0.0086 - mae: 0.0542 - root_mean_squared_error: 0.093 - 0s 30us/sample - loss: 0.0500 - mse: 0.0073 - mae: 0.0500 - root_mean_squared_error: 0.0856 - val_loss: 0.0574 - val_mse: 0.0087 - val_mae: 0.0574 - val_root_mean_squared_error: 0.0935
# Epoch 36/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0497 - mse: 0.0073 - mae: 0.0497 - root_mean_squared_error: 0.0853 - val_loss: 0.0571 - val_mse: 0.0087 - val_mae: 0.0571 - val_root_mean_squared_error: 0.0933
# Epoch 37/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0494 - mse: 0.0072 - mae: 0.0494 - root_mean_squared_error: 0.0849 - val_loss: 0.0569 - val_mse: 0.0087 - val_mae: 0.0569 - val_root_mean_squared_error: 0.0930
# Epoch 38/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0492 - mse: 0.0072 - mae: 0.0492 - root_mean_squared_error: 0.0846 - val_loss: 0.0567 - val_mse: 0.0086 - val_mae: 0.0567 - val_root_mean_squared_error: 0.0928
# Epoch 39/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0489 - mse: 0.0071 - mae: 0.0489 - root_mean_squared_error: 0.0842 - val_loss: 0.0565 - val_mse: 0.0086 - val_mae: 0.0565 - val_root_mean_squared_error: 0.0925
# Epoch 40/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0487 - mse: 0.0070 - mae: 0.0487 - root_mean_squared_error: 0.0839 - val_loss: 0.0563 - val_mse: 0.0085 - val_mae: 0.0563 - val_root_mean_squared_error: 0.0923
# Epoch 41/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0485 - mse: 0.0070 - mae: 0.0485 - root_mean_squared_error: 0.0836 - val_loss: 0.0561 - val_mse: 0.0085 - val_mae: 0.0561 - val_root_mean_squared_error: 0.0921
# Epoch 42/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0483 - mse: 0.0069 - mae: 0.0483 - root_mean_squared_error: 0.0833 - val_loss: 0.0559 - val_mse: 0.0084 - val_mae: 0.0559 - val_root_mean_squared_error: 0.0919
# Epoch 43/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0480 - mse: 0.0069 - mae: 0.0480 - root_mean_squared_error: 0.0831 - val_loss: 0.0557 - val_mse: 0.0084 - val_mae: 0.0557 - val_root_mean_squared_error: 0.0917
# Epoch 44/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0478 - mse: 0.0069 - mae: 0.0478 - root_mean_squared_error: 0.0828 - val_loss: 0.0555 - val_mse: 0.0084 - val_mae: 0.0555 - val_root_mean_squared_error: 0.0915
# Epoch 45/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0476 - mse: 0.0068 - mae: 0.0476 - root_mean_squared_error: 0.0826 - val_loss: 0.0553 - val_mse: 0.0083 - val_mae: 0.0553 - val_root_mean_squared_error: 0.0913
# Epoch 46/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0474 - mse: 0.0068 - mae: 0.0474 - root_mean_squared_error: 0.0823 - val_loss: 0.0552 - val_mse: 0.0083 - val_mae: 0.0552 - val_root_mean_squared_error: 0.0912
# Epoch 47/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0508 - mse: 0.0077 - mae: 0.0508 - root_mean_squared_error: 0.087 - 0s 29us/sample - loss: 0.0472 - mse: 0.0067 - mae: 0.0472 - root_mean_squared_error: 0.0821 - val_loss: 0.0550 - val_mse: 0.0083 - val_mae: 0.0550 - val_root_mean_squared_error: 0.0910
# Epoch 48/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0471 - mse: 0.0067 - mae: 0.0471 - root_mean_squared_error: 0.0819 - val_loss: 0.0548 - val_mse: 0.0083 - val_mae: 0.0548 - val_root_mean_squared_error: 0.0909
# Epoch 49/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0469 - mse: 0.0067 - mae: 0.0469 - root_mean_squared_error: 0.0817 - val_loss: 0.0547 - val_mse: 0.0082 - val_mae: 0.0547 - val_root_mean_squared_error: 0.0907
# Epoch 50/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0467 - mse: 0.0066 - mae: 0.0467 - root_mean_squared_error: 0.0815 - val_loss: 0.0545 - val_mse: 0.0082 - val_mae: 0.0545 - val_root_mean_squared_error: 0.0905
# Epoch 51/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0465 - mse: 0.0066 - mae: 0.0465 - root_mean_squared_error: 0.0813 - val_loss: 0.0543 - val_mse: 0.0082 - val_mae: 0.0543 - val_root_mean_squared_error: 0.0904
# Epoch 52/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0463 - mse: 0.0066 - mae: 0.0463 - root_mean_squared_error: 0.0812 - val_loss: 0.0542 - val_mse: 0.0081 - val_mae: 0.0542 - val_root_mean_squared_error: 0.0902
# Epoch 53/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0461 - mse: 0.0066 - mae: 0.0461 - root_mean_squared_error: 0.0810 - val_loss: 0.0540 - val_mse: 0.0081 - val_mae: 0.0540 - val_root_mean_squared_error: 0.0901
# Epoch 54/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0460 - mse: 0.0065 - mae: 0.0460 - root_mean_squared_error: 0.0809 - val_loss: 0.0538 - val_mse: 0.0081 - val_mae: 0.0538 - val_root_mean_squared_error: 0.0899
# Epoch 55/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0458 - mse: 0.0065 - mae: 0.0458 - root_mean_squared_error: 0.0807 - val_loss: 0.0537 - val_mse: 0.0081 - val_mae: 0.0537 - val_root_mean_squared_error: 0.0898
# Epoch 56/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0457 - mse: 0.0065 - mae: 0.0457 - root_mean_squared_error: 0.0806 - val_loss: 0.0535 - val_mse: 0.0080 - val_mae: 0.0535 - val_root_mean_squared_error: 0.0896
# Epoch 57/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0487 - mse: 0.0074 - mae: 0.0487 - root_mean_squared_error: 0.086 - 0s 29us/sample - loss: 0.0455 - mse: 0.0065 - mae: 0.0455 - root_mean_squared_error: 0.0805 - val_loss: 0.0534 - val_mse: 0.0080 - val_mae: 0.0534 - val_root_mean_squared_error: 0.0895
# Epoch 58/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0454 - mse: 0.0065 - mae: 0.0454 - root_mean_squared_error: 0.0803 - val_loss: 0.0532 - val_mse: 0.0080 - val_mae: 0.0532 - val_root_mean_squared_error: 0.0894
# Epoch 59/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0452 - mse: 0.0064 - mae: 0.0452 - root_mean_squared_error: 0.0802 - val_loss: 0.0531 - val_mse: 0.0080 - val_mae: 0.0531 - val_root_mean_squared_error: 0.0893
# Epoch 60/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0451 - mse: 0.0064 - mae: 0.0451 - root_mean_squared_error: 0.0801 - val_loss: 0.0529 - val_mse: 0.0080 - val_mae: 0.0529 - val_root_mean_squared_error: 0.0892
# Epoch 61/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0450 - mse: 0.0064 - mae: 0.0450 - root_mean_squared_error: 0.0801 - val_loss: 0.0528 - val_mse: 0.0079 - val_mae: 0.0528 - val_root_mean_squared_error: 0.0891
# Epoch 62/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0449 - mse: 0.0064 - mae: 0.0449 - root_mean_squared_error: 0.0800 - val_loss: 0.0527 - val_mse: 0.0079 - val_mae: 0.0527 - val_root_mean_squared_error: 0.0890
# Epoch 63/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0447 - mse: 0.0064 - mae: 0.0447 - root_mean_squared_error: 0.0799 - val_loss: 0.0526 - val_mse: 0.0079 - val_mae: 0.0526 - val_root_mean_squared_error: 0.0889
# Epoch 64/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0446 - mse: 0.0064 - mae: 0.0446 - root_mean_squared_error: 0.0798 - val_loss: 0.0524 - val_mse: 0.0079 - val_mae: 0.0524 - val_root_mean_squared_error: 0.0888
# Epoch 65/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0445 - mse: 0.0064 - mae: 0.0445 - root_mean_squared_error: 0.0797 - val_loss: 0.0523 - val_mse: 0.0079 - val_mae: 0.0523 - val_root_mean_squared_error: 0.0887
# Epoch 66/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0444 - mse: 0.0063 - mae: 0.0444 - root_mean_squared_error: 0.0797 - val_loss: 0.0522 - val_mse: 0.0079 - val_mae: 0.0522 - val_root_mean_squared_error: 0.0887
# Epoch 67/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0443 - mse: 0.0063 - mae: 0.0443 - root_mean_squared_error: 0.0796 - val_loss: 0.0521 - val_mse: 0.0078 - val_mae: 0.0521 - val_root_mean_squared_error: 0.0886
# Epoch 68/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0442 - mse: 0.0063 - mae: 0.0442 - root_mean_squared_error: 0.0795 - val_loss: 0.0519 - val_mse: 0.0078 - val_mae: 0.0519 - val_root_mean_squared_error: 0.0885
# Epoch 69/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0441 - mse: 0.0063 - mae: 0.0441 - root_mean_squared_error: 0.0794 - val_loss: 0.0518 - val_mse: 0.0078 - val_mae: 0.0518 - val_root_mean_squared_error: 0.0884
# Epoch 70/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0440 - mse: 0.0063 - mae: 0.0440 - root_mean_squared_error: 0.0794 - val_loss: 0.0517 - val_mse: 0.0078 - val_mae: 0.0517 - val_root_mean_squared_error: 0.0883
# Epoch 71/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0471 - mse: 0.0074 - mae: 0.0471 - root_mean_squared_error: 0.086 - 0s 32us/sample - loss: 0.0439 - mse: 0.0063 - mae: 0.0439 - root_mean_squared_error: 0.0793 - val_loss: 0.0515 - val_mse: 0.0078 - val_mae: 0.0515 - val_root_mean_squared_error: 0.0882
# Epoch 72/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0437 - mse: 0.0063 - mae: 0.0437 - root_mean_squared_error: 0.0792 - val_loss: 0.0514 - val_mse: 0.0078 - val_mae: 0.0514 - val_root_mean_squared_error: 0.0881
# Epoch 73/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0436 - mse: 0.0063 - mae: 0.0436 - root_mean_squared_error: 0.0792 - val_loss: 0.0513 - val_mse: 0.0077 - val_mae: 0.0513 - val_root_mean_squared_error: 0.0880
# Epoch 74/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0435 - mse: 0.0063 - mae: 0.0435 - root_mean_squared_error: 0.0791 - val_loss: 0.0511 - val_mse: 0.0077 - val_mae: 0.0511 - val_root_mean_squared_error: 0.0879
# Epoch 75/500
# 3175/3175 [==============================] - 0s 53us/sample - loss: 0.0434 - mse: 0.0062 - mae: 0.0434 - root_mean_squared_error: 0.0790 - val_loss: 0.0510 - val_mse: 0.0077 - val_mae: 0.0510 - val_root_mean_squared_error: 0.0878
# Epoch 76/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0433 - mse: 0.0062 - mae: 0.0433 - root_mean_squared_error: 0.0789 - val_loss: 0.0509 - val_mse: 0.0077 - val_mae: 0.0509 - val_root_mean_squared_error: 0.0877
# Epoch 77/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0432 - mse: 0.0062 - mae: 0.0432 - root_mean_squared_error: 0.0789 - val_loss: 0.0507 - val_mse: 0.0077 - val_mae: 0.0507 - val_root_mean_squared_error: 0.0876
# Epoch 78/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0431 - mse: 0.0062 - mae: 0.0431 - root_mean_squared_error: 0.0788 - val_loss: 0.0506 - val_mse: 0.0077 - val_mae: 0.0506 - val_root_mean_squared_error: 0.0875
# Epoch 79/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0453 - mse: 0.0071 - mae: 0.0453 - root_mean_squared_error: 0.084 - 0s 29us/sample - loss: 0.0430 - mse: 0.0062 - mae: 0.0430 - root_mean_squared_error: 0.0787 - val_loss: 0.0504 - val_mse: 0.0076 - val_mae: 0.0504 - val_root_mean_squared_error: 0.0874
# Epoch 80/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0429 - mse: 0.0062 - mae: 0.0429 - root_mean_squared_error: 0.0787 - val_loss: 0.0503 - val_mse: 0.0076 - val_mae: 0.0503 - val_root_mean_squared_error: 0.0873
# Epoch 81/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0428 - mse: 0.0062 - mae: 0.0428 - root_mean_squared_error: 0.0786 - val_loss: 0.0501 - val_mse: 0.0076 - val_mae: 0.0501 - val_root_mean_squared_error: 0.0872
# Epoch 82/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0427 - mse: 0.0062 - mae: 0.0427 - root_mean_squared_error: 0.0785 - val_loss: 0.0500 - val_mse: 0.0076 - val_mae: 0.0500 - val_root_mean_squared_error: 0.0871
# Epoch 83/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0426 - mse: 0.0062 - mae: 0.0426 - root_mean_squared_error: 0.0784 - val_loss: 0.0499 - val_mse: 0.0076 - val_mae: 0.0499 - val_root_mean_squared_error: 0.0870
# Epoch 84/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0425 - mse: 0.0061 - mae: 0.0425 - root_mean_squared_error: 0.0784 - val_loss: 0.0498 - val_mse: 0.0075 - val_mae: 0.0498 - val_root_mean_squared_error: 0.0869
# Epoch 85/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0424 - mse: 0.0061 - mae: 0.0424 - root_mean_squared_error: 0.0783 - val_loss: 0.0496 - val_mse: 0.0075 - val_mae: 0.0496 - val_root_mean_squared_error: 0.0868
# Epoch 86/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0423 - mse: 0.0061 - mae: 0.0423 - root_mean_squared_error: 0.0782 - val_loss: 0.0495 - val_mse: 0.0075 - val_mae: 0.0495 - val_root_mean_squared_error: 0.0867
# Epoch 87/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0444 - mse: 0.0070 - mae: 0.0444 - root_mean_squared_error: 0.083 - 0s 30us/sample - loss: 0.0422 - mse: 0.0061 - mae: 0.0422 - root_mean_squared_error: 0.0782 - val_loss: 0.0494 - val_mse: 0.0075 - val_mae: 0.0494 - val_root_mean_squared_error: 0.0866
# Epoch 88/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0421 - mse: 0.0061 - mae: 0.0421 - root_mean_squared_error: 0.0781 - val_loss: 0.0493 - val_mse: 0.0075 - val_mae: 0.0493 - val_root_mean_squared_error: 0.0866
# Epoch 89/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0420 - mse: 0.0061 - mae: 0.0420 - root_mean_squared_error: 0.0780 - val_loss: 0.0492 - val_mse: 0.0075 - val_mae: 0.0492 - val_root_mean_squared_error: 0.0865
# Epoch 90/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0419 - mse: 0.0061 - mae: 0.0419 - root_mean_squared_error: 0.0780 - val_loss: 0.0491 - val_mse: 0.0075 - val_mae: 0.0491 - val_root_mean_squared_error: 0.0865
# Epoch 91/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0419 - mse: 0.0061 - mae: 0.0419 - root_mean_squared_error: 0.0780 - val_loss: 0.0490 - val_mse: 0.0075 - val_mae: 0.0490 - val_root_mean_squared_error: 0.0864
# Epoch 92/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0418 - mse: 0.0061 - mae: 0.0418 - root_mean_squared_error: 0.0779 - val_loss: 0.0489 - val_mse: 0.0075 - val_mae: 0.0489 - val_root_mean_squared_error: 0.0863
# Epoch 93/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0417 - mse: 0.0061 - mae: 0.0417 - root_mean_squared_error: 0.0778 - val_loss: 0.0488 - val_mse: 0.0074 - val_mae: 0.0488 - val_root_mean_squared_error: 0.0863
# Epoch 94/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0416 - mse: 0.0060 - mae: 0.0416 - root_mean_squared_error: 0.0778 - val_loss: 0.0487 - val_mse: 0.0074 - val_mae: 0.0487 - val_root_mean_squared_error: 0.0862
# Epoch 95/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0415 - mse: 0.0060 - mae: 0.0415 - root_mean_squared_error: 0.0777 - val_loss: 0.0486 - val_mse: 0.0074 - val_mae: 0.0486 - val_root_mean_squared_error: 0.0862
# Epoch 96/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0415 - mse: 0.0060 - mae: 0.0415 - root_mean_squared_error: 0.0777 - val_loss: 0.0485 - val_mse: 0.0074 - val_mae: 0.0485 - val_root_mean_squared_error: 0.0861
# Epoch 97/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0414 - mse: 0.0060 - mae: 0.0414 - root_mean_squared_error: 0.0776 - val_loss: 0.0484 - val_mse: 0.0074 - val_mae: 0.0484 - val_root_mean_squared_error: 0.0860
# Epoch 98/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0413 - mse: 0.0060 - mae: 0.0413 - root_mean_squared_error: 0.0775 - val_loss: 0.0483 - val_mse: 0.0074 - val_mae: 0.0483 - val_root_mean_squared_error: 0.0860
# Epoch 99/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0412 - mse: 0.0060 - mae: 0.0412 - root_mean_squared_error: 0.0775 - val_loss: 0.0482 - val_mse: 0.0074 - val_mae: 0.0482 - val_root_mean_squared_error: 0.0859
# Epoch 100/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0412 - mse: 0.0060 - mae: 0.0412 - root_mean_squared_error: 0.0775 - val_loss: 0.0481 - val_mse: 0.0074 - val_mae: 0.0481 - val_root_mean_squared_error: 0.0859
# Epoch 101/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0411 - mse: 0.0060 - mae: 0.0411 - root_mean_squared_error: 0.0774 - val_loss: 0.0480 - val_mse: 0.0074 - val_mae: 0.0480 - val_root_mean_squared_error: 0.0858
# Epoch 102/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0410 - mse: 0.0060 - mae: 0.0410 - root_mean_squared_error: 0.0774 - val_loss: 0.0479 - val_mse: 0.0074 - val_mae: 0.0479 - val_root_mean_squared_error: 0.0858
# Epoch 103/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0410 - mse: 0.0060 - mae: 0.0410 - root_mean_squared_error: 0.0773 - val_loss: 0.0478 - val_mse: 0.0074 - val_mae: 0.0478 - val_root_mean_squared_error: 0.0858
# Epoch 104/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0429 - mse: 0.0068 - mae: 0.0429 - root_mean_squared_error: 0.082 - 0s 29us/sample - loss: 0.0409 - mse: 0.0060 - mae: 0.0409 - root_mean_squared_error: 0.0773 - val_loss: 0.0477 - val_mse: 0.0074 - val_mae: 0.0477 - val_root_mean_squared_error: 0.0857
# Epoch 105/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0408 - mse: 0.0060 - mae: 0.0408 - root_mean_squared_error: 0.0772 - val_loss: 0.0476 - val_mse: 0.0073 - val_mae: 0.0476 - val_root_mean_squared_error: 0.0857
# Epoch 106/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0432 - mse: 0.0068 - mae: 0.0432 - root_mean_squared_error: 0.082 - 0s 29us/sample - loss: 0.0408 - mse: 0.0060 - mae: 0.0408 - root_mean_squared_error: 0.0772 - val_loss: 0.0476 - val_mse: 0.0073 - val_mae: 0.0476 - val_root_mean_squared_error: 0.0857
# Epoch 107/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0407 - mse: 0.0060 - mae: 0.0407 - root_mean_squared_error: 0.0772 - val_loss: 0.0475 - val_mse: 0.0073 - val_mae: 0.0475 - val_root_mean_squared_error: 0.0856
# Epoch 108/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0406 - mse: 0.0059 - mae: 0.0406 - root_mean_squared_error: 0.0771 - val_loss: 0.0474 - val_mse: 0.0073 - val_mae: 0.0474 - val_root_mean_squared_error: 0.0856
# Epoch 109/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0406 - mse: 0.0059 - mae: 0.0406 - root_mean_squared_error: 0.0771 - val_loss: 0.0473 - val_mse: 0.0073 - val_mae: 0.0473 - val_root_mean_squared_error: 0.0856
# Epoch 110/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0405 - mse: 0.0059 - mae: 0.0405 - root_mean_squared_error: 0.0771 - val_loss: 0.0473 - val_mse: 0.0073 - val_mae: 0.0473 - val_root_mean_squared_error: 0.0855
# Epoch 111/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0405 - mse: 0.0059 - mae: 0.0405 - root_mean_squared_error: 0.0770 - val_loss: 0.0472 - val_mse: 0.0073 - val_mae: 0.0472 - val_root_mean_squared_error: 0.0855
# Epoch 112/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0404 - mse: 0.0059 - mae: 0.0404 - root_mean_squared_error: 0.0770 - val_loss: 0.0471 - val_mse: 0.0073 - val_mae: 0.0471 - val_root_mean_squared_error: 0.0855
# Epoch 113/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0403 - mse: 0.0059 - mae: 0.0403 - root_mean_squared_error: 0.0770 - val_loss: 0.0470 - val_mse: 0.0073 - val_mae: 0.0470 - val_root_mean_squared_error: 0.0855
# Epoch 114/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0403 - mse: 0.0059 - mae: 0.0403 - root_mean_squared_error: 0.0770 - val_loss: 0.0470 - val_mse: 0.0073 - val_mae: 0.0470 - val_root_mean_squared_error: 0.0854
# Epoch 115/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0402 - mse: 0.0059 - mae: 0.0402 - root_mean_squared_error: 0.0770 - val_loss: 0.0469 - val_mse: 0.0073 - val_mae: 0.0469 - val_root_mean_squared_error: 0.0854
# Epoch 116/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0402 - mse: 0.0059 - mae: 0.0402 - root_mean_squared_error: 0.0769 - val_loss: 0.0468 - val_mse: 0.0073 - val_mae: 0.0468 - val_root_mean_squared_error: 0.0854
# Epoch 117/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0401 - mse: 0.0059 - mae: 0.0401 - root_mean_squared_error: 0.0769 - val_loss: 0.0468 - val_mse: 0.0073 - val_mae: 0.0468 - val_root_mean_squared_error: 0.0854
# Epoch 118/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0401 - mse: 0.0059 - mae: 0.0401 - root_mean_squared_error: 0.0769 - val_loss: 0.0467 - val_mse: 0.0073 - val_mae: 0.0467 - val_root_mean_squared_error: 0.0853
# Epoch 119/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0400 - mse: 0.0059 - mae: 0.0400 - root_mean_squared_error: 0.0769 - val_loss: 0.0466 - val_mse: 0.0073 - val_mae: 0.0466 - val_root_mean_squared_error: 0.0853
# Epoch 120/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0400 - mse: 0.0059 - mae: 0.0400 - root_mean_squared_error: 0.0769 - val_loss: 0.0465 - val_mse: 0.0073 - val_mae: 0.0465 - val_root_mean_squared_error: 0.0853
# Epoch 121/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0399 - mse: 0.0059 - mae: 0.0399 - root_mean_squared_error: 0.0768 - val_loss: 0.0465 - val_mse: 0.0073 - val_mae: 0.0465 - val_root_mean_squared_error: 0.0853
# Epoch 122/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0422 - mse: 0.0067 - mae: 0.0422 - root_mean_squared_error: 0.081 - 0s 30us/sample - loss: 0.0399 - mse: 0.0059 - mae: 0.0399 - root_mean_squared_error: 0.0768 - val_loss: 0.0464 - val_mse: 0.0073 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0852
# Epoch 123/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0398 - mse: 0.0059 - mae: 0.0398 - root_mean_squared_error: 0.0768 - val_loss: 0.0463 - val_mse: 0.0073 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0852
# Epoch 124/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0398 - mse: 0.0059 - mae: 0.0398 - root_mean_squared_error: 0.0768 - val_loss: 0.0463 - val_mse: 0.0073 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0852
# Epoch 125/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0397 - mse: 0.0059 - mae: 0.0397 - root_mean_squared_error: 0.0768 - val_loss: 0.0462 - val_mse: 0.0073 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0852
# Epoch 126/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0397 - mse: 0.0059 - mae: 0.0397 - root_mean_squared_error: 0.0768 - val_loss: 0.0462 - val_mse: 0.0073 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0852
# Epoch 127/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0396 - mse: 0.0059 - mae: 0.0396 - root_mean_squared_error: 0.0768 - val_loss: 0.0461 - val_mse: 0.0073 - val_mae: 0.0461 - val_root_mean_squared_error: 0.0851
# Epoch 128/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0396 - mse: 0.0059 - mae: 0.0396 - root_mean_squared_error: 0.0768 - val_loss: 0.0461 - val_mse: 0.0072 - val_mae: 0.0461 - val_root_mean_squared_error: 0.0851
# Epoch 129/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0396 - mse: 0.0059 - mae: 0.0396 - root_mean_squared_error: 0.0767 - val_loss: 0.0460 - val_mse: 0.0072 - val_mae: 0.0460 - val_root_mean_squared_error: 0.0851
# Epoch 130/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0395 - mse: 0.0059 - mae: 0.0395 - root_mean_squared_error: 0.0767 - val_loss: 0.0459 - val_mse: 0.0072 - val_mae: 0.0459 - val_root_mean_squared_error: 0.0851
# Epoch 131/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0395 - mse: 0.0059 - mae: 0.0395 - root_mean_squared_error: 0.0767 - val_loss: 0.0459 - val_mse: 0.0072 - val_mae: 0.0459 - val_root_mean_squared_error: 0.0851
# Epoch 132/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0394 - mse: 0.0059 - mae: 0.0394 - root_mean_squared_error: 0.0767 - val_loss: 0.0458 - val_mse: 0.0072 - val_mae: 0.0458 - val_root_mean_squared_error: 0.0851
# Epoch 133/500
# 3175/3175 [==============================] - 0s 56us/sample - loss: 0.0394 - mse: 0.0059 - mae: 0.0394 - root_mean_squared_error: 0.0767 - val_loss: 0.0458 - val_mse: 0.0072 - val_mae: 0.0458 - val_root_mean_squared_error: 0.0851
# Epoch 134/500
# 3175/3175 [==============================] - 0s 60us/sample - loss: 0.0394 - mse: 0.0059 - mae: 0.0394 - root_mean_squared_error: 0.0767 - val_loss: 0.0458 - val_mse: 0.0072 - val_mae: 0.0458 - val_root_mean_squared_error: 0.0851
# Epoch 135/500
# 3175/3175 [==============================] - 0s 58us/sample - loss: 0.0393 - mse: 0.0059 - mae: 0.0393 - root_mean_squared_error: 0.0767 - val_loss: 0.0457 - val_mse: 0.0072 - val_mae: 0.0457 - val_root_mean_squared_error: 0.0850
# Epoch 136/500
# 3175/3175 [==============================] - 0s 59us/sample - loss: 0.0393 - mse: 0.0059 - mae: 0.0393 - root_mean_squared_error: 0.0767 - val_loss: 0.0457 - val_mse: 0.0072 - val_mae: 0.0457 - val_root_mean_squared_error: 0.0851
# Epoch 137/500
# 3175/3175 [==============================] - 0s 59us/sample - loss: 0.0393 - mse: 0.0059 - mae: 0.0393 - root_mean_squared_error: 0.0767 - val_loss: 0.0456 - val_mse: 0.0072 - val_mae: 0.0456 - val_root_mean_squared_error: 0.0850
# Epoch 138/500
# 3175/3175 [==============================] - 0s 59us/sample - loss: 0.0392 - mse: 0.0059 - mae: 0.0392 - root_mean_squared_error: 0.0767 - val_loss: 0.0456 - val_mse: 0.0072 - val_mae: 0.0456 - val_root_mean_squared_error: 0.0850
# Epoch 139/500
# 3175/3175 [==============================] - 0s 58us/sample - loss: 0.0392 - mse: 0.0059 - mae: 0.0392 - root_mean_squared_error: 0.0767 - val_loss: 0.0455 - val_mse: 0.0072 - val_mae: 0.0455 - val_root_mean_squared_error: 0.0850
# Epoch 140/500
# 3175/3175 [==============================] - 0s 60us/sample - loss: 0.0392 - mse: 0.0059 - mae: 0.0392 - root_mean_squared_error: 0.0767 - val_loss: 0.0455 - val_mse: 0.0072 - val_mae: 0.0455 - val_root_mean_squared_error: 0.0850
# Epoch 141/500
# 3175/3175 [==============================] - 0s 58us/sample - loss: 0.0392 - mse: 0.0059 - mae: 0.0392 - root_mean_squared_error: 0.0767 - val_loss: 0.0454 - val_mse: 0.0072 - val_mae: 0.0454 - val_root_mean_squared_error: 0.0850
# Epoch 142/500
# 3175/3175 [==============================] - 0s 59us/sample - loss: 0.0391 - mse: 0.0059 - mae: 0.0391 - root_mean_squared_error: 0.0766 - val_loss: 0.0454 - val_mse: 0.0072 - val_mae: 0.0454 - val_root_mean_squared_error: 0.0849
# Epoch 143/500
# 3175/3175 [==============================] - 0s 64us/sample - loss: 0.0391 - mse: 0.0059 - mae: 0.0391 - root_mean_squared_error: 0.0766 - val_loss: 0.0454 - val_mse: 0.0072 - val_mae: 0.0454 - val_root_mean_squared_error: 0.0849
# Epoch 144/500
# 3175/3175 [==============================] - 0s 60us/sample - loss: 0.0391 - mse: 0.0059 - mae: 0.0391 - root_mean_squared_error: 0.0766 - val_loss: 0.0453 - val_mse: 0.0072 - val_mae: 0.0453 - val_root_mean_squared_error: 0.0849
# Epoch 145/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0391 - mse: 0.0059 - mae: 0.0391 - root_mean_squared_error: 0.0766 - val_loss: 0.0453 - val_mse: 0.0072 - val_mae: 0.0453 - val_root_mean_squared_error: 0.0849
# Epoch 146/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0390 - mse: 0.0059 - mae: 0.0390 - root_mean_squared_error: 0.0766 - val_loss: 0.0452 - val_mse: 0.0072 - val_mae: 0.0452 - val_root_mean_squared_error: 0.0849
# Epoch 147/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0390 - mse: 0.0059 - mae: 0.0390 - root_mean_squared_error: 0.0766 - val_loss: 0.0452 - val_mse: 0.0072 - val_mae: 0.0452 - val_root_mean_squared_error: 0.0848
# Epoch 148/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0390 - mse: 0.0059 - mae: 0.0390 - root_mean_squared_error: 0.0766 - val_loss: 0.0452 - val_mse: 0.0072 - val_mae: 0.0452 - val_root_mean_squared_error: 0.0848
# Epoch 149/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0390 - mse: 0.0059 - mae: 0.0390 - root_mean_squared_error: 0.0766 - val_loss: 0.0451 - val_mse: 0.0072 - val_mae: 0.0451 - val_root_mean_squared_error: 0.0848
# Epoch 150/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0389 - mse: 0.0059 - mae: 0.0389 - root_mean_squared_error: 0.0766 - val_loss: 0.0451 - val_mse: 0.0072 - val_mae: 0.0451 - val_root_mean_squared_error: 0.0848
# Epoch 151/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0389 - mse: 0.0059 - mae: 0.0389 - root_mean_squared_error: 0.0766 - val_loss: 0.0451 - val_mse: 0.0072 - val_mae: 0.0451 - val_root_mean_squared_error: 0.0848
# Epoch 152/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0389 - mse: 0.0059 - mae: 0.0389 - root_mean_squared_error: 0.0766 - val_loss: 0.0450 - val_mse: 0.0072 - val_mae: 0.0450 - val_root_mean_squared_error: 0.0848
# Epoch 153/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0389 - mse: 0.0059 - mae: 0.0389 - root_mean_squared_error: 0.0766 - val_loss: 0.0450 - val_mse: 0.0072 - val_mae: 0.0450 - val_root_mean_squared_error: 0.0848
# Epoch 154/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0389 - mse: 0.0059 - mae: 0.0389 - root_mean_squared_error: 0.0766 - val_loss: 0.0450 - val_mse: 0.0072 - val_mae: 0.0450 - val_root_mean_squared_error: 0.0848
# Epoch 155/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0389 - mse: 0.0059 - mae: 0.0389 - root_mean_squared_error: 0.0766 - val_loss: 0.0449 - val_mse: 0.0072 - val_mae: 0.0449 - val_root_mean_squared_error: 0.0848
# Epoch 156/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0388 - mse: 0.0059 - mae: 0.0388 - root_mean_squared_error: 0.0766 - val_loss: 0.0449 - val_mse: 0.0072 - val_mae: 0.0449 - val_root_mean_squared_error: 0.0847
# Epoch 157/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0388 - mse: 0.0059 - mae: 0.0388 - root_mean_squared_error: 0.0766 - val_loss: 0.0448 - val_mse: 0.0072 - val_mae: 0.0448 - val_root_mean_squared_error: 0.0847
# Epoch 158/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0388 - mse: 0.0059 - mae: 0.0388 - root_mean_squared_error: 0.0766 - val_loss: 0.0448 - val_mse: 0.0072 - val_mae: 0.0448 - val_root_mean_squared_error: 0.0847
# Epoch 159/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0388 - mse: 0.0059 - mae: 0.0388 - root_mean_squared_error: 0.0766 - val_loss: 0.0448 - val_mse: 0.0072 - val_mae: 0.0448 - val_root_mean_squared_error: 0.0847
# Epoch 160/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0410 - mse: 0.0067 - mae: 0.0410 - root_mean_squared_error: 0.081 - 0s 30us/sample - loss: 0.0388 - mse: 0.0059 - mae: 0.0388 - root_mean_squared_error: 0.0765 - val_loss: 0.0447 - val_mse: 0.0072 - val_mae: 0.0447 - val_root_mean_squared_error: 0.0847
# Epoch 161/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0387 - mse: 0.0059 - mae: 0.0387 - root_mean_squared_error: 0.0765 - val_loss: 0.0447 - val_mse: 0.0072 - val_mae: 0.0447 - val_root_mean_squared_error: 0.0847
# Epoch 162/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0387 - mse: 0.0059 - mae: 0.0387 - root_mean_squared_error: 0.0765 - val_loss: 0.0447 - val_mse: 0.0072 - val_mae: 0.0447 - val_root_mean_squared_error: 0.0847
# Epoch 163/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0387 - mse: 0.0059 - mae: 0.0387 - root_mean_squared_error: 0.0765 - val_loss: 0.0446 - val_mse: 0.0072 - val_mae: 0.0446 - val_root_mean_squared_error: 0.0847
# Epoch 164/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0387 - mse: 0.0059 - mae: 0.0387 - root_mean_squared_error: 0.0765 - val_loss: 0.0446 - val_mse: 0.0072 - val_mae: 0.0446 - val_root_mean_squared_error: 0.0847
# Epoch 165/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0411 - mse: 0.0068 - mae: 0.0411 - root_mean_squared_error: 0.082 - 0s 31us/sample - loss: 0.0387 - mse: 0.0059 - mae: 0.0387 - root_mean_squared_error: 0.0765 - val_loss: 0.0446 - val_mse: 0.0072 - val_mae: 0.0446 - val_root_mean_squared_error: 0.0847
# Epoch 166/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0387 - mse: 0.0059 - mae: 0.0387 - root_mean_squared_error: 0.0765 - val_loss: 0.0446 - val_mse: 0.0072 - val_mae: 0.0446 - val_root_mean_squared_error: 0.0846
# Epoch 167/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0386 - mse: 0.0059 - mae: 0.0386 - root_mean_squared_error: 0.0765 - val_loss: 0.0445 - val_mse: 0.0072 - val_mae: 0.0445 - val_root_mean_squared_error: 0.0847
# Epoch 168/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0386 - mse: 0.0059 - mae: 0.0386 - root_mean_squared_error: 0.0765 - val_loss: 0.0445 - val_mse: 0.0072 - val_mae: 0.0445 - val_root_mean_squared_error: 0.0846
# Epoch 169/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0386 - mse: 0.0059 - mae: 0.0386 - root_mean_squared_error: 0.0765 - val_loss: 0.0445 - val_mse: 0.0072 - val_mae: 0.0445 - val_root_mean_squared_error: 0.0847
# Epoch 170/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0386 - mse: 0.0059 - mae: 0.0386 - root_mean_squared_error: 0.0765 - val_loss: 0.0445 - val_mse: 0.0072 - val_mae: 0.0445 - val_root_mean_squared_error: 0.0847
# Epoch 171/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0386 - mse: 0.0059 - mae: 0.0386 - root_mean_squared_error: 0.0765 - val_loss: 0.0444 - val_mse: 0.0072 - val_mae: 0.0444 - val_root_mean_squared_error: 0.0846
# Epoch 172/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0386 - mse: 0.0059 - mae: 0.0386 - root_mean_squared_error: 0.0765 - val_loss: 0.0444 - val_mse: 0.0072 - val_mae: 0.0444 - val_root_mean_squared_error: 0.0846
# Epoch 173/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0385 - mse: 0.0059 - mae: 0.0385 - root_mean_squared_error: 0.0765 - val_loss: 0.0444 - val_mse: 0.0072 - val_mae: 0.0444 - val_root_mean_squared_error: 0.0846
# Epoch 174/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0385 - mse: 0.0059 - mae: 0.0385 - root_mean_squared_error: 0.0765 - val_loss: 0.0444 - val_mse: 0.0072 - val_mae: 0.0444 - val_root_mean_squared_error: 0.0846
# Epoch 175/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0385 - mse: 0.0059 - mae: 0.0385 - root_mean_squared_error: 0.0765 - val_loss: 0.0443 - val_mse: 0.0072 - val_mae: 0.0443 - val_root_mean_squared_error: 0.0846
# Epoch 176/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0385 - mse: 0.0059 - mae: 0.0385 - root_mean_squared_error: 0.0765 - val_loss: 0.0443 - val_mse: 0.0072 - val_mae: 0.0443 - val_root_mean_squared_error: 0.0846
# Epoch 177/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0385 - mse: 0.0059 - mae: 0.0385 - root_mean_squared_error: 0.0765 - val_loss: 0.0443 - val_mse: 0.0072 - val_mae: 0.0443 - val_root_mean_squared_error: 0.0846
# Epoch 178/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0385 - mse: 0.0059 - mae: 0.0385 - root_mean_squared_error: 0.0765 - val_loss: 0.0443 - val_mse: 0.0072 - val_mae: 0.0443 - val_root_mean_squared_error: 0.0846
# Epoch 179/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0385 - mse: 0.0059 - mae: 0.0385 - root_mean_squared_error: 0.0765 - val_loss: 0.0442 - val_mse: 0.0072 - val_mae: 0.0442 - val_root_mean_squared_error: 0.0846
# Epoch 180/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0385 - mse: 0.0058 - mae: 0.0385 - root_mean_squared_error: 0.0765 - val_loss: 0.0442 - val_mse: 0.0072 - val_mae: 0.0442 - val_root_mean_squared_error: 0.0846
# Epoch 181/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0384 - mse: 0.0058 - mae: 0.0384 - root_mean_squared_error: 0.0765 - val_loss: 0.0442 - val_mse: 0.0072 - val_mae: 0.0442 - val_root_mean_squared_error: 0.0846
# Epoch 182/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0384 - mse: 0.0058 - mae: 0.0384 - root_mean_squared_error: 0.0765 - val_loss: 0.0442 - val_mse: 0.0072 - val_mae: 0.0442 - val_root_mean_squared_error: 0.0846
# Epoch 183/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0384 - mse: 0.0058 - mae: 0.0384 - root_mean_squared_error: 0.0765 - val_loss: 0.0442 - val_mse: 0.0071 - val_mae: 0.0442 - val_root_mean_squared_error: 0.0846
# Epoch 184/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0384 - mse: 0.0058 - mae: 0.0384 - root_mean_squared_error: 0.0765 - val_loss: 0.0441 - val_mse: 0.0071 - val_mae: 0.0441 - val_root_mean_squared_error: 0.0845
# Epoch 185/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0384 - mse: 0.0058 - mae: 0.0384 - root_mean_squared_error: 0.0765 - val_loss: 0.0441 - val_mse: 0.0071 - val_mae: 0.0441 - val_root_mean_squared_error: 0.0845
# Epoch 186/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0384 - mse: 0.0058 - mae: 0.0384 - root_mean_squared_error: 0.0764 - val_loss: 0.0441 - val_mse: 0.0071 - val_mae: 0.0441 - val_root_mean_squared_error: 0.0845
# Epoch 187/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0384 - mse: 0.0058 - mae: 0.0384 - root_mean_squared_error: 0.0764 - val_loss: 0.0441 - val_mse: 0.0071 - val_mae: 0.0441 - val_root_mean_squared_error: 0.0845
# Epoch 188/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0384 - mse: 0.0058 - mae: 0.0384 - root_mean_squared_error: 0.0764 - val_loss: 0.0440 - val_mse: 0.0071 - val_mae: 0.0440 - val_root_mean_squared_error: 0.0845
# Epoch 189/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0384 - mse: 0.0058 - mae: 0.0384 - root_mean_squared_error: 0.0764 - val_loss: 0.0440 - val_mse: 0.0071 - val_mae: 0.0440 - val_root_mean_squared_error: 0.0845
# Epoch 190/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0383 - mse: 0.0058 - mae: 0.0383 - root_mean_squared_error: 0.0764 - val_loss: 0.0440 - val_mse: 0.0071 - val_mae: 0.0440 - val_root_mean_squared_error: 0.0844
# Epoch 191/500
# 3175/3175 [==============================] - 0s 40us/sample - loss: 0.0383 - mse: 0.0058 - mae: 0.0383 - root_mean_squared_error: 0.0764 - val_loss: 0.0440 - val_mse: 0.0071 - val_mae: 0.0440 - val_root_mean_squared_error: 0.0845
# Epoch 192/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0383 - mse: 0.0058 - mae: 0.0383 - root_mean_squared_error: 0.0764 - val_loss: 0.0439 - val_mse: 0.0071 - val_mae: 0.0439 - val_root_mean_squared_error: 0.0845
# Epoch 193/500
# ...
# Epoch 436/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0371 - mse: 0.0057 - mae: 0.0371 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 437/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0371 - mse: 0.0057 - mae: 0.0371 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 438/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0371 - mse: 0.0057 - mae: 0.0371 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 439/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0371 - mse: 0.0057 - mae: 0.0371 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 440/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0835
# Epoch 441/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0835
# Epoch 442/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0835
# Epoch 443/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0835
# Epoch 444/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 445/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 446/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 447/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 448/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0835
# Epoch 449/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0835
# Epoch 450/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0835
# Epoch 451/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0835
# Epoch 452/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 453/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 454/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 455/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0835
# Epoch 456/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0835
# Epoch 457/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0835
# Epoch 458/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 459/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 460/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 461/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 462/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0835
# Epoch 463/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0756 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0835
# Epoch 464/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 465/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 466/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 467/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 468/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0835
# Epoch 469/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0835
# Epoch 470/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0835
# Epoch 471/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0835
# Epoch 472/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0835
# Epoch 473/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 474/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 475/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0835
# Epoch 476/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0835
# Epoch 477/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 478/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 479/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 480/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0370 - mse: 0.0057 - mae: 0.0370 - root_mean_squared_error: 0.0755 - val_loss: 0.0420 - val_mse: 0.0070 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0836
# Epoch 481/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0419 - val_mse: 0.0070 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0835
# Epoch 482/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0419 - val_mse: 0.0070 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0835
# Epoch 483/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0419 - val_mse: 0.0070 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0835
# Epoch 484/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0419 - val_mse: 0.0070 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0835
# Epoch 485/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0419 - val_mse: 0.0070 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0835
# Epoch 486/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0419 - val_mse: 0.0070 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0835
# Epoch 487/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0419 - val_mse: 0.0070 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0835
# Epoch 488/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0419 - val_mse: 0.0070 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0836
# Epoch 489/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0419 - val_mse: 0.0070 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0836
# Epoch 490/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0419 - val_mse: 0.0070 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0836
# Epoch 491/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0419 - val_mse: 0.0070 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0836
# Epoch 492/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0419 - val_mse: 0.0070 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0835
# Epoch 493/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0419 - val_mse: 0.0070 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0835
# Epoch 494/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0419 - val_mse: 0.0070 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0835
# Epoch 495/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0419 - val_mse: 0.0070 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0835
# Epoch 496/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0419 - val_mse: 0.0070 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0835
# Epoch 497/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0419 - val_mse: 0.0070 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0835
# Epoch 498/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0419 - val_mse: 0.0070 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0835
# Epoch 499/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0419 - val_mse: 0.0070 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0835
# Epoch 500/500
# 3175/3175 [==============================] - 0s 40us/sample - loss: 0.0369 - mse: 0.0057 - mae: 0.0369 - root_mean_squared_error: 0.0755 - val_loss: 0.0419 - val_mse: 0.0070 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0835

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mae'],label='train mae')
pyplot.plot(history.history['val_mae'],label='val mae')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mse'],label='train mse')
pyplot.plot(history.history['val_mse'],label='val mse')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['root_mean_squared_error'],label='train rmse')
pyplot.plot(history.history['val_root_mean_squared_error'],label='val rmse')
pyplot.legend()
pyplot.show()
# Out:
# The testing MAE loss is: 0.039370604
# The testing MSE loss is: 0.006319939
# The testing RMSE loss is: 0.079498045

# %%
pyplot.plot(test_y[:,3],color='red', label='True Values')
pyplot.plot(out[:,3],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()

# %%
dataset_test=pd.read_excel('F:\MS thesis data/Hopper Crossing.xlsx')
dataset_test=dataset_test.drop(['Date/Time','Flowd'],axis=1)
dataset_test.dropna(inplace=True)

# %%
shape=np.shape(dataset_test)
print(shape)
pyplot.plot(dataset_test)
# Out:
# (26285, 3)
# [<matplotlib.lines.Line2D at 0x241815cec48>,
#  <matplotlib.lines.Line2D at 0x241815ceec8>,
#  <matplotlib.lines.Line2D at 0x241815cf1c8>]

# %%
dataset_test
# Out:
#        Cumulative rainfall   Flow  Level
# 0                      0.0  0.093    1.50
# 1                      0.0  0.093    1.50
# 2                      0.0  0.093    1.50
# 3                      0.0  0.093    1.50
# 4                      0.0  0.093    1.50
# ...                    ...    ...     ...
# 26280                  0.2  0.080    1.49
# 26281                  0.2  0.080    1.49
# 26282                  0.2  0.080    1.49
# 26283                  0.2  0.080    1.49
# 26284                  0.2  0.080    1.49
#
# [26285 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset_test)))
# Out:
# The std of original data is Cumulative rainfall    2.451640
# Flow                   0.520832
# Level                  0.083204
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset_test=dataset_test.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset_test.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset_test[:,0]== maxi[0])
    ind2=np.argwhere(dataset_test[:,1]== maxi[1])
    ind3=np.argwhere(dataset_test[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset_test.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset_test[:,0]== mini[0])
    ind2=np.argwhere(dataset_test[:,1]== mini[1])
    ind3=np.argwhere(dataset_test[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset_test)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset_test = min_max_scaler.fit_transform(dataset_test)
# Out:
# The std of cleaned data is 1.5154548293543502

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=4
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values

#one hour
#test_X, test_y = values[:, :-out_hour], values[:,-1]


test_X, test_y = values[:, :-out_hour], values[:, -out_hour: ]


test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6342, 30)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var1(t-2)  var2(t-2)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.230769   0.524545
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.215385   0.524545
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.123077   0.549980
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.092308   0.603309
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.092308   0.650485
#
#     var3(t-2)  var1(t-1)  var2(t-1)  var3(t-1)   var3(t)  var3(t+1)  \
# 6    0.776699   0.215385   0.524545   0.776699  0.791262   0.820388
# 7    0.776699   0.123077   0.549980   0.791262  0.820388   0.844660
# 8    0.791262   0.092308   0.603309   0.820388  0.844660   0.873786
# 9    0.820388   0.092308   0.650485   0.844660  0.873786   0.898058
# 10   0.844660   0.092308   0.709285   0.873786  0.898058   0.932039
#
#     var3(t+2)  var3(t+3)
# 6    0.844660   0.873786
# 7    0.873786   0.898058
# 8    0.898058   0.932039
# 9    0.932039   0.966019
# 10   0.966019   1.000000
#
# [5 rows x 22 columns]

# %%
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
# Out:
# The testing MAE loss is: 0.038704682
# The testing MSE loss is: 0.0061770156
# The testing RMSE loss is: 0.07859399

# %%
pyplot.plot(test_y[:,3],color='red', label='True Values')
pyplot.plot(out[:,3],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()
