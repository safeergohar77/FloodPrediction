# %%
import pandas as pd
from pandas import concat
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from sklearn import preprocessing
from tensorflow.keras import backend as K
#from sklearn.preprocessing import MinMaxScaler
#from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input, Dense, LSTM,GRU,SimpleRNN, Activation
from matplotlib import pyplot
#from sklearn.model_selection import train_test_split

# %%
"# convert series to supervised learning\n" 
#windowing of data
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1),
    for i in range(n_in, 0, -1): #startes from n_in and decreses to 0 by decreasing each time -1
     cols.append(df.shift(i))
     names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
     cols.append(df.shift(-i))
     if i == 0:
       names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
     else:
       names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together\n",
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values\n",
    if dropnan:
      agg.dropna(inplace=True)
    return agg

# %%
#def root_mean_squared_error(y_true, y_pred):
 #       return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
dataset1=pd.read_excel('F:\MS thesis data/Brooklyn.xlsx')
dataset1=dataset1.drop(['Date/Time','Flowd'],axis=1)
dataset1.dropna(inplace=True)

# %%
shape=np.shape(dataset1)
print(shape)
pyplot.plot(dataset1)
# Out:
# (26302, 3)
# [<matplotlib.lines.Line2D at 0x1be72163348>,
#  <matplotlib.lines.Line2D at 0x1be72165808>,
#  <matplotlib.lines.Line2D at 0x1be72156fc8>]

# %%
dataset1
# Out:
#        Cumulative rainfall    Flow  Level
# 0                       0.0  0.172   0.352
# 1                       0.0  0.180   0.356
# 2                       0.0  0.180   0.356
# 3                       0.0  0.189   0.360
# 4                       0.0  0.189   0.360
# ...                     ...    ...     ...
# 26297                   0.0  0.025   0.232
# 26298                   0.0  0.023   0.228
# 26299                   0.0  0.023   0.228
# 26300                   0.0  0.023   0.228
# 26301                   0.0  0.023   0.228
#
# [26302 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset1)))
# Out:
# The std of original data is Cumulative rainfall     2.872616
# Flow                    1.306642
# Level                   0.147238
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset=dataset1.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset[:,0]== maxi[0])
    ind2=np.argwhere(dataset[:,1]== maxi[1])
    ind3=np.argwhere(dataset[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset[:,0]== mini[0])
    ind2=np.argwhere(dataset[:,1]== mini[1])
    ind3=np.argwhere(dataset[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset = min_max_scaler.fit_transform(dataset)
# Out:
# The std of cleaned data is 1.626639593959813

# %%
pyplot.plot(dataset)
# Out:
# [<matplotlib.lines.Line2D at 0x1be719a3308>,
#  <matplotlib.lines.Line2D at 0x1be7176f348>,
#  <matplotlib.lines.Line2D at 0x1be7176f508>]

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=8
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values
train_size  = int(len(dataset) * 0.50)
val_size=int(len(dataset) * 0.75)
train_X, train_y = values[0:train_size, :-out_hour], values[0:train_size,-out_hour: ]
val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-out_hour: ]
test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-out_hour:]
#for last hour
#train_X, train_y = values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]  #for only last hour
#val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]
#test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-1]
print(train_X, train_y)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6338, 42)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var2(t-1)  var3(t-1)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.524545   0.776699
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.549980   0.791262
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.603309   0.820388
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.650485   0.844660
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.709285   0.873786
#
#      var3(t)  var3(t+1)  var3(t+2)  var3(t+3)  var3(t+4)  var3(t+5)  \
# 6   0.791262   0.820388   0.844660   0.873786   0.898058   0.932039
# 7   0.820388   0.844660   0.873786   0.898058   0.932039   0.966019
# 8   0.844660   0.873786   0.898058   0.932039   0.966019   1.000000
# 9   0.873786   0.898058   0.932039   0.966019   1.000000   0.941748
# 10  0.898058   0.932039   0.966019   1.000000   0.941748   0.912621
#
#     var3(t+6)  var3(t+7)
# 6    0.966019   1.000000
# 7    1.000000   0.941748
# 8    0.941748   0.912621
# 9    0.912621   0.800971
# 10   0.800971   0.723301
#
# [5 rows x 26 columns]
# [[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]
#  [0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]
#  [0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]
#  ...
#  [0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]
#  [0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]
#  [0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]] [[0.79126215 0.8203884  0.8446602  ... 0.93203884 0.9660194  1.        ]
#  [0.8203884  0.8446602  0.8737864  ... 0.9660194  1.         0.94174755]
#  [0.8446602  0.8737864  0.89805824 ... 1.         0.94174755 0.9126214 ]
#  ...
#  [0.23786408 0.24271844 0.24757281 ... 0.2184466  0.23300971 0.24271844]
#  [0.24271844 0.24757281 0.24757281 ... 0.23300971 0.24271844 0.25728154]
#  [0.24757281 0.24757281 0.24757281 ... 0.24271844 0.25728154 0.27184466]]

# %%
print(train_X, train_y)
# Out:
# [[[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]]
#
#  [[0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]]
#
#  [[0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]]
#
#  ...
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]]] [[0.79126215 0.8203884  0.8446602  ... 0.93203884 0.9660194  1.        ]
#  [0.8203884  0.8446602  0.8737864  ... 0.9660194  1.         0.94174755]
#  [0.8446602  0.8737864  0.89805824 ... 1.         0.94174755 0.9126214 ]
#  ...
#  [0.23786408 0.24271844 0.24757281 ... 0.2184466  0.23300971 0.24271844]
#  [0.24271844 0.24757281 0.24757281 ... 0.23300971 0.24271844 0.25728154]
#  [0.24757281 0.24757281 0.24757281 ... 0.24271844 0.25728154 0.27184466]]

# %%
print(train_X.shape, train_y.shape, val_X.shape, val_y.shape)
# Out:
# (3175, 1, 18) (3175, 8) (1588, 1, 18) (1588, 8)

# %%
randomState = 46
np.random.seed(randomState)
#tensorflow.random.set_random_seed(randomState)
tensorflow.random.set_seed(randomState)
model = Sequential()
model.add(GRU(15,input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dense(22))
#model.add(Activation('relu'))    
model.add(Dense(out_hour,activation = "sigmoid"))
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.001)
#    opt=tensorflow.keras.optimizers.Adam(learning_rate=0.00075)
model.compile(loss='mae', optimizer=opt,metrics=['mse','mae',tensorflow.keras.metrics.RootMeanSquaredError()])
history = model.fit(train_X, train_y,validation_data=(val_X, val_y), epochs=500, batch_size=100,verbose=1,shuffle=False)
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)
# Out:
# Train on 3175 samples, validate on 1588 samples
# Epoch 1/500
# 3175/3175 [==============================] - 3s 865us/sample - loss: 0.2548 - mse: 0.0778 - mae: 0.2548 - root_mean_squared_error: 0.2789 - val_loss: 0.2648 - val_mse: 0.0866 - val_mae: 0.2648 - val_root_mean_squared_error: 0.2943
# Epoch 2/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.2313 - mse: 0.0659 - mae: 0.2313 - root_mean_squared_error: 0.2568 - val_loss: 0.2404 - val_mse: 0.0727 - val_mae: 0.2404 - val_root_mean_squared_error: 0.2697
# Epoch 3/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.2066 - mse: 0.0552 - mae: 0.2066 - root_mean_squared_error: 0.2350 - val_loss: 0.2151 - val_mse: 0.0603 - val_mae: 0.2151 - val_root_mean_squared_error: 0.2455
# Epoch 4/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.1842 - mse: 0.0474 - mae: 0.1842 - root_mean_squared_error: 0.2177 - val_loss: 0.1937 - val_mse: 0.0512 - val_mae: 0.1937 - val_root_mean_squared_error: 0.2262
# Epoch 5/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1673 - mse: 0.0426 - mae: 0.1673 - root_mean_squared_error: 0.2064 - val_loss: 0.1776 - val_mse: 0.0450 - val_mae: 0.1776 - val_root_mean_squared_error: 0.2121
# Epoch 6/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.1549 - mse: 0.0393 - mae: 0.1549 - root_mean_squared_error: 0.1981 - val_loss: 0.1652 - val_mse: 0.0404 - val_mae: 0.1652 - val_root_mean_squared_error: 0.2009
# Epoch 7/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.1449 - mse: 0.0361 - mae: 0.1449 - root_mean_squared_error: 0.1901 - val_loss: 0.1547 - val_mse: 0.0363 - val_mae: 0.1547 - val_root_mean_squared_error: 0.1905
# Epoch 8/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.1357 - mse: 0.0328 - mae: 0.1357 - root_mean_squared_error: 0.1812 - val_loss: 0.1449 - val_mse: 0.0325 - val_mae: 0.1449 - val_root_mean_squared_error: 0.1803
# Epoch 9/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.1271 - mse: 0.0294 - mae: 0.1271 - root_mean_squared_error: 0.1716 - val_loss: 0.1359 - val_mse: 0.0291 - val_mae: 0.1359 - val_root_mean_squared_error: 0.1705
# Epoch 10/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.1194 - mse: 0.0263 - mae: 0.1194 - root_mean_squared_error: 0.1622 - val_loss: 0.1278 - val_mse: 0.0261 - val_mae: 0.1278 - val_root_mean_squared_error: 0.1616
# Epoch 11/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1126 - mse: 0.0236 - mae: 0.1126 - root_mean_squared_error: 0.1537 - val_loss: 0.1207 - val_mse: 0.0237 - val_mae: 0.1207 - val_root_mean_squared_error: 0.1539
# Epoch 12/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.1068 - mse: 0.0214 - mae: 0.1068 - root_mean_squared_error: 0.1464 - val_loss: 0.1146 - val_mse: 0.0217 - val_mae: 0.1146 - val_root_mean_squared_error: 0.1475
# Epoch 13/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.1018 - mse: 0.0197 - mae: 0.1018 - root_mean_squared_error: 0.1404 - val_loss: 0.1093 - val_mse: 0.0202 - val_mae: 0.1093 - val_root_mean_squared_error: 0.1422
# Epoch 14/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0975 - mse: 0.0184 - mae: 0.0975 - root_mean_squared_error: 0.1356 - val_loss: 0.1047 - val_mse: 0.0190 - val_mae: 0.1047 - val_root_mean_squared_error: 0.1379
# Epoch 15/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0938 - mse: 0.0173 - mae: 0.0938 - root_mean_squared_error: 0.1317 - val_loss: 0.1007 - val_mse: 0.0180 - val_mae: 0.1007 - val_root_mean_squared_error: 0.1343
# Epoch 16/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0968 - mse: 0.0185 - mae: 0.0968 - root_mean_squared_error: 0.135 - 0s 28us/sample - loss: 0.0906 - mse: 0.0165 - mae: 0.0906 - root_mean_squared_error: 0.1285 - val_loss: 0.0971 - val_mse: 0.0172 - val_mae: 0.0971 - val_root_mean_squared_error: 0.1313
# Epoch 17/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0876 - mse: 0.0158 - mae: 0.0876 - root_mean_squared_error: 0.1258 - val_loss: 0.0939 - val_mse: 0.0166 - val_mae: 0.0939 - val_root_mean_squared_error: 0.1288
# Epoch 18/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0850 - mse: 0.0153 - mae: 0.0850 - root_mean_squared_error: 0.1236 - val_loss: 0.0909 - val_mse: 0.0160 - val_mae: 0.0909 - val_root_mean_squared_error: 0.1267
# Epoch 19/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0827 - mse: 0.0148 - mae: 0.0827 - root_mean_squared_error: 0.1217 - val_loss: 0.0883 - val_mse: 0.0156 - val_mae: 0.0883 - val_root_mean_squared_error: 0.1248
# Epoch 20/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0806 - mse: 0.0144 - mae: 0.0806 - root_mean_squared_error: 0.1201 - val_loss: 0.0859 - val_mse: 0.0152 - val_mae: 0.0859 - val_root_mean_squared_error: 0.1232
# Epoch 21/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0788 - mse: 0.0141 - mae: 0.0788 - root_mean_squared_error: 0.1188 - val_loss: 0.0838 - val_mse: 0.0149 - val_mae: 0.0838 - val_root_mean_squared_error: 0.1219
# Epoch 22/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0771 - mse: 0.0138 - mae: 0.0771 - root_mean_squared_error: 0.1176 - val_loss: 0.0819 - val_mse: 0.0146 - val_mae: 0.0819 - val_root_mean_squared_error: 0.1206
# Epoch 23/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0756 - mse: 0.0136 - mae: 0.0756 - root_mean_squared_error: 0.1167 - val_loss: 0.0802 - val_mse: 0.0143 - val_mae: 0.0802 - val_root_mean_squared_error: 0.1195
# Epoch 24/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0744 - mse: 0.0134 - mae: 0.0744 - root_mean_squared_error: 0.1158 - val_loss: 0.0788 - val_mse: 0.0140 - val_mae: 0.0788 - val_root_mean_squared_error: 0.1185
# Epoch 25/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0733 - mse: 0.0132 - mae: 0.0733 - root_mean_squared_error: 0.1150 - val_loss: 0.0775 - val_mse: 0.0138 - val_mae: 0.0775 - val_root_mean_squared_error: 0.1176
# Epoch 26/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0723 - mse: 0.0130 - mae: 0.0723 - root_mean_squared_error: 0.1142 - val_loss: 0.0764 - val_mse: 0.0136 - val_mae: 0.0764 - val_root_mean_squared_error: 0.1167
# Epoch 27/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0714 - mse: 0.0129 - mae: 0.0714 - root_mean_squared_error: 0.1135 - val_loss: 0.0753 - val_mse: 0.0134 - val_mae: 0.0753 - val_root_mean_squared_error: 0.1159
# Epoch 28/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0706 - mse: 0.0127 - mae: 0.0706 - root_mean_squared_error: 0.1128 - val_loss: 0.0744 - val_mse: 0.0133 - val_mae: 0.0744 - val_root_mean_squared_error: 0.1152
# Epoch 29/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0699 - mse: 0.0126 - mae: 0.0699 - root_mean_squared_error: 0.1122 - val_loss: 0.0736 - val_mse: 0.0131 - val_mae: 0.0736 - val_root_mean_squared_error: 0.1145
# Epoch 30/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0692 - mse: 0.0125 - mae: 0.0692 - root_mean_squared_error: 0.1116 - val_loss: 0.0728 - val_mse: 0.0130 - val_mae: 0.0728 - val_root_mean_squared_error: 0.1139
# Epoch 31/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0686 - mse: 0.0123 - mae: 0.0686 - root_mean_squared_error: 0.1111 - val_loss: 0.0721 - val_mse: 0.0129 - val_mae: 0.0721 - val_root_mean_squared_error: 0.1134
# Epoch 32/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0680 - mse: 0.0122 - mae: 0.0680 - root_mean_squared_error: 0.1105 - val_loss: 0.0715 - val_mse: 0.0127 - val_mae: 0.0715 - val_root_mean_squared_error: 0.1129
# Epoch 33/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0675 - mse: 0.0121 - mae: 0.0675 - root_mean_squared_error: 0.1100 - val_loss: 0.0710 - val_mse: 0.0126 - val_mae: 0.0710 - val_root_mean_squared_error: 0.1124
# Epoch 34/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0670 - mse: 0.0120 - mae: 0.0670 - root_mean_squared_error: 0.1096 - val_loss: 0.0705 - val_mse: 0.0125 - val_mae: 0.0705 - val_root_mean_squared_error: 0.1120
# Epoch 35/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0665 - mse: 0.0119 - mae: 0.0665 - root_mean_squared_error: 0.1092 - val_loss: 0.0700 - val_mse: 0.0124 - val_mae: 0.0700 - val_root_mean_squared_error: 0.1116
# Epoch 36/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0661 - mse: 0.0118 - mae: 0.0661 - root_mean_squared_error: 0.1087 - val_loss: 0.0696 - val_mse: 0.0124 - val_mae: 0.0696 - val_root_mean_squared_error: 0.1112
# Epoch 37/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0658 - mse: 0.0117 - mae: 0.0658 - root_mean_squared_error: 0.1083 - val_loss: 0.0692 - val_mse: 0.0123 - val_mae: 0.0692 - val_root_mean_squared_error: 0.1108
# Epoch 38/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0654 - mse: 0.0117 - mae: 0.0654 - root_mean_squared_error: 0.1079 - val_loss: 0.0688 - val_mse: 0.0122 - val_mae: 0.0688 - val_root_mean_squared_error: 0.1105
# Epoch 39/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0651 - mse: 0.0116 - mae: 0.0651 - root_mean_squared_error: 0.1076 - val_loss: 0.0685 - val_mse: 0.0121 - val_mae: 0.0685 - val_root_mean_squared_error: 0.1102
# Epoch 40/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0648 - mse: 0.0115 - mae: 0.0648 - root_mean_squared_error: 0.1073 - val_loss: 0.0682 - val_mse: 0.0121 - val_mae: 0.0682 - val_root_mean_squared_error: 0.1099
# Epoch 41/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0645 - mse: 0.0114 - mae: 0.0645 - root_mean_squared_error: 0.1070 - val_loss: 0.0679 - val_mse: 0.0120 - val_mae: 0.0679 - val_root_mean_squared_error: 0.1097
# Epoch 42/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0643 - mse: 0.0114 - mae: 0.0643 - root_mean_squared_error: 0.1067 - val_loss: 0.0676 - val_mse: 0.0120 - val_mae: 0.0676 - val_root_mean_squared_error: 0.1095
# Epoch 43/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0640 - mse: 0.0113 - mae: 0.0640 - root_mean_squared_error: 0.1064 - val_loss: 0.0674 - val_mse: 0.0119 - val_mae: 0.0674 - val_root_mean_squared_error: 0.1092
# Epoch 44/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0638 - mse: 0.0113 - mae: 0.0638 - root_mean_squared_error: 0.1062 - val_loss: 0.0672 - val_mse: 0.0119 - val_mae: 0.0672 - val_root_mean_squared_error: 0.1090
# Epoch 45/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0636 - mse: 0.0112 - mae: 0.0636 - root_mean_squared_error: 0.1059 - val_loss: 0.0670 - val_mse: 0.0118 - val_mae: 0.0670 - val_root_mean_squared_error: 0.1088
# Epoch 46/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0634 - mse: 0.0112 - mae: 0.0634 - root_mean_squared_error: 0.1057 - val_loss: 0.0668 - val_mse: 0.0118 - val_mae: 0.0668 - val_root_mean_squared_error: 0.1087
# Epoch 47/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0632 - mse: 0.0111 - mae: 0.0632 - root_mean_squared_error: 0.1055 - val_loss: 0.0666 - val_mse: 0.0118 - val_mae: 0.0666 - val_root_mean_squared_error: 0.1085
# Epoch 48/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0630 - mse: 0.0111 - mae: 0.0630 - root_mean_squared_error: 0.1053 - val_loss: 0.0664 - val_mse: 0.0117 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1083
# Epoch 49/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0665 - mse: 0.0123 - mae: 0.0665 - root_mean_squared_error: 0.111 - 0s 29us/sample - loss: 0.0628 - mse: 0.0110 - mae: 0.0628 - root_mean_squared_error: 0.1050 - val_loss: 0.0662 - val_mse: 0.0117 - val_mae: 0.0662 - val_root_mean_squared_error: 0.1081
# Epoch 50/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0626 - mse: 0.0110 - mae: 0.0626 - root_mean_squared_error: 0.1048 - val_loss: 0.0660 - val_mse: 0.0117 - val_mae: 0.0660 - val_root_mean_squared_error: 0.1080
# Epoch 51/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0625 - mse: 0.0110 - mae: 0.0625 - root_mean_squared_error: 0.1047 - val_loss: 0.0658 - val_mse: 0.0116 - val_mae: 0.0658 - val_root_mean_squared_error: 0.1078
# Epoch 52/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0623 - mse: 0.0109 - mae: 0.0623 - root_mean_squared_error: 0.1045 - val_loss: 0.0657 - val_mse: 0.0116 - val_mae: 0.0657 - val_root_mean_squared_error: 0.1077
# Epoch 53/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0621 - mse: 0.0109 - mae: 0.0621 - root_mean_squared_error: 0.1044 - val_loss: 0.0655 - val_mse: 0.0116 - val_mae: 0.0655 - val_root_mean_squared_error: 0.1076
# Epoch 54/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0620 - mse: 0.0109 - mae: 0.0620 - root_mean_squared_error: 0.1042 - val_loss: 0.0654 - val_mse: 0.0116 - val_mae: 0.0654 - val_root_mean_squared_error: 0.1075
# Epoch 55/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0618 - mse: 0.0108 - mae: 0.0618 - root_mean_squared_error: 0.1041 - val_loss: 0.0652 - val_mse: 0.0115 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1074
# Epoch 56/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0617 - mse: 0.0108 - mae: 0.0617 - root_mean_squared_error: 0.1040 - val_loss: 0.0651 - val_mse: 0.0115 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1073
# Epoch 57/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0615 - mse: 0.0108 - mae: 0.0615 - root_mean_squared_error: 0.1038 - val_loss: 0.0650 - val_mse: 0.0115 - val_mae: 0.0650 - val_root_mean_squared_error: 0.1072
# Epoch 58/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0614 - mse: 0.0108 - mae: 0.0614 - root_mean_squared_error: 0.1037 - val_loss: 0.0648 - val_mse: 0.0115 - val_mae: 0.0648 - val_root_mean_squared_error: 0.1071
# Epoch 59/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0613 - mse: 0.0107 - mae: 0.0613 - root_mean_squared_error: 0.1036 - val_loss: 0.0647 - val_mse: 0.0114 - val_mae: 0.0647 - val_root_mean_squared_error: 0.1070
# Epoch 60/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0611 - mse: 0.0107 - mae: 0.0611 - root_mean_squared_error: 0.1035 - val_loss: 0.0646 - val_mse: 0.0114 - val_mae: 0.0646 - val_root_mean_squared_error: 0.1069
# Epoch 61/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0610 - mse: 0.0107 - mae: 0.0610 - root_mean_squared_error: 0.1034 - val_loss: 0.0645 - val_mse: 0.0114 - val_mae: 0.0645 - val_root_mean_squared_error: 0.1068
# Epoch 62/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0609 - mse: 0.0107 - mae: 0.0609 - root_mean_squared_error: 0.1033 - val_loss: 0.0643 - val_mse: 0.0114 - val_mae: 0.0643 - val_root_mean_squared_error: 0.1067
# Epoch 63/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0608 - mse: 0.0106 - mae: 0.0608 - root_mean_squared_error: 0.1032 - val_loss: 0.0642 - val_mse: 0.0114 - val_mae: 0.0642 - val_root_mean_squared_error: 0.1067
# Epoch 64/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0606 - mse: 0.0106 - mae: 0.0606 - root_mean_squared_error: 0.1031 - val_loss: 0.0641 - val_mse: 0.0114 - val_mae: 0.0641 - val_root_mean_squared_error: 0.1066
# Epoch 65/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0605 - mse: 0.0106 - mae: 0.0605 - root_mean_squared_error: 0.1030 - val_loss: 0.0640 - val_mse: 0.0113 - val_mae: 0.0640 - val_root_mean_squared_error: 0.1065
# Epoch 66/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0604 - mse: 0.0106 - mae: 0.0604 - root_mean_squared_error: 0.1029 - val_loss: 0.0639 - val_mse: 0.0113 - val_mae: 0.0639 - val_root_mean_squared_error: 0.1064
# Epoch 67/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0603 - mse: 0.0106 - mae: 0.0603 - root_mean_squared_error: 0.1028 - val_loss: 0.0638 - val_mse: 0.0113 - val_mae: 0.0638 - val_root_mean_squared_error: 0.1064
# Epoch 68/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0602 - mse: 0.0106 - mae: 0.0602 - root_mean_squared_error: 0.1027 - val_loss: 0.0637 - val_mse: 0.0113 - val_mae: 0.0637 - val_root_mean_squared_error: 0.1063
# Epoch 69/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0601 - mse: 0.0105 - mae: 0.0601 - root_mean_squared_error: 0.1026 - val_loss: 0.0636 - val_mse: 0.0113 - val_mae: 0.0636 - val_root_mean_squared_error: 0.1062
# Epoch 70/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0600 - mse: 0.0105 - mae: 0.0600 - root_mean_squared_error: 0.1026 - val_loss: 0.0635 - val_mse: 0.0113 - val_mae: 0.0635 - val_root_mean_squared_error: 0.1062
# Epoch 71/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0599 - mse: 0.0105 - mae: 0.0599 - root_mean_squared_error: 0.1025 - val_loss: 0.0634 - val_mse: 0.0113 - val_mae: 0.0634 - val_root_mean_squared_error: 0.1061
# Epoch 72/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0598 - mse: 0.0105 - mae: 0.0598 - root_mean_squared_error: 0.1024 - val_loss: 0.0633 - val_mse: 0.0112 - val_mae: 0.0633 - val_root_mean_squared_error: 0.1060
# Epoch 73/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0597 - mse: 0.0105 - mae: 0.0597 - root_mean_squared_error: 0.1023 - val_loss: 0.0632 - val_mse: 0.0112 - val_mae: 0.0632 - val_root_mean_squared_error: 0.1060
# Epoch 74/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0596 - mse: 0.0105 - mae: 0.0596 - root_mean_squared_error: 0.1023 - val_loss: 0.0631 - val_mse: 0.0112 - val_mae: 0.0631 - val_root_mean_squared_error: 0.1059
# Epoch 75/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0595 - mse: 0.0104 - mae: 0.0595 - root_mean_squared_error: 0.1022 - val_loss: 0.0630 - val_mse: 0.0112 - val_mae: 0.0630 - val_root_mean_squared_error: 0.1059
# Epoch 76/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0594 - mse: 0.0104 - mae: 0.0594 - root_mean_squared_error: 0.1022 - val_loss: 0.0629 - val_mse: 0.0112 - val_mae: 0.0629 - val_root_mean_squared_error: 0.1058
# Epoch 77/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0593 - mse: 0.0104 - mae: 0.0593 - root_mean_squared_error: 0.1021 - val_loss: 0.0628 - val_mse: 0.0112 - val_mae: 0.0628 - val_root_mean_squared_error: 0.1058
# Epoch 78/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0593 - mse: 0.0104 - mae: 0.0593 - root_mean_squared_error: 0.1020 - val_loss: 0.0627 - val_mse: 0.0112 - val_mae: 0.0627 - val_root_mean_squared_error: 0.1057
# Epoch 79/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0592 - mse: 0.0104 - mae: 0.0592 - root_mean_squared_error: 0.1020 - val_loss: 0.0626 - val_mse: 0.0112 - val_mae: 0.0626 - val_root_mean_squared_error: 0.1057
# Epoch 80/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0591 - mse: 0.0104 - mae: 0.0591 - root_mean_squared_error: 0.1019 - val_loss: 0.0625 - val_mse: 0.0112 - val_mae: 0.0625 - val_root_mean_squared_error: 0.1056
# Epoch 81/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0590 - mse: 0.0104 - mae: 0.0590 - root_mean_squared_error: 0.1019 - val_loss: 0.0624 - val_mse: 0.0111 - val_mae: 0.0624 - val_root_mean_squared_error: 0.1056
# Epoch 82/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0590 - mse: 0.0104 - mae: 0.0590 - root_mean_squared_error: 0.1018 - val_loss: 0.0623 - val_mse: 0.0111 - val_mae: 0.0623 - val_root_mean_squared_error: 0.1055
# Epoch 83/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0589 - mse: 0.0104 - mae: 0.0589 - root_mean_squared_error: 0.1018 - val_loss: 0.0623 - val_mse: 0.0111 - val_mae: 0.0623 - val_root_mean_squared_error: 0.1055
# Epoch 84/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0588 - mse: 0.0103 - mae: 0.0588 - root_mean_squared_error: 0.1017 - val_loss: 0.0622 - val_mse: 0.0111 - val_mae: 0.0622 - val_root_mean_squared_error: 0.1054
# Epoch 85/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0587 - mse: 0.0103 - mae: 0.0587 - root_mean_squared_error: 0.1017 - val_loss: 0.0621 - val_mse: 0.0111 - val_mae: 0.0621 - val_root_mean_squared_error: 0.1054
# Epoch 86/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0587 - mse: 0.0103 - mae: 0.0587 - root_mean_squared_error: 0.1016 - val_loss: 0.0620 - val_mse: 0.0111 - val_mae: 0.0620 - val_root_mean_squared_error: 0.1053
# Epoch 87/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0586 - mse: 0.0103 - mae: 0.0586 - root_mean_squared_error: 0.1016 - val_loss: 0.0619 - val_mse: 0.0111 - val_mae: 0.0619 - val_root_mean_squared_error: 0.1053
# Epoch 88/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0585 - mse: 0.0103 - mae: 0.0585 - root_mean_squared_error: 0.1015 - val_loss: 0.0619 - val_mse: 0.0111 - val_mae: 0.0619 - val_root_mean_squared_error: 0.1053
# Epoch 89/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0585 - mse: 0.0103 - mae: 0.0585 - root_mean_squared_error: 0.1015 - val_loss: 0.0618 - val_mse: 0.0111 - val_mae: 0.0618 - val_root_mean_squared_error: 0.1052
# Epoch 90/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0584 - mse: 0.0103 - mae: 0.0584 - root_mean_squared_error: 0.1014 - val_loss: 0.0617 - val_mse: 0.0111 - val_mae: 0.0617 - val_root_mean_squared_error: 0.1052
# Epoch 91/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0583 - mse: 0.0103 - mae: 0.0583 - root_mean_squared_error: 0.1014 - val_loss: 0.0616 - val_mse: 0.0111 - val_mae: 0.0616 - val_root_mean_squared_error: 0.1051
# Epoch 92/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0583 - mse: 0.0103 - mae: 0.0583 - root_mean_squared_error: 0.1013 - val_loss: 0.0616 - val_mse: 0.0110 - val_mae: 0.0616 - val_root_mean_squared_error: 0.1051
# Epoch 93/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0582 - mse: 0.0103 - mae: 0.0582 - root_mean_squared_error: 0.1012 - val_loss: 0.0615 - val_mse: 0.0110 - val_mae: 0.0615 - val_root_mean_squared_error: 0.1050
# Epoch 94/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0581 - mse: 0.0102 - mae: 0.0581 - root_mean_squared_error: 0.1012 - val_loss: 0.0614 - val_mse: 0.0110 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1050
# Epoch 95/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0581 - mse: 0.0102 - mae: 0.0581 - root_mean_squared_error: 0.1011 - val_loss: 0.0613 - val_mse: 0.0110 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1049
# Epoch 96/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0580 - mse: 0.0102 - mae: 0.0580 - root_mean_squared_error: 0.1011 - val_loss: 0.0613 - val_mse: 0.0110 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1049
# Epoch 97/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0580 - mse: 0.0102 - mae: 0.0580 - root_mean_squared_error: 0.1010 - val_loss: 0.0612 - val_mse: 0.0110 - val_mae: 0.0612 - val_root_mean_squared_error: 0.1049
# Epoch 98/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0579 - mse: 0.0102 - mae: 0.0579 - root_mean_squared_error: 0.1010 - val_loss: 0.0611 - val_mse: 0.0110 - val_mae: 0.0611 - val_root_mean_squared_error: 0.1048
# Epoch 99/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0578 - mse: 0.0102 - mae: 0.0578 - root_mean_squared_error: 0.1009 - val_loss: 0.0611 - val_mse: 0.0110 - val_mae: 0.0611 - val_root_mean_squared_error: 0.1048
# Epoch 100/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0578 - mse: 0.0102 - mae: 0.0578 - root_mean_squared_error: 0.1009 - val_loss: 0.0610 - val_mse: 0.0110 - val_mae: 0.0610 - val_root_mean_squared_error: 0.1048
# Epoch 101/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0577 - mse: 0.0102 - mae: 0.0577 - root_mean_squared_error: 0.1008 - val_loss: 0.0610 - val_mse: 0.0110 - val_mae: 0.0610 - val_root_mean_squared_error: 0.1047
# Epoch 102/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0577 - mse: 0.0102 - mae: 0.0577 - root_mean_squared_error: 0.1008 - val_loss: 0.0609 - val_mse: 0.0110 - val_mae: 0.0609 - val_root_mean_squared_error: 0.1047
# Epoch 103/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0576 - mse: 0.0101 - mae: 0.0576 - root_mean_squared_error: 0.1007 - val_loss: 0.0609 - val_mse: 0.0110 - val_mae: 0.0609 - val_root_mean_squared_error: 0.1047
# Epoch 104/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0576 - mse: 0.0101 - mae: 0.0576 - root_mean_squared_error: 0.1007 - val_loss: 0.0608 - val_mse: 0.0109 - val_mae: 0.0608 - val_root_mean_squared_error: 0.1046
# Epoch 105/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0575 - mse: 0.0101 - mae: 0.0575 - root_mean_squared_error: 0.1006 - val_loss: 0.0607 - val_mse: 0.0109 - val_mae: 0.0607 - val_root_mean_squared_error: 0.1046
# Epoch 106/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0575 - mse: 0.0101 - mae: 0.0575 - root_mean_squared_error: 0.1006 - val_loss: 0.0607 - val_mse: 0.0109 - val_mae: 0.0607 - val_root_mean_squared_error: 0.1046
# Epoch 107/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0574 - mse: 0.0101 - mae: 0.0574 - root_mean_squared_error: 0.1005 - val_loss: 0.0606 - val_mse: 0.0109 - val_mae: 0.0606 - val_root_mean_squared_error: 0.1045
# Epoch 108/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0574 - mse: 0.0101 - mae: 0.0574 - root_mean_squared_error: 0.1005 - val_loss: 0.0606 - val_mse: 0.0109 - val_mae: 0.0606 - val_root_mean_squared_error: 0.1045
# Epoch 109/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0573 - mse: 0.0101 - mae: 0.0573 - root_mean_squared_error: 0.1004 - val_loss: 0.0605 - val_mse: 0.0109 - val_mae: 0.0605 - val_root_mean_squared_error: 0.1045
# Epoch 110/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0573 - mse: 0.0101 - mae: 0.0573 - root_mean_squared_error: 0.1004 - val_loss: 0.0605 - val_mse: 0.0109 - val_mae: 0.0605 - val_root_mean_squared_error: 0.1044
# Epoch 111/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0572 - mse: 0.0101 - mae: 0.0572 - root_mean_squared_error: 0.1003 - val_loss: 0.0604 - val_mse: 0.0109 - val_mae: 0.0604 - val_root_mean_squared_error: 0.1044
# Epoch 112/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0572 - mse: 0.0101 - mae: 0.0572 - root_mean_squared_error: 0.1003 - val_loss: 0.0604 - val_mse: 0.0109 - val_mae: 0.0604 - val_root_mean_squared_error: 0.1044
# Epoch 113/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0571 - mse: 0.0100 - mae: 0.0571 - root_mean_squared_error: 0.1002 - val_loss: 0.0603 - val_mse: 0.0109 - val_mae: 0.0603 - val_root_mean_squared_error: 0.1043
# Epoch 114/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0571 - mse: 0.0100 - mae: 0.0571 - root_mean_squared_error: 0.1002 - val_loss: 0.0603 - val_mse: 0.0109 - val_mae: 0.0603 - val_root_mean_squared_error: 0.1043
# Epoch 115/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0570 - mse: 0.0100 - mae: 0.0570 - root_mean_squared_error: 0.1001 - val_loss: 0.0602 - val_mse: 0.0109 - val_mae: 0.0602 - val_root_mean_squared_error: 0.1043
# Epoch 116/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0570 - mse: 0.0100 - mae: 0.0570 - root_mean_squared_error: 0.1001 - val_loss: 0.0601 - val_mse: 0.0109 - val_mae: 0.0601 - val_root_mean_squared_error: 0.1042
# Epoch 117/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0569 - mse: 0.0100 - mae: 0.0569 - root_mean_squared_error: 0.1000 - val_loss: 0.0601 - val_mse: 0.0109 - val_mae: 0.0601 - val_root_mean_squared_error: 0.1042
# Epoch 118/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0569 - mse: 0.0100 - mae: 0.0569 - root_mean_squared_error: 0.1000 - val_loss: 0.0601 - val_mse: 0.0109 - val_mae: 0.0601 - val_root_mean_squared_error: 0.1042
# Epoch 119/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0568 - mse: 0.0100 - mae: 0.0568 - root_mean_squared_error: 0.0999 - val_loss: 0.0600 - val_mse: 0.0108 - val_mae: 0.0600 - val_root_mean_squared_error: 0.1041
# Epoch 120/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0568 - mse: 0.0100 - mae: 0.0568 - root_mean_squared_error: 0.0999 - val_loss: 0.0600 - val_mse: 0.0108 - val_mae: 0.0600 - val_root_mean_squared_error: 0.1041
# Epoch 121/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0567 - mse: 0.0100 - mae: 0.0567 - root_mean_squared_error: 0.0998 - val_loss: 0.0599 - val_mse: 0.0108 - val_mae: 0.0599 - val_root_mean_squared_error: 0.1041
# Epoch 122/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0567 - mse: 0.0100 - mae: 0.0567 - root_mean_squared_error: 0.0998 - val_loss: 0.0599 - val_mse: 0.0108 - val_mae: 0.0599 - val_root_mean_squared_error: 0.1040
# Epoch 123/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0567 - mse: 0.0099 - mae: 0.0567 - root_mean_squared_error: 0.0997 - val_loss: 0.0598 - val_mse: 0.0108 - val_mae: 0.0598 - val_root_mean_squared_error: 0.1040
# Epoch 124/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0566 - mse: 0.0099 - mae: 0.0566 - root_mean_squared_error: 0.0997 - val_loss: 0.0598 - val_mse: 0.0108 - val_mae: 0.0598 - val_root_mean_squared_error: 0.1039
# Epoch 125/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0566 - mse: 0.0099 - mae: 0.0566 - root_mean_squared_error: 0.0996 - val_loss: 0.0597 - val_mse: 0.0108 - val_mae: 0.0597 - val_root_mean_squared_error: 0.1039
# Epoch 126/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0565 - mse: 0.0099 - mae: 0.0565 - root_mean_squared_error: 0.0996 - val_loss: 0.0597 - val_mse: 0.0108 - val_mae: 0.0597 - val_root_mean_squared_error: 0.1039
# Epoch 127/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0565 - mse: 0.0099 - mae: 0.0565 - root_mean_squared_error: 0.0995 - val_loss: 0.0596 - val_mse: 0.0108 - val_mae: 0.0596 - val_root_mean_squared_error: 0.1038
# Epoch 128/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0565 - mse: 0.0099 - mae: 0.0565 - root_mean_squared_error: 0.0995 - val_loss: 0.0596 - val_mse: 0.0108 - val_mae: 0.0596 - val_root_mean_squared_error: 0.1038
# Epoch 129/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0564 - mse: 0.0099 - mae: 0.0564 - root_mean_squared_error: 0.0994 - val_loss: 0.0595 - val_mse: 0.0108 - val_mae: 0.0595 - val_root_mean_squared_error: 0.1038
# Epoch 130/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0564 - mse: 0.0099 - mae: 0.0564 - root_mean_squared_error: 0.0994 - val_loss: 0.0595 - val_mse: 0.0108 - val_mae: 0.0595 - val_root_mean_squared_error: 0.1037
# Epoch 131/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0563 - mse: 0.0099 - mae: 0.0563 - root_mean_squared_error: 0.0993 - val_loss: 0.0595 - val_mse: 0.0108 - val_mae: 0.0595 - val_root_mean_squared_error: 0.1037
# Epoch 132/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0563 - mse: 0.0099 - mae: 0.0563 - root_mean_squared_error: 0.0993 - val_loss: 0.0594 - val_mse: 0.0108 - val_mae: 0.0594 - val_root_mean_squared_error: 0.1037
# Epoch 133/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0575 - mse: 0.0104 - mae: 0.0575 - root_mean_squared_error: 0.101 - 0s 30us/sample - loss: 0.0563 - mse: 0.0098 - mae: 0.0563 - root_mean_squared_error: 0.0992 - val_loss: 0.0594 - val_mse: 0.0107 - val_mae: 0.0594 - val_root_mean_squared_error: 0.1037
# Epoch 134/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0562 - mse: 0.0098 - mae: 0.0562 - root_mean_squared_error: 0.0991 - val_loss: 0.0593 - val_mse: 0.0107 - val_mae: 0.0593 - val_root_mean_squared_error: 0.1036
# Epoch 135/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0562 - mse: 0.0098 - mae: 0.0562 - root_mean_squared_error: 0.0991 - val_loss: 0.0593 - val_mse: 0.0107 - val_mae: 0.0593 - val_root_mean_squared_error: 0.1036
# Epoch 136/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0562 - mse: 0.0098 - mae: 0.0562 - root_mean_squared_error: 0.0990 - val_loss: 0.0592 - val_mse: 0.0107 - val_mae: 0.0592 - val_root_mean_squared_error: 0.1035
# Epoch 137/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0561 - mse: 0.0098 - mae: 0.0561 - root_mean_squared_error: 0.0990 - val_loss: 0.0592 - val_mse: 0.0107 - val_mae: 0.0592 - val_root_mean_squared_error: 0.1035
# Epoch 138/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0561 - mse: 0.0098 - mae: 0.0561 - root_mean_squared_error: 0.0989 - val_loss: 0.0592 - val_mse: 0.0107 - val_mae: 0.0592 - val_root_mean_squared_error: 0.1035
# Epoch 139/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0561 - mse: 0.0098 - mae: 0.0561 - root_mean_squared_error: 0.0989 - val_loss: 0.0591 - val_mse: 0.0107 - val_mae: 0.0591 - val_root_mean_squared_error: 0.1035
# Epoch 140/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0560 - mse: 0.0098 - mae: 0.0560 - root_mean_squared_error: 0.0989 - val_loss: 0.0591 - val_mse: 0.0107 - val_mae: 0.0591 - val_root_mean_squared_error: 0.1034
# Epoch 141/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0560 - mse: 0.0098 - mae: 0.0560 - root_mean_squared_error: 0.0988 - val_loss: 0.0591 - val_mse: 0.0107 - val_mae: 0.0591 - val_root_mean_squared_error: 0.1034
# Epoch 142/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0560 - mse: 0.0098 - mae: 0.0560 - root_mean_squared_error: 0.0988 - val_loss: 0.0590 - val_mse: 0.0107 - val_mae: 0.0590 - val_root_mean_squared_error: 0.1034
# Epoch 143/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0559 - mse: 0.0098 - mae: 0.0559 - root_mean_squared_error: 0.0987 - val_loss: 0.0590 - val_mse: 0.0107 - val_mae: 0.0590 - val_root_mean_squared_error: 0.1034
# Epoch 144/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0559 - mse: 0.0097 - mae: 0.0559 - root_mean_squared_error: 0.0987 - val_loss: 0.0590 - val_mse: 0.0107 - val_mae: 0.0590 - val_root_mean_squared_error: 0.1034
# Epoch 145/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0559 - mse: 0.0097 - mae: 0.0559 - root_mean_squared_error: 0.0987 - val_loss: 0.0589 - val_mse: 0.0107 - val_mae: 0.0589 - val_root_mean_squared_error: 0.1034
# Epoch 146/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0558 - mse: 0.0097 - mae: 0.0558 - root_mean_squared_error: 0.0986 - val_loss: 0.0589 - val_mse: 0.0107 - val_mae: 0.0589 - val_root_mean_squared_error: 0.1034
# Epoch 147/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0558 - mse: 0.0097 - mae: 0.0558 - root_mean_squared_error: 0.0986 - val_loss: 0.0589 - val_mse: 0.0107 - val_mae: 0.0589 - val_root_mean_squared_error: 0.1033
# Epoch 148/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0558 - mse: 0.0097 - mae: 0.0558 - root_mean_squared_error: 0.0986 - val_loss: 0.0588 - val_mse: 0.0107 - val_mae: 0.0588 - val_root_mean_squared_error: 0.1033
# Epoch 149/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0557 - mse: 0.0097 - mae: 0.0557 - root_mean_squared_error: 0.0985 - val_loss: 0.0588 - val_mse: 0.0107 - val_mae: 0.0588 - val_root_mean_squared_error: 0.1033
# Epoch 150/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0557 - mse: 0.0097 - mae: 0.0557 - root_mean_squared_error: 0.0985 - val_loss: 0.0588 - val_mse: 0.0107 - val_mae: 0.0588 - val_root_mean_squared_error: 0.1033
# Epoch 151/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0557 - mse: 0.0097 - mae: 0.0557 - root_mean_squared_error: 0.0985 - val_loss: 0.0587 - val_mse: 0.0107 - val_mae: 0.0587 - val_root_mean_squared_error: 0.1033
# Epoch 152/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0557 - mse: 0.0097 - mae: 0.0557 - root_mean_squared_error: 0.0984 - val_loss: 0.0587 - val_mse: 0.0107 - val_mae: 0.0587 - val_root_mean_squared_error: 0.1033
# Epoch 153/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0568 - mse: 0.0102 - mae: 0.0568 - root_mean_squared_error: 0.100 - 0s 25us/sample - loss: 0.0556 - mse: 0.0097 - mae: 0.0556 - root_mean_squared_error: 0.0984 - val_loss: 0.0587 - val_mse: 0.0107 - val_mae: 0.0587 - val_root_mean_squared_error: 0.1033
# Epoch 154/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0568 - mse: 0.0102 - mae: 0.0568 - root_mean_squared_error: 0.100 - 0s 27us/sample - loss: 0.0556 - mse: 0.0097 - mae: 0.0556 - root_mean_squared_error: 0.0984 - val_loss: 0.0587 - val_mse: 0.0107 - val_mae: 0.0587 - val_root_mean_squared_error: 0.1033
# Epoch 155/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0556 - mse: 0.0097 - mae: 0.0556 - root_mean_squared_error: 0.0984 - val_loss: 0.0586 - val_mse: 0.0107 - val_mae: 0.0586 - val_root_mean_squared_error: 0.1033
# Epoch 156/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0555 - mse: 0.0097 - mae: 0.0555 - root_mean_squared_error: 0.0984 - val_loss: 0.0586 - val_mse: 0.0107 - val_mae: 0.0586 - val_root_mean_squared_error: 0.1033
# Epoch 157/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0555 - mse: 0.0097 - mae: 0.0555 - root_mean_squared_error: 0.0983 - val_loss: 0.0586 - val_mse: 0.0107 - val_mae: 0.0586 - val_root_mean_squared_error: 0.1033
# Epoch 158/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0555 - mse: 0.0097 - mae: 0.0555 - root_mean_squared_error: 0.0983 - val_loss: 0.0586 - val_mse: 0.0107 - val_mae: 0.0586 - val_root_mean_squared_error: 0.1033
# Epoch 159/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0555 - mse: 0.0097 - mae: 0.0555 - root_mean_squared_error: 0.0983 - val_loss: 0.0585 - val_mse: 0.0107 - val_mae: 0.0585 - val_root_mean_squared_error: 0.1032
# Epoch 160/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0554 - mse: 0.0097 - mae: 0.0554 - root_mean_squared_error: 0.0982 - val_loss: 0.0585 - val_mse: 0.0107 - val_mae: 0.0585 - val_root_mean_squared_error: 0.1032
# Epoch 161/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0554 - mse: 0.0096 - mae: 0.0554 - root_mean_squared_error: 0.0982 - val_loss: 0.0585 - val_mse: 0.0107 - val_mae: 0.0585 - val_root_mean_squared_error: 0.1032
# Epoch 162/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0554 - mse: 0.0096 - mae: 0.0554 - root_mean_squared_error: 0.0982 - val_loss: 0.0584 - val_mse: 0.0107 - val_mae: 0.0584 - val_root_mean_squared_error: 0.1032
# Epoch 163/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0554 - mse: 0.0096 - mae: 0.0554 - root_mean_squared_error: 0.0982 - val_loss: 0.0584 - val_mse: 0.0107 - val_mae: 0.0584 - val_root_mean_squared_error: 0.1032
# Epoch 164/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0553 - mse: 0.0096 - mae: 0.0553 - root_mean_squared_error: 0.0981 - val_loss: 0.0584 - val_mse: 0.0107 - val_mae: 0.0584 - val_root_mean_squared_error: 0.1032
# Epoch 165/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0553 - mse: 0.0096 - mae: 0.0553 - root_mean_squared_error: 0.0981 - val_loss: 0.0584 - val_mse: 0.0106 - val_mae: 0.0584 - val_root_mean_squared_error: 0.1032
# Epoch 166/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0553 - mse: 0.0096 - mae: 0.0553 - root_mean_squared_error: 0.0981 - val_loss: 0.0583 - val_mse: 0.0106 - val_mae: 0.0583 - val_root_mean_squared_error: 0.1032
# Epoch 167/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0552 - mse: 0.0096 - mae: 0.0552 - root_mean_squared_error: 0.0981 - val_loss: 0.0583 - val_mse: 0.0106 - val_mae: 0.0583 - val_root_mean_squared_error: 0.1032
# Epoch 168/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0552 - mse: 0.0096 - mae: 0.0552 - root_mean_squared_error: 0.0980 - val_loss: 0.0583 - val_mse: 0.0106 - val_mae: 0.0583 - val_root_mean_squared_error: 0.1031
# Epoch 169/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0552 - mse: 0.0096 - mae: 0.0552 - root_mean_squared_error: 0.0980 - val_loss: 0.0583 - val_mse: 0.0106 - val_mae: 0.0583 - val_root_mean_squared_error: 0.1032
# Epoch 170/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0552 - mse: 0.0096 - mae: 0.0552 - root_mean_squared_error: 0.0980 - val_loss: 0.0582 - val_mse: 0.0106 - val_mae: 0.0582 - val_root_mean_squared_error: 0.1032
# Epoch 171/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0552 - mse: 0.0096 - mae: 0.0552 - root_mean_squared_error: 0.0980 - val_loss: 0.0582 - val_mse: 0.0106 - val_mae: 0.0582 - val_root_mean_squared_error: 0.1032
# Epoch 172/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0551 - mse: 0.0096 - mae: 0.0551 - root_mean_squared_error: 0.0980 - val_loss: 0.0582 - val_mse: 0.0106 - val_mae: 0.0582 - val_root_mean_squared_error: 0.1032
# Epoch 173/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0551 - mse: 0.0096 - mae: 0.0551 - root_mean_squared_error: 0.0979 - val_loss: 0.0582 - val_mse: 0.0106 - val_mae: 0.0582 - val_root_mean_squared_error: 0.1031
# Epoch 174/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0551 - mse: 0.0096 - mae: 0.0551 - root_mean_squared_error: 0.0979 - val_loss: 0.0581 - val_mse: 0.0106 - val_mae: 0.0581 - val_root_mean_squared_error: 0.1031
# Epoch 175/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0551 - mse: 0.0096 - mae: 0.0551 - root_mean_squared_error: 0.0979 - val_loss: 0.0581 - val_mse: 0.0106 - val_mae: 0.0581 - val_root_mean_squared_error: 0.1031
# Epoch 176/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0551 - mse: 0.0096 - mae: 0.0551 - root_mean_squared_error: 0.0979 - val_loss: 0.0581 - val_mse: 0.0106 - val_mae: 0.0581 - val_root_mean_squared_error: 0.1031
# Epoch 177/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0550 - mse: 0.0096 - mae: 0.0550 - root_mean_squared_error: 0.0979 - val_loss: 0.0581 - val_mse: 0.0106 - val_mae: 0.0581 - val_root_mean_squared_error: 0.1031
# Epoch 178/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0550 - mse: 0.0096 - mae: 0.0550 - root_mean_squared_error: 0.0979 - val_loss: 0.0580 - val_mse: 0.0106 - val_mae: 0.0580 - val_root_mean_squared_error: 0.1031
# Epoch 179/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0550 - mse: 0.0096 - mae: 0.0550 - root_mean_squared_error: 0.0978 - val_loss: 0.0580 - val_mse: 0.0106 - val_mae: 0.0580 - val_root_mean_squared_error: 0.1031
# Epoch 180/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0550 - mse: 0.0096 - mae: 0.0550 - root_mean_squared_error: 0.0978 - val_loss: 0.0580 - val_mse: 0.0106 - val_mae: 0.0580 - val_root_mean_squared_error: 0.1031
# Epoch 181/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0550 - mse: 0.0096 - mae: 0.0550 - root_mean_squared_error: 0.0978 - val_loss: 0.0580 - val_mse: 0.0106 - val_mae: 0.0580 - val_root_mean_squared_error: 0.1031
# Epoch 182/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0549 - mse: 0.0096 - mae: 0.0549 - root_mean_squared_error: 0.0978 - val_loss: 0.0580 - val_mse: 0.0106 - val_mae: 0.0580 - val_root_mean_squared_error: 0.1031
# Epoch 183/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0549 - mse: 0.0096 - mae: 0.0549 - root_mean_squared_error: 0.0978 - val_loss: 0.0580 - val_mse: 0.0106 - val_mae: 0.0580 - val_root_mean_squared_error: 0.1031
# Epoch 184/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0549 - mse: 0.0096 - mae: 0.0549 - root_mean_squared_error: 0.0978 - val_loss: 0.0579 - val_mse: 0.0106 - val_mae: 0.0579 - val_root_mean_squared_error: 0.1032
# Epoch 185/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0549 - mse: 0.0096 - mae: 0.0549 - root_mean_squared_error: 0.0977 - val_loss: 0.0579 - val_mse: 0.0106 - val_mae: 0.0579 - val_root_mean_squared_error: 0.1031
# Epoch 186/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0549 - mse: 0.0096 - mae: 0.0549 - root_mean_squared_error: 0.0977 - val_loss: 0.0579 - val_mse: 0.0106 - val_mae: 0.0579 - val_root_mean_squared_error: 0.1031
# Epoch 187/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0548 - mse: 0.0095 - mae: 0.0548 - root_mean_squared_error: 0.0977 - val_loss: 0.0579 - val_mse: 0.0106 - val_mae: 0.0579 - val_root_mean_squared_error: 0.1031
# Epoch 188/500
# 3175/3175 [==============================] - 0s 70us/sample - loss: 0.0548 - mse: 0.0095 - mae: 0.0548 - root_mean_squared_error: 0.0977 - val_loss: 0.0579 - val_mse: 0.0106 - val_mae: 0.0579 - val_root_mean_squared_error: 0.1032
# Epoch 189/500
# 3175/3175 [==============================] - 0s 63us/sample - loss: 0.0548 - mse: 0.0095 - mae: 0.0548 - root_mean_squared_error: 0.0977 - val_loss: 0.0578 - val_mse: 0.0106 - val_mae: 0.0578 - val_root_mean_squared_error: 0.1031
# Epoch 190/500
# 3175/3175 [==============================] - 0s 61us/sample - loss: 0.0548 - mse: 0.0095 - mae: 0.0548 - root_mean_squared_error: 0.0977 - val_loss: 0.0578 - val_mse: 0.0106 - val_mae: 0.0578 - val_root_mean_squared_error: 0.1031
# Epoch 191/500
# 3175/3175 [==============================] - 0s 59us/sample - loss: 0.0548 - mse: 0.0095 - mae: 0.0548 - root_mean_squared_error: 0.0977 - val_loss: 0.0578 - val_mse: 0.0106 - val_mae: 0.0578 - val_root_mean_squared_error: 0.1031
# Epoch 192/500
# 3175/3175 [==============================] - 0s 60us/sample - loss: 0.0548 - mse: 0.0095 - mae: 0.0548 - root_mean_squared_error: 0.0976 - val_loss: 0.0578 - val_mse: 0.0106 - val_mae: 0.0578 - val_root_mean_squared_error: 0.1031
# Epoch 193/500
# 3175/3175 [==============================] - 0s 67us/sample - loss: 0.0547 - mse: 0.0095 - mae: 0.0547 - root_mean_squared_error: 0.0976 - val_loss: 0.0578 - val_mse: 0.0106 - val_mae: 0.0578 - val_root_mean_squared_error: 0.1031
# Epoch 194/500
# 3175/3175 [==============================] - 0s 66us/sample - loss: 0.0547 - mse: 0.0095 - mae: 0.0547 - root_mean_squared_error: 0.0976 - val_loss: 0.0577 - val_mse: 0.0106 - val_mae: 0.0577 - val_root_mean_squared_error: 0.1031
# Epoch 195/500
# 3175/3175 [==============================] - 0s 64us/sample - loss: 0.0547 - mse: 0.0095 - mae: 0.0547 - root_mean_squared_error: 0.0976 - val_loss: 0.0577 - val_mse: 0.0106 - val_mae: 0.0577 - val_root_mean_squared_error: 0.1031
# Epoch 196/500
# ...
# Epoch 436/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0963 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1037
# Epoch 437/500
# 3175/3175 [==============================] - 0s 56us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1037
# Epoch 438/500
# 3175/3175 [==============================] - 0s 49us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0963 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1037
# Epoch 439/500
# 3175/3175 [==============================] - 0s 43us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1037
# Epoch 440/500
# 3175/3175 [==============================] - 0s 43us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1037
# Epoch 441/500
# 3175/3175 [==============================] - 0s 53us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1037
# Epoch 442/500
# 3175/3175 [==============================] - 0s 57us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1037
# Epoch 443/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1037
# Epoch 444/500
# 3175/3175 [==============================] - 0s 67us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1037
# Epoch 445/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1037
# Epoch 446/500
# 3175/3175 [==============================] - 0s 49us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1037
# Epoch 447/500
# 3175/3175 [==============================] - 0s 49us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1037
# Epoch 448/500
# 3175/3175 [==============================] - 0s 52us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1038
# Epoch 449/500
# 3175/3175 [==============================] - 0s 51us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1038
# Epoch 450/500
# 3175/3175 [==============================] - 0s 44us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1037
# Epoch 451/500
# 3175/3175 [==============================] - 0s 43us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1038
# Epoch 452/500
# 3175/3175 [==============================] - 0s 42us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1037
# Epoch 453/500
# 3175/3175 [==============================] - 0s 45us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1037
# Epoch 454/500
# 3175/3175 [==============================] - 0s 47us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1038
# Epoch 455/500
# 3175/3175 [==============================] - 0s 42us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1037
# Epoch 456/500
# 3175/3175 [==============================] - 0s 46us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1038
# Epoch 457/500
# 3175/3175 [==============================] - 0s 41us/sample - loss: 0.0531 - mse: 0.0093 - mae: 0.0531 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1038
# Epoch 458/500
# 3175/3175 [==============================] - 0s 42us/sample - loss: 0.0532 - mse: 0.0093 - mae: 0.0532 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1037
# Epoch 459/500
# 3175/3175 [==============================] - 0s 45us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1038
# Epoch 460/500
# 3175/3175 [==============================] - 0s 47us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1038
# Epoch 461/500
# 3175/3175 [==============================] - 0s 66us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1038
# Epoch 462/500
# 3175/3175 [==============================] - 0s 60us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1038
# Epoch 463/500
# 3175/3175 [==============================] - 0s 59us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1038
# Epoch 464/500
# 3175/3175 [==============================] - 0s 57us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1038
# Epoch 465/500
# 3175/3175 [==============================] - 0s 43us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0962 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1038
# Epoch 466/500
# 3175/3175 [==============================] - 0s 49us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1038
# Epoch 467/500
# 3175/3175 [==============================] - 0s 59us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1038
# Epoch 468/500
# 3175/3175 [==============================] - 0s 64us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1038
# Epoch 469/500
# 3175/3175 [==============================] - 0s 41us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1038
# Epoch 470/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1038
# Epoch 471/500
# 3175/3175 [==============================] - 0s 41us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0563 - val_mse: 0.0108 - val_mae: 0.0563 - val_root_mean_squared_error: 0.1038
# Epoch 472/500
# 3175/3175 [==============================] - 0s 45us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 473/500
# 3175/3175 [==============================] - 0s 40us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 474/500
# 3175/3175 [==============================] - 0s 41us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 475/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 476/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 477/500
# 3175/3175 [==============================] - 0s 40us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 478/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 479/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 480/500
# 3175/3175 [==============================] - 0s 41us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 481/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 482/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 483/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 484/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 485/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 486/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 487/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0961 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 488/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0960 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 489/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0960 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 490/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0960 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 491/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0960 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 492/500
# 3175/3175 [==============================] - 0s 41us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0960 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 493/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0960 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 494/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0960 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 495/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0531 - mse: 0.0092 - mae: 0.0531 - root_mean_squared_error: 0.0960 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 496/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0530 - mse: 0.0092 - mae: 0.0530 - root_mean_squared_error: 0.0960 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 497/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0530 - mse: 0.0092 - mae: 0.0530 - root_mean_squared_error: 0.0960 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 498/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0530 - mse: 0.0092 - mae: 0.0530 - root_mean_squared_error: 0.0960 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 499/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0530 - mse: 0.0092 - mae: 0.0530 - root_mean_squared_error: 0.0960 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038
# Epoch 500/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0530 - mse: 0.0092 - mae: 0.0530 - root_mean_squared_error: 0.0960 - val_loss: 0.0562 - val_mse: 0.0108 - val_mae: 0.0562 - val_root_mean_squared_error: 0.1038

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mae'],label='train mae')
pyplot.plot(history.history['val_mae'],label='val mae')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mse'],label='train mse')
pyplot.plot(history.history['val_mse'],label='val mse')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['root_mean_squared_error'],label='train rmse')
pyplot.plot(history.history['val_root_mean_squared_error'],label='val rmse')
pyplot.legend()
pyplot.show()
# Out:
# The testing MAE loss is: 0.054420613
# The testing MSE loss is: 0.009891295
# The testing RMSE loss is: 0.099454984

# %%
pyplot.plot(test_y[:,7],color='red', label='True Values')
pyplot.plot(out[:,7],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()

# %%
dataset_test=pd.read_excel('F:\MS thesis data/Hopper Crossing.xlsx')
dataset_test=dataset_test.drop(['Date/Time','Flowd'],axis=1)
dataset_test.dropna(inplace=True)

# %%
shape=np.shape(dataset_test)
print(shape)
pyplot.plot(dataset_test)
# Out:
# (26285, 3)
# [<matplotlib.lines.Line2D at 0x1be792efa48>,
#  <matplotlib.lines.Line2D at 0x1be792ef788>,
#  <matplotlib.lines.Line2D at 0x1be792ef588>]

# %%
dataset_test
# Out:
#        Cumulative rainfall   Flow  Level
# 0                      0.0  0.093    1.50
# 1                      0.0  0.093    1.50
# 2                      0.0  0.093    1.50
# 3                      0.0  0.093    1.50
# 4                      0.0  0.093    1.50
# ...                    ...    ...     ...
# 26280                  0.2  0.080    1.49
# 26281                  0.2  0.080    1.49
# 26282                  0.2  0.080    1.49
# 26283                  0.2  0.080    1.49
# 26284                  0.2  0.080    1.49
#
# [26285 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset_test)))
# Out:
# The std of original data is Cumulative rainfall    2.451640
# Flow                   0.520832
# Level                  0.083204
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset_test=dataset_test.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset_test.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset_test[:,0]== maxi[0])
    ind2=np.argwhere(dataset_test[:,1]== maxi[1])
    ind3=np.argwhere(dataset_test[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset_test.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset_test[:,0]== mini[0])
    ind2=np.argwhere(dataset_test[:,1]== mini[1])
    ind3=np.argwhere(dataset_test[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset_test)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset_test = min_max_scaler.fit_transform(dataset_test)
# Out:
# The std of cleaned data is 1.5154548293543502

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=8
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values

#one hour
#test_X, test_y = values[:, :-out_hour], values[:,-1]


test_X, test_y = values[:, :-out_hour], values[:, -out_hour: ]


test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6338, 42)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var2(t-1)  var3(t-1)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.524545   0.776699
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.549980   0.791262
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.603309   0.820388
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.650485   0.844660
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.709285   0.873786
#
#      var3(t)  var3(t+1)  var3(t+2)  var3(t+3)  var3(t+4)  var3(t+5)  \
# 6   0.791262   0.820388   0.844660   0.873786   0.898058   0.932039
# 7   0.820388   0.844660   0.873786   0.898058   0.932039   0.966019
# 8   0.844660   0.873786   0.898058   0.932039   0.966019   1.000000
# 9   0.873786   0.898058   0.932039   0.966019   1.000000   0.941748
# 10  0.898058   0.932039   0.966019   1.000000   0.941748   0.912621
#
#     var3(t+6)  var3(t+7)
# 6    0.966019   1.000000
# 7    1.000000   0.941748
# 8    0.941748   0.912621
# 9    0.912621   0.800971
# 10   0.800971   0.723301
#
# [5 rows x 26 columns]

# %%
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
# Out:
# The testing MAE loss is: 0.05408166
# The testing MSE loss is: 0.0097659975
# The testing RMSE loss is: 0.09882306

# %%
pyplot.plot(test_y[:,7],color='red', label='True Values')
pyplot.plot(out[:,7],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()
