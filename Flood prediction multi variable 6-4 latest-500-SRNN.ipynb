# %%
import pandas as pd
from pandas import concat
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from sklearn import preprocessing
from tensorflow.keras import backend as K
#from sklearn.preprocessing import MinMaxScaler
#from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input, Dense, LSTM,GRU,SimpleRNN, Activation
from matplotlib import pyplot
#from sklearn.model_selection import train_test_split

# %%
"# convert series to supervised learning\n" 
#windowing of data
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1),
    for i in range(n_in, 0, -1): #startes from n_in and decreses to 0 by decreasing each time -1
     cols.append(df.shift(i))
     names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
     cols.append(df.shift(-i))
     if i == 0:
       names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
     else:
       names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together\n",
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values\n",
    if dropnan:
      agg.dropna(inplace=True)
    return agg

# %%
#def root_mean_squared_error(y_true, y_pred):
 #       return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
dataset1=pd.read_excel('F:\MS thesis data/Brooklyn.xlsx')
dataset1=dataset1.drop(['Date/Time','Flowd'],axis=1)
dataset1.dropna(inplace=True)

# %%
shape=np.shape(dataset1)
print(shape)
pyplot.plot(dataset1)
# Out:
# (26302, 3)
# [<matplotlib.lines.Line2D at 0x25e3d6750c8>,
#  <matplotlib.lines.Line2D at 0x25e3d670688>,
#  <matplotlib.lines.Line2D at 0x25e3d6653c8>]

# %%
dataset1
# Out:
#        Cumulative rainfall    Flow  Level
# 0                       0.0  0.172   0.352
# 1                       0.0  0.180   0.356
# 2                       0.0  0.180   0.356
# 3                       0.0  0.189   0.360
# 4                       0.0  0.189   0.360
# ...                     ...    ...     ...
# 26297                   0.0  0.025   0.232
# 26298                   0.0  0.023   0.228
# 26299                   0.0  0.023   0.228
# 26300                   0.0  0.023   0.228
# 26301                   0.0  0.023   0.228
#
# [26302 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset1)))
# Out:
# The std of original data is Cumulative rainfall     2.872616
# Flow                    1.306642
# Level                   0.147238
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset=dataset1.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset[:,0]== maxi[0])
    ind2=np.argwhere(dataset[:,1]== maxi[1])
    ind3=np.argwhere(dataset[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset[:,0]== mini[0])
    ind2=np.argwhere(dataset[:,1]== mini[1])
    ind3=np.argwhere(dataset[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset = min_max_scaler.fit_transform(dataset)
# Out:
# The std of cleaned data is 1.626639593959813

# %%
pyplot.plot(dataset)
# Out:
# [<matplotlib.lines.Line2D at 0x25e3d4fe488>,
#  <matplotlib.lines.Line2D at 0x25e3d299388>,
#  <matplotlib.lines.Line2D at 0x25e3d299548>]

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=4
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values
train_size  = int(len(dataset) * 0.50)
val_size=int(len(dataset) * 0.75)
train_X, train_y = values[0:train_size, :-out_hour], values[0:train_size,-out_hour: ]
val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-out_hour: ]
test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-out_hour:]
#for last hour
#train_X, train_y = values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]  #for only last hour
#val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]
#test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-1]
print(train_X, train_y)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6342, 30)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var1(t-2)  var2(t-2)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.230769   0.524545
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.215385   0.524545
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.123077   0.549980
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.092308   0.603309
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.092308   0.650485
#
#     var3(t-2)  var1(t-1)  var2(t-1)  var3(t-1)   var3(t)  var3(t+1)  \
# 6    0.776699   0.215385   0.524545   0.776699  0.791262   0.820388
# 7    0.776699   0.123077   0.549980   0.791262  0.820388   0.844660
# 8    0.791262   0.092308   0.603309   0.820388  0.844660   0.873786
# 9    0.820388   0.092308   0.650485   0.844660  0.873786   0.898058
# 10   0.844660   0.092308   0.709285   0.873786  0.898058   0.932039
#
#     var3(t+2)  var3(t+3)
# 6    0.844660   0.873786
# 7    0.873786   0.898058
# 8    0.898058   0.932039
# 9    0.932039   0.966019
# 10   0.966019   1.000000
#
# [5 rows x 22 columns]
# [[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]
#  [0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]
#  [0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]
#  ...
#  [0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]
#  [0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]
#  [0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]] [[0.79126215 0.8203884  0.8446602  0.8737864 ]
#  [0.8203884  0.8446602  0.8737864  0.89805824]
#  [0.8446602  0.8737864  0.89805824 0.93203884]
#  ...
#  [0.23786408 0.24271844 0.24757281 0.24757281]
#  [0.24271844 0.24757281 0.24757281 0.24757281]
#  [0.24757281 0.24757281 0.24757281 0.2184466 ]]

# %%
print(train_X, train_y)
# Out:
# [[[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]]
#
#  [[0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]]
#
#  [[0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]]
#
#  ...
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]]] [[0.79126215 0.8203884  0.8446602  0.8737864 ]
#  [0.8203884  0.8446602  0.8737864  0.89805824]
#  [0.8446602  0.8737864  0.89805824 0.93203884]
#  ...
#  [0.23786408 0.24271844 0.24757281 0.24757281]
#  [0.24271844 0.24757281 0.24757281 0.24757281]
#  [0.24757281 0.24757281 0.24757281 0.2184466 ]]

# %%
print(train_X.shape, train_y.shape, val_X.shape, val_y.shape)
# Out:
# (3175, 1, 18) (3175, 4) (1588, 1, 18) (1588, 4)

# %%
randomState = 46
np.random.seed(randomState)
#tensorflow.random.set_random_seed(randomState)
tensorflow.random.set_seed(randomState)
model = Sequential()
model.add(LSTM(15,input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dense(22))
#model.add(Activation('relu'))    
model.add(Dense(out_hour,activation = "sigmoid"))
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.001)
#    opt=tensorflow.keras.optimizers.Adam(learning_rate=0.00075)
model.compile(loss='mae', optimizer=opt,metrics=['mse','mae',tensorflow.keras.metrics.RootMeanSquaredError()])
history = model.fit(train_X, train_y,validation_data=(val_X, val_y), epochs=500, batch_size=100,verbose=1,shuffle=False)
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)
# Out:
# Train on 3175 samples, validate on 1588 samples
# Epoch 1/500
# 3175/3175 [==============================] - 2s 575us/sample - loss: 0.2578 - mse: 0.0793 - mae: 0.2578 - root_mean_squared_error: 0.2816 - val_loss: 0.2716 - val_mse: 0.0907 - val_mae: 0.2716 - val_root_mean_squared_error: 0.3012
# Epoch 2/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.2430 - mse: 0.0715 - mae: 0.2430 - root_mean_squared_error: 0.2674 - val_loss: 0.2569 - val_mse: 0.0818 - val_mae: 0.2569 - val_root_mean_squared_error: 0.2860
# Epoch 3/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.2274 - mse: 0.0639 - mae: 0.2274 - root_mean_squared_error: 0.2527 - val_loss: 0.2407 - val_mse: 0.0727 - val_mae: 0.2407 - val_root_mean_squared_error: 0.2696
# Epoch 4/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.2110 - mse: 0.0566 - mae: 0.2110 - root_mean_squared_error: 0.2380 - val_loss: 0.2238 - val_mse: 0.0642 - val_mae: 0.2238 - val_root_mean_squared_error: 0.2533
# Epoch 5/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1951 - mse: 0.0504 - mae: 0.1951 - root_mean_squared_error: 0.2245 - val_loss: 0.2079 - val_mse: 0.0568 - val_mae: 0.2079 - val_root_mean_squared_error: 0.2384
# Epoch 6/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1806 - mse: 0.0453 - mae: 0.1806 - root_mean_squared_error: 0.2128 - val_loss: 0.1937 - val_mse: 0.0507 - val_mae: 0.1937 - val_root_mean_squared_error: 0.2252
# Epoch 7/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.1680 - mse: 0.0409 - mae: 0.1680 - root_mean_squared_error: 0.2022 - val_loss: 0.1812 - val_mse: 0.0454 - val_mae: 0.1812 - val_root_mean_squared_error: 0.2131
# Epoch 8/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1569 - mse: 0.0368 - mae: 0.1569 - root_mean_squared_error: 0.1919 - val_loss: 0.1699 - val_mse: 0.0407 - val_mae: 0.1699 - val_root_mean_squared_error: 0.2017
# Epoch 9/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.1466 - mse: 0.0330 - mae: 0.1466 - root_mean_squared_error: 0.1816 - val_loss: 0.1593 - val_mse: 0.0364 - val_mae: 0.1593 - val_root_mean_squared_error: 0.1908
# Epoch 10/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.1369 - mse: 0.0294 - mae: 0.1369 - root_mean_squared_error: 0.1714 - val_loss: 0.1491 - val_mse: 0.0325 - val_mae: 0.1491 - val_root_mean_squared_error: 0.1803
# Epoch 11/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1276 - mse: 0.0261 - mae: 0.1276 - root_mean_squared_error: 0.1616 - val_loss: 0.1394 - val_mse: 0.0291 - val_mae: 0.1394 - val_root_mean_squared_error: 0.1705
# Epoch 12/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1190 - mse: 0.0232 - mae: 0.1190 - root_mean_squared_error: 0.1525 - val_loss: 0.1305 - val_mse: 0.0260 - val_mae: 0.1305 - val_root_mean_squared_error: 0.1613
# Epoch 13/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1112 - mse: 0.0208 - mae: 0.1112 - root_mean_squared_error: 0.1443 - val_loss: 0.1225 - val_mse: 0.0234 - val_mae: 0.1225 - val_root_mean_squared_error: 0.1530
# Epoch 14/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1042 - mse: 0.0187 - mae: 0.1042 - root_mean_squared_error: 0.1368 - val_loss: 0.1155 - val_mse: 0.0212 - val_mae: 0.1155 - val_root_mean_squared_error: 0.1455
# Epoch 15/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0979 - mse: 0.0169 - mae: 0.0979 - root_mean_squared_error: 0.1299 - val_loss: 0.1093 - val_mse: 0.0193 - val_mae: 0.1093 - val_root_mean_squared_error: 0.1389
# Epoch 16/500
# 3175/3175 [==============================] - 0s 53us/sample - loss: 0.0925 - mse: 0.0154 - mae: 0.0925 - root_mean_squared_error: 0.1239 - val_loss: 0.1037 - val_mse: 0.0177 - val_mae: 0.1037 - val_root_mean_squared_error: 0.1332
# Epoch 17/500
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.0877 - mse: 0.0141 - mae: 0.0877 - root_mean_squared_error: 0.1189 - val_loss: 0.0988 - val_mse: 0.0165 - val_mae: 0.0988 - val_root_mean_squared_error: 0.1284
# Epoch 18/500
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.0835 - mse: 0.0131 - mae: 0.0835 - root_mean_squared_error: 0.1146 - val_loss: 0.0945 - val_mse: 0.0154 - val_mae: 0.0945 - val_root_mean_squared_error: 0.1242
# Epoch 19/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.0797 - mse: 0.0123 - mae: 0.0797 - root_mean_squared_error: 0.1111 - val_loss: 0.0906 - val_mse: 0.0146 - val_mae: 0.0906 - val_root_mean_squared_error: 0.1208
# Epoch 20/500
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.0764 - mse: 0.0117 - mae: 0.0764 - root_mean_squared_error: 0.1081 - val_loss: 0.0872 - val_mse: 0.0139 - val_mae: 0.0872 - val_root_mean_squared_error: 0.1178
# Epoch 21/500
# 3175/3175 [==============================] - 0s 52us/sample - loss: 0.0735 - mse: 0.0111 - mae: 0.0735 - root_mean_squared_error: 0.1056 - val_loss: 0.0841 - val_mse: 0.0133 - val_mae: 0.0841 - val_root_mean_squared_error: 0.1153
# Epoch 22/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0709 - mse: 0.0107 - mae: 0.0709 - root_mean_squared_error: 0.1034 - val_loss: 0.0814 - val_mse: 0.0128 - val_mae: 0.0814 - val_root_mean_squared_error: 0.1131
# Epoch 23/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0687 - mse: 0.0103 - mae: 0.0687 - root_mean_squared_error: 0.1015 - val_loss: 0.0790 - val_mse: 0.0124 - val_mae: 0.0790 - val_root_mean_squared_error: 0.1113
# Epoch 24/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0667 - mse: 0.0100 - mae: 0.0667 - root_mean_squared_error: 0.0999 - val_loss: 0.0769 - val_mse: 0.0120 - val_mae: 0.0769 - val_root_mean_squared_error: 0.1095
# Epoch 25/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0650 - mse: 0.0097 - mae: 0.0650 - root_mean_squared_error: 0.0984 - val_loss: 0.0750 - val_mse: 0.0116 - val_mae: 0.0750 - val_root_mean_squared_error: 0.1079
# Epoch 26/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0635 - mse: 0.0094 - mae: 0.0635 - root_mean_squared_error: 0.0970 - val_loss: 0.0733 - val_mse: 0.0113 - val_mae: 0.0733 - val_root_mean_squared_error: 0.1063
# Epoch 27/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0621 - mse: 0.0091 - mae: 0.0621 - root_mean_squared_error: 0.0956 - val_loss: 0.0718 - val_mse: 0.0110 - val_mae: 0.0718 - val_root_mean_squared_error: 0.1049
# Epoch 28/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0609 - mse: 0.0089 - mae: 0.0609 - root_mean_squared_error: 0.0944 - val_loss: 0.0704 - val_mse: 0.0107 - val_mae: 0.0704 - val_root_mean_squared_error: 0.1036
# Epoch 29/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0597 - mse: 0.0087 - mae: 0.0597 - root_mean_squared_error: 0.0932 - val_loss: 0.0691 - val_mse: 0.0105 - val_mae: 0.0691 - val_root_mean_squared_error: 0.1024
# Epoch 30/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0587 - mse: 0.0085 - mae: 0.0587 - root_mean_squared_error: 0.0922 - val_loss: 0.0679 - val_mse: 0.0103 - val_mae: 0.0679 - val_root_mean_squared_error: 0.1013
# Epoch 31/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0577 - mse: 0.0083 - mae: 0.0577 - root_mean_squared_error: 0.0912 - val_loss: 0.0668 - val_mse: 0.0101 - val_mae: 0.0668 - val_root_mean_squared_error: 0.1003
# Epoch 32/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0568 - mse: 0.0082 - mae: 0.0568 - root_mean_squared_error: 0.0903 - val_loss: 0.0658 - val_mse: 0.0099 - val_mae: 0.0658 - val_root_mean_squared_error: 0.0994
# Epoch 33/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0559 - mse: 0.0080 - mae: 0.0559 - root_mean_squared_error: 0.0895 - val_loss: 0.0649 - val_mse: 0.0097 - val_mae: 0.0649 - val_root_mean_squared_error: 0.0986
# Epoch 34/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0552 - mse: 0.0079 - mae: 0.0552 - root_mean_squared_error: 0.0888 - val_loss: 0.0641 - val_mse: 0.0096 - val_mae: 0.0641 - val_root_mean_squared_error: 0.0978
# Epoch 35/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0545 - mse: 0.0078 - mae: 0.0545 - root_mean_squared_error: 0.0882 - val_loss: 0.0633 - val_mse: 0.0094 - val_mae: 0.0633 - val_root_mean_squared_error: 0.0971
# Epoch 36/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0538 - mse: 0.0077 - mae: 0.0538 - root_mean_squared_error: 0.0875 - val_loss: 0.0626 - val_mse: 0.0093 - val_mae: 0.0626 - val_root_mean_squared_error: 0.0965
# Epoch 37/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0533 - mse: 0.0076 - mae: 0.0533 - root_mean_squared_error: 0.0870 - val_loss: 0.0620 - val_mse: 0.0092 - val_mae: 0.0620 - val_root_mean_squared_error: 0.0959
# Epoch 38/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0527 - mse: 0.0075 - mae: 0.0527 - root_mean_squared_error: 0.0865 - val_loss: 0.0615 - val_mse: 0.0091 - val_mae: 0.0615 - val_root_mean_squared_error: 0.0954
# Epoch 39/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0522 - mse: 0.0074 - mae: 0.0522 - root_mean_squared_error: 0.0860 - val_loss: 0.0610 - val_mse: 0.0090 - val_mae: 0.0610 - val_root_mean_squared_error: 0.0950
# Epoch 40/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0518 - mse: 0.0073 - mae: 0.0518 - root_mean_squared_error: 0.0856 - val_loss: 0.0606 - val_mse: 0.0089 - val_mae: 0.0606 - val_root_mean_squared_error: 0.0946
# Epoch 41/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0514 - mse: 0.0073 - mae: 0.0514 - root_mean_squared_error: 0.0852 - val_loss: 0.0602 - val_mse: 0.0089 - val_mae: 0.0602 - val_root_mean_squared_error: 0.0942
# Epoch 42/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0510 - mse: 0.0072 - mae: 0.0510 - root_mean_squared_error: 0.0849 - val_loss: 0.0598 - val_mse: 0.0088 - val_mae: 0.0598 - val_root_mean_squared_error: 0.0938
# Epoch 43/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0507 - mse: 0.0071 - mae: 0.0507 - root_mean_squared_error: 0.0845 - val_loss: 0.0594 - val_mse: 0.0087 - val_mae: 0.0594 - val_root_mean_squared_error: 0.0935
# Epoch 44/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0503 - mse: 0.0071 - mae: 0.0503 - root_mean_squared_error: 0.0842 - val_loss: 0.0591 - val_mse: 0.0087 - val_mae: 0.0591 - val_root_mean_squared_error: 0.0932
# Epoch 45/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0500 - mse: 0.0070 - mae: 0.0500 - root_mean_squared_error: 0.0839 - val_loss: 0.0588 - val_mse: 0.0086 - val_mae: 0.0588 - val_root_mean_squared_error: 0.0929
# Epoch 46/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0497 - mse: 0.0070 - mae: 0.0497 - root_mean_squared_error: 0.0836 - val_loss: 0.0584 - val_mse: 0.0086 - val_mae: 0.0584 - val_root_mean_squared_error: 0.0926
# Epoch 47/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0494 - mse: 0.0069 - mae: 0.0494 - root_mean_squared_error: 0.0833 - val_loss: 0.0581 - val_mse: 0.0085 - val_mae: 0.0581 - val_root_mean_squared_error: 0.0923
# Epoch 48/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0491 - mse: 0.0069 - mae: 0.0491 - root_mean_squared_error: 0.0830 - val_loss: 0.0578 - val_mse: 0.0085 - val_mae: 0.0578 - val_root_mean_squared_error: 0.0920
# Epoch 49/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0488 - mse: 0.0068 - mae: 0.0488 - root_mean_squared_error: 0.0827 - val_loss: 0.0576 - val_mse: 0.0084 - val_mae: 0.0576 - val_root_mean_squared_error: 0.0918
# Epoch 50/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0485 - mse: 0.0068 - mae: 0.0485 - root_mean_squared_error: 0.0825 - val_loss: 0.0573 - val_mse: 0.0084 - val_mae: 0.0573 - val_root_mean_squared_error: 0.0915
# Epoch 51/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0482 - mse: 0.0068 - mae: 0.0482 - root_mean_squared_error: 0.0823 - val_loss: 0.0570 - val_mse: 0.0083 - val_mae: 0.0570 - val_root_mean_squared_error: 0.0913
# Epoch 52/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0480 - mse: 0.0067 - mae: 0.0480 - root_mean_squared_error: 0.0821 - val_loss: 0.0567 - val_mse: 0.0083 - val_mae: 0.0567 - val_root_mean_squared_error: 0.0910
# Epoch 53/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0923 - mse: 0.0180 - mae: 0.0923 - root_mean_squared_error: 0.134 - 0s 24us/sample - loss: 0.0477 - mse: 0.0067 - mae: 0.0477 - root_mean_squared_error: 0.0818 - val_loss: 0.0564 - val_mse: 0.0082 - val_mae: 0.0564 - val_root_mean_squared_error: 0.0908
# Epoch 54/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0475 - mse: 0.0067 - mae: 0.0475 - root_mean_squared_error: 0.0817 - val_loss: 0.0562 - val_mse: 0.0082 - val_mae: 0.0562 - val_root_mean_squared_error: 0.0906
# Epoch 55/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0472 - mse: 0.0066 - mae: 0.0472 - root_mean_squared_error: 0.0815 - val_loss: 0.0559 - val_mse: 0.0082 - val_mae: 0.0559 - val_root_mean_squared_error: 0.0904
# Epoch 56/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0470 - mse: 0.0066 - mae: 0.0470 - root_mean_squared_error: 0.0813 - val_loss: 0.0557 - val_mse: 0.0081 - val_mae: 0.0557 - val_root_mean_squared_error: 0.0902
# Epoch 57/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0468 - mse: 0.0066 - mae: 0.0468 - root_mean_squared_error: 0.0811 - val_loss: 0.0554 - val_mse: 0.0081 - val_mae: 0.0554 - val_root_mean_squared_error: 0.0900
# Epoch 58/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0465 - mse: 0.0066 - mae: 0.0465 - root_mean_squared_error: 0.0810 - val_loss: 0.0552 - val_mse: 0.0081 - val_mae: 0.0552 - val_root_mean_squared_error: 0.0898
# Epoch 59/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0463 - mse: 0.0065 - mae: 0.0463 - root_mean_squared_error: 0.0808 - val_loss: 0.0549 - val_mse: 0.0080 - val_mae: 0.0549 - val_root_mean_squared_error: 0.0896
# Epoch 60/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0461 - mse: 0.0065 - mae: 0.0461 - root_mean_squared_error: 0.0807 - val_loss: 0.0547 - val_mse: 0.0080 - val_mae: 0.0547 - val_root_mean_squared_error: 0.0894
# Epoch 61/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0459 - mse: 0.0065 - mae: 0.0459 - root_mean_squared_error: 0.0805 - val_loss: 0.0544 - val_mse: 0.0080 - val_mae: 0.0544 - val_root_mean_squared_error: 0.0892
# Epoch 62/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0457 - mse: 0.0065 - mae: 0.0457 - root_mean_squared_error: 0.0804 - val_loss: 0.0542 - val_mse: 0.0079 - val_mae: 0.0542 - val_root_mean_squared_error: 0.0891
# Epoch 63/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0455 - mse: 0.0064 - mae: 0.0455 - root_mean_squared_error: 0.0803 - val_loss: 0.0540 - val_mse: 0.0079 - val_mae: 0.0540 - val_root_mean_squared_error: 0.0889
# Epoch 64/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0453 - mse: 0.0064 - mae: 0.0453 - root_mean_squared_error: 0.0802 - val_loss: 0.0538 - val_mse: 0.0079 - val_mae: 0.0538 - val_root_mean_squared_error: 0.0888
# Epoch 65/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0451 - mse: 0.0064 - mae: 0.0451 - root_mean_squared_error: 0.0801 - val_loss: 0.0535 - val_mse: 0.0079 - val_mae: 0.0535 - val_root_mean_squared_error: 0.0886
# Epoch 66/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0450 - mse: 0.0064 - mae: 0.0450 - root_mean_squared_error: 0.0799 - val_loss: 0.0533 - val_mse: 0.0078 - val_mae: 0.0533 - val_root_mean_squared_error: 0.0885
# Epoch 67/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0461 - mse: 0.0068 - mae: 0.0461 - root_mean_squared_error: 0.082 - 0s 27us/sample - loss: 0.0448 - mse: 0.0064 - mae: 0.0448 - root_mean_squared_error: 0.0798 - val_loss: 0.0531 - val_mse: 0.0078 - val_mae: 0.0531 - val_root_mean_squared_error: 0.0883
# Epoch 68/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0446 - mse: 0.0064 - mae: 0.0446 - root_mean_squared_error: 0.0797 - val_loss: 0.0529 - val_mse: 0.0078 - val_mae: 0.0529 - val_root_mean_squared_error: 0.0882
# Epoch 69/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0444 - mse: 0.0063 - mae: 0.0444 - root_mean_squared_error: 0.0796 - val_loss: 0.0527 - val_mse: 0.0077 - val_mae: 0.0527 - val_root_mean_squared_error: 0.0880
# Epoch 70/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0443 - mse: 0.0063 - mae: 0.0443 - root_mean_squared_error: 0.0795 - val_loss: 0.0525 - val_mse: 0.0077 - val_mae: 0.0525 - val_root_mean_squared_error: 0.0879
# Epoch 71/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0441 - mse: 0.0063 - mae: 0.0441 - root_mean_squared_error: 0.0794 - val_loss: 0.0523 - val_mse: 0.0077 - val_mae: 0.0523 - val_root_mean_squared_error: 0.0878
# Epoch 72/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0439 - mse: 0.0063 - mae: 0.0439 - root_mean_squared_error: 0.0793 - val_loss: 0.0521 - val_mse: 0.0077 - val_mae: 0.0521 - val_root_mean_squared_error: 0.0877
# Epoch 73/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0438 - mse: 0.0063 - mae: 0.0438 - root_mean_squared_error: 0.0792 - val_loss: 0.0519 - val_mse: 0.0077 - val_mae: 0.0519 - val_root_mean_squared_error: 0.0876
# Epoch 74/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0437 - mse: 0.0063 - mae: 0.0437 - root_mean_squared_error: 0.0792 - val_loss: 0.0518 - val_mse: 0.0076 - val_mae: 0.0518 - val_root_mean_squared_error: 0.0874
# Epoch 75/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0435 - mse: 0.0063 - mae: 0.0435 - root_mean_squared_error: 0.0791 - val_loss: 0.0516 - val_mse: 0.0076 - val_mae: 0.0516 - val_root_mean_squared_error: 0.0873
# Epoch 76/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0434 - mse: 0.0062 - mae: 0.0434 - root_mean_squared_error: 0.0790 - val_loss: 0.0514 - val_mse: 0.0076 - val_mae: 0.0514 - val_root_mean_squared_error: 0.0872
# Epoch 77/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0432 - mse: 0.0062 - mae: 0.0432 - root_mean_squared_error: 0.0789 - val_loss: 0.0513 - val_mse: 0.0076 - val_mae: 0.0513 - val_root_mean_squared_error: 0.0871
# Epoch 78/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0431 - mse: 0.0062 - mae: 0.0431 - root_mean_squared_error: 0.0788 - val_loss: 0.0511 - val_mse: 0.0076 - val_mae: 0.0511 - val_root_mean_squared_error: 0.0870
# Epoch 79/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0430 - mse: 0.0062 - mae: 0.0430 - root_mean_squared_error: 0.0787 - val_loss: 0.0509 - val_mse: 0.0076 - val_mae: 0.0509 - val_root_mean_squared_error: 0.0869
# Epoch 80/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0428 - mse: 0.0062 - mae: 0.0428 - root_mean_squared_error: 0.0787 - val_loss: 0.0508 - val_mse: 0.0075 - val_mae: 0.0508 - val_root_mean_squared_error: 0.0869
# Epoch 81/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0427 - mse: 0.0062 - mae: 0.0427 - root_mean_squared_error: 0.0786 - val_loss: 0.0506 - val_mse: 0.0075 - val_mae: 0.0506 - val_root_mean_squared_error: 0.0868
# Epoch 82/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0426 - mse: 0.0062 - mae: 0.0426 - root_mean_squared_error: 0.0786 - val_loss: 0.0505 - val_mse: 0.0075 - val_mae: 0.0505 - val_root_mean_squared_error: 0.0867
# Epoch 83/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0425 - mse: 0.0062 - mae: 0.0425 - root_mean_squared_error: 0.0785 - val_loss: 0.0503 - val_mse: 0.0075 - val_mae: 0.0503 - val_root_mean_squared_error: 0.0866
# Epoch 84/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0424 - mse: 0.0062 - mae: 0.0424 - root_mean_squared_error: 0.0785 - val_loss: 0.0502 - val_mse: 0.0075 - val_mae: 0.0502 - val_root_mean_squared_error: 0.0866
# Epoch 85/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0422 - mse: 0.0061 - mae: 0.0422 - root_mean_squared_error: 0.0784 - val_loss: 0.0500 - val_mse: 0.0075 - val_mae: 0.0500 - val_root_mean_squared_error: 0.0865
# Epoch 86/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0421 - mse: 0.0061 - mae: 0.0421 - root_mean_squared_error: 0.0784 - val_loss: 0.0499 - val_mse: 0.0075 - val_mae: 0.0499 - val_root_mean_squared_error: 0.0864
# Epoch 87/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0420 - mse: 0.0061 - mae: 0.0420 - root_mean_squared_error: 0.0783 - val_loss: 0.0497 - val_mse: 0.0074 - val_mae: 0.0497 - val_root_mean_squared_error: 0.0863
# Epoch 88/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0419 - mse: 0.0061 - mae: 0.0419 - root_mean_squared_error: 0.0782 - val_loss: 0.0496 - val_mse: 0.0074 - val_mae: 0.0496 - val_root_mean_squared_error: 0.0862
# Epoch 89/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0418 - mse: 0.0061 - mae: 0.0418 - root_mean_squared_error: 0.0782 - val_loss: 0.0495 - val_mse: 0.0074 - val_mae: 0.0495 - val_root_mean_squared_error: 0.0862
# Epoch 90/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0417 - mse: 0.0061 - mae: 0.0417 - root_mean_squared_error: 0.0782 - val_loss: 0.0494 - val_mse: 0.0074 - val_mae: 0.0494 - val_root_mean_squared_error: 0.0861
# Epoch 91/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0416 - mse: 0.0061 - mae: 0.0416 - root_mean_squared_error: 0.0781 - val_loss: 0.0492 - val_mse: 0.0074 - val_mae: 0.0492 - val_root_mean_squared_error: 0.0861
# Epoch 92/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0415 - mse: 0.0061 - mae: 0.0415 - root_mean_squared_error: 0.0781 - val_loss: 0.0491 - val_mse: 0.0074 - val_mae: 0.0491 - val_root_mean_squared_error: 0.0860
# Epoch 93/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0414 - mse: 0.0061 - mae: 0.0414 - root_mean_squared_error: 0.0780 - val_loss: 0.0490 - val_mse: 0.0074 - val_mae: 0.0490 - val_root_mean_squared_error: 0.0860
# Epoch 94/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0413 - mse: 0.0061 - mae: 0.0413 - root_mean_squared_error: 0.0780 - val_loss: 0.0488 - val_mse: 0.0074 - val_mae: 0.0488 - val_root_mean_squared_error: 0.0859
# Epoch 95/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0412 - mse: 0.0061 - mae: 0.0412 - root_mean_squared_error: 0.0779 - val_loss: 0.0487 - val_mse: 0.0074 - val_mae: 0.0487 - val_root_mean_squared_error: 0.0859
# Epoch 96/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0411 - mse: 0.0061 - mae: 0.0411 - root_mean_squared_error: 0.0779 - val_loss: 0.0486 - val_mse: 0.0074 - val_mae: 0.0486 - val_root_mean_squared_error: 0.0858
# Epoch 97/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0410 - mse: 0.0061 - mae: 0.0410 - root_mean_squared_error: 0.0778 - val_loss: 0.0485 - val_mse: 0.0074 - val_mae: 0.0485 - val_root_mean_squared_error: 0.0857
# Epoch 98/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0410 - mse: 0.0060 - mae: 0.0410 - root_mean_squared_error: 0.0778 - val_loss: 0.0484 - val_mse: 0.0073 - val_mae: 0.0484 - val_root_mean_squared_error: 0.0857
# Epoch 99/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0409 - mse: 0.0060 - mae: 0.0409 - root_mean_squared_error: 0.0777 - val_loss: 0.0482 - val_mse: 0.0073 - val_mae: 0.0482 - val_root_mean_squared_error: 0.0856
# Epoch 100/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0408 - mse: 0.0060 - mae: 0.0408 - root_mean_squared_error: 0.0777 - val_loss: 0.0481 - val_mse: 0.0073 - val_mae: 0.0481 - val_root_mean_squared_error: 0.0856
# Epoch 101/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0407 - mse: 0.0060 - mae: 0.0407 - root_mean_squared_error: 0.0776 - val_loss: 0.0480 - val_mse: 0.0073 - val_mae: 0.0480 - val_root_mean_squared_error: 0.0855
# Epoch 102/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0406 - mse: 0.0060 - mae: 0.0406 - root_mean_squared_error: 0.0776 - val_loss: 0.0479 - val_mse: 0.0073 - val_mae: 0.0479 - val_root_mean_squared_error: 0.0854
# Epoch 103/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0406 - mse: 0.0060 - mae: 0.0406 - root_mean_squared_error: 0.0775 - val_loss: 0.0478 - val_mse: 0.0073 - val_mae: 0.0478 - val_root_mean_squared_error: 0.0854
# Epoch 104/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0405 - mse: 0.0060 - mae: 0.0405 - root_mean_squared_error: 0.0775 - val_loss: 0.0477 - val_mse: 0.0073 - val_mae: 0.0477 - val_root_mean_squared_error: 0.0853
# Epoch 105/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0404 - mse: 0.0060 - mae: 0.0404 - root_mean_squared_error: 0.0774 - val_loss: 0.0476 - val_mse: 0.0073 - val_mae: 0.0476 - val_root_mean_squared_error: 0.0853
# Epoch 106/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0404 - mse: 0.0060 - mae: 0.0404 - root_mean_squared_error: 0.0774 - val_loss: 0.0475 - val_mse: 0.0073 - val_mae: 0.0475 - val_root_mean_squared_error: 0.0852
# Epoch 107/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0403 - mse: 0.0060 - mae: 0.0403 - root_mean_squared_error: 0.0774 - val_loss: 0.0474 - val_mse: 0.0073 - val_mae: 0.0474 - val_root_mean_squared_error: 0.0852
# Epoch 108/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0402 - mse: 0.0060 - mae: 0.0402 - root_mean_squared_error: 0.0773 - val_loss: 0.0474 - val_mse: 0.0073 - val_mae: 0.0474 - val_root_mean_squared_error: 0.0852
# Epoch 109/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0402 - mse: 0.0060 - mae: 0.0402 - root_mean_squared_error: 0.0773 - val_loss: 0.0473 - val_mse: 0.0072 - val_mae: 0.0473 - val_root_mean_squared_error: 0.0851
# Epoch 110/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0401 - mse: 0.0060 - mae: 0.0401 - root_mean_squared_error: 0.0773 - val_loss: 0.0472 - val_mse: 0.0072 - val_mae: 0.0472 - val_root_mean_squared_error: 0.0851
# Epoch 111/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0400 - mse: 0.0060 - mae: 0.0400 - root_mean_squared_error: 0.0773 - val_loss: 0.0471 - val_mse: 0.0072 - val_mae: 0.0471 - val_root_mean_squared_error: 0.0851
# Epoch 112/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0400 - mse: 0.0060 - mae: 0.0400 - root_mean_squared_error: 0.0772 - val_loss: 0.0470 - val_mse: 0.0072 - val_mae: 0.0470 - val_root_mean_squared_error: 0.0850
# Epoch 113/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0399 - mse: 0.0060 - mae: 0.0399 - root_mean_squared_error: 0.0772 - val_loss: 0.0470 - val_mse: 0.0072 - val_mae: 0.0470 - val_root_mean_squared_error: 0.0850
# Epoch 114/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0399 - mse: 0.0060 - mae: 0.0399 - root_mean_squared_error: 0.0772 - val_loss: 0.0469 - val_mse: 0.0072 - val_mae: 0.0469 - val_root_mean_squared_error: 0.0850
# Epoch 115/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0398 - mse: 0.0059 - mae: 0.0398 - root_mean_squared_error: 0.0771 - val_loss: 0.0468 - val_mse: 0.0072 - val_mae: 0.0468 - val_root_mean_squared_error: 0.0850
# Epoch 116/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0398 - mse: 0.0059 - mae: 0.0398 - root_mean_squared_error: 0.0771 - val_loss: 0.0468 - val_mse: 0.0072 - val_mae: 0.0468 - val_root_mean_squared_error: 0.0850
# Epoch 117/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0397 - mse: 0.0059 - mae: 0.0397 - root_mean_squared_error: 0.0771 - val_loss: 0.0467 - val_mse: 0.0072 - val_mae: 0.0467 - val_root_mean_squared_error: 0.0850
# Epoch 118/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0397 - mse: 0.0059 - mae: 0.0397 - root_mean_squared_error: 0.0771 - val_loss: 0.0466 - val_mse: 0.0072 - val_mae: 0.0466 - val_root_mean_squared_error: 0.0850
# Epoch 119/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0396 - mse: 0.0059 - mae: 0.0396 - root_mean_squared_error: 0.0771 - val_loss: 0.0466 - val_mse: 0.0072 - val_mae: 0.0466 - val_root_mean_squared_error: 0.0849
# Epoch 120/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0396 - mse: 0.0059 - mae: 0.0396 - root_mean_squared_error: 0.0771 - val_loss: 0.0465 - val_mse: 0.0072 - val_mae: 0.0465 - val_root_mean_squared_error: 0.0849
# Epoch 121/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0395 - mse: 0.0059 - mae: 0.0395 - root_mean_squared_error: 0.0770 - val_loss: 0.0464 - val_mse: 0.0072 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0848
# Epoch 122/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0395 - mse: 0.0059 - mae: 0.0395 - root_mean_squared_error: 0.0770 - val_loss: 0.0464 - val_mse: 0.0072 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0848
# Epoch 123/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0395 - mse: 0.0059 - mae: 0.0395 - root_mean_squared_error: 0.0770 - val_loss: 0.0463 - val_mse: 0.0072 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0848
# Epoch 124/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0394 - mse: 0.0059 - mae: 0.0394 - root_mean_squared_error: 0.0770 - val_loss: 0.0463 - val_mse: 0.0072 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0848
# Epoch 125/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0394 - mse: 0.0059 - mae: 0.0394 - root_mean_squared_error: 0.0770 - val_loss: 0.0462 - val_mse: 0.0072 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0848
# Epoch 126/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0394 - mse: 0.0059 - mae: 0.0394 - root_mean_squared_error: 0.0770 - val_loss: 0.0461 - val_mse: 0.0072 - val_mae: 0.0461 - val_root_mean_squared_error: 0.0848
# Epoch 127/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0393 - mse: 0.0059 - mae: 0.0393 - root_mean_squared_error: 0.0770 - val_loss: 0.0461 - val_mse: 0.0072 - val_mae: 0.0461 - val_root_mean_squared_error: 0.0848
# Epoch 128/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0393 - mse: 0.0059 - mae: 0.0393 - root_mean_squared_error: 0.0769 - val_loss: 0.0460 - val_mse: 0.0072 - val_mae: 0.0460 - val_root_mean_squared_error: 0.0847
# Epoch 129/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0392 - mse: 0.0059 - mae: 0.0392 - root_mean_squared_error: 0.0769 - val_loss: 0.0460 - val_mse: 0.0072 - val_mae: 0.0460 - val_root_mean_squared_error: 0.0847
# Epoch 130/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0392 - mse: 0.0059 - mae: 0.0392 - root_mean_squared_error: 0.0769 - val_loss: 0.0459 - val_mse: 0.0072 - val_mae: 0.0459 - val_root_mean_squared_error: 0.0847
# Epoch 131/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0392 - mse: 0.0059 - mae: 0.0392 - root_mean_squared_error: 0.0769 - val_loss: 0.0459 - val_mse: 0.0072 - val_mae: 0.0459 - val_root_mean_squared_error: 0.0847
# Epoch 132/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0391 - mse: 0.0059 - mae: 0.0391 - root_mean_squared_error: 0.0769 - val_loss: 0.0458 - val_mse: 0.0072 - val_mae: 0.0458 - val_root_mean_squared_error: 0.0846
# Epoch 133/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0391 - mse: 0.0059 - mae: 0.0391 - root_mean_squared_error: 0.0769 - val_loss: 0.0458 - val_mse: 0.0072 - val_mae: 0.0458 - val_root_mean_squared_error: 0.0846
# Epoch 134/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0391 - mse: 0.0059 - mae: 0.0391 - root_mean_squared_error: 0.0769 - val_loss: 0.0457 - val_mse: 0.0072 - val_mae: 0.0457 - val_root_mean_squared_error: 0.0846
# Epoch 135/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0391 - mse: 0.0059 - mae: 0.0391 - root_mean_squared_error: 0.0768 - val_loss: 0.0457 - val_mse: 0.0072 - val_mae: 0.0457 - val_root_mean_squared_error: 0.0846
# Epoch 136/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0390 - mse: 0.0059 - mae: 0.0390 - root_mean_squared_error: 0.0768 - val_loss: 0.0456 - val_mse: 0.0072 - val_mae: 0.0456 - val_root_mean_squared_error: 0.0846
# Epoch 137/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0410 - mse: 0.0067 - mae: 0.0410 - root_mean_squared_error: 0.082 - 0s 34us/sample - loss: 0.0390 - mse: 0.0059 - mae: 0.0390 - root_mean_squared_error: 0.0768 - val_loss: 0.0456 - val_mse: 0.0071 - val_mae: 0.0456 - val_root_mean_squared_error: 0.0845
# Epoch 138/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0390 - mse: 0.0059 - mae: 0.0390 - root_mean_squared_error: 0.0768 - val_loss: 0.0456 - val_mse: 0.0071 - val_mae: 0.0456 - val_root_mean_squared_error: 0.0845
# Epoch 139/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0390 - mse: 0.0059 - mae: 0.0390 - root_mean_squared_error: 0.0768 - val_loss: 0.0455 - val_mse: 0.0071 - val_mae: 0.0455 - val_root_mean_squared_error: 0.0846
# Epoch 140/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0389 - mse: 0.0059 - mae: 0.0389 - root_mean_squared_error: 0.0768 - val_loss: 0.0455 - val_mse: 0.0071 - val_mae: 0.0455 - val_root_mean_squared_error: 0.0845
# Epoch 141/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0389 - mse: 0.0059 - mae: 0.0389 - root_mean_squared_error: 0.0768 - val_loss: 0.0454 - val_mse: 0.0071 - val_mae: 0.0454 - val_root_mean_squared_error: 0.0845
# Epoch 142/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0389 - mse: 0.0059 - mae: 0.0389 - root_mean_squared_error: 0.0768 - val_loss: 0.0454 - val_mse: 0.0071 - val_mae: 0.0454 - val_root_mean_squared_error: 0.0845
# Epoch 143/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0389 - mse: 0.0059 - mae: 0.0389 - root_mean_squared_error: 0.0768 - val_loss: 0.0454 - val_mse: 0.0071 - val_mae: 0.0454 - val_root_mean_squared_error: 0.0845
# Epoch 144/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0388 - mse: 0.0059 - mae: 0.0388 - root_mean_squared_error: 0.0768 - val_loss: 0.0453 - val_mse: 0.0071 - val_mae: 0.0453 - val_root_mean_squared_error: 0.0844
# Epoch 145/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0388 - mse: 0.0059 - mae: 0.0388 - root_mean_squared_error: 0.0768 - val_loss: 0.0453 - val_mse: 0.0071 - val_mae: 0.0453 - val_root_mean_squared_error: 0.0844
# Epoch 146/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0403 - mse: 0.0065 - mae: 0.0403 - root_mean_squared_error: 0.080 - 0s 29us/sample - loss: 0.0388 - mse: 0.0059 - mae: 0.0388 - root_mean_squared_error: 0.0767 - val_loss: 0.0452 - val_mse: 0.0071 - val_mae: 0.0452 - val_root_mean_squared_error: 0.0844
# Epoch 147/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0388 - mse: 0.0059 - mae: 0.0388 - root_mean_squared_error: 0.0767 - val_loss: 0.0452 - val_mse: 0.0071 - val_mae: 0.0452 - val_root_mean_squared_error: 0.0844
# Epoch 148/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0387 - mse: 0.0059 - mae: 0.0387 - root_mean_squared_error: 0.0767 - val_loss: 0.0452 - val_mse: 0.0071 - val_mae: 0.0452 - val_root_mean_squared_error: 0.0844
# Epoch 149/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0387 - mse: 0.0059 - mae: 0.0387 - root_mean_squared_error: 0.0767 - val_loss: 0.0451 - val_mse: 0.0071 - val_mae: 0.0451 - val_root_mean_squared_error: 0.0844
# Epoch 150/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0387 - mse: 0.0059 - mae: 0.0387 - root_mean_squared_error: 0.0767 - val_loss: 0.0451 - val_mse: 0.0071 - val_mae: 0.0451 - val_root_mean_squared_error: 0.0844
# Epoch 151/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0387 - mse: 0.0059 - mae: 0.0387 - root_mean_squared_error: 0.0767 - val_loss: 0.0451 - val_mse: 0.0071 - val_mae: 0.0451 - val_root_mean_squared_error: 0.0843
# Epoch 152/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0387 - mse: 0.0059 - mae: 0.0387 - root_mean_squared_error: 0.0767 - val_loss: 0.0450 - val_mse: 0.0071 - val_mae: 0.0450 - val_root_mean_squared_error: 0.0843
# Epoch 153/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0386 - mse: 0.0059 - mae: 0.0386 - root_mean_squared_error: 0.0767 - val_loss: 0.0450 - val_mse: 0.0071 - val_mae: 0.0450 - val_root_mean_squared_error: 0.0843
# Epoch 154/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0386 - mse: 0.0059 - mae: 0.0386 - root_mean_squared_error: 0.0767 - val_loss: 0.0449 - val_mse: 0.0071 - val_mae: 0.0449 - val_root_mean_squared_error: 0.0843
# Epoch 155/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0386 - mse: 0.0059 - mae: 0.0386 - root_mean_squared_error: 0.0767 - val_loss: 0.0449 - val_mse: 0.0071 - val_mae: 0.0449 - val_root_mean_squared_error: 0.0843
# Epoch 156/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0386 - mse: 0.0059 - mae: 0.0386 - root_mean_squared_error: 0.0767 - val_loss: 0.0449 - val_mse: 0.0071 - val_mae: 0.0449 - val_root_mean_squared_error: 0.0843
# Epoch 157/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0386 - mse: 0.0059 - mae: 0.0386 - root_mean_squared_error: 0.0766 - val_loss: 0.0449 - val_mse: 0.0071 - val_mae: 0.0449 - val_root_mean_squared_error: 0.0843
# Epoch 158/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0386 - mse: 0.0059 - mae: 0.0386 - root_mean_squared_error: 0.0766 - val_loss: 0.0448 - val_mse: 0.0071 - val_mae: 0.0448 - val_root_mean_squared_error: 0.0842
# Epoch 159/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0385 - mse: 0.0059 - mae: 0.0385 - root_mean_squared_error: 0.0766 - val_loss: 0.0448 - val_mse: 0.0071 - val_mae: 0.0448 - val_root_mean_squared_error: 0.0842
# Epoch 160/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0385 - mse: 0.0059 - mae: 0.0385 - root_mean_squared_error: 0.0766 - val_loss: 0.0448 - val_mse: 0.0071 - val_mae: 0.0448 - val_root_mean_squared_error: 0.0842
# Epoch 161/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0385 - mse: 0.0059 - mae: 0.0385 - root_mean_squared_error: 0.0766 - val_loss: 0.0447 - val_mse: 0.0071 - val_mae: 0.0447 - val_root_mean_squared_error: 0.0842
# Epoch 162/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0385 - mse: 0.0059 - mae: 0.0385 - root_mean_squared_error: 0.0766 - val_loss: 0.0447 - val_mse: 0.0071 - val_mae: 0.0447 - val_root_mean_squared_error: 0.0842
# Epoch 163/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0385 - mse: 0.0059 - mae: 0.0385 - root_mean_squared_error: 0.0766 - val_loss: 0.0447 - val_mse: 0.0071 - val_mae: 0.0447 - val_root_mean_squared_error: 0.0842
# Epoch 164/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0384 - mse: 0.0059 - mae: 0.0384 - root_mean_squared_error: 0.0766 - val_loss: 0.0446 - val_mse: 0.0071 - val_mae: 0.0446 - val_root_mean_squared_error: 0.0842
# Epoch 165/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0384 - mse: 0.0059 - mae: 0.0384 - root_mean_squared_error: 0.0766 - val_loss: 0.0446 - val_mse: 0.0071 - val_mae: 0.0446 - val_root_mean_squared_error: 0.0842
# Epoch 166/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0384 - mse: 0.0059 - mae: 0.0384 - root_mean_squared_error: 0.0766 - val_loss: 0.0446 - val_mse: 0.0071 - val_mae: 0.0446 - val_root_mean_squared_error: 0.0842
# Epoch 167/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0384 - mse: 0.0059 - mae: 0.0384 - root_mean_squared_error: 0.0766 - val_loss: 0.0445 - val_mse: 0.0071 - val_mae: 0.0445 - val_root_mean_squared_error: 0.0842
# Epoch 168/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0384 - mse: 0.0059 - mae: 0.0384 - root_mean_squared_error: 0.0766 - val_loss: 0.0445 - val_mse: 0.0071 - val_mae: 0.0445 - val_root_mean_squared_error: 0.0842
# Epoch 169/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0384 - mse: 0.0059 - mae: 0.0384 - root_mean_squared_error: 0.0766 - val_loss: 0.0445 - val_mse: 0.0071 - val_mae: 0.0445 - val_root_mean_squared_error: 0.0842
# Epoch 170/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0383 - mse: 0.0059 - mae: 0.0383 - root_mean_squared_error: 0.0765 - val_loss: 0.0445 - val_mse: 0.0071 - val_mae: 0.0445 - val_root_mean_squared_error: 0.0842
# Epoch 171/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0383 - mse: 0.0059 - mae: 0.0383 - root_mean_squared_error: 0.0765 - val_loss: 0.0444 - val_mse: 0.0071 - val_mae: 0.0444 - val_root_mean_squared_error: 0.0841
# Epoch 172/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0383 - mse: 0.0059 - mae: 0.0383 - root_mean_squared_error: 0.0765 - val_loss: 0.0444 - val_mse: 0.0071 - val_mae: 0.0444 - val_root_mean_squared_error: 0.0841
# Epoch 173/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0383 - mse: 0.0059 - mae: 0.0383 - root_mean_squared_error: 0.0765 - val_loss: 0.0444 - val_mse: 0.0071 - val_mae: 0.0444 - val_root_mean_squared_error: 0.0841
# Epoch 174/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0383 - mse: 0.0059 - mae: 0.0383 - root_mean_squared_error: 0.0765 - val_loss: 0.0444 - val_mse: 0.0071 - val_mae: 0.0444 - val_root_mean_squared_error: 0.0841
# Epoch 175/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0383 - mse: 0.0059 - mae: 0.0383 - root_mean_squared_error: 0.0765 - val_loss: 0.0443 - val_mse: 0.0071 - val_mae: 0.0443 - val_root_mean_squared_error: 0.0841
# Epoch 176/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0383 - mse: 0.0059 - mae: 0.0383 - root_mean_squared_error: 0.0765 - val_loss: 0.0443 - val_mse: 0.0071 - val_mae: 0.0443 - val_root_mean_squared_error: 0.0840
# Epoch 177/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0382 - mse: 0.0059 - mae: 0.0382 - root_mean_squared_error: 0.0765 - val_loss: 0.0443 - val_mse: 0.0071 - val_mae: 0.0443 - val_root_mean_squared_error: 0.0841
# Epoch 178/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0382 - mse: 0.0058 - mae: 0.0382 - root_mean_squared_error: 0.0765 - val_loss: 0.0443 - val_mse: 0.0071 - val_mae: 0.0443 - val_root_mean_squared_error: 0.0841
# Epoch 179/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0382 - mse: 0.0058 - mae: 0.0382 - root_mean_squared_error: 0.0765 - val_loss: 0.0442 - val_mse: 0.0071 - val_mae: 0.0442 - val_root_mean_squared_error: 0.0840
# Epoch 180/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0382 - mse: 0.0058 - mae: 0.0382 - root_mean_squared_error: 0.0765 - val_loss: 0.0442 - val_mse: 0.0071 - val_mae: 0.0442 - val_root_mean_squared_error: 0.0840
# Epoch 181/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0382 - mse: 0.0058 - mae: 0.0382 - root_mean_squared_error: 0.0764 - val_loss: 0.0442 - val_mse: 0.0071 - val_mae: 0.0442 - val_root_mean_squared_error: 0.0840
# Epoch 182/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0382 - mse: 0.0058 - mae: 0.0382 - root_mean_squared_error: 0.0764 - val_loss: 0.0442 - val_mse: 0.0071 - val_mae: 0.0442 - val_root_mean_squared_error: 0.0840
# Epoch 183/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0382 - mse: 0.0058 - mae: 0.0382 - root_mean_squared_error: 0.0764 - val_loss: 0.0441 - val_mse: 0.0071 - val_mae: 0.0441 - val_root_mean_squared_error: 0.0840
# Epoch 184/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0382 - mse: 0.0058 - mae: 0.0382 - root_mean_squared_error: 0.0764 - val_loss: 0.0441 - val_mse: 0.0070 - val_mae: 0.0441 - val_root_mean_squared_error: 0.0839
# Epoch 185/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0381 - mse: 0.0058 - mae: 0.0381 - root_mean_squared_error: 0.0764 - val_loss: 0.0441 - val_mse: 0.0070 - val_mae: 0.0441 - val_root_mean_squared_error: 0.0839
# Epoch 186/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0381 - mse: 0.0058 - mae: 0.0381 - root_mean_squared_error: 0.0764 - val_loss: 0.0441 - val_mse: 0.0070 - val_mae: 0.0441 - val_root_mean_squared_error: 0.0839
# Epoch 187/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0381 - mse: 0.0058 - mae: 0.0381 - root_mean_squared_error: 0.0764 - val_loss: 0.0440 - val_mse: 0.0070 - val_mae: 0.0440 - val_root_mean_squared_error: 0.0839
# Epoch 188/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0381 - mse: 0.0058 - mae: 0.0381 - root_mean_squared_error: 0.0764 - val_loss: 0.0440 - val_mse: 0.0070 - val_mae: 0.0440 - val_root_mean_squared_error: 0.0839
# Epoch 189/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0381 - mse: 0.0058 - mae: 0.0381 - root_mean_squared_error: 0.0764 - val_loss: 0.0440 - val_mse: 0.0070 - val_mae: 0.0440 - val_root_mean_squared_error: 0.0839
# Epoch 190/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0381 - mse: 0.0058 - mae: 0.0381 - root_mean_squared_error: 0.0763 - val_loss: 0.0440 - val_mse: 0.0070 - val_mae: 0.0440 - val_root_mean_squared_error: 0.0839
# Epoch 191/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0381 - mse: 0.0058 - mae: 0.0381 - root_mean_squared_error: 0.0763 - val_loss: 0.0439 - val_mse: 0.0070 - val_mae: 0.0439 - val_root_mean_squared_error: 0.0839
# Epoch 192/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0381 - mse: 0.0058 - mae: 0.0381 - root_mean_squared_error: 0.0763 - val_loss: 0.0439 - val_mse: 0.0070 - val_mae: 0.0439 - val_root_mean_squared_error: 0.0839
# Epoch 193/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0380 - mse: 0.0058 - mae: 0.0380 - root_mean_squared_error: 0.0763 - val_loss: 0.0439 - val_mse: 0.0070 - val_mae: 0.0439 - val_root_mean_squared_error: 0.0839
# Epoch 194/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0380 - mse: 0.0058 - mae: 0.0380 - root_mean_squared_error: 0.0763 - val_loss: 0.0439 - val_mse: 0.0070 - val_mae: 0.0439 - val_root_mean_squared_error: 0.0839
# Epoch 195/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0380 - mse: 0.0058 - mae: 0.0380 - root_mean_squared_error: 0.0763 - val_loss: 0.0439 - val_mse: 0.0070 - val_mae: 0.0439 - val_root_mean_squared_error: 0.0838
# Epoch 196/500
# ...
# Epoch 436/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0368 - mse: 0.0057 - mae: 0.0368 - root_mean_squared_error: 0.0752 - val_loss: 0.0419 - val_mse: 0.0069 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0832
# Epoch 437/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0368 - mse: 0.0057 - mae: 0.0368 - root_mean_squared_error: 0.0752 - val_loss: 0.0419 - val_mse: 0.0069 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0832
# Epoch 438/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0368 - mse: 0.0057 - mae: 0.0368 - root_mean_squared_error: 0.0752 - val_loss: 0.0419 - val_mse: 0.0069 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0832
# Epoch 439/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0368 - mse: 0.0057 - mae: 0.0368 - root_mean_squared_error: 0.0752 - val_loss: 0.0419 - val_mse: 0.0069 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0832
# Epoch 440/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0368 - mse: 0.0057 - mae: 0.0368 - root_mean_squared_error: 0.0752 - val_loss: 0.0419 - val_mse: 0.0069 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0832
# Epoch 441/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0368 - mse: 0.0057 - mae: 0.0368 - root_mean_squared_error: 0.0752 - val_loss: 0.0419 - val_mse: 0.0069 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0832
# Epoch 442/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0368 - mse: 0.0057 - mae: 0.0368 - root_mean_squared_error: 0.0752 - val_loss: 0.0419 - val_mse: 0.0069 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0832
# Epoch 443/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0368 - mse: 0.0057 - mae: 0.0368 - root_mean_squared_error: 0.0752 - val_loss: 0.0419 - val_mse: 0.0069 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0831
# Epoch 444/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0368 - mse: 0.0056 - mae: 0.0368 - root_mean_squared_error: 0.0752 - val_loss: 0.0419 - val_mse: 0.0069 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0832
# Epoch 445/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0368 - mse: 0.0056 - mae: 0.0368 - root_mean_squared_error: 0.0752 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0832
# Epoch 446/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0368 - mse: 0.0056 - mae: 0.0368 - root_mean_squared_error: 0.0752 - val_loss: 0.0419 - val_mse: 0.0069 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0832
# Epoch 447/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0368 - mse: 0.0056 - mae: 0.0368 - root_mean_squared_error: 0.0752 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0832
# Epoch 448/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0368 - mse: 0.0056 - mae: 0.0368 - root_mean_squared_error: 0.0752 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0832
# Epoch 449/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0368 - mse: 0.0056 - mae: 0.0368 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0832
# Epoch 450/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0368 - mse: 0.0056 - mae: 0.0368 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 451/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0368 - mse: 0.0056 - mae: 0.0368 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0832
# Epoch 452/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0368 - mse: 0.0056 - mae: 0.0368 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0832
# Epoch 453/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0368 - mse: 0.0056 - mae: 0.0368 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 454/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0368 - mse: 0.0056 - mae: 0.0368 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0832
# Epoch 455/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0368 - mse: 0.0056 - mae: 0.0368 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0832
# Epoch 456/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0368 - mse: 0.0056 - mae: 0.0368 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0832
# Epoch 457/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0368 - mse: 0.0056 - mae: 0.0368 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0832
# Epoch 458/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0368 - mse: 0.0056 - mae: 0.0368 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 459/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0368 - mse: 0.0056 - mae: 0.0368 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 460/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0368 - mse: 0.0056 - mae: 0.0368 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0832
# Epoch 461/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0368 - mse: 0.0056 - mae: 0.0368 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 462/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0368 - mse: 0.0056 - mae: 0.0368 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 463/500
# 3175/3175 [==============================] - 0s 53us/sample - loss: 0.0368 - mse: 0.0056 - mae: 0.0368 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 464/500
# 3175/3175 [==============================] - 0s 51us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 465/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 466/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 467/500
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 468/500
# 3175/3175 [==============================] - 0s 52us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 469/500
# 3175/3175 [==============================] - 0s 53us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 470/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 471/500
# 3175/3175 [==============================] - 0s 52us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 472/500
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 473/500
# 3175/3175 [==============================] - 0s 52us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 474/500
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 475/500
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 476/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 477/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 478/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0751 - val_loss: 0.0418 - val_mse: 0.0069 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0831
# Epoch 479/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0751 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 480/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0751 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 481/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0751 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 482/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0750 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 483/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0750 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 484/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0751 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 485/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0751 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 486/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0750 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 487/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0750 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 488/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0750 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 489/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0750 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 490/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0750 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 491/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0750 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 492/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0750 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 493/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0750 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 494/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0750 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 495/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0750 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 496/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0750 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 497/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0750 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 498/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0750 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 499/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0750 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831
# Epoch 500/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0367 - mse: 0.0056 - mae: 0.0367 - root_mean_squared_error: 0.0750 - val_loss: 0.0417 - val_mse: 0.0069 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0831

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mae'],label='train mae')
pyplot.plot(history.history['val_mae'],label='val mae')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mse'],label='train mse')
pyplot.plot(history.history['val_mse'],label='val mse')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['root_mean_squared_error'],label='train rmse')
pyplot.plot(history.history['val_root_mean_squared_error'],label='val rmse')
pyplot.legend()
pyplot.show()
# Out:
# The testing MAE loss is: 0.039151207
# The testing MSE loss is: 0.0061556906
# The testing RMSE loss is: 0.07845821

# %%
pyplot.plot(test_y[:,3],color='red', label='True Values')
pyplot.plot(out[:,3],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()

# %%
dataset_test=pd.read_excel('F:\MS thesis data/Hopper Crossing.xlsx')
dataset_test=dataset_test.drop(['Date/Time','Flowd'],axis=1)
dataset_test.dropna(inplace=True)

# %%
shape=np.shape(dataset_test)
print(shape)
pyplot.plot(dataset_test)
# Out:
# (26285, 3)
# [<matplotlib.lines.Line2D at 0x25e44971748>,
#  <matplotlib.lines.Line2D at 0x25e44979f08>,
#  <matplotlib.lines.Line2D at 0x25e4497f788>]

# %%
dataset_test
# Out:
#        Cumulative rainfall   Flow  Level
# 0                      0.0  0.093    1.50
# 1                      0.0  0.093    1.50
# 2                      0.0  0.093    1.50
# 3                      0.0  0.093    1.50
# 4                      0.0  0.093    1.50
# ...                    ...    ...     ...
# 26280                  0.2  0.080    1.49
# 26281                  0.2  0.080    1.49
# 26282                  0.2  0.080    1.49
# 26283                  0.2  0.080    1.49
# 26284                  0.2  0.080    1.49
#
# [26285 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset_test)))
# Out:
# The std of original data is Cumulative rainfall    2.451640
# Flow                   0.520832
# Level                  0.083204
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset_test=dataset_test.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset_test.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset_test[:,0]== maxi[0])
    ind2=np.argwhere(dataset_test[:,1]== maxi[1])
    ind3=np.argwhere(dataset_test[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset_test.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset_test[:,0]== mini[0])
    ind2=np.argwhere(dataset_test[:,1]== mini[1])
    ind3=np.argwhere(dataset_test[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset_test)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset_test = min_max_scaler.fit_transform(dataset_test)
# Out:
# The std of cleaned data is 1.5154548293543502

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=4
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values

#one hour
#test_X, test_y = values[:, :-out_hour], values[:,-1]


test_X, test_y = values[:, :-out_hour], values[:, -out_hour: ]


test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6342, 30)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var1(t-2)  var2(t-2)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.230769   0.524545
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.215385   0.524545
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.123077   0.549980
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.092308   0.603309
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.092308   0.650485
#
#     var3(t-2)  var1(t-1)  var2(t-1)  var3(t-1)   var3(t)  var3(t+1)  \
# 6    0.776699   0.215385   0.524545   0.776699  0.791262   0.820388
# 7    0.776699   0.123077   0.549980   0.791262  0.820388   0.844660
# 8    0.791262   0.092308   0.603309   0.820388  0.844660   0.873786
# 9    0.820388   0.092308   0.650485   0.844660  0.873786   0.898058
# 10   0.844660   0.092308   0.709285   0.873786  0.898058   0.932039
#
#     var3(t+2)  var3(t+3)
# 6    0.844660   0.873786
# 7    0.873786   0.898058
# 8    0.898058   0.932039
# 9    0.932039   0.966019
# 10   0.966019   1.000000
#
# [5 rows x 22 columns]

# %%
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
# Out:
# The testing MAE loss is: 0.038513295
# The testing MSE loss is: 0.0060846317
# The testing RMSE loss is: 0.07800405

# %%
pyplot.plot(test_y[:,3],color='red', label='True Values')
pyplot.plot(out[:,3],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()
