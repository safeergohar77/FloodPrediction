# %%
import pandas as pd
from pandas import concat
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from sklearn import preprocessing
from tensorflow.keras import backend as K
#from sklearn.preprocessing import MinMaxScaler
#from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input, Dense, LSTM,GRU,SimpleRNN, Activation
from matplotlib import pyplot
#from sklearn.model_selection import train_test_split

# %%
"# convert series to supervised learning\n" 
#windowing of data
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1),
    for i in range(n_in, 0, -1): #startes from n_in and decreses to 0 by decreasing each time -1
     cols.append(df.shift(i))
     names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
     cols.append(df.shift(-i))
     if i == 0:
       names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
     else:
       names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together\n",
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values\n",
    if dropnan:
      agg.dropna(inplace=True)
    return agg

# %%
#def root_mean_squared_error(y_true, y_pred):
 #       return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
dataset1=pd.read_excel('F:\MS thesis data/Brooklyn.xlsx')
dataset1=dataset1.drop(['Date/Time','Flowd'],axis=1)
dataset1.dropna(inplace=True)

# %%
shape=np.shape(dataset1)
print(shape)
pyplot.plot(dataset1)
# Out:
# (26302, 3)
# [<matplotlib.lines.Line2D at 0x1ba9181f4c8>,
#  <matplotlib.lines.Line2D at 0x1ba918144c8>,
#  <matplotlib.lines.Line2D at 0x1ba91813c08>]

# %%
dataset1
# Out:
#        Cumulative rainfall    Flow  Level
# 0                       0.0  0.172   0.352
# 1                       0.0  0.180   0.356
# 2                       0.0  0.180   0.356
# 3                       0.0  0.189   0.360
# 4                       0.0  0.189   0.360
# ...                     ...    ...     ...
# 26297                   0.0  0.025   0.232
# 26298                   0.0  0.023   0.228
# 26299                   0.0  0.023   0.228
# 26300                   0.0  0.023   0.228
# 26301                   0.0  0.023   0.228
#
# [26302 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset1)))
# Out:
# The std of original data is Cumulative rainfall     2.872616
# Flow                    1.306642
# Level                   0.147238
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset=dataset1.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset[:,0]== maxi[0])
    ind2=np.argwhere(dataset[:,1]== maxi[1])
    ind3=np.argwhere(dataset[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset[:,0]== mini[0])
    ind2=np.argwhere(dataset[:,1]== mini[1])
    ind3=np.argwhere(dataset[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset = min_max_scaler.fit_transform(dataset)
# Out:
# The std of cleaned data is 1.626639593959813

# %%
pyplot.plot(dataset)
# Out:
# [<matplotlib.lines.Line2D at 0x1ba910fe608>,
#  <matplotlib.lines.Line2D at 0x1ba9105d508>,
#  <matplotlib.lines.Line2D at 0x1ba9105d6c8>]

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=1
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values
train_size  = int(len(dataset) * 0.50)
val_size=int(len(dataset) * 0.75)
train_X, train_y = values[0:train_size, :-out_hour], values[0:train_size,-out_hour: ]
val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-out_hour: ]
test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-out_hour:]
#for last hour
#train_X, train_y = values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]  #for only last hour
#val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]
#test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-1]
print(train_X, train_y)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6345, 21)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  var2(t-3)  var3(t-3)  \
# 6    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 7    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 8    0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
# 9    0.215385   0.524545   0.776699   0.123077   0.549980   0.791262
# 10   0.123077   0.549980   0.791262   0.092308   0.603309   0.820388
#
#     var1(t-2)  var2(t-2)  var3(t-2)  var1(t-1)  var2(t-1)  var3(t-1)   var3(t)
# 6    0.230769   0.524545   0.776699   0.215385   0.524545   0.776699  0.791262
# 7    0.215385   0.524545   0.776699   0.123077   0.549980   0.791262  0.820388
# 8    0.123077   0.549980   0.791262   0.092308   0.603309   0.820388  0.844660
# 9    0.092308   0.603309   0.820388   0.092308   0.650485   0.844660  0.873786
# 10   0.092308   0.650485   0.844660   0.092308   0.709285   0.873786  0.898058
# [[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]
#  [0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]
#  [0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]
#  ...
#  [0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]
#  [0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]
#  [0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]] [[0.79126215]
#  [0.8203884 ]
#  [0.8446602 ]
#  ...
#  [0.23786408]
#  [0.24271844]
#  [0.24757281]]

# %%
print(train_X, train_y)
# Out:
# [[[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]]
#
#  [[0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]]
#
#  [[0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]]
#
#  ...
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]]] [[0.79126215]
#  [0.8203884 ]
#  [0.8446602 ]
#  ...
#  [0.23786408]
#  [0.24271844]
#  [0.24757281]]

# %%
print(train_X.shape, train_y.shape, val_X.shape, val_y.shape)
# Out:
# (3175, 1, 18) (3175, 1) (1588, 1, 18) (1588, 1)

# %%
randomState = 46
np.random.seed(randomState)
#tensorflow.random.set_random_seed(randomState)
tensorflow.random.set_seed(randomState)
model = Sequential()
model.add(SimpleRNN(15,input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dense(22))
#model.add(Activation('relu'))    
model.add(Dense(out_hour,activation = "sigmoid"))
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.001)
#    opt=tensorflow.keras.optimizers.Adam(learning_rate=0.00075)
model.compile(loss='mae', optimizer=opt,metrics=['mse','mae',tensorflow.keras.metrics.RootMeanSquaredError()])
history = model.fit(train_X, train_y,validation_data=(val_X, val_y), epochs=500, batch_size=100,verbose=1,shuffle=False)
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)
# Out:
# Train on 3175 samples, validate on 1588 samples
# Epoch 1/500
# 3175/3175 [==============================] - 1s 343us/sample - loss: 0.2276 - mse: 0.0646 - mae: 0.2276 - root_mean_squared_error: 0.2541 - val_loss: 0.2302 - val_mse: 0.0683 - val_mae: 0.2302 - val_root_mean_squared_error: 0.2614
# Epoch 2/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1942 - mse: 0.0511 - mae: 0.1942 - root_mean_squared_error: 0.2260 - val_loss: 0.2060 - val_mse: 0.0570 - val_mae: 0.2060 - val_root_mean_squared_error: 0.2388
# Epoch 3/500
# 3175/3175 [==============================] - 0s 19us/sample - loss: 0.1764 - mse: 0.0451 - mae: 0.1764 - root_mean_squared_error: 0.2125 - val_loss: 0.1890 - val_mse: 0.0494 - val_mae: 0.1890 - val_root_mean_squared_error: 0.2222
# Epoch 4/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.1619 - mse: 0.0394 - mae: 0.1619 - root_mean_squared_error: 0.1984 - val_loss: 0.1735 - val_mse: 0.0421 - val_mae: 0.1735 - val_root_mean_squared_error: 0.2053
# Epoch 5/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1468 - mse: 0.0325 - mae: 0.1468 - root_mean_squared_error: 0.1803 - val_loss: 0.1571 - val_mse: 0.0346 - val_mae: 0.1571 - val_root_mean_squared_error: 0.1861
# Epoch 6/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.1303 - mse: 0.0251 - mae: 0.1303 - root_mean_squared_error: 0.1586 - val_loss: 0.1393 - val_mse: 0.0276 - val_mae: 0.1393 - val_root_mean_squared_error: 0.1660
# Epoch 7/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.1134 - mse: 0.0188 - mae: 0.1134 - root_mean_squared_error: 0.1370 - val_loss: 0.1217 - val_mse: 0.0217 - val_mae: 0.1217 - val_root_mean_squared_error: 0.1472
# Epoch 8/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0982 - mse: 0.0143 - mae: 0.0982 - root_mean_squared_error: 0.1197 - val_loss: 0.1070 - val_mse: 0.0172 - val_mae: 0.1070 - val_root_mean_squared_error: 0.1311
# Epoch 9/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0849 - mse: 0.0114 - mae: 0.0849 - root_mean_squared_error: 0.1069 - val_loss: 0.0951 - val_mse: 0.0140 - val_mae: 0.0951 - val_root_mean_squared_error: 0.1184
# Epoch 10/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0747 - mse: 0.0097 - mae: 0.0747 - root_mean_squared_error: 0.0987 - val_loss: 0.0858 - val_mse: 0.0120 - val_mae: 0.0858 - val_root_mean_squared_error: 0.1093
# Epoch 11/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0671 - mse: 0.0088 - mae: 0.0671 - root_mean_squared_error: 0.0938 - val_loss: 0.0791 - val_mse: 0.0107 - val_mae: 0.0791 - val_root_mean_squared_error: 0.1033
# Epoch 12/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0621 - mse: 0.0083 - mae: 0.0621 - root_mean_squared_error: 0.0910 - val_loss: 0.0743 - val_mse: 0.0099 - val_mae: 0.0743 - val_root_mean_squared_error: 0.0994
# Epoch 13/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0590 - mse: 0.0080 - mae: 0.0590 - root_mean_squared_error: 0.0894 - val_loss: 0.0709 - val_mse: 0.0094 - val_mae: 0.0709 - val_root_mean_squared_error: 0.0968
# Epoch 14/500
# 3175/3175 [==============================] - 0s 40us/sample - loss: 0.0570 - mse: 0.0077 - mae: 0.0570 - root_mean_squared_error: 0.0880 - val_loss: 0.0682 - val_mse: 0.0090 - val_mae: 0.0682 - val_root_mean_squared_error: 0.0947
# Epoch 15/500
# 3175/3175 [==============================] - 0s 40us/sample - loss: 0.0553 - mse: 0.0075 - mae: 0.0553 - root_mean_squared_error: 0.0866 - val_loss: 0.0659 - val_mse: 0.0086 - val_mae: 0.0659 - val_root_mean_squared_error: 0.0928
# Epoch 16/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0538 - mse: 0.0072 - mae: 0.0538 - root_mean_squared_error: 0.0851 - val_loss: 0.0640 - val_mse: 0.0083 - val_mae: 0.0640 - val_root_mean_squared_error: 0.0912
# Epoch 17/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0524 - mse: 0.0070 - mae: 0.0524 - root_mean_squared_error: 0.0835 - val_loss: 0.0623 - val_mse: 0.0080 - val_mae: 0.0623 - val_root_mean_squared_error: 0.0896
# Epoch 18/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0510 - mse: 0.0067 - mae: 0.0510 - root_mean_squared_error: 0.0817 - val_loss: 0.0607 - val_mse: 0.0077 - val_mae: 0.0607 - val_root_mean_squared_error: 0.0879
# Epoch 19/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0496 - mse: 0.0064 - mae: 0.0496 - root_mean_squared_error: 0.0797 - val_loss: 0.0592 - val_mse: 0.0074 - val_mae: 0.0592 - val_root_mean_squared_error: 0.0861
# Epoch 20/500
# 3175/3175 [==============================] - 0s 19us/sample - loss: 0.0481 - mse: 0.0060 - mae: 0.0481 - root_mean_squared_error: 0.0775 - val_loss: 0.0577 - val_mse: 0.0071 - val_mae: 0.0577 - val_root_mean_squared_error: 0.0842
# Epoch 21/500
# 3175/3175 [==============================] - 0s 19us/sample - loss: 0.0468 - mse: 0.0057 - mae: 0.0468 - root_mean_squared_error: 0.0752 - val_loss: 0.0562 - val_mse: 0.0068 - val_mae: 0.0562 - val_root_mean_squared_error: 0.0828
# Epoch 22/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0455 - mse: 0.0054 - mae: 0.0455 - root_mean_squared_error: 0.0732 - val_loss: 0.0548 - val_mse: 0.0066 - val_mae: 0.0548 - val_root_mean_squared_error: 0.0812
# Epoch 23/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0441 - mse: 0.0051 - mae: 0.0441 - root_mean_squared_error: 0.0712 - val_loss: 0.0534 - val_mse: 0.0064 - val_mae: 0.0534 - val_root_mean_squared_error: 0.0797
# Epoch 24/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0746 - mse: 0.0118 - mae: 0.0746 - root_mean_squared_error: 0.108 - 0s 23us/sample - loss: 0.0427 - mse: 0.0048 - mae: 0.0427 - root_mean_squared_error: 0.0691 - val_loss: 0.0521 - val_mse: 0.0062 - val_mae: 0.0521 - val_root_mean_squared_error: 0.0784
# Epoch 25/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0414 - mse: 0.0045 - mae: 0.0414 - root_mean_squared_error: 0.0671 - val_loss: 0.0508 - val_mse: 0.0059 - val_mae: 0.0508 - val_root_mean_squared_error: 0.0771
# Epoch 26/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0400 - mse: 0.0043 - mae: 0.0400 - root_mean_squared_error: 0.0652 - val_loss: 0.0495 - val_mse: 0.0057 - val_mae: 0.0495 - val_root_mean_squared_error: 0.0758
# Epoch 27/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0388 - mse: 0.0040 - mae: 0.0388 - root_mean_squared_error: 0.0635 - val_loss: 0.0484 - val_mse: 0.0056 - val_mae: 0.0484 - val_root_mean_squared_error: 0.0748
# Epoch 28/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0376 - mse: 0.0039 - mae: 0.0376 - root_mean_squared_error: 0.0621 - val_loss: 0.0473 - val_mse: 0.0055 - val_mae: 0.0473 - val_root_mean_squared_error: 0.0739
# Epoch 29/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0366 - mse: 0.0037 - mae: 0.0366 - root_mean_squared_error: 0.0609 - val_loss: 0.0464 - val_mse: 0.0053 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0731
# Epoch 30/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0357 - mse: 0.0036 - mae: 0.0357 - root_mean_squared_error: 0.0598 - val_loss: 0.0456 - val_mse: 0.0052 - val_mae: 0.0456 - val_root_mean_squared_error: 0.0724
# Epoch 31/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0349 - mse: 0.0035 - mae: 0.0349 - root_mean_squared_error: 0.0589 - val_loss: 0.0447 - val_mse: 0.0051 - val_mae: 0.0447 - val_root_mean_squared_error: 0.0716
# Epoch 32/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0342 - mse: 0.0034 - mae: 0.0342 - root_mean_squared_error: 0.0581 - val_loss: 0.0440 - val_mse: 0.0050 - val_mae: 0.0440 - val_root_mean_squared_error: 0.0709
# Epoch 33/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0337 - mse: 0.0033 - mae: 0.0337 - root_mean_squared_error: 0.0574 - val_loss: 0.0436 - val_mse: 0.0050 - val_mae: 0.0436 - val_root_mean_squared_error: 0.0706
# Epoch 34/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0332 - mse: 0.0032 - mae: 0.0332 - root_mean_squared_error: 0.0569 - val_loss: 0.0431 - val_mse: 0.0049 - val_mae: 0.0431 - val_root_mean_squared_error: 0.0703
# Epoch 35/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0596 - mse: 0.0079 - mae: 0.0596 - root_mean_squared_error: 0.088 - 0s 20us/sample - loss: 0.0329 - mse: 0.0032 - mae: 0.0329 - root_mean_squared_error: 0.0565 - val_loss: 0.0428 - val_mse: 0.0049 - val_mae: 0.0428 - val_root_mean_squared_error: 0.0701
# Epoch 36/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0326 - mse: 0.0032 - mae: 0.0326 - root_mean_squared_error: 0.0561 - val_loss: 0.0423 - val_mse: 0.0049 - val_mae: 0.0423 - val_root_mean_squared_error: 0.0697
# Epoch 37/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0322 - mse: 0.0031 - mae: 0.0322 - root_mean_squared_error: 0.0557 - val_loss: 0.0418 - val_mse: 0.0048 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0692
# Epoch 38/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0319 - mse: 0.0031 - mae: 0.0319 - root_mean_squared_error: 0.0554 - val_loss: 0.0414 - val_mse: 0.0047 - val_mae: 0.0414 - val_root_mean_squared_error: 0.0688
# Epoch 39/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0586 - mse: 0.0076 - mae: 0.0586 - root_mean_squared_error: 0.087 - 0s 20us/sample - loss: 0.0317 - mse: 0.0030 - mae: 0.0317 - root_mean_squared_error: 0.0551 - val_loss: 0.0411 - val_mse: 0.0047 - val_mae: 0.0411 - val_root_mean_squared_error: 0.0684
# Epoch 40/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0314 - mse: 0.0030 - mae: 0.0314 - root_mean_squared_error: 0.0548 - val_loss: 0.0408 - val_mse: 0.0047 - val_mae: 0.0408 - val_root_mean_squared_error: 0.0682
# Epoch 41/500
# 3175/3175 [==============================] - 0s 19us/sample - loss: 0.0312 - mse: 0.0030 - mae: 0.0312 - root_mean_squared_error: 0.0546 - val_loss: 0.0405 - val_mse: 0.0046 - val_mae: 0.0405 - val_root_mean_squared_error: 0.0679
# Epoch 42/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0310 - mse: 0.0030 - mae: 0.0310 - root_mean_squared_error: 0.0543 - val_loss: 0.0402 - val_mse: 0.0046 - val_mae: 0.0402 - val_root_mean_squared_error: 0.0676
# Epoch 43/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0307 - mse: 0.0029 - mae: 0.0307 - root_mean_squared_error: 0.0540 - val_loss: 0.0399 - val_mse: 0.0045 - val_mae: 0.0399 - val_root_mean_squared_error: 0.0672
# Epoch 44/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0305 - mse: 0.0029 - mae: 0.0305 - root_mean_squared_error: 0.0538 - val_loss: 0.0397 - val_mse: 0.0045 - val_mae: 0.0397 - val_root_mean_squared_error: 0.0670
# Epoch 45/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0303 - mse: 0.0029 - mae: 0.0303 - root_mean_squared_error: 0.0535 - val_loss: 0.0394 - val_mse: 0.0044 - val_mae: 0.0394 - val_root_mean_squared_error: 0.0667
# Epoch 46/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0300 - mse: 0.0028 - mae: 0.0300 - root_mean_squared_error: 0.0533 - val_loss: 0.0391 - val_mse: 0.0044 - val_mae: 0.0391 - val_root_mean_squared_error: 0.0664
# Epoch 47/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0298 - mse: 0.0028 - mae: 0.0298 - root_mean_squared_error: 0.0530 - val_loss: 0.0389 - val_mse: 0.0044 - val_mae: 0.0389 - val_root_mean_squared_error: 0.0661
# Epoch 48/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0296 - mse: 0.0028 - mae: 0.0296 - root_mean_squared_error: 0.0527 - val_loss: 0.0386 - val_mse: 0.0043 - val_mae: 0.0386 - val_root_mean_squared_error: 0.0658
# Epoch 49/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0294 - mse: 0.0028 - mae: 0.0294 - root_mean_squared_error: 0.0525 - val_loss: 0.0383 - val_mse: 0.0043 - val_mae: 0.0383 - val_root_mean_squared_error: 0.0655
# Epoch 50/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0292 - mse: 0.0027 - mae: 0.0292 - root_mean_squared_error: 0.0522 - val_loss: 0.0381 - val_mse: 0.0043 - val_mae: 0.0381 - val_root_mean_squared_error: 0.0653
# Epoch 51/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0289 - mse: 0.0027 - mae: 0.0289 - root_mean_squared_error: 0.0520 - val_loss: 0.0378 - val_mse: 0.0042 - val_mae: 0.0378 - val_root_mean_squared_error: 0.0650
# Epoch 52/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0287 - mse: 0.0027 - mae: 0.0287 - root_mean_squared_error: 0.0518 - val_loss: 0.0375 - val_mse: 0.0042 - val_mae: 0.0375 - val_root_mean_squared_error: 0.0647
# Epoch 53/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0284 - mse: 0.0027 - mae: 0.0284 - root_mean_squared_error: 0.0515 - val_loss: 0.0373 - val_mse: 0.0042 - val_mae: 0.0373 - val_root_mean_squared_error: 0.0644
# Epoch 54/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0283 - mse: 0.0026 - mae: 0.0283 - root_mean_squared_error: 0.0513 - val_loss: 0.0370 - val_mse: 0.0041 - val_mae: 0.0370 - val_root_mean_squared_error: 0.0642
# Epoch 55/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0281 - mse: 0.0026 - mae: 0.0281 - root_mean_squared_error: 0.0512 - val_loss: 0.0368 - val_mse: 0.0041 - val_mae: 0.0368 - val_root_mean_squared_error: 0.0640
# Epoch 56/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0279 - mse: 0.0026 - mae: 0.0279 - root_mean_squared_error: 0.0510 - val_loss: 0.0365 - val_mse: 0.0041 - val_mae: 0.0365 - val_root_mean_squared_error: 0.0637
# Epoch 57/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0277 - mse: 0.0026 - mae: 0.0277 - root_mean_squared_error: 0.0508 - val_loss: 0.0363 - val_mse: 0.0040 - val_mae: 0.0363 - val_root_mean_squared_error: 0.0635
# Epoch 58/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0275 - mse: 0.0026 - mae: 0.0275 - root_mean_squared_error: 0.0506 - val_loss: 0.0360 - val_mse: 0.0040 - val_mae: 0.0360 - val_root_mean_squared_error: 0.0633
# Epoch 59/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0274 - mse: 0.0025 - mae: 0.0274 - root_mean_squared_error: 0.0504 - val_loss: 0.0358 - val_mse: 0.0040 - val_mae: 0.0358 - val_root_mean_squared_error: 0.0632
# Epoch 60/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0272 - mse: 0.0025 - mae: 0.0272 - root_mean_squared_error: 0.0503 - val_loss: 0.0356 - val_mse: 0.0040 - val_mae: 0.0356 - val_root_mean_squared_error: 0.0629
# Epoch 61/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0271 - mse: 0.0025 - mae: 0.0271 - root_mean_squared_error: 0.0502 - val_loss: 0.0354 - val_mse: 0.0039 - val_mae: 0.0354 - val_root_mean_squared_error: 0.0628
# Epoch 62/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0269 - mse: 0.0025 - mae: 0.0269 - root_mean_squared_error: 0.0500 - val_loss: 0.0352 - val_mse: 0.0039 - val_mae: 0.0352 - val_root_mean_squared_error: 0.0626
# Epoch 63/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0267 - mse: 0.0025 - mae: 0.0267 - root_mean_squared_error: 0.0499 - val_loss: 0.0350 - val_mse: 0.0039 - val_mae: 0.0350 - val_root_mean_squared_error: 0.0624
# Epoch 64/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0265 - mse: 0.0025 - mae: 0.0265 - root_mean_squared_error: 0.0497 - val_loss: 0.0347 - val_mse: 0.0039 - val_mae: 0.0347 - val_root_mean_squared_error: 0.0622
# Epoch 65/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0264 - mse: 0.0025 - mae: 0.0264 - root_mean_squared_error: 0.0496 - val_loss: 0.0346 - val_mse: 0.0039 - val_mae: 0.0346 - val_root_mean_squared_error: 0.0621
# Epoch 66/500
# 3175/3175 [==============================] - 0s 19us/sample - loss: 0.0262 - mse: 0.0024 - mae: 0.0262 - root_mean_squared_error: 0.0494 - val_loss: 0.0344 - val_mse: 0.0038 - val_mae: 0.0344 - val_root_mean_squared_error: 0.0620
# Epoch 67/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0261 - mse: 0.0024 - mae: 0.0261 - root_mean_squared_error: 0.0494 - val_loss: 0.0342 - val_mse: 0.0038 - val_mae: 0.0342 - val_root_mean_squared_error: 0.0617
# Epoch 68/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0260 - mse: 0.0024 - mae: 0.0260 - root_mean_squared_error: 0.0492 - val_loss: 0.0340 - val_mse: 0.0038 - val_mae: 0.0340 - val_root_mean_squared_error: 0.0616
# Epoch 69/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0258 - mse: 0.0024 - mae: 0.0258 - root_mean_squared_error: 0.0491 - val_loss: 0.0338 - val_mse: 0.0038 - val_mae: 0.0338 - val_root_mean_squared_error: 0.0616
# Epoch 70/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0257 - mse: 0.0024 - mae: 0.0257 - root_mean_squared_error: 0.0490 - val_loss: 0.0336 - val_mse: 0.0038 - val_mae: 0.0336 - val_root_mean_squared_error: 0.0614
# Epoch 71/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0255 - mse: 0.0024 - mae: 0.0255 - root_mean_squared_error: 0.0489 - val_loss: 0.0334 - val_mse: 0.0038 - val_mae: 0.0334 - val_root_mean_squared_error: 0.0613
# Epoch 72/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0254 - mse: 0.0024 - mae: 0.0254 - root_mean_squared_error: 0.0489 - val_loss: 0.0332 - val_mse: 0.0037 - val_mae: 0.0332 - val_root_mean_squared_error: 0.0612
# Epoch 73/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0253 - mse: 0.0024 - mae: 0.0253 - root_mean_squared_error: 0.0488 - val_loss: 0.0331 - val_mse: 0.0038 - val_mae: 0.0331 - val_root_mean_squared_error: 0.0613
# Epoch 74/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0252 - mse: 0.0024 - mae: 0.0252 - root_mean_squared_error: 0.0488 - val_loss: 0.0329 - val_mse: 0.0037 - val_mae: 0.0329 - val_root_mean_squared_error: 0.0611
# Epoch 75/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0446 - mse: 0.0062 - mae: 0.0446 - root_mean_squared_error: 0.078 - 0s 20us/sample - loss: 0.0252 - mse: 0.0024 - mae: 0.0252 - root_mean_squared_error: 0.0487 - val_loss: 0.0329 - val_mse: 0.0038 - val_mae: 0.0329 - val_root_mean_squared_error: 0.0613
# Epoch 76/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0251 - mse: 0.0024 - mae: 0.0251 - root_mean_squared_error: 0.0486 - val_loss: 0.0328 - val_mse: 0.0038 - val_mae: 0.0328 - val_root_mean_squared_error: 0.0613
# Epoch 77/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0250 - mse: 0.0024 - mae: 0.0250 - root_mean_squared_error: 0.0486 - val_loss: 0.0326 - val_mse: 0.0037 - val_mae: 0.0326 - val_root_mean_squared_error: 0.0610
# Epoch 78/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0441 - mse: 0.0062 - mae: 0.0441 - root_mean_squared_error: 0.078 - 0s 20us/sample - loss: 0.0248 - mse: 0.0024 - mae: 0.0248 - root_mean_squared_error: 0.0486 - val_loss: 0.0323 - val_mse: 0.0037 - val_mae: 0.0323 - val_root_mean_squared_error: 0.0607
# Epoch 79/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0247 - mse: 0.0024 - mae: 0.0247 - root_mean_squared_error: 0.0485 - val_loss: 0.0322 - val_mse: 0.0037 - val_mae: 0.0322 - val_root_mean_squared_error: 0.0607
# Epoch 80/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0246 - mse: 0.0024 - mae: 0.0246 - root_mean_squared_error: 0.0485 - val_loss: 0.0320 - val_mse: 0.0037 - val_mae: 0.0320 - val_root_mean_squared_error: 0.0605
# Epoch 81/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0245 - mse: 0.0023 - mae: 0.0245 - root_mean_squared_error: 0.0484 - val_loss: 0.0320 - val_mse: 0.0037 - val_mae: 0.0320 - val_root_mean_squared_error: 0.0606
# Epoch 82/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0245 - mse: 0.0023 - mae: 0.0245 - root_mean_squared_error: 0.0484 - val_loss: 0.0318 - val_mse: 0.0037 - val_mae: 0.0318 - val_root_mean_squared_error: 0.0605
# Epoch 83/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0243 - mse: 0.0023 - mae: 0.0243 - root_mean_squared_error: 0.0484 - val_loss: 0.0317 - val_mse: 0.0036 - val_mae: 0.0317 - val_root_mean_squared_error: 0.0603
# Epoch 84/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0243 - mse: 0.0023 - mae: 0.0243 - root_mean_squared_error: 0.0483 - val_loss: 0.0315 - val_mse: 0.0036 - val_mae: 0.0315 - val_root_mean_squared_error: 0.0602
# Epoch 85/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0242 - mse: 0.0023 - mae: 0.0242 - root_mean_squared_error: 0.0483 - val_loss: 0.0314 - val_mse: 0.0036 - val_mae: 0.0314 - val_root_mean_squared_error: 0.0601
# Epoch 86/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0241 - mse: 0.0023 - mae: 0.0241 - root_mean_squared_error: 0.0483 - val_loss: 0.0313 - val_mse: 0.0036 - val_mae: 0.0313 - val_root_mean_squared_error: 0.0602
# Epoch 87/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0241 - mse: 0.0023 - mae: 0.0241 - root_mean_squared_error: 0.0483 - val_loss: 0.0312 - val_mse: 0.0036 - val_mae: 0.0312 - val_root_mean_squared_error: 0.0602
# Epoch 88/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0240 - mse: 0.0023 - mae: 0.0240 - root_mean_squared_error: 0.0483 - val_loss: 0.0311 - val_mse: 0.0036 - val_mae: 0.0311 - val_root_mean_squared_error: 0.0601
# Epoch 89/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0239 - mse: 0.0023 - mae: 0.0239 - root_mean_squared_error: 0.0482 - val_loss: 0.0310 - val_mse: 0.0036 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0600
# Epoch 90/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0238 - mse: 0.0023 - mae: 0.0238 - root_mean_squared_error: 0.0482 - val_loss: 0.0308 - val_mse: 0.0036 - val_mae: 0.0308 - val_root_mean_squared_error: 0.0599
# Epoch 91/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0237 - mse: 0.0023 - mae: 0.0237 - root_mean_squared_error: 0.0482 - val_loss: 0.0307 - val_mse: 0.0036 - val_mae: 0.0307 - val_root_mean_squared_error: 0.0598
# Epoch 92/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0237 - mse: 0.0023 - mae: 0.0237 - root_mean_squared_error: 0.0482 - val_loss: 0.0306 - val_mse: 0.0036 - val_mae: 0.0306 - val_root_mean_squared_error: 0.0597
# Epoch 93/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0236 - mse: 0.0023 - mae: 0.0236 - root_mean_squared_error: 0.0482 - val_loss: 0.0305 - val_mse: 0.0035 - val_mae: 0.0305 - val_root_mean_squared_error: 0.0595
# Epoch 94/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0235 - mse: 0.0023 - mae: 0.0235 - root_mean_squared_error: 0.0482 - val_loss: 0.0305 - val_mse: 0.0035 - val_mae: 0.0305 - val_root_mean_squared_error: 0.0596
# Epoch 95/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0235 - mse: 0.0023 - mae: 0.0235 - root_mean_squared_error: 0.0482 - val_loss: 0.0304 - val_mse: 0.0035 - val_mae: 0.0304 - val_root_mean_squared_error: 0.0595
# Epoch 96/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0234 - mse: 0.0023 - mae: 0.0234 - root_mean_squared_error: 0.0482 - val_loss: 0.0303 - val_mse: 0.0035 - val_mae: 0.0303 - val_root_mean_squared_error: 0.0595
# Epoch 97/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0234 - mse: 0.0023 - mae: 0.0234 - root_mean_squared_error: 0.0482 - val_loss: 0.0302 - val_mse: 0.0035 - val_mae: 0.0302 - val_root_mean_squared_error: 0.0594
# Epoch 98/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0233 - mse: 0.0023 - mae: 0.0233 - root_mean_squared_error: 0.0481 - val_loss: 0.0301 - val_mse: 0.0035 - val_mae: 0.0301 - val_root_mean_squared_error: 0.0593
# Epoch 99/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0232 - mse: 0.0023 - mae: 0.0232 - root_mean_squared_error: 0.0481 - val_loss: 0.0300 - val_mse: 0.0035 - val_mae: 0.0300 - val_root_mean_squared_error: 0.0593
# Epoch 100/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0232 - mse: 0.0023 - mae: 0.0232 - root_mean_squared_error: 0.0481 - val_loss: 0.0299 - val_mse: 0.0035 - val_mae: 0.0299 - val_root_mean_squared_error: 0.0592
# Epoch 101/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0232 - mse: 0.0023 - mae: 0.0232 - root_mean_squared_error: 0.0481 - val_loss: 0.0298 - val_mse: 0.0035 - val_mae: 0.0298 - val_root_mean_squared_error: 0.0593
# Epoch 102/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0231 - mse: 0.0023 - mae: 0.0231 - root_mean_squared_error: 0.0481 - val_loss: 0.0297 - val_mse: 0.0035 - val_mae: 0.0297 - val_root_mean_squared_error: 0.0593
# Epoch 103/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0231 - mse: 0.0023 - mae: 0.0231 - root_mean_squared_error: 0.0481 - val_loss: 0.0297 - val_mse: 0.0035 - val_mae: 0.0297 - val_root_mean_squared_error: 0.0595
# Epoch 104/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0231 - mse: 0.0023 - mae: 0.0231 - root_mean_squared_error: 0.0481 - val_loss: 0.0296 - val_mse: 0.0035 - val_mae: 0.0296 - val_root_mean_squared_error: 0.0596
# Epoch 105/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0231 - mse: 0.0023 - mae: 0.0231 - root_mean_squared_error: 0.0481 - val_loss: 0.0297 - val_mse: 0.0036 - val_mae: 0.0297 - val_root_mean_squared_error: 0.0597
# Epoch 106/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0232 - mse: 0.0023 - mae: 0.0232 - root_mean_squared_error: 0.0482 - val_loss: 0.0296 - val_mse: 0.0036 - val_mae: 0.0296 - val_root_mean_squared_error: 0.0597
# Epoch 107/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0232 - mse: 0.0023 - mae: 0.0232 - root_mean_squared_error: 0.0482 - val_loss: 0.0297 - val_mse: 0.0036 - val_mae: 0.0297 - val_root_mean_squared_error: 0.0598
# Epoch 108/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0232 - mse: 0.0023 - mae: 0.0232 - root_mean_squared_error: 0.0482 - val_loss: 0.0296 - val_mse: 0.0036 - val_mae: 0.0296 - val_root_mean_squared_error: 0.0598
# Epoch 109/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0231 - mse: 0.0023 - mae: 0.0231 - root_mean_squared_error: 0.0482 - val_loss: 0.0295 - val_mse: 0.0036 - val_mae: 0.0295 - val_root_mean_squared_error: 0.0597
# Epoch 110/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0231 - mse: 0.0023 - mae: 0.0231 - root_mean_squared_error: 0.0482 - val_loss: 0.0294 - val_mse: 0.0035 - val_mae: 0.0294 - val_root_mean_squared_error: 0.0596
# Epoch 111/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0230 - mse: 0.0023 - mae: 0.0230 - root_mean_squared_error: 0.0482 - val_loss: 0.0293 - val_mse: 0.0036 - val_mae: 0.0293 - val_root_mean_squared_error: 0.0596
# Epoch 112/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0230 - mse: 0.0023 - mae: 0.0230 - root_mean_squared_error: 0.0482 - val_loss: 0.0293 - val_mse: 0.0036 - val_mae: 0.0293 - val_root_mean_squared_error: 0.0597
# Epoch 113/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0230 - mse: 0.0023 - mae: 0.0230 - root_mean_squared_error: 0.0482 - val_loss: 0.0293 - val_mse: 0.0036 - val_mae: 0.0293 - val_root_mean_squared_error: 0.0597
# Epoch 114/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0229 - mse: 0.0023 - mae: 0.0229 - root_mean_squared_error: 0.0482 - val_loss: 0.0292 - val_mse: 0.0035 - val_mae: 0.0292 - val_root_mean_squared_error: 0.0595
# Epoch 115/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0229 - mse: 0.0023 - mae: 0.0229 - root_mean_squared_error: 0.0482 - val_loss: 0.0291 - val_mse: 0.0035 - val_mae: 0.0291 - val_root_mean_squared_error: 0.0595
# Epoch 116/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0228 - mse: 0.0023 - mae: 0.0228 - root_mean_squared_error: 0.0481 - val_loss: 0.0290 - val_mse: 0.0035 - val_mae: 0.0290 - val_root_mean_squared_error: 0.0594
# Epoch 117/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0228 - mse: 0.0023 - mae: 0.0228 - root_mean_squared_error: 0.0482 - val_loss: 0.0290 - val_mse: 0.0035 - val_mae: 0.0290 - val_root_mean_squared_error: 0.0595
# Epoch 118/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0228 - mse: 0.0023 - mae: 0.0228 - root_mean_squared_error: 0.0482 - val_loss: 0.0289 - val_mse: 0.0035 - val_mae: 0.0289 - val_root_mean_squared_error: 0.0594
# Epoch 119/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0227 - mse: 0.0023 - mae: 0.0227 - root_mean_squared_error: 0.0482 - val_loss: 0.0289 - val_mse: 0.0035 - val_mae: 0.0289 - val_root_mean_squared_error: 0.0594
# Epoch 120/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0227 - mse: 0.0023 - mae: 0.0227 - root_mean_squared_error: 0.0482 - val_loss: 0.0288 - val_mse: 0.0035 - val_mae: 0.0288 - val_root_mean_squared_error: 0.0593
# Epoch 121/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0227 - mse: 0.0023 - mae: 0.0227 - root_mean_squared_error: 0.0482 - val_loss: 0.0287 - val_mse: 0.0035 - val_mae: 0.0287 - val_root_mean_squared_error: 0.0593
# Epoch 122/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0227 - mse: 0.0023 - mae: 0.0227 - root_mean_squared_error: 0.0482 - val_loss: 0.0287 - val_mse: 0.0035 - val_mae: 0.0287 - val_root_mean_squared_error: 0.0594
# Epoch 123/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0227 - mse: 0.0023 - mae: 0.0227 - root_mean_squared_error: 0.0482 - val_loss: 0.0287 - val_mse: 0.0035 - val_mae: 0.0287 - val_root_mean_squared_error: 0.0595
# Epoch 124/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0227 - mse: 0.0023 - mae: 0.0227 - root_mean_squared_error: 0.0482 - val_loss: 0.0288 - val_mse: 0.0035 - val_mae: 0.0288 - val_root_mean_squared_error: 0.0595
# Epoch 125/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0227 - mse: 0.0023 - mae: 0.0227 - root_mean_squared_error: 0.0483 - val_loss: 0.0287 - val_mse: 0.0035 - val_mae: 0.0287 - val_root_mean_squared_error: 0.0594
# Epoch 126/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0226 - mse: 0.0023 - mae: 0.0226 - root_mean_squared_error: 0.0482 - val_loss: 0.0285 - val_mse: 0.0035 - val_mae: 0.0285 - val_root_mean_squared_error: 0.0593
# Epoch 127/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0225 - mse: 0.0023 - mae: 0.0225 - root_mean_squared_error: 0.0482 - val_loss: 0.0285 - val_mse: 0.0035 - val_mae: 0.0285 - val_root_mean_squared_error: 0.0592
# Epoch 128/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0225 - mse: 0.0023 - mae: 0.0225 - root_mean_squared_error: 0.0482 - val_loss: 0.0283 - val_mse: 0.0035 - val_mae: 0.0283 - val_root_mean_squared_error: 0.0590
# Epoch 129/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0224 - mse: 0.0023 - mae: 0.0224 - root_mean_squared_error: 0.0481 - val_loss: 0.0283 - val_mse: 0.0035 - val_mae: 0.0283 - val_root_mean_squared_error: 0.0591
# Epoch 130/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0224 - mse: 0.0023 - mae: 0.0224 - root_mean_squared_error: 0.0482 - val_loss: 0.0283 - val_mse: 0.0035 - val_mae: 0.0283 - val_root_mean_squared_error: 0.0591
# Epoch 131/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0224 - mse: 0.0023 - mae: 0.0224 - root_mean_squared_error: 0.0482 - val_loss: 0.0283 - val_mse: 0.0035 - val_mae: 0.0283 - val_root_mean_squared_error: 0.0591
# Epoch 132/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0224 - mse: 0.0023 - mae: 0.0224 - root_mean_squared_error: 0.0482 - val_loss: 0.0282 - val_mse: 0.0035 - val_mae: 0.0282 - val_root_mean_squared_error: 0.0591
# Epoch 133/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0224 - mse: 0.0023 - mae: 0.0224 - root_mean_squared_error: 0.0482 - val_loss: 0.0282 - val_mse: 0.0035 - val_mae: 0.0282 - val_root_mean_squared_error: 0.0591
# Epoch 134/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0224 - mse: 0.0023 - mae: 0.0224 - root_mean_squared_error: 0.0482 - val_loss: 0.0280 - val_mse: 0.0035 - val_mae: 0.0280 - val_root_mean_squared_error: 0.0588
# Epoch 135/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0223 - mse: 0.0023 - mae: 0.0223 - root_mean_squared_error: 0.0481 - val_loss: 0.0281 - val_mse: 0.0035 - val_mae: 0.0281 - val_root_mean_squared_error: 0.0591
# Epoch 136/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0223 - mse: 0.0023 - mae: 0.0223 - root_mean_squared_error: 0.0482 - val_loss: 0.0281 - val_mse: 0.0035 - val_mae: 0.0281 - val_root_mean_squared_error: 0.0591
# Epoch 137/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0223 - mse: 0.0023 - mae: 0.0223 - root_mean_squared_error: 0.0482 - val_loss: 0.0280 - val_mse: 0.0035 - val_mae: 0.0280 - val_root_mean_squared_error: 0.0590
# Epoch 138/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0223 - mse: 0.0023 - mae: 0.0223 - root_mean_squared_error: 0.0482 - val_loss: 0.0279 - val_mse: 0.0035 - val_mae: 0.0279 - val_root_mean_squared_error: 0.0588
# Epoch 139/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0222 - mse: 0.0023 - mae: 0.0222 - root_mean_squared_error: 0.0482 - val_loss: 0.0279 - val_mse: 0.0035 - val_mae: 0.0279 - val_root_mean_squared_error: 0.0589
# Epoch 140/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0222 - mse: 0.0023 - mae: 0.0222 - root_mean_squared_error: 0.0482 - val_loss: 0.0279 - val_mse: 0.0035 - val_mae: 0.0279 - val_root_mean_squared_error: 0.0590
# Epoch 141/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0222 - mse: 0.0023 - mae: 0.0222 - root_mean_squared_error: 0.0482 - val_loss: 0.0279 - val_mse: 0.0035 - val_mae: 0.0279 - val_root_mean_squared_error: 0.0591
# Epoch 142/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0417 - mse: 0.0064 - mae: 0.0417 - root_mean_squared_error: 0.079 - 0s 20us/sample - loss: 0.0222 - mse: 0.0023 - mae: 0.0222 - root_mean_squared_error: 0.0482 - val_loss: 0.0277 - val_mse: 0.0034 - val_mae: 0.0277 - val_root_mean_squared_error: 0.0587
# Epoch 143/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0221 - mse: 0.0023 - mae: 0.0221 - root_mean_squared_error: 0.0481 - val_loss: 0.0276 - val_mse: 0.0034 - val_mae: 0.0276 - val_root_mean_squared_error: 0.0587
# Epoch 144/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0220 - mse: 0.0023 - mae: 0.0220 - root_mean_squared_error: 0.0481 - val_loss: 0.0275 - val_mse: 0.0034 - val_mae: 0.0275 - val_root_mean_squared_error: 0.0586
# Epoch 145/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0220 - mse: 0.0023 - mae: 0.0220 - root_mean_squared_error: 0.0481 - val_loss: 0.0276 - val_mse: 0.0035 - val_mae: 0.0276 - val_root_mean_squared_error: 0.0588
# Epoch 146/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0221 - mse: 0.0023 - mae: 0.0221 - root_mean_squared_error: 0.0481 - val_loss: 0.0275 - val_mse: 0.0034 - val_mae: 0.0275 - val_root_mean_squared_error: 0.0586
# Epoch 147/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0220 - mse: 0.0023 - mae: 0.0220 - root_mean_squared_error: 0.0481 - val_loss: 0.0275 - val_mse: 0.0034 - val_mae: 0.0275 - val_root_mean_squared_error: 0.0586
# Epoch 148/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0220 - mse: 0.0023 - mae: 0.0220 - root_mean_squared_error: 0.0481 - val_loss: 0.0274 - val_mse: 0.0034 - val_mae: 0.0274 - val_root_mean_squared_error: 0.0585
# Epoch 149/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0219 - mse: 0.0023 - mae: 0.0219 - root_mean_squared_error: 0.0481 - val_loss: 0.0274 - val_mse: 0.0034 - val_mae: 0.0274 - val_root_mean_squared_error: 0.0585
# Epoch 150/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0219 - mse: 0.0023 - mae: 0.0219 - root_mean_squared_error: 0.0481 - val_loss: 0.0273 - val_mse: 0.0034 - val_mae: 0.0273 - val_root_mean_squared_error: 0.0585
# Epoch 151/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0219 - mse: 0.0023 - mae: 0.0219 - root_mean_squared_error: 0.0481 - val_loss: 0.0274 - val_mse: 0.0034 - val_mae: 0.0274 - val_root_mean_squared_error: 0.0586
# Epoch 152/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0219 - mse: 0.0023 - mae: 0.0219 - root_mean_squared_error: 0.0481 - val_loss: 0.0272 - val_mse: 0.0034 - val_mae: 0.0272 - val_root_mean_squared_error: 0.0583
# Epoch 153/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0218 - mse: 0.0023 - mae: 0.0218 - root_mean_squared_error: 0.0480 - val_loss: 0.0272 - val_mse: 0.0034 - val_mae: 0.0272 - val_root_mean_squared_error: 0.0583
# Epoch 154/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0217 - mse: 0.0023 - mae: 0.0217 - root_mean_squared_error: 0.0480 - val_loss: 0.0271 - val_mse: 0.0034 - val_mae: 0.0271 - val_root_mean_squared_error: 0.0581
# Epoch 155/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0217 - mse: 0.0023 - mae: 0.0217 - root_mean_squared_error: 0.0480 - val_loss: 0.0271 - val_mse: 0.0034 - val_mae: 0.0271 - val_root_mean_squared_error: 0.0582
# Epoch 156/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0217 - mse: 0.0023 - mae: 0.0217 - root_mean_squared_error: 0.0480 - val_loss: 0.0270 - val_mse: 0.0034 - val_mae: 0.0270 - val_root_mean_squared_error: 0.0580
# Epoch 157/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0217 - mse: 0.0023 - mae: 0.0217 - root_mean_squared_error: 0.0480 - val_loss: 0.0270 - val_mse: 0.0034 - val_mae: 0.0270 - val_root_mean_squared_error: 0.0581
# Epoch 158/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0216 - mse: 0.0023 - mae: 0.0216 - root_mean_squared_error: 0.0480 - val_loss: 0.0270 - val_mse: 0.0033 - val_mae: 0.0270 - val_root_mean_squared_error: 0.0578
# Epoch 159/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0216 - mse: 0.0023 - mae: 0.0216 - root_mean_squared_error: 0.0480 - val_loss: 0.0270 - val_mse: 0.0034 - val_mae: 0.0270 - val_root_mean_squared_error: 0.0579
# Epoch 160/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0216 - mse: 0.0023 - mae: 0.0216 - root_mean_squared_error: 0.0480 - val_loss: 0.0269 - val_mse: 0.0033 - val_mae: 0.0269 - val_root_mean_squared_error: 0.0578
# Epoch 161/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0216 - mse: 0.0023 - mae: 0.0216 - root_mean_squared_error: 0.0480 - val_loss: 0.0269 - val_mse: 0.0033 - val_mae: 0.0269 - val_root_mean_squared_error: 0.0579
# Epoch 162/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0216 - mse: 0.0023 - mae: 0.0216 - root_mean_squared_error: 0.0480 - val_loss: 0.0268 - val_mse: 0.0033 - val_mae: 0.0268 - val_root_mean_squared_error: 0.0578
# Epoch 163/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0216 - mse: 0.0023 - mae: 0.0216 - root_mean_squared_error: 0.0480 - val_loss: 0.0268 - val_mse: 0.0034 - val_mae: 0.0268 - val_root_mean_squared_error: 0.0580
# Epoch 164/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0215 - mse: 0.0023 - mae: 0.0215 - root_mean_squared_error: 0.0480 - val_loss: 0.0268 - val_mse: 0.0033 - val_mae: 0.0268 - val_root_mean_squared_error: 0.0578
# Epoch 165/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0215 - mse: 0.0023 - mae: 0.0215 - root_mean_squared_error: 0.0480 - val_loss: 0.0268 - val_mse: 0.0033 - val_mae: 0.0268 - val_root_mean_squared_error: 0.0578
# Epoch 166/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0215 - mse: 0.0023 - mae: 0.0215 - root_mean_squared_error: 0.0480 - val_loss: 0.0267 - val_mse: 0.0033 - val_mae: 0.0267 - val_root_mean_squared_error: 0.0578
# Epoch 167/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0215 - mse: 0.0023 - mae: 0.0215 - root_mean_squared_error: 0.0480 - val_loss: 0.0267 - val_mse: 0.0034 - val_mae: 0.0267 - val_root_mean_squared_error: 0.0579
# Epoch 168/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0215 - mse: 0.0023 - mae: 0.0215 - root_mean_squared_error: 0.0480 - val_loss: 0.0267 - val_mse: 0.0033 - val_mae: 0.0267 - val_root_mean_squared_error: 0.0577
# Epoch 169/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0215 - mse: 0.0023 - mae: 0.0215 - root_mean_squared_error: 0.0479 - val_loss: 0.0266 - val_mse: 0.0033 - val_mae: 0.0266 - val_root_mean_squared_error: 0.0577
# Epoch 170/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0214 - mse: 0.0023 - mae: 0.0214 - root_mean_squared_error: 0.0479 - val_loss: 0.0266 - val_mse: 0.0034 - val_mae: 0.0266 - val_root_mean_squared_error: 0.0580
# Epoch 171/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0400 - mse: 0.0062 - mae: 0.0400 - root_mean_squared_error: 0.078 - 0s 20us/sample - loss: 0.0214 - mse: 0.0023 - mae: 0.0214 - root_mean_squared_error: 0.0479 - val_loss: 0.0266 - val_mse: 0.0033 - val_mae: 0.0266 - val_root_mean_squared_error: 0.0578
# Epoch 172/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0401 - mse: 0.0062 - mae: 0.0401 - root_mean_squared_error: 0.078 - 0s 20us/sample - loss: 0.0214 - mse: 0.0023 - mae: 0.0214 - root_mean_squared_error: 0.0480 - val_loss: 0.0265 - val_mse: 0.0033 - val_mae: 0.0265 - val_root_mean_squared_error: 0.0577
# Epoch 173/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0400 - mse: 0.0062 - mae: 0.0400 - root_mean_squared_error: 0.078 - 0s 20us/sample - loss: 0.0214 - mse: 0.0023 - mae: 0.0214 - root_mean_squared_error: 0.0479 - val_loss: 0.0265 - val_mse: 0.0034 - val_mae: 0.0265 - val_root_mean_squared_error: 0.0579
# Epoch 174/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0214 - mse: 0.0023 - mae: 0.0214 - root_mean_squared_error: 0.0480 - val_loss: 0.0265 - val_mse: 0.0034 - val_mae: 0.0265 - val_root_mean_squared_error: 0.0579
# Epoch 175/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0214 - mse: 0.0023 - mae: 0.0214 - root_mean_squared_error: 0.0479 - val_loss: 0.0265 - val_mse: 0.0033 - val_mae: 0.0265 - val_root_mean_squared_error: 0.0578
# Epoch 176/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0214 - mse: 0.0023 - mae: 0.0214 - root_mean_squared_error: 0.0479 - val_loss: 0.0264 - val_mse: 0.0033 - val_mae: 0.0264 - val_root_mean_squared_error: 0.0577
# Epoch 177/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0214 - mse: 0.0023 - mae: 0.0214 - root_mean_squared_error: 0.0479 - val_loss: 0.0264 - val_mse: 0.0033 - val_mae: 0.0264 - val_root_mean_squared_error: 0.0576
# Epoch 178/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0213 - mse: 0.0023 - mae: 0.0213 - root_mean_squared_error: 0.0479 - val_loss: 0.0263 - val_mse: 0.0033 - val_mae: 0.0263 - val_root_mean_squared_error: 0.0577
# Epoch 179/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0214 - mse: 0.0023 - mae: 0.0214 - root_mean_squared_error: 0.0480 - val_loss: 0.0265 - val_mse: 0.0034 - val_mae: 0.0265 - val_root_mean_squared_error: 0.0580
# Epoch 180/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0214 - mse: 0.0023 - mae: 0.0214 - root_mean_squared_error: 0.0479 - val_loss: 0.0263 - val_mse: 0.0033 - val_mae: 0.0263 - val_root_mean_squared_error: 0.0578
# Epoch 181/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0213 - mse: 0.0023 - mae: 0.0213 - root_mean_squared_error: 0.0479 - val_loss: 0.0263 - val_mse: 0.0033 - val_mae: 0.0263 - val_root_mean_squared_error: 0.0578
# Epoch 182/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0213 - mse: 0.0023 - mae: 0.0213 - root_mean_squared_error: 0.0480 - val_loss: 0.0264 - val_mse: 0.0034 - val_mae: 0.0264 - val_root_mean_squared_error: 0.0582
# Epoch 183/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0213 - mse: 0.0023 - mae: 0.0213 - root_mean_squared_error: 0.0479 - val_loss: 0.0263 - val_mse: 0.0033 - val_mae: 0.0263 - val_root_mean_squared_error: 0.0579
# Epoch 184/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0212 - mse: 0.0023 - mae: 0.0212 - root_mean_squared_error: 0.0479 - val_loss: 0.0263 - val_mse: 0.0033 - val_mae: 0.0263 - val_root_mean_squared_error: 0.0578
# Epoch 185/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0212 - mse: 0.0023 - mae: 0.0212 - root_mean_squared_error: 0.0479 - val_loss: 0.0262 - val_mse: 0.0033 - val_mae: 0.0262 - val_root_mean_squared_error: 0.0577
# Epoch 186/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0213 - mse: 0.0023 - mae: 0.0213 - root_mean_squared_error: 0.0479 - val_loss: 0.0263 - val_mse: 0.0034 - val_mae: 0.0263 - val_root_mean_squared_error: 0.0580
# Epoch 187/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0213 - mse: 0.0023 - mae: 0.0213 - root_mean_squared_error: 0.0479 - val_loss: 0.0262 - val_mse: 0.0034 - val_mae: 0.0262 - val_root_mean_squared_error: 0.0580
# Epoch 188/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0213 - mse: 0.0023 - mae: 0.0213 - root_mean_squared_error: 0.0479 - val_loss: 0.0261 - val_mse: 0.0033 - val_mae: 0.0261 - val_root_mean_squared_error: 0.0577
# Epoch 189/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0212 - mse: 0.0023 - mae: 0.0212 - root_mean_squared_error: 0.0479 - val_loss: 0.0261 - val_mse: 0.0033 - val_mae: 0.0261 - val_root_mean_squared_error: 0.0578
# Epoch 190/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0212 - mse: 0.0023 - mae: 0.0212 - root_mean_squared_error: 0.0479 - val_loss: 0.0262 - val_mse: 0.0034 - val_mae: 0.0262 - val_root_mean_squared_error: 0.0580
# Epoch 191/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0213 - mse: 0.0023 - mae: 0.0213 - root_mean_squared_error: 0.0479 - val_loss: 0.0261 - val_mse: 0.0033 - val_mae: 0.0261 - val_root_mean_squared_error: 0.0579
# Epoch 192/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0212 - mse: 0.0023 - mae: 0.0212 - root_mean_squared_error: 0.0479 - val_loss: 0.0261 - val_mse: 0.0034 - val_mae: 0.0261 - val_root_mean_squared_error: 0.0579
# Epoch 193/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0212 - mse: 0.0023 - mae: 0.0212 - root_mean_squared_error: 0.0479 - val_loss: 0.0260 - val_mse: 0.0033 - val_mae: 0.0260 - val_root_mean_squared_error: 0.0578
# Epoch 194/500
# ...
# Epoch 436/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0571
# Epoch 437/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0200 - mse: 0.0022 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0572
# Epoch 438/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0200 - mse: 0.0022 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0572
# Epoch 439/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0200 - mse: 0.0022 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0572
# Epoch 440/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0200 - mse: 0.0022 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0572
# Epoch 441/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0200 - mse: 0.0022 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0571
# Epoch 442/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0200 - mse: 0.0022 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0572
# Epoch 443/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0200 - mse: 0.0022 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0573
# Epoch 444/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0200 - mse: 0.0023 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0572
# Epoch 445/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0572
# Epoch 446/500
# 3175/3175 [==============================] - 0s 47us/sample - loss: 0.0200 - mse: 0.0022 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0573
# Epoch 447/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0200 - mse: 0.0023 - mae: 0.0200 - root_mean_squared_error: 0.0475 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0573
# Epoch 448/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0200 - mse: 0.0023 - mae: 0.0200 - root_mean_squared_error: 0.0475 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0573
# Epoch 449/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0200 - mse: 0.0022 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0571
# Epoch 450/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0570
# Epoch 451/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0200 - mse: 0.0022 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0572
# Epoch 452/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0200 - mse: 0.0023 - mae: 0.0200 - root_mean_squared_error: 0.0475 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0572
# Epoch 453/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0200 - mse: 0.0022 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0572
# Epoch 454/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 455/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0200 - mse: 0.0023 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0571
# Epoch 456/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0200 - mse: 0.0022 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 457/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0200 - mse: 0.0023 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0572
# Epoch 458/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0200 - mse: 0.0023 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 459/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0200 - mse: 0.0022 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0573
# Epoch 460/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0200 - mse: 0.0023 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0573
# Epoch 461/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 462/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0571
# Epoch 463/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 464/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0200 - mse: 0.0023 - mae: 0.0200 - root_mean_squared_error: 0.0475 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0573
# Epoch 465/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0571
# Epoch 466/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0571
# Epoch 467/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0571
# Epoch 468/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0200 - mse: 0.0022 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0241 - val_mse: 0.0033 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0572
# Epoch 469/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 470/500
# 3175/3175 [==============================] - 0s 64us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0573
# Epoch 471/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 472/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0473 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 473/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0200 - mse: 0.0022 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0573
# Epoch 474/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0573
# Epoch 475/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0573
# Epoch 476/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0573
# Epoch 477/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0573
# Epoch 478/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 479/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0571
# Epoch 480/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0200 - mse: 0.0022 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 481/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 482/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0200 - mse: 0.0022 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 483/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0571
# Epoch 484/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0200 - mse: 0.0022 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0571
# Epoch 485/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0571
# Epoch 486/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0200 - mse: 0.0022 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 487/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0573
# Epoch 488/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 489/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 490/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0200 - mse: 0.0022 - mae: 0.0200 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0573
# Epoch 491/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 492/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 493/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0573
# Epoch 494/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 495/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 496/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 497/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0199 - mse: 0.0023 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 498/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0198 - mse: 0.0022 - mae: 0.0198 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0571
# Epoch 499/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0572
# Epoch 500/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0199 - mse: 0.0022 - mae: 0.0199 - root_mean_squared_error: 0.0474 - val_loss: 0.0240 - val_mse: 0.0033 - val_mae: 0.0240 - val_root_mean_squared_error: 0.0571

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mae'],label='train mae')
pyplot.plot(history.history['val_mae'],label='val mae')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mse'],label='train mse')
pyplot.plot(history.history['val_mse'],label='val mse')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['root_mean_squared_error'],label='train rmse')
pyplot.plot(history.history['val_root_mean_squared_error'],label='val rmse')
pyplot.legend()
pyplot.show()
# Out:
# The testing MAE loss is: 0.022685139
# The testing MSE loss is: 0.0028908753
# The testing RMSE loss is: 0.05376686

# %%
pyplot.plot(test_y,color='red', label='True Values')
pyplot.plot(out,color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()

# %%
dataset_test=pd.read_excel('F:\MS thesis data/Hopper Crossing.xlsx')
dataset_test=dataset_test.drop(['Date/Time','Flowd'],axis=1)
dataset_test.dropna(inplace=True)

# %%
shape=np.shape(dataset_test)
print(shape)
pyplot.plot(dataset_test)
# Out:
# (26285, 3)
# [<matplotlib.lines.Line2D at 0x1ba96657388>,
#  <matplotlib.lines.Line2D at 0x1ba96657948>,
#  <matplotlib.lines.Line2D at 0x1ba96658288>]

# %%
dataset_test
# Out:
#        Cumulative rainfall   Flow  Level
# 0                      0.0  0.093    1.50
# 1                      0.0  0.093    1.50
# 2                      0.0  0.093    1.50
# 3                      0.0  0.093    1.50
# 4                      0.0  0.093    1.50
# ...                    ...    ...     ...
# 26280                  0.2  0.080    1.49
# 26281                  0.2  0.080    1.49
# 26282                  0.2  0.080    1.49
# 26283                  0.2  0.080    1.49
# 26284                  0.2  0.080    1.49
#
# [26285 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset_test)))
# Out:
# The std of original data is Cumulative rainfall    2.451640
# Flow                   0.520832
# Level                  0.083204
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset_test=dataset_test.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset_test.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset_test[:,0]== maxi[0])
    ind2=np.argwhere(dataset_test[:,1]== maxi[1])
    ind3=np.argwhere(dataset_test[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset_test.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset_test[:,0]== mini[0])
    ind2=np.argwhere(dataset_test[:,1]== mini[1])
    ind3=np.argwhere(dataset_test[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset_test)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset_test = min_max_scaler.fit_transform(dataset_test)
# Out:
# The std of cleaned data is 1.5154548293543502

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=1
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values

#one hour
#test_X, test_y = values[:, :-out_hour], values[:,-1]


test_X, test_y = values[:, :-out_hour], values[:, -out_hour: ]


test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6345, 21)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  var2(t-3)  var3(t-3)  \
# 6    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 7    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 8    0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
# 9    0.215385   0.524545   0.776699   0.123077   0.549980   0.791262
# 10   0.123077   0.549980   0.791262   0.092308   0.603309   0.820388
#
#     var1(t-2)  var2(t-2)  var3(t-2)  var1(t-1)  var2(t-1)  var3(t-1)   var3(t)
# 6    0.230769   0.524545   0.776699   0.215385   0.524545   0.776699  0.791262
# 7    0.215385   0.524545   0.776699   0.123077   0.549980   0.791262  0.820388
# 8    0.123077   0.549980   0.791262   0.092308   0.603309   0.820388  0.844660
# 9    0.092308   0.603309   0.820388   0.092308   0.650485   0.844660  0.873786
# 10   0.092308   0.650485   0.844660   0.092308   0.709285   0.873786  0.898058

# %%
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
# Out:
# The testing MAE loss is: 0.021560963
# The testing MSE loss is: 0.002671243
# The testing RMSE loss is: 0.051684067

# %%
pyplot.plot(test_y,color='red', label='True Values')
pyplot.plot(out,color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()
