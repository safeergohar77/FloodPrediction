# %%
import pandas as pd
from pandas import concat
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from sklearn import preprocessing
from tensorflow.keras import backend as K
#from sklearn.preprocessing import MinMaxScaler
#from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input, Dense, LSTM,GRU,SimpleRNN, Activation
from matplotlib import pyplot
#from sklearn.model_selection import train_test_split

# %%
"# convert series to supervised learning\n" 
#windowing of data
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1),
    for i in range(n_in, 0, -1): #startes from n_in and decreses to 0 by decreasing each time -1
     cols.append(df.shift(i))
     names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
     cols.append(df.shift(-i))
     if i == 0:
       names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
     else:
       names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together\n",
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values\n",
    if dropnan:
      agg.dropna(inplace=True)
    return agg

# %%
#def root_mean_squared_error(y_true, y_pred):
 #       return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
dataset1=pd.read_excel('F:\MS thesis data/Brooklyn.xlsx')
dataset1=dataset1.drop(['Date/Time','Flowd'],axis=1)
dataset1.dropna(inplace=True)

# %%
shape=np.shape(dataset1)
print(shape)
pyplot.plot(dataset1)
# Out:
# (26302, 3)
# [<matplotlib.lines.Line2D at 0x2c02bf33088>,
#  <matplotlib.lines.Line2D at 0x2c02becff08>,
#  <matplotlib.lines.Line2D at 0x2c02be9d608>]

# %%
dataset1
# Out:
#        Cumulative rainfall    Flow  Level
# 0                       0.0  0.172   0.352
# 1                       0.0  0.180   0.356
# 2                       0.0  0.180   0.356
# 3                       0.0  0.189   0.360
# 4                       0.0  0.189   0.360
# ...                     ...    ...     ...
# 26297                   0.0  0.025   0.232
# 26298                   0.0  0.023   0.228
# 26299                   0.0  0.023   0.228
# 26300                   0.0  0.023   0.228
# 26301                   0.0  0.023   0.228
#
# [26302 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset1)))
# Out:
# The std of original data is Cumulative rainfall     2.872616
# Flow                    1.306642
# Level                   0.147238
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset=dataset1.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset[:,0]== maxi[0])
    ind2=np.argwhere(dataset[:,1]== maxi[1])
    ind3=np.argwhere(dataset[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset[:,0]== mini[0])
    ind2=np.argwhere(dataset[:,1]== mini[1])
    ind3=np.argwhere(dataset[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset = min_max_scaler.fit_transform(dataset)
# Out:
# The std of cleaned data is 1.626639593959813

# %%
pyplot.plot(dataset)
# Out:
# [<matplotlib.lines.Line2D at 0x2c02c9c5d48>,
#  <matplotlib.lines.Line2D at 0x2c02c2704c8>,
#  <matplotlib.lines.Line2D at 0x2c02c270688>]

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=8
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values
train_size  = int(len(dataset) * 0.50)
val_size=int(len(dataset) * 0.75)
train_X, train_y = values[0:train_size, :-out_hour], values[0:train_size,-out_hour: ]
val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-out_hour: ]
test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-out_hour:]
#for last hour
#train_X, train_y = values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]  #for only last hour
#val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]
#test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-1]
print(train_X, train_y)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6338, 42)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var2(t-1)  var3(t-1)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.524545   0.776699
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.549980   0.791262
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.603309   0.820388
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.650485   0.844660
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.709285   0.873786
#
#      var3(t)  var3(t+1)  var3(t+2)  var3(t+3)  var3(t+4)  var3(t+5)  \
# 6   0.791262   0.820388   0.844660   0.873786   0.898058   0.932039
# 7   0.820388   0.844660   0.873786   0.898058   0.932039   0.966019
# 8   0.844660   0.873786   0.898058   0.932039   0.966019   1.000000
# 9   0.873786   0.898058   0.932039   0.966019   1.000000   0.941748
# 10  0.898058   0.932039   0.966019   1.000000   0.941748   0.912621
#
#     var3(t+6)  var3(t+7)
# 6    0.966019   1.000000
# 7    1.000000   0.941748
# 8    0.941748   0.912621
# 9    0.912621   0.800971
# 10   0.800971   0.723301
#
# [5 rows x 26 columns]
# [[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]
#  [0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]
#  [0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]
#  ...
#  [0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]
#  [0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]
#  [0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]] [[0.79126215 0.8203884  0.8446602  ... 0.93203884 0.9660194  1.        ]
#  [0.8203884  0.8446602  0.8737864  ... 0.9660194  1.         0.94174755]
#  [0.8446602  0.8737864  0.89805824 ... 1.         0.94174755 0.9126214 ]
#  ...
#  [0.23786408 0.24271844 0.24757281 ... 0.2184466  0.23300971 0.24271844]
#  [0.24271844 0.24757281 0.24757281 ... 0.23300971 0.24271844 0.25728154]
#  [0.24757281 0.24757281 0.24757281 ... 0.24271844 0.25728154 0.27184466]]

# %%
print(train_X, train_y)
# Out:
# [[[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]]
#
#  [[0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]]
#
#  [[0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]]
#
#  ...
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]]] [[0.79126215 0.8203884  0.8446602  ... 0.93203884 0.9660194  1.        ]
#  [0.8203884  0.8446602  0.8737864  ... 0.9660194  1.         0.94174755]
#  [0.8446602  0.8737864  0.89805824 ... 1.         0.94174755 0.9126214 ]
#  ...
#  [0.23786408 0.24271844 0.24757281 ... 0.2184466  0.23300971 0.24271844]
#  [0.24271844 0.24757281 0.24757281 ... 0.23300971 0.24271844 0.25728154]
#  [0.24757281 0.24757281 0.24757281 ... 0.24271844 0.25728154 0.27184466]]

# %%
print(train_X.shape, train_y.shape, val_X.shape, val_y.shape)
# Out:
# (3175, 1, 18) (3175, 8) (1588, 1, 18) (1588, 8)

# %%
randomState = 46
np.random.seed(randomState)
#tensorflow.random.set_random_seed(randomState)
tensorflow.random.set_seed(randomState)
model = Sequential()
model.add(SimpleRNN(15,input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dense(22))
#model.add(Activation('relu'))    
model.add(Dense(out_hour,activation = "sigmoid"))
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.001)
#    opt=tensorflow.keras.optimizers.Adam(learning_rate=0.00075)
model.compile(loss='mae', optimizer=opt,metrics=['mse','mae',tensorflow.keras.metrics.RootMeanSquaredError()])
history = model.fit(train_X, train_y,validation_data=(val_X, val_y), epochs=500, batch_size=100,verbose=1,shuffle=False)
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)
# Out:
# Train on 3175 samples, validate on 1588 samples
# Epoch 1/500
# 3175/3175 [==============================] - 2s 699us/sample - loss: 0.2551 - mse: 0.0790 - mae: 0.2551 - root_mean_squared_error: 0.2811 - val_loss: 0.2619 - val_mse: 0.0858 - val_mae: 0.2619 - val_root_mean_squared_error: 0.2929
# Epoch 2/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.2249 - mse: 0.0639 - mae: 0.2249 - root_mean_squared_error: 0.2528 - val_loss: 0.2341 - val_mse: 0.0707 - val_mae: 0.2341 - val_root_mean_squared_error: 0.2659
# Epoch 3/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.2003 - mse: 0.0542 - mae: 0.2003 - root_mean_squared_error: 0.2328 - val_loss: 0.2125 - val_mse: 0.0604 - val_mae: 0.2125 - val_root_mean_squared_error: 0.2458
# Epoch 4/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.1830 - mse: 0.0490 - mae: 0.1830 - root_mean_squared_error: 0.2213 - val_loss: 0.1972 - val_mse: 0.0541 - val_mae: 0.1972 - val_root_mean_squared_error: 0.2326
# Epoch 5/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1716 - mse: 0.0464 - mae: 0.1716 - root_mean_squared_error: 0.2153 - val_loss: 0.1863 - val_mse: 0.0500 - val_mae: 0.1863 - val_root_mean_squared_error: 0.2236
# Epoch 6/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1633 - mse: 0.0445 - mae: 0.1633 - root_mean_squared_error: 0.2109 - val_loss: 0.1778 - val_mse: 0.0468 - val_mae: 0.1778 - val_root_mean_squared_error: 0.2162
# Epoch 7/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.1563 - mse: 0.0425 - mae: 0.1563 - root_mean_squared_error: 0.2061 - val_loss: 0.1702 - val_mse: 0.0436 - val_mae: 0.1702 - val_root_mean_squared_error: 0.2089
# Epoch 8/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.1494 - mse: 0.0398 - mae: 0.1494 - root_mean_squared_error: 0.1994 - val_loss: 0.1627 - val_mse: 0.0402 - val_mae: 0.1627 - val_root_mean_squared_error: 0.2006
# Epoch 9/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1421 - mse: 0.0363 - mae: 0.1421 - root_mean_squared_error: 0.1905 - val_loss: 0.1547 - val_mse: 0.0365 - val_mae: 0.1547 - val_root_mean_squared_error: 0.1911
# Epoch 10/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1343 - mse: 0.0323 - mae: 0.1343 - root_mean_squared_error: 0.1798 - val_loss: 0.1462 - val_mse: 0.0327 - val_mae: 0.1462 - val_root_mean_squared_error: 0.1809
# Epoch 11/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.1262 - mse: 0.0284 - mae: 0.1262 - root_mean_squared_error: 0.1686 - val_loss: 0.1375 - val_mse: 0.0292 - val_mae: 0.1375 - val_root_mean_squared_error: 0.1708
# Epoch 12/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.1186 - mse: 0.0250 - mae: 0.1186 - root_mean_squared_error: 0.1581 - val_loss: 0.1291 - val_mse: 0.0262 - val_mae: 0.1291 - val_root_mean_squared_error: 0.1617
# Epoch 13/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1118 - mse: 0.0224 - mae: 0.1118 - root_mean_squared_error: 0.1495 - val_loss: 0.1218 - val_mse: 0.0237 - val_mae: 0.1218 - val_root_mean_squared_error: 0.1541
# Epoch 14/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.1060 - mse: 0.0204 - mae: 0.1060 - root_mean_squared_error: 0.1430 - val_loss: 0.1157 - val_mse: 0.0219 - val_mae: 0.1157 - val_root_mean_squared_error: 0.1480
# Epoch 15/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.1010 - mse: 0.0191 - mae: 0.1010 - root_mean_squared_error: 0.1381 - val_loss: 0.1106 - val_mse: 0.0205 - val_mae: 0.1106 - val_root_mean_squared_error: 0.1430
# Epoch 16/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0967 - mse: 0.0181 - mae: 0.0967 - root_mean_squared_error: 0.1345 - val_loss: 0.1061 - val_mse: 0.0193 - val_mae: 0.1061 - val_root_mean_squared_error: 0.1391
# Epoch 17/500
# 3175/3175 [==============================] - 0s 19us/sample - loss: 0.0929 - mse: 0.0174 - mae: 0.0929 - root_mean_squared_error: 0.1318 - val_loss: 0.1021 - val_mse: 0.0185 - val_mae: 0.1021 - val_root_mean_squared_error: 0.1360
# Epoch 18/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0897 - mse: 0.0169 - mae: 0.0897 - root_mean_squared_error: 0.1300 - val_loss: 0.0987 - val_mse: 0.0178 - val_mae: 0.0987 - val_root_mean_squared_error: 0.1335
# Epoch 19/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0870 - mse: 0.0165 - mae: 0.0870 - root_mean_squared_error: 0.1286 - val_loss: 0.0958 - val_mse: 0.0173 - val_mae: 0.0958 - val_root_mean_squared_error: 0.1316
# Epoch 20/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.1335 - mse: 0.0351 - mae: 0.1335 - root_mean_squared_error: 0.187 - 0s 20us/sample - loss: 0.0848 - mse: 0.0163 - mae: 0.0848 - root_mean_squared_error: 0.1276 - val_loss: 0.0933 - val_mse: 0.0169 - val_mae: 0.0933 - val_root_mean_squared_error: 0.1301
# Epoch 21/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0829 - mse: 0.0161 - mae: 0.0829 - root_mean_squared_error: 0.1267 - val_loss: 0.0911 - val_mse: 0.0166 - val_mae: 0.0911 - val_root_mean_squared_error: 0.1288
# Epoch 22/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0814 - mse: 0.0159 - mae: 0.0814 - root_mean_squared_error: 0.1260 - val_loss: 0.0891 - val_mse: 0.0163 - val_mae: 0.0891 - val_root_mean_squared_error: 0.1277
# Epoch 23/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0800 - mse: 0.0157 - mae: 0.0800 - root_mean_squared_error: 0.1252 - val_loss: 0.0874 - val_mse: 0.0160 - val_mae: 0.0874 - val_root_mean_squared_error: 0.1267
# Epoch 24/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0787 - mse: 0.0155 - mae: 0.0787 - root_mean_squared_error: 0.1245 - val_loss: 0.0858 - val_mse: 0.0158 - val_mae: 0.0858 - val_root_mean_squared_error: 0.1258
# Epoch 25/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.1377 - mse: 0.0373 - mae: 0.1377 - root_mean_squared_error: 0.193 - 0s 19us/sample - loss: 0.0776 - mse: 0.0153 - mae: 0.0776 - root_mean_squared_error: 0.1238 - val_loss: 0.0843 - val_mse: 0.0156 - val_mae: 0.0843 - val_root_mean_squared_error: 0.1248
# Epoch 26/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0765 - mse: 0.0151 - mae: 0.0765 - root_mean_squared_error: 0.1229 - val_loss: 0.0829 - val_mse: 0.0153 - val_mae: 0.0829 - val_root_mean_squared_error: 0.1238
# Epoch 27/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0754 - mse: 0.0149 - mae: 0.0754 - root_mean_squared_error: 0.1221 - val_loss: 0.0817 - val_mse: 0.0151 - val_mae: 0.0817 - val_root_mean_squared_error: 0.1228
# Epoch 28/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0744 - mse: 0.0147 - mae: 0.0744 - root_mean_squared_error: 0.1211 - val_loss: 0.0804 - val_mse: 0.0148 - val_mae: 0.0804 - val_root_mean_squared_error: 0.1219
# Epoch 29/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0734 - mse: 0.0144 - mae: 0.0734 - root_mean_squared_error: 0.1201 - val_loss: 0.0793 - val_mse: 0.0146 - val_mae: 0.0793 - val_root_mean_squared_error: 0.1209
# Epoch 30/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0725 - mse: 0.0142 - mae: 0.0725 - root_mean_squared_error: 0.1190 - val_loss: 0.0782 - val_mse: 0.0144 - val_mae: 0.0782 - val_root_mean_squared_error: 0.1199
# Epoch 31/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0716 - mse: 0.0139 - mae: 0.0716 - root_mean_squared_error: 0.1180 - val_loss: 0.0771 - val_mse: 0.0142 - val_mae: 0.0771 - val_root_mean_squared_error: 0.1190
# Epoch 32/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0707 - mse: 0.0137 - mae: 0.0707 - root_mean_squared_error: 0.1169 - val_loss: 0.0762 - val_mse: 0.0139 - val_mae: 0.0762 - val_root_mean_squared_error: 0.1181
# Epoch 33/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0699 - mse: 0.0134 - mae: 0.0699 - root_mean_squared_error: 0.1159 - val_loss: 0.0753 - val_mse: 0.0138 - val_mae: 0.0753 - val_root_mean_squared_error: 0.1173
# Epoch 34/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0691 - mse: 0.0132 - mae: 0.0691 - root_mean_squared_error: 0.1150 - val_loss: 0.0745 - val_mse: 0.0136 - val_mae: 0.0745 - val_root_mean_squared_error: 0.1165
# Epoch 35/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0683 - mse: 0.0130 - mae: 0.0683 - root_mean_squared_error: 0.1140 - val_loss: 0.0737 - val_mse: 0.0134 - val_mae: 0.0737 - val_root_mean_squared_error: 0.1158
# Epoch 36/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0676 - mse: 0.0128 - mae: 0.0676 - root_mean_squared_error: 0.1132 - val_loss: 0.0731 - val_mse: 0.0133 - val_mae: 0.0731 - val_root_mean_squared_error: 0.1152
# Epoch 37/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0670 - mse: 0.0126 - mae: 0.0670 - root_mean_squared_error: 0.1123 - val_loss: 0.0724 - val_mse: 0.0131 - val_mae: 0.0724 - val_root_mean_squared_error: 0.1145
# Epoch 38/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0664 - mse: 0.0124 - mae: 0.0664 - root_mean_squared_error: 0.1116 - val_loss: 0.0719 - val_mse: 0.0130 - val_mae: 0.0719 - val_root_mean_squared_error: 0.1139
# Epoch 39/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0658 - mse: 0.0123 - mae: 0.0658 - root_mean_squared_error: 0.1109 - val_loss: 0.0714 - val_mse: 0.0129 - val_mae: 0.0714 - val_root_mean_squared_error: 0.1134
# Epoch 40/500
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.0653 - mse: 0.0121 - mae: 0.0653 - root_mean_squared_error: 0.1102 - val_loss: 0.0709 - val_mse: 0.0128 - val_mae: 0.0709 - val_root_mean_squared_error: 0.1130
# Epoch 41/500
# 3175/3175 [==============================] - 0s 43us/sample - loss: 0.0649 - mse: 0.0120 - mae: 0.0649 - root_mean_squared_error: 0.1096 - val_loss: 0.0705 - val_mse: 0.0127 - val_mae: 0.0705 - val_root_mean_squared_error: 0.1126
# Epoch 42/500
# 3175/3175 [==============================] - 0s 46us/sample - loss: 0.0645 - mse: 0.0119 - mae: 0.0645 - root_mean_squared_error: 0.1091 - val_loss: 0.0701 - val_mse: 0.0126 - val_mae: 0.0701 - val_root_mean_squared_error: 0.1122
# Epoch 43/500
# 3175/3175 [==============================] - 0s 42us/sample - loss: 0.0642 - mse: 0.0118 - mae: 0.0642 - root_mean_squared_error: 0.1086 - val_loss: 0.0697 - val_mse: 0.0125 - val_mae: 0.0697 - val_root_mean_squared_error: 0.1119
# Epoch 44/500
# 3175/3175 [==============================] - 0s 45us/sample - loss: 0.0638 - mse: 0.0117 - mae: 0.0638 - root_mean_squared_error: 0.1081 - val_loss: 0.0694 - val_mse: 0.0124 - val_mae: 0.0694 - val_root_mean_squared_error: 0.1115
# Epoch 45/500
# 3175/3175 [==============================] - 0s 43us/sample - loss: 0.0636 - mse: 0.0116 - mae: 0.0636 - root_mean_squared_error: 0.1077 - val_loss: 0.0691 - val_mse: 0.0124 - val_mae: 0.0691 - val_root_mean_squared_error: 0.1113
# Epoch 46/500
# 3175/3175 [==============================] - 0s 60us/sample - loss: 0.0633 - mse: 0.0115 - mae: 0.0633 - root_mean_squared_error: 0.1073 - val_loss: 0.0688 - val_mse: 0.0123 - val_mae: 0.0688 - val_root_mean_squared_error: 0.1110
# Epoch 47/500
# 3175/3175 [==============================] - 0s 69us/sample - loss: 0.0630 - mse: 0.0114 - mae: 0.0630 - root_mean_squared_error: 0.1070 - val_loss: 0.0685 - val_mse: 0.0123 - val_mae: 0.0685 - val_root_mean_squared_error: 0.1108
# Epoch 48/500
# 3175/3175 [==============================] - 0s 47us/sample - loss: 0.0628 - mse: 0.0114 - mae: 0.0628 - root_mean_squared_error: 0.1067 - val_loss: 0.0683 - val_mse: 0.0122 - val_mae: 0.0683 - val_root_mean_squared_error: 0.1106
# Epoch 49/500
# 3175/3175 [==============================] - 0s 48us/sample - loss: 0.0626 - mse: 0.0113 - mae: 0.0626 - root_mean_squared_error: 0.1064 - val_loss: 0.0681 - val_mse: 0.0122 - val_mae: 0.0681 - val_root_mean_squared_error: 0.1105
# Epoch 50/500
# 3175/3175 [==============================] - 0s 44us/sample - loss: 0.0624 - mse: 0.0113 - mae: 0.0624 - root_mean_squared_error: 0.1061 - val_loss: 0.0678 - val_mse: 0.0122 - val_mae: 0.0678 - val_root_mean_squared_error: 0.1103
# Epoch 51/500
# 3175/3175 [==============================] - 0s 42us/sample - loss: 0.0622 - mse: 0.0112 - mae: 0.0622 - root_mean_squared_error: 0.1059 - val_loss: 0.0676 - val_mse: 0.0121 - val_mae: 0.0676 - val_root_mean_squared_error: 0.1101
# Epoch 52/500
# 3175/3175 [==============================] - 0s 43us/sample - loss: 0.0621 - mse: 0.0112 - mae: 0.0621 - root_mean_squared_error: 0.1056 - val_loss: 0.0674 - val_mse: 0.0121 - val_mae: 0.0674 - val_root_mean_squared_error: 0.1099
# Epoch 53/500
# 3175/3175 [==============================] - 0s 41us/sample - loss: 0.0619 - mse: 0.0111 - mae: 0.0619 - root_mean_squared_error: 0.1054 - val_loss: 0.0672 - val_mse: 0.0120 - val_mae: 0.0672 - val_root_mean_squared_error: 0.1098
# Epoch 54/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0617 - mse: 0.0111 - mae: 0.0617 - root_mean_squared_error: 0.1052 - val_loss: 0.0671 - val_mse: 0.0120 - val_mae: 0.0671 - val_root_mean_squared_error: 0.1096
# Epoch 55/500
# 3175/3175 [==============================] - 0s 19us/sample - loss: 0.0616 - mse: 0.0110 - mae: 0.0616 - root_mean_squared_error: 0.1049 - val_loss: 0.0669 - val_mse: 0.0120 - val_mae: 0.0669 - val_root_mean_squared_error: 0.1095
# Epoch 56/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0615 - mse: 0.0110 - mae: 0.0615 - root_mean_squared_error: 0.1048 - val_loss: 0.0668 - val_mse: 0.0120 - val_mae: 0.0668 - val_root_mean_squared_error: 0.1093
# Epoch 57/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0613 - mse: 0.0109 - mae: 0.0613 - root_mean_squared_error: 0.1046 - val_loss: 0.0666 - val_mse: 0.0119 - val_mae: 0.0666 - val_root_mean_squared_error: 0.1092
# Epoch 58/500
# 3175/3175 [==============================] - 0s 19us/sample - loss: 0.0612 - mse: 0.0109 - mae: 0.0612 - root_mean_squared_error: 0.1044 - val_loss: 0.0664 - val_mse: 0.0119 - val_mae: 0.0664 - val_root_mean_squared_error: 0.1091
# Epoch 59/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0611 - mse: 0.0109 - mae: 0.0611 - root_mean_squared_error: 0.1042 - val_loss: 0.0663 - val_mse: 0.0119 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1090
# Epoch 60/500
# 3175/3175 [==============================] - 0s 18us/sample - loss: 0.0610 - mse: 0.0108 - mae: 0.0610 - root_mean_squared_error: 0.1041 - val_loss: 0.0662 - val_mse: 0.0118 - val_mae: 0.0662 - val_root_mean_squared_error: 0.1088
# Epoch 61/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0609 - mse: 0.0108 - mae: 0.0609 - root_mean_squared_error: 0.1039 - val_loss: 0.0660 - val_mse: 0.0118 - val_mae: 0.0660 - val_root_mean_squared_error: 0.1087
# Epoch 62/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0608 - mse: 0.0108 - mae: 0.0608 - root_mean_squared_error: 0.1038 - val_loss: 0.0659 - val_mse: 0.0118 - val_mae: 0.0659 - val_root_mean_squared_error: 0.1086
# Epoch 63/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0607 - mse: 0.0107 - mae: 0.0607 - root_mean_squared_error: 0.1037 - val_loss: 0.0658 - val_mse: 0.0118 - val_mae: 0.0658 - val_root_mean_squared_error: 0.1086
# Epoch 64/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0606 - mse: 0.0107 - mae: 0.0606 - root_mean_squared_error: 0.1035 - val_loss: 0.0657 - val_mse: 0.0118 - val_mae: 0.0657 - val_root_mean_squared_error: 0.1085
# Epoch 65/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0605 - mse: 0.0107 - mae: 0.0605 - root_mean_squared_error: 0.1034 - val_loss: 0.0656 - val_mse: 0.0117 - val_mae: 0.0656 - val_root_mean_squared_error: 0.1084
# Epoch 66/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0604 - mse: 0.0107 - mae: 0.0604 - root_mean_squared_error: 0.1033 - val_loss: 0.0655 - val_mse: 0.0117 - val_mae: 0.0655 - val_root_mean_squared_error: 0.1083
# Epoch 67/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0603 - mse: 0.0107 - mae: 0.0603 - root_mean_squared_error: 0.1032 - val_loss: 0.0654 - val_mse: 0.0117 - val_mae: 0.0654 - val_root_mean_squared_error: 0.1082
# Epoch 68/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0602 - mse: 0.0106 - mae: 0.0602 - root_mean_squared_error: 0.1031 - val_loss: 0.0652 - val_mse: 0.0117 - val_mae: 0.0652 - val_root_mean_squared_error: 0.1081
# Epoch 69/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0601 - mse: 0.0106 - mae: 0.0601 - root_mean_squared_error: 0.1030 - val_loss: 0.0651 - val_mse: 0.0117 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1080
# Epoch 70/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0600 - mse: 0.0106 - mae: 0.0600 - root_mean_squared_error: 0.1029 - val_loss: 0.0650 - val_mse: 0.0117 - val_mae: 0.0650 - val_root_mean_squared_error: 0.1080
# Epoch 71/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0600 - mse: 0.0106 - mae: 0.0600 - root_mean_squared_error: 0.1028 - val_loss: 0.0649 - val_mse: 0.0116 - val_mae: 0.0649 - val_root_mean_squared_error: 0.1079
# Epoch 72/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0599 - mse: 0.0105 - mae: 0.0599 - root_mean_squared_error: 0.1027 - val_loss: 0.0648 - val_mse: 0.0116 - val_mae: 0.0648 - val_root_mean_squared_error: 0.1078
# Epoch 73/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0598 - mse: 0.0105 - mae: 0.0598 - root_mean_squared_error: 0.1026 - val_loss: 0.0648 - val_mse: 0.0116 - val_mae: 0.0648 - val_root_mean_squared_error: 0.1077
# Epoch 74/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0597 - mse: 0.0105 - mae: 0.0597 - root_mean_squared_error: 0.1025 - val_loss: 0.0647 - val_mse: 0.0116 - val_mae: 0.0647 - val_root_mean_squared_error: 0.1077
# Epoch 75/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0597 - mse: 0.0105 - mae: 0.0597 - root_mean_squared_error: 0.1024 - val_loss: 0.0646 - val_mse: 0.0116 - val_mae: 0.0646 - val_root_mean_squared_error: 0.1076
# Epoch 76/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0596 - mse: 0.0105 - mae: 0.0596 - root_mean_squared_error: 0.1023 - val_loss: 0.0645 - val_mse: 0.0116 - val_mae: 0.0645 - val_root_mean_squared_error: 0.1075
# Epoch 77/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0595 - mse: 0.0105 - mae: 0.0595 - root_mean_squared_error: 0.1023 - val_loss: 0.0644 - val_mse: 0.0115 - val_mae: 0.0644 - val_root_mean_squared_error: 0.1074
# Epoch 78/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0594 - mse: 0.0104 - mae: 0.0594 - root_mean_squared_error: 0.1022 - val_loss: 0.0643 - val_mse: 0.0115 - val_mae: 0.0643 - val_root_mean_squared_error: 0.1073
# Epoch 79/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0593 - mse: 0.0104 - mae: 0.0593 - root_mean_squared_error: 0.1021 - val_loss: 0.0642 - val_mse: 0.0115 - val_mae: 0.0642 - val_root_mean_squared_error: 0.1073
# Epoch 80/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.1218 - mse: 0.0286 - mae: 0.1218 - root_mean_squared_error: 0.169 - 0s 21us/sample - loss: 0.0593 - mse: 0.0104 - mae: 0.0593 - root_mean_squared_error: 0.1020 - val_loss: 0.0641 - val_mse: 0.0115 - val_mae: 0.0641 - val_root_mean_squared_error: 0.1072
# Epoch 81/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0592 - mse: 0.0104 - mae: 0.0592 - root_mean_squared_error: 0.1019 - val_loss: 0.0640 - val_mse: 0.0115 - val_mae: 0.0640 - val_root_mean_squared_error: 0.1072
# Epoch 82/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0591 - mse: 0.0104 - mae: 0.0591 - root_mean_squared_error: 0.1019 - val_loss: 0.0640 - val_mse: 0.0115 - val_mae: 0.0640 - val_root_mean_squared_error: 0.1071
# Epoch 83/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0591 - mse: 0.0104 - mae: 0.0591 - root_mean_squared_error: 0.1018 - val_loss: 0.0639 - val_mse: 0.0115 - val_mae: 0.0639 - val_root_mean_squared_error: 0.1070
# Epoch 84/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0590 - mse: 0.0103 - mae: 0.0590 - root_mean_squared_error: 0.1017 - val_loss: 0.0638 - val_mse: 0.0114 - val_mae: 0.0638 - val_root_mean_squared_error: 0.1070
# Epoch 85/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0590 - mse: 0.0103 - mae: 0.0590 - root_mean_squared_error: 0.1016 - val_loss: 0.0637 - val_mse: 0.0114 - val_mae: 0.0637 - val_root_mean_squared_error: 0.1069
# Epoch 86/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0589 - mse: 0.0103 - mae: 0.0589 - root_mean_squared_error: 0.1016 - val_loss: 0.0636 - val_mse: 0.0114 - val_mae: 0.0636 - val_root_mean_squared_error: 0.1069
# Epoch 87/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0588 - mse: 0.0103 - mae: 0.0588 - root_mean_squared_error: 0.1015 - val_loss: 0.0636 - val_mse: 0.0114 - val_mae: 0.0636 - val_root_mean_squared_error: 0.1068
# Epoch 88/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0588 - mse: 0.0103 - mae: 0.0588 - root_mean_squared_error: 0.1015 - val_loss: 0.0635 - val_mse: 0.0114 - val_mae: 0.0635 - val_root_mean_squared_error: 0.1068
# Epoch 89/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0587 - mse: 0.0103 - mae: 0.0587 - root_mean_squared_error: 0.1014 - val_loss: 0.0634 - val_mse: 0.0114 - val_mae: 0.0634 - val_root_mean_squared_error: 0.1067
# Epoch 90/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0587 - mse: 0.0103 - mae: 0.0587 - root_mean_squared_error: 0.1014 - val_loss: 0.0634 - val_mse: 0.0114 - val_mae: 0.0634 - val_root_mean_squared_error: 0.1067
# Epoch 91/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0586 - mse: 0.0103 - mae: 0.0586 - root_mean_squared_error: 0.1013 - val_loss: 0.0633 - val_mse: 0.0114 - val_mae: 0.0633 - val_root_mean_squared_error: 0.1066
# Epoch 92/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0586 - mse: 0.0103 - mae: 0.0586 - root_mean_squared_error: 0.1012 - val_loss: 0.0632 - val_mse: 0.0114 - val_mae: 0.0632 - val_root_mean_squared_error: 0.1065
# Epoch 93/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0585 - mse: 0.0102 - mae: 0.0585 - root_mean_squared_error: 0.1012 - val_loss: 0.0632 - val_mse: 0.0113 - val_mae: 0.0632 - val_root_mean_squared_error: 0.1065
# Epoch 94/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0585 - mse: 0.0102 - mae: 0.0585 - root_mean_squared_error: 0.1011 - val_loss: 0.0631 - val_mse: 0.0113 - val_mae: 0.0631 - val_root_mean_squared_error: 0.1064
# Epoch 95/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0584 - mse: 0.0102 - mae: 0.0584 - root_mean_squared_error: 0.1010 - val_loss: 0.0630 - val_mse: 0.0113 - val_mae: 0.0630 - val_root_mean_squared_error: 0.1064
# Epoch 96/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0584 - mse: 0.0102 - mae: 0.0584 - root_mean_squared_error: 0.1010 - val_loss: 0.0629 - val_mse: 0.0113 - val_mae: 0.0629 - val_root_mean_squared_error: 0.1063
# Epoch 97/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0583 - mse: 0.0102 - mae: 0.0583 - root_mean_squared_error: 0.1009 - val_loss: 0.0629 - val_mse: 0.0113 - val_mae: 0.0629 - val_root_mean_squared_error: 0.1062
# Epoch 98/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0582 - mse: 0.0102 - mae: 0.0582 - root_mean_squared_error: 0.1009 - val_loss: 0.0628 - val_mse: 0.0113 - val_mae: 0.0628 - val_root_mean_squared_error: 0.1062
# Epoch 99/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0582 - mse: 0.0102 - mae: 0.0582 - root_mean_squared_error: 0.1008 - val_loss: 0.0628 - val_mse: 0.0113 - val_mae: 0.0628 - val_root_mean_squared_error: 0.1062
# Epoch 100/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0582 - mse: 0.0102 - mae: 0.0582 - root_mean_squared_error: 0.1008 - val_loss: 0.0627 - val_mse: 0.0113 - val_mae: 0.0627 - val_root_mean_squared_error: 0.1061
# Epoch 101/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0581 - mse: 0.0101 - mae: 0.0581 - root_mean_squared_error: 0.1007 - val_loss: 0.0626 - val_mse: 0.0112 - val_mae: 0.0626 - val_root_mean_squared_error: 0.1061
# Epoch 102/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0581 - mse: 0.0101 - mae: 0.0581 - root_mean_squared_error: 0.1007 - val_loss: 0.0625 - val_mse: 0.0112 - val_mae: 0.0625 - val_root_mean_squared_error: 0.1060
# Epoch 103/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0580 - mse: 0.0101 - mae: 0.0580 - root_mean_squared_error: 0.1006 - val_loss: 0.0625 - val_mse: 0.0112 - val_mae: 0.0625 - val_root_mean_squared_error: 0.1059
# Epoch 104/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0580 - mse: 0.0101 - mae: 0.0580 - root_mean_squared_error: 0.1006 - val_loss: 0.0624 - val_mse: 0.0112 - val_mae: 0.0624 - val_root_mean_squared_error: 0.1059
# Epoch 105/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0579 - mse: 0.0101 - mae: 0.0579 - root_mean_squared_error: 0.1005 - val_loss: 0.0623 - val_mse: 0.0112 - val_mae: 0.0623 - val_root_mean_squared_error: 0.1058
# Epoch 106/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0579 - mse: 0.0101 - mae: 0.0579 - root_mean_squared_error: 0.1005 - val_loss: 0.0623 - val_mse: 0.0112 - val_mae: 0.0623 - val_root_mean_squared_error: 0.1058
# Epoch 107/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0578 - mse: 0.0101 - mae: 0.0578 - root_mean_squared_error: 0.1004 - val_loss: 0.0623 - val_mse: 0.0112 - val_mae: 0.0623 - val_root_mean_squared_error: 0.1058
# Epoch 108/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0578 - mse: 0.0101 - mae: 0.0578 - root_mean_squared_error: 0.1004 - val_loss: 0.0622 - val_mse: 0.0112 - val_mae: 0.0622 - val_root_mean_squared_error: 0.1057
# Epoch 109/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0578 - mse: 0.0101 - mae: 0.0578 - root_mean_squared_error: 0.1004 - val_loss: 0.0621 - val_mse: 0.0112 - val_mae: 0.0621 - val_root_mean_squared_error: 0.1057
# Epoch 110/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0577 - mse: 0.0101 - mae: 0.0577 - root_mean_squared_error: 0.1003 - val_loss: 0.0621 - val_mse: 0.0112 - val_mae: 0.0621 - val_root_mean_squared_error: 0.1056
# Epoch 111/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0577 - mse: 0.0101 - mae: 0.0577 - root_mean_squared_error: 0.1003 - val_loss: 0.0620 - val_mse: 0.0112 - val_mae: 0.0620 - val_root_mean_squared_error: 0.1056
# Epoch 112/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0576 - mse: 0.0101 - mae: 0.0576 - root_mean_squared_error: 0.1003 - val_loss: 0.0620 - val_mse: 0.0111 - val_mae: 0.0620 - val_root_mean_squared_error: 0.1056
# Epoch 113/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0576 - mse: 0.0100 - mae: 0.0576 - root_mean_squared_error: 0.1002 - val_loss: 0.0619 - val_mse: 0.0111 - val_mae: 0.0619 - val_root_mean_squared_error: 0.1055
# Epoch 114/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0576 - mse: 0.0100 - mae: 0.0576 - root_mean_squared_error: 0.1002 - val_loss: 0.0618 - val_mse: 0.0111 - val_mae: 0.0618 - val_root_mean_squared_error: 0.1054
# Epoch 115/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0575 - mse: 0.0100 - mae: 0.0575 - root_mean_squared_error: 0.1002 - val_loss: 0.0618 - val_mse: 0.0111 - val_mae: 0.0618 - val_root_mean_squared_error: 0.1054
# Epoch 116/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0575 - mse: 0.0100 - mae: 0.0575 - root_mean_squared_error: 0.1001 - val_loss: 0.0617 - val_mse: 0.0111 - val_mae: 0.0617 - val_root_mean_squared_error: 0.1053
# Epoch 117/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0574 - mse: 0.0100 - mae: 0.0574 - root_mean_squared_error: 0.1001 - val_loss: 0.0617 - val_mse: 0.0111 - val_mae: 0.0617 - val_root_mean_squared_error: 0.1053
# Epoch 118/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0574 - mse: 0.0100 - mae: 0.0574 - root_mean_squared_error: 0.1000 - val_loss: 0.0616 - val_mse: 0.0111 - val_mae: 0.0616 - val_root_mean_squared_error: 0.1053
# Epoch 119/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0574 - mse: 0.0100 - mae: 0.0574 - root_mean_squared_error: 0.1000 - val_loss: 0.0616 - val_mse: 0.0111 - val_mae: 0.0616 - val_root_mean_squared_error: 0.1052
# Epoch 120/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0573 - mse: 0.0100 - mae: 0.0573 - root_mean_squared_error: 0.1000 - val_loss: 0.0615 - val_mse: 0.0111 - val_mae: 0.0615 - val_root_mean_squared_error: 0.1052
# Epoch 121/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0573 - mse: 0.0100 - mae: 0.0573 - root_mean_squared_error: 0.1000 - val_loss: 0.0615 - val_mse: 0.0111 - val_mae: 0.0615 - val_root_mean_squared_error: 0.1052
# Epoch 122/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0573 - mse: 0.0100 - mae: 0.0573 - root_mean_squared_error: 0.0999 - val_loss: 0.0614 - val_mse: 0.0110 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1051
# Epoch 123/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0572 - mse: 0.0100 - mae: 0.0572 - root_mean_squared_error: 0.0999 - val_loss: 0.0614 - val_mse: 0.0110 - val_mae: 0.0614 - val_root_mean_squared_error: 0.1051
# Epoch 124/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0572 - mse: 0.0100 - mae: 0.0572 - root_mean_squared_error: 0.0999 - val_loss: 0.0613 - val_mse: 0.0110 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1050
# Epoch 125/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0572 - mse: 0.0100 - mae: 0.0572 - root_mean_squared_error: 0.0998 - val_loss: 0.0613 - val_mse: 0.0110 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1050
# Epoch 126/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0571 - mse: 0.0100 - mae: 0.0571 - root_mean_squared_error: 0.0998 - val_loss: 0.0612 - val_mse: 0.0110 - val_mae: 0.0612 - val_root_mean_squared_error: 0.1050
# Epoch 127/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0571 - mse: 0.0100 - mae: 0.0571 - root_mean_squared_error: 0.0998 - val_loss: 0.0612 - val_mse: 0.0110 - val_mae: 0.0612 - val_root_mean_squared_error: 0.1049
# Epoch 128/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0571 - mse: 0.0100 - mae: 0.0571 - root_mean_squared_error: 0.0998 - val_loss: 0.0612 - val_mse: 0.0110 - val_mae: 0.0612 - val_root_mean_squared_error: 0.1049
# Epoch 129/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0570 - mse: 0.0099 - mae: 0.0570 - root_mean_squared_error: 0.0997 - val_loss: 0.0611 - val_mse: 0.0110 - val_mae: 0.0611 - val_root_mean_squared_error: 0.1049
# Epoch 130/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0570 - mse: 0.0099 - mae: 0.0570 - root_mean_squared_error: 0.0997 - val_loss: 0.0611 - val_mse: 0.0110 - val_mae: 0.0611 - val_root_mean_squared_error: 0.1049
# Epoch 131/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0570 - mse: 0.0099 - mae: 0.0570 - root_mean_squared_error: 0.0997 - val_loss: 0.0610 - val_mse: 0.0110 - val_mae: 0.0610 - val_root_mean_squared_error: 0.1048
# Epoch 132/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0570 - mse: 0.0099 - mae: 0.0570 - root_mean_squared_error: 0.0997 - val_loss: 0.0610 - val_mse: 0.0110 - val_mae: 0.0610 - val_root_mean_squared_error: 0.1048
# Epoch 133/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0569 - mse: 0.0099 - mae: 0.0569 - root_mean_squared_error: 0.0997 - val_loss: 0.0610 - val_mse: 0.0110 - val_mae: 0.0610 - val_root_mean_squared_error: 0.1048
# Epoch 134/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0569 - mse: 0.0099 - mae: 0.0569 - root_mean_squared_error: 0.0997 - val_loss: 0.0609 - val_mse: 0.0110 - val_mae: 0.0609 - val_root_mean_squared_error: 0.1048
# Epoch 135/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0569 - mse: 0.0099 - mae: 0.0569 - root_mean_squared_error: 0.0996 - val_loss: 0.0609 - val_mse: 0.0110 - val_mae: 0.0609 - val_root_mean_squared_error: 0.1047
# Epoch 136/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0569 - mse: 0.0099 - mae: 0.0569 - root_mean_squared_error: 0.0996 - val_loss: 0.0608 - val_mse: 0.0110 - val_mae: 0.0608 - val_root_mean_squared_error: 0.1047
# Epoch 137/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0568 - mse: 0.0099 - mae: 0.0568 - root_mean_squared_error: 0.0996 - val_loss: 0.0608 - val_mse: 0.0110 - val_mae: 0.0608 - val_root_mean_squared_error: 0.1047
# Epoch 138/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0568 - mse: 0.0099 - mae: 0.0568 - root_mean_squared_error: 0.0996 - val_loss: 0.0608 - val_mse: 0.0110 - val_mae: 0.0608 - val_root_mean_squared_error: 0.1046
# Epoch 139/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0568 - mse: 0.0099 - mae: 0.0568 - root_mean_squared_error: 0.0996 - val_loss: 0.0607 - val_mse: 0.0109 - val_mae: 0.0607 - val_root_mean_squared_error: 0.1046
# Epoch 140/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0568 - mse: 0.0099 - mae: 0.0568 - root_mean_squared_error: 0.0995 - val_loss: 0.0607 - val_mse: 0.0109 - val_mae: 0.0607 - val_root_mean_squared_error: 0.1046
# Epoch 141/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0567 - mse: 0.0099 - mae: 0.0567 - root_mean_squared_error: 0.0995 - val_loss: 0.0606 - val_mse: 0.0109 - val_mae: 0.0606 - val_root_mean_squared_error: 0.1046
# Epoch 142/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0567 - mse: 0.0099 - mae: 0.0567 - root_mean_squared_error: 0.0995 - val_loss: 0.0606 - val_mse: 0.0109 - val_mae: 0.0606 - val_root_mean_squared_error: 0.1045
# Epoch 143/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0567 - mse: 0.0099 - mae: 0.0567 - root_mean_squared_error: 0.0995 - val_loss: 0.0606 - val_mse: 0.0109 - val_mae: 0.0606 - val_root_mean_squared_error: 0.1045
# Epoch 144/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0567 - mse: 0.0099 - mae: 0.0567 - root_mean_squared_error: 0.0995 - val_loss: 0.0605 - val_mse: 0.0109 - val_mae: 0.0605 - val_root_mean_squared_error: 0.1045
# Epoch 145/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0567 - mse: 0.0099 - mae: 0.0567 - root_mean_squared_error: 0.0995 - val_loss: 0.0605 - val_mse: 0.0109 - val_mae: 0.0605 - val_root_mean_squared_error: 0.1045
# Epoch 146/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0567 - mse: 0.0099 - mae: 0.0567 - root_mean_squared_error: 0.0994 - val_loss: 0.0605 - val_mse: 0.0109 - val_mae: 0.0605 - val_root_mean_squared_error: 0.1045
# Epoch 147/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0566 - mse: 0.0099 - mae: 0.0566 - root_mean_squared_error: 0.0994 - val_loss: 0.0604 - val_mse: 0.0109 - val_mae: 0.0604 - val_root_mean_squared_error: 0.1044
# Epoch 148/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0566 - mse: 0.0099 - mae: 0.0566 - root_mean_squared_error: 0.0994 - val_loss: 0.0604 - val_mse: 0.0109 - val_mae: 0.0604 - val_root_mean_squared_error: 0.1044
# Epoch 149/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0566 - mse: 0.0099 - mae: 0.0566 - root_mean_squared_error: 0.0994 - val_loss: 0.0604 - val_mse: 0.0109 - val_mae: 0.0604 - val_root_mean_squared_error: 0.1044
# Epoch 150/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0566 - mse: 0.0099 - mae: 0.0566 - root_mean_squared_error: 0.0994 - val_loss: 0.0604 - val_mse: 0.0109 - val_mae: 0.0604 - val_root_mean_squared_error: 0.1044
# Epoch 151/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0565 - mse: 0.0099 - mae: 0.0565 - root_mean_squared_error: 0.0994 - val_loss: 0.0603 - val_mse: 0.0109 - val_mae: 0.0603 - val_root_mean_squared_error: 0.1044
# Epoch 152/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0565 - mse: 0.0099 - mae: 0.0565 - root_mean_squared_error: 0.0994 - val_loss: 0.0603 - val_mse: 0.0109 - val_mae: 0.0603 - val_root_mean_squared_error: 0.1043
# Epoch 153/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0565 - mse: 0.0099 - mae: 0.0565 - root_mean_squared_error: 0.0993 - val_loss: 0.0602 - val_mse: 0.0109 - val_mae: 0.0602 - val_root_mean_squared_error: 0.1043
# Epoch 154/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0565 - mse: 0.0099 - mae: 0.0565 - root_mean_squared_error: 0.0993 - val_loss: 0.0602 - val_mse: 0.0109 - val_mae: 0.0602 - val_root_mean_squared_error: 0.1043
# Epoch 155/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0565 - mse: 0.0099 - mae: 0.0565 - root_mean_squared_error: 0.0993 - val_loss: 0.0602 - val_mse: 0.0109 - val_mae: 0.0602 - val_root_mean_squared_error: 0.1043
# Epoch 156/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0564 - mse: 0.0099 - mae: 0.0564 - root_mean_squared_error: 0.0993 - val_loss: 0.0602 - val_mse: 0.0109 - val_mae: 0.0602 - val_root_mean_squared_error: 0.1043
# Epoch 157/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0564 - mse: 0.0099 - mae: 0.0564 - root_mean_squared_error: 0.0993 - val_loss: 0.0601 - val_mse: 0.0109 - val_mae: 0.0601 - val_root_mean_squared_error: 0.1042
# Epoch 158/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0564 - mse: 0.0099 - mae: 0.0564 - root_mean_squared_error: 0.0993 - val_loss: 0.0601 - val_mse: 0.0109 - val_mae: 0.0601 - val_root_mean_squared_error: 0.1042
# Epoch 159/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0564 - mse: 0.0099 - mae: 0.0564 - root_mean_squared_error: 0.0993 - val_loss: 0.0601 - val_mse: 0.0109 - val_mae: 0.0601 - val_root_mean_squared_error: 0.1042
# Epoch 160/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0564 - mse: 0.0099 - mae: 0.0564 - root_mean_squared_error: 0.0993 - val_loss: 0.0600 - val_mse: 0.0109 - val_mae: 0.0600 - val_root_mean_squared_error: 0.1042
# Epoch 161/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0564 - mse: 0.0099 - mae: 0.0564 - root_mean_squared_error: 0.0993 - val_loss: 0.0600 - val_mse: 0.0109 - val_mae: 0.0600 - val_root_mean_squared_error: 0.1042
# Epoch 162/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0563 - mse: 0.0099 - mae: 0.0563 - root_mean_squared_error: 0.0993 - val_loss: 0.0600 - val_mse: 0.0108 - val_mae: 0.0600 - val_root_mean_squared_error: 0.1041
# Epoch 163/500
# 3175/3175 [==============================] - 0s 19us/sample - loss: 0.0563 - mse: 0.0099 - mae: 0.0563 - root_mean_squared_error: 0.0993 - val_loss: 0.0600 - val_mse: 0.0108 - val_mae: 0.0600 - val_root_mean_squared_error: 0.1041
# Epoch 164/500
# 3175/3175 [==============================] - 0s 17us/sample - loss: 0.0563 - mse: 0.0098 - mae: 0.0563 - root_mean_squared_error: 0.0992 - val_loss: 0.0599 - val_mse: 0.0108 - val_mae: 0.0599 - val_root_mean_squared_error: 0.1041
# Epoch 165/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0563 - mse: 0.0098 - mae: 0.0563 - root_mean_squared_error: 0.0992 - val_loss: 0.0599 - val_mse: 0.0108 - val_mae: 0.0599 - val_root_mean_squared_error: 0.1041
# Epoch 166/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0563 - mse: 0.0098 - mae: 0.0563 - root_mean_squared_error: 0.0992 - val_loss: 0.0599 - val_mse: 0.0108 - val_mae: 0.0599 - val_root_mean_squared_error: 0.1041
# Epoch 167/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0563 - mse: 0.0098 - mae: 0.0563 - root_mean_squared_error: 0.0992 - val_loss: 0.0599 - val_mse: 0.0108 - val_mae: 0.0599 - val_root_mean_squared_error: 0.1041
# Epoch 168/500
# 3175/3175 [==============================] - 0s 16us/sample - loss: 0.0562 - mse: 0.0098 - mae: 0.0562 - root_mean_squared_error: 0.0992 - val_loss: 0.0598 - val_mse: 0.0108 - val_mae: 0.0598 - val_root_mean_squared_error: 0.1041
# Epoch 169/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0562 - mse: 0.0098 - mae: 0.0562 - root_mean_squared_error: 0.0992 - val_loss: 0.0598 - val_mse: 0.0108 - val_mae: 0.0598 - val_root_mean_squared_error: 0.1041
# Epoch 170/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0562 - mse: 0.0098 - mae: 0.0562 - root_mean_squared_error: 0.0992 - val_loss: 0.0598 - val_mse: 0.0108 - val_mae: 0.0598 - val_root_mean_squared_error: 0.1040
# Epoch 171/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0562 - mse: 0.0098 - mae: 0.0562 - root_mean_squared_error: 0.0992 - val_loss: 0.0598 - val_mse: 0.0108 - val_mae: 0.0598 - val_root_mean_squared_error: 0.1040
# Epoch 172/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0562 - mse: 0.0098 - mae: 0.0562 - root_mean_squared_error: 0.0992 - val_loss: 0.0597 - val_mse: 0.0108 - val_mae: 0.0597 - val_root_mean_squared_error: 0.1040
# Epoch 173/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0562 - mse: 0.0098 - mae: 0.0562 - root_mean_squared_error: 0.0992 - val_loss: 0.0597 - val_mse: 0.0108 - val_mae: 0.0597 - val_root_mean_squared_error: 0.1040
# Epoch 174/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0562 - mse: 0.0098 - mae: 0.0562 - root_mean_squared_error: 0.0992 - val_loss: 0.0597 - val_mse: 0.0108 - val_mae: 0.0597 - val_root_mean_squared_error: 0.1040
# Epoch 175/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0562 - mse: 0.0098 - mae: 0.0562 - root_mean_squared_error: 0.0992 - val_loss: 0.0597 - val_mse: 0.0108 - val_mae: 0.0597 - val_root_mean_squared_error: 0.1040
# Epoch 176/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0561 - mse: 0.0098 - mae: 0.0561 - root_mean_squared_error: 0.0992 - val_loss: 0.0597 - val_mse: 0.0108 - val_mae: 0.0597 - val_root_mean_squared_error: 0.1040
# Epoch 177/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0561 - mse: 0.0098 - mae: 0.0561 - root_mean_squared_error: 0.0992 - val_loss: 0.0596 - val_mse: 0.0108 - val_mae: 0.0596 - val_root_mean_squared_error: 0.1040
# Epoch 178/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0561 - mse: 0.0098 - mae: 0.0561 - root_mean_squared_error: 0.0991 - val_loss: 0.0596 - val_mse: 0.0108 - val_mae: 0.0596 - val_root_mean_squared_error: 0.1039
# Epoch 179/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0561 - mse: 0.0098 - mae: 0.0561 - root_mean_squared_error: 0.0991 - val_loss: 0.0596 - val_mse: 0.0108 - val_mae: 0.0596 - val_root_mean_squared_error: 0.1039
# Epoch 180/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0561 - mse: 0.0098 - mae: 0.0561 - root_mean_squared_error: 0.0991 - val_loss: 0.0596 - val_mse: 0.0108 - val_mae: 0.0596 - val_root_mean_squared_error: 0.1039
# Epoch 181/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0561 - mse: 0.0098 - mae: 0.0561 - root_mean_squared_error: 0.0991 - val_loss: 0.0595 - val_mse: 0.0108 - val_mae: 0.0595 - val_root_mean_squared_error: 0.1039
# Epoch 182/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0561 - mse: 0.0098 - mae: 0.0561 - root_mean_squared_error: 0.0991 - val_loss: 0.0595 - val_mse: 0.0108 - val_mae: 0.0595 - val_root_mean_squared_error: 0.1039
# Epoch 183/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0561 - mse: 0.0098 - mae: 0.0561 - root_mean_squared_error: 0.0991 - val_loss: 0.0595 - val_mse: 0.0108 - val_mae: 0.0595 - val_root_mean_squared_error: 0.1039
# Epoch 184/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0560 - mse: 0.0098 - mae: 0.0560 - root_mean_squared_error: 0.0991 - val_loss: 0.0595 - val_mse: 0.0108 - val_mae: 0.0595 - val_root_mean_squared_error: 0.1039
# Epoch 185/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0560 - mse: 0.0098 - mae: 0.0560 - root_mean_squared_error: 0.0991 - val_loss: 0.0595 - val_mse: 0.0108 - val_mae: 0.0595 - val_root_mean_squared_error: 0.1038
# Epoch 186/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0560 - mse: 0.0098 - mae: 0.0560 - root_mean_squared_error: 0.0991 - val_loss: 0.0594 - val_mse: 0.0108 - val_mae: 0.0594 - val_root_mean_squared_error: 0.1038
# Epoch 187/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0560 - mse: 0.0098 - mae: 0.0560 - root_mean_squared_error: 0.0991 - val_loss: 0.0594 - val_mse: 0.0108 - val_mae: 0.0594 - val_root_mean_squared_error: 0.1038
# Epoch 188/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0560 - mse: 0.0098 - mae: 0.0560 - root_mean_squared_error: 0.0991 - val_loss: 0.0594 - val_mse: 0.0108 - val_mae: 0.0594 - val_root_mean_squared_error: 0.1038
# Epoch 189/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0560 - mse: 0.0098 - mae: 0.0560 - root_mean_squared_error: 0.0991 - val_loss: 0.0594 - val_mse: 0.0108 - val_mae: 0.0594 - val_root_mean_squared_error: 0.1038
# Epoch 190/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0560 - mse: 0.0098 - mae: 0.0560 - root_mean_squared_error: 0.0991 - val_loss: 0.0594 - val_mse: 0.0108 - val_mae: 0.0594 - val_root_mean_squared_error: 0.1038
# Epoch 191/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0560 - mse: 0.0098 - mae: 0.0560 - root_mean_squared_error: 0.0991 - val_loss: 0.0593 - val_mse: 0.0108 - val_mae: 0.0593 - val_root_mean_squared_error: 0.1038
# Epoch 192/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0560 - mse: 0.0098 - mae: 0.0560 - root_mean_squared_error: 0.0991 - val_loss: 0.0593 - val_mse: 0.0108 - val_mae: 0.0593 - val_root_mean_squared_error: 0.1038
# Epoch 193/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0559 - mse: 0.0098 - mae: 0.0559 - root_mean_squared_error: 0.0991 - val_loss: 0.0593 - val_mse: 0.0108 - val_mae: 0.0593 - val_root_mean_squared_error: 0.1038
# Epoch 194/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0559 - mse: 0.0098 - mae: 0.0559 - root_mean_squared_error: 0.0990 - val_loss: 0.0593 - val_mse: 0.0108 - val_mae: 0.0593 - val_root_mean_squared_error: 0.1038
# Epoch 195/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0559 - mse: 0.0098 - mae: 0.0559 - root_mean_squared_error: 0.0990 - val_loss: 0.0593 - val_mse: 0.0108 - val_mae: 0.0593 - val_root_mean_squared_error: 0.1037
# Epoch 196/500
# ...
# Epoch 436/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0544 - mse: 0.0096 - mae: 0.0544 - root_mean_squared_error: 0.0978 - val_loss: 0.0569 - val_mse: 0.0106 - val_mae: 0.0569 - val_root_mean_squared_error: 0.1028
# Epoch 437/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0544 - mse: 0.0096 - mae: 0.0544 - root_mean_squared_error: 0.0978 - val_loss: 0.0568 - val_mse: 0.0106 - val_mae: 0.0568 - val_root_mean_squared_error: 0.1028
# Epoch 438/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0544 - mse: 0.0096 - mae: 0.0544 - root_mean_squared_error: 0.0978 - val_loss: 0.0568 - val_mse: 0.0106 - val_mae: 0.0568 - val_root_mean_squared_error: 0.1028
# Epoch 439/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0544 - mse: 0.0096 - mae: 0.0544 - root_mean_squared_error: 0.0978 - val_loss: 0.0568 - val_mse: 0.0106 - val_mae: 0.0568 - val_root_mean_squared_error: 0.1028
# Epoch 440/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0544 - mse: 0.0096 - mae: 0.0544 - root_mean_squared_error: 0.0978 - val_loss: 0.0568 - val_mse: 0.0106 - val_mae: 0.0568 - val_root_mean_squared_error: 0.1028
# Epoch 441/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0544 - mse: 0.0096 - mae: 0.0544 - root_mean_squared_error: 0.0978 - val_loss: 0.0568 - val_mse: 0.0106 - val_mae: 0.0568 - val_root_mean_squared_error: 0.1028
# Epoch 442/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0544 - mse: 0.0096 - mae: 0.0544 - root_mean_squared_error: 0.0977 - val_loss: 0.0568 - val_mse: 0.0106 - val_mae: 0.0568 - val_root_mean_squared_error: 0.1028
# Epoch 443/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0544 - mse: 0.0096 - mae: 0.0544 - root_mean_squared_error: 0.0977 - val_loss: 0.0568 - val_mse: 0.0106 - val_mae: 0.0568 - val_root_mean_squared_error: 0.1028
# Epoch 444/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0544 - mse: 0.0096 - mae: 0.0544 - root_mean_squared_error: 0.0977 - val_loss: 0.0568 - val_mse: 0.0106 - val_mae: 0.0568 - val_root_mean_squared_error: 0.1028
# Epoch 445/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0544 - mse: 0.0096 - mae: 0.0544 - root_mean_squared_error: 0.0977 - val_loss: 0.0568 - val_mse: 0.0106 - val_mae: 0.0568 - val_root_mean_squared_error: 0.1028
# Epoch 446/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0544 - mse: 0.0096 - mae: 0.0544 - root_mean_squared_error: 0.0977 - val_loss: 0.0568 - val_mse: 0.0106 - val_mae: 0.0568 - val_root_mean_squared_error: 0.1028
# Epoch 447/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0544 - mse: 0.0096 - mae: 0.0544 - root_mean_squared_error: 0.0977 - val_loss: 0.0568 - val_mse: 0.0106 - val_mae: 0.0568 - val_root_mean_squared_error: 0.1028
# Epoch 448/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0544 - mse: 0.0095 - mae: 0.0544 - root_mean_squared_error: 0.0977 - val_loss: 0.0568 - val_mse: 0.0106 - val_mae: 0.0568 - val_root_mean_squared_error: 0.1028
# Epoch 449/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0544 - mse: 0.0095 - mae: 0.0544 - root_mean_squared_error: 0.0977 - val_loss: 0.0568 - val_mse: 0.0106 - val_mae: 0.0568 - val_root_mean_squared_error: 0.1028
# Epoch 450/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0544 - mse: 0.0095 - mae: 0.0544 - root_mean_squared_error: 0.0977 - val_loss: 0.0568 - val_mse: 0.0106 - val_mae: 0.0568 - val_root_mean_squared_error: 0.1028
# Epoch 451/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0544 - mse: 0.0095 - mae: 0.0544 - root_mean_squared_error: 0.0977 - val_loss: 0.0568 - val_mse: 0.0106 - val_mae: 0.0568 - val_root_mean_squared_error: 0.1028
# Epoch 452/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0544 - mse: 0.0095 - mae: 0.0544 - root_mean_squared_error: 0.0977 - val_loss: 0.0568 - val_mse: 0.0106 - val_mae: 0.0568 - val_root_mean_squared_error: 0.1028
# Epoch 453/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0544 - mse: 0.0095 - mae: 0.0544 - root_mean_squared_error: 0.0977 - val_loss: 0.0568 - val_mse: 0.0106 - val_mae: 0.0568 - val_root_mean_squared_error: 0.1028
# Epoch 454/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0977 - val_loss: 0.0568 - val_mse: 0.0106 - val_mae: 0.0568 - val_root_mean_squared_error: 0.1028
# Epoch 455/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0977 - val_loss: 0.0567 - val_mse: 0.0106 - val_mae: 0.0567 - val_root_mean_squared_error: 0.1028
# Epoch 456/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0977 - val_loss: 0.0567 - val_mse: 0.0106 - val_mae: 0.0567 - val_root_mean_squared_error: 0.1028
# Epoch 457/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0977 - val_loss: 0.0567 - val_mse: 0.0106 - val_mae: 0.0567 - val_root_mean_squared_error: 0.1028
# Epoch 458/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0977 - val_loss: 0.0567 - val_mse: 0.0106 - val_mae: 0.0567 - val_root_mean_squared_error: 0.1028
# Epoch 459/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0977 - val_loss: 0.0567 - val_mse: 0.0106 - val_mae: 0.0567 - val_root_mean_squared_error: 0.1028
# Epoch 460/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0977 - val_loss: 0.0567 - val_mse: 0.0106 - val_mae: 0.0567 - val_root_mean_squared_error: 0.1028
# Epoch 461/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0977 - val_loss: 0.0567 - val_mse: 0.0106 - val_mae: 0.0567 - val_root_mean_squared_error: 0.1028
# Epoch 462/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0977 - val_loss: 0.0567 - val_mse: 0.0106 - val_mae: 0.0567 - val_root_mean_squared_error: 0.1028
# Epoch 463/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0977 - val_loss: 0.0567 - val_mse: 0.0106 - val_mae: 0.0567 - val_root_mean_squared_error: 0.1028
# Epoch 464/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0977 - val_loss: 0.0567 - val_mse: 0.0106 - val_mae: 0.0567 - val_root_mean_squared_error: 0.1028
# Epoch 465/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0977 - val_loss: 0.0567 - val_mse: 0.0106 - val_mae: 0.0567 - val_root_mean_squared_error: 0.1028
# Epoch 466/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0976 - val_loss: 0.0567 - val_mse: 0.0106 - val_mae: 0.0567 - val_root_mean_squared_error: 0.1028
# Epoch 467/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0976 - val_loss: 0.0567 - val_mse: 0.0106 - val_mae: 0.0567 - val_root_mean_squared_error: 0.1028
# Epoch 468/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0976 - val_loss: 0.0567 - val_mse: 0.0106 - val_mae: 0.0567 - val_root_mean_squared_error: 0.1028
# Epoch 469/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0976 - val_loss: 0.0567 - val_mse: 0.0106 - val_mae: 0.0567 - val_root_mean_squared_error: 0.1028
# Epoch 470/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0976 - val_loss: 0.0567 - val_mse: 0.0106 - val_mae: 0.0567 - val_root_mean_squared_error: 0.1028
# Epoch 471/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0976 - val_loss: 0.0567 - val_mse: 0.0106 - val_mae: 0.0567 - val_root_mean_squared_error: 0.1028
# Epoch 472/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0976 - val_loss: 0.0567 - val_mse: 0.0106 - val_mae: 0.0567 - val_root_mean_squared_error: 0.1028
# Epoch 473/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0976 - val_loss: 0.0567 - val_mse: 0.0106 - val_mae: 0.0567 - val_root_mean_squared_error: 0.1028
# Epoch 474/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0976 - val_loss: 0.0566 - val_mse: 0.0106 - val_mae: 0.0566 - val_root_mean_squared_error: 0.1027
# Epoch 475/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0976 - val_loss: 0.0566 - val_mse: 0.0106 - val_mae: 0.0566 - val_root_mean_squared_error: 0.1028
# Epoch 476/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0976 - val_loss: 0.0566 - val_mse: 0.0106 - val_mae: 0.0566 - val_root_mean_squared_error: 0.1028
# Epoch 477/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0543 - mse: 0.0095 - mae: 0.0543 - root_mean_squared_error: 0.0976 - val_loss: 0.0566 - val_mse: 0.0106 - val_mae: 0.0566 - val_root_mean_squared_error: 0.1028
# Epoch 478/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0976 - val_loss: 0.0566 - val_mse: 0.0106 - val_mae: 0.0566 - val_root_mean_squared_error: 0.1027
# Epoch 479/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0976 - val_loss: 0.0566 - val_mse: 0.0106 - val_mae: 0.0566 - val_root_mean_squared_error: 0.1027
# Epoch 480/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0976 - val_loss: 0.0566 - val_mse: 0.0106 - val_mae: 0.0566 - val_root_mean_squared_error: 0.1027
# Epoch 481/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0976 - val_loss: 0.0566 - val_mse: 0.0106 - val_mae: 0.0566 - val_root_mean_squared_error: 0.1027
# Epoch 482/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0976 - val_loss: 0.0566 - val_mse: 0.0106 - val_mae: 0.0566 - val_root_mean_squared_error: 0.1027
# Epoch 483/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0976 - val_loss: 0.0566 - val_mse: 0.0106 - val_mae: 0.0566 - val_root_mean_squared_error: 0.1027
# Epoch 484/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0976 - val_loss: 0.0566 - val_mse: 0.0106 - val_mae: 0.0566 - val_root_mean_squared_error: 0.1027
# Epoch 485/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0976 - val_loss: 0.0566 - val_mse: 0.0106 - val_mae: 0.0566 - val_root_mean_squared_error: 0.1027
# Epoch 486/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0975 - val_loss: 0.0566 - val_mse: 0.0106 - val_mae: 0.0566 - val_root_mean_squared_error: 0.1027
# Epoch 487/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0975 - val_loss: 0.0566 - val_mse: 0.0106 - val_mae: 0.0566 - val_root_mean_squared_error: 0.1027
# Epoch 488/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0975 - val_loss: 0.0566 - val_mse: 0.0106 - val_mae: 0.0566 - val_root_mean_squared_error: 0.1027
# Epoch 489/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0975 - val_loss: 0.0566 - val_mse: 0.0106 - val_mae: 0.0566 - val_root_mean_squared_error: 0.1027
# Epoch 490/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0975 - val_loss: 0.0566 - val_mse: 0.0106 - val_mae: 0.0566 - val_root_mean_squared_error: 0.1027
# Epoch 491/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0975 - val_loss: 0.0565 - val_mse: 0.0106 - val_mae: 0.0565 - val_root_mean_squared_error: 0.1027
# Epoch 492/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0975 - val_loss: 0.0565 - val_mse: 0.0106 - val_mae: 0.0565 - val_root_mean_squared_error: 0.1027
# Epoch 493/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0975 - val_loss: 0.0565 - val_mse: 0.0106 - val_mae: 0.0565 - val_root_mean_squared_error: 0.1027
# Epoch 494/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0975 - val_loss: 0.0565 - val_mse: 0.0106 - val_mae: 0.0565 - val_root_mean_squared_error: 0.1027
# Epoch 495/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0975 - val_loss: 0.0565 - val_mse: 0.0106 - val_mae: 0.0565 - val_root_mean_squared_error: 0.1027
# Epoch 496/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0975 - val_loss: 0.0565 - val_mse: 0.0106 - val_mae: 0.0565 - val_root_mean_squared_error: 0.1027
# Epoch 497/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0975 - val_loss: 0.0565 - val_mse: 0.0106 - val_mae: 0.0565 - val_root_mean_squared_error: 0.1027
# Epoch 498/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0975 - val_loss: 0.0565 - val_mse: 0.0106 - val_mae: 0.0565 - val_root_mean_squared_error: 0.1027
# Epoch 499/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0975 - val_loss: 0.0565 - val_mse: 0.0106 - val_mae: 0.0565 - val_root_mean_squared_error: 0.1027
# Epoch 500/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0542 - mse: 0.0095 - mae: 0.0542 - root_mean_squared_error: 0.0975 - val_loss: 0.0565 - val_mse: 0.0106 - val_mae: 0.0565 - val_root_mean_squared_error: 0.1027

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mae'],label='train mae')
pyplot.plot(history.history['val_mae'],label='val mae')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mse'],label='train mse')
pyplot.plot(history.history['val_mse'],label='val mse')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['root_mean_squared_error'],label='train rmse')
pyplot.plot(history.history['val_root_mean_squared_error'],label='val rmse')
pyplot.legend()
pyplot.show()
# Out:
# The testing MAE loss is: 0.055176817
# The testing MSE loss is: 0.009868687
# The testing RMSE loss is: 0.099341266

# %%
pyplot.plot(test_y[:,7],color='red', label='True Values')
pyplot.plot(out[:,7],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()

# %%
dataset_test=pd.read_excel('F:\MS thesis data/Hopper Crossing.xlsx')
dataset_test=dataset_test.drop(['Date/Time','Flowd'],axis=1)
dataset_test.dropna(inplace=True)

# %%
shape=np.shape(dataset_test)
print(shape)
pyplot.plot(dataset_test)
# Out:
# (26285, 3)
# [<matplotlib.lines.Line2D at 0x2c0317fcd08>,
#  <matplotlib.lines.Line2D at 0x2c0317fc648>,
#  <matplotlib.lines.Line2D at 0x2c0317fc848>]

# %%
dataset_test
# Out:
#        Cumulative rainfall   Flow  Level
# 0                      0.0  0.093    1.50
# 1                      0.0  0.093    1.50
# 2                      0.0  0.093    1.50
# 3                      0.0  0.093    1.50
# 4                      0.0  0.093    1.50
# ...                    ...    ...     ...
# 26280                  0.2  0.080    1.49
# 26281                  0.2  0.080    1.49
# 26282                  0.2  0.080    1.49
# 26283                  0.2  0.080    1.49
# 26284                  0.2  0.080    1.49
#
# [26285 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset_test)))
# Out:
# The std of original data is Cumulative rainfall    2.451640
# Flow                   0.520832
# Level                  0.083204
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset_test=dataset_test.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset_test.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset_test[:,0]== maxi[0])
    ind2=np.argwhere(dataset_test[:,1]== maxi[1])
    ind3=np.argwhere(dataset_test[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset_test.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset_test[:,0]== mini[0])
    ind2=np.argwhere(dataset_test[:,1]== mini[1])
    ind3=np.argwhere(dataset_test[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset_test)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset_test = min_max_scaler.fit_transform(dataset_test)
# Out:
# The std of cleaned data is 1.5154548293543502

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=8
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values

#one hour
#test_X, test_y = values[:, :-out_hour], values[:,-1]


test_X, test_y = values[:, :-out_hour], values[:, -out_hour: ]


test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6338, 42)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var2(t-1)  var3(t-1)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.524545   0.776699
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.549980   0.791262
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.603309   0.820388
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.650485   0.844660
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.709285   0.873786
#
#      var3(t)  var3(t+1)  var3(t+2)  var3(t+3)  var3(t+4)  var3(t+5)  \
# 6   0.791262   0.820388   0.844660   0.873786   0.898058   0.932039
# 7   0.820388   0.844660   0.873786   0.898058   0.932039   0.966019
# 8   0.844660   0.873786   0.898058   0.932039   0.966019   1.000000
# 9   0.873786   0.898058   0.932039   0.966019   1.000000   0.941748
# 10  0.898058   0.932039   0.966019   1.000000   0.941748   0.912621
#
#     var3(t+6)  var3(t+7)
# 6    0.966019   1.000000
# 7    1.000000   0.941748
# 8    0.941748   0.912621
# 9    0.912621   0.800971
# 10   0.800971   0.723301
#
# [5 rows x 26 columns]

# %%
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
# Out:
# The testing MAE loss is: 0.054950193
# The testing MSE loss is: 0.009851479
# The testing RMSE loss is: 0.099254616

# %%
pyplot.plot(test_y[:,7],color='red', label='True Values')
pyplot.plot(out[:,7],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()
