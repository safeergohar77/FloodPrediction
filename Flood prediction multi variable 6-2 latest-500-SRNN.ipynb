# %%
import pandas as pd
from pandas import concat
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from sklearn import preprocessing
from tensorflow.keras import backend as K
#from sklearn.preprocessing import MinMaxScaler
#from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input, Dense, LSTM,GRU,SimpleRNN, Activation
from matplotlib import pyplot
#from sklearn.model_selection import train_test_split

# %%
"# convert series to supervised learning\n" 
#windowing of data
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1),
    for i in range(n_in, 0, -1): #startes from n_in and decreses to 0 by decreasing each time -1
     cols.append(df.shift(i))
     names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
     cols.append(df.shift(-i))
     if i == 0:
       names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
     else:
       names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together\n",
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values\n",
    if dropnan:
      agg.dropna(inplace=True)
    return agg

# %%
#def root_mean_squared_error(y_true, y_pred):
 #       return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
dataset1=pd.read_excel('F:\MS thesis data/Brooklyn.xlsx')
dataset1=dataset1.drop(['Date/Time','Flowd'],axis=1)
dataset1.dropna(inplace=True)

# %%
shape=np.shape(dataset1)
print(shape)
pyplot.plot(dataset1)
# Out:
# (26302, 3)
# [<matplotlib.lines.Line2D at 0x2297e099bc8>,
#  <matplotlib.lines.Line2D at 0x2297ec47388>,
#  <matplotlib.lines.Line2D at 0x2297ec45d08>]

# %%
dataset1
# Out:
#        Cumulative rainfall    Flow  Level
# 0                       0.0  0.172   0.352
# 1                       0.0  0.180   0.356
# 2                       0.0  0.180   0.356
# 3                       0.0  0.189   0.360
# 4                       0.0  0.189   0.360
# ...                     ...    ...     ...
# 26297                   0.0  0.025   0.232
# 26298                   0.0  0.023   0.228
# 26299                   0.0  0.023   0.228
# 26300                   0.0  0.023   0.228
# 26301                   0.0  0.023   0.228
#
# [26302 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset1)))
# Out:
# The std of original data is Cumulative rainfall     2.872616
# Flow                    1.306642
# Level                   0.147238
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset=dataset1.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset[:,0]== maxi[0])
    ind2=np.argwhere(dataset[:,1]== maxi[1])
    ind3=np.argwhere(dataset[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset[:,0]== mini[0])
    ind2=np.argwhere(dataset[:,1]== mini[1])
    ind3=np.argwhere(dataset[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset = min_max_scaler.fit_transform(dataset)
# Out:
# The std of cleaned data is 1.626639593959813

# %%
pyplot.plot(dataset)
# Out:
# [<matplotlib.lines.Line2D at 0x2297ebcf208>,
#  <matplotlib.lines.Line2D at 0x2297eb7e3c8>,
#  <matplotlib.lines.Line2D at 0x2297eb7e588>]

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=2
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values
train_size  = int(len(dataset) * 0.50)
val_size=int(len(dataset) * 0.75)
train_X, train_y = values[0:train_size, :-out_hour], values[0:train_size,-out_hour: ]
val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-out_hour: ]
test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-out_hour:]
#for last hour
#train_X, train_y = values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]  #for only last hour
#val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]
#test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-1]
print(train_X, train_y)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6344, 24)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  var2(t-3)  var3(t-3)  \
# 6    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 7    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 8    0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
# 9    0.215385   0.524545   0.776699   0.123077   0.549980   0.791262
# 10   0.123077   0.549980   0.791262   0.092308   0.603309   0.820388
#
#     var1(t-2)  var2(t-2)  var3(t-2)  var1(t-1)  var2(t-1)  var3(t-1)  \
# 6    0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
# 7    0.215385   0.524545   0.776699   0.123077   0.549980   0.791262
# 8    0.123077   0.549980   0.791262   0.092308   0.603309   0.820388
# 9    0.092308   0.603309   0.820388   0.092308   0.650485   0.844660
# 10   0.092308   0.650485   0.844660   0.092308   0.709285   0.873786
#
#      var3(t)  var3(t+1)
# 6   0.791262   0.820388
# 7   0.820388   0.844660
# 8   0.844660   0.873786
# 9   0.873786   0.898058
# 10  0.898058   0.932039
# [[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]
#  [0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]
#  [0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]
#  ...
#  [0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]
#  [0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]
#  [0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]] [[0.79126215 0.8203884 ]
#  [0.8203884  0.8446602 ]
#  [0.8446602  0.8737864 ]
#  ...
#  [0.23786408 0.24271844]
#  [0.24271844 0.24757281]
#  [0.24757281 0.24757281]]

# %%
print(train_X, train_y)
# Out:
# [[[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]]
#
#  [[0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]]
#
#  [[0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]]
#
#  ...
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]]] [[0.79126215 0.8203884 ]
#  [0.8203884  0.8446602 ]
#  [0.8446602  0.8737864 ]
#  ...
#  [0.23786408 0.24271844]
#  [0.24271844 0.24757281]
#  [0.24757281 0.24757281]]

# %%
print(train_X.shape, train_y.shape, val_X.shape, val_y.shape)
# Out:
# (3175, 1, 18) (3175, 2) (1588, 1, 18) (1588, 2)

# %%
randomState = 46
np.random.seed(randomState)
#tensorflow.random.set_random_seed(randomState)
tensorflow.random.set_seed(randomState)
model = Sequential()
model.add(SimpleRNN(15,input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dense(22))
#model.add(Activation('relu'))    
model.add(Dense(out_hour,activation = "sigmoid"))
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.001)
#    opt=tensorflow.keras.optimizers.Adam(learning_rate=0.00075)
model.compile(loss='mae', optimizer=opt,metrics=['mse','mae',tensorflow.keras.metrics.RootMeanSquaredError()])
history = model.fit(train_X, train_y,validation_data=(val_X, val_y), epochs=500, batch_size=100,verbose=1,shuffle=False)
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)
# Out:
# Train on 3175 samples, validate on 1588 samples
# Epoch 1/500
# 3175/3175 [==============================] - 1s 338us/sample - loss: 0.2204 - mse: 0.0624 - mae: 0.2204 - root_mean_squared_error: 0.2497 - val_loss: 0.2314 - val_mse: 0.0699 - val_mae: 0.2314 - val_root_mean_squared_error: 0.2644
# Epoch 2/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.1972 - mse: 0.0534 - mae: 0.1972 - root_mean_squared_error: 0.2311 - val_loss: 0.2114 - val_mse: 0.0604 - val_mae: 0.2114 - val_root_mean_squared_error: 0.2457
# Epoch 3/500
# 3175/3175 [==============================] - 0s 19us/sample - loss: 0.1813 - mse: 0.0481 - mae: 0.1813 - root_mean_squared_error: 0.2192 - val_loss: 0.1961 - val_mse: 0.0535 - val_mae: 0.1961 - val_root_mean_squared_error: 0.2312
# Epoch 4/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.1685 - mse: 0.0435 - mae: 0.1685 - root_mean_squared_error: 0.2086 - val_loss: 0.1826 - val_mse: 0.0474 - val_mae: 0.1826 - val_root_mean_squared_error: 0.2176
# Epoch 5/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.1562 - mse: 0.0384 - mae: 0.1562 - root_mean_squared_error: 0.1959 - val_loss: 0.1694 - val_mse: 0.0412 - val_mae: 0.1694 - val_root_mean_squared_error: 0.2030
# Epoch 6/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.1433 - mse: 0.0325 - mae: 0.1433 - root_mean_squared_error: 0.1802 - val_loss: 0.1555 - val_mse: 0.0349 - val_mae: 0.1555 - val_root_mean_squared_error: 0.1868
# Epoch 7/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1296 - mse: 0.0264 - mae: 0.1296 - root_mean_squared_error: 0.1624 - val_loss: 0.1407 - val_mse: 0.0289 - val_mae: 0.1407 - val_root_mean_squared_error: 0.1700
# Epoch 8/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1159 - mse: 0.0209 - mae: 0.1159 - root_mean_squared_error: 0.1447 - val_loss: 0.1263 - val_mse: 0.0237 - val_mae: 0.1263 - val_root_mean_squared_error: 0.1540
# Epoch 9/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.1031 - mse: 0.0167 - mae: 0.1031 - root_mean_squared_error: 0.1291 - val_loss: 0.1136 - val_mse: 0.0196 - val_mae: 0.1136 - val_root_mean_squared_error: 0.1401
# Epoch 10/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0918 - mse: 0.0138 - mae: 0.0918 - root_mean_squared_error: 0.1173 - val_loss: 0.1029 - val_mse: 0.0166 - val_mae: 0.1029 - val_root_mean_squared_error: 0.1288
# Epoch 11/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0823 - mse: 0.0119 - mae: 0.0823 - root_mean_squared_error: 0.1091 - val_loss: 0.0941 - val_mse: 0.0144 - val_mae: 0.0941 - val_root_mean_squared_error: 0.1200
# Epoch 12/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0748 - mse: 0.0108 - mae: 0.0748 - root_mean_squared_error: 0.1037 - val_loss: 0.0873 - val_mse: 0.0130 - val_mae: 0.0873 - val_root_mean_squared_error: 0.1140
# Epoch 13/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0690 - mse: 0.0101 - mae: 0.0690 - root_mean_squared_error: 0.1006 - val_loss: 0.0821 - val_mse: 0.0121 - val_mae: 0.0821 - val_root_mean_squared_error: 0.1100
# Epoch 14/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0964 - mse: 0.0202 - mae: 0.0964 - root_mean_squared_error: 0.142 - 0s 21us/sample - loss: 0.0650 - mse: 0.0098 - mae: 0.0650 - root_mean_squared_error: 0.0989 - val_loss: 0.0782 - val_mse: 0.0115 - val_mae: 0.0782 - val_root_mean_squared_error: 0.1071
# Epoch 15/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0626 - mse: 0.0095 - mae: 0.0626 - root_mean_squared_error: 0.0977 - val_loss: 0.0753 - val_mse: 0.0110 - val_mae: 0.0753 - val_root_mean_squared_error: 0.1049
# Epoch 16/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0608 - mse: 0.0093 - mae: 0.0608 - root_mean_squared_error: 0.0966 - val_loss: 0.0731 - val_mse: 0.0107 - val_mae: 0.0731 - val_root_mean_squared_error: 0.1033
# Epoch 17/500
# 3175/3175 [==============================] - 0s 41us/sample - loss: 0.0594 - mse: 0.0091 - mae: 0.0594 - root_mean_squared_error: 0.0956 - val_loss: 0.0712 - val_mse: 0.0104 - val_mae: 0.0712 - val_root_mean_squared_error: 0.1018
# Epoch 18/500
# 3175/3175 [==============================] - 0s 40us/sample - loss: 0.0581 - mse: 0.0089 - mae: 0.0581 - root_mean_squared_error: 0.0944 - val_loss: 0.0695 - val_mse: 0.0100 - val_mae: 0.0695 - val_root_mean_squared_error: 0.1002
# Epoch 19/500
# 3175/3175 [==============================] - 0s 41us/sample - loss: 0.0568 - mse: 0.0087 - mae: 0.0568 - root_mean_squared_error: 0.0931 - val_loss: 0.0680 - val_mse: 0.0097 - val_mae: 0.0680 - val_root_mean_squared_error: 0.0987
# Epoch 20/500
# 3175/3175 [==============================] - 0s 41us/sample - loss: 0.0557 - mse: 0.0084 - mae: 0.0557 - root_mean_squared_error: 0.0916 - val_loss: 0.0666 - val_mse: 0.0095 - val_mae: 0.0666 - val_root_mean_squared_error: 0.0972
# Epoch 21/500
# 3175/3175 [==============================] - 0s 41us/sample - loss: 0.0545 - mse: 0.0081 - mae: 0.0545 - root_mean_squared_error: 0.0901 - val_loss: 0.0652 - val_mse: 0.0092 - val_mae: 0.0652 - val_root_mean_squared_error: 0.0958
# Epoch 22/500
# 3175/3175 [==============================] - 0s 40us/sample - loss: 0.0533 - mse: 0.0078 - mae: 0.0533 - root_mean_squared_error: 0.0886 - val_loss: 0.0638 - val_mse: 0.0089 - val_mae: 0.0638 - val_root_mean_squared_error: 0.0944
# Epoch 23/500
# 3175/3175 [==============================] - 0s 41us/sample - loss: 0.0521 - mse: 0.0075 - mae: 0.0521 - root_mean_squared_error: 0.0869 - val_loss: 0.0625 - val_mse: 0.0086 - val_mae: 0.0625 - val_root_mean_squared_error: 0.0929
# Epoch 24/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0509 - mse: 0.0073 - mae: 0.0509 - root_mean_squared_error: 0.0852 - val_loss: 0.0611 - val_mse: 0.0083 - val_mae: 0.0611 - val_root_mean_squared_error: 0.0913
# Epoch 25/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0497 - mse: 0.0070 - mae: 0.0497 - root_mean_squared_error: 0.0834 - val_loss: 0.0598 - val_mse: 0.0081 - val_mae: 0.0598 - val_root_mean_squared_error: 0.0898
# Epoch 26/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0484 - mse: 0.0067 - mae: 0.0484 - root_mean_squared_error: 0.0816 - val_loss: 0.0585 - val_mse: 0.0078 - val_mae: 0.0585 - val_root_mean_squared_error: 0.0885
# Epoch 27/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0473 - mse: 0.0064 - mae: 0.0473 - root_mean_squared_error: 0.0799 - val_loss: 0.0572 - val_mse: 0.0076 - val_mae: 0.0572 - val_root_mean_squared_error: 0.0871
# Epoch 28/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0849 - mse: 0.0154 - mae: 0.0849 - root_mean_squared_error: 0.124 - 0s 21us/sample - loss: 0.0461 - mse: 0.0061 - mae: 0.0461 - root_mean_squared_error: 0.0783 - val_loss: 0.0561 - val_mse: 0.0074 - val_mae: 0.0561 - val_root_mean_squared_error: 0.0861
# Epoch 29/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0450 - mse: 0.0059 - mae: 0.0450 - root_mean_squared_error: 0.0768 - val_loss: 0.0549 - val_mse: 0.0072 - val_mae: 0.0549 - val_root_mean_squared_error: 0.0849
# Epoch 30/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0440 - mse: 0.0057 - mae: 0.0440 - root_mean_squared_error: 0.0754 - val_loss: 0.0540 - val_mse: 0.0071 - val_mae: 0.0540 - val_root_mean_squared_error: 0.0841
# Epoch 31/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0431 - mse: 0.0055 - mae: 0.0431 - root_mean_squared_error: 0.0741 - val_loss: 0.0531 - val_mse: 0.0069 - val_mae: 0.0531 - val_root_mean_squared_error: 0.0832
# Epoch 32/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0422 - mse: 0.0053 - mae: 0.0422 - root_mean_squared_error: 0.0729 - val_loss: 0.0522 - val_mse: 0.0068 - val_mae: 0.0522 - val_root_mean_squared_error: 0.0825
# Epoch 33/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0414 - mse: 0.0052 - mae: 0.0414 - root_mean_squared_error: 0.0718 - val_loss: 0.0514 - val_mse: 0.0067 - val_mae: 0.0514 - val_root_mean_squared_error: 0.0817
# Epoch 34/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0407 - mse: 0.0050 - mae: 0.0407 - root_mean_squared_error: 0.0708 - val_loss: 0.0507 - val_mse: 0.0066 - val_mae: 0.0507 - val_root_mean_squared_error: 0.0812
# Epoch 35/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0400 - mse: 0.0049 - mae: 0.0400 - root_mean_squared_error: 0.0699 - val_loss: 0.0501 - val_mse: 0.0065 - val_mae: 0.0501 - val_root_mean_squared_error: 0.0807
# Epoch 36/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0394 - mse: 0.0048 - mae: 0.0394 - root_mean_squared_error: 0.0691 - val_loss: 0.0495 - val_mse: 0.0064 - val_mae: 0.0495 - val_root_mean_squared_error: 0.0801
# Epoch 37/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0389 - mse: 0.0047 - mae: 0.0389 - root_mean_squared_error: 0.0684 - val_loss: 0.0490 - val_mse: 0.0064 - val_mae: 0.0490 - val_root_mean_squared_error: 0.0797
# Epoch 38/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0385 - mse: 0.0046 - mae: 0.0385 - root_mean_squared_error: 0.0678 - val_loss: 0.0486 - val_mse: 0.0063 - val_mae: 0.0486 - val_root_mean_squared_error: 0.0794
# Epoch 39/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0382 - mse: 0.0045 - mae: 0.0382 - root_mean_squared_error: 0.0672 - val_loss: 0.0482 - val_mse: 0.0063 - val_mae: 0.0482 - val_root_mean_squared_error: 0.0791
# Epoch 40/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0379 - mse: 0.0044 - mae: 0.0379 - root_mean_squared_error: 0.0667 - val_loss: 0.0479 - val_mse: 0.0062 - val_mae: 0.0479 - val_root_mean_squared_error: 0.0788
# Epoch 41/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0376 - mse: 0.0044 - mae: 0.0376 - root_mean_squared_error: 0.0662 - val_loss: 0.0476 - val_mse: 0.0062 - val_mae: 0.0476 - val_root_mean_squared_error: 0.0785
# Epoch 42/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0373 - mse: 0.0043 - mae: 0.0373 - root_mean_squared_error: 0.0658 - val_loss: 0.0473 - val_mse: 0.0061 - val_mae: 0.0473 - val_root_mean_squared_error: 0.0783
# Epoch 43/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0371 - mse: 0.0043 - mae: 0.0371 - root_mean_squared_error: 0.0655 - val_loss: 0.0470 - val_mse: 0.0061 - val_mae: 0.0470 - val_root_mean_squared_error: 0.0780
# Epoch 44/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0716 - mse: 0.0110 - mae: 0.0716 - root_mean_squared_error: 0.104 - 0s 21us/sample - loss: 0.0368 - mse: 0.0042 - mae: 0.0368 - root_mean_squared_error: 0.0651 - val_loss: 0.0466 - val_mse: 0.0060 - val_mae: 0.0466 - val_root_mean_squared_error: 0.0776
# Epoch 45/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0366 - mse: 0.0042 - mae: 0.0366 - root_mean_squared_error: 0.0647 - val_loss: 0.0464 - val_mse: 0.0060 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0774
# Epoch 46/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0364 - mse: 0.0042 - mae: 0.0364 - root_mean_squared_error: 0.0645 - val_loss: 0.0462 - val_mse: 0.0060 - val_mae: 0.0462 - val_root_mean_squared_error: 0.0773
# Epoch 47/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0363 - mse: 0.0041 - mae: 0.0363 - root_mean_squared_error: 0.0642 - val_loss: 0.0459 - val_mse: 0.0059 - val_mae: 0.0459 - val_root_mean_squared_error: 0.0770
# Epoch 48/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0706 - mse: 0.0107 - mae: 0.0706 - root_mean_squared_error: 0.103 - 0s 21us/sample - loss: 0.0361 - mse: 0.0041 - mae: 0.0361 - root_mean_squared_error: 0.0640 - val_loss: 0.0456 - val_mse: 0.0059 - val_mae: 0.0456 - val_root_mean_squared_error: 0.0768
# Epoch 49/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0359 - mse: 0.0041 - mae: 0.0359 - root_mean_squared_error: 0.0638 - val_loss: 0.0453 - val_mse: 0.0058 - val_mae: 0.0453 - val_root_mean_squared_error: 0.0765
# Epoch 50/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0356 - mse: 0.0040 - mae: 0.0356 - root_mean_squared_error: 0.0635 - val_loss: 0.0451 - val_mse: 0.0058 - val_mae: 0.0451 - val_root_mean_squared_error: 0.0763
# Epoch 51/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0355 - mse: 0.0040 - mae: 0.0355 - root_mean_squared_error: 0.0633 - val_loss: 0.0448 - val_mse: 0.0058 - val_mae: 0.0448 - val_root_mean_squared_error: 0.0761
# Epoch 52/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0695 - mse: 0.0105 - mae: 0.0695 - root_mean_squared_error: 0.102 - 0s 21us/sample - loss: 0.0353 - mse: 0.0040 - mae: 0.0353 - root_mean_squared_error: 0.0632 - val_loss: 0.0446 - val_mse: 0.0058 - val_mae: 0.0446 - val_root_mean_squared_error: 0.0758
# Epoch 53/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0351 - mse: 0.0040 - mae: 0.0351 - root_mean_squared_error: 0.0630 - val_loss: 0.0444 - val_mse: 0.0057 - val_mae: 0.0444 - val_root_mean_squared_error: 0.0756
# Epoch 54/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0350 - mse: 0.0039 - mae: 0.0350 - root_mean_squared_error: 0.0628 - val_loss: 0.0442 - val_mse: 0.0057 - val_mae: 0.0442 - val_root_mean_squared_error: 0.0754
# Epoch 55/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0348 - mse: 0.0039 - mae: 0.0348 - root_mean_squared_error: 0.0626 - val_loss: 0.0440 - val_mse: 0.0057 - val_mae: 0.0440 - val_root_mean_squared_error: 0.0752
# Epoch 56/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0347 - mse: 0.0039 - mae: 0.0347 - root_mean_squared_error: 0.0625 - val_loss: 0.0437 - val_mse: 0.0056 - val_mae: 0.0437 - val_root_mean_squared_error: 0.0750
# Epoch 57/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0345 - mse: 0.0039 - mae: 0.0345 - root_mean_squared_error: 0.0623 - val_loss: 0.0435 - val_mse: 0.0056 - val_mae: 0.0435 - val_root_mean_squared_error: 0.0748
# Epoch 58/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0344 - mse: 0.0039 - mae: 0.0344 - root_mean_squared_error: 0.0622 - val_loss: 0.0434 - val_mse: 0.0056 - val_mae: 0.0434 - val_root_mean_squared_error: 0.0747
# Epoch 59/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0342 - mse: 0.0038 - mae: 0.0342 - root_mean_squared_error: 0.0620 - val_loss: 0.0432 - val_mse: 0.0056 - val_mae: 0.0432 - val_root_mean_squared_error: 0.0745
# Epoch 60/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0341 - mse: 0.0038 - mae: 0.0341 - root_mean_squared_error: 0.0619 - val_loss: 0.0431 - val_mse: 0.0055 - val_mae: 0.0431 - val_root_mean_squared_error: 0.0745
# Epoch 61/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0340 - mse: 0.0038 - mae: 0.0340 - root_mean_squared_error: 0.0618 - val_loss: 0.0429 - val_mse: 0.0055 - val_mae: 0.0429 - val_root_mean_squared_error: 0.0743
# Epoch 62/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0339 - mse: 0.0038 - mae: 0.0339 - root_mean_squared_error: 0.0617 - val_loss: 0.0427 - val_mse: 0.0055 - val_mae: 0.0427 - val_root_mean_squared_error: 0.0742
# Epoch 63/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0337 - mse: 0.0038 - mae: 0.0337 - root_mean_squared_error: 0.0616 - val_loss: 0.0425 - val_mse: 0.0055 - val_mae: 0.0425 - val_root_mean_squared_error: 0.0740
# Epoch 64/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0336 - mse: 0.0038 - mae: 0.0336 - root_mean_squared_error: 0.0615 - val_loss: 0.0424 - val_mse: 0.0055 - val_mae: 0.0424 - val_root_mean_squared_error: 0.0739
# Epoch 65/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0335 - mse: 0.0038 - mae: 0.0335 - root_mean_squared_error: 0.0614 - val_loss: 0.0422 - val_mse: 0.0054 - val_mae: 0.0422 - val_root_mean_squared_error: 0.0738
# Epoch 66/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0334 - mse: 0.0038 - mae: 0.0334 - root_mean_squared_error: 0.0613 - val_loss: 0.0420 - val_mse: 0.0054 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0736
# Epoch 67/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0332 - mse: 0.0037 - mae: 0.0332 - root_mean_squared_error: 0.0612 - val_loss: 0.0419 - val_mse: 0.0054 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0735
# Epoch 68/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0331 - mse: 0.0037 - mae: 0.0331 - root_mean_squared_error: 0.0612 - val_loss: 0.0417 - val_mse: 0.0054 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0733
# Epoch 69/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0330 - mse: 0.0037 - mae: 0.0330 - root_mean_squared_error: 0.0610 - val_loss: 0.0415 - val_mse: 0.0053 - val_mae: 0.0415 - val_root_mean_squared_error: 0.0731
# Epoch 70/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0328 - mse: 0.0037 - mae: 0.0328 - root_mean_squared_error: 0.0609 - val_loss: 0.0413 - val_mse: 0.0053 - val_mae: 0.0413 - val_root_mean_squared_error: 0.0730
# Epoch 71/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0327 - mse: 0.0037 - mae: 0.0327 - root_mean_squared_error: 0.0609 - val_loss: 0.0412 - val_mse: 0.0053 - val_mae: 0.0412 - val_root_mean_squared_error: 0.0729
# Epoch 72/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0326 - mse: 0.0037 - mae: 0.0326 - root_mean_squared_error: 0.0608 - val_loss: 0.0410 - val_mse: 0.0053 - val_mae: 0.0410 - val_root_mean_squared_error: 0.0727
# Epoch 73/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0324 - mse: 0.0037 - mae: 0.0324 - root_mean_squared_error: 0.0607 - val_loss: 0.0409 - val_mse: 0.0053 - val_mae: 0.0409 - val_root_mean_squared_error: 0.0726
# Epoch 74/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0626 - mse: 0.0096 - mae: 0.0626 - root_mean_squared_error: 0.098 - 0s 21us/sample - loss: 0.0324 - mse: 0.0037 - mae: 0.0324 - root_mean_squared_error: 0.0606 - val_loss: 0.0407 - val_mse: 0.0053 - val_mae: 0.0407 - val_root_mean_squared_error: 0.0725
# Epoch 75/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0322 - mse: 0.0037 - mae: 0.0322 - root_mean_squared_error: 0.0605 - val_loss: 0.0406 - val_mse: 0.0052 - val_mae: 0.0406 - val_root_mean_squared_error: 0.0724
# Epoch 76/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0321 - mse: 0.0037 - mae: 0.0321 - root_mean_squared_error: 0.0605 - val_loss: 0.0404 - val_mse: 0.0052 - val_mae: 0.0404 - val_root_mean_squared_error: 0.0723
# Epoch 77/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0320 - mse: 0.0036 - mae: 0.0320 - root_mean_squared_error: 0.0604 - val_loss: 0.0403 - val_mse: 0.0052 - val_mae: 0.0403 - val_root_mean_squared_error: 0.0722
# Epoch 78/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0319 - mse: 0.0036 - mae: 0.0319 - root_mean_squared_error: 0.0603 - val_loss: 0.0401 - val_mse: 0.0052 - val_mae: 0.0401 - val_root_mean_squared_error: 0.0721
# Epoch 79/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0318 - mse: 0.0036 - mae: 0.0318 - root_mean_squared_error: 0.0603 - val_loss: 0.0400 - val_mse: 0.0052 - val_mae: 0.0400 - val_root_mean_squared_error: 0.0720
# Epoch 80/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0317 - mse: 0.0036 - mae: 0.0317 - root_mean_squared_error: 0.0602 - val_loss: 0.0398 - val_mse: 0.0052 - val_mae: 0.0398 - val_root_mean_squared_error: 0.0719
# Epoch 81/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0316 - mse: 0.0036 - mae: 0.0316 - root_mean_squared_error: 0.0602 - val_loss: 0.0397 - val_mse: 0.0052 - val_mae: 0.0397 - val_root_mean_squared_error: 0.0718
# Epoch 82/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0315 - mse: 0.0036 - mae: 0.0315 - root_mean_squared_error: 0.0601 - val_loss: 0.0396 - val_mse: 0.0051 - val_mae: 0.0396 - val_root_mean_squared_error: 0.0717
# Epoch 83/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0314 - mse: 0.0036 - mae: 0.0314 - root_mean_squared_error: 0.0601 - val_loss: 0.0394 - val_mse: 0.0051 - val_mae: 0.0394 - val_root_mean_squared_error: 0.0717
# Epoch 84/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0313 - mse: 0.0036 - mae: 0.0313 - root_mean_squared_error: 0.0600 - val_loss: 0.0393 - val_mse: 0.0051 - val_mae: 0.0393 - val_root_mean_squared_error: 0.0716
# Epoch 85/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0312 - mse: 0.0036 - mae: 0.0312 - root_mean_squared_error: 0.0600 - val_loss: 0.0392 - val_mse: 0.0051 - val_mae: 0.0392 - val_root_mean_squared_error: 0.0715
# Epoch 86/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0311 - mse: 0.0036 - mae: 0.0311 - root_mean_squared_error: 0.0599 - val_loss: 0.0390 - val_mse: 0.0051 - val_mae: 0.0390 - val_root_mean_squared_error: 0.0714
# Epoch 87/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0310 - mse: 0.0036 - mae: 0.0310 - root_mean_squared_error: 0.0599 - val_loss: 0.0389 - val_mse: 0.0051 - val_mae: 0.0389 - val_root_mean_squared_error: 0.0713
# Epoch 88/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0309 - mse: 0.0036 - mae: 0.0309 - root_mean_squared_error: 0.0599 - val_loss: 0.0387 - val_mse: 0.0051 - val_mae: 0.0387 - val_root_mean_squared_error: 0.0712
# Epoch 89/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0308 - mse: 0.0036 - mae: 0.0308 - root_mean_squared_error: 0.0598 - val_loss: 0.0386 - val_mse: 0.0051 - val_mae: 0.0386 - val_root_mean_squared_error: 0.0712
# Epoch 90/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0307 - mse: 0.0036 - mae: 0.0307 - root_mean_squared_error: 0.0598 - val_loss: 0.0385 - val_mse: 0.0051 - val_mae: 0.0385 - val_root_mean_squared_error: 0.0711
# Epoch 91/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0306 - mse: 0.0036 - mae: 0.0306 - root_mean_squared_error: 0.0598 - val_loss: 0.0384 - val_mse: 0.0051 - val_mae: 0.0384 - val_root_mean_squared_error: 0.0711
# Epoch 92/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0305 - mse: 0.0036 - mae: 0.0305 - root_mean_squared_error: 0.0597 - val_loss: 0.0383 - val_mse: 0.0050 - val_mae: 0.0383 - val_root_mean_squared_error: 0.0710
# Epoch 93/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0304 - mse: 0.0036 - mae: 0.0304 - root_mean_squared_error: 0.0597 - val_loss: 0.0382 - val_mse: 0.0050 - val_mae: 0.0382 - val_root_mean_squared_error: 0.0709
# Epoch 94/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0304 - mse: 0.0036 - mae: 0.0304 - root_mean_squared_error: 0.0597 - val_loss: 0.0380 - val_mse: 0.0050 - val_mae: 0.0380 - val_root_mean_squared_error: 0.0708
# Epoch 95/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0303 - mse: 0.0036 - mae: 0.0303 - root_mean_squared_error: 0.0596 - val_loss: 0.0379 - val_mse: 0.0050 - val_mae: 0.0379 - val_root_mean_squared_error: 0.0708
# Epoch 96/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0302 - mse: 0.0036 - mae: 0.0302 - root_mean_squared_error: 0.0596 - val_loss: 0.0378 - val_mse: 0.0050 - val_mae: 0.0378 - val_root_mean_squared_error: 0.0707
# Epoch 97/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0301 - mse: 0.0036 - mae: 0.0301 - root_mean_squared_error: 0.0596 - val_loss: 0.0377 - val_mse: 0.0050 - val_mae: 0.0377 - val_root_mean_squared_error: 0.0708
# Epoch 98/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0300 - mse: 0.0036 - mae: 0.0300 - root_mean_squared_error: 0.0596 - val_loss: 0.0376 - val_mse: 0.0050 - val_mae: 0.0376 - val_root_mean_squared_error: 0.0707
# Epoch 99/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0300 - mse: 0.0036 - mae: 0.0300 - root_mean_squared_error: 0.0596 - val_loss: 0.0375 - val_mse: 0.0050 - val_mae: 0.0375 - val_root_mean_squared_error: 0.0706
# Epoch 100/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0299 - mse: 0.0036 - mae: 0.0299 - root_mean_squared_error: 0.0596 - val_loss: 0.0374 - val_mse: 0.0050 - val_mae: 0.0374 - val_root_mean_squared_error: 0.0706
# Epoch 101/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0298 - mse: 0.0036 - mae: 0.0298 - root_mean_squared_error: 0.0596 - val_loss: 0.0373 - val_mse: 0.0050 - val_mae: 0.0373 - val_root_mean_squared_error: 0.0705
# Epoch 102/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0298 - mse: 0.0036 - mae: 0.0298 - root_mean_squared_error: 0.0596 - val_loss: 0.0372 - val_mse: 0.0050 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0704
# Epoch 103/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0297 - mse: 0.0036 - mae: 0.0297 - root_mean_squared_error: 0.0596 - val_loss: 0.0371 - val_mse: 0.0050 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0704
# Epoch 104/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0296 - mse: 0.0036 - mae: 0.0296 - root_mean_squared_error: 0.0596 - val_loss: 0.0370 - val_mse: 0.0049 - val_mae: 0.0370 - val_root_mean_squared_error: 0.0704
# Epoch 105/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0296 - mse: 0.0036 - mae: 0.0296 - root_mean_squared_error: 0.0596 - val_loss: 0.0369 - val_mse: 0.0049 - val_mae: 0.0369 - val_root_mean_squared_error: 0.0703
# Epoch 106/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0295 - mse: 0.0036 - mae: 0.0295 - root_mean_squared_error: 0.0596 - val_loss: 0.0368 - val_mse: 0.0049 - val_mae: 0.0368 - val_root_mean_squared_error: 0.0702
# Epoch 107/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0295 - mse: 0.0036 - mae: 0.0295 - root_mean_squared_error: 0.0596 - val_loss: 0.0367 - val_mse: 0.0049 - val_mae: 0.0367 - val_root_mean_squared_error: 0.0702
# Epoch 108/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0294 - mse: 0.0036 - mae: 0.0294 - root_mean_squared_error: 0.0596 - val_loss: 0.0367 - val_mse: 0.0049 - val_mae: 0.0367 - val_root_mean_squared_error: 0.0702
# Epoch 109/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0294 - mse: 0.0036 - mae: 0.0294 - root_mean_squared_error: 0.0596 - val_loss: 0.0366 - val_mse: 0.0049 - val_mae: 0.0366 - val_root_mean_squared_error: 0.0701
# Epoch 110/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0293 - mse: 0.0036 - mae: 0.0293 - root_mean_squared_error: 0.0596 - val_loss: 0.0365 - val_mse: 0.0049 - val_mae: 0.0365 - val_root_mean_squared_error: 0.0700
# Epoch 111/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0293 - mse: 0.0036 - mae: 0.0293 - root_mean_squared_error: 0.0596 - val_loss: 0.0364 - val_mse: 0.0049 - val_mae: 0.0364 - val_root_mean_squared_error: 0.0700
# Epoch 112/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0293 - mse: 0.0036 - mae: 0.0293 - root_mean_squared_error: 0.0596 - val_loss: 0.0364 - val_mse: 0.0049 - val_mae: 0.0364 - val_root_mean_squared_error: 0.0699
# Epoch 113/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0292 - mse: 0.0036 - mae: 0.0292 - root_mean_squared_error: 0.0596 - val_loss: 0.0363 - val_mse: 0.0049 - val_mae: 0.0363 - val_root_mean_squared_error: 0.0699
# Epoch 114/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0292 - mse: 0.0036 - mae: 0.0292 - root_mean_squared_error: 0.0596 - val_loss: 0.0362 - val_mse: 0.0049 - val_mae: 0.0362 - val_root_mean_squared_error: 0.0699
# Epoch 115/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0291 - mse: 0.0036 - mae: 0.0291 - root_mean_squared_error: 0.0596 - val_loss: 0.0362 - val_mse: 0.0049 - val_mae: 0.0362 - val_root_mean_squared_error: 0.0698
# Epoch 116/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0291 - mse: 0.0036 - mae: 0.0291 - root_mean_squared_error: 0.0596 - val_loss: 0.0361 - val_mse: 0.0049 - val_mae: 0.0361 - val_root_mean_squared_error: 0.0697
# Epoch 117/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0291 - mse: 0.0036 - mae: 0.0291 - root_mean_squared_error: 0.0596 - val_loss: 0.0360 - val_mse: 0.0049 - val_mae: 0.0360 - val_root_mean_squared_error: 0.0697
# Epoch 118/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0290 - mse: 0.0036 - mae: 0.0290 - root_mean_squared_error: 0.0596 - val_loss: 0.0360 - val_mse: 0.0049 - val_mae: 0.0360 - val_root_mean_squared_error: 0.0697
# Epoch 119/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0290 - mse: 0.0036 - mae: 0.0290 - root_mean_squared_error: 0.0596 - val_loss: 0.0359 - val_mse: 0.0049 - val_mae: 0.0359 - val_root_mean_squared_error: 0.0697
# Epoch 120/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0290 - mse: 0.0036 - mae: 0.0290 - root_mean_squared_error: 0.0596 - val_loss: 0.0358 - val_mse: 0.0049 - val_mae: 0.0358 - val_root_mean_squared_error: 0.0697
# Epoch 121/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0289 - mse: 0.0036 - mae: 0.0289 - root_mean_squared_error: 0.0596 - val_loss: 0.0358 - val_mse: 0.0048 - val_mae: 0.0358 - val_root_mean_squared_error: 0.0696
# Epoch 122/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0289 - mse: 0.0036 - mae: 0.0289 - root_mean_squared_error: 0.0596 - val_loss: 0.0357 - val_mse: 0.0048 - val_mae: 0.0357 - val_root_mean_squared_error: 0.0696
# Epoch 123/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0289 - mse: 0.0036 - mae: 0.0289 - root_mean_squared_error: 0.0596 - val_loss: 0.0357 - val_mse: 0.0048 - val_mae: 0.0357 - val_root_mean_squared_error: 0.0696
# Epoch 124/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0288 - mse: 0.0036 - mae: 0.0288 - root_mean_squared_error: 0.0596 - val_loss: 0.0356 - val_mse: 0.0049 - val_mae: 0.0356 - val_root_mean_squared_error: 0.0697
# Epoch 125/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0288 - mse: 0.0035 - mae: 0.0288 - root_mean_squared_error: 0.0596 - val_loss: 0.0355 - val_mse: 0.0049 - val_mae: 0.0355 - val_root_mean_squared_error: 0.0697
# Epoch 126/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0288 - mse: 0.0035 - mae: 0.0288 - root_mean_squared_error: 0.0596 - val_loss: 0.0354 - val_mse: 0.0049 - val_mae: 0.0354 - val_root_mean_squared_error: 0.0698
# Epoch 127/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0287 - mse: 0.0036 - mae: 0.0287 - root_mean_squared_error: 0.0596 - val_loss: 0.0354 - val_mse: 0.0049 - val_mae: 0.0354 - val_root_mean_squared_error: 0.0697
# Epoch 128/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0287 - mse: 0.0035 - mae: 0.0287 - root_mean_squared_error: 0.0596 - val_loss: 0.0353 - val_mse: 0.0049 - val_mae: 0.0353 - val_root_mean_squared_error: 0.0698
# Epoch 129/500
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0550 - mse: 0.0094 - mae: 0.0550 - root_mean_squared_error: 0.096 - 0s 20us/sample - loss: 0.0287 - mse: 0.0035 - mae: 0.0287 - root_mean_squared_error: 0.0596 - val_loss: 0.0353 - val_mse: 0.0049 - val_mae: 0.0353 - val_root_mean_squared_error: 0.0697
# Epoch 130/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0287 - mse: 0.0036 - mae: 0.0287 - root_mean_squared_error: 0.0596 - val_loss: 0.0352 - val_mse: 0.0048 - val_mae: 0.0352 - val_root_mean_squared_error: 0.0696
# Epoch 131/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0287 - mse: 0.0036 - mae: 0.0287 - root_mean_squared_error: 0.0596 - val_loss: 0.0352 - val_mse: 0.0048 - val_mae: 0.0352 - val_root_mean_squared_error: 0.0696
# Epoch 132/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0286 - mse: 0.0036 - mae: 0.0286 - root_mean_squared_error: 0.0596 - val_loss: 0.0351 - val_mse: 0.0048 - val_mae: 0.0351 - val_root_mean_squared_error: 0.0696
# Epoch 133/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0286 - mse: 0.0036 - mae: 0.0286 - root_mean_squared_error: 0.0596 - val_loss: 0.0351 - val_mse: 0.0049 - val_mae: 0.0351 - val_root_mean_squared_error: 0.0697
# Epoch 134/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0286 - mse: 0.0036 - mae: 0.0286 - root_mean_squared_error: 0.0596 - val_loss: 0.0350 - val_mse: 0.0049 - val_mae: 0.0350 - val_root_mean_squared_error: 0.0697
# Epoch 135/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0286 - mse: 0.0036 - mae: 0.0286 - root_mean_squared_error: 0.0596 - val_loss: 0.0350 - val_mse: 0.0048 - val_mae: 0.0350 - val_root_mean_squared_error: 0.0696
# Epoch 136/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0285 - mse: 0.0036 - mae: 0.0285 - root_mean_squared_error: 0.0596 - val_loss: 0.0349 - val_mse: 0.0048 - val_mae: 0.0349 - val_root_mean_squared_error: 0.0696
# Epoch 137/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0285 - mse: 0.0036 - mae: 0.0285 - root_mean_squared_error: 0.0596 - val_loss: 0.0349 - val_mse: 0.0048 - val_mae: 0.0349 - val_root_mean_squared_error: 0.0696
# Epoch 138/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0285 - mse: 0.0036 - mae: 0.0285 - root_mean_squared_error: 0.0596 - val_loss: 0.0348 - val_mse: 0.0048 - val_mae: 0.0348 - val_root_mean_squared_error: 0.0696
# Epoch 139/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0285 - mse: 0.0036 - mae: 0.0285 - root_mean_squared_error: 0.0596 - val_loss: 0.0348 - val_mse: 0.0049 - val_mae: 0.0348 - val_root_mean_squared_error: 0.0697
# Epoch 140/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0285 - mse: 0.0036 - mae: 0.0285 - root_mean_squared_error: 0.0597 - val_loss: 0.0348 - val_mse: 0.0049 - val_mae: 0.0348 - val_root_mean_squared_error: 0.0697
# Epoch 141/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0284 - mse: 0.0036 - mae: 0.0284 - root_mean_squared_error: 0.0597 - val_loss: 0.0347 - val_mse: 0.0049 - val_mae: 0.0347 - val_root_mean_squared_error: 0.0697
# Epoch 142/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0284 - mse: 0.0036 - mae: 0.0284 - root_mean_squared_error: 0.0597 - val_loss: 0.0347 - val_mse: 0.0049 - val_mae: 0.0347 - val_root_mean_squared_error: 0.0697
# Epoch 143/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0284 - mse: 0.0036 - mae: 0.0284 - root_mean_squared_error: 0.0597 - val_loss: 0.0347 - val_mse: 0.0049 - val_mae: 0.0347 - val_root_mean_squared_error: 0.0697
# Epoch 144/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0284 - mse: 0.0036 - mae: 0.0284 - root_mean_squared_error: 0.0597 - val_loss: 0.0346 - val_mse: 0.0049 - val_mae: 0.0346 - val_root_mean_squared_error: 0.0697
# Epoch 145/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0284 - mse: 0.0036 - mae: 0.0284 - root_mean_squared_error: 0.0597 - val_loss: 0.0346 - val_mse: 0.0049 - val_mae: 0.0346 - val_root_mean_squared_error: 0.0697
# Epoch 146/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0284 - mse: 0.0036 - mae: 0.0284 - root_mean_squared_error: 0.0597 - val_loss: 0.0346 - val_mse: 0.0049 - val_mae: 0.0346 - val_root_mean_squared_error: 0.0697
# Epoch 147/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0283 - mse: 0.0036 - mae: 0.0283 - root_mean_squared_error: 0.0597 - val_loss: 0.0345 - val_mse: 0.0049 - val_mae: 0.0345 - val_root_mean_squared_error: 0.0698
# Epoch 148/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0284 - mse: 0.0036 - mae: 0.0284 - root_mean_squared_error: 0.0597 - val_loss: 0.0345 - val_mse: 0.0049 - val_mae: 0.0345 - val_root_mean_squared_error: 0.0697
# Epoch 149/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0284 - mse: 0.0036 - mae: 0.0284 - root_mean_squared_error: 0.0597 - val_loss: 0.0344 - val_mse: 0.0049 - val_mae: 0.0344 - val_root_mean_squared_error: 0.0697
# Epoch 150/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0284 - mse: 0.0036 - mae: 0.0284 - root_mean_squared_error: 0.0597 - val_loss: 0.0344 - val_mse: 0.0049 - val_mae: 0.0344 - val_root_mean_squared_error: 0.0697
# Epoch 151/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0283 - mse: 0.0036 - mae: 0.0283 - root_mean_squared_error: 0.0597 - val_loss: 0.0343 - val_mse: 0.0048 - val_mae: 0.0343 - val_root_mean_squared_error: 0.0696
# Epoch 152/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0283 - mse: 0.0036 - mae: 0.0283 - root_mean_squared_error: 0.0597 - val_loss: 0.0343 - val_mse: 0.0049 - val_mae: 0.0343 - val_root_mean_squared_error: 0.0697
# Epoch 153/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0283 - mse: 0.0036 - mae: 0.0283 - root_mean_squared_error: 0.0597 - val_loss: 0.0342 - val_mse: 0.0048 - val_mae: 0.0342 - val_root_mean_squared_error: 0.0696
# Epoch 154/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0282 - mse: 0.0036 - mae: 0.0282 - root_mean_squared_error: 0.0597 - val_loss: 0.0342 - val_mse: 0.0048 - val_mae: 0.0342 - val_root_mean_squared_error: 0.0696
# Epoch 155/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0282 - mse: 0.0036 - mae: 0.0282 - root_mean_squared_error: 0.0597 - val_loss: 0.0342 - val_mse: 0.0048 - val_mae: 0.0342 - val_root_mean_squared_error: 0.0696
# Epoch 156/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0282 - mse: 0.0036 - mae: 0.0282 - root_mean_squared_error: 0.0597 - val_loss: 0.0341 - val_mse: 0.0048 - val_mae: 0.0341 - val_root_mean_squared_error: 0.0694
# Epoch 157/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0282 - mse: 0.0036 - mae: 0.0282 - root_mean_squared_error: 0.0597 - val_loss: 0.0342 - val_mse: 0.0048 - val_mae: 0.0342 - val_root_mean_squared_error: 0.0696
# Epoch 158/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0282 - mse: 0.0036 - mae: 0.0282 - root_mean_squared_error: 0.0597 - val_loss: 0.0341 - val_mse: 0.0048 - val_mae: 0.0341 - val_root_mean_squared_error: 0.0695
# Epoch 159/500
# 3175/3175 [==============================] - 0s 18us/sample - loss: 0.0281 - mse: 0.0036 - mae: 0.0281 - root_mean_squared_error: 0.0597 - val_loss: 0.0341 - val_mse: 0.0048 - val_mae: 0.0341 - val_root_mean_squared_error: 0.0694
# Epoch 160/500
# 3175/3175 [==============================] - 0s 17us/sample - loss: 0.0281 - mse: 0.0036 - mae: 0.0281 - root_mean_squared_error: 0.0597 - val_loss: 0.0341 - val_mse: 0.0048 - val_mae: 0.0341 - val_root_mean_squared_error: 0.0694
# Epoch 161/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0281 - mse: 0.0036 - mae: 0.0281 - root_mean_squared_error: 0.0596 - val_loss: 0.0340 - val_mse: 0.0048 - val_mae: 0.0340 - val_root_mean_squared_error: 0.0693
# Epoch 162/500
# 3175/3175 [==============================] - 0s 18us/sample - loss: 0.0281 - mse: 0.0036 - mae: 0.0281 - root_mean_squared_error: 0.0597 - val_loss: 0.0340 - val_mse: 0.0048 - val_mae: 0.0340 - val_root_mean_squared_error: 0.0694
# Epoch 163/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0281 - mse: 0.0036 - mae: 0.0281 - root_mean_squared_error: 0.0596 - val_loss: 0.0340 - val_mse: 0.0048 - val_mae: 0.0340 - val_root_mean_squared_error: 0.0693
# Epoch 164/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0281 - mse: 0.0036 - mae: 0.0281 - root_mean_squared_error: 0.0597 - val_loss: 0.0339 - val_mse: 0.0048 - val_mae: 0.0339 - val_root_mean_squared_error: 0.0693
# Epoch 165/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0281 - mse: 0.0036 - mae: 0.0281 - root_mean_squared_error: 0.0596 - val_loss: 0.0339 - val_mse: 0.0048 - val_mae: 0.0339 - val_root_mean_squared_error: 0.0693
# Epoch 166/500
# 3175/3175 [==============================] - 0s 16us/sample - loss: 0.0280 - mse: 0.0036 - mae: 0.0280 - root_mean_squared_error: 0.0596 - val_loss: 0.0338 - val_mse: 0.0048 - val_mae: 0.0338 - val_root_mean_squared_error: 0.0693
# Epoch 167/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0280 - mse: 0.0036 - mae: 0.0280 - root_mean_squared_error: 0.0596 - val_loss: 0.0338 - val_mse: 0.0048 - val_mae: 0.0338 - val_root_mean_squared_error: 0.0692
# Epoch 168/500
# 3175/3175 [==============================] - 0s 17us/sample - loss: 0.0280 - mse: 0.0036 - mae: 0.0280 - root_mean_squared_error: 0.0596 - val_loss: 0.0338 - val_mse: 0.0048 - val_mae: 0.0338 - val_root_mean_squared_error: 0.0692
# Epoch 169/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0280 - mse: 0.0036 - mae: 0.0280 - root_mean_squared_error: 0.0596 - val_loss: 0.0338 - val_mse: 0.0048 - val_mae: 0.0338 - val_root_mean_squared_error: 0.0691
# Epoch 170/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0280 - mse: 0.0036 - mae: 0.0280 - root_mean_squared_error: 0.0596 - val_loss: 0.0338 - val_mse: 0.0048 - val_mae: 0.0338 - val_root_mean_squared_error: 0.0691
# Epoch 171/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0280 - mse: 0.0036 - mae: 0.0280 - root_mean_squared_error: 0.0596 - val_loss: 0.0337 - val_mse: 0.0048 - val_mae: 0.0337 - val_root_mean_squared_error: 0.0692
# Epoch 172/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0280 - mse: 0.0036 - mae: 0.0280 - root_mean_squared_error: 0.0596 - val_loss: 0.0337 - val_mse: 0.0048 - val_mae: 0.0337 - val_root_mean_squared_error: 0.0691
# Epoch 173/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0279 - mse: 0.0036 - mae: 0.0279 - root_mean_squared_error: 0.0596 - val_loss: 0.0337 - val_mse: 0.0048 - val_mae: 0.0337 - val_root_mean_squared_error: 0.0691
# Epoch 174/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0279 - mse: 0.0036 - mae: 0.0279 - root_mean_squared_error: 0.0596 - val_loss: 0.0336 - val_mse: 0.0048 - val_mae: 0.0336 - val_root_mean_squared_error: 0.0691
# Epoch 175/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0280 - mse: 0.0036 - mae: 0.0280 - root_mean_squared_error: 0.0596 - val_loss: 0.0336 - val_mse: 0.0048 - val_mae: 0.0336 - val_root_mean_squared_error: 0.0690
# Epoch 176/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0279 - mse: 0.0036 - mae: 0.0279 - root_mean_squared_error: 0.0596 - val_loss: 0.0336 - val_mse: 0.0048 - val_mae: 0.0336 - val_root_mean_squared_error: 0.0690
# Epoch 177/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0279 - mse: 0.0035 - mae: 0.0279 - root_mean_squared_error: 0.0596 - val_loss: 0.0336 - val_mse: 0.0048 - val_mae: 0.0336 - val_root_mean_squared_error: 0.0690
# Epoch 178/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0279 - mse: 0.0035 - mae: 0.0279 - root_mean_squared_error: 0.0596 - val_loss: 0.0335 - val_mse: 0.0048 - val_mae: 0.0335 - val_root_mean_squared_error: 0.0690
# Epoch 179/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0279 - mse: 0.0035 - mae: 0.0279 - root_mean_squared_error: 0.0596 - val_loss: 0.0335 - val_mse: 0.0048 - val_mae: 0.0335 - val_root_mean_squared_error: 0.0690
# Epoch 180/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0279 - mse: 0.0036 - mae: 0.0279 - root_mean_squared_error: 0.0596 - val_loss: 0.0335 - val_mse: 0.0048 - val_mae: 0.0335 - val_root_mean_squared_error: 0.0690
# Epoch 181/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0279 - mse: 0.0035 - mae: 0.0279 - root_mean_squared_error: 0.0596 - val_loss: 0.0335 - val_mse: 0.0048 - val_mae: 0.0335 - val_root_mean_squared_error: 0.0689
# Epoch 182/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0278 - mse: 0.0036 - mae: 0.0278 - root_mean_squared_error: 0.0596 - val_loss: 0.0334 - val_mse: 0.0048 - val_mae: 0.0334 - val_root_mean_squared_error: 0.0690
# Epoch 183/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0279 - mse: 0.0035 - mae: 0.0279 - root_mean_squared_error: 0.0596 - val_loss: 0.0334 - val_mse: 0.0047 - val_mae: 0.0334 - val_root_mean_squared_error: 0.0689
# Epoch 184/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0278 - mse: 0.0035 - mae: 0.0278 - root_mean_squared_error: 0.0596 - val_loss: 0.0334 - val_mse: 0.0047 - val_mae: 0.0334 - val_root_mean_squared_error: 0.0689
# Epoch 185/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0279 - mse: 0.0035 - mae: 0.0279 - root_mean_squared_error: 0.0596 - val_loss: 0.0334 - val_mse: 0.0047 - val_mae: 0.0334 - val_root_mean_squared_error: 0.0688
# Epoch 186/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0278 - mse: 0.0035 - mae: 0.0278 - root_mean_squared_error: 0.0596 - val_loss: 0.0334 - val_mse: 0.0047 - val_mae: 0.0334 - val_root_mean_squared_error: 0.0688
# Epoch 187/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0278 - mse: 0.0035 - mae: 0.0278 - root_mean_squared_error: 0.0596 - val_loss: 0.0334 - val_mse: 0.0047 - val_mae: 0.0334 - val_root_mean_squared_error: 0.0688
# Epoch 188/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0278 - mse: 0.0035 - mae: 0.0278 - root_mean_squared_error: 0.0596 - val_loss: 0.0333 - val_mse: 0.0047 - val_mae: 0.0333 - val_root_mean_squared_error: 0.0687
# Epoch 189/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0278 - mse: 0.0035 - mae: 0.0278 - root_mean_squared_error: 0.0595 - val_loss: 0.0333 - val_mse: 0.0047 - val_mae: 0.0333 - val_root_mean_squared_error: 0.0687
# Epoch 190/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0278 - mse: 0.0035 - mae: 0.0278 - root_mean_squared_error: 0.0595 - val_loss: 0.0333 - val_mse: 0.0047 - val_mae: 0.0333 - val_root_mean_squared_error: 0.0687
# Epoch 191/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0278 - mse: 0.0035 - mae: 0.0278 - root_mean_squared_error: 0.0595 - val_loss: 0.0333 - val_mse: 0.0047 - val_mae: 0.0333 - val_root_mean_squared_error: 0.0687
# Epoch 192/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0278 - mse: 0.0035 - mae: 0.0278 - root_mean_squared_error: 0.0595 - val_loss: 0.0333 - val_mse: 0.0047 - val_mae: 0.0333 - val_root_mean_squared_error: 0.0686
# Epoch 193/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0278 - mse: 0.0035 - mae: 0.0278 - root_mean_squared_error: 0.0595 - val_loss: 0.0333 - val_mse: 0.0047 - val_mae: 0.0333 - val_root_mean_squared_error: 0.0687
# Epoch 194/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0278 - mse: 0.0035 - mae: 0.0278 - root_mean_squared_error: 0.0595 - val_loss: 0.0333 - val_mse: 0.0047 - val_mae: 0.0333 - val_root_mean_squared_error: 0.0686
# Epoch 195/500
# ...
# Epoch 436/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0590 - val_loss: 0.0317 - val_mse: 0.0046 - val_mae: 0.0317 - val_root_mean_squared_error: 0.0678
# Epoch 437/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 438/500
# 3175/3175 [==============================] - 0s 22us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 439/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 440/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 441/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 442/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 443/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 444/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0590 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 445/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 446/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 447/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 448/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 449/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0678
# Epoch 450/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0590 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0678
# Epoch 451/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0589 - val_loss: 0.0317 - val_mse: 0.0046 - val_mae: 0.0317 - val_root_mean_squared_error: 0.0678
# Epoch 452/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0589 - val_loss: 0.0317 - val_mse: 0.0046 - val_mae: 0.0317 - val_root_mean_squared_error: 0.0678
# Epoch 453/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0590 - val_loss: 0.0317 - val_mse: 0.0046 - val_mae: 0.0317 - val_root_mean_squared_error: 0.0678
# Epoch 454/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0589 - val_loss: 0.0317 - val_mse: 0.0046 - val_mae: 0.0317 - val_root_mean_squared_error: 0.0678
# Epoch 455/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0678
# Epoch 456/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0590 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 457/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0590 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 458/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 459/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0315 - val_mse: 0.0046 - val_mae: 0.0315 - val_root_mean_squared_error: 0.0679
# Epoch 460/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0315 - val_mse: 0.0046 - val_mae: 0.0315 - val_root_mean_squared_error: 0.0680
# Epoch 461/500
# 3175/3175 [==============================] - 0s 19us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0315 - val_mse: 0.0046 - val_mae: 0.0315 - val_root_mean_squared_error: 0.0680
# Epoch 462/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0315 - val_mse: 0.0046 - val_mae: 0.0315 - val_root_mean_squared_error: 0.0679
# Epoch 463/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0315 - val_mse: 0.0046 - val_mae: 0.0315 - val_root_mean_squared_error: 0.0679
# Epoch 464/500
# 3175/3175 [==============================] - 0s 20us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0315 - val_mse: 0.0046 - val_mae: 0.0315 - val_root_mean_squared_error: 0.0679
# Epoch 465/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 466/500
# 3175/3175 [==============================] - 0s 21us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0315 - val_mse: 0.0046 - val_mae: 0.0315 - val_root_mean_squared_error: 0.0679
# Epoch 467/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 468/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 469/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0678
# Epoch 470/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0678
# Epoch 471/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0678
# Epoch 472/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0678
# Epoch 473/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 474/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0678
# Epoch 475/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0678
# Epoch 476/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 477/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 478/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 479/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 480/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 481/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0315 - val_mse: 0.0046 - val_mae: 0.0315 - val_root_mean_squared_error: 0.0679
# Epoch 482/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0315 - val_mse: 0.0046 - val_mae: 0.0315 - val_root_mean_squared_error: 0.0679
# Epoch 483/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0315 - val_mse: 0.0046 - val_mae: 0.0315 - val_root_mean_squared_error: 0.0679
# Epoch 484/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0315 - val_mse: 0.0046 - val_mae: 0.0315 - val_root_mean_squared_error: 0.0679
# Epoch 485/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0315 - val_mse: 0.0046 - val_mae: 0.0315 - val_root_mean_squared_error: 0.0680
# Epoch 486/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0315 - val_mse: 0.0046 - val_mae: 0.0315 - val_root_mean_squared_error: 0.0680
# Epoch 487/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0315 - val_mse: 0.0046 - val_mae: 0.0315 - val_root_mean_squared_error: 0.0680
# Epoch 488/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0315 - val_mse: 0.0046 - val_mae: 0.0315 - val_root_mean_squared_error: 0.0679
# Epoch 489/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0315 - val_mse: 0.0046 - val_mae: 0.0315 - val_root_mean_squared_error: 0.0679
# Epoch 490/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0315 - val_mse: 0.0046 - val_mae: 0.0315 - val_root_mean_squared_error: 0.0679
# Epoch 491/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0315 - val_mse: 0.0046 - val_mae: 0.0315 - val_root_mean_squared_error: 0.0679
# Epoch 492/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 493/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0678
# Epoch 494/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0678
# Epoch 495/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0590 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0678
# Epoch 496/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0678
# Epoch 497/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0679
# Epoch 498/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0268 - mse: 0.0035 - mae: 0.0268 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0678
# Epoch 499/500
# 3175/3175 [==============================] - 0s 23us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0589 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0678
# Epoch 500/500
# 3175/3175 [==============================] - 0s 24us/sample - loss: 0.0269 - mse: 0.0035 - mae: 0.0269 - root_mean_squared_error: 0.0590 - val_loss: 0.0316 - val_mse: 0.0046 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0678

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mae'],label='train mae')
pyplot.plot(history.history['val_mae'],label='val mae')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mse'],label='train mse')
pyplot.plot(history.history['val_mse'],label='val mse')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['root_mean_squared_error'],label='train rmse')
pyplot.plot(history.history['val_root_mean_squared_error'],label='val rmse')
pyplot.legend()
pyplot.show()
# Out:
# The testing MAE loss is: 0.029433062
# The testing MSE loss is: 0.0041199327
# The testing RMSE loss is: 0.0641867

# %%
pyplot.plot(test_y[:,1],color='red', label='True Values')
pyplot.plot(out[:,1],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()

# %%
dataset_test=pd.read_excel('F:\MS thesis data/Hopper Crossing.xlsx')
dataset_test=dataset_test.drop(['Date/Time','Flowd'],axis=1)
dataset_test.dropna(inplace=True)

# %%
shape=np.shape(dataset_test)
print(shape)
pyplot.plot(dataset_test)
# Out:
# (26285, 3)
# [<matplotlib.lines.Line2D at 0x22903aa2c08>,
#  <matplotlib.lines.Line2D at 0x22903aa2908>,
#  <matplotlib.lines.Line2D at 0x22903aa2788>]

# %%
dataset_test
# Out:
#        Cumulative rainfall   Flow  Level
# 0                      0.0  0.093    1.50
# 1                      0.0  0.093    1.50
# 2                      0.0  0.093    1.50
# 3                      0.0  0.093    1.50
# 4                      0.0  0.093    1.50
# ...                    ...    ...     ...
# 26280                  0.2  0.080    1.49
# 26281                  0.2  0.080    1.49
# 26282                  0.2  0.080    1.49
# 26283                  0.2  0.080    1.49
# 26284                  0.2  0.080    1.49
#
# [26285 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset_test)))
# Out:
# The std of original data is Cumulative rainfall    2.451640
# Flow                   0.520832
# Level                  0.083204
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset_test=dataset_test.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset_test.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset_test[:,0]== maxi[0])
    ind2=np.argwhere(dataset_test[:,1]== maxi[1])
    ind3=np.argwhere(dataset_test[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset_test.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset_test[:,0]== mini[0])
    ind2=np.argwhere(dataset_test[:,1]== mini[1])
    ind3=np.argwhere(dataset_test[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset_test)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset_test = min_max_scaler.fit_transform(dataset_test)
# Out:
# The std of cleaned data is 1.5154548293543502

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=2
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values

#one hour
#test_X, test_y = values[:, :-out_hour], values[:,-1]


test_X, test_y = values[:, :-out_hour], values[:, -out_hour: ]


test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6344, 24)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  var2(t-3)  var3(t-3)  \
# 6    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 7    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 8    0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
# 9    0.215385   0.524545   0.776699   0.123077   0.549980   0.791262
# 10   0.123077   0.549980   0.791262   0.092308   0.603309   0.820388
#
#     var1(t-2)  var2(t-2)  var3(t-2)  var1(t-1)  var2(t-1)  var3(t-1)  \
# 6    0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
# 7    0.215385   0.524545   0.776699   0.123077   0.549980   0.791262
# 8    0.123077   0.549980   0.791262   0.092308   0.603309   0.820388
# 9    0.092308   0.603309   0.820388   0.092308   0.650485   0.844660
# 10   0.092308   0.650485   0.844660   0.092308   0.709285   0.873786
#
#      var3(t)  var3(t+1)
# 6   0.791262   0.820388
# 7   0.820388   0.844660
# 8   0.844660   0.873786
# 9   0.873786   0.898058
# 10  0.898058   0.932039

# %%
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
# Out:
# The testing MAE loss is: 0.028673535
# The testing MSE loss is: 0.0038971636
# The testing RMSE loss is: 0.062427267

# %%
pyplot.plot(test_y[:,1],color='red', label='True Values')
pyplot.plot(out[:,1],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()
