# %%
import pandas as pd
from pandas import concat
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from sklearn import preprocessing
from tensorflow.keras import backend as K
#from sklearn.preprocessing import MinMaxScaler
#from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input, Dense, LSTM,GRU,SimpleRNN, Activation
from matplotlib import pyplot
#from sklearn.model_selection import train_test_split

# %%
"# convert series to supervised learning\n" 
#windowing of data
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1),
    for i in range(n_in, 0, -1): #startes from n_in and decreses to 0 by decreasing each time -1
     cols.append(df.shift(i))
     names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
     cols.append(df.shift(-i))
     if i == 0:
       names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
     else:
       names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together\n",
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values\n",
    if dropnan:
      agg.dropna(inplace=True)
    return agg

# %%
#def root_mean_squared_error(y_true, y_pred):
 #       return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
dataset1=pd.read_excel('F:\MS thesis data/Brooklyn.xlsx')
dataset1=dataset1.drop(['Date/Time','Flowd'],axis=1)
dataset1.dropna(inplace=True)

# %%
shape=np.shape(dataset1)
print(shape)
pyplot.plot(dataset1)
# Out:
# (26302, 3)
# [<matplotlib.lines.Line2D at 0x165d910be08>,
#  <matplotlib.lines.Line2D at 0x165d9114188>,
#  <matplotlib.lines.Line2D at 0x165d8d6de08>]

# %%
dataset1
# Out:
#        Cumulative rainfall    Flow  Level
# 0                       0.0  0.172   0.352
# 1                       0.0  0.180   0.356
# 2                       0.0  0.180   0.356
# 3                       0.0  0.189   0.360
# 4                       0.0  0.189   0.360
# ...                     ...    ...     ...
# 26297                   0.0  0.025   0.232
# 26298                   0.0  0.023   0.228
# 26299                   0.0  0.023   0.228
# 26300                   0.0  0.023   0.228
# 26301                   0.0  0.023   0.228
#
# [26302 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset1)))
# Out:
# The std of original data is Cumulative rainfall     2.872616
# Flow                    1.306642
# Level                   0.147238
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset=dataset1.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset[:,0]== maxi[0])
    ind2=np.argwhere(dataset[:,1]== maxi[1])
    ind3=np.argwhere(dataset[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset[:,0]== mini[0])
    ind2=np.argwhere(dataset[:,1]== mini[1])
    ind3=np.argwhere(dataset[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset = min_max_scaler.fit_transform(dataset)
# Out:
# The std of cleaned data is 1.626639593959813

# %%
pyplot.plot(dataset)
# Out:
# [<matplotlib.lines.Line2D at 0x165d8fe0388>,
#  <matplotlib.lines.Line2D at 0x165d8f65408>,
#  <matplotlib.lines.Line2D at 0x165d8f655c8>]

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=6
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values
train_size  = int(len(dataset) * 0.50)
val_size=int(len(dataset) * 0.75)
train_X, train_y = values[0:train_size, :-out_hour], values[0:train_size,-out_hour: ]
val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-out_hour: ]
test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-out_hour:]
#for last hour
#train_X, train_y = values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]  #for only last hour
#val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]
#test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-1]
print(train_X, train_y)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6340, 36)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var3(t-2)  var1(t-1)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.776699   0.215385
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.776699   0.123077
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.791262   0.092308
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.820388   0.092308
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.844660   0.092308
#
#     var2(t-1)  var3(t-1)   var3(t)  var3(t+1)  var3(t+2)  var3(t+3)  \
# 6    0.524545   0.776699  0.791262   0.820388   0.844660   0.873786
# 7    0.549980   0.791262  0.820388   0.844660   0.873786   0.898058
# 8    0.603309   0.820388  0.844660   0.873786   0.898058   0.932039
# 9    0.650485   0.844660  0.873786   0.898058   0.932039   0.966019
# 10   0.709285   0.873786  0.898058   0.932039   0.966019   1.000000
#
#     var3(t+4)  var3(t+5)
# 6    0.898058   0.932039
# 7    0.932039   0.966019
# 8    0.966019   1.000000
# 9    1.000000   0.941748
# 10   0.941748   0.912621
#
# [5 rows x 24 columns]
# [[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]
#  [0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]
#  [0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]
#  ...
#  [0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]
#  [0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]
#  [0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]] [[0.79126215 0.8203884  0.8446602  0.8737864  0.89805824 0.93203884]
#  [0.8203884  0.8446602  0.8737864  0.89805824 0.93203884 0.9660194 ]
#  [0.8446602  0.8737864  0.89805824 0.93203884 0.9660194  1.        ]
#  ...
#  [0.23786408 0.24271844 0.24757281 0.24757281 0.24757281 0.2184466 ]
#  [0.24271844 0.24757281 0.24757281 0.24757281 0.2184466  0.23300971]
#  [0.24757281 0.24757281 0.24757281 0.2184466  0.23300971 0.24271844]]

# %%
print(train_X, train_y)
# Out:
# [[[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]]
#
#  [[0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]]
#
#  [[0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]]
#
#  ...
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]]] [[0.79126215 0.8203884  0.8446602  0.8737864  0.89805824 0.93203884]
#  [0.8203884  0.8446602  0.8737864  0.89805824 0.93203884 0.9660194 ]
#  [0.8446602  0.8737864  0.89805824 0.93203884 0.9660194  1.        ]
#  ...
#  [0.23786408 0.24271844 0.24757281 0.24757281 0.24757281 0.2184466 ]
#  [0.24271844 0.24757281 0.24757281 0.24757281 0.2184466  0.23300971]
#  [0.24757281 0.24757281 0.24757281 0.2184466  0.23300971 0.24271844]]

# %%
print(train_X.shape, train_y.shape, val_X.shape, val_y.shape)
# Out:
# (3175, 1, 18) (3175, 6) (1588, 1, 18) (1588, 6)

# %%
randomState = 46
np.random.seed(randomState)
#tensorflow.random.set_random_seed(randomState)
tensorflow.random.set_seed(randomState)
model = Sequential()
model.add(GRU(15,input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dense(22))
#model.add(Activation('relu'))    
model.add(Dense(out_hour,activation = "sigmoid"))
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.001)
#    opt=tensorflow.keras.optimizers.Adam(learning_rate=0.00075)
model.compile(loss='mae', optimizer=opt,metrics=['mse','mae',tensorflow.keras.metrics.RootMeanSquaredError()])
history = model.fit(train_X, train_y,validation_data=(val_X, val_y), epochs=100, batch_size=100,verbose=1,shuffle=False)
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)
# Out:
# Train on 3175 samples, validate on 1588 samples
# Epoch 1/100
# 3175/3175 [==============================] - 3s 876us/sample - loss: 0.2547 - mse: 0.0776 - mae: 0.2547 - root_mean_squared_error: 0.2786 - val_loss: 0.2660 - val_mse: 0.0873 - val_mae: 0.2660 - val_root_mean_squared_error: 0.2955
# Epoch 2/100
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.2336 - mse: 0.0667 - mae: 0.2336 - root_mean_squared_error: 0.2582 - val_loss: 0.2437 - val_mse: 0.0743 - val_mae: 0.2437 - val_root_mean_squared_error: 0.2725
# Epoch 3/100
# 3175/3175 [==============================] - 0s 57us/sample - loss: 0.2097 - mse: 0.0558 - mae: 0.2097 - root_mean_squared_error: 0.2363 - val_loss: 0.2184 - val_mse: 0.0614 - val_mae: 0.2184 - val_root_mean_squared_error: 0.2477
# Epoch 4/100
# 3175/3175 [==============================] - 0s 56us/sample - loss: 0.1863 - mse: 0.0473 - mae: 0.1863 - root_mean_squared_error: 0.2176 - val_loss: 0.1956 - val_mse: 0.0516 - val_mae: 0.1956 - val_root_mean_squared_error: 0.2271
# Epoch 5/100
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.1684 - mse: 0.0423 - mae: 0.1684 - root_mean_squared_error: 0.2057 - val_loss: 0.1788 - val_mse: 0.0452 - val_mae: 0.1788 - val_root_mean_squared_error: 0.2125
# Epoch 6/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.1560 - mse: 0.0392 - mae: 0.1560 - root_mean_squared_error: 0.1980 - val_loss: 0.1664 - val_mse: 0.0406 - val_mae: 0.1664 - val_root_mean_squared_error: 0.2015
# Epoch 7/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.1462 - mse: 0.0363 - mae: 0.1462 - root_mean_squared_error: 0.1906 - val_loss: 0.1559 - val_mse: 0.0367 - val_mae: 0.1559 - val_root_mean_squared_error: 0.1916
# Epoch 8/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1373 - mse: 0.0333 - mae: 0.1373 - root_mean_squared_error: 0.1824 - val_loss: 0.1464 - val_mse: 0.0330 - val_mae: 0.1464 - val_root_mean_squared_error: 0.1817
# Epoch 9/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1289 - mse: 0.0300 - mae: 0.1289 - root_mean_squared_error: 0.1733 - val_loss: 0.1376 - val_mse: 0.0296 - val_mae: 0.1376 - val_root_mean_squared_error: 0.1719
# Epoch 10/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1210 - mse: 0.0268 - mae: 0.1210 - root_mean_squared_error: 0.1636 - val_loss: 0.1292 - val_mse: 0.0263 - val_mae: 0.1292 - val_root_mean_squared_error: 0.1622
# Epoch 11/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1134 - mse: 0.0236 - mae: 0.1134 - root_mean_squared_error: 0.1537 - val_loss: 0.1211 - val_mse: 0.0234 - val_mae: 0.1211 - val_root_mean_squared_error: 0.1530
# Epoch 12/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.1063 - mse: 0.0208 - mae: 0.1063 - root_mean_squared_error: 0.1441 - val_loss: 0.1135 - val_mse: 0.0209 - val_mae: 0.1135 - val_root_mean_squared_error: 0.1445
# Epoch 13/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0998 - mse: 0.0184 - mae: 0.0998 - root_mean_squared_error: 0.1356 - val_loss: 0.1065 - val_mse: 0.0188 - val_mae: 0.1065 - val_root_mean_squared_error: 0.1372
# Epoch 14/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0939 - mse: 0.0165 - mae: 0.0939 - root_mean_squared_error: 0.1285 - val_loss: 0.1003 - val_mse: 0.0172 - val_mae: 0.1003 - val_root_mean_squared_error: 0.1311
# Epoch 15/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0888 - mse: 0.0151 - mae: 0.0888 - root_mean_squared_error: 0.1229 - val_loss: 0.0951 - val_mse: 0.0159 - val_mae: 0.0951 - val_root_mean_squared_error: 0.1262
# Epoch 16/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0843 - mse: 0.0140 - mae: 0.0843 - root_mean_squared_error: 0.1185 - val_loss: 0.0906 - val_mse: 0.0150 - val_mae: 0.0906 - val_root_mean_squared_error: 0.1224
# Epoch 17/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0805 - mse: 0.0133 - mae: 0.0805 - root_mean_squared_error: 0.1151 - val_loss: 0.0866 - val_mse: 0.0143 - val_mae: 0.0866 - val_root_mean_squared_error: 0.1194
# Epoch 18/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0772 - mse: 0.0127 - mae: 0.0772 - root_mean_squared_error: 0.1126 - val_loss: 0.0832 - val_mse: 0.0137 - val_mae: 0.0832 - val_root_mean_squared_error: 0.1172
# Epoch 19/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0744 - mse: 0.0123 - mae: 0.0744 - root_mean_squared_error: 0.1107 - val_loss: 0.0802 - val_mse: 0.0133 - val_mae: 0.0802 - val_root_mean_squared_error: 0.1154
# Epoch 20/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0719 - mse: 0.0119 - mae: 0.0719 - root_mean_squared_error: 0.1093 - val_loss: 0.0776 - val_mse: 0.0130 - val_mae: 0.0776 - val_root_mean_squared_error: 0.1139
# Epoch 21/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0698 - mse: 0.0117 - mae: 0.0698 - root_mean_squared_error: 0.1081 - val_loss: 0.0755 - val_mse: 0.0127 - val_mae: 0.0755 - val_root_mean_squared_error: 0.1128
# Epoch 22/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0681 - mse: 0.0115 - mae: 0.0681 - root_mean_squared_error: 0.1071 - val_loss: 0.0738 - val_mse: 0.0125 - val_mae: 0.0738 - val_root_mean_squared_error: 0.1118
# Epoch 23/100
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0666 - mse: 0.0113 - mae: 0.0666 - root_mean_squared_error: 0.1062 - val_loss: 0.0722 - val_mse: 0.0123 - val_mae: 0.0722 - val_root_mean_squared_error: 0.1109
# Epoch 24/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0653 - mse: 0.0111 - mae: 0.0653 - root_mean_squared_error: 0.1053 - val_loss: 0.0709 - val_mse: 0.0121 - val_mae: 0.0709 - val_root_mean_squared_error: 0.1100
# Epoch 25/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0642 - mse: 0.0109 - mae: 0.0642 - root_mean_squared_error: 0.1044 - val_loss: 0.0697 - val_mse: 0.0119 - val_mae: 0.0697 - val_root_mean_squared_error: 0.1092
# Epoch 26/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0633 - mse: 0.0107 - mae: 0.0633 - root_mean_squared_error: 0.1036 - val_loss: 0.0687 - val_mse: 0.0118 - val_mae: 0.0687 - val_root_mean_squared_error: 0.1085
# Epoch 27/100
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0643 - mse: 0.0112 - mae: 0.0643 - root_mean_squared_error: 0.105 - 0s 26us/sample - loss: 0.0624 - mse: 0.0106 - mae: 0.0624 - root_mean_squared_error: 0.1028 - val_loss: 0.0678 - val_mse: 0.0116 - val_mae: 0.0678 - val_root_mean_squared_error: 0.1077
# Epoch 28/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0617 - mse: 0.0104 - mae: 0.0617 - root_mean_squared_error: 0.1020 - val_loss: 0.0670 - val_mse: 0.0114 - val_mae: 0.0670 - val_root_mean_squared_error: 0.1069
# Epoch 29/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0610 - mse: 0.0102 - mae: 0.0610 - root_mean_squared_error: 0.1012 - val_loss: 0.0663 - val_mse: 0.0113 - val_mae: 0.0663 - val_root_mean_squared_error: 0.1063
# Epoch 30/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0604 - mse: 0.0101 - mae: 0.0604 - root_mean_squared_error: 0.1005 - val_loss: 0.0657 - val_mse: 0.0112 - val_mae: 0.0657 - val_root_mean_squared_error: 0.1056
# Epoch 31/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0599 - mse: 0.0100 - mae: 0.0599 - root_mean_squared_error: 0.0998 - val_loss: 0.0651 - val_mse: 0.0110 - val_mae: 0.0651 - val_root_mean_squared_error: 0.1051
# Epoch 32/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0594 - mse: 0.0098 - mae: 0.0594 - root_mean_squared_error: 0.0992 - val_loss: 0.0646 - val_mse: 0.0109 - val_mae: 0.0646 - val_root_mean_squared_error: 0.1046
# Epoch 33/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0590 - mse: 0.0097 - mae: 0.0590 - root_mean_squared_error: 0.0987 - val_loss: 0.0642 - val_mse: 0.0108 - val_mae: 0.0642 - val_root_mean_squared_error: 0.1041
# Epoch 34/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0586 - mse: 0.0096 - mae: 0.0586 - root_mean_squared_error: 0.0982 - val_loss: 0.0638 - val_mse: 0.0107 - val_mae: 0.0638 - val_root_mean_squared_error: 0.1037
# Epoch 35/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0583 - mse: 0.0095 - mae: 0.0583 - root_mean_squared_error: 0.0977 - val_loss: 0.0634 - val_mse: 0.0107 - val_mae: 0.0634 - val_root_mean_squared_error: 0.1032
# Epoch 36/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0579 - mse: 0.0094 - mae: 0.0579 - root_mean_squared_error: 0.0972 - val_loss: 0.0631 - val_mse: 0.0106 - val_mae: 0.0631 - val_root_mean_squared_error: 0.1028
# Epoch 37/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0576 - mse: 0.0094 - mae: 0.0576 - root_mean_squared_error: 0.0968 - val_loss: 0.0628 - val_mse: 0.0105 - val_mae: 0.0628 - val_root_mean_squared_error: 0.1025
# Epoch 38/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0573 - mse: 0.0093 - mae: 0.0573 - root_mean_squared_error: 0.0964 - val_loss: 0.0625 - val_mse: 0.0104 - val_mae: 0.0625 - val_root_mean_squared_error: 0.1021
# Epoch 39/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0571 - mse: 0.0092 - mae: 0.0571 - root_mean_squared_error: 0.0960 - val_loss: 0.0622 - val_mse: 0.0104 - val_mae: 0.0622 - val_root_mean_squared_error: 0.1018
# Epoch 40/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0568 - mse: 0.0092 - mae: 0.0568 - root_mean_squared_error: 0.0957 - val_loss: 0.0620 - val_mse: 0.0103 - val_mae: 0.0620 - val_root_mean_squared_error: 0.1015
# Epoch 41/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0566 - mse: 0.0091 - mae: 0.0566 - root_mean_squared_error: 0.0954 - val_loss: 0.0617 - val_mse: 0.0102 - val_mae: 0.0617 - val_root_mean_squared_error: 0.1012
# Epoch 42/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0563 - mse: 0.0090 - mae: 0.0563 - root_mean_squared_error: 0.0951 - val_loss: 0.0615 - val_mse: 0.0102 - val_mae: 0.0615 - val_root_mean_squared_error: 0.1010
# Epoch 43/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0561 - mse: 0.0090 - mae: 0.0561 - root_mean_squared_error: 0.0949 - val_loss: 0.0613 - val_mse: 0.0102 - val_mae: 0.0613 - val_root_mean_squared_error: 0.1008
# Epoch 44/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0559 - mse: 0.0090 - mae: 0.0559 - root_mean_squared_error: 0.0946 - val_loss: 0.0611 - val_mse: 0.0101 - val_mae: 0.0611 - val_root_mean_squared_error: 0.1006
# Epoch 45/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0557 - mse: 0.0089 - mae: 0.0557 - root_mean_squared_error: 0.0944 - val_loss: 0.0609 - val_mse: 0.0101 - val_mae: 0.0609 - val_root_mean_squared_error: 0.1004
# Epoch 46/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0555 - mse: 0.0089 - mae: 0.0555 - root_mean_squared_error: 0.0942 - val_loss: 0.0607 - val_mse: 0.0100 - val_mae: 0.0607 - val_root_mean_squared_error: 0.1002
# Epoch 47/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0553 - mse: 0.0088 - mae: 0.0553 - root_mean_squared_error: 0.0940 - val_loss: 0.0606 - val_mse: 0.0100 - val_mae: 0.0606 - val_root_mean_squared_error: 0.1000
# Epoch 48/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0551 - mse: 0.0088 - mae: 0.0551 - root_mean_squared_error: 0.0938 - val_loss: 0.0604 - val_mse: 0.0100 - val_mae: 0.0604 - val_root_mean_squared_error: 0.0998
# Epoch 49/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0550 - mse: 0.0088 - mae: 0.0550 - root_mean_squared_error: 0.0936 - val_loss: 0.0602 - val_mse: 0.0099 - val_mae: 0.0602 - val_root_mean_squared_error: 0.0997
# Epoch 50/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0548 - mse: 0.0087 - mae: 0.0548 - root_mean_squared_error: 0.0934 - val_loss: 0.0601 - val_mse: 0.0099 - val_mae: 0.0601 - val_root_mean_squared_error: 0.0996
# Epoch 51/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0546 - mse: 0.0087 - mae: 0.0546 - root_mean_squared_error: 0.0933 - val_loss: 0.0599 - val_mse: 0.0099 - val_mae: 0.0599 - val_root_mean_squared_error: 0.0995
# Epoch 52/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0545 - mse: 0.0087 - mae: 0.0545 - root_mean_squared_error: 0.0931 - val_loss: 0.0598 - val_mse: 0.0099 - val_mae: 0.0598 - val_root_mean_squared_error: 0.0993
# Epoch 53/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0543 - mse: 0.0086 - mae: 0.0543 - root_mean_squared_error: 0.0930 - val_loss: 0.0597 - val_mse: 0.0098 - val_mae: 0.0597 - val_root_mean_squared_error: 0.0992
# Epoch 54/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0542 - mse: 0.0086 - mae: 0.0542 - root_mean_squared_error: 0.0929 - val_loss: 0.0596 - val_mse: 0.0098 - val_mae: 0.0596 - val_root_mean_squared_error: 0.0991
# Epoch 55/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0541 - mse: 0.0086 - mae: 0.0541 - root_mean_squared_error: 0.0928 - val_loss: 0.0594 - val_mse: 0.0098 - val_mae: 0.0594 - val_root_mean_squared_error: 0.0990
# Epoch 56/100
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0557 - mse: 0.0092 - mae: 0.0557 - root_mean_squared_error: 0.096 - 0s 26us/sample - loss: 0.0539 - mse: 0.0086 - mae: 0.0539 - root_mean_squared_error: 0.0926 - val_loss: 0.0593 - val_mse: 0.0098 - val_mae: 0.0593 - val_root_mean_squared_error: 0.0989
# Epoch 57/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0538 - mse: 0.0086 - mae: 0.0538 - root_mean_squared_error: 0.0925 - val_loss: 0.0592 - val_mse: 0.0098 - val_mae: 0.0592 - val_root_mean_squared_error: 0.0988
# Epoch 58/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0537 - mse: 0.0085 - mae: 0.0537 - root_mean_squared_error: 0.0924 - val_loss: 0.0591 - val_mse: 0.0097 - val_mae: 0.0591 - val_root_mean_squared_error: 0.0987
# Epoch 59/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0536 - mse: 0.0085 - mae: 0.0536 - root_mean_squared_error: 0.0923 - val_loss: 0.0590 - val_mse: 0.0097 - val_mae: 0.0590 - val_root_mean_squared_error: 0.0987
# Epoch 60/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0535 - mse: 0.0085 - mae: 0.0535 - root_mean_squared_error: 0.0922 - val_loss: 0.0589 - val_mse: 0.0097 - val_mae: 0.0589 - val_root_mean_squared_error: 0.0986
# Epoch 61/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0533 - mse: 0.0085 - mae: 0.0533 - root_mean_squared_error: 0.0921 - val_loss: 0.0588 - val_mse: 0.0097 - val_mae: 0.0588 - val_root_mean_squared_error: 0.0985
# Epoch 62/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0532 - mse: 0.0085 - mae: 0.0532 - root_mean_squared_error: 0.0920 - val_loss: 0.0587 - val_mse: 0.0097 - val_mae: 0.0587 - val_root_mean_squared_error: 0.0984
# Epoch 63/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0531 - mse: 0.0085 - mae: 0.0531 - root_mean_squared_error: 0.0920 - val_loss: 0.0586 - val_mse: 0.0097 - val_mae: 0.0586 - val_root_mean_squared_error: 0.0983
# Epoch 64/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0530 - mse: 0.0084 - mae: 0.0530 - root_mean_squared_error: 0.0919 - val_loss: 0.0585 - val_mse: 0.0097 - val_mae: 0.0585 - val_root_mean_squared_error: 0.0983
# Epoch 65/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0529 - mse: 0.0084 - mae: 0.0529 - root_mean_squared_error: 0.0918 - val_loss: 0.0584 - val_mse: 0.0096 - val_mae: 0.0584 - val_root_mean_squared_error: 0.0982
# Epoch 66/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0529 - mse: 0.0084 - mae: 0.0529 - root_mean_squared_error: 0.0917 - val_loss: 0.0584 - val_mse: 0.0096 - val_mae: 0.0584 - val_root_mean_squared_error: 0.0982
# Epoch 67/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0528 - mse: 0.0084 - mae: 0.0528 - root_mean_squared_error: 0.0917 - val_loss: 0.0583 - val_mse: 0.0096 - val_mae: 0.0583 - val_root_mean_squared_error: 0.0981
# Epoch 68/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0527 - mse: 0.0084 - mae: 0.0527 - root_mean_squared_error: 0.0916 - val_loss: 0.0582 - val_mse: 0.0096 - val_mae: 0.0582 - val_root_mean_squared_error: 0.0980
# Epoch 69/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0526 - mse: 0.0084 - mae: 0.0526 - root_mean_squared_error: 0.0915 - val_loss: 0.0581 - val_mse: 0.0096 - val_mae: 0.0581 - val_root_mean_squared_error: 0.0979
# Epoch 70/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0525 - mse: 0.0084 - mae: 0.0525 - root_mean_squared_error: 0.0915 - val_loss: 0.0580 - val_mse: 0.0096 - val_mae: 0.0580 - val_root_mean_squared_error: 0.0979
# Epoch 71/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0525 - mse: 0.0084 - mae: 0.0525 - root_mean_squared_error: 0.0914 - val_loss: 0.0579 - val_mse: 0.0096 - val_mae: 0.0579 - val_root_mean_squared_error: 0.0978
# Epoch 72/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0524 - mse: 0.0083 - mae: 0.0524 - root_mean_squared_error: 0.0913 - val_loss: 0.0578 - val_mse: 0.0096 - val_mae: 0.0578 - val_root_mean_squared_error: 0.0978
# Epoch 73/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0523 - mse: 0.0083 - mae: 0.0523 - root_mean_squared_error: 0.0913 - val_loss: 0.0578 - val_mse: 0.0095 - val_mae: 0.0578 - val_root_mean_squared_error: 0.0977
# Epoch 74/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0522 - mse: 0.0083 - mae: 0.0522 - root_mean_squared_error: 0.0912 - val_loss: 0.0577 - val_mse: 0.0095 - val_mae: 0.0577 - val_root_mean_squared_error: 0.0976
# Epoch 75/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0521 - mse: 0.0083 - mae: 0.0521 - root_mean_squared_error: 0.0912 - val_loss: 0.0576 - val_mse: 0.0095 - val_mae: 0.0576 - val_root_mean_squared_error: 0.0976
# Epoch 76/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0521 - mse: 0.0083 - mae: 0.0521 - root_mean_squared_error: 0.0911 - val_loss: 0.0575 - val_mse: 0.0095 - val_mae: 0.0575 - val_root_mean_squared_error: 0.0975
# Epoch 77/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0520 - mse: 0.0083 - mae: 0.0520 - root_mean_squared_error: 0.0911 - val_loss: 0.0574 - val_mse: 0.0095 - val_mae: 0.0574 - val_root_mean_squared_error: 0.0975
# Epoch 78/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0519 - mse: 0.0083 - mae: 0.0519 - root_mean_squared_error: 0.0910 - val_loss: 0.0574 - val_mse: 0.0095 - val_mae: 0.0574 - val_root_mean_squared_error: 0.0974
# Epoch 79/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0519 - mse: 0.0083 - mae: 0.0519 - root_mean_squared_error: 0.0910 - val_loss: 0.0573 - val_mse: 0.0095 - val_mae: 0.0573 - val_root_mean_squared_error: 0.0974
# Epoch 80/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0518 - mse: 0.0083 - mae: 0.0518 - root_mean_squared_error: 0.0909 - val_loss: 0.0572 - val_mse: 0.0095 - val_mae: 0.0572 - val_root_mean_squared_error: 0.0974
# Epoch 81/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0517 - mse: 0.0083 - mae: 0.0517 - root_mean_squared_error: 0.0909 - val_loss: 0.0572 - val_mse: 0.0095 - val_mae: 0.0572 - val_root_mean_squared_error: 0.0973
# Epoch 82/100
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0516 - mse: 0.0083 - mae: 0.0516 - root_mean_squared_error: 0.0909 - val_loss: 0.0571 - val_mse: 0.0095 - val_mae: 0.0571 - val_root_mean_squared_error: 0.0973
# Epoch 83/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0516 - mse: 0.0082 - mae: 0.0516 - root_mean_squared_error: 0.0908 - val_loss: 0.0570 - val_mse: 0.0095 - val_mae: 0.0570 - val_root_mean_squared_error: 0.0972
# Epoch 84/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0515 - mse: 0.0082 - mae: 0.0515 - root_mean_squared_error: 0.0908 - val_loss: 0.0569 - val_mse: 0.0094 - val_mae: 0.0569 - val_root_mean_squared_error: 0.0972
# Epoch 85/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0515 - mse: 0.0082 - mae: 0.0515 - root_mean_squared_error: 0.0907 - val_loss: 0.0569 - val_mse: 0.0094 - val_mae: 0.0569 - val_root_mean_squared_error: 0.0971
# Epoch 86/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0514 - mse: 0.0082 - mae: 0.0514 - root_mean_squared_error: 0.0907 - val_loss: 0.0568 - val_mse: 0.0094 - val_mae: 0.0568 - val_root_mean_squared_error: 0.0971
# Epoch 87/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0513 - mse: 0.0082 - mae: 0.0513 - root_mean_squared_error: 0.0906 - val_loss: 0.0567 - val_mse: 0.0094 - val_mae: 0.0567 - val_root_mean_squared_error: 0.0970
# Epoch 88/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0513 - mse: 0.0082 - mae: 0.0513 - root_mean_squared_error: 0.0906 - val_loss: 0.0566 - val_mse: 0.0094 - val_mae: 0.0566 - val_root_mean_squared_error: 0.0970
# Epoch 89/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0512 - mse: 0.0082 - mae: 0.0512 - root_mean_squared_error: 0.0905 - val_loss: 0.0566 - val_mse: 0.0094 - val_mae: 0.0566 - val_root_mean_squared_error: 0.0969
# Epoch 90/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0511 - mse: 0.0082 - mae: 0.0511 - root_mean_squared_error: 0.0905 - val_loss: 0.0565 - val_mse: 0.0094 - val_mae: 0.0565 - val_root_mean_squared_error: 0.0969
# Epoch 91/100
# 3175/3175 [==============================] - ETA: 0s - loss: 0.0522 - mse: 0.0086 - mae: 0.0522 - root_mean_squared_error: 0.092 - 0s 27us/sample - loss: 0.0511 - mse: 0.0082 - mae: 0.0511 - root_mean_squared_error: 0.0904 - val_loss: 0.0564 - val_mse: 0.0094 - val_mae: 0.0564 - val_root_mean_squared_error: 0.0968
# Epoch 92/100
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0510 - mse: 0.0082 - mae: 0.0510 - root_mean_squared_error: 0.0904 - val_loss: 0.0564 - val_mse: 0.0094 - val_mae: 0.0564 - val_root_mean_squared_error: 0.0968
# Epoch 93/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0510 - mse: 0.0082 - mae: 0.0510 - root_mean_squared_error: 0.0904 - val_loss: 0.0563 - val_mse: 0.0094 - val_mae: 0.0563 - val_root_mean_squared_error: 0.0967
# Epoch 94/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0509 - mse: 0.0082 - mae: 0.0509 - root_mean_squared_error: 0.0903 - val_loss: 0.0562 - val_mse: 0.0093 - val_mae: 0.0562 - val_root_mean_squared_error: 0.0967
# Epoch 95/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0508 - mse: 0.0081 - mae: 0.0508 - root_mean_squared_error: 0.0903 - val_loss: 0.0561 - val_mse: 0.0093 - val_mae: 0.0561 - val_root_mean_squared_error: 0.0966
# Epoch 96/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0508 - mse: 0.0081 - mae: 0.0508 - root_mean_squared_error: 0.0902 - val_loss: 0.0560 - val_mse: 0.0093 - val_mae: 0.0560 - val_root_mean_squared_error: 0.0966
# Epoch 97/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0507 - mse: 0.0081 - mae: 0.0507 - root_mean_squared_error: 0.0902 - val_loss: 0.0560 - val_mse: 0.0093 - val_mae: 0.0560 - val_root_mean_squared_error: 0.0965
# Epoch 98/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0507 - mse: 0.0081 - mae: 0.0507 - root_mean_squared_error: 0.0901 - val_loss: 0.0559 - val_mse: 0.0093 - val_mae: 0.0559 - val_root_mean_squared_error: 0.0965
# Epoch 99/100
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0506 - mse: 0.0081 - mae: 0.0506 - root_mean_squared_error: 0.0901 - val_loss: 0.0558 - val_mse: 0.0093 - val_mae: 0.0558 - val_root_mean_squared_error: 0.0964
# Epoch 100/100
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0505 - mse: 0.0081 - mae: 0.0505 - root_mean_squared_error: 0.0900 - val_loss: 0.0558 - val_mse: 0.0093 - val_mae: 0.0558 - val_root_mean_squared_error: 0.0964

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mae'],label='train mae')
pyplot.plot(history.history['val_mae'],label='val mae')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mse'],label='train mse')
pyplot.plot(history.history['val_mse'],label='val mse')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['root_mean_squared_error'],label='train rmse')
pyplot.plot(history.history['val_root_mean_squared_error'],label='val rmse')
pyplot.legend()
pyplot.show()
# Out:
# The testing MAE loss is: 0.054505672
# The testing MSE loss is: 0.008568082
# The testing RMSE loss is: 0.09256393

# %%
pyplot.plot(test_y[:,5],color='red', label='True Values')
pyplot.plot(out[:,5],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()

# %%
dataset_test=pd.read_excel('F:\MS thesis data/Hopper Crossing.xlsx')
dataset_test=dataset_test.drop(['Date/Time','Flowd'],axis=1)
dataset_test.dropna(inplace=True)

# %%
shape=np.shape(dataset_test)
print(shape)
pyplot.plot(dataset_test)
# Out:
# (26285, 3)
# [<matplotlib.lines.Line2D at 0x165e0a8be88>,
#  <matplotlib.lines.Line2D at 0x165e0a91448>,
#  <matplotlib.lines.Line2D at 0x165e0a91488>]

# %%
dataset_test
# Out:
#        Cumulative rainfall   Flow  Level
# 0                      0.0  0.093    1.50
# 1                      0.0  0.093    1.50
# 2                      0.0  0.093    1.50
# 3                      0.0  0.093    1.50
# 4                      0.0  0.093    1.50
# ...                    ...    ...     ...
# 26280                  0.2  0.080    1.49
# 26281                  0.2  0.080    1.49
# 26282                  0.2  0.080    1.49
# 26283                  0.2  0.080    1.49
# 26284                  0.2  0.080    1.49
#
# [26285 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset_test)))
# Out:
# The std of original data is Cumulative rainfall    2.451640
# Flow                   0.520832
# Level                  0.083204
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset_test=dataset_test.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset_test.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset_test[:,0]== maxi[0])
    ind2=np.argwhere(dataset_test[:,1]== maxi[1])
    ind3=np.argwhere(dataset_test[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset_test.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset_test[:,0]== mini[0])
    ind2=np.argwhere(dataset_test[:,1]== mini[1])
    ind3=np.argwhere(dataset_test[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset_test)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset_test = min_max_scaler.fit_transform(dataset_test)
# Out:
# The std of cleaned data is 1.5154548293543502

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=6
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values

#one hour
#test_X, test_y = values[:, :-out_hour], values[:,-1]


test_X, test_y = values[:, :-out_hour], values[:, -out_hour: ]


test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6340, 36)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var3(t-2)  var1(t-1)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.776699   0.215385
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.776699   0.123077
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.791262   0.092308
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.820388   0.092308
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.844660   0.092308
#
#     var2(t-1)  var3(t-1)   var3(t)  var3(t+1)  var3(t+2)  var3(t+3)  \
# 6    0.524545   0.776699  0.791262   0.820388   0.844660   0.873786
# 7    0.549980   0.791262  0.820388   0.844660   0.873786   0.898058
# 8    0.603309   0.820388  0.844660   0.873786   0.898058   0.932039
# 9    0.650485   0.844660  0.873786   0.898058   0.932039   0.966019
# 10   0.709285   0.873786  0.898058   0.932039   0.966019   1.000000
#
#     var3(t+4)  var3(t+5)
# 6    0.898058   0.932039
# 7    0.932039   0.966019
# 8    0.966019   1.000000
# 9    1.000000   0.941748
# 10   0.941748   0.912621
#
# [5 rows x 24 columns]

# %%
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
# Out:
# The testing MAE loss is: 0.052846458
# The testing MSE loss is: 0.008517256
# The testing RMSE loss is: 0.09228898

# %%
pyplot.plot(test_y[:,5],color='red', label='True Values')
pyplot.plot(out[:,5],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()
