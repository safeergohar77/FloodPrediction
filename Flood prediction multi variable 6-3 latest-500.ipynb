# %%
import pandas as pd
from pandas import concat
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from sklearn import preprocessing
from tensorflow.keras import backend as K
#from sklearn.preprocessing import MinMaxScaler
#from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input, Dense, LSTM,GRU,SimpleRNN, Activation
from matplotlib import pyplot
#from sklearn.model_selection import train_test_split

# %%
"# convert series to supervised learning\n" 
#windowing of data
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1),
    for i in range(n_in, 0, -1): #startes from n_in and decreses to 0 by decreasing each time -1
     cols.append(df.shift(i))
     names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
     cols.append(df.shift(-i))
     if i == 0:
       names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
     else:
       names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together\n",
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values\n",
    if dropnan:
      agg.dropna(inplace=True)
    return agg

# %%
#def root_mean_squared_error(y_true, y_pred):
 #       return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
dataset1=pd.read_excel('F:\MS thesis data/Brooklyn.xlsx')
dataset1=dataset1.drop(['Date/Time','Flowd'],axis=1)
dataset1.dropna(inplace=True)

# %%
shape=np.shape(dataset1)
print(shape)
pyplot.plot(dataset1)
# Out:
# (26302, 3)
# [<matplotlib.lines.Line2D at 0x29e69bc5d48>,
#  <matplotlib.lines.Line2D at 0x29e69bc3788>,
#  <matplotlib.lines.Line2D at 0x29e69bb41c8>]

# %%
dataset1
# Out:
#        Cumulative rainfall    Flow  Level
# 0                       0.0  0.172   0.352
# 1                       0.0  0.180   0.356
# 2                       0.0  0.180   0.356
# 3                       0.0  0.189   0.360
# 4                       0.0  0.189   0.360
# ...                     ...    ...     ...
# 26297                   0.0  0.025   0.232
# 26298                   0.0  0.023   0.228
# 26299                   0.0  0.023   0.228
# 26300                   0.0  0.023   0.228
# 26301                   0.0  0.023   0.228
#
# [26302 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset1)))
# Out:
# The std of original data is Cumulative rainfall     2.872616
# Flow                    1.306642
# Level                   0.147238
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset=dataset1.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset[:,0]== maxi[0])
    ind2=np.argwhere(dataset[:,1]== maxi[1])
    ind3=np.argwhere(dataset[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset[:,0]== mini[0])
    ind2=np.argwhere(dataset[:,1]== mini[1])
    ind3=np.argwhere(dataset[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset=np.delete(dataset,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset = min_max_scaler.fit_transform(dataset)
# Out:
# The std of cleaned data is 1.626639593959813

# %%
pyplot.plot(dataset)
# Out:
# [<matplotlib.lines.Line2D at 0x29e69431448>,
#  <matplotlib.lines.Line2D at 0x29e691c32c8>,
#  <matplotlib.lines.Line2D at 0x29e691c3488>]

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=3
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values
train_size  = int(len(dataset) * 0.50)
val_size=int(len(dataset) * 0.75)
train_X, train_y = values[0:train_size, :-out_hour], values[0:train_size,-out_hour: ]
val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-out_hour: ]
test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-out_hour:]
#for last hour
#train_X, train_y = values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]  #for only last hour
#val_X, val_y=values[train_size:val_size, :-out_hour], values[train_size:val_size,-1 ]
#test_X, test_y = values[val_size:, :-out_hour], values[val_size:,-1]
print(train_X, train_y)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6343, 27)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var3(t-3)  var1(t-2)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.762136   0.230769
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.776699   0.215385
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.776699   0.123077
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.791262   0.092308
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.820388   0.092308
#
#     var2(t-2)  var3(t-2)  var1(t-1)  var2(t-1)  var3(t-1)   var3(t)  \
# 6    0.524545   0.776699   0.215385   0.524545   0.776699  0.791262
# 7    0.524545   0.776699   0.123077   0.549980   0.791262  0.820388
# 8    0.549980   0.791262   0.092308   0.603309   0.820388  0.844660
# 9    0.603309   0.820388   0.092308   0.650485   0.844660  0.873786
# 10   0.650485   0.844660   0.092308   0.709285   0.873786  0.898058
#
#     var3(t+1)  var3(t+2)
# 6    0.820388   0.844660
# 7    0.844660   0.873786
# 8    0.873786   0.898058
# 9    0.898058   0.932039
# 10   0.932039   0.966019
#
# [5 rows x 21 columns]
# [[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]
#  [0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]
#  [0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]
#  ...
#  [0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]
#  [0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]
#  [0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]] [[0.79126215 0.8203884  0.8446602 ]
#  [0.8203884  0.8446602  0.8737864 ]
#  [0.8446602  0.8737864  0.89805824]
#  ...
#  [0.23786408 0.24271844 0.24757281]
#  [0.24271844 0.24757281 0.24757281]
#  [0.24757281 0.24757281 0.24757281]]

# %%
print(train_X, train_y)
# Out:
# [[[0.23076923 0.40188706 0.69902915 ... 0.21538462 0.5245453  0.776699  ]]
#
#  [[0.23076923 0.43826064 0.723301   ... 0.12307692 0.5499795  0.79126215]]
#
#  [[0.23076923 0.47627512 0.74757284 ... 0.09230769 0.60330915 0.8203884 ]]
#
#  ...
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04321072 0.23300971]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04498838 0.23786408]]
#
#  [[0.         0.04321072 0.23300971 ... 0.         0.04662929 0.24271844]]] [[0.79126215 0.8203884  0.8446602 ]
#  [0.8203884  0.8446602  0.8737864 ]
#  [0.8446602  0.8737864  0.89805824]
#  ...
#  [0.23786408 0.24271844 0.24757281]
#  [0.24271844 0.24757281 0.24757281]
#  [0.24757281 0.24757281 0.24757281]]

# %%
print(train_X.shape, train_y.shape, val_X.shape, val_y.shape)
# Out:
# (3175, 1, 18) (3175, 3) (1588, 1, 18) (1588, 3)

# %%
randomState = 46
np.random.seed(randomState)
#tensorflow.random.set_random_seed(randomState)
tensorflow.random.set_seed(randomState)
model = Sequential()
model.add(LSTM(15,input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dense(22))
#model.add(Activation('relu'))    
model.add(Dense(out_hour,activation = "sigmoid"))
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.001)
#    opt=tensorflow.keras.optimizers.Adam(learning_rate=0.00075)
model.compile(loss='mae', optimizer=opt,metrics=['mse','mae',tensorflow.keras.metrics.RootMeanSquaredError()])
history = model.fit(train_X, train_y,validation_data=(val_X, val_y), epochs=500, batch_size=100,verbose=1,shuffle=False)
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)
# Out:
# Train on 3175 samples, validate on 1588 samples
# Epoch 1/500
# 3175/3175 [==============================] - 2s 688us/sample - loss: 0.2507 - mse: 0.0758 - mae: 0.2507 - root_mean_squared_error: 0.2753 - val_loss: 0.2647 - val_mse: 0.0865 - val_mae: 0.2647 - val_root_mean_squared_error: 0.2942
# Epoch 2/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.2352 - mse: 0.0679 - mae: 0.2352 - root_mean_squared_error: 0.2607 - val_loss: 0.2492 - val_mse: 0.0775 - val_mae: 0.2492 - val_root_mean_squared_error: 0.2784
# Epoch 3/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.2197 - mse: 0.0607 - mae: 0.2197 - root_mean_squared_error: 0.2464 - val_loss: 0.2331 - val_mse: 0.0690 - val_mae: 0.2331 - val_root_mean_squared_error: 0.2627
# Epoch 4/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.2042 - mse: 0.0543 - mae: 0.2042 - root_mean_squared_error: 0.2330 - val_loss: 0.2174 - val_mse: 0.0615 - val_mae: 0.2174 - val_root_mean_squared_error: 0.2479
# Epoch 5/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.1897 - mse: 0.0488 - mae: 0.1897 - root_mean_squared_error: 0.2210 - val_loss: 0.2028 - val_mse: 0.0549 - val_mae: 0.2028 - val_root_mean_squared_error: 0.2344
# Epoch 6/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.1766 - mse: 0.0442 - mae: 0.1766 - root_mean_squared_error: 0.2103 - val_loss: 0.1898 - val_mse: 0.0493 - val_mae: 0.1898 - val_root_mean_squared_error: 0.2220
# Epoch 7/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1648 - mse: 0.0399 - mae: 0.1648 - root_mean_squared_error: 0.1999 - val_loss: 0.1778 - val_mse: 0.0441 - val_mae: 0.1778 - val_root_mean_squared_error: 0.2100
# Epoch 8/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1535 - mse: 0.0355 - mae: 0.1535 - root_mean_squared_error: 0.1884 - val_loss: 0.1659 - val_mse: 0.0390 - val_mae: 0.1659 - val_root_mean_squared_error: 0.1975
# Epoch 9/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.1421 - mse: 0.0308 - mae: 0.1421 - root_mean_squared_error: 0.1754 - val_loss: 0.1537 - val_mse: 0.0340 - val_mae: 0.1537 - val_root_mean_squared_error: 0.1843
# Epoch 10/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.1304 - mse: 0.0261 - mae: 0.1304 - root_mean_squared_error: 0.1617 - val_loss: 0.1414 - val_mse: 0.0293 - val_mae: 0.1414 - val_root_mean_squared_error: 0.1713
# Epoch 11/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.1192 - mse: 0.0221 - mae: 0.1192 - root_mean_squared_error: 0.1487 - val_loss: 0.1299 - val_mse: 0.0254 - val_mae: 0.1299 - val_root_mean_squared_error: 0.1592
# Epoch 12/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.1090 - mse: 0.0189 - mae: 0.1090 - root_mean_squared_error: 0.1375 - val_loss: 0.1198 - val_mse: 0.0221 - val_mae: 0.1198 - val_root_mean_squared_error: 0.1487
# Epoch 13/500
# 3175/3175 [==============================] - 0s 41us/sample - loss: 0.1002 - mse: 0.0164 - mae: 0.1002 - root_mean_squared_error: 0.1281 - val_loss: 0.1112 - val_mse: 0.0195 - val_mae: 0.1112 - val_root_mean_squared_error: 0.1397
# Epoch 14/500
# 3175/3175 [==============================] - 0s 37us/sample - loss: 0.0925 - mse: 0.0145 - mae: 0.0925 - root_mean_squared_error: 0.1203 - val_loss: 0.1039 - val_mse: 0.0175 - val_mae: 0.1039 - val_root_mean_squared_error: 0.1323
# Epoch 15/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0863 - mse: 0.0130 - mae: 0.0863 - root_mean_squared_error: 0.1141 - val_loss: 0.0979 - val_mse: 0.0159 - val_mae: 0.0979 - val_root_mean_squared_error: 0.1263
# Epoch 16/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0810 - mse: 0.0119 - mae: 0.0810 - root_mean_squared_error: 0.1092 - val_loss: 0.0928 - val_mse: 0.0147 - val_mae: 0.0928 - val_root_mean_squared_error: 0.1214
# Epoch 17/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0767 - mse: 0.0111 - mae: 0.0767 - root_mean_squared_error: 0.1053 - val_loss: 0.0884 - val_mse: 0.0138 - val_mae: 0.0884 - val_root_mean_squared_error: 0.1173
# Epoch 18/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0729 - mse: 0.0104 - mae: 0.0729 - root_mean_squared_error: 0.1021 - val_loss: 0.0845 - val_mse: 0.0130 - val_mae: 0.0845 - val_root_mean_squared_error: 0.1140
# Epoch 19/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0697 - mse: 0.0099 - mae: 0.0697 - root_mean_squared_error: 0.0996 - val_loss: 0.0811 - val_mse: 0.0124 - val_mae: 0.0811 - val_root_mean_squared_error: 0.1113
# Epoch 20/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0670 - mse: 0.0095 - mae: 0.0670 - root_mean_squared_error: 0.0975 - val_loss: 0.0782 - val_mse: 0.0119 - val_mae: 0.0782 - val_root_mean_squared_error: 0.1090
# Epoch 21/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.0646 - mse: 0.0092 - mae: 0.0646 - root_mean_squared_error: 0.0958 - val_loss: 0.0756 - val_mse: 0.0115 - val_mae: 0.0756 - val_root_mean_squared_error: 0.1071
# Epoch 22/500
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.0626 - mse: 0.0089 - mae: 0.0626 - root_mean_squared_error: 0.0944 - val_loss: 0.0733 - val_mse: 0.0111 - val_mae: 0.0733 - val_root_mean_squared_error: 0.1053
# Epoch 23/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.0608 - mse: 0.0087 - mae: 0.0608 - root_mean_squared_error: 0.0930 - val_loss: 0.0713 - val_mse: 0.0108 - val_mae: 0.0713 - val_root_mean_squared_error: 0.1037
# Epoch 24/500
# 3175/3175 [==============================] - 0s 56us/sample - loss: 0.0592 - mse: 0.0084 - mae: 0.0592 - root_mean_squared_error: 0.0917 - val_loss: 0.0696 - val_mse: 0.0104 - val_mae: 0.0696 - val_root_mean_squared_error: 0.1021
# Epoch 25/500
# 3175/3175 [==============================] - 0s 52us/sample - loss: 0.0578 - mse: 0.0082 - mae: 0.0578 - root_mean_squared_error: 0.0905 - val_loss: 0.0680 - val_mse: 0.0101 - val_mae: 0.0680 - val_root_mean_squared_error: 0.1006
# Epoch 26/500
# 3175/3175 [==============================] - 0s 52us/sample - loss: 0.0565 - mse: 0.0080 - mae: 0.0565 - root_mean_squared_error: 0.0892 - val_loss: 0.0665 - val_mse: 0.0098 - val_mae: 0.0665 - val_root_mean_squared_error: 0.0991
# Epoch 27/500
# 3175/3175 [==============================] - 0s 40us/sample - loss: 0.0553 - mse: 0.0077 - mae: 0.0553 - root_mean_squared_error: 0.0880 - val_loss: 0.0652 - val_mse: 0.0096 - val_mae: 0.0652 - val_root_mean_squared_error: 0.0977
# Epoch 28/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0542 - mse: 0.0075 - mae: 0.0542 - root_mean_squared_error: 0.0868 - val_loss: 0.0640 - val_mse: 0.0093 - val_mae: 0.0640 - val_root_mean_squared_error: 0.0965
# Epoch 29/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0531 - mse: 0.0074 - mae: 0.0531 - root_mean_squared_error: 0.0858 - val_loss: 0.0630 - val_mse: 0.0091 - val_mae: 0.0630 - val_root_mean_squared_error: 0.0954
# Epoch 30/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0522 - mse: 0.0072 - mae: 0.0522 - root_mean_squared_error: 0.0848 - val_loss: 0.0620 - val_mse: 0.0089 - val_mae: 0.0620 - val_root_mean_squared_error: 0.0944
# Epoch 31/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0513 - mse: 0.0070 - mae: 0.0513 - root_mean_squared_error: 0.0839 - val_loss: 0.0611 - val_mse: 0.0087 - val_mae: 0.0611 - val_root_mean_squared_error: 0.0934
# Epoch 32/500
# 3175/3175 [==============================] - 0s 42us/sample - loss: 0.0505 - mse: 0.0069 - mae: 0.0505 - root_mean_squared_error: 0.0830 - val_loss: 0.0603 - val_mse: 0.0086 - val_mae: 0.0603 - val_root_mean_squared_error: 0.0926
# Epoch 33/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0497 - mse: 0.0068 - mae: 0.0497 - root_mean_squared_error: 0.0822 - val_loss: 0.0595 - val_mse: 0.0084 - val_mae: 0.0595 - val_root_mean_squared_error: 0.0917
# Epoch 34/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0491 - mse: 0.0066 - mae: 0.0491 - root_mean_squared_error: 0.0814 - val_loss: 0.0588 - val_mse: 0.0083 - val_mae: 0.0588 - val_root_mean_squared_error: 0.0909
# Epoch 35/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0484 - mse: 0.0065 - mae: 0.0484 - root_mean_squared_error: 0.0806 - val_loss: 0.0582 - val_mse: 0.0081 - val_mae: 0.0582 - val_root_mean_squared_error: 0.0903
# Epoch 36/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0478 - mse: 0.0064 - mae: 0.0478 - root_mean_squared_error: 0.0800 - val_loss: 0.0576 - val_mse: 0.0080 - val_mae: 0.0576 - val_root_mean_squared_error: 0.0897
# Epoch 37/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0473 - mse: 0.0063 - mae: 0.0473 - root_mean_squared_error: 0.0794 - val_loss: 0.0571 - val_mse: 0.0079 - val_mae: 0.0571 - val_root_mean_squared_error: 0.0891
# Epoch 38/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0468 - mse: 0.0062 - mae: 0.0468 - root_mean_squared_error: 0.0788 - val_loss: 0.0566 - val_mse: 0.0078 - val_mae: 0.0566 - val_root_mean_squared_error: 0.0886
# Epoch 39/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0463 - mse: 0.0061 - mae: 0.0463 - root_mean_squared_error: 0.0783 - val_loss: 0.0561 - val_mse: 0.0078 - val_mae: 0.0561 - val_root_mean_squared_error: 0.0881
# Epoch 40/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0459 - mse: 0.0061 - mae: 0.0459 - root_mean_squared_error: 0.0778 - val_loss: 0.0557 - val_mse: 0.0077 - val_mae: 0.0557 - val_root_mean_squared_error: 0.0877
# Epoch 41/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0455 - mse: 0.0060 - mae: 0.0455 - root_mean_squared_error: 0.0774 - val_loss: 0.0553 - val_mse: 0.0076 - val_mae: 0.0553 - val_root_mean_squared_error: 0.0873
# Epoch 42/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0451 - mse: 0.0059 - mae: 0.0451 - root_mean_squared_error: 0.0770 - val_loss: 0.0550 - val_mse: 0.0076 - val_mae: 0.0550 - val_root_mean_squared_error: 0.0869
# Epoch 43/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0447 - mse: 0.0059 - mae: 0.0447 - root_mean_squared_error: 0.0767 - val_loss: 0.0546 - val_mse: 0.0075 - val_mae: 0.0546 - val_root_mean_squared_error: 0.0866
# Epoch 44/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0444 - mse: 0.0058 - mae: 0.0444 - root_mean_squared_error: 0.0763 - val_loss: 0.0543 - val_mse: 0.0074 - val_mae: 0.0543 - val_root_mean_squared_error: 0.0863
# Epoch 45/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0440 - mse: 0.0058 - mae: 0.0440 - root_mean_squared_error: 0.0760 - val_loss: 0.0539 - val_mse: 0.0074 - val_mae: 0.0539 - val_root_mean_squared_error: 0.0860
# Epoch 46/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0437 - mse: 0.0057 - mae: 0.0437 - root_mean_squared_error: 0.0757 - val_loss: 0.0536 - val_mse: 0.0073 - val_mae: 0.0536 - val_root_mean_squared_error: 0.0856
# Epoch 47/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0434 - mse: 0.0057 - mae: 0.0434 - root_mean_squared_error: 0.0754 - val_loss: 0.0533 - val_mse: 0.0073 - val_mae: 0.0533 - val_root_mean_squared_error: 0.0853
# Epoch 48/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0431 - mse: 0.0056 - mae: 0.0431 - root_mean_squared_error: 0.0751 - val_loss: 0.0530 - val_mse: 0.0072 - val_mae: 0.0530 - val_root_mean_squared_error: 0.0850
# Epoch 49/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0428 - mse: 0.0056 - mae: 0.0428 - root_mean_squared_error: 0.0749 - val_loss: 0.0527 - val_mse: 0.0072 - val_mae: 0.0527 - val_root_mean_squared_error: 0.0848
# Epoch 50/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0425 - mse: 0.0056 - mae: 0.0425 - root_mean_squared_error: 0.0746 - val_loss: 0.0524 - val_mse: 0.0072 - val_mae: 0.0524 - val_root_mean_squared_error: 0.0846
# Epoch 51/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0423 - mse: 0.0055 - mae: 0.0423 - root_mean_squared_error: 0.0744 - val_loss: 0.0521 - val_mse: 0.0071 - val_mae: 0.0521 - val_root_mean_squared_error: 0.0844
# Epoch 52/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0420 - mse: 0.0055 - mae: 0.0420 - root_mean_squared_error: 0.0742 - val_loss: 0.0519 - val_mse: 0.0071 - val_mae: 0.0519 - val_root_mean_squared_error: 0.0842
# Epoch 53/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0418 - mse: 0.0055 - mae: 0.0418 - root_mean_squared_error: 0.0741 - val_loss: 0.0516 - val_mse: 0.0070 - val_mae: 0.0516 - val_root_mean_squared_error: 0.0839
# Epoch 54/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0416 - mse: 0.0055 - mae: 0.0416 - root_mean_squared_error: 0.0738 - val_loss: 0.0513 - val_mse: 0.0070 - val_mae: 0.0513 - val_root_mean_squared_error: 0.0838
# Epoch 55/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0413 - mse: 0.0054 - mae: 0.0413 - root_mean_squared_error: 0.0737 - val_loss: 0.0511 - val_mse: 0.0070 - val_mae: 0.0511 - val_root_mean_squared_error: 0.0836
# Epoch 56/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0411 - mse: 0.0054 - mae: 0.0411 - root_mean_squared_error: 0.0735 - val_loss: 0.0508 - val_mse: 0.0070 - val_mae: 0.0508 - val_root_mean_squared_error: 0.0834
# Epoch 57/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0409 - mse: 0.0054 - mae: 0.0409 - root_mean_squared_error: 0.0734 - val_loss: 0.0505 - val_mse: 0.0069 - val_mae: 0.0505 - val_root_mean_squared_error: 0.0832
# Epoch 58/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0407 - mse: 0.0054 - mae: 0.0407 - root_mean_squared_error: 0.0732 - val_loss: 0.0503 - val_mse: 0.0069 - val_mae: 0.0503 - val_root_mean_squared_error: 0.0830
# Epoch 59/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0405 - mse: 0.0053 - mae: 0.0405 - root_mean_squared_error: 0.0730 - val_loss: 0.0500 - val_mse: 0.0069 - val_mae: 0.0500 - val_root_mean_squared_error: 0.0828
# Epoch 60/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0403 - mse: 0.0053 - mae: 0.0403 - root_mean_squared_error: 0.0729 - val_loss: 0.0498 - val_mse: 0.0068 - val_mae: 0.0498 - val_root_mean_squared_error: 0.0826
# Epoch 61/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0401 - mse: 0.0053 - mae: 0.0401 - root_mean_squared_error: 0.0727 - val_loss: 0.0495 - val_mse: 0.0068 - val_mae: 0.0495 - val_root_mean_squared_error: 0.0825
# Epoch 62/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0399 - mse: 0.0053 - mae: 0.0399 - root_mean_squared_error: 0.0726 - val_loss: 0.0493 - val_mse: 0.0068 - val_mae: 0.0493 - val_root_mean_squared_error: 0.0823
# Epoch 63/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0397 - mse: 0.0053 - mae: 0.0397 - root_mean_squared_error: 0.0725 - val_loss: 0.0491 - val_mse: 0.0067 - val_mae: 0.0491 - val_root_mean_squared_error: 0.0821
# Epoch 64/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0395 - mse: 0.0052 - mae: 0.0395 - root_mean_squared_error: 0.0723 - val_loss: 0.0488 - val_mse: 0.0067 - val_mae: 0.0488 - val_root_mean_squared_error: 0.0820
# Epoch 65/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0393 - mse: 0.0052 - mae: 0.0393 - root_mean_squared_error: 0.0722 - val_loss: 0.0486 - val_mse: 0.0067 - val_mae: 0.0486 - val_root_mean_squared_error: 0.0818
# Epoch 66/500
# 3175/3175 [==============================] - 0s 43us/sample - loss: 0.0392 - mse: 0.0052 - mae: 0.0392 - root_mean_squared_error: 0.0721 - val_loss: 0.0484 - val_mse: 0.0067 - val_mae: 0.0484 - val_root_mean_squared_error: 0.0816
# Epoch 67/500
# 3175/3175 [==============================] - 0s 43us/sample - loss: 0.0390 - mse: 0.0052 - mae: 0.0390 - root_mean_squared_error: 0.0720 - val_loss: 0.0482 - val_mse: 0.0066 - val_mae: 0.0482 - val_root_mean_squared_error: 0.0815
# Epoch 68/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0389 - mse: 0.0052 - mae: 0.0389 - root_mean_squared_error: 0.0719 - val_loss: 0.0479 - val_mse: 0.0066 - val_mae: 0.0479 - val_root_mean_squared_error: 0.0813
# Epoch 69/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0387 - mse: 0.0051 - mae: 0.0387 - root_mean_squared_error: 0.0718 - val_loss: 0.0477 - val_mse: 0.0066 - val_mae: 0.0477 - val_root_mean_squared_error: 0.0812
# Epoch 70/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0386 - mse: 0.0051 - mae: 0.0386 - root_mean_squared_error: 0.0716 - val_loss: 0.0476 - val_mse: 0.0066 - val_mae: 0.0476 - val_root_mean_squared_error: 0.0811
# Epoch 71/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0384 - mse: 0.0051 - mae: 0.0384 - root_mean_squared_error: 0.0715 - val_loss: 0.0474 - val_mse: 0.0066 - val_mae: 0.0474 - val_root_mean_squared_error: 0.0809
# Epoch 72/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0383 - mse: 0.0051 - mae: 0.0383 - root_mean_squared_error: 0.0714 - val_loss: 0.0472 - val_mse: 0.0065 - val_mae: 0.0472 - val_root_mean_squared_error: 0.0808
# Epoch 73/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0382 - mse: 0.0051 - mae: 0.0382 - root_mean_squared_error: 0.0713 - val_loss: 0.0470 - val_mse: 0.0065 - val_mae: 0.0470 - val_root_mean_squared_error: 0.0807
# Epoch 74/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0380 - mse: 0.0051 - mae: 0.0380 - root_mean_squared_error: 0.0712 - val_loss: 0.0468 - val_mse: 0.0065 - val_mae: 0.0468 - val_root_mean_squared_error: 0.0806
# Epoch 75/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0379 - mse: 0.0051 - mae: 0.0379 - root_mean_squared_error: 0.0712 - val_loss: 0.0466 - val_mse: 0.0065 - val_mae: 0.0466 - val_root_mean_squared_error: 0.0805
# Epoch 76/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0378 - mse: 0.0051 - mae: 0.0378 - root_mean_squared_error: 0.0711 - val_loss: 0.0464 - val_mse: 0.0065 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0804
# Epoch 77/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0377 - mse: 0.0050 - mae: 0.0377 - root_mean_squared_error: 0.0710 - val_loss: 0.0463 - val_mse: 0.0064 - val_mae: 0.0463 - val_root_mean_squared_error: 0.0803
# Epoch 78/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0375 - mse: 0.0050 - mae: 0.0375 - root_mean_squared_error: 0.0709 - val_loss: 0.0461 - val_mse: 0.0064 - val_mae: 0.0461 - val_root_mean_squared_error: 0.0802
# Epoch 79/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0374 - mse: 0.0050 - mae: 0.0374 - root_mean_squared_error: 0.0708 - val_loss: 0.0459 - val_mse: 0.0064 - val_mae: 0.0459 - val_root_mean_squared_error: 0.0800
# Epoch 80/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0373 - mse: 0.0050 - mae: 0.0373 - root_mean_squared_error: 0.0707 - val_loss: 0.0458 - val_mse: 0.0064 - val_mae: 0.0458 - val_root_mean_squared_error: 0.0800
# Epoch 81/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0372 - mse: 0.0050 - mae: 0.0372 - root_mean_squared_error: 0.0706 - val_loss: 0.0456 - val_mse: 0.0064 - val_mae: 0.0456 - val_root_mean_squared_error: 0.0799
# Epoch 82/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0371 - mse: 0.0050 - mae: 0.0371 - root_mean_squared_error: 0.0706 - val_loss: 0.0455 - val_mse: 0.0064 - val_mae: 0.0455 - val_root_mean_squared_error: 0.0798
# Epoch 83/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0370 - mse: 0.0050 - mae: 0.0370 - root_mean_squared_error: 0.0705 - val_loss: 0.0453 - val_mse: 0.0064 - val_mae: 0.0453 - val_root_mean_squared_error: 0.0797
# Epoch 84/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0369 - mse: 0.0050 - mae: 0.0369 - root_mean_squared_error: 0.0704 - val_loss: 0.0452 - val_mse: 0.0063 - val_mae: 0.0452 - val_root_mean_squared_error: 0.0796
# Epoch 85/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0368 - mse: 0.0049 - mae: 0.0368 - root_mean_squared_error: 0.0704 - val_loss: 0.0450 - val_mse: 0.0063 - val_mae: 0.0450 - val_root_mean_squared_error: 0.0795
# Epoch 86/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0367 - mse: 0.0049 - mae: 0.0367 - root_mean_squared_error: 0.0703 - val_loss: 0.0449 - val_mse: 0.0063 - val_mae: 0.0449 - val_root_mean_squared_error: 0.0795
# Epoch 87/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0366 - mse: 0.0049 - mae: 0.0366 - root_mean_squared_error: 0.0702 - val_loss: 0.0447 - val_mse: 0.0063 - val_mae: 0.0447 - val_root_mean_squared_error: 0.0794
# Epoch 88/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0365 - mse: 0.0049 - mae: 0.0365 - root_mean_squared_error: 0.0701 - val_loss: 0.0446 - val_mse: 0.0063 - val_mae: 0.0446 - val_root_mean_squared_error: 0.0793
# Epoch 89/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0364 - mse: 0.0049 - mae: 0.0364 - root_mean_squared_error: 0.0701 - val_loss: 0.0445 - val_mse: 0.0063 - val_mae: 0.0445 - val_root_mean_squared_error: 0.0793
# Epoch 90/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0363 - mse: 0.0049 - mae: 0.0363 - root_mean_squared_error: 0.0700 - val_loss: 0.0443 - val_mse: 0.0063 - val_mae: 0.0443 - val_root_mean_squared_error: 0.0792
# Epoch 91/500
# 3175/3175 [==============================] - 0s 45us/sample - loss: 0.0362 - mse: 0.0049 - mae: 0.0362 - root_mean_squared_error: 0.0700 - val_loss: 0.0442 - val_mse: 0.0063 - val_mae: 0.0442 - val_root_mean_squared_error: 0.0791
# Epoch 92/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0361 - mse: 0.0049 - mae: 0.0361 - root_mean_squared_error: 0.0699 - val_loss: 0.0440 - val_mse: 0.0062 - val_mae: 0.0440 - val_root_mean_squared_error: 0.0790
# Epoch 93/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0361 - mse: 0.0049 - mae: 0.0361 - root_mean_squared_error: 0.0699 - val_loss: 0.0439 - val_mse: 0.0062 - val_mae: 0.0439 - val_root_mean_squared_error: 0.0790
# Epoch 94/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0360 - mse: 0.0049 - mae: 0.0360 - root_mean_squared_error: 0.0698 - val_loss: 0.0438 - val_mse: 0.0062 - val_mae: 0.0438 - val_root_mean_squared_error: 0.0789
# Epoch 95/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0359 - mse: 0.0049 - mae: 0.0359 - root_mean_squared_error: 0.0698 - val_loss: 0.0437 - val_mse: 0.0062 - val_mae: 0.0437 - val_root_mean_squared_error: 0.0789
# Epoch 96/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0358 - mse: 0.0049 - mae: 0.0358 - root_mean_squared_error: 0.0697 - val_loss: 0.0436 - val_mse: 0.0062 - val_mae: 0.0436 - val_root_mean_squared_error: 0.0788
# Epoch 97/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0357 - mse: 0.0049 - mae: 0.0357 - root_mean_squared_error: 0.0697 - val_loss: 0.0435 - val_mse: 0.0062 - val_mae: 0.0435 - val_root_mean_squared_error: 0.0787
# Epoch 98/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0357 - mse: 0.0049 - mae: 0.0357 - root_mean_squared_error: 0.0696 - val_loss: 0.0433 - val_mse: 0.0062 - val_mae: 0.0433 - val_root_mean_squared_error: 0.0787
# Epoch 99/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0356 - mse: 0.0048 - mae: 0.0356 - root_mean_squared_error: 0.0696 - val_loss: 0.0432 - val_mse: 0.0062 - val_mae: 0.0432 - val_root_mean_squared_error: 0.0786
# Epoch 100/500
# 3175/3175 [==============================] - 0s 87us/sample - loss: 0.0355 - mse: 0.0048 - mae: 0.0355 - root_mean_squared_error: 0.0696 - val_loss: 0.0431 - val_mse: 0.0062 - val_mae: 0.0431 - val_root_mean_squared_error: 0.0786
# Epoch 101/500
# 3175/3175 [==============================] - 0s 74us/sample - loss: 0.0355 - mse: 0.0048 - mae: 0.0355 - root_mean_squared_error: 0.0695 - val_loss: 0.0430 - val_mse: 0.0062 - val_mae: 0.0430 - val_root_mean_squared_error: 0.0786
# Epoch 102/500
# 3175/3175 [==============================] - 0s 60us/sample - loss: 0.0354 - mse: 0.0048 - mae: 0.0354 - root_mean_squared_error: 0.0695 - val_loss: 0.0429 - val_mse: 0.0062 - val_mae: 0.0429 - val_root_mean_squared_error: 0.0785
# Epoch 103/500
# 3175/3175 [==============================] - 0s 63us/sample - loss: 0.0353 - mse: 0.0048 - mae: 0.0353 - root_mean_squared_error: 0.0694 - val_loss: 0.0428 - val_mse: 0.0062 - val_mae: 0.0428 - val_root_mean_squared_error: 0.0785
# Epoch 104/500
# 3175/3175 [==============================] - 0s 60us/sample - loss: 0.0353 - mse: 0.0048 - mae: 0.0353 - root_mean_squared_error: 0.0694 - val_loss: 0.0427 - val_mse: 0.0062 - val_mae: 0.0427 - val_root_mean_squared_error: 0.0784
# Epoch 105/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.0352 - mse: 0.0048 - mae: 0.0352 - root_mean_squared_error: 0.0694 - val_loss: 0.0426 - val_mse: 0.0061 - val_mae: 0.0426 - val_root_mean_squared_error: 0.0784
# Epoch 106/500
# 3175/3175 [==============================] - 0s 65us/sample - loss: 0.0352 - mse: 0.0048 - mae: 0.0352 - root_mean_squared_error: 0.0693 - val_loss: 0.0425 - val_mse: 0.0061 - val_mae: 0.0425 - val_root_mean_squared_error: 0.0784
# Epoch 107/500
# 3175/3175 [==============================] - 0s 63us/sample - loss: 0.0351 - mse: 0.0048 - mae: 0.0351 - root_mean_squared_error: 0.0693 - val_loss: 0.0425 - val_mse: 0.0061 - val_mae: 0.0425 - val_root_mean_squared_error: 0.0783
# Epoch 108/500
# 3175/3175 [==============================] - 0s 75us/sample - loss: 0.0350 - mse: 0.0048 - mae: 0.0350 - root_mean_squared_error: 0.0693 - val_loss: 0.0424 - val_mse: 0.0061 - val_mae: 0.0424 - val_root_mean_squared_error: 0.0783
# Epoch 109/500
# 3175/3175 [==============================] - 0s 63us/sample - loss: 0.0350 - mse: 0.0048 - mae: 0.0350 - root_mean_squared_error: 0.0692 - val_loss: 0.0423 - val_mse: 0.0061 - val_mae: 0.0423 - val_root_mean_squared_error: 0.0782
# Epoch 110/500
# 3175/3175 [==============================] - 0s 52us/sample - loss: 0.0349 - mse: 0.0048 - mae: 0.0349 - root_mean_squared_error: 0.0692 - val_loss: 0.0422 - val_mse: 0.0061 - val_mae: 0.0422 - val_root_mean_squared_error: 0.0782
# Epoch 111/500
# 3175/3175 [==============================] - 0s 55us/sample - loss: 0.0349 - mse: 0.0048 - mae: 0.0349 - root_mean_squared_error: 0.0692 - val_loss: 0.0421 - val_mse: 0.0061 - val_mae: 0.0421 - val_root_mean_squared_error: 0.0782
# Epoch 112/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0348 - mse: 0.0048 - mae: 0.0348 - root_mean_squared_error: 0.0691 - val_loss: 0.0420 - val_mse: 0.0061 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0781
# Epoch 113/500
# 3175/3175 [==============================] - 0s 36us/sample - loss: 0.0348 - mse: 0.0048 - mae: 0.0348 - root_mean_squared_error: 0.0691 - val_loss: 0.0420 - val_mse: 0.0061 - val_mae: 0.0420 - val_root_mean_squared_error: 0.0781
# Epoch 114/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0347 - mse: 0.0048 - mae: 0.0347 - root_mean_squared_error: 0.0691 - val_loss: 0.0419 - val_mse: 0.0061 - val_mae: 0.0419 - val_root_mean_squared_error: 0.0781
# Epoch 115/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0347 - mse: 0.0048 - mae: 0.0347 - root_mean_squared_error: 0.0691 - val_loss: 0.0418 - val_mse: 0.0061 - val_mae: 0.0418 - val_root_mean_squared_error: 0.0781
# Epoch 116/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0346 - mse: 0.0048 - mae: 0.0346 - root_mean_squared_error: 0.0691 - val_loss: 0.0417 - val_mse: 0.0061 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0780
# Epoch 117/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0346 - mse: 0.0048 - mae: 0.0346 - root_mean_squared_error: 0.0690 - val_loss: 0.0417 - val_mse: 0.0061 - val_mae: 0.0417 - val_root_mean_squared_error: 0.0780
# Epoch 118/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0345 - mse: 0.0048 - mae: 0.0345 - root_mean_squared_error: 0.0690 - val_loss: 0.0416 - val_mse: 0.0061 - val_mae: 0.0416 - val_root_mean_squared_error: 0.0780
# Epoch 119/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0345 - mse: 0.0048 - mae: 0.0345 - root_mean_squared_error: 0.0690 - val_loss: 0.0415 - val_mse: 0.0061 - val_mae: 0.0415 - val_root_mean_squared_error: 0.0780
# Epoch 120/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0344 - mse: 0.0048 - mae: 0.0344 - root_mean_squared_error: 0.0690 - val_loss: 0.0415 - val_mse: 0.0061 - val_mae: 0.0415 - val_root_mean_squared_error: 0.0779
# Epoch 121/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0344 - mse: 0.0048 - mae: 0.0344 - root_mean_squared_error: 0.0689 - val_loss: 0.0414 - val_mse: 0.0061 - val_mae: 0.0414 - val_root_mean_squared_error: 0.0779
# Epoch 122/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0344 - mse: 0.0047 - mae: 0.0344 - root_mean_squared_error: 0.0689 - val_loss: 0.0413 - val_mse: 0.0061 - val_mae: 0.0413 - val_root_mean_squared_error: 0.0778
# Epoch 123/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0343 - mse: 0.0047 - mae: 0.0343 - root_mean_squared_error: 0.0689 - val_loss: 0.0412 - val_mse: 0.0061 - val_mae: 0.0412 - val_root_mean_squared_error: 0.0778
# Epoch 124/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0343 - mse: 0.0047 - mae: 0.0343 - root_mean_squared_error: 0.0689 - val_loss: 0.0412 - val_mse: 0.0061 - val_mae: 0.0412 - val_root_mean_squared_error: 0.0778
# Epoch 125/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0343 - mse: 0.0047 - mae: 0.0343 - root_mean_squared_error: 0.0689 - val_loss: 0.0411 - val_mse: 0.0061 - val_mae: 0.0411 - val_root_mean_squared_error: 0.0778
# Epoch 126/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0342 - mse: 0.0047 - mae: 0.0342 - root_mean_squared_error: 0.0688 - val_loss: 0.0411 - val_mse: 0.0060 - val_mae: 0.0411 - val_root_mean_squared_error: 0.0778
# Epoch 127/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0342 - mse: 0.0047 - mae: 0.0342 - root_mean_squared_error: 0.0688 - val_loss: 0.0410 - val_mse: 0.0060 - val_mae: 0.0410 - val_root_mean_squared_error: 0.0777
# Epoch 128/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0341 - mse: 0.0047 - mae: 0.0341 - root_mean_squared_error: 0.0688 - val_loss: 0.0410 - val_mse: 0.0060 - val_mae: 0.0410 - val_root_mean_squared_error: 0.0777
# Epoch 129/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0341 - mse: 0.0047 - mae: 0.0341 - root_mean_squared_error: 0.0688 - val_loss: 0.0409 - val_mse: 0.0060 - val_mae: 0.0409 - val_root_mean_squared_error: 0.0777
# Epoch 130/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0341 - mse: 0.0047 - mae: 0.0341 - root_mean_squared_error: 0.0688 - val_loss: 0.0408 - val_mse: 0.0060 - val_mae: 0.0408 - val_root_mean_squared_error: 0.0777
# Epoch 131/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0340 - mse: 0.0047 - mae: 0.0340 - root_mean_squared_error: 0.0688 - val_loss: 0.0408 - val_mse: 0.0060 - val_mae: 0.0408 - val_root_mean_squared_error: 0.0777
# Epoch 132/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0340 - mse: 0.0047 - mae: 0.0340 - root_mean_squared_error: 0.0688 - val_loss: 0.0407 - val_mse: 0.0060 - val_mae: 0.0407 - val_root_mean_squared_error: 0.0776
# Epoch 133/500
# 3175/3175 [==============================] - 0s 42us/sample - loss: 0.0340 - mse: 0.0047 - mae: 0.0340 - root_mean_squared_error: 0.0687 - val_loss: 0.0407 - val_mse: 0.0060 - val_mae: 0.0407 - val_root_mean_squared_error: 0.0776
# Epoch 134/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0339 - mse: 0.0047 - mae: 0.0339 - root_mean_squared_error: 0.0687 - val_loss: 0.0406 - val_mse: 0.0060 - val_mae: 0.0406 - val_root_mean_squared_error: 0.0776
# Epoch 135/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0339 - mse: 0.0047 - mae: 0.0339 - root_mean_squared_error: 0.0687 - val_loss: 0.0406 - val_mse: 0.0060 - val_mae: 0.0406 - val_root_mean_squared_error: 0.0776
# Epoch 136/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0339 - mse: 0.0047 - mae: 0.0339 - root_mean_squared_error: 0.0687 - val_loss: 0.0406 - val_mse: 0.0060 - val_mae: 0.0406 - val_root_mean_squared_error: 0.0775
# Epoch 137/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0338 - mse: 0.0047 - mae: 0.0338 - root_mean_squared_error: 0.0687 - val_loss: 0.0405 - val_mse: 0.0060 - val_mae: 0.0405 - val_root_mean_squared_error: 0.0775
# Epoch 138/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0338 - mse: 0.0047 - mae: 0.0338 - root_mean_squared_error: 0.0687 - val_loss: 0.0405 - val_mse: 0.0060 - val_mae: 0.0405 - val_root_mean_squared_error: 0.0775
# Epoch 139/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0338 - mse: 0.0047 - mae: 0.0338 - root_mean_squared_error: 0.0687 - val_loss: 0.0404 - val_mse: 0.0060 - val_mae: 0.0404 - val_root_mean_squared_error: 0.0775
# Epoch 140/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0338 - mse: 0.0047 - mae: 0.0338 - root_mean_squared_error: 0.0687 - val_loss: 0.0404 - val_mse: 0.0060 - val_mae: 0.0404 - val_root_mean_squared_error: 0.0775
# Epoch 141/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0337 - mse: 0.0047 - mae: 0.0337 - root_mean_squared_error: 0.0687 - val_loss: 0.0403 - val_mse: 0.0060 - val_mae: 0.0403 - val_root_mean_squared_error: 0.0775
# Epoch 142/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0337 - mse: 0.0047 - mae: 0.0337 - root_mean_squared_error: 0.0687 - val_loss: 0.0403 - val_mse: 0.0060 - val_mae: 0.0403 - val_root_mean_squared_error: 0.0774
# Epoch 143/500
# 3175/3175 [==============================] - 0s 38us/sample - loss: 0.0337 - mse: 0.0047 - mae: 0.0337 - root_mean_squared_error: 0.0686 - val_loss: 0.0403 - val_mse: 0.0060 - val_mae: 0.0403 - val_root_mean_squared_error: 0.0774
# Epoch 144/500
# 3175/3175 [==============================] - 0s 35us/sample - loss: 0.0337 - mse: 0.0047 - mae: 0.0337 - root_mean_squared_error: 0.0686 - val_loss: 0.0402 - val_mse: 0.0060 - val_mae: 0.0402 - val_root_mean_squared_error: 0.0774
# Epoch 145/500
# 3175/3175 [==============================] - 0s 48us/sample - loss: 0.0336 - mse: 0.0047 - mae: 0.0336 - root_mean_squared_error: 0.0686 - val_loss: 0.0402 - val_mse: 0.0060 - val_mae: 0.0402 - val_root_mean_squared_error: 0.0774
# Epoch 146/500
# 3175/3175 [==============================] - 0s 59us/sample - loss: 0.0336 - mse: 0.0047 - mae: 0.0336 - root_mean_squared_error: 0.0686 - val_loss: 0.0401 - val_mse: 0.0060 - val_mae: 0.0401 - val_root_mean_squared_error: 0.0774
# Epoch 147/500
# 3175/3175 [==============================] - 0s 56us/sample - loss: 0.0336 - mse: 0.0047 - mae: 0.0336 - root_mean_squared_error: 0.0686 - val_loss: 0.0401 - val_mse: 0.0060 - val_mae: 0.0401 - val_root_mean_squared_error: 0.0774
# Epoch 148/500
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.0336 - mse: 0.0047 - mae: 0.0336 - root_mean_squared_error: 0.0686 - val_loss: 0.0401 - val_mse: 0.0060 - val_mae: 0.0401 - val_root_mean_squared_error: 0.0774
# Epoch 149/500
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.0335 - mse: 0.0047 - mae: 0.0335 - root_mean_squared_error: 0.0686 - val_loss: 0.0400 - val_mse: 0.0060 - val_mae: 0.0400 - val_root_mean_squared_error: 0.0774
# Epoch 150/500
# 3175/3175 [==============================] - 0s 53us/sample - loss: 0.0335 - mse: 0.0047 - mae: 0.0335 - root_mean_squared_error: 0.0686 - val_loss: 0.0400 - val_mse: 0.0060 - val_mae: 0.0400 - val_root_mean_squared_error: 0.0773
# Epoch 151/500
# 3175/3175 [==============================] - 0s 54us/sample - loss: 0.0335 - mse: 0.0047 - mae: 0.0335 - root_mean_squared_error: 0.0686 - val_loss: 0.0400 - val_mse: 0.0060 - val_mae: 0.0400 - val_root_mean_squared_error: 0.0773
# Epoch 152/500
# 3175/3175 [==============================] - 0s 48us/sample - loss: 0.0335 - mse: 0.0047 - mae: 0.0335 - root_mean_squared_error: 0.0686 - val_loss: 0.0399 - val_mse: 0.0060 - val_mae: 0.0399 - val_root_mean_squared_error: 0.0773
# Epoch 153/500
# 3175/3175 [==============================] - 0s 52us/sample - loss: 0.0335 - mse: 0.0047 - mae: 0.0335 - root_mean_squared_error: 0.0685 - val_loss: 0.0399 - val_mse: 0.0060 - val_mae: 0.0399 - val_root_mean_squared_error: 0.0773
# Epoch 154/500
# 3175/3175 [==============================] - 0s 52us/sample - loss: 0.0334 - mse: 0.0047 - mae: 0.0334 - root_mean_squared_error: 0.0685 - val_loss: 0.0399 - val_mse: 0.0060 - val_mae: 0.0399 - val_root_mean_squared_error: 0.0773
# Epoch 155/500
# 3175/3175 [==============================] - 0s 60us/sample - loss: 0.0334 - mse: 0.0047 - mae: 0.0334 - root_mean_squared_error: 0.0685 - val_loss: 0.0398 - val_mse: 0.0060 - val_mae: 0.0398 - val_root_mean_squared_error: 0.0773
# Epoch 156/500
# 3175/3175 [==============================] - 0s 51us/sample - loss: 0.0334 - mse: 0.0047 - mae: 0.0334 - root_mean_squared_error: 0.0685 - val_loss: 0.0398 - val_mse: 0.0060 - val_mae: 0.0398 - val_root_mean_squared_error: 0.0773
# Epoch 157/500
# 3175/3175 [==============================] - 0s 52us/sample - loss: 0.0334 - mse: 0.0047 - mae: 0.0334 - root_mean_squared_error: 0.0685 - val_loss: 0.0398 - val_mse: 0.0060 - val_mae: 0.0398 - val_root_mean_squared_error: 0.0773
# Epoch 158/500
# 3175/3175 [==============================] - 0s 52us/sample - loss: 0.0334 - mse: 0.0047 - mae: 0.0334 - root_mean_squared_error: 0.0685 - val_loss: 0.0397 - val_mse: 0.0060 - val_mae: 0.0397 - val_root_mean_squared_error: 0.0773
# Epoch 159/500
# 3175/3175 [==============================] - 0s 52us/sample - loss: 0.0333 - mse: 0.0047 - mae: 0.0333 - root_mean_squared_error: 0.0685 - val_loss: 0.0397 - val_mse: 0.0060 - val_mae: 0.0397 - val_root_mean_squared_error: 0.0773
# Epoch 160/500
# 3175/3175 [==============================] - 0s 51us/sample - loss: 0.0333 - mse: 0.0047 - mae: 0.0333 - root_mean_squared_error: 0.0685 - val_loss: 0.0397 - val_mse: 0.0060 - val_mae: 0.0397 - val_root_mean_squared_error: 0.0772
# Epoch 161/500
# 3175/3175 [==============================] - 0s 53us/sample - loss: 0.0333 - mse: 0.0047 - mae: 0.0333 - root_mean_squared_error: 0.0685 - val_loss: 0.0396 - val_mse: 0.0060 - val_mae: 0.0396 - val_root_mean_squared_error: 0.0772
# Epoch 162/500
# 3175/3175 [==============================] - 0s 51us/sample - loss: 0.0333 - mse: 0.0047 - mae: 0.0333 - root_mean_squared_error: 0.0685 - val_loss: 0.0396 - val_mse: 0.0060 - val_mae: 0.0396 - val_root_mean_squared_error: 0.0772
# Epoch 163/500
# 3175/3175 [==============================] - 0s 52us/sample - loss: 0.0333 - mse: 0.0047 - mae: 0.0333 - root_mean_squared_error: 0.0685 - val_loss: 0.0396 - val_mse: 0.0060 - val_mae: 0.0396 - val_root_mean_squared_error: 0.0772
# Epoch 164/500
# 3175/3175 [==============================] - 0s 53us/sample - loss: 0.0332 - mse: 0.0047 - mae: 0.0332 - root_mean_squared_error: 0.0685 - val_loss: 0.0395 - val_mse: 0.0060 - val_mae: 0.0395 - val_root_mean_squared_error: 0.0771
# Epoch 165/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0332 - mse: 0.0047 - mae: 0.0332 - root_mean_squared_error: 0.0685 - val_loss: 0.0395 - val_mse: 0.0059 - val_mae: 0.0395 - val_root_mean_squared_error: 0.0771
# Epoch 166/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0332 - mse: 0.0047 - mae: 0.0332 - root_mean_squared_error: 0.0684 - val_loss: 0.0395 - val_mse: 0.0059 - val_mae: 0.0395 - val_root_mean_squared_error: 0.0771
# Epoch 167/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0332 - mse: 0.0047 - mae: 0.0332 - root_mean_squared_error: 0.0684 - val_loss: 0.0394 - val_mse: 0.0059 - val_mae: 0.0394 - val_root_mean_squared_error: 0.0771
# Epoch 168/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0332 - mse: 0.0047 - mae: 0.0332 - root_mean_squared_error: 0.0684 - val_loss: 0.0394 - val_mse: 0.0059 - val_mae: 0.0394 - val_root_mean_squared_error: 0.0771
# Epoch 169/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0331 - mse: 0.0047 - mae: 0.0331 - root_mean_squared_error: 0.0684 - val_loss: 0.0394 - val_mse: 0.0059 - val_mae: 0.0394 - val_root_mean_squared_error: 0.0771
# Epoch 170/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0331 - mse: 0.0047 - mae: 0.0331 - root_mean_squared_error: 0.0684 - val_loss: 0.0394 - val_mse: 0.0059 - val_mae: 0.0394 - val_root_mean_squared_error: 0.0771
# Epoch 171/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0331 - mse: 0.0047 - mae: 0.0331 - root_mean_squared_error: 0.0684 - val_loss: 0.0393 - val_mse: 0.0059 - val_mae: 0.0393 - val_root_mean_squared_error: 0.0770
# Epoch 172/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0331 - mse: 0.0047 - mae: 0.0331 - root_mean_squared_error: 0.0684 - val_loss: 0.0393 - val_mse: 0.0059 - val_mae: 0.0393 - val_root_mean_squared_error: 0.0770
# Epoch 173/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0331 - mse: 0.0047 - mae: 0.0331 - root_mean_squared_error: 0.0684 - val_loss: 0.0393 - val_mse: 0.0059 - val_mae: 0.0393 - val_root_mean_squared_error: 0.0770
# Epoch 174/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0331 - mse: 0.0047 - mae: 0.0331 - root_mean_squared_error: 0.0684 - val_loss: 0.0393 - val_mse: 0.0059 - val_mae: 0.0393 - val_root_mean_squared_error: 0.0770
# Epoch 175/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0331 - mse: 0.0047 - mae: 0.0331 - root_mean_squared_error: 0.0684 - val_loss: 0.0392 - val_mse: 0.0059 - val_mae: 0.0392 - val_root_mean_squared_error: 0.0770
# Epoch 176/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0330 - mse: 0.0047 - mae: 0.0330 - root_mean_squared_error: 0.0684 - val_loss: 0.0392 - val_mse: 0.0059 - val_mae: 0.0392 - val_root_mean_squared_error: 0.0770
# Epoch 177/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0330 - mse: 0.0047 - mae: 0.0330 - root_mean_squared_error: 0.0684 - val_loss: 0.0392 - val_mse: 0.0059 - val_mae: 0.0392 - val_root_mean_squared_error: 0.0770
# Epoch 178/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0330 - mse: 0.0047 - mae: 0.0330 - root_mean_squared_error: 0.0684 - val_loss: 0.0392 - val_mse: 0.0059 - val_mae: 0.0392 - val_root_mean_squared_error: 0.0770
# Epoch 179/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0330 - mse: 0.0047 - mae: 0.0330 - root_mean_squared_error: 0.0683 - val_loss: 0.0392 - val_mse: 0.0059 - val_mae: 0.0392 - val_root_mean_squared_error: 0.0769
# Epoch 180/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0330 - mse: 0.0047 - mae: 0.0330 - root_mean_squared_error: 0.0683 - val_loss: 0.0391 - val_mse: 0.0059 - val_mae: 0.0391 - val_root_mean_squared_error: 0.0769
# Epoch 181/500
# 3175/3175 [==============================] - 0s 25us/sample - loss: 0.0330 - mse: 0.0047 - mae: 0.0330 - root_mean_squared_error: 0.0683 - val_loss: 0.0391 - val_mse: 0.0059 - val_mae: 0.0391 - val_root_mean_squared_error: 0.0769
# Epoch 182/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0330 - mse: 0.0047 - mae: 0.0330 - root_mean_squared_error: 0.0683 - val_loss: 0.0391 - val_mse: 0.0059 - val_mae: 0.0391 - val_root_mean_squared_error: 0.0769
# Epoch 183/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0329 - mse: 0.0047 - mae: 0.0329 - root_mean_squared_error: 0.0683 - val_loss: 0.0391 - val_mse: 0.0059 - val_mae: 0.0391 - val_root_mean_squared_error: 0.0769
# Epoch 184/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0329 - mse: 0.0047 - mae: 0.0329 - root_mean_squared_error: 0.0683 - val_loss: 0.0390 - val_mse: 0.0059 - val_mae: 0.0390 - val_root_mean_squared_error: 0.0769
# Epoch 185/500
# 3175/3175 [==============================] - 0s 27us/sample - loss: 0.0329 - mse: 0.0047 - mae: 0.0329 - root_mean_squared_error: 0.0683 - val_loss: 0.0390 - val_mse: 0.0059 - val_mae: 0.0390 - val_root_mean_squared_error: 0.0769
# Epoch 186/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0329 - mse: 0.0047 - mae: 0.0329 - root_mean_squared_error: 0.0683 - val_loss: 0.0390 - val_mse: 0.0059 - val_mae: 0.0390 - val_root_mean_squared_error: 0.0769
# Epoch 187/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0329 - mse: 0.0047 - mae: 0.0329 - root_mean_squared_error: 0.0683 - val_loss: 0.0390 - val_mse: 0.0059 - val_mae: 0.0390 - val_root_mean_squared_error: 0.0769
# Epoch 188/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0329 - mse: 0.0047 - mae: 0.0329 - root_mean_squared_error: 0.0683 - val_loss: 0.0389 - val_mse: 0.0059 - val_mae: 0.0389 - val_root_mean_squared_error: 0.0769
# Epoch 189/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0329 - mse: 0.0047 - mae: 0.0329 - root_mean_squared_error: 0.0683 - val_loss: 0.0389 - val_mse: 0.0059 - val_mae: 0.0389 - val_root_mean_squared_error: 0.0769
# Epoch 190/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0329 - mse: 0.0047 - mae: 0.0329 - root_mean_squared_error: 0.0682 - val_loss: 0.0389 - val_mse: 0.0059 - val_mae: 0.0389 - val_root_mean_squared_error: 0.0769
# Epoch 191/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0328 - mse: 0.0047 - mae: 0.0328 - root_mean_squared_error: 0.0683 - val_loss: 0.0389 - val_mse: 0.0059 - val_mae: 0.0389 - val_root_mean_squared_error: 0.0768
# Epoch 192/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0328 - mse: 0.0047 - mae: 0.0328 - root_mean_squared_error: 0.0682 - val_loss: 0.0389 - val_mse: 0.0059 - val_mae: 0.0389 - val_root_mean_squared_error: 0.0768
# Epoch 193/500
# 3175/3175 [==============================] - 0s 39us/sample - loss: 0.0328 - mse: 0.0047 - mae: 0.0328 - root_mean_squared_error: 0.0682 - val_loss: 0.0388 - val_mse: 0.0059 - val_mae: 0.0388 - val_root_mean_squared_error: 0.0768
# Epoch 194/500
# 3175/3175 [==============================] - 0s 28us/sample - loss: 0.0328 - mse: 0.0047 - mae: 0.0328 - root_mean_squared_error: 0.0682 - val_loss: 0.0388 - val_mse: 0.0059 - val_mae: 0.0388 - val_root_mean_squared_error: 0.0768
# Epoch 195/500
# 3175/3175 [==============================] - 0s 26us/sample - loss: 0.0328 - mse: 0.0047 - mae: 0.0328 - root_mean_squared_error: 0.0682 - val_loss: 0.0388 - val_mse: 0.0059 - val_mae: 0.0388 - val_root_mean_squared_error: 0.0768
# Epoch 196/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0328 - mse: 0.0047 - mae: 0.0328 - root_mean_squared_error: 0.0682 - val_loss: 0.0388 - val_mse: 0.0059 - val_mae: 0.0388 - val_root_mean_squared_error: 0.0768
# Epoch 197/500
# ...
# Epoch 436/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 437/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 438/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 439/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 440/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 441/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 442/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 443/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 444/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 445/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 446/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 447/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 448/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 449/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 450/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 451/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 452/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 453/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 454/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 455/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0765
# Epoch 456/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 457/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 458/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 459/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 460/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 461/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 462/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 463/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 464/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0317 - mse: 0.0046 - mae: 0.0317 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 465/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 466/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0765
# Epoch 467/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 468/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 469/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0765
# Epoch 470/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 471/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0372 - val_mse: 0.0058 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0764
# Epoch 472/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 473/500
# 3175/3175 [==============================] - 0s 29us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 474/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 475/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 476/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 477/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 478/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 479/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 480/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 481/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 482/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 483/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 484/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 485/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 486/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 487/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 488/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 489/500
# 3175/3175 [==============================] - 0s 32us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 490/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 491/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 492/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 493/500
# 3175/3175 [==============================] - 0s 30us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 494/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0764
# Epoch 495/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 496/500
# 3175/3175 [==============================] - 0s 34us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 497/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 498/500
# 3175/3175 [==============================] - 0s 33us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 499/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765
# Epoch 500/500
# 3175/3175 [==============================] - 0s 31us/sample - loss: 0.0316 - mse: 0.0046 - mae: 0.0316 - root_mean_squared_error: 0.0678 - val_loss: 0.0371 - val_mse: 0.0058 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0765

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mae'],label='train mae')
pyplot.plot(history.history['val_mae'],label='val mae')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['mse'],label='train mse')
pyplot.plot(history.history['val_mse'],label='val mse')
pyplot.legend()
pyplot.show()
pyplot.plot(history.history['root_mean_squared_error'],label='train rmse')
pyplot.plot(history.history['val_root_mean_squared_error'],label='val rmse')
pyplot.legend()
pyplot.show()
# Out:
# The testing MAE loss is: 0.034323398
# The testing MSE loss is: 0.005195752
# The testing RMSE loss is: 0.07208156

# %%
pyplot.plot(test_y[:,2],color='red', label='True Values')
pyplot.plot(out[:,2],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()

# %%
dataset_test=pd.read_excel('F:\MS thesis data/Hopper Crossing.xlsx')
dataset_test=dataset_test.drop(['Date/Time','Flowd'],axis=1)
dataset_test.dropna(inplace=True)

# %%
shape=np.shape(dataset_test)
print(shape)
pyplot.plot(dataset_test)
# Out:
# (26285, 3)
# [<matplotlib.lines.Line2D at 0x29e70edf7c8>,
#  <matplotlib.lines.Line2D at 0x29e70ee7a08>,
#  <matplotlib.lines.Line2D at 0x29e70eed108>]

# %%
dataset_test
# Out:
#        Cumulative rainfall   Flow  Level
# 0                      0.0  0.093    1.50
# 1                      0.0  0.093    1.50
# 2                      0.0  0.093    1.50
# 3                      0.0  0.093    1.50
# 4                      0.0  0.093    1.50
# ...                    ...    ...     ...
# 26280                  0.2  0.080    1.49
# 26281                  0.2  0.080    1.49
# 26282                  0.2  0.080    1.49
# 26283                  0.2  0.080    1.49
# 26284                  0.2  0.080    1.49
#
# [26285 rows x 3 columns]

# %%
print('The std of original data is ' + str(np.std(dataset_test)))
# Out:
# The std of original data is Cumulative rainfall    2.451640
# Flow                   0.520832
# Level                  0.083204
# dtype: float64

# %%
#Normalizing and removing outlier from Dataset
#Outliers removel
num=int((shape[0]*0.03)/2)
dataset_test=dataset_test.values
#dataset=np.array(dataset)
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])
count=0
#for j in range(num):
while(count<num):
    
    maxi=dataset_test.max(axis=0)
#    print(maxi)
    ind1=np.argwhere(dataset_test[:,0]== maxi[0])
    ind2=np.argwhere(dataset_test[:,1]== maxi[1])
    ind3=np.argwhere(dataset_test[:,2]== maxi[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2])    
    
count=0
#for j in range(num):
while(count<num):
    
    mini=dataset_test.min(axis=0)
#    print(mini)
    ind1=np.argwhere(dataset_test[:,0]== mini[0])
    ind2=np.argwhere(dataset_test[:,1]== mini[1])
    ind3=np.argwhere(dataset_test[:,2]== mini[2])
    ind=np.append(ind1,ind2)
    ind=np.append(ind,ind3)
    index=[]
    for i in ind:
        if i not in index:
            index.append(i)
    count=count+len(index)
    dataset_test=np.delete(dataset_test,index,axis=0) 
#pyplot.plot(dataset[:,0])
#pyplot.plot(dataset[:,1])
#pyplot.plot(dataset[:,2]) 
print('The std of cleaned data is ' +str(np.std(dataset_test)))
min_max_scaler = preprocessing.MinMaxScaler()   #scaling values
dataset_test = min_max_scaler.fit_transform(dataset_test)
# Out:
# The std of cleaned data is 1.5154548293543502

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset.columns=['rain','flow','level']
n_hours =6
out_hour=3
values =dataset.values
values = values.astype('float32')
reframed = series_to_supervised(values, n_hours, out_hour)
print(reframed.shape)
trainx_column=n_hours*3
pred_columns=reframed.shape[1]-trainx_column
for i in range(out_hour):
    reframed.drop(reframed.columns[[-3-i,-2-i]], axis=1, inplace=True)
print(reframed.head())
values = reframed.values

#one hour
#test_X, test_y = values[:, :-out_hour], values[:,-1]


test_X, test_y = values[:, :-out_hour], values[:, -out_hour: ]


test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
# Out:
# (6343, 27)
#     var1(t-6)  var2(t-6)  var3(t-6)  var1(t-5)  var2(t-5)  var3(t-5)  \
# 6    0.230769   0.401887   0.699029   0.230769   0.438261   0.723301
# 7    0.230769   0.438261   0.723301   0.230769   0.476275   0.747573
# 8    0.230769   0.476275   0.747573   0.230769   0.500068   0.762136
# 9    0.230769   0.500068   0.762136   0.230769   0.524545   0.776699
# 10   0.230769   0.524545   0.776699   0.215385   0.524545   0.776699
#
#     var1(t-4)  var2(t-4)  var3(t-4)  var1(t-3)  ...  var3(t-3)  var1(t-2)  \
# 6    0.230769   0.476275   0.747573   0.230769  ...   0.762136   0.230769
# 7    0.230769   0.500068   0.762136   0.230769  ...   0.776699   0.215385
# 8    0.230769   0.524545   0.776699   0.215385  ...   0.776699   0.123077
# 9    0.215385   0.524545   0.776699   0.123077  ...   0.791262   0.092308
# 10   0.123077   0.549980   0.791262   0.092308  ...   0.820388   0.092308
#
#     var2(t-2)  var3(t-2)  var1(t-1)  var2(t-1)  var3(t-1)   var3(t)  \
# 6    0.524545   0.776699   0.215385   0.524545   0.776699  0.791262
# 7    0.524545   0.776699   0.123077   0.549980   0.791262  0.820388
# 8    0.549980   0.791262   0.092308   0.603309   0.820388  0.844660
# 9    0.603309   0.820388   0.092308   0.650485   0.844660  0.873786
# 10   0.650485   0.844660   0.092308   0.709285   0.873786  0.898058
#
#     var3(t+1)  var3(t+2)
# 6    0.820388   0.844660
# 7    0.844660   0.873786
# 8    0.873786   0.898058
# 9    0.898058   0.932039
# 10   0.932039   0.966019
#
# [5 rows x 21 columns]

# %%
score = model.evaluate(test_X, test_y, verbose=0)
out=model.predict(test_X)

# %%
print('The testing MAE loss is:', str(score[2]))
print('The testing MSE loss is:', str(score[1]))
print('The testing RMSE loss is:', str(score[3]))
# Out:
# The testing MAE loss is: 0.033597846
# The testing MSE loss is: 0.0050604898
# The testing RMSE loss is: 0.07113714

# %%
pyplot.plot(test_y[:,2],color='red', label='True Values')
pyplot.plot(out[:,2],color='blue',label='Predicted values')
pyplot.title("Level Predictions")
pyplot.legend(loc='upper left')
pyplot.xlabel("Samples")
pyplot.ylabel("Level")
pyplot.show()
